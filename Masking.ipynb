# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset, ConcatDataset
from torch_geometric.loader import DataLoader as GeometricDataLoader
from torch_geometric.data import Data
from torch_geometric.utils import dense_to_sparse, k_hop_subgraph
import torch_geometric.nn as pyg_nn
from scipy.io import loadmat, savemat
import os
import matplotlib.pyplot as plt

# %%
# Load saved beta data from mat file
analysis_type = 'N170'
curr_dir = os.getcwd()
datain_dir = os.path.join(os.getcwd(), 'datain')
datain_mat = loadmat(os.path.join(datain_dir, analysis_type + '_original_betas.mat'))
binatry_matrix_mat = loadmat(os.path.join(datain_dir, 'adjacency_matrix.mat'))
datain = datain_mat['data']
binatry_matrix = binatry_matrix_mat['adjacency_matrix']

datain = np.array(datain)          # shape: [nBeta, nTime, nChan, nSubject] (adjust as needed)
binatry_matrix = np.array(binatry_matrix)

# Parse shapes
nBeta     = datain.shape[0]
nTime     = datain.shape[1]
nChan     = datain.shape[2]
nSubject  = datain.shape[3]
print(f'Data shape: {datain.shape}') # shape: [nBeta, nTime, nChan, nSubject]
# Out:
# Data shape: (5, 201, 30, 39)

# %%
# ===========================================
# 2) Set device & convert adjacency
# ===========================================
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
edge_index, _ = dense_to_sparse(torch.tensor(binatry_matrix, dtype=torch.float32))
print(device)

# ===========================================
# 3) Dataset builder
# ===========================================
def build_concat_dataset_for_beta(datain, beta_idx):
    """
    Build a ConcatDataset across all subjects for one beta index.
    `datain` is [nBeta, nTime, nChan, nSubject].
    Returns: ConcatDataset of length nSubject.
    """
    subject_datasets = []
    for s in range(nSubject):
        # Extract slice for one subject and one beta
        # shape: [nTime, nChan]
        single_beta_data = datain[beta_idx, :, :, s]

        # If each node is a channel and its feature dimension is time,
        # we might want single_beta_data to be [nChan, nTime].
        # If so, transpose here:
        single_beta_data = single_beta_data.T  # shape: [nChan, nTime]

        # For an autoencoder, features=labels
        x_tensor = torch.tensor(single_beta_data, dtype=torch.float32)
        x_tensor = x_tensor.unsqueeze(0)

        subject_datasets.append(TensorDataset(x_tensor, x_tensor))

    return ConcatDataset(subject_datasets)
# Out:
# cuda

# %%
# ===========================================
# 4) PyG Graph Dataset
# ===========================================
class EEGGraphDataset(torch.utils.data.Dataset):
    """
    Wraps a standard dataset so that each item is a PyG Data object:
      x -> node features (channels)
      edge_index -> adjacency
    """
    def __init__(self, eeg_data, edge_index):
        self.eeg_data = eeg_data
        self.edge_index = edge_index

    def __len__(self):
        return len(self.eeg_data)

    def __getitem__(self, idx):
        # item: (x, x) because it's autoencoder
        sample = self.eeg_data[idx]
        x = sample[0]  # shape: [nChan, nTime] (if you used transpose above)
        # Convert x -> float32, build PyG Data
        graph_data = Data(x=torch.tensor(x, dtype=torch.float32),
                          edge_index=self.edge_index)
        return graph_data

# %%
# ===========================================
# 5) Define GraphAutoencoder
# ===========================================
class GraphAutoencoder(nn.Module):
    def __init__(self, num_features, embedding_dim=64):
        """
        num_features = dimension of each node's feature vector.
                       If each channel is a node, and you pass
                       [nChan, nTime], then num_features = nTime.
        """
        super(GraphAutoencoder, self).__init__()
        # Example with two ARMAConv layers
        self.encoder_gcn1 = pyg_nn.ARMAConv(num_features, 128, 
                                            num_stacks=2, 
                                            num_layers=3,
                                            shared_weights=True)
        self.encoder_gcn2 = pyg_nn.ARMAConv(128, embedding_dim, 
                                            num_stacks=2, 
                                            num_layers=3,
                                            shared_weights=True)
        self.decoder_fc1 = nn.Linear(embedding_dim, 128)
        self.decoder_fc2 = nn.Linear(128, num_features)

    def forward(self, x, edge_index):
        x = torch.relu(self.encoder_gcn1(x, edge_index))
        latent = torch.relu(self.encoder_gcn2(x, edge_index))
        x = torch.relu(self.decoder_fc1(latent))
        reconstructed = self.decoder_fc2(x)
        return reconstructed

# %%
# ===========================================
# 6) Training and evaluation
# ===========================================
def train_model_all(model, train_loader, device, num_epochs):
    model.to(device)
    optimizer = optim.Adam(model.parameters(), lr=1e-3)
    criterion = nn.SmoothL1Loss()

    for epoch in range(num_epochs):
        model.train()
        epoch_loss = 0.0
        for batch_data in train_loader:
            batch_data = batch_data.to(device)
            optimizer.zero_grad()

            # Forward
            reconstructed = model(batch_data.x, batch_data.edge_index)
            loss = criterion(reconstructed, batch_data.x)

            # Backprop
            loss.backward()
            optimizer.step()
            epoch_loss += loss.item()

        epoch_loss /= len(train_loader)
        print(f"Beta Model Training - Epoch [{epoch+1}/{num_epochs}], Loss: {epoch_loss:.4f}")
    return model

def evaluation_model(model, data_sample, edge_index, device):
    """
    data_sample: shape [nChan, nTime], or [nTime, nChan],
                 whichever you used in training.
    Returns: (original_np, reconstructed_np, error_np)
    """
    model.eval()
    with torch.no_grad():
        x = torch.tensor(data_sample, dtype=torch.float32, device=device)
        eidx = edge_index.to(device)
        reconstructed = model(x, eidx)
    orig = x.cpu().numpy()
    recon = reconstructed.cpu().numpy()
    error = orig - recon
    return orig, recon, error

# %%
# Channel Masking

# Define channel masking function with 'zero' and 'mean' methods
def channel_masking(x_n, ch_idx, mode='mean'):
    x_masked = x_n.copy()
    if mode == 'zero':
        x_masked[ch_idx, :] = 0.0
    # Mean of all other channels
    elif mode == 'mean':
        channel_mean = x_n.mean(axis=0)
        x_masked[ch_idx, :] = channel_mean
    return x_masked

# Apply channel masking and compute importance
def apply_channel_masking(model, sample_n, edge_index, device, mode='mean'):
    model.eval()
    with torch.no_grad():
        x = torch.tensor(sample_n, dtype=torch.float32, device=device)
        recon = model(x, edge_index.to(device))
        base_lose = nn.SmoothL1Loss()(recon, x).item()
        
        nChan = sample_n.shape[0]
        imp = np.zeros(nChan)
        
        # Iterate over channels to compute importance
        # The higher the loss increase, the more important the channel
        for c in range(nChan):
            x_masked = channel_masking(sample_n, c, mode=mode)
            x_masked = torch.tensor(x_masked, dtype=torch.float32, device=device)
            recon_masked = model(x_masked, edge_index.to(device))
            masked_loss = nn.SmoothL1Loss()(recon_masked, x).item()
            imp[c] = masked_loss - base_lose
            
    return imp

# %%
# Channel region hard masking

# Compute k-hop neighborhood channels for each channel
def compute_neighborhood_channels(edge_index, k=1):
    neighborhood_channels = []
    for c in range(edge_index.max().item() + 1):
        channels, _, _, _ = k_hop_subgraph(c, k, edge_index)
        neighborhood_channels.append(channels.cpu().numpy())
    return neighborhood_channels

# Define region hard masking function with 'zero' and 'mean' methods
def region_hard_masking(x_n, neig_list, mode='local_mean'):
    x_masked = x_n.copy()

    # Get the rest of the channels except the neighborhood list
    nChan = x_n.shape[0]
    mask_neig = np.zeros(nChan, dtype=bool)
    mask_neig[neig_list] = True
    mask_rest = ~mask_neig
    
    if mode == 'zero':
        x_masked[mask_neig, :] = 0.0
    # The mean of the rest of the channels
    elif mode == 'global_mean':
        if mask_rest.any():
            rest_mean = x_n[mask_rest, :].mean(axis=0)
        # If no rest channels, use overall mean
        else:
            rest_mean = x_n.mean(axis=0)
        x_masked[mask_neig, :] = rest_mean
    elif mode == 'local_mean':
        if mask_rest.any():
            local_mean = x_n[mask_neig, :].mean(axis=0)
        else:
            local_mean = x_n.mean(axis=0)
        x_masked[mask_neig, :] = local_mean
    return x_masked

# Apply region hard masking and compute importance
def apply_region_hard_masking(model, sample_n, edge_index, device, mode='mean', k=1):
    model.eval()
    with torch.no_grad():
        neighborhood_channels = compute_neighborhood_channels(edge_index, k)
        x = torch.tensor(sample_n, dtype=torch.float32, device=device)
        recon = model(x, edge_index.to(device))
        base_loss = nn.SmoothL1Loss()(recon, x).item()

        nChan = sample_n.shape[0]
        imp = np.zeros(nChan)
        
        for c in range(nChan):
            neig_list = neighborhood_channels[c]
            x_masked = region_hard_masking(sample_n, neig_list, mode=mode)
            x_masked = torch.tensor(x_masked, dtype=torch.float32, device=device)
            recon_masked = model(x_masked, edge_index.to(device))
            masked_loss = nn.SmoothL1Loss()(recon_masked, x).item()
            imp[c] = masked_loss - base_loss
    return imp

# %%
# Time frame masking
def time_frame_masking(x_n, seg_idx, boundaries, n_segments=10, mode='mean'):
    x_masked = x_n.copy()
    nTime = x_n.shape[1]
    
    start = boundaries[seg_idx]
    end = boundaries[seg_idx + 1]
    if mode == 'zero':
        x_masked[:, start:end] = 0.0
    elif mode == 'mean':
        mask = np.ones(nTime, dtype=bool)
        mask[start:end] = False
        time_mean = x_n[:, mask].mean(axis=1, keepdims=True)
        x_masked[:, start:end] = time_mean
    return x_masked

def apply_time_frame_masking(model, sample_n, edge_index, device, n_segments=10, mode='mean'):
    model.eval()
    with torch.no_grad():
        x = torch.tensor(sample_n, dtype=torch.float32, device=device)
        recon = model(x, edge_index.to(device))
        base_loss = nn.SmoothL1Loss()(recon, x).item()
        nTime = sample_n.shape[1]
        imp = np.zeros(n_segments)
        boundaries = np.linspace(0, nTime, n_segments + 1, dtype=int)
        for seg_idx in range(n_segments):
            x_masked = time_frame_masking(sample_n, seg_idx, boundaries, n_segments=n_segments, mode=mode)
            x_masked = torch.tensor(x_masked, dtype=torch.float32, device=device)
            recon_masked = model(x_masked, edge_index.to(device))
            masked_loss = nn.SmoothL1Loss()(recon_masked, x).item()
            imp[seg_idx] = masked_loss - base_loss
    return imp

# %%
num_features = nTime   # if each channel is a node, and feature vector = [nTime]
num_epochs   = 200     # number of training - set as needed
batch_size   = 4;      # dataset/batch to update hyperparameters

models = []

imp_chan_zero_list = []
imp_chan_mean_list = []
imp_region_localmean_list = []
imp_region_globalmean_list = []
imp_time_mean_list = []
imp_time_zero_list = []

for iBeta in range(nBeta):
    print(f"\n=== Building dataset/model for Beta {iBeta} ===")
    # Build dataset & loader
    full_dataset_i  = build_concat_dataset_for_beta(datain, iBeta)
    graph_dataset_i = EEGGraphDataset(full_dataset_i, edge_index)
    full_loader_i   = GeometricDataLoader(graph_dataset_i, batch_size=batch_size, shuffle=True)

    # Init model & train
    model_i = GraphAutoencoder(num_features=num_features, embedding_dim=32)
    model_i = train_model_all(model_i, full_loader_i, device, num_epochs=num_epochs)
    models.append(model_i)

    imp_chan_zero_per_subject = []
    imp_chan_mean_per_subject = []
    imp_region_localmean_per_subject = []
    imp_region_globalmean_per_subject = []
    imp_time_mean_per_subject = []
    imp_time_zero_per_subject = []
    for s in range(len(full_dataset_i)):
        x_s = full_dataset_i[s][0].numpy()  # [nChan, nTime]
        imp_chan_zero = apply_channel_masking(model_i, x_s, edge_index, device, mode='zero')
        imp_chan_mean = apply_channel_masking(model_i, x_s, edge_index, device, mode='mean')
        imp_region_localmean = apply_region_hard_masking(model_i, x_s, edge_index, device, mode='local_mean', k=1)
        imp_region_globalmean = apply_region_hard_masking(model_i, x_s, edge_index, device, mode='global_mean', k=1)
        imp_time_mean = apply_time_frame_masking(model_i, x_s, edge_index, device, n_segments=100, mode='mean')
        imp_time_zero = apply_time_frame_masking(model_i, x_s, edge_index, device, n_segments=100, mode='zero')
        imp_chan_zero_per_subject.append(imp_chan_zero)
        imp_chan_mean_per_subject.append(imp_chan_mean)
        imp_region_localmean_per_subject.append(imp_region_localmean)
        imp_region_globalmean_per_subject.append(imp_region_globalmean)
        imp_time_mean_per_subject.append(imp_time_mean)
        imp_time_zero_per_subject.append(imp_time_zero)

    imp_chan_zero_list.append(np.array(imp_chan_zero_per_subject))
    imp_chan_mean_list.append(np.array(imp_chan_mean_per_subject))
    imp_region_localmean_list.append(np.array(imp_region_localmean_per_subject))
    imp_region_globalmean_list.append(np.array(imp_region_globalmean_per_subject))
    imp_time_mean_list.append(np.array(imp_time_mean_per_subject))
    imp_time_zero_list.append(np.array(imp_time_zero_per_subject))

all_imp_chan_zero = np.array(imp_chan_zero_list)
all_imp_chan_mean = np.array(imp_chan_mean_list)
all_imp_region_localmean = np.array(imp_region_localmean_list)
all_imp_region_globalmean = np.array(imp_region_globalmean_list)
all_imp_time_mean = np.array(imp_time_mean_list)
all_imp_time_zero = np.array(imp_time_zero_list)
# Out:
# === Building dataset/model for Beta 0 ===
# Beta Model Training - Epoch [1/200], Loss: 1.8097
# Beta Model Training - Epoch [2/200], Loss: 1.6785
# C:\Users\86136\AppData\Local\Temp\ipykernel_54796\1382389434.py:22: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   graph_data = Data(x=torch.tensor(x, dtype=torch.float32),
# Beta Model Training - Epoch [3/200], Loss: 1.4894
# Beta Model Training - Epoch [4/200], Loss: 1.3622
# Beta Model Training - Epoch [5/200], Loss: 1.2610
# Beta Model Training - Epoch [6/200], Loss: 1.1798
# Beta Model Training - Epoch [7/200], Loss: 1.1151
# Beta Model Training - Epoch [8/200], Loss: 1.0630
# Beta Model Training - Epoch [9/200], Loss: 1.0217
# Beta Model Training - Epoch [10/200], Loss: 0.9846
# Beta Model Training - Epoch [11/200], Loss: 0.9520
# Beta Model Training - Epoch [12/200], Loss: 0.9229
# Beta Model Training - Epoch [13/200], Loss: 0.8901
# Beta Model Training - Epoch [14/200], Loss: 0.8638
# Beta Model Training - Epoch [15/200], Loss: 0.8430
# Beta Model Training - Epoch [16/200], Loss: 0.8160
# Beta Model Training - Epoch [17/200], Loss: 0.7940
# Beta Model Training - Epoch [18/200], Loss: 0.7732
# Beta Model Training - Epoch [19/200], Loss: 0.7583
# Beta Model Training - Epoch [20/200], Loss: 0.7427
# Beta Model Training - Epoch [21/200], Loss: 0.7288
# Beta Model Training - Epoch [22/200], Loss: 0.7162
# Beta Model Training - Epoch [23/200], Loss: 0.7102
# Beta Model Training - Epoch [24/200], Loss: 0.7042
# Beta Model Training - Epoch [25/200], Loss: 0.6899
# Beta Model Training - Epoch [26/200], Loss: 0.6893
# Beta Model Training - Epoch [27/200], Loss: 0.6840
# Beta Model Training - Epoch [28/200], Loss: 0.6753
# Beta Model Training - Epoch [29/200], Loss: 0.6733
# Beta Model Training - Epoch [30/200], Loss: 0.6655
# Beta Model Training - Epoch [31/200], Loss: 0.6539
# Beta Model Training - Epoch [32/200], Loss: 0.6358
# Beta Model Training - Epoch [33/200], Loss: 0.6315
# Beta Model Training - Epoch [34/200], Loss: 0.6241
# Beta Model Training - Epoch [35/200], Loss: 0.6191
# Beta Model Training - Epoch [36/200], Loss: 0.6155
# Beta Model Training - Epoch [37/200], Loss: 0.6107
# Beta Model Training - Epoch [38/200], Loss: 0.6019
# Beta Model Training - Epoch [39/200], Loss: 0.6034
# Beta Model Training - Epoch [40/200], Loss: 0.6017
# Beta Model Training - Epoch [41/200], Loss: 0.5989
# Beta Model Training - Epoch [42/200], Loss: 0.5947
# Beta Model Training - Epoch [43/200], Loss: 0.5900
# Beta Model Training - Epoch [44/200], Loss: 0.5840
# Beta Model Training - Epoch [45/200], Loss: 0.5827
# Beta Model Training - Epoch [46/200], Loss: 0.5775
# Beta Model Training - Epoch [47/200], Loss: 0.5720
# Beta Model Training - Epoch [48/200], Loss: 0.5659
# Beta Model Training - Epoch [49/200], Loss: 0.5571
# Beta Model Training - Epoch [50/200], Loss: 0.5526
# Beta Model Training - Epoch [51/200], Loss: 0.5504
# Beta Model Training - Epoch [52/200], Loss: 0.5453
# Beta Model Training - Epoch [53/200], Loss: 0.5436
# Beta Model Training - Epoch [54/200], Loss: 0.5419
# Beta Model Training - Epoch [55/200], Loss: 0.5395
# Beta Model Training - Epoch [56/200], Loss: 0.5349
# Beta Model Training - Epoch [57/200], Loss: 0.5369
# Beta Model Training - Epoch [58/200], Loss: 0.5342
# Beta Model Training - Epoch [59/200], Loss: 0.5307
# Beta Model Training - Epoch [60/200], Loss: 0.5270
# Beta Model Training - Epoch [61/200], Loss: 0.5220
# Beta Model Training - Epoch [62/200], Loss: 0.5208
# Beta Model Training - Epoch [63/200], Loss: 0.5263
# Beta Model Training - Epoch [64/200], Loss: 0.5257
# Beta Model Training - Epoch [65/200], Loss: 0.5149
# Beta Model Training - Epoch [66/200], Loss: 0.5191
# Beta Model Training - Epoch [67/200], Loss: 0.5119
# Beta Model Training - Epoch [68/200], Loss: 0.5078
# Beta Model Training - Epoch [69/200], Loss: 0.5031
# Beta Model Training - Epoch [70/200], Loss: 0.5012
# Beta Model Training - Epoch [71/200], Loss: 0.5025
# Beta Model Training - Epoch [72/200], Loss: 0.5048
# Beta Model Training - Epoch [73/200], Loss: 0.5051
# Beta Model Training - Epoch [74/200], Loss: 0.5022
# Beta Model Training - Epoch [75/200], Loss: 0.5014
# Beta Model Training - Epoch [76/200], Loss: 0.4993
# Beta Model Training - Epoch [77/200], Loss: 0.5185
# Beta Model Training - Epoch [78/200], Loss: 0.5298
# Beta Model Training - Epoch [79/200], Loss: 0.5197
# Beta Model Training - Epoch [80/200], Loss: 0.5035
# Beta Model Training - Epoch [81/200], Loss: 0.4974
# Beta Model Training - Epoch [82/200], Loss: 0.4958
# Beta Model Training - Epoch [83/200], Loss: 0.4970
# Beta Model Training - Epoch [84/200], Loss: 0.4882
# Beta Model Training - Epoch [85/200], Loss: 0.4846
# Beta Model Training - Epoch [86/200], Loss: 0.4817
# Beta Model Training - Epoch [87/200], Loss: 0.4795
# Beta Model Training - Epoch [88/200], Loss: 0.4794
# Beta Model Training - Epoch [89/200], Loss: 0.4794
# Beta Model Training - Epoch [90/200], Loss: 0.4756
# Beta Model Training - Epoch [91/200], Loss: 0.4738
# Beta Model Training - Epoch [92/200], Loss: 0.4786
# Beta Model Training - Epoch [93/200], Loss: 0.4856
# Beta Model Training - Epoch [94/200], Loss: 0.4794
# Beta Model Training - Epoch [95/200], Loss: 0.4769
# Beta Model Training - Epoch [96/200], Loss: 0.4748
# Beta Model Training - Epoch [97/200], Loss: 0.4748
# Beta Model Training - Epoch [98/200], Loss: 0.4717
# Beta Model Training - Epoch [99/200], Loss: 0.4750
# Beta Model Training - Epoch [100/200], Loss: 0.4834
# Beta Model Training - Epoch [101/200], Loss: 0.4768
# Beta Model Training - Epoch [102/200], Loss: 0.4720
# Beta Model Training - Epoch [103/200], Loss: 0.4678
# Beta Model Training - Epoch [104/200], Loss: 0.4651
# Beta Model Training - Epoch [105/200], Loss: 0.4682
# Beta Model Training - Epoch [106/200], Loss: 0.4660
# Beta Model Training - Epoch [107/200], Loss: 0.4630
# Beta Model Training - Epoch [108/200], Loss: 0.4623
# Beta Model Training - Epoch [109/200], Loss: 0.4606
# Beta Model Training - Epoch [110/200], Loss: 0.4612
# Beta Model Training - Epoch [111/200], Loss: 0.4593
# Beta Model Training - Epoch [112/200], Loss: 0.4612
# Beta Model Training - Epoch [113/200], Loss: 0.4650
# Beta Model Training - Epoch [114/200], Loss: 0.4631
# Beta Model Training - Epoch [115/200], Loss: 0.4630
# Beta Model Training - Epoch [116/200], Loss: 0.4605
# Beta Model Training - Epoch [117/200], Loss: 0.4602
# Beta Model Training - Epoch [118/200], Loss: 0.4648
# Beta Model Training - Epoch [119/200], Loss: 0.4748
# Beta Model Training - Epoch [120/200], Loss: 0.4718
# Beta Model Training - Epoch [121/200], Loss: 0.4723
# Beta Model Training - Epoch [122/200], Loss: 0.4751
# Beta Model Training - Epoch [123/200], Loss: 0.4709
# Beta Model Training - Epoch [124/200], Loss: 0.4628
# Beta Model Training - Epoch [125/200], Loss: 0.4624
# Beta Model Training - Epoch [126/200], Loss: 0.4618
# Beta Model Training - Epoch [127/200], Loss: 0.4623
# Beta Model Training - Epoch [128/200], Loss: 0.4605
# Beta Model Training - Epoch [129/200], Loss: 0.4612
# Beta Model Training - Epoch [130/200], Loss: 0.4583
# Beta Model Training - Epoch [131/200], Loss: 0.4578
# Beta Model Training - Epoch [132/200], Loss: 0.4603
# Beta Model Training - Epoch [133/200], Loss: 0.4587
# Beta Model Training - Epoch [134/200], Loss: 0.4591
# Beta Model Training - Epoch [135/200], Loss: 0.4575
# Beta Model Training - Epoch [136/200], Loss: 0.4561
# Beta Model Training - Epoch [137/200], Loss: 0.4564
# Beta Model Training - Epoch [138/200], Loss: 0.4533
# Beta Model Training - Epoch [139/200], Loss: 0.4518
# Beta Model Training - Epoch [140/200], Loss: 0.4547
# Beta Model Training - Epoch [141/200], Loss: 0.4548
# Beta Model Training - Epoch [142/200], Loss: 0.4535
# Beta Model Training - Epoch [143/200], Loss: 0.4562
# Beta Model Training - Epoch [144/200], Loss: 0.4529
# Beta Model Training - Epoch [145/200], Loss: 0.4514
# Beta Model Training - Epoch [146/200], Loss: 0.4547
# Beta Model Training - Epoch [147/200], Loss: 0.4564
# Beta Model Training - Epoch [148/200], Loss: 0.4633
# Beta Model Training - Epoch [149/200], Loss: 0.4674
# Beta Model Training - Epoch [150/200], Loss: 0.4606
# Beta Model Training - Epoch [151/200], Loss: 0.4684
# Beta Model Training - Epoch [152/200], Loss: 0.4763
# Beta Model Training - Epoch [153/200], Loss: 0.4601
# Beta Model Training - Epoch [154/200], Loss: 0.4538
# Beta Model Training - Epoch [155/200], Loss: 0.4544
# Beta Model Training - Epoch [156/200], Loss: 0.4559
# Beta Model Training - Epoch [157/200], Loss: 0.4617
# Beta Model Training - Epoch [158/200], Loss: 0.4559
# Beta Model Training - Epoch [159/200], Loss: 0.4543
# Beta Model Training - Epoch [160/200], Loss: 0.4538
# Beta Model Training - Epoch [161/200], Loss: 0.4525
# Beta Model Training - Epoch [162/200], Loss: 0.4508
# Beta Model Training - Epoch [163/200], Loss: 0.4521
# Beta Model Training - Epoch [164/200], Loss: 0.4486
# Beta Model Training - Epoch [165/200], Loss: 0.4483
# Beta Model Training - Epoch [166/200], Loss: 0.4474
# Beta Model Training - Epoch [167/200], Loss: 0.4459
# Beta Model Training - Epoch [168/200], Loss: 0.4452
# Beta Model Training - Epoch [169/200], Loss: 0.4458
# Beta Model Training - Epoch [170/200], Loss: 0.4455
# Beta Model Training - Epoch [171/200], Loss: 0.4451
# Beta Model Training - Epoch [172/200], Loss: 0.4466
# Beta Model Training - Epoch [173/200], Loss: 0.4461
# Beta Model Training - Epoch [174/200], Loss: 0.4474
# Beta Model Training - Epoch [175/200], Loss: 0.4473
# Beta Model Training - Epoch [176/200], Loss: 0.4438
# Beta Model Training - Epoch [177/200], Loss: 0.4420
# Beta Model Training - Epoch [178/200], Loss: 0.4423
# Beta Model Training - Epoch [179/200], Loss: 0.4425
# Beta Model Training - Epoch [180/200], Loss: 0.4413
# Beta Model Training - Epoch [181/200], Loss: 0.4432
# Beta Model Training - Epoch [182/200], Loss: 0.4450
# Beta Model Training - Epoch [183/200], Loss: 0.4456
# Beta Model Training - Epoch [184/200], Loss: 0.4473
# Beta Model Training - Epoch [185/200], Loss: 0.4472
# Beta Model Training - Epoch [186/200], Loss: 0.4480
# Beta Model Training - Epoch [187/200], Loss: 0.4534
# Beta Model Training - Epoch [188/200], Loss: 0.4528
# Beta Model Training - Epoch [189/200], Loss: 0.4531
# Beta Model Training - Epoch [190/200], Loss: 0.4634
# Beta Model Training - Epoch [191/200], Loss: 0.4611
# Beta Model Training - Epoch [192/200], Loss: 0.4580
# Beta Model Training - Epoch [193/200], Loss: 0.4489
# Beta Model Training - Epoch [194/200], Loss: 0.4489
# Beta Model Training - Epoch [195/200], Loss: 0.4507
# Beta Model Training - Epoch [196/200], Loss: 0.4463
# Beta Model Training - Epoch [197/200], Loss: 0.4476
# Beta Model Training - Epoch [198/200], Loss: 0.4454
# Beta Model Training - Epoch [199/200], Loss: 0.4436
# Beta Model Training - Epoch [200/200], Loss: 0.4412
#
# === Building dataset/model for Beta 1 ===
# Beta Model Training - Epoch [1/200], Loss: 1.8780
# Beta Model Training - Epoch [2/200], Loss: 1.7553
# Beta Model Training - Epoch [3/200], Loss: 1.5753
# Beta Model Training - Epoch [4/200], Loss: 1.4790
# Beta Model Training - Epoch [5/200], Loss: 1.4054
# Beta Model Training - Epoch [6/200], Loss: 1.3351
# Beta Model Training - Epoch [7/200], Loss: 1.2665
# Beta Model Training - Epoch [8/200], Loss: 1.2057
# Beta Model Training - Epoch [9/200], Loss: 1.1593
# Beta Model Training - Epoch [10/200], Loss: 1.1103
# Beta Model Training - Epoch [11/200], Loss: 1.0657
# Beta Model Training - Epoch [12/200], Loss: 1.0275
# Beta Model Training - Epoch [13/200], Loss: 0.9962
# Beta Model Training - Epoch [14/200], Loss: 0.9686
# Beta Model Training - Epoch [15/200], Loss: 0.9476
# Beta Model Training - Epoch [16/200], Loss: 0.9187
# Beta Model Training - Epoch [17/200], Loss: 0.8932
# Beta Model Training - Epoch [18/200], Loss: 0.8695
# Beta Model Training - Epoch [19/200], Loss: 0.8569
# Beta Model Training - Epoch [20/200], Loss: 0.8387
# Beta Model Training - Epoch [21/200], Loss: 0.8257
# Beta Model Training - Epoch [22/200], Loss: 0.8097
# Beta Model Training - Epoch [23/200], Loss: 0.7936
# Beta Model Training - Epoch [24/200], Loss: 0.7824
# Beta Model Training - Epoch [25/200], Loss: 0.7818
# Beta Model Training - Epoch [26/200], Loss: 0.7709
# Beta Model Training - Epoch [27/200], Loss: 0.7499
# Beta Model Training - Epoch [28/200], Loss: 0.7388
# Beta Model Training - Epoch [29/200], Loss: 0.7260
# Beta Model Training - Epoch [30/200], Loss: 0.7132
# Beta Model Training - Epoch [31/200], Loss: 0.7011
# Beta Model Training - Epoch [32/200], Loss: 0.6924
# Beta Model Training - Epoch [33/200], Loss: 0.6905
# Beta Model Training - Epoch [34/200], Loss: 0.6823
# Beta Model Training - Epoch [35/200], Loss: 0.6739
# Beta Model Training - Epoch [36/200], Loss: 0.6659
# Beta Model Training - Epoch [37/200], Loss: 0.6634
# Beta Model Training - Epoch [38/200], Loss: 0.6610
# Beta Model Training - Epoch [39/200], Loss: 0.6589
# Beta Model Training - Epoch [40/200], Loss: 0.6603
# Beta Model Training - Epoch [41/200], Loss: 0.6500
# Beta Model Training - Epoch [42/200], Loss: 0.6462
# Beta Model Training - Epoch [43/200], Loss: 0.6498
# Beta Model Training - Epoch [44/200], Loss: 0.6382
# Beta Model Training - Epoch [45/200], Loss: 0.6419
# Beta Model Training - Epoch [46/200], Loss: 0.6308
# Beta Model Training - Epoch [47/200], Loss: 0.6386
# Beta Model Training - Epoch [48/200], Loss: 0.6307
# Beta Model Training - Epoch [49/200], Loss: 0.6235
# Beta Model Training - Epoch [50/200], Loss: 0.6219
# Beta Model Training - Epoch [51/200], Loss: 0.6141
# Beta Model Training - Epoch [52/200], Loss: 0.6140
# Beta Model Training - Epoch [53/200], Loss: 0.6117
# Beta Model Training - Epoch [54/200], Loss: 0.6082
# Beta Model Training - Epoch [55/200], Loss: 0.6138
# Beta Model Training - Epoch [56/200], Loss: 0.6097
# Beta Model Training - Epoch [57/200], Loss: 0.6023
# Beta Model Training - Epoch [58/200], Loss: 0.5966
# Beta Model Training - Epoch [59/200], Loss: 0.5931
# Beta Model Training - Epoch [60/200], Loss: 0.5916
# Beta Model Training - Epoch [61/200], Loss: 0.5875
# Beta Model Training - Epoch [62/200], Loss: 0.5867
# Beta Model Training - Epoch [63/200], Loss: 0.5828
# Beta Model Training - Epoch [64/200], Loss: 0.5818
# Beta Model Training - Epoch [65/200], Loss: 0.5824
# Beta Model Training - Epoch [66/200], Loss: 0.5772
# Beta Model Training - Epoch [67/200], Loss: 0.5746
# Beta Model Training - Epoch [68/200], Loss: 0.5770
# Beta Model Training - Epoch [69/200], Loss: 0.5710
# Beta Model Training - Epoch [70/200], Loss: 0.5738
# Beta Model Training - Epoch [71/200], Loss: 0.5710
# Beta Model Training - Epoch [72/200], Loss: 0.5654
# Beta Model Training - Epoch [73/200], Loss: 0.5623
# Beta Model Training - Epoch [74/200], Loss: 0.5612
# Beta Model Training - Epoch [75/200], Loss: 0.5566
# Beta Model Training - Epoch [76/200], Loss: 0.5564
# Beta Model Training - Epoch [77/200], Loss: 0.5555
# Beta Model Training - Epoch [78/200], Loss: 0.5525
# Beta Model Training - Epoch [79/200], Loss: 0.5518
# Beta Model Training - Epoch [80/200], Loss: 0.5519
# Beta Model Training - Epoch [81/200], Loss: 0.5512
# Beta Model Training - Epoch [82/200], Loss: 0.5518
# Beta Model Training - Epoch [83/200], Loss: 0.5502
# Beta Model Training - Epoch [84/200], Loss: 0.5494
# Beta Model Training - Epoch [85/200], Loss: 0.5511
# Beta Model Training - Epoch [86/200], Loss: 0.5567
# Beta Model Training - Epoch [87/200], Loss: 0.5741
# Beta Model Training - Epoch [88/200], Loss: 0.5571
# Beta Model Training - Epoch [89/200], Loss: 0.5450
# Beta Model Training - Epoch [90/200], Loss: 0.5376
# Beta Model Training - Epoch [91/200], Loss: 0.5349
# Beta Model Training - Epoch [92/200], Loss: 0.5335
# Beta Model Training - Epoch [93/200], Loss: 0.5358
# Beta Model Training - Epoch [94/200], Loss: 0.5361
# Beta Model Training - Epoch [95/200], Loss: 0.5438
# Beta Model Training - Epoch [96/200], Loss: 0.5415
# Beta Model Training - Epoch [97/200], Loss: 0.5460
# Beta Model Training - Epoch [98/200], Loss: 0.5464
# Beta Model Training - Epoch [99/200], Loss: 0.5503
# Beta Model Training - Epoch [100/200], Loss: 0.5491
# Beta Model Training - Epoch [101/200], Loss: 0.5502
# Beta Model Training - Epoch [102/200], Loss: 0.5633
# Beta Model Training - Epoch [103/200], Loss: 0.5365
# Beta Model Training - Epoch [104/200], Loss: 0.5396
# Beta Model Training - Epoch [105/200], Loss: 0.5657
# Beta Model Training - Epoch [106/200], Loss: 0.5651
# Beta Model Training - Epoch [107/200], Loss: 0.5352
# Beta Model Training - Epoch [108/200], Loss: 0.5457
# Beta Model Training - Epoch [109/200], Loss: 0.5288
# Beta Model Training - Epoch [110/200], Loss: 0.5180
# Beta Model Training - Epoch [111/200], Loss: 0.5145
# Beta Model Training - Epoch [112/200], Loss: 0.5158
# Beta Model Training - Epoch [113/200], Loss: 0.5133
# Beta Model Training - Epoch [114/200], Loss: 0.5096
# Beta Model Training - Epoch [115/200], Loss: 0.5073
# Beta Model Training - Epoch [116/200], Loss: 0.5058
# Beta Model Training - Epoch [117/200], Loss: 0.5057
# Beta Model Training - Epoch [118/200], Loss: 0.5030
# Beta Model Training - Epoch [119/200], Loss: 0.5060
# Beta Model Training - Epoch [120/200], Loss: 0.5040
# Beta Model Training - Epoch [121/200], Loss: 0.5019
# Beta Model Training - Epoch [122/200], Loss: 0.5059
# Beta Model Training - Epoch [123/200], Loss: 0.5048
# Beta Model Training - Epoch [124/200], Loss: 0.5052
# Beta Model Training - Epoch [125/200], Loss: 0.5149
# Beta Model Training - Epoch [126/200], Loss: 0.5080
# Beta Model Training - Epoch [127/200], Loss: 0.5040
# Beta Model Training - Epoch [128/200], Loss: 0.4984
# Beta Model Training - Epoch [129/200], Loss: 0.4989
# Beta Model Training - Epoch [130/200], Loss: 0.5015
# Beta Model Training - Epoch [131/200], Loss: 0.4960
# Beta Model Training - Epoch [132/200], Loss: 0.4954
# Beta Model Training - Epoch [133/200], Loss: 0.4966
# Beta Model Training - Epoch [134/200], Loss: 0.5047
# Beta Model Training - Epoch [135/200], Loss: 0.4961
# Beta Model Training - Epoch [136/200], Loss: 0.4931
# Beta Model Training - Epoch [137/200], Loss: 0.4958
# Beta Model Training - Epoch [138/200], Loss: 0.4919
# Beta Model Training - Epoch [139/200], Loss: 0.4912
# Beta Model Training - Epoch [140/200], Loss: 0.4951
# Beta Model Training - Epoch [141/200], Loss: 0.5122
# Beta Model Training - Epoch [142/200], Loss: 0.5156
# Beta Model Training - Epoch [143/200], Loss: 0.5003
# Beta Model Training - Epoch [144/200], Loss: 0.4981
# Beta Model Training - Epoch [145/200], Loss: 0.4939
# Beta Model Training - Epoch [146/200], Loss: 0.4914
# Beta Model Training - Epoch [147/200], Loss: 0.4898
# Beta Model Training - Epoch [148/200], Loss: 0.4880
# Beta Model Training - Epoch [149/200], Loss: 0.4860
# Beta Model Training - Epoch [150/200], Loss: 0.4877
# Beta Model Training - Epoch [151/200], Loss: 0.4853
# Beta Model Training - Epoch [152/200], Loss: 0.4854
# Beta Model Training - Epoch [153/200], Loss: 0.4850
# Beta Model Training - Epoch [154/200], Loss: 0.4894
# Beta Model Training - Epoch [155/200], Loss: 0.4845
# Beta Model Training - Epoch [156/200], Loss: 0.4829
# Beta Model Training - Epoch [157/200], Loss: 0.4838
# Beta Model Training - Epoch [158/200], Loss: 0.4851
# Beta Model Training - Epoch [159/200], Loss: 0.4837
# Beta Model Training - Epoch [160/200], Loss: 0.4803
# Beta Model Training - Epoch [161/200], Loss: 0.4810
# Beta Model Training - Epoch [162/200], Loss: 0.4823
# Beta Model Training - Epoch [163/200], Loss: 0.4809
# Beta Model Training - Epoch [164/200], Loss: 0.4858
# Beta Model Training - Epoch [165/200], Loss: 0.4884
# Beta Model Training - Epoch [166/200], Loss: 0.4848
# Beta Model Training - Epoch [167/200], Loss: 0.4836
# Beta Model Training - Epoch [168/200], Loss: 0.4798
# Beta Model Training - Epoch [169/200], Loss: 0.4787
# Beta Model Training - Epoch [170/200], Loss: 0.4770
# Beta Model Training - Epoch [171/200], Loss: 0.4761
# Beta Model Training - Epoch [172/200], Loss: 0.4777
# Beta Model Training - Epoch [173/200], Loss: 0.4766
# Beta Model Training - Epoch [174/200], Loss: 0.4754
# Beta Model Training - Epoch [175/200], Loss: 0.4780
# Beta Model Training - Epoch [176/200], Loss: 0.4794
# Beta Model Training - Epoch [177/200], Loss: 0.4923
# Beta Model Training - Epoch [178/200], Loss: 0.5166
# Beta Model Training - Epoch [179/200], Loss: 0.4970
# Beta Model Training - Epoch [180/200], Loss: 0.4922
# Beta Model Training - Epoch [181/200], Loss: 0.4938
# Beta Model Training - Epoch [182/200], Loss: 0.4891
# Beta Model Training - Epoch [183/200], Loss: 0.4838
# Beta Model Training - Epoch [184/200], Loss: 0.4882
# Beta Model Training - Epoch [185/200], Loss: 0.5134
# Beta Model Training - Epoch [186/200], Loss: 0.5218
# Beta Model Training - Epoch [187/200], Loss: 0.5020
# Beta Model Training - Epoch [188/200], Loss: 0.4833
# Beta Model Training - Epoch [189/200], Loss: 0.4815
# Beta Model Training - Epoch [190/200], Loss: 0.4786
# Beta Model Training - Epoch [191/200], Loss: 0.4805
# Beta Model Training - Epoch [192/200], Loss: 0.4770
# Beta Model Training - Epoch [193/200], Loss: 0.4736
# Beta Model Training - Epoch [194/200], Loss: 0.4729
# Beta Model Training - Epoch [195/200], Loss: 0.4730
# Beta Model Training - Epoch [196/200], Loss: 0.4742
# Beta Model Training - Epoch [197/200], Loss: 0.4720
# Beta Model Training - Epoch [198/200], Loss: 0.4694
# Beta Model Training - Epoch [199/200], Loss: 0.4725
# Beta Model Training - Epoch [200/200], Loss: 0.4767
#
# === Building dataset/model for Beta 2 ===
# Beta Model Training - Epoch [1/200], Loss: 1.8084
# Beta Model Training - Epoch [2/200], Loss: 1.7107
# Beta Model Training - Epoch [3/200], Loss: 1.5741
# Beta Model Training - Epoch [4/200], Loss: 1.4762
# Beta Model Training - Epoch [5/200], Loss: 1.4089
# Beta Model Training - Epoch [6/200], Loss: 1.3431
# Beta Model Training - Epoch [7/200], Loss: 1.2776
# Beta Model Training - Epoch [8/200], Loss: 1.2183
# Beta Model Training - Epoch [9/200], Loss: 1.1602
# Beta Model Training - Epoch [10/200], Loss: 1.1061
# Beta Model Training - Epoch [11/200], Loss: 1.0565
# Beta Model Training - Epoch [12/200], Loss: 1.0167
# Beta Model Training - Epoch [13/200], Loss: 0.9829
# Beta Model Training - Epoch [14/200], Loss: 0.9469
# Beta Model Training - Epoch [15/200], Loss: 0.9107
# Beta Model Training - Epoch [16/200], Loss: 0.8771
# Beta Model Training - Epoch [17/200], Loss: 0.8544
# Beta Model Training - Epoch [18/200], Loss: 0.8335
# Beta Model Training - Epoch [19/200], Loss: 0.8212
# Beta Model Training - Epoch [20/200], Loss: 0.8085
# Beta Model Training - Epoch [21/200], Loss: 0.7882
# Beta Model Training - Epoch [22/200], Loss: 0.7788
# Beta Model Training - Epoch [23/200], Loss: 0.7702
# Beta Model Training - Epoch [24/200], Loss: 0.7587
# Beta Model Training - Epoch [25/200], Loss: 0.7387
# Beta Model Training - Epoch [26/200], Loss: 0.7238
# Beta Model Training - Epoch [27/200], Loss: 0.7139
# Beta Model Training - Epoch [28/200], Loss: 0.7055
# Beta Model Training - Epoch [29/200], Loss: 0.6957
# Beta Model Training - Epoch [30/200], Loss: 0.6879
# Beta Model Training - Epoch [31/200], Loss: 0.6850
# Beta Model Training - Epoch [32/200], Loss: 0.6768
# Beta Model Training - Epoch [33/200], Loss: 0.6699
# Beta Model Training - Epoch [34/200], Loss: 0.6645
# Beta Model Training - Epoch [35/200], Loss: 0.6631
# Beta Model Training - Epoch [36/200], Loss: 0.6587
# Beta Model Training - Epoch [37/200], Loss: 0.6547
# Beta Model Training - Epoch [38/200], Loss: 0.6535
# Beta Model Training - Epoch [39/200], Loss: 0.6444
# Beta Model Training - Epoch [40/200], Loss: 0.6398
# Beta Model Training - Epoch [41/200], Loss: 0.6360
# Beta Model Training - Epoch [42/200], Loss: 0.6369
# Beta Model Training - Epoch [43/200], Loss: 0.6407
# Beta Model Training - Epoch [44/200], Loss: 0.6345
# Beta Model Training - Epoch [45/200], Loss: 0.6279
# Beta Model Training - Epoch [46/200], Loss: 0.6184
# Beta Model Training - Epoch [47/200], Loss: 0.6158
# Beta Model Training - Epoch [48/200], Loss: 0.6132
# Beta Model Training - Epoch [49/200], Loss: 0.6082
# Beta Model Training - Epoch [50/200], Loss: 0.6061
# Beta Model Training - Epoch [51/200], Loss: 0.6036
# Beta Model Training - Epoch [52/200], Loss: 0.6095
# Beta Model Training - Epoch [53/200], Loss: 0.5999
# Beta Model Training - Epoch [54/200], Loss: 0.5927
# Beta Model Training - Epoch [55/200], Loss: 0.5902
# Beta Model Training - Epoch [56/200], Loss: 0.5869
# Beta Model Training - Epoch [57/200], Loss: 0.5825
# Beta Model Training - Epoch [58/200], Loss: 0.5798
# Beta Model Training - Epoch [59/200], Loss: 0.5835
# Beta Model Training - Epoch [60/200], Loss: 0.5841
# Beta Model Training - Epoch [61/200], Loss: 0.5760
# Beta Model Training - Epoch [62/200], Loss: 0.5746
# Beta Model Training - Epoch [63/200], Loss: 0.5727
# Beta Model Training - Epoch [64/200], Loss: 0.5753
# Beta Model Training - Epoch [65/200], Loss: 0.5722
# Beta Model Training - Epoch [66/200], Loss: 0.5709
# Beta Model Training - Epoch [67/200], Loss: 0.5733
# Beta Model Training - Epoch [68/200], Loss: 0.5770
# Beta Model Training - Epoch [69/200], Loss: 0.5704
# Beta Model Training - Epoch [70/200], Loss: 0.5720
# Beta Model Training - Epoch [71/200], Loss: 0.5696
# Beta Model Training - Epoch [72/200], Loss: 0.5700
# Beta Model Training - Epoch [73/200], Loss: 0.5751
# Beta Model Training - Epoch [74/200], Loss: 0.5634
# Beta Model Training - Epoch [75/200], Loss: 0.5535
# Beta Model Training - Epoch [76/200], Loss: 0.5472
# Beta Model Training - Epoch [77/200], Loss: 0.5453
# Beta Model Training - Epoch [78/200], Loss: 0.5573
# Beta Model Training - Epoch [79/200], Loss: 0.5525
# Beta Model Training - Epoch [80/200], Loss: 0.5535
# Beta Model Training - Epoch [81/200], Loss: 0.5553
# Beta Model Training - Epoch [82/200], Loss: 0.5435
# Beta Model Training - Epoch [83/200], Loss: 0.5399
# Beta Model Training - Epoch [84/200], Loss: 0.5385
# Beta Model Training - Epoch [85/200], Loss: 0.5358
# Beta Model Training - Epoch [86/200], Loss: 0.5335
# Beta Model Training - Epoch [87/200], Loss: 0.5319
# Beta Model Training - Epoch [88/200], Loss: 0.5309
# Beta Model Training - Epoch [89/200], Loss: 0.5299
# Beta Model Training - Epoch [90/200], Loss: 0.5275
# Beta Model Training - Epoch [91/200], Loss: 0.5290
# Beta Model Training - Epoch [92/200], Loss: 0.5265
# Beta Model Training - Epoch [93/200], Loss: 0.5242
# Beta Model Training - Epoch [94/200], Loss: 0.5248
# Beta Model Training - Epoch [95/200], Loss: 0.5272
# Beta Model Training - Epoch [96/200], Loss: 0.5249
# Beta Model Training - Epoch [97/200], Loss: 0.5220
# Beta Model Training - Epoch [98/200], Loss: 0.5248
# Beta Model Training - Epoch [99/200], Loss: 0.5296
# Beta Model Training - Epoch [100/200], Loss: 0.5276
# Beta Model Training - Epoch [101/200], Loss: 0.5218
# Beta Model Training - Epoch [102/200], Loss: 0.5220
# Beta Model Training - Epoch [103/200], Loss: 0.5224
# Beta Model Training - Epoch [104/200], Loss: 0.5161
# Beta Model Training - Epoch [105/200], Loss: 0.5130
# Beta Model Training - Epoch [106/200], Loss: 0.5119
# Beta Model Training - Epoch [107/200], Loss: 0.5146
# Beta Model Training - Epoch [108/200], Loss: 0.5170
# Beta Model Training - Epoch [109/200], Loss: 0.5131
# Beta Model Training - Epoch [110/200], Loss: 0.5087
# Beta Model Training - Epoch [111/200], Loss: 0.5097
# Beta Model Training - Epoch [112/200], Loss: 0.5109
# Beta Model Training - Epoch [113/200], Loss: 0.5296
# Beta Model Training - Epoch [114/200], Loss: 0.5236
# Beta Model Training - Epoch [115/200], Loss: 0.5199
# Beta Model Training - Epoch [116/200], Loss: 0.5434
# Beta Model Training - Epoch [117/200], Loss: 0.5199
# Beta Model Training - Epoch [118/200], Loss: 0.5124
# Beta Model Training - Epoch [119/200], Loss: 0.5117
# Beta Model Training - Epoch [120/200], Loss: 0.5124
# Beta Model Training - Epoch [121/200], Loss: 0.5115
# Beta Model Training - Epoch [122/200], Loss: 0.5106
# Beta Model Training - Epoch [123/200], Loss: 0.5138
# Beta Model Training - Epoch [124/200], Loss: 0.5160
# Beta Model Training - Epoch [125/200], Loss: 0.5101
# Beta Model Training - Epoch [126/200], Loss: 0.5133
# Beta Model Training - Epoch [127/200], Loss: 0.5093
# Beta Model Training - Epoch [128/200], Loss: 0.5077
# Beta Model Training - Epoch [129/200], Loss: 0.5028
# Beta Model Training - Epoch [130/200], Loss: 0.4983
# Beta Model Training - Epoch [131/200], Loss: 0.4942
# Beta Model Training - Epoch [132/200], Loss: 0.4951
# Beta Model Training - Epoch [133/200], Loss: 0.4962
# Beta Model Training - Epoch [134/200], Loss: 0.4942
# Beta Model Training - Epoch [135/200], Loss: 0.4997
# Beta Model Training - Epoch [136/200], Loss: 0.4939
# Beta Model Training - Epoch [137/200], Loss: 0.4919
# Beta Model Training - Epoch [138/200], Loss: 0.4917
# Beta Model Training - Epoch [139/200], Loss: 0.4887
# Beta Model Training - Epoch [140/200], Loss: 0.4878
# Beta Model Training - Epoch [141/200], Loss: 0.4873
# Beta Model Training - Epoch [142/200], Loss: 0.4863
# Beta Model Training - Epoch [143/200], Loss: 0.4902
# Beta Model Training - Epoch [144/200], Loss: 0.4899
# Beta Model Training - Epoch [145/200], Loss: 0.4885
# Beta Model Training - Epoch [146/200], Loss: 0.4888
# Beta Model Training - Epoch [147/200], Loss: 0.4898
# Beta Model Training - Epoch [148/200], Loss: 0.4854
# Beta Model Training - Epoch [149/200], Loss: 0.4885
# Beta Model Training - Epoch [150/200], Loss: 0.4918
# Beta Model Training - Epoch [151/200], Loss: 0.4921
# Beta Model Training - Epoch [152/200], Loss: 0.4959
# Beta Model Training - Epoch [153/200], Loss: 0.4971
# Beta Model Training - Epoch [154/200], Loss: 0.4974
# Beta Model Training - Epoch [155/200], Loss: 0.5144
# Beta Model Training - Epoch [156/200], Loss: 0.5102
# Beta Model Training - Epoch [157/200], Loss: 0.5049
# Beta Model Training - Epoch [158/200], Loss: 0.4926
# Beta Model Training - Epoch [159/200], Loss: 0.4893
# Beta Model Training - Epoch [160/200], Loss: 0.4904
# Beta Model Training - Epoch [161/200], Loss: 0.4879
# Beta Model Training - Epoch [162/200], Loss: 0.4846
# Beta Model Training - Epoch [163/200], Loss: 0.4846
# Beta Model Training - Epoch [164/200], Loss: 0.4829
# Beta Model Training - Epoch [165/200], Loss: 0.4835
# Beta Model Training - Epoch [166/200], Loss: 0.4793
# Beta Model Training - Epoch [167/200], Loss: 0.4798
# Beta Model Training - Epoch [168/200], Loss: 0.4781
# Beta Model Training - Epoch [169/200], Loss: 0.4768
# Beta Model Training - Epoch [170/200], Loss: 0.4799
# Beta Model Training - Epoch [171/200], Loss: 0.4807
# Beta Model Training - Epoch [172/200], Loss: 0.4793
# Beta Model Training - Epoch [173/200], Loss: 0.4780
# Beta Model Training - Epoch [174/200], Loss: 0.4792
# Beta Model Training - Epoch [175/200], Loss: 0.4802
# Beta Model Training - Epoch [176/200], Loss: 0.4779
# Beta Model Training - Epoch [177/200], Loss: 0.4768
# Beta Model Training - Epoch [178/200], Loss: 0.4764
# Beta Model Training - Epoch [179/200], Loss: 0.4759
# Beta Model Training - Epoch [180/200], Loss: 0.4735
# Beta Model Training - Epoch [181/200], Loss: 0.4757
# Beta Model Training - Epoch [182/200], Loss: 0.4762
# Beta Model Training - Epoch [183/200], Loss: 0.4743
# Beta Model Training - Epoch [184/200], Loss: 0.4730
# Beta Model Training - Epoch [185/200], Loss: 0.4741
# Beta Model Training - Epoch [186/200], Loss: 0.4745
# Beta Model Training - Epoch [187/200], Loss: 0.4737
# Beta Model Training - Epoch [188/200], Loss: 0.4739
# Beta Model Training - Epoch [189/200], Loss: 0.4776
# Beta Model Training - Epoch [190/200], Loss: 0.4791
# Beta Model Training - Epoch [191/200], Loss: 0.4746
# Beta Model Training - Epoch [192/200], Loss: 0.4733
# Beta Model Training - Epoch [193/200], Loss: 0.4764
# Beta Model Training - Epoch [194/200], Loss: 0.4780
# Beta Model Training - Epoch [195/200], Loss: 0.4752
# Beta Model Training - Epoch [196/200], Loss: 0.4762
# Beta Model Training - Epoch [197/200], Loss: 0.4735
# Beta Model Training - Epoch [198/200], Loss: 0.4743
# Beta Model Training - Epoch [199/200], Loss: 0.4716
# Beta Model Training - Epoch [200/200], Loss: 0.4734
#
# === Building dataset/model for Beta 3 ===
# Beta Model Training - Epoch [1/200], Loss: 1.7737
# Beta Model Training - Epoch [2/200], Loss: 1.6482
# Beta Model Training - Epoch [3/200], Loss: 1.5135
# Beta Model Training - Epoch [4/200], Loss: 1.4448
# Beta Model Training - Epoch [5/200], Loss: 1.3686
# Beta Model Training - Epoch [6/200], Loss: 1.2924
# Beta Model Training - Epoch [7/200], Loss: 1.2230
# Beta Model Training - Epoch [8/200], Loss: 1.1662
# Beta Model Training - Epoch [9/200], Loss: 1.1139
# Beta Model Training - Epoch [10/200], Loss: 1.0688
# Beta Model Training - Epoch [11/200], Loss: 1.0242
# Beta Model Training - Epoch [12/200], Loss: 0.9890
# Beta Model Training - Epoch [13/200], Loss: 0.9539
# Beta Model Training - Epoch [14/200], Loss: 0.9279
# Beta Model Training - Epoch [15/200], Loss: 0.9025
# Beta Model Training - Epoch [16/200], Loss: 0.8661
# Beta Model Training - Epoch [17/200], Loss: 0.8403
# Beta Model Training - Epoch [18/200], Loss: 0.8157
# Beta Model Training - Epoch [19/200], Loss: 0.7927
# Beta Model Training - Epoch [20/200], Loss: 0.7745
# Beta Model Training - Epoch [21/200], Loss: 0.7567
# Beta Model Training - Epoch [22/200], Loss: 0.7486
# Beta Model Training - Epoch [23/200], Loss: 0.7334
# Beta Model Training - Epoch [24/200], Loss: 0.7214
# Beta Model Training - Epoch [25/200], Loss: 0.7083
# Beta Model Training - Epoch [26/200], Loss: 0.6908
# Beta Model Training - Epoch [27/200], Loss: 0.6789
# Beta Model Training - Epoch [28/200], Loss: 0.6696
# Beta Model Training - Epoch [29/200], Loss: 0.6617
# Beta Model Training - Epoch [30/200], Loss: 0.6543
# Beta Model Training - Epoch [31/200], Loss: 0.6437
# Beta Model Training - Epoch [32/200], Loss: 0.6372
# Beta Model Training - Epoch [33/200], Loss: 0.6343
# Beta Model Training - Epoch [34/200], Loss: 0.6347
# Beta Model Training - Epoch [35/200], Loss: 0.6349
# Beta Model Training - Epoch [36/200], Loss: 0.6290
# Beta Model Training - Epoch [37/200], Loss: 0.6195
# Beta Model Training - Epoch [38/200], Loss: 0.6140
# Beta Model Training - Epoch [39/200], Loss: 0.6157
# Beta Model Training - Epoch [40/200], Loss: 0.6135
# Beta Model Training - Epoch [41/200], Loss: 0.6086
# Beta Model Training - Epoch [42/200], Loss: 0.6065
# Beta Model Training - Epoch [43/200], Loss: 0.6074
# Beta Model Training - Epoch [44/200], Loss: 0.5955
# Beta Model Training - Epoch [45/200], Loss: 0.5847
# Beta Model Training - Epoch [46/200], Loss: 0.5846
# Beta Model Training - Epoch [47/200], Loss: 0.5826
# Beta Model Training - Epoch [48/200], Loss: 0.5778
# Beta Model Training - Epoch [49/200], Loss: 0.5750
# Beta Model Training - Epoch [50/200], Loss: 0.5699
# Beta Model Training - Epoch [51/200], Loss: 0.5643
# Beta Model Training - Epoch [52/200], Loss: 0.5606
# Beta Model Training - Epoch [53/200], Loss: 0.5577
# Beta Model Training - Epoch [54/200], Loss: 0.5562
# Beta Model Training - Epoch [55/200], Loss: 0.5538
# Beta Model Training - Epoch [56/200], Loss: 0.5512
# Beta Model Training - Epoch [57/200], Loss: 0.5511
# Beta Model Training - Epoch [58/200], Loss: 0.5490
# Beta Model Training - Epoch [59/200], Loss: 0.5468
# Beta Model Training - Epoch [60/200], Loss: 0.5455
# Beta Model Training - Epoch [61/200], Loss: 0.5431
# Beta Model Training - Epoch [62/200], Loss: 0.5399
# Beta Model Training - Epoch [63/200], Loss: 0.5391
# Beta Model Training - Epoch [64/200], Loss: 0.5444
# Beta Model Training - Epoch [65/200], Loss: 0.5462
# Beta Model Training - Epoch [66/200], Loss: 0.5495
# Beta Model Training - Epoch [67/200], Loss: 0.5520
# Beta Model Training - Epoch [68/200], Loss: 0.5418
# Beta Model Training - Epoch [69/200], Loss: 0.5366
# Beta Model Training - Epoch [70/200], Loss: 0.5316
# Beta Model Training - Epoch [71/200], Loss: 0.5310
# Beta Model Training - Epoch [72/200], Loss: 0.5291
# Beta Model Training - Epoch [73/200], Loss: 0.5258
# Beta Model Training - Epoch [74/200], Loss: 0.5212
# Beta Model Training - Epoch [75/200], Loss: 0.5231
# Beta Model Training - Epoch [76/200], Loss: 0.5207
# Beta Model Training - Epoch [77/200], Loss: 0.5196
# Beta Model Training - Epoch [78/200], Loss: 0.5157
# Beta Model Training - Epoch [79/200], Loss: 0.5141
# Beta Model Training - Epoch [80/200], Loss: 0.5155
# Beta Model Training - Epoch [81/200], Loss: 0.5208
# Beta Model Training - Epoch [82/200], Loss: 0.5162
# Beta Model Training - Epoch [83/200], Loss: 0.5168
# Beta Model Training - Epoch [84/200], Loss: 0.5167
# Beta Model Training - Epoch [85/200], Loss: 0.5149
# Beta Model Training - Epoch [86/200], Loss: 0.5132
# Beta Model Training - Epoch [87/200], Loss: 0.5112
# Beta Model Training - Epoch [88/200], Loss: 0.5045
# Beta Model Training - Epoch [89/200], Loss: 0.5036
# Beta Model Training - Epoch [90/200], Loss: 0.5011
# Beta Model Training - Epoch [91/200], Loss: 0.4974
# Beta Model Training - Epoch [92/200], Loss: 0.4982
# Beta Model Training - Epoch [93/200], Loss: 0.4965
# Beta Model Training - Epoch [94/200], Loss: 0.4937
# Beta Model Training - Epoch [95/200], Loss: 0.4912
# Beta Model Training - Epoch [96/200], Loss: 0.4925
# Beta Model Training - Epoch [97/200], Loss: 0.4912
# Beta Model Training - Epoch [98/200], Loss: 0.4911
# Beta Model Training - Epoch [99/200], Loss: 0.4924
# Beta Model Training - Epoch [100/200], Loss: 0.4926
# Beta Model Training - Epoch [101/200], Loss: 0.4925
# Beta Model Training - Epoch [102/200], Loss: 0.4987
# Beta Model Training - Epoch [103/200], Loss: 0.4985
# Beta Model Training - Epoch [104/200], Loss: 0.4949
# Beta Model Training - Epoch [105/200], Loss: 0.4925
# Beta Model Training - Epoch [106/200], Loss: 0.5027
# Beta Model Training - Epoch [107/200], Loss: 0.4984
# Beta Model Training - Epoch [108/200], Loss: 0.4892
# Beta Model Training - Epoch [109/200], Loss: 0.4870
# Beta Model Training - Epoch [110/200], Loss: 0.4894
# Beta Model Training - Epoch [111/200], Loss: 0.4887
# Beta Model Training - Epoch [112/200], Loss: 0.4828
# Beta Model Training - Epoch [113/200], Loss: 0.4793
# Beta Model Training - Epoch [114/200], Loss: 0.4801
# Beta Model Training - Epoch [115/200], Loss: 0.4797
# Beta Model Training - Epoch [116/200], Loss: 0.4783
# Beta Model Training - Epoch [117/200], Loss: 0.4761
# Beta Model Training - Epoch [118/200], Loss: 0.4764
# Beta Model Training - Epoch [119/200], Loss: 0.4768
# Beta Model Training - Epoch [120/200], Loss: 0.4738
# Beta Model Training - Epoch [121/200], Loss: 0.4739
# Beta Model Training - Epoch [122/200], Loss: 0.4747
# Beta Model Training - Epoch [123/200], Loss: 0.4734
# Beta Model Training - Epoch [124/200], Loss: 0.4729
# Beta Model Training - Epoch [125/200], Loss: 0.4725
# Beta Model Training - Epoch [126/200], Loss: 0.4710
# Beta Model Training - Epoch [127/200], Loss: 0.4716
# Beta Model Training - Epoch [128/200], Loss: 0.4688
# Beta Model Training - Epoch [129/200], Loss: 0.4684
# Beta Model Training - Epoch [130/200], Loss: 0.4688
# Beta Model Training - Epoch [131/200], Loss: 0.4682
# Beta Model Training - Epoch [132/200], Loss: 0.4709
# Beta Model Training - Epoch [133/200], Loss: 0.4715
# Beta Model Training - Epoch [134/200], Loss: 0.4715
# Beta Model Training - Epoch [135/200], Loss: 0.4709
# Beta Model Training - Epoch [136/200], Loss: 0.4698
# Beta Model Training - Epoch [137/200], Loss: 0.4754
# Beta Model Training - Epoch [138/200], Loss: 0.4759
# Beta Model Training - Epoch [139/200], Loss: 0.4719
# Beta Model Training - Epoch [140/200], Loss: 0.4714
# Beta Model Training - Epoch [141/200], Loss: 0.4679
# Beta Model Training - Epoch [142/200], Loss: 0.4655
# Beta Model Training - Epoch [143/200], Loss: 0.4647
# Beta Model Training - Epoch [144/200], Loss: 0.4674
# Beta Model Training - Epoch [145/200], Loss: 0.4673
# Beta Model Training - Epoch [146/200], Loss: 0.4651
# Beta Model Training - Epoch [147/200], Loss: 0.4646
# Beta Model Training - Epoch [148/200], Loss: 0.4652
# Beta Model Training - Epoch [149/200], Loss: 0.4663
# Beta Model Training - Epoch [150/200], Loss: 0.4694
# Beta Model Training - Epoch [151/200], Loss: 0.4681
# Beta Model Training - Epoch [152/200], Loss: 0.4660
# Beta Model Training - Epoch [153/200], Loss: 0.4651
# Beta Model Training - Epoch [154/200], Loss: 0.4642
# Beta Model Training - Epoch [155/200], Loss: 0.4646
# Beta Model Training - Epoch [156/200], Loss: 0.4655
# Beta Model Training - Epoch [157/200], Loss: 0.4642
# Beta Model Training - Epoch [158/200], Loss: 0.4655
# Beta Model Training - Epoch [159/200], Loss: 0.4658
# Beta Model Training - Epoch [160/200], Loss: 0.4631
# Beta Model Training - Epoch [161/200], Loss: 0.4645
# Beta Model Training - Epoch [162/200], Loss: 0.4646
# Beta Model Training - Epoch [163/200], Loss: 0.4687
# Beta Model Training - Epoch [164/200], Loss: 0.4722
# Beta Model Training - Epoch [165/200], Loss: 0.4713
# Beta Model Training - Epoch [166/200], Loss: 0.4711
# Beta Model Training - Epoch [167/200], Loss: 0.4674
# Beta Model Training - Epoch [168/200], Loss: 0.4642
# Beta Model Training - Epoch [169/200], Loss: 0.4759
# Beta Model Training - Epoch [170/200], Loss: 0.4817
# Beta Model Training - Epoch [171/200], Loss: 0.4823
# Beta Model Training - Epoch [172/200], Loss: 0.4795
# Beta Model Training - Epoch [173/200], Loss: 0.4766
# Beta Model Training - Epoch [174/200], Loss: 0.4769
# Beta Model Training - Epoch [175/200], Loss: 0.4827
# Beta Model Training - Epoch [176/200], Loss: 0.4726
# Beta Model Training - Epoch [177/200], Loss: 0.4676
# Beta Model Training - Epoch [178/200], Loss: 0.4652
# Beta Model Training - Epoch [179/200], Loss: 0.4586
# Beta Model Training - Epoch [180/200], Loss: 0.4599
# Beta Model Training - Epoch [181/200], Loss: 0.4586
# Beta Model Training - Epoch [182/200], Loss: 0.4573
# Beta Model Training - Epoch [183/200], Loss: 0.4571
# Beta Model Training - Epoch [184/200], Loss: 0.4555
# Beta Model Training - Epoch [185/200], Loss: 0.4535
# Beta Model Training - Epoch [186/200], Loss: 0.4526
# Beta Model Training - Epoch [187/200], Loss: 0.4542
# Beta Model Training - Epoch [188/200], Loss: 0.4559
# Beta Model Training - Epoch [189/200], Loss: 0.4556
# Beta Model Training - Epoch [190/200], Loss: 0.4572
# Beta Model Training - Epoch [191/200], Loss: 0.4560
# Beta Model Training - Epoch [192/200], Loss: 0.4544
# Beta Model Training - Epoch [193/200], Loss: 0.4563
# Beta Model Training - Epoch [194/200], Loss: 0.4593
# Beta Model Training - Epoch [195/200], Loss: 0.4581
# Beta Model Training - Epoch [196/200], Loss: 0.4545
# Beta Model Training - Epoch [197/200], Loss: 0.4556
# Beta Model Training - Epoch [198/200], Loss: 0.4517
# Beta Model Training - Epoch [199/200], Loss: 0.4514
# Beta Model Training - Epoch [200/200], Loss: 0.4498
#
# === Building dataset/model for Beta 4 ===
# Beta Model Training - Epoch [1/200], Loss: 1.7449
# Beta Model Training - Epoch [2/200], Loss: 1.6363
# Beta Model Training - Epoch [3/200], Loss: 1.5224
# Beta Model Training - Epoch [4/200], Loss: 1.4401
# Beta Model Training - Epoch [5/200], Loss: 1.3711
# Beta Model Training - Epoch [6/200], Loss: 1.3011
# Beta Model Training - Epoch [7/200], Loss: 1.2395
# Beta Model Training - Epoch [8/200], Loss: 1.1762
# Beta Model Training - Epoch [9/200], Loss: 1.1235
# Beta Model Training - Epoch [10/200], Loss: 1.0755
# Beta Model Training - Epoch [11/200], Loss: 1.0500
# Beta Model Training - Epoch [12/200], Loss: 1.0028
# Beta Model Training - Epoch [13/200], Loss: 0.9593
# Beta Model Training - Epoch [14/200], Loss: 0.9245
# Beta Model Training - Epoch [15/200], Loss: 0.8865
# Beta Model Training - Epoch [16/200], Loss: 0.8570
# Beta Model Training - Epoch [17/200], Loss: 0.8397
# Beta Model Training - Epoch [18/200], Loss: 0.8234
# Beta Model Training - Epoch [19/200], Loss: 0.8092
# Beta Model Training - Epoch [20/200], Loss: 0.7798
# Beta Model Training - Epoch [21/200], Loss: 0.7577
# Beta Model Training - Epoch [22/200], Loss: 0.7499
# Beta Model Training - Epoch [23/200], Loss: 0.7338
# Beta Model Training - Epoch [24/200], Loss: 0.7183
# Beta Model Training - Epoch [25/200], Loss: 0.7073
# Beta Model Training - Epoch [26/200], Loss: 0.6903
# Beta Model Training - Epoch [27/200], Loss: 0.6787
# Beta Model Training - Epoch [28/200], Loss: 0.6729
# Beta Model Training - Epoch [29/200], Loss: 0.6622
# Beta Model Training - Epoch [30/200], Loss: 0.6585
# Beta Model Training - Epoch [31/200], Loss: 0.6599
# Beta Model Training - Epoch [32/200], Loss: 0.6556
# Beta Model Training - Epoch [33/200], Loss: 0.6478
# Beta Model Training - Epoch [34/200], Loss: 0.6483
# Beta Model Training - Epoch [35/200], Loss: 0.6257
# Beta Model Training - Epoch [36/200], Loss: 0.6144
# Beta Model Training - Epoch [37/200], Loss: 0.6102
# Beta Model Training - Epoch [38/200], Loss: 0.6069
# Beta Model Training - Epoch [39/200], Loss: 0.5989
# Beta Model Training - Epoch [40/200], Loss: 0.5935
# Beta Model Training - Epoch [41/200], Loss: 0.6050
# Beta Model Training - Epoch [42/200], Loss: 0.6030
# Beta Model Training - Epoch [43/200], Loss: 0.6021
# Beta Model Training - Epoch [44/200], Loss: 0.5974
# Beta Model Training - Epoch [45/200], Loss: 0.6082
# Beta Model Training - Epoch [46/200], Loss: 0.6176
# Beta Model Training - Epoch [47/200], Loss: 0.6248
# Beta Model Training - Epoch [48/200], Loss: 0.6219
# Beta Model Training - Epoch [49/200], Loss: 0.6103
# Beta Model Training - Epoch [50/200], Loss: 0.6011
# Beta Model Training - Epoch [51/200], Loss: 0.5810
# Beta Model Training - Epoch [52/200], Loss: 0.5682
# Beta Model Training - Epoch [53/200], Loss: 0.5635
# Beta Model Training - Epoch [54/200], Loss: 0.5604
# Beta Model Training - Epoch [55/200], Loss: 0.5543
# Beta Model Training - Epoch [56/200], Loss: 0.5493
# Beta Model Training - Epoch [57/200], Loss: 0.5475
# Beta Model Training - Epoch [58/200], Loss: 0.5413
# Beta Model Training - Epoch [59/200], Loss: 0.5386
# Beta Model Training - Epoch [60/200], Loss: 0.5374
# Beta Model Training - Epoch [61/200], Loss: 0.5363
# Beta Model Training - Epoch [62/200], Loss: 0.5343
# Beta Model Training - Epoch [63/200], Loss: 0.5272
# Beta Model Training - Epoch [64/200], Loss: 0.5282
# Beta Model Training - Epoch [65/200], Loss: 0.5279
# Beta Model Training - Epoch [66/200], Loss: 0.5287
# Beta Model Training - Epoch [67/200], Loss: 0.5292
# Beta Model Training - Epoch [68/200], Loss: 0.5252
# Beta Model Training - Epoch [69/200], Loss: 0.5228
# Beta Model Training - Epoch [70/200], Loss: 0.5182
# Beta Model Training - Epoch [71/200], Loss: 0.5177
# Beta Model Training - Epoch [72/200], Loss: 0.5216
# Beta Model Training - Epoch [73/200], Loss: 0.5215
# Beta Model Training - Epoch [74/200], Loss: 0.5201
# Beta Model Training - Epoch [75/200], Loss: 0.5221
# Beta Model Training - Epoch [76/200], Loss: 0.5208
# Beta Model Training - Epoch [77/200], Loss: 0.5131
# Beta Model Training - Epoch [78/200], Loss: 0.5078
# Beta Model Training - Epoch [79/200], Loss: 0.5130
# Beta Model Training - Epoch [80/200], Loss: 0.5110
# Beta Model Training - Epoch [81/200], Loss: 0.5148
# Beta Model Training - Epoch [82/200], Loss: 0.5038
# Beta Model Training - Epoch [83/200], Loss: 0.5023
# Beta Model Training - Epoch [84/200], Loss: 0.5022
# Beta Model Training - Epoch [85/200], Loss: 0.4985
# Beta Model Training - Epoch [86/200], Loss: 0.4995
# Beta Model Training - Epoch [87/200], Loss: 0.4999
# Beta Model Training - Epoch [88/200], Loss: 0.5051
# Beta Model Training - Epoch [89/200], Loss: 0.5026
# Beta Model Training - Epoch [90/200], Loss: 0.5035
# Beta Model Training - Epoch [91/200], Loss: 0.4965
# Beta Model Training - Epoch [92/200], Loss: 0.4917
# Beta Model Training - Epoch [93/200], Loss: 0.4972
# Beta Model Training - Epoch [94/200], Loss: 0.4936
# Beta Model Training - Epoch [95/200], Loss: 0.4948
# Beta Model Training - Epoch [96/200], Loss: 0.5036
# Beta Model Training - Epoch [97/200], Loss: 0.4962
# Beta Model Training - Epoch [98/200], Loss: 0.4883
# Beta Model Training - Epoch [99/200], Loss: 0.4819
# Beta Model Training - Epoch [100/200], Loss: 0.4831
# Beta Model Training - Epoch [101/200], Loss: 0.4781
# Beta Model Training - Epoch [102/200], Loss: 0.4761
# Beta Model Training - Epoch [103/200], Loss: 0.4759
# Beta Model Training - Epoch [104/200], Loss: 0.4789
# Beta Model Training - Epoch [105/200], Loss: 0.4786
# Beta Model Training - Epoch [106/200], Loss: 0.4730
# Beta Model Training - Epoch [107/200], Loss: 0.4697
# Beta Model Training - Epoch [108/200], Loss: 0.4683
# Beta Model Training - Epoch [109/200], Loss: 0.4679
# Beta Model Training - Epoch [110/200], Loss: 0.4654
# Beta Model Training - Epoch [111/200], Loss: 0.4626
# Beta Model Training - Epoch [112/200], Loss: 0.4635
# Beta Model Training - Epoch [113/200], Loss: 0.4640
# Beta Model Training - Epoch [114/200], Loss: 0.4636
# Beta Model Training - Epoch [115/200], Loss: 0.4608
# Beta Model Training - Epoch [116/200], Loss: 0.4598
# Beta Model Training - Epoch [117/200], Loss: 0.4551
# Beta Model Training - Epoch [118/200], Loss: 0.4548
# Beta Model Training - Epoch [119/200], Loss: 0.4549
# Beta Model Training - Epoch [120/200], Loss: 0.4560
# Beta Model Training - Epoch [121/200], Loss: 0.4547
# Beta Model Training - Epoch [122/200], Loss: 0.4545
# Beta Model Training - Epoch [123/200], Loss: 0.4576
# ...
# Beta Model Training - Epoch [92/200], Loss: 0.5050
# Beta Model Training - Epoch [93/200], Loss: 0.5029
# Beta Model Training - Epoch [94/200], Loss: 0.4988
# Beta Model Training - Epoch [95/200], Loss: 0.4982
# Beta Model Training - Epoch [96/200], Loss: 0.5079
# Beta Model Training - Epoch [97/200], Loss: 0.5065
# Beta Model Training - Epoch [98/200], Loss: 0.5017
# Beta Model Training - Epoch [99/200], Loss: 0.4980
# Beta Model Training - Epoch [100/200], Loss: 0.4931
# Beta Model Training - Epoch [101/200], Loss: 0.4932
# Beta Model Training - Epoch [102/200], Loss: 0.4950
# Beta Model Training - Epoch [103/200], Loss: 0.4993
# Beta Model Training - Epoch [104/200], Loss: 0.5000
# Beta Model Training - Epoch [105/200], Loss: 0.4943
# Beta Model Training - Epoch [106/200], Loss: 0.4890
# Beta Model Training - Epoch [107/200], Loss: 0.4880
# Beta Model Training - Epoch [108/200], Loss: 0.4860
# Beta Model Training - Epoch [109/200], Loss: 0.4842
# Beta Model Training - Epoch [110/200], Loss: 0.4836
# Beta Model Training - Epoch [111/200], Loss: 0.4832
# Beta Model Training - Epoch [112/200], Loss: 0.4850
# Beta Model Training - Epoch [113/200], Loss: 0.4867
# Beta Model Training - Epoch [114/200], Loss: 0.4859
# Beta Model Training - Epoch [115/200], Loss: 0.4835
# Beta Model Training - Epoch [116/200], Loss: 0.4828
# Beta Model Training - Epoch [117/200], Loss: 0.4799
# Beta Model Training - Epoch [118/200], Loss: 0.4805
# Beta Model Training - Epoch [119/200], Loss: 0.4815
# Beta Model Training - Epoch [120/200], Loss: 0.4812
# Beta Model Training - Epoch [121/200], Loss: 0.4792
# Beta Model Training - Epoch [122/200], Loss: 0.4757
# Beta Model Training - Epoch [123/200], Loss: 0.4752
# Beta Model Training - Epoch [124/200], Loss: 0.4739
# Beta Model Training - Epoch [125/200], Loss: 0.4724
# Beta Model Training - Epoch [126/200], Loss: 0.4703
# Beta Model Training - Epoch [127/200], Loss: 0.4727
# Beta Model Training - Epoch [128/200], Loss: 0.4734
# Beta Model Training - Epoch [129/200], Loss: 0.4724
# Beta Model Training - Epoch [130/200], Loss: 0.4749
# Beta Model Training - Epoch [131/200], Loss: 0.4848
# Beta Model Training - Epoch [132/200], Loss: 0.4730
# Beta Model Training - Epoch [133/200], Loss: 0.4703
# Beta Model Training - Epoch [134/200], Loss: 0.4663
# Beta Model Training - Epoch [135/200], Loss: 0.4673
# Beta Model Training - Epoch [136/200], Loss: 0.4700
# Beta Model Training - Epoch [137/200], Loss: 0.4709
# Beta Model Training - Epoch [138/200], Loss: 0.4711
# Beta Model Training - Epoch [139/200], Loss: 0.4726
# Beta Model Training - Epoch [140/200], Loss: 0.4745
# Beta Model Training - Epoch [141/200], Loss: 0.4712
# Beta Model Training - Epoch [142/200], Loss: 0.4696
# Beta Model Training - Epoch [143/200], Loss: 0.4748
# Beta Model Training - Epoch [144/200], Loss: 0.4905
# Beta Model Training - Epoch [145/200], Loss: 0.4853
# Beta Model Training - Epoch [146/200], Loss: 0.4809
# Beta Model Training - Epoch [147/200], Loss: 0.4786
# Beta Model Training - Epoch [148/200], Loss: 0.4794
# Beta Model Training - Epoch [149/200], Loss: 0.4808
# Beta Model Training - Epoch [150/200], Loss: 0.4794
# Beta Model Training - Epoch [151/200], Loss: 0.4824
# Beta Model Training - Epoch [152/200], Loss: 0.4729
# Beta Model Training - Epoch [153/200], Loss: 0.4707
# Beta Model Training - Epoch [154/200], Loss: 0.4656
# Beta Model Training - Epoch [155/200], Loss: 0.4650
# Beta Model Training - Epoch [156/200], Loss: 0.4714
# Beta Model Training - Epoch [157/200], Loss: 0.4690
# Beta Model Training - Epoch [158/200], Loss: 0.4667
# Beta Model Training - Epoch [159/200], Loss: 0.4748
# Beta Model Training - Epoch [160/200], Loss: 0.4678
# Beta Model Training - Epoch [161/200], Loss: 0.4823
# Beta Model Training - Epoch [162/200], Loss: 0.4857
# Beta Model Training - Epoch [163/200], Loss: 0.4830
# Beta Model Training - Epoch [164/200], Loss: 0.4726
# Beta Model Training - Epoch [165/200], Loss: 0.4679
# Beta Model Training - Epoch [166/200], Loss: 0.4610
# Beta Model Training - Epoch [167/200], Loss: 0.4635
# Beta Model Training - Epoch [168/200], Loss: 0.4620
# Beta Model Training - Epoch [169/200], Loss: 0.4618
# Beta Model Training - Epoch [170/200], Loss: 0.4640
# Beta Model Training - Epoch [171/200], Loss: 0.4565
# Beta Model Training - Epoch [172/200], Loss: 0.4561
# Beta Model Training - Epoch [173/200], Loss: 0.4543
# Beta Model Training - Epoch [174/200], Loss: 0.4511
# Beta Model Training - Epoch [175/200], Loss: 0.4494
# Beta Model Training - Epoch [176/200], Loss: 0.4497
# Beta Model Training - Epoch [177/200], Loss: 0.4500
# Beta Model Training - Epoch [178/200], Loss: 0.4508
# Beta Model Training - Epoch [179/200], Loss: 0.4494
# Beta Model Training - Epoch [180/200], Loss: 0.4506
# Beta Model Training - Epoch [181/200], Loss: 0.4499
# Beta Model Training - Epoch [182/200], Loss: 0.4515
# Beta Model Training - Epoch [183/200], Loss: 0.4487
# Beta Model Training - Epoch [184/200], Loss: 0.4497
# Beta Model Training - Epoch [185/200], Loss: 0.4530
# Beta Model Training - Epoch [186/200], Loss: 0.4544
# Beta Model Training - Epoch [187/200], Loss: 0.4545
# Beta Model Training - Epoch [188/200], Loss: 0.4559
# Beta Model Training - Epoch [189/200], Loss: 0.4546
# Beta Model Training - Epoch [190/200], Loss: 0.4606
# Beta Model Training - Epoch [191/200], Loss: 0.4658
# Beta Model Training - Epoch [192/200], Loss: 0.4747
# Beta Model Training - Epoch [193/200], Loss: 0.4552
# Beta Model Training - Epoch [194/200], Loss: 0.4550
# Beta Model Training - Epoch [195/200], Loss: 0.4625
# Beta Model Training - Epoch [196/200], Loss: 0.4554
# Beta Model Training - Epoch [197/200], Loss: 0.4515
# Beta Model Training - Epoch [198/200], Loss: 0.4500
# Beta Model Training - Epoch [199/200], Loss: 0.4466
# Beta Model Training - Epoch [200/200], Loss: 0.4458
#
# === Building dataset/model for Beta 25 ===
# Beta Model Training - Epoch [1/200], Loss: 1.1080
# Beta Model Training - Epoch [2/200], Loss: 0.9878
# Beta Model Training - Epoch [3/200], Loss: 0.7551
# Beta Model Training - Epoch [4/200], Loss: 0.5826
# Beta Model Training - Epoch [5/200], Loss: 0.5115
# Beta Model Training - Epoch [6/200], Loss: 0.4793
# Beta Model Training - Epoch [7/200], Loss: 0.4444
# Beta Model Training - Epoch [8/200], Loss: 0.4105
# Beta Model Training - Epoch [9/200], Loss: 0.3752
# Beta Model Training - Epoch [10/200], Loss: 0.3420
# Beta Model Training - Epoch [11/200], Loss: 0.3172
# Beta Model Training - Epoch [12/200], Loss: 0.2896
# Beta Model Training - Epoch [13/200], Loss: 0.2640
# Beta Model Training - Epoch [14/200], Loss: 0.2446
# Beta Model Training - Epoch [15/200], Loss: 0.2435
# Beta Model Training - Epoch [16/200], Loss: 0.2374
# Beta Model Training - Epoch [17/200], Loss: 0.2298
# Beta Model Training - Epoch [18/200], Loss: 0.2263
# Beta Model Training - Epoch [19/200], Loss: 0.2054
# Beta Model Training - Epoch [20/200], Loss: 0.2001
# Beta Model Training - Epoch [21/200], Loss: 0.1893
# Beta Model Training - Epoch [22/200], Loss: 0.1878
# Beta Model Training - Epoch [23/200], Loss: 0.1834
# Beta Model Training - Epoch [24/200], Loss: 0.1782
# Beta Model Training - Epoch [25/200], Loss: 0.1790
# Beta Model Training - Epoch [26/200], Loss: 0.1728
# Beta Model Training - Epoch [27/200], Loss: 0.1655
# Beta Model Training - Epoch [28/200], Loss: 0.1605
# Beta Model Training - Epoch [29/200], Loss: 0.1564
# Beta Model Training - Epoch [30/200], Loss: 0.1559
# Beta Model Training - Epoch [31/200], Loss: 0.1536
# Beta Model Training - Epoch [32/200], Loss: 0.1530
# Beta Model Training - Epoch [33/200], Loss: 0.1519
# Beta Model Training - Epoch [34/200], Loss: 0.1494
# Beta Model Training - Epoch [35/200], Loss: 0.1529
# Beta Model Training - Epoch [36/200], Loss: 0.1469
# Beta Model Training - Epoch [37/200], Loss: 0.1405
# Beta Model Training - Epoch [38/200], Loss: 0.1405
# Beta Model Training - Epoch [39/200], Loss: 0.1388
# Beta Model Training - Epoch [40/200], Loss: 0.1374
# Beta Model Training - Epoch [41/200], Loss: 0.1370
# Beta Model Training - Epoch [42/200], Loss: 0.1311
# Beta Model Training - Epoch [43/200], Loss: 0.1282
# Beta Model Training - Epoch [44/200], Loss: 0.1246
# Beta Model Training - Epoch [45/200], Loss: 0.1228
# Beta Model Training - Epoch [46/200], Loss: 0.1219
# Beta Model Training - Epoch [47/200], Loss: 0.1185
# Beta Model Training - Epoch [48/200], Loss: 0.1142
# Beta Model Training - Epoch [49/200], Loss: 0.1167
# Beta Model Training - Epoch [50/200], Loss: 0.1162
# Beta Model Training - Epoch [51/200], Loss: 0.1175
# Beta Model Training - Epoch [52/200], Loss: 0.1156
# Beta Model Training - Epoch [53/200], Loss: 0.1170
# Beta Model Training - Epoch [54/200], Loss: 0.1140
# Beta Model Training - Epoch [55/200], Loss: 0.1104
# Beta Model Training - Epoch [56/200], Loss: 0.1106
# Beta Model Training - Epoch [57/200], Loss: 0.1135
# Beta Model Training - Epoch [58/200], Loss: 0.1095
# Beta Model Training - Epoch [59/200], Loss: 0.1075
# Beta Model Training - Epoch [60/200], Loss: 0.1075
# Beta Model Training - Epoch [61/200], Loss: 0.1063
# Beta Model Training - Epoch [62/200], Loss: 0.1167
# Beta Model Training - Epoch [63/200], Loss: 0.1068
# Beta Model Training - Epoch [64/200], Loss: 0.1101
# Beta Model Training - Epoch [65/200], Loss: 0.1065
# Beta Model Training - Epoch [66/200], Loss: 0.1039
# Beta Model Training - Epoch [67/200], Loss: 0.1035
# Beta Model Training - Epoch [68/200], Loss: 0.1005
# Beta Model Training - Epoch [69/200], Loss: 0.0972
# Beta Model Training - Epoch [70/200], Loss: 0.1016
# Beta Model Training - Epoch [71/200], Loss: 0.0988
# Beta Model Training - Epoch [72/200], Loss: 0.0969
# Beta Model Training - Epoch [73/200], Loss: 0.0941
# Beta Model Training - Epoch [74/200], Loss: 0.0956
# Beta Model Training - Epoch [75/200], Loss: 0.0912
# Beta Model Training - Epoch [76/200], Loss: 0.0893
# Beta Model Training - Epoch [77/200], Loss: 0.0899
# Beta Model Training - Epoch [78/200], Loss: 0.0885
# Beta Model Training - Epoch [79/200], Loss: 0.0866
# Beta Model Training - Epoch [80/200], Loss: 0.0872
# Beta Model Training - Epoch [81/200], Loss: 0.0882
# Beta Model Training - Epoch [82/200], Loss: 0.0908
# Beta Model Training - Epoch [83/200], Loss: 0.0971
# Beta Model Training - Epoch [84/200], Loss: 0.0870
# Beta Model Training - Epoch [85/200], Loss: 0.0871
# Beta Model Training - Epoch [86/200], Loss: 0.0879
# Beta Model Training - Epoch [87/200], Loss: 0.0919
# Beta Model Training - Epoch [88/200], Loss: 0.0902
# Beta Model Training - Epoch [89/200], Loss: 0.0870
# Beta Model Training - Epoch [90/200], Loss: 0.0847
# Beta Model Training - Epoch [91/200], Loss: 0.0808
# Beta Model Training - Epoch [92/200], Loss: 0.0822
# Beta Model Training - Epoch [93/200], Loss: 0.0815
# Beta Model Training - Epoch [94/200], Loss: 0.0820
# Beta Model Training - Epoch [95/200], Loss: 0.0820
# Beta Model Training - Epoch [96/200], Loss: 0.0816
# Beta Model Training - Epoch [97/200], Loss: 0.0806
# Beta Model Training - Epoch [98/200], Loss: 0.0773
# Beta Model Training - Epoch [99/200], Loss: 0.0769
# Beta Model Training - Epoch [100/200], Loss: 0.0768
# Beta Model Training - Epoch [101/200], Loss: 0.0769
# Beta Model Training - Epoch [102/200], Loss: 0.0775
# Beta Model Training - Epoch [103/200], Loss: 0.0773
# Beta Model Training - Epoch [104/200], Loss: 0.0780
# Beta Model Training - Epoch [105/200], Loss: 0.0773
# Beta Model Training - Epoch [106/200], Loss: 0.0764
# Beta Model Training - Epoch [107/200], Loss: 0.0755
# Beta Model Training - Epoch [108/200], Loss: 0.0766
# Beta Model Training - Epoch [109/200], Loss: 0.0756
# Beta Model Training - Epoch [110/200], Loss: 0.0790
# Beta Model Training - Epoch [111/200], Loss: 0.0792
# Beta Model Training - Epoch [112/200], Loss: 0.0769
# Beta Model Training - Epoch [113/200], Loss: 0.0786
# Beta Model Training - Epoch [114/200], Loss: 0.0812
# Beta Model Training - Epoch [115/200], Loss: 0.0783
# Beta Model Training - Epoch [116/200], Loss: 0.0747
# Beta Model Training - Epoch [117/200], Loss: 0.0777
# Beta Model Training - Epoch [118/200], Loss: 0.0730
# Beta Model Training - Epoch [119/200], Loss: 0.0695
# Beta Model Training - Epoch [120/200], Loss: 0.0729
# Beta Model Training - Epoch [121/200], Loss: 0.0676
# Beta Model Training - Epoch [122/200], Loss: 0.0686
# Beta Model Training - Epoch [123/200], Loss: 0.0712
# Beta Model Training - Epoch [124/200], Loss: 0.0702
# Beta Model Training - Epoch [125/200], Loss: 0.0670
# Beta Model Training - Epoch [126/200], Loss: 0.0698
# Beta Model Training - Epoch [127/200], Loss: 0.0681
# Beta Model Training - Epoch [128/200], Loss: 0.0698
# Beta Model Training - Epoch [129/200], Loss: 0.0713
# Beta Model Training - Epoch [130/200], Loss: 0.0703
# Beta Model Training - Epoch [131/200], Loss: 0.0761
# Beta Model Training - Epoch [132/200], Loss: 0.0750
# Beta Model Training - Epoch [133/200], Loss: 0.0793
# Beta Model Training - Epoch [134/200], Loss: 0.0717
# Beta Model Training - Epoch [135/200], Loss: 0.0725
# Beta Model Training - Epoch [136/200], Loss: 0.0707
# Beta Model Training - Epoch [137/200], Loss: 0.0671
# Beta Model Training - Epoch [138/200], Loss: 0.0653
# Beta Model Training - Epoch [139/200], Loss: 0.0645
# Beta Model Training - Epoch [140/200], Loss: 0.0664
# Beta Model Training - Epoch [141/200], Loss: 0.0655
# Beta Model Training - Epoch [142/200], Loss: 0.0647
# Beta Model Training - Epoch [143/200], Loss: 0.0632
# Beta Model Training - Epoch [144/200], Loss: 0.0615
# Beta Model Training - Epoch [145/200], Loss: 0.0634
# Beta Model Training - Epoch [146/200], Loss: 0.0633
# Beta Model Training - Epoch [147/200], Loss: 0.0629
# Beta Model Training - Epoch [148/200], Loss: 0.0626
# Beta Model Training - Epoch [149/200], Loss: 0.0622
# Beta Model Training - Epoch [150/200], Loss: 0.0630
# Beta Model Training - Epoch [151/200], Loss: 0.0625
# Beta Model Training - Epoch [152/200], Loss: 0.0624
# Beta Model Training - Epoch [153/200], Loss: 0.0615
# Beta Model Training - Epoch [154/200], Loss: 0.0619
# Beta Model Training - Epoch [155/200], Loss: 0.0624
# Beta Model Training - Epoch [156/200], Loss: 0.0630
# Beta Model Training - Epoch [157/200], Loss: 0.0614
# Beta Model Training - Epoch [158/200], Loss: 0.0604
# Beta Model Training - Epoch [159/200], Loss: 0.0612
# Beta Model Training - Epoch [160/200], Loss: 0.0603
# Beta Model Training - Epoch [161/200], Loss: 0.0589
# Beta Model Training - Epoch [162/200], Loss: 0.0595
# Beta Model Training - Epoch [163/200], Loss: 0.0590
# Beta Model Training - Epoch [164/200], Loss: 0.0612
# Beta Model Training - Epoch [165/200], Loss: 0.0608
# Beta Model Training - Epoch [166/200], Loss: 0.0632
# Beta Model Training - Epoch [167/200], Loss: 0.0663
# Beta Model Training - Epoch [168/200], Loss: 0.0675
# Beta Model Training - Epoch [169/200], Loss: 0.0660
# Beta Model Training - Epoch [170/200], Loss: 0.0634
# Beta Model Training - Epoch [171/200], Loss: 0.0668
# Beta Model Training - Epoch [172/200], Loss: 0.0717
# Beta Model Training - Epoch [173/200], Loss: 0.0649
# Beta Model Training - Epoch [174/200], Loss: 0.0628
# Beta Model Training - Epoch [175/200], Loss: 0.0637
# Beta Model Training - Epoch [176/200], Loss: 0.0624
# Beta Model Training - Epoch [177/200], Loss: 0.0589
# Beta Model Training - Epoch [178/200], Loss: 0.0570
# Beta Model Training - Epoch [179/200], Loss: 0.0566
# Beta Model Training - Epoch [180/200], Loss: 0.0554
# Beta Model Training - Epoch [181/200], Loss: 0.0538
# Beta Model Training - Epoch [182/200], Loss: 0.0527
# Beta Model Training - Epoch [183/200], Loss: 0.0532
# Beta Model Training - Epoch [184/200], Loss: 0.0527
# Beta Model Training - Epoch [185/200], Loss: 0.0537
# Beta Model Training - Epoch [186/200], Loss: 0.0531
# Beta Model Training - Epoch [187/200], Loss: 0.0522
# Beta Model Training - Epoch [188/200], Loss: 0.0564
# Beta Model Training - Epoch [189/200], Loss: 0.0545
# Beta Model Training - Epoch [190/200], Loss: 0.0547
# Beta Model Training - Epoch [191/200], Loss: 0.0607
# Beta Model Training - Epoch [192/200], Loss: 0.0568
# Beta Model Training - Epoch [193/200], Loss: 0.0599
# Beta Model Training - Epoch [194/200], Loss: 0.0594
# Beta Model Training - Epoch [195/200], Loss: 0.0554
# Beta Model Training - Epoch [196/200], Loss: 0.0534
# Beta Model Training - Epoch [197/200], Loss: 0.0521
# Beta Model Training - Epoch [198/200], Loss: 0.0509
# Beta Model Training - Epoch [199/200], Loss: 0.0523
# Beta Model Training - Epoch [200/200], Loss: 0.0528

# %%
# save importances results
save_dir = os.path.join(curr_dir, analysis_type, 'Masking')
os.makedirs(save_dir, exist_ok=True)

save_subdir_chan = os.path.join(save_dir, 'Channel Masking')
os.makedirs(save_subdir_chan, exist_ok=True)

save_subdir_region = os.path.join(save_dir, 'Region Masking')
os.makedirs(save_subdir_region, exist_ok=True)

save_subdir_time = os.path.join(save_dir, 'Time Frame Masking')
os.makedirs(save_subdir_time, exist_ok=True)

imp_chan_zero_data = {'all_imp_chan_zero': all_imp_chan_zero}
imp_chan_mean_data = {'all_imp_chan_mean': all_imp_chan_mean}
imp_region_localmean_data = {'all_imp_region_localmean': all_imp_region_localmean}
imp_region_globalmean_data = {'all_imp_region_globalmean': all_imp_region_globalmean}
imp_time_mean_data = {'all_imp_time_mean': all_imp_time_mean}
imp_time_zero_data = {'all_imp_time_zero': all_imp_time_zero}

savemat(os.path.join(save_subdir_chan, 'imp_chan_zero.mat'), imp_chan_zero_data)
savemat(os.path.join(save_subdir_chan, 'imp_chan_mean.mat'), imp_chan_mean_data)
savemat(os.path.join(save_subdir_region, 'imp_region_localmean.mat'), imp_region_localmean_data)
savemat(os.path.join(save_subdir_region, 'imp_region_globalmean.mat'), imp_region_globalmean_data)
savemat(os.path.join(save_subdir_time, 'imp_time_mean.mat'), imp_time_mean_data)
savemat(os.path.join(save_subdir_time, 'imp_time_zero.mat'), imp_time_zero_data)

# %%
save_dir = os.path.join(curr_dir, analysis_type, 'Masking')
save_subdir_chan = os.path.join(save_dir, 'Channel Masking')
save_subdir_region = os.path.join(save_dir, 'Region Masking')
save_subdir_time = os.path.join(save_dir, 'Time Frame Masking')

all_imp_chan_zero = loadmat(os.path.join(save_subdir_chan, 'imp_chan_zero.mat'))['all_imp_chan_zero']
all_imp_chan_mean = loadmat(os.path.join(save_subdir_chan, 'imp_chan_mean.mat'))['all_imp_chan_mean']
all_imp_region_localmean = loadmat(os.path.join(save_subdir_region, 'imp_region_localmean.mat'))['all_imp_region_localmean']
all_imp_region_globalmean = loadmat(os.path.join(save_subdir_region, 'imp_region_globalmean.mat'))['all_imp_region_globalmean']
all_imp_time_mean = loadmat(os.path.join(save_subdir_time, 'imp_time_mean.mat'))['all_imp_time_mean']
all_imp_time_zero = loadmat(os.path.join(save_subdir_time, 'imp_time_zero.mat'))['all_imp_time_zero']
print(save_dir)
# Out:
# e:\MThesis\GAEtesting\N170\Masking

# %%
def visualize_importance_across_betas(
    data,
    savepath,
    lablename='Channel Index',
    x_positions=None,      # bar positions (length nUnits)
    x_ticks=None,          # tick positions (can be shorter than nUnits)
    x_ticklabels=None,     # tick labels (same length as x_ticks)
    analysis_type='N400'   # pass in explicitly to avoid global
):
    nBeta, nUnits = data.shape
    norm_all_imp = np.zeros_like(data, dtype=float)

    # Normalize per Beta
    for iBeta in range(nBeta):
        value = data[iBeta]
        max_abs = np.max(np.abs(value))
        norm_all_imp[iBeta] = value / max_abs if max_abs > 0 else value

    # Cross Beta Average
    agg_imp = norm_all_imp.mean(axis=0)

    # Bar positions
    if x_positions is None:
        x_positions = np.arange(nUnits)

    fig, ax = plt.subplots(figsize=(10, 6))

    # Bar width for time-like continuous x
    if lablename in ['Time Frame', 'Time (ms)'] and len(x_positions) > 1:
        width = (x_positions[1] - x_positions[0]) * 0.8
        ax.bar(x_positions, agg_imp, width=width, align='center')
    else:
        ax.bar(x_positions, agg_imp)

    # ---- FIX: ticks separate from bar positions ----
    if x_ticks is None:
        # default: tick at every bar
        x_ticks = x_positions

    ax.set_xticks(x_ticks)

    if x_ticklabels is None:
        # default labels match ticks
        x_ticklabels = [str(int(x)+1) for x in x_ticks]

    ax.set_xticklabels(x_ticklabels, fontsize=12)

    ax.tick_params(axis='x', labelsize=12, rotation=0)
    ax.tick_params(axis='y', labelsize=12)

    ax.set_xlabel(lablename, fontsize=16)
    ax.set_ylabel('Aggregated Importance (normalized)', fontsize=16)
    ax.set_title(f'{analysis_type} Aggregated Importance across Betas',
                 fontsize=18, pad=10)

    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.grid(axis='y', linestyle='--', alpha=0.4)

    fig.tight_layout()
    fig.savefig(savepath, dpi=300)
    plt.close(fig)

# %%
# Visualize importances of channel masking

def visualize_channel_importance(data, analysis_type, save_path, method, target='channel'):
    print("shape of input data:", data.shape)

    global_max = np.percentile(data, 97)
    global_min = np.min(data)
    # [nBeta, nChan], mean across subjects
    values = data.mean(axis=1) 
    
    visualize_importance_across_betas(values,
        os.path.join(save_path, f'{analysis_type}_Aggregated_Importance_{target.capitalize()}_{method.capitalize()}.png'),
        lablename='Channel Index', analysis_type=analysis_type)

    fig, ax = plt.subplots(figsize=(10, 6))

    im = ax.imshow(
        values,
        aspect='auto',
        origin='lower',
        cmap='Reds',
        vmin=global_min,
        vmax=global_max
    )

    # Set axis labels, font sizes, and title
    ax.set_xlabel(target.capitalize(), fontsize=16)
    ax.set_ylabel('Beta Index', fontsize=16)
    ax.set_title(f'{analysis_type} – {target.capitalize()}-{method.capitalize()}',
                fontsize=18, pad=10)

    # Customize tick labels
    ax.set_xticks(np.arange(nChan))
    ax.set_xticklabels(np.arange(1, nChan + 1), fontsize=10)
    ax.set_yticks(np.arange(nBeta))
    ax.set_yticklabels(np.arange(1, nBeta + 1), fontsize=12)

    # Remove top and right spines
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)

    # Add colorbar
    cbar = fig.colorbar(im, ax=ax, pad=0.02)
    cbar.set_label('Importance', fontsize=14)
    cbar.ax.tick_params(labelsize=12)

    fig.tight_layout()
    fig.savefig(
        os.path.join(save_path, f'{analysis_type}_{target.capitalize()}_Importance_{method.capitalize()}.png'),
        dpi=300
    )
    plt.close(fig)


    for iBeta in range(nBeta):
        # Mean across subjects
        values = data[iBeta].mean(axis=0)

        fig, ax = plt.subplots(figsize=(10, 6))

        x = np.arange(nChan)
        ax.bar(x, values)

        # Set axis labels, font sizes, and title
        ax.set_xticks(x)
        ax.set_xticklabels(np.arange(1, nChan + 1))
        ax.tick_params(axis='x', labelsize=10)
        ax.tick_params(axis='y', labelsize=10)

        ax.set_xlabel(f'Channel index', fontsize=18)
        ax.set_ylabel('Importance', fontsize=18)
        ax.set_ylim(global_min, global_max)
        ax.set_title(
            f'{analysis_type} Beta {iBeta+1} {target.capitalize()}-{method.capitalize()}',
            fontsize=14,
            pad=12
        )

        # Remove top and right spines
        ax.spines['top'].set_visible(False)
        ax.spines['right'].set_visible(False)
        # Add grid lines for y-axis
        ax.grid(axis='y', linestyle='--', alpha=0.4)

        # Save figure
        fig.tight_layout()
        fig.savefig(os.path.join(save_path, f'{analysis_type}_Beta_{iBeta+1}_{target.capitalize()}_Importance_{method.capitalize()}.png'), dpi=300)
        plt.close(fig)

# %%
import os
import numpy as np
import matplotlib.pyplot as plt

def visualize_time_importance(data, analysis_type, save_path, method,
                              tmin_ms=-200, tmax_ms=600, tick_step_ms=50):
    """
    data: [nBeta, nSubject, nSeg]
    x-axis shown in ms from tmin_ms to tmax_ms with ticks every tick_step_ms
    """
    nBeta, _, nSeg = data.shape
    print("shape of input data:", data.shape)

    global_max = np.percentile(data, 97)
    global_min = np.min(data)

    # [nBeta, nSeg] mean across subjects
    values = data.mean(axis=1)

    # =========================
    # Build segment centers in ms
    # =========================
    # nSeg segments spanning [tmin_ms, tmax_ms]
    boundaries_ms = np.linspace(tmin_ms, tmax_ms, nSeg + 1)          # [nSeg+1]
    centers_ms = (boundaries_ms[:-1] + boundaries_ms[1:]) / 2.0      # [nSeg]
    seg_width_ms = (tmax_ms - tmin_ms) / nSeg

    # ticks every 50 ms
    xticks_ms = np.arange(tmin_ms, tmax_ms + 1e-9, tick_step_ms)

    # =========================
    # Heatmap (Betas x Time segments)
    # =========================
    fig, ax = plt.subplots(figsize=(10, 6))
    im = ax.imshow(
        values,
        aspect='auto',
        origin='lower',
        cmap='Reds',
        vmin=global_min,
        vmax=global_max,
        extent=[tmin_ms, tmax_ms, 0, nBeta]   # make x-axis in ms
    )

    ax.set_xlabel('Time (ms)', fontsize=16)
    ax.set_ylabel('Beta Index', fontsize=16)
    ax.set_title(f'{analysis_type} – Time masking-{method.capitalize()}',
                 fontsize=18, pad=10)

    ax.set_xticks(xticks_ms)
    ax.tick_params(axis='x', labelsize=10)
    ax.set_yticks(np.arange(nBeta) + 0.5)  # center ticks in rows
    ax.set_yticklabels(np.arange(1, nBeta + 1), fontsize=12)

    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)

    cbar = fig.colorbar(im, ax=ax, pad=0.02)
    cbar.set_label('Importance', fontsize=14)
    cbar.ax.tick_params(labelsize=12)

    fig.tight_layout()
    fig.savefig(
        os.path.join(save_path, f'{analysis_type}_Time_Masking_Importance_{method.capitalize()}.png'),
        dpi=300
    )
    plt.close(fig)

    xticks_ms = np.arange(-200, 601, 50)

    visualize_importance_across_betas(
        values,
        os.path.join(save_path, f'{analysis_type}_Aggregated_Importance_Time_{method.capitalize()}.png'),
        lablename='Time (ms)',
        x_positions=centers_ms,  # nSeg
        x_ticks=xticks_ms,       # 17
        x_ticklabels=[str(int(x)) for x in xticks_ms],
        analysis_type=analysis_type
    )

    # =========================
    # Per-beta bar plots
    # =========================
    for iBeta in range(nBeta):
        values_beta = data[iBeta].mean(axis=0)  # [nSeg]

        fig, ax = plt.subplots(figsize=(10, 6))
        ax.bar(centers_ms, values_beta, width=seg_width_ms * 0.8)

        ax.set_xlim(tmin_ms, tmax_ms)
        ax.set_xticks(xticks_ms)
        ax.set_xticklabels([str(int(x)) for x in xticks_ms])

        ax.tick_params(axis='x', labelsize=10)
        ax.tick_params(axis='y', labelsize=10)

        ax.set_xlabel('Time (ms)', fontsize=18)
        ax.set_ylabel('Importance', fontsize=18)
        ax.set_ylim(global_min, global_max)
        ax.set_title(
            f'{analysis_type} Beta {iBeta+1} Time Masking-{method.capitalize()}',
            fontsize=14,
            pad=12
        )

        ax.spines['top'].set_visible(False)
        ax.spines['right'].set_visible(False)
        ax.grid(axis='y', linestyle='--', alpha=0.4)

        fig.tight_layout()
        fig.savefig(
            os.path.join(save_path, f'{analysis_type}_Beta_{iBeta+1}_Time_Masking_Importance_{method.capitalize()}.png'),
            dpi=300
        )
        plt.close(fig)

# %%
print(all_imp_chan_zero.shape)  # [nBeta, nSubject, nChan]
print(all_imp_time_mean.shape)
# Out:
# (5, 39, 30)
# (5, 39, 100)

# %%
visualize_channel_importance(all_imp_chan_zero, analysis_type, save_subdir_chan, method='zero', target='channel')
visualize_channel_importance(all_imp_chan_mean, analysis_type, save_subdir_chan, method='mean', target='channel')
visualize_channel_importance(all_imp_region_localmean, analysis_type, save_subdir_region, method='local_mean', target='region')
visualize_channel_importance(all_imp_region_globalmean, analysis_type, save_subdir_region, method='global_mean', target='region')
visualize_time_importance(all_imp_time_mean, analysis_type, save_subdir_time, method='mean')
visualize_time_importance(all_imp_time_zero, analysis_type, save_subdir_time, method='zero')
# Out:
# shape of input data: (26, 36, 30)
# shape of input data: (26, 36, 30)
# shape of input data: (26, 36, 30)
# shape of input data: (26, 36, 30)

# %%
test = compute_neighborhood_channels(edge_index, k=1)
for i in range(len(test)):
    nbrs = [int(x) + 1 for x in test[i]]
    degree = len(nbrs) - 1  # exclude self
    print(f"Channel {i+1}: Neighbors {nbrs}, Degree {degree}")
# Out:
# Channel 1: Neighbors [1, 2, 3, 16, 17], Degree 4
# Channel 2: Neighbors [1, 2, 3, 4, 17, 21], Degree 5
# Channel 3: Neighbors [1, 2, 3, 4, 6], Degree 4
# Channel 4: Neighbors [2, 3, 4, 5, 6, 17, 21, 22], Degree 7
# Channel 5: Neighbors [4, 5, 6, 7, 8, 15, 21, 22], Degree 7
# Channel 6: Neighbors [3, 4, 5, 6, 7, 8, 9], Degree 6
# Channel 7: Neighbors [5, 6, 7, 8, 10, 11, 14, 15], Degree 7
# Channel 8: Neighbors [5, 6, 7, 8, 9, 10, 11], Degree 6
# Channel 9: Neighbors [6, 8, 9, 10, 12], Degree 4
# Channel 10: Neighbors [7, 8, 9, 10, 11, 12], Degree 5
# Channel 11: Neighbors [7, 8, 10, 11, 12, 13, 14, 15, 29], Degree 8
# Channel 12: Neighbors [9, 10, 11, 12, 13], Degree 4
# Channel 13: Neighbors [11, 12, 13, 14, 29, 30], Degree 5
# Channel 14: Neighbors [7, 11, 13, 14, 15, 25, 29], Degree 6
# Channel 15: Neighbors [5, 7, 11, 14, 15, 22, 23, 25, 29], Degree 8
# Channel 16: Neighbors [1, 16, 17, 18, 19], Degree 4
# Channel 17: Neighbors [1, 2, 4, 16, 17, 18, 20, 21], Degree 7
# Channel 18: Neighbors [16, 17, 18, 19, 20, 21], Degree 5
# Channel 19: Neighbors [16, 18, 19, 20, 24], Degree 4
# Channel 20: Neighbors [17, 18, 19, 20, 21, 22, 23, 24], Degree 7
# Channel 21: Neighbors [2, 4, 5, 17, 18, 20, 21, 22, 23], Degree 8
# Channel 22: Neighbors [4, 5, 15, 20, 21, 22, 23], Degree 6
# Channel 23: Neighbors [15, 20, 21, 22, 23, 24, 25, 26], Degree 7
# Channel 24: Neighbors [19, 20, 23, 24, 25, 26, 27], Degree 6
# Channel 25: Neighbors [14, 15, 23, 24, 25, 26, 28, 29], Degree 7
# Channel 26: Neighbors [23, 24, 25, 26, 27, 28, 29], Degree 6
# Channel 27: Neighbors [24, 26, 27, 28, 30], Degree 4
# Channel 28: Neighbors [25, 26, 27, 28, 29, 30], Degree 5
# Channel 29: Neighbors [11, 13, 14, 15, 25, 26, 28, 29, 30], Degree 8
# Channel 30: Neighbors [13, 27, 28, 29, 30], Degree 4
