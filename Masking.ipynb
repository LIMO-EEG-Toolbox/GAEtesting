# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset, ConcatDataset
from torch_geometric.loader import DataLoader as GeometricDataLoader
from torch_geometric.data import Data
from torch_geometric.utils import dense_to_sparse
import torch_geometric.nn as pyg_nn
import os

from scipy.io import loadmat, savemat

# %%
# Test - load saved beta data from mat file
analysis_type = 'N170'
datain_mat = loadmat(analysis_type + '_data.mat')
binatry_matrix_mat = loadmat('adjacency_matrix.mat')
datain = datain_mat['data']
binatry_matrix = binatry_matrix_mat['adjacency_matrix']

datain = np.array(datain)          # shape: [nBeta, nTime, nChan, nSubject] (adjust as needed)
binatry_matrix = np.array(binatry_matrix)

# Parse shapes
nBeta     = datain.shape[0]
nTime     = datain.shape[1]
nChan     = datain.shape[2]
nSubject  = datain.shape[3]

# %%
# ===========================================
# 2) Set device & convert adjacency
# ===========================================
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
edge_index, _ = dense_to_sparse(torch.tensor(binatry_matrix, dtype=torch.float32))
print(device)

# ===========================================
# 3) Dataset builder
# ===========================================
def build_concat_dataset_for_beta(datain, beta_idx):
    """
    Build a ConcatDataset across all subjects for one beta index.
    `datain` is [nBeta, nTime, nChan, nSubject].
    Returns: ConcatDataset of length nSubject.
    """
    subject_datasets = []
    for s in range(nSubject):
        # Extract slice for one subject and one beta
        # shape: [nTime, nChan]
        single_beta_data = datain[beta_idx, :, :, s]

        # If each node is a channel and its feature dimension is time,
        # we might want single_beta_data to be [nChan, nTime].
        # If so, transpose here:
        single_beta_data = single_beta_data.T  # shape: [nChan, nTime]

        # For an autoencoder, features=labels
        x_tensor = torch.tensor(single_beta_data, dtype=torch.float32)
        x_tensor = x_tensor.unsqueeze(0)

        subject_datasets.append(TensorDataset(x_tensor, x_tensor))

    return ConcatDataset(subject_datasets)
# Out:
# cuda

# %%
# ===========================================
# 4) PyG Graph Dataset
# ===========================================
class EEGGraphDataset(torch.utils.data.Dataset):
    """
    Wraps a standard dataset so that each item is a PyG Data object:
      x -> node features (channels)
      edge_index -> adjacency
    """
    def __init__(self, eeg_data, edge_index):
        self.eeg_data = eeg_data
        self.edge_index = edge_index

    def __len__(self):
        return len(self.eeg_data)

    def __getitem__(self, idx):
        # item: (x, x) because it's autoencoder
        sample = self.eeg_data[idx]
        x = sample[0]  # shape: [nChan, nTime] (if you used transpose above)
        # Convert x -> float32, build PyG Data
        graph_data = Data(x=torch.tensor(x, dtype=torch.float32),
                          edge_index=self.edge_index)
        return graph_data

# %%
# ===========================================
# 5) Define GraphAutoencoder
# ===========================================
class GraphAutoencoder(nn.Module):
    def __init__(self, num_features, embedding_dim=64):
        """
        num_features = dimension of each node's feature vector.
                       If each channel is a node, and you pass
                       [nChan, nTime], then num_features = nTime.
        """
        super(GraphAutoencoder, self).__init__()
        # Example with two ARMAConv layers
        self.encoder_gcn1 = pyg_nn.ARMAConv(num_features, 128, 
                                            num_stacks=2, 
                                            num_layers=3,
                                            shared_weights=True)
        self.encoder_gcn2 = pyg_nn.ARMAConv(128, embedding_dim, 
                                            num_stacks=2, 
                                            num_layers=3,
                                            shared_weights=True)
        self.decoder_fc1 = nn.Linear(embedding_dim, 128)
        self.decoder_fc2 = nn.Linear(128, num_features)

    def forward(self, x, edge_index):
        x = torch.relu(self.encoder_gcn1(x, edge_index))
        latent = torch.relu(self.encoder_gcn2(x, edge_index))
        x = torch.relu(self.decoder_fc1(latent))
        reconstructed = self.decoder_fc2(x)
        return reconstructed

# %%
# ===========================================
# 6) Training and evaluation
# ===========================================
def train_model_all(model, train_loader, device, num_epochs):
    model.to(device)
    optimizer = optim.Adam(model.parameters(), lr=1e-3)
    criterion = nn.SmoothL1Loss()

    for epoch in range(num_epochs):
        model.train()
        epoch_loss = 0.0
        for batch_data in train_loader:
            batch_data = batch_data.to(device)
            optimizer.zero_grad()

            # Forward
            reconstructed = model(batch_data.x, batch_data.edge_index)
            loss = criterion(reconstructed, batch_data.x)

            # Backprop
            loss.backward()
            optimizer.step()
            epoch_loss += loss.item()

        epoch_loss /= len(train_loader)
        print(f"Beta Model Training - Epoch [{epoch+1}/{num_epochs}], Loss: {epoch_loss:.4f}")
    return model

def evaluation_model(model, data_sample, edge_index, device):
    """
    data_sample: shape [nChan, nTime], or [nTime, nChan],
                 whichever you used in training.
    Returns: (original_np, reconstructed_np, error_np)
    """
    model.eval()
    with torch.no_grad():
        x = torch.tensor(data_sample, dtype=torch.float32, device=device)
        eidx = edge_index.to(device)
        reconstructed = model(x, eidx)
    orig = x.cpu().numpy()
    recon = reconstructed.cpu().numpy()
    error = orig - recon
    return orig, recon, error

# %%
# Channel Masking

def channel_masking(x_n, ch_idx, mode='zero'):
    x_masked = x_n.copy()
    if mode == 'zero':
        x_masked[ch_idx, :] = 0.0
    elif mode == 'noise':
        mu = x_n[ch_idx, :].mean()
        sigma = x_n[ch_idx, :].std()
        x_masked[ch_idx, :] = np.random.normal(mu, sigma, size=x_n[ch_idx, :].shape)
    return x_masked

def apply_channel_masking(model, sample_n, edge_index, device, mode):
    model.eval()
    with torch.no_grad():
        x = torch.tensor(sample_n, dtype=torch.float32, device=device)
        recon = model(x, edge_index.to(device))
        base_lose = nn.SmoothL1Loss()(recon, x).item()
        
        nChan = sample_n.shape[0]
        imp = np.zeros(nChan)
        
        for c in range(nChan):
            x_masked_n = channel_masking(sample_n, c, mode=mode)
            x_masked = torch.tensor(x_masked_n, dtype=torch.float32, device=device)
            recon_masked = model(x_masked, edge_index.to(device))
            masked_loss = nn.SmoothL1Loss()(recon_masked, x_masked).item()
            imp[c] = masked_loss - base_lose
            
    return imp

# %%
# Channel dropping
from torch_geometric.utils import subgraph


def channel_dropping(model, sample_n, edge_index, device):
    model.eval()
    with torch.no_grad():
        x = torch.tensor(sample_n, dtype=torch.float32, device=device)
        recon = model(x, edge_index.to(device))
        base_loss = nn.SmoothL1Loss()(recon, x).item()

        nChan = sample_n.shape[0]
        imp = np.zeros(nChan)
        all_channels = torch.arange(nChan, device=device)
        e_idx = edge_index.to(device)
        
        for c in range(nChan):
            mask = torch.ones(nChan, dtype=torch.bool, device=device)
            mask[c] = False
            masked_channels = all_channels[mask]
            masked_edge_index = subgraph(masked_channels, e_idx, relabel_nodes=True)[0]
            masked_x = x[masked_channels, :]
            recon_masked = model(masked_x, masked_edge_index)
            masked_loss = nn.SmoothL1Loss()(recon_masked, masked_x).item()
            imp[c] = masked_loss - base_loss
            
    return imp

# %%
num_features = nTime   # if each channel is a node, and feature vector = [nTime]
num_epochs   = 200     # number of training - set as needed
batch_size   = 4;      # dataset/batch to update hyperparameters

models = []

imp_zero_list = []
imp_drop_list = []
for iBeta in range(nBeta):
    print(f"\n=== Building dataset/model for Beta {iBeta} ===")
    # Build dataset & loader
    full_dataset_i  = build_concat_dataset_for_beta(datain, iBeta)
    graph_dataset_i = EEGGraphDataset(full_dataset_i, edge_index)
    full_loader_i   = GeometricDataLoader(graph_dataset_i, batch_size=batch_size, shuffle=True)

    # Init model & train
    model_i = GraphAutoencoder(num_features=num_features, embedding_dim=32)
    model_i = train_model_all(model_i, full_loader_i, device, num_epochs=num_epochs)
    models.append(model_i)

    imp_zero_per_subject = []
    imp_drop_per_subject = []
    for s in range(len(full_dataset_i)):
        x_s = full_dataset_i[s][0].numpy()  # [nChan, nTime]
        imp_zero = apply_channel_masking(model_i, x_s, edge_index, device, mode='zero')
        imp_drop = channel_dropping(model_i, x_s, edge_index, device)
        imp_zero_per_subject.append(imp_zero)
        imp_drop_per_subject.append(imp_drop)
        
    imp_zero_list.append(np.array(imp_zero_per_subject))
    imp_drop_list.append(np.array(imp_drop_per_subject))
    
all_imp_zero = np.array(imp_zero_list)
all_imp_drop = np.array(imp_drop_list)
# Out:
# === Building dataset/model for Beta 0 ===
# C:\Users\86136\AppData\Local\Temp\ipykernel_54372\1382389434.py:22: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   graph_data = Data(x=torch.tensor(x, dtype=torch.float32),
# Beta Model Training - Epoch [1/200], Loss: 0.7662
# Beta Model Training - Epoch [2/200], Loss: 0.5737
# Beta Model Training - Epoch [3/200], Loss: 0.4263
# Beta Model Training - Epoch [4/200], Loss: 0.3755
# Beta Model Training - Epoch [5/200], Loss: 0.3442
# Beta Model Training - Epoch [6/200], Loss: 0.3307
# Beta Model Training - Epoch [7/200], Loss: 0.3215
# Beta Model Training - Epoch [8/200], Loss: 0.3093
# Beta Model Training - Epoch [9/200], Loss: 0.2891
# Beta Model Training - Epoch [10/200], Loss: 0.2682
# Beta Model Training - Epoch [11/200], Loss: 0.2469
# Beta Model Training - Epoch [12/200], Loss: 0.2305
# Beta Model Training - Epoch [13/200], Loss: 0.2190
# Beta Model Training - Epoch [14/200], Loss: 0.2137
# Beta Model Training - Epoch [15/200], Loss: 0.2035
# Beta Model Training - Epoch [16/200], Loss: 0.1971
# Beta Model Training - Epoch [17/200], Loss: 0.1799
# Beta Model Training - Epoch [18/200], Loss: 0.1713
# Beta Model Training - Epoch [19/200], Loss: 0.1661
# Beta Model Training - Epoch [20/200], Loss: 0.1594
# Beta Model Training - Epoch [21/200], Loss: 0.1528
# Beta Model Training - Epoch [22/200], Loss: 0.1482
# Beta Model Training - Epoch [23/200], Loss: 0.1448
# Beta Model Training - Epoch [24/200], Loss: 0.1416
# Beta Model Training - Epoch [25/200], Loss: 0.1388
# Beta Model Training - Epoch [26/200], Loss: 0.1349
# Beta Model Training - Epoch [27/200], Loss: 0.1340
# Beta Model Training - Epoch [28/200], Loss: 0.1316
# Beta Model Training - Epoch [29/200], Loss: 0.1247
# Beta Model Training - Epoch [30/200], Loss: 0.1228
# Beta Model Training - Epoch [31/200], Loss: 0.1205
# Beta Model Training - Epoch [32/200], Loss: 0.1173
# Beta Model Training - Epoch [33/200], Loss: 0.1137
# Beta Model Training - Epoch [34/200], Loss: 0.1124
# Beta Model Training - Epoch [35/200], Loss: 0.1100
# Beta Model Training - Epoch [36/200], Loss: 0.1066
# Beta Model Training - Epoch [37/200], Loss: 0.1043
# Beta Model Training - Epoch [38/200], Loss: 0.1032
# Beta Model Training - Epoch [39/200], Loss: 0.1020
# Beta Model Training - Epoch [40/200], Loss: 0.0991
# Beta Model Training - Epoch [41/200], Loss: 0.0974
# Beta Model Training - Epoch [42/200], Loss: 0.0955
# Beta Model Training - Epoch [43/200], Loss: 0.0952
# Beta Model Training - Epoch [44/200], Loss: 0.0982
# Beta Model Training - Epoch [45/200], Loss: 0.0970
# Beta Model Training - Epoch [46/200], Loss: 0.0957
# Beta Model Training - Epoch [47/200], Loss: 0.0974
# Beta Model Training - Epoch [48/200], Loss: 0.0988
# Beta Model Training - Epoch [49/200], Loss: 0.0961
# Beta Model Training - Epoch [50/200], Loss: 0.0895
# Beta Model Training - Epoch [51/200], Loss: 0.0879
# Beta Model Training - Epoch [52/200], Loss: 0.0858
# Beta Model Training - Epoch [53/200], Loss: 0.0831
# Beta Model Training - Epoch [54/200], Loss: 0.0819
# Beta Model Training - Epoch [55/200], Loss: 0.0812
# Beta Model Training - Epoch [56/200], Loss: 0.0829
# Beta Model Training - Epoch [57/200], Loss: 0.0811
# Beta Model Training - Epoch [58/200], Loss: 0.0795
# Beta Model Training - Epoch [59/200], Loss: 0.0775
# Beta Model Training - Epoch [60/200], Loss: 0.0787
# Beta Model Training - Epoch [61/200], Loss: 0.0772
# Beta Model Training - Epoch [62/200], Loss: 0.0769
# Beta Model Training - Epoch [63/200], Loss: 0.0757
# Beta Model Training - Epoch [64/200], Loss: 0.0735
# Beta Model Training - Epoch [65/200], Loss: 0.0741
# Beta Model Training - Epoch [66/200], Loss: 0.0737
# Beta Model Training - Epoch [67/200], Loss: 0.0737
# Beta Model Training - Epoch [68/200], Loss: 0.0739
# Beta Model Training - Epoch [69/200], Loss: 0.0720
# Beta Model Training - Epoch [70/200], Loss: 0.0722
# Beta Model Training - Epoch [71/200], Loss: 0.0727
# Beta Model Training - Epoch [72/200], Loss: 0.0722
# Beta Model Training - Epoch [73/200], Loss: 0.0707
# Beta Model Training - Epoch [74/200], Loss: 0.0710
# Beta Model Training - Epoch [75/200], Loss: 0.0716
# Beta Model Training - Epoch [76/200], Loss: 0.0695
# Beta Model Training - Epoch [77/200], Loss: 0.0694
# Beta Model Training - Epoch [78/200], Loss: 0.0689
# Beta Model Training - Epoch [79/200], Loss: 0.0685
# Beta Model Training - Epoch [80/200], Loss: 0.0706
# Beta Model Training - Epoch [81/200], Loss: 0.0700
# Beta Model Training - Epoch [82/200], Loss: 0.0751
# Beta Model Training - Epoch [83/200], Loss: 0.0764
# Beta Model Training - Epoch [84/200], Loss: 0.0736
# Beta Model Training - Epoch [85/200], Loss: 0.0729
# Beta Model Training - Epoch [86/200], Loss: 0.0691
# Beta Model Training - Epoch [87/200], Loss: 0.0679
# Beta Model Training - Epoch [88/200], Loss: 0.0660
# Beta Model Training - Epoch [89/200], Loss: 0.0653
# Beta Model Training - Epoch [90/200], Loss: 0.0640
# Beta Model Training - Epoch [91/200], Loss: 0.0627
# Beta Model Training - Epoch [92/200], Loss: 0.0629
# Beta Model Training - Epoch [93/200], Loss: 0.0617
# Beta Model Training - Epoch [94/200], Loss: 0.0620
# Beta Model Training - Epoch [95/200], Loss: 0.0614
# Beta Model Training - Epoch [96/200], Loss: 0.0620
# Beta Model Training - Epoch [97/200], Loss: 0.0613
# Beta Model Training - Epoch [98/200], Loss: 0.0618
# Beta Model Training - Epoch [99/200], Loss: 0.0625
# Beta Model Training - Epoch [100/200], Loss: 0.0610
# Beta Model Training - Epoch [101/200], Loss: 0.0618
# Beta Model Training - Epoch [102/200], Loss: 0.0616
# Beta Model Training - Epoch [103/200], Loss: 0.0603
# Beta Model Training - Epoch [104/200], Loss: 0.0601
# Beta Model Training - Epoch [105/200], Loss: 0.0589
# Beta Model Training - Epoch [106/200], Loss: 0.0598
# Beta Model Training - Epoch [107/200], Loss: 0.0606
# Beta Model Training - Epoch [108/200], Loss: 0.0613
# Beta Model Training - Epoch [109/200], Loss: 0.0637
# Beta Model Training - Epoch [110/200], Loss: 0.0633
# Beta Model Training - Epoch [111/200], Loss: 0.0627
# Beta Model Training - Epoch [112/200], Loss: 0.0603
# Beta Model Training - Epoch [113/200], Loss: 0.0621
# Beta Model Training - Epoch [114/200], Loss: 0.0647
# Beta Model Training - Epoch [115/200], Loss: 0.0621
# Beta Model Training - Epoch [116/200], Loss: 0.0606
# Beta Model Training - Epoch [117/200], Loss: 0.0595
# Beta Model Training - Epoch [118/200], Loss: 0.0591
# Beta Model Training - Epoch [119/200], Loss: 0.0585
# Beta Model Training - Epoch [120/200], Loss: 0.0617
# Beta Model Training - Epoch [121/200], Loss: 0.0592
# Beta Model Training - Epoch [122/200], Loss: 0.0584
# Beta Model Training - Epoch [123/200], Loss: 0.0573
# Beta Model Training - Epoch [124/200], Loss: 0.0569
# Beta Model Training - Epoch [125/200], Loss: 0.0573
# Beta Model Training - Epoch [126/200], Loss: 0.0564
# Beta Model Training - Epoch [127/200], Loss: 0.0568
# Beta Model Training - Epoch [128/200], Loss: 0.0558
# Beta Model Training - Epoch [129/200], Loss: 0.0558
# Beta Model Training - Epoch [130/200], Loss: 0.0555
# Beta Model Training - Epoch [131/200], Loss: 0.0549
# Beta Model Training - Epoch [132/200], Loss: 0.0551
# Beta Model Training - Epoch [133/200], Loss: 0.0552
# Beta Model Training - Epoch [134/200], Loss: 0.0548
# Beta Model Training - Epoch [135/200], Loss: 0.0553
# Beta Model Training - Epoch [136/200], Loss: 0.0552
# Beta Model Training - Epoch [137/200], Loss: 0.0550
# Beta Model Training - Epoch [138/200], Loss: 0.0546
# Beta Model Training - Epoch [139/200], Loss: 0.0545
# Beta Model Training - Epoch [140/200], Loss: 0.0541
# Beta Model Training - Epoch [141/200], Loss: 0.0541
# Beta Model Training - Epoch [142/200], Loss: 0.0543
# Beta Model Training - Epoch [143/200], Loss: 0.0546
# Beta Model Training - Epoch [144/200], Loss: 0.0569
# Beta Model Training - Epoch [145/200], Loss: 0.0554
# Beta Model Training - Epoch [146/200], Loss: 0.0550
# Beta Model Training - Epoch [147/200], Loss: 0.0551
# Beta Model Training - Epoch [148/200], Loss: 0.0558
# Beta Model Training - Epoch [149/200], Loss: 0.0556
# Beta Model Training - Epoch [150/200], Loss: 0.0543
# Beta Model Training - Epoch [151/200], Loss: 0.0546
# Beta Model Training - Epoch [152/200], Loss: 0.0539
# Beta Model Training - Epoch [153/200], Loss: 0.0542
# Beta Model Training - Epoch [154/200], Loss: 0.0528
# Beta Model Training - Epoch [155/200], Loss: 0.0532
# Beta Model Training - Epoch [156/200], Loss: 0.0529
# Beta Model Training - Epoch [157/200], Loss: 0.0527
# Beta Model Training - Epoch [158/200], Loss: 0.0526
# Beta Model Training - Epoch [159/200], Loss: 0.0545
# Beta Model Training - Epoch [160/200], Loss: 0.0515
# Beta Model Training - Epoch [161/200], Loss: 0.0515
# Beta Model Training - Epoch [162/200], Loss: 0.0513
# Beta Model Training - Epoch [163/200], Loss: 0.0523
# Beta Model Training - Epoch [164/200], Loss: 0.0521
# Beta Model Training - Epoch [165/200], Loss: 0.0513
# Beta Model Training - Epoch [166/200], Loss: 0.0533
# Beta Model Training - Epoch [167/200], Loss: 0.0564
# Beta Model Training - Epoch [168/200], Loss: 0.0549
# Beta Model Training - Epoch [169/200], Loss: 0.0543
# Beta Model Training - Epoch [170/200], Loss: 0.0558
# Beta Model Training - Epoch [171/200], Loss: 0.0541
# Beta Model Training - Epoch [172/200], Loss: 0.0566
# Beta Model Training - Epoch [173/200], Loss: 0.0543
# Beta Model Training - Epoch [174/200], Loss: 0.0547
# Beta Model Training - Epoch [175/200], Loss: 0.0522
# Beta Model Training - Epoch [176/200], Loss: 0.0515
# Beta Model Training - Epoch [177/200], Loss: 0.0506
# Beta Model Training - Epoch [178/200], Loss: 0.0505
# Beta Model Training - Epoch [179/200], Loss: 0.0504
# Beta Model Training - Epoch [180/200], Loss: 0.0527
# Beta Model Training - Epoch [181/200], Loss: 0.0549
# Beta Model Training - Epoch [182/200], Loss: 0.0529
# Beta Model Training - Epoch [183/200], Loss: 0.0508
# Beta Model Training - Epoch [184/200], Loss: 0.0519
# Beta Model Training - Epoch [185/200], Loss: 0.0545
# Beta Model Training - Epoch [186/200], Loss: 0.0572
# Beta Model Training - Epoch [187/200], Loss: 0.0580
# Beta Model Training - Epoch [188/200], Loss: 0.0523
# Beta Model Training - Epoch [189/200], Loss: 0.0506
# Beta Model Training - Epoch [190/200], Loss: 0.0509
# Beta Model Training - Epoch [191/200], Loss: 0.0506
# Beta Model Training - Epoch [192/200], Loss: 0.0503
# Beta Model Training - Epoch [193/200], Loss: 0.0503
# Beta Model Training - Epoch [194/200], Loss: 0.0521
# Beta Model Training - Epoch [195/200], Loss: 0.0503
# Beta Model Training - Epoch [196/200], Loss: 0.0501
# Beta Model Training - Epoch [197/200], Loss: 0.0502
# Beta Model Training - Epoch [198/200], Loss: 0.0494
# Beta Model Training - Epoch [199/200], Loss: 0.0500
# Beta Model Training - Epoch [200/200], Loss: 0.0485
#
# === Building dataset/model for Beta 1 ===
# Beta Model Training - Epoch [1/200], Loss: 0.7415
# Beta Model Training - Epoch [2/200], Loss: 0.5991
# Beta Model Training - Epoch [3/200], Loss: 0.4753
# Beta Model Training - Epoch [4/200], Loss: 0.4013
# Beta Model Training - Epoch [5/200], Loss: 0.3651
# Beta Model Training - Epoch [6/200], Loss: 0.3383
# Beta Model Training - Epoch [7/200], Loss: 0.3117
# Beta Model Training - Epoch [8/200], Loss: 0.2902
# Beta Model Training - Epoch [9/200], Loss: 0.2693
# Beta Model Training - Epoch [10/200], Loss: 0.2468
# Beta Model Training - Epoch [11/200], Loss: 0.2288
# Beta Model Training - Epoch [12/200], Loss: 0.2185
# Beta Model Training - Epoch [13/200], Loss: 0.2069
# Beta Model Training - Epoch [14/200], Loss: 0.2004
# Beta Model Training - Epoch [15/200], Loss: 0.1916
# Beta Model Training - Epoch [16/200], Loss: 0.1875
# Beta Model Training - Epoch [17/200], Loss: 0.1782
# Beta Model Training - Epoch [18/200], Loss: 0.1691
# Beta Model Training - Epoch [19/200], Loss: 0.1603
# Beta Model Training - Epoch [20/200], Loss: 0.1520
# Beta Model Training - Epoch [21/200], Loss: 0.1471
# Beta Model Training - Epoch [22/200], Loss: 0.1421
# Beta Model Training - Epoch [23/200], Loss: 0.1355
# Beta Model Training - Epoch [24/200], Loss: 0.1330
# Beta Model Training - Epoch [25/200], Loss: 0.1284
# Beta Model Training - Epoch [26/200], Loss: 0.1254
# Beta Model Training - Epoch [27/200], Loss: 0.1232
# Beta Model Training - Epoch [28/200], Loss: 0.1199
# Beta Model Training - Epoch [29/200], Loss: 0.1199
# Beta Model Training - Epoch [30/200], Loss: 0.1196
# Beta Model Training - Epoch [31/200], Loss: 0.1201
# Beta Model Training - Epoch [32/200], Loss: 0.1142
# Beta Model Training - Epoch [33/200], Loss: 0.1106
# Beta Model Training - Epoch [34/200], Loss: 0.1090
# Beta Model Training - Epoch [35/200], Loss: 0.1069
# Beta Model Training - Epoch [36/200], Loss: 0.1046
# Beta Model Training - Epoch [37/200], Loss: 0.1045
# Beta Model Training - Epoch [38/200], Loss: 0.1054
# Beta Model Training - Epoch [39/200], Loss: 0.1069
# Beta Model Training - Epoch [40/200], Loss: 0.1049
# Beta Model Training - Epoch [41/200], Loss: 0.1027
# Beta Model Training - Epoch [42/200], Loss: 0.0967
# Beta Model Training - Epoch [43/200], Loss: 0.0956
# Beta Model Training - Epoch [44/200], Loss: 0.0929
# Beta Model Training - Epoch [45/200], Loss: 0.0926
# Beta Model Training - Epoch [46/200], Loss: 0.0929
# Beta Model Training - Epoch [47/200], Loss: 0.0911
# Beta Model Training - Epoch [48/200], Loss: 0.0903
# Beta Model Training - Epoch [49/200], Loss: 0.0943
# Beta Model Training - Epoch [50/200], Loss: 0.0901
# Beta Model Training - Epoch [51/200], Loss: 0.0888
# Beta Model Training - Epoch [52/200], Loss: 0.0898
# Beta Model Training - Epoch [53/200], Loss: 0.0874
# Beta Model Training - Epoch [54/200], Loss: 0.0864
# Beta Model Training - Epoch [55/200], Loss: 0.0864
# Beta Model Training - Epoch [56/200], Loss: 0.0852
# Beta Model Training - Epoch [57/200], Loss: 0.0854
# Beta Model Training - Epoch [58/200], Loss: 0.0826
# Beta Model Training - Epoch [59/200], Loss: 0.0822
# Beta Model Training - Epoch [60/200], Loss: 0.0807
# Beta Model Training - Epoch [61/200], Loss: 0.0803
# Beta Model Training - Epoch [62/200], Loss: 0.0809
# Beta Model Training - Epoch [63/200], Loss: 0.0790
# Beta Model Training - Epoch [64/200], Loss: 0.0787
# Beta Model Training - Epoch [65/200], Loss: 0.0782
# Beta Model Training - Epoch [66/200], Loss: 0.0774
# Beta Model Training - Epoch [67/200], Loss: 0.0760
# Beta Model Training - Epoch [68/200], Loss: 0.0764
# Beta Model Training - Epoch [69/200], Loss: 0.0758
# Beta Model Training - Epoch [70/200], Loss: 0.0735
# Beta Model Training - Epoch [71/200], Loss: 0.0748
# Beta Model Training - Epoch [72/200], Loss: 0.0748
# Beta Model Training - Epoch [73/200], Loss: 0.0745
# Beta Model Training - Epoch [74/200], Loss: 0.0751
# Beta Model Training - Epoch [75/200], Loss: 0.0781
# Beta Model Training - Epoch [76/200], Loss: 0.0755
# Beta Model Training - Epoch [77/200], Loss: 0.0743
# Beta Model Training - Epoch [78/200], Loss: 0.0741
# Beta Model Training - Epoch [79/200], Loss: 0.0716
# Beta Model Training - Epoch [80/200], Loss: 0.0701
# Beta Model Training - Epoch [81/200], Loss: 0.0692
# Beta Model Training - Epoch [82/200], Loss: 0.0688
# Beta Model Training - Epoch [83/200], Loss: 0.0694
# Beta Model Training - Epoch [84/200], Loss: 0.0678
# Beta Model Training - Epoch [85/200], Loss: 0.0700
# Beta Model Training - Epoch [86/200], Loss: 0.0691
# Beta Model Training - Epoch [87/200], Loss: 0.0693
# Beta Model Training - Epoch [88/200], Loss: 0.0692
# Beta Model Training - Epoch [89/200], Loss: 0.0698
# Beta Model Training - Epoch [90/200], Loss: 0.0684
# Beta Model Training - Epoch [91/200], Loss: 0.0694
# Beta Model Training - Epoch [92/200], Loss: 0.0682
# Beta Model Training - Epoch [93/200], Loss: 0.0687
# Beta Model Training - Epoch [94/200], Loss: 0.0657
# Beta Model Training - Epoch [95/200], Loss: 0.0681
# Beta Model Training - Epoch [96/200], Loss: 0.0655
# Beta Model Training - Epoch [97/200], Loss: 0.0643
# Beta Model Training - Epoch [98/200], Loss: 0.0639
# Beta Model Training - Epoch [99/200], Loss: 0.0626
# Beta Model Training - Epoch [100/200], Loss: 0.0616
# Beta Model Training - Epoch [101/200], Loss: 0.0614
# Beta Model Training - Epoch [102/200], Loss: 0.0610
# Beta Model Training - Epoch [103/200], Loss: 0.0602
# Beta Model Training - Epoch [104/200], Loss: 0.0600
# Beta Model Training - Epoch [105/200], Loss: 0.0602
# Beta Model Training - Epoch [106/200], Loss: 0.0600
# Beta Model Training - Epoch [107/200], Loss: 0.0593
# Beta Model Training - Epoch [108/200], Loss: 0.0590
# Beta Model Training - Epoch [109/200], Loss: 0.0598
# Beta Model Training - Epoch [110/200], Loss: 0.0591
# Beta Model Training - Epoch [111/200], Loss: 0.0601
# Beta Model Training - Epoch [112/200], Loss: 0.0617
# Beta Model Training - Epoch [113/200], Loss: 0.0630
# Beta Model Training - Epoch [114/200], Loss: 0.0741
# Beta Model Training - Epoch [115/200], Loss: 0.0760
# Beta Model Training - Epoch [116/200], Loss: 0.0694
# Beta Model Training - Epoch [117/200], Loss: 0.0669
# Beta Model Training - Epoch [118/200], Loss: 0.0639
# Beta Model Training - Epoch [119/200], Loss: 0.0630
# Beta Model Training - Epoch [120/200], Loss: 0.0607
# Beta Model Training - Epoch [121/200], Loss: 0.0621
# Beta Model Training - Epoch [122/200], Loss: 0.0594
# Beta Model Training - Epoch [123/200], Loss: 0.0587
# Beta Model Training - Epoch [124/200], Loss: 0.0589
# Beta Model Training - Epoch [125/200], Loss: 0.0571
# Beta Model Training - Epoch [126/200], Loss: 0.0560
# Beta Model Training - Epoch [127/200], Loss: 0.0572
# Beta Model Training - Epoch [128/200], Loss: 0.0566
# Beta Model Training - Epoch [129/200], Loss: 0.0557
# Beta Model Training - Epoch [130/200], Loss: 0.0575
# Beta Model Training - Epoch [131/200], Loss: 0.0564
# Beta Model Training - Epoch [132/200], Loss: 0.0558
# Beta Model Training - Epoch [133/200], Loss: 0.0563
# Beta Model Training - Epoch [134/200], Loss: 0.0570
# Beta Model Training - Epoch [135/200], Loss: 0.0575
# Beta Model Training - Epoch [136/200], Loss: 0.0571
# Beta Model Training - Epoch [137/200], Loss: 0.0567
# Beta Model Training - Epoch [138/200], Loss: 0.0573
# Beta Model Training - Epoch [139/200], Loss: 0.0580
# Beta Model Training - Epoch [140/200], Loss: 0.0575
# Beta Model Training - Epoch [141/200], Loss: 0.0574
# Beta Model Training - Epoch [142/200], Loss: 0.0560
# Beta Model Training - Epoch [143/200], Loss: 0.0555
# Beta Model Training - Epoch [144/200], Loss: 0.0558
# Beta Model Training - Epoch [145/200], Loss: 0.0559
# Beta Model Training - Epoch [146/200], Loss: 0.0552
# Beta Model Training - Epoch [147/200], Loss: 0.0548
# Beta Model Training - Epoch [148/200], Loss: 0.0548
# Beta Model Training - Epoch [149/200], Loss: 0.0550
# Beta Model Training - Epoch [150/200], Loss: 0.0541
# Beta Model Training - Epoch [151/200], Loss: 0.0544
# Beta Model Training - Epoch [152/200], Loss: 0.0540
# Beta Model Training - Epoch [153/200], Loss: 0.0537
# Beta Model Training - Epoch [154/200], Loss: 0.0534
# Beta Model Training - Epoch [155/200], Loss: 0.0526
# Beta Model Training - Epoch [156/200], Loss: 0.0529
# Beta Model Training - Epoch [157/200], Loss: 0.0536
# Beta Model Training - Epoch [158/200], Loss: 0.0532
# Beta Model Training - Epoch [159/200], Loss: 0.0534
# Beta Model Training - Epoch [160/200], Loss: 0.0536
# Beta Model Training - Epoch [161/200], Loss: 0.0529
# Beta Model Training - Epoch [162/200], Loss: 0.0530
# Beta Model Training - Epoch [163/200], Loss: 0.0525
# Beta Model Training - Epoch [164/200], Loss: 0.0519
# Beta Model Training - Epoch [165/200], Loss: 0.0521
# Beta Model Training - Epoch [166/200], Loss: 0.0519
# Beta Model Training - Epoch [167/200], Loss: 0.0519
# Beta Model Training - Epoch [168/200], Loss: 0.0533
# Beta Model Training - Epoch [169/200], Loss: 0.0538
# Beta Model Training - Epoch [170/200], Loss: 0.0531
# Beta Model Training - Epoch [171/200], Loss: 0.0536
# Beta Model Training - Epoch [172/200], Loss: 0.0566
# Beta Model Training - Epoch [173/200], Loss: 0.0544
# Beta Model Training - Epoch [174/200], Loss: 0.0551
# Beta Model Training - Epoch [175/200], Loss: 0.0544
# Beta Model Training - Epoch [176/200], Loss: 0.0528
# Beta Model Training - Epoch [177/200], Loss: 0.0518
# Beta Model Training - Epoch [178/200], Loss: 0.0516
# Beta Model Training - Epoch [179/200], Loss: 0.0511
# Beta Model Training - Epoch [180/200], Loss: 0.0514
# Beta Model Training - Epoch [181/200], Loss: 0.0506
# Beta Model Training - Epoch [182/200], Loss: 0.0519
# Beta Model Training - Epoch [183/200], Loss: 0.0508
# Beta Model Training - Epoch [184/200], Loss: 0.0501
# Beta Model Training - Epoch [185/200], Loss: 0.0506
# Beta Model Training - Epoch [186/200], Loss: 0.0504
# Beta Model Training - Epoch [187/200], Loss: 0.0504
# Beta Model Training - Epoch [188/200], Loss: 0.0500
# Beta Model Training - Epoch [189/200], Loss: 0.0505
# Beta Model Training - Epoch [190/200], Loss: 0.0505
# Beta Model Training - Epoch [191/200], Loss: 0.0519
# Beta Model Training - Epoch [192/200], Loss: 0.0516
# Beta Model Training - Epoch [193/200], Loss: 0.0525
# Beta Model Training - Epoch [194/200], Loss: 0.0514
# Beta Model Training - Epoch [195/200], Loss: 0.0519
# Beta Model Training - Epoch [196/200], Loss: 0.0513
# Beta Model Training - Epoch [197/200], Loss: 0.0523
# Beta Model Training - Epoch [198/200], Loss: 0.0525
# Beta Model Training - Epoch [199/200], Loss: 0.0522
# Beta Model Training - Epoch [200/200], Loss: 0.0526
#
# === Building dataset/model for Beta 2 ===
# Beta Model Training - Epoch [1/200], Loss: 1.7320
# Beta Model Training - Epoch [2/200], Loss: 1.1240
# Beta Model Training - Epoch [3/200], Loss: 0.7062
# Beta Model Training - Epoch [4/200], Loss: 0.5236
# Beta Model Training - Epoch [5/200], Loss: 0.4283
# Beta Model Training - Epoch [6/200], Loss: 0.3621
# Beta Model Training - Epoch [7/200], Loss: 0.3322
# Beta Model Training - Epoch [8/200], Loss: 0.3136
# Beta Model Training - Epoch [9/200], Loss: 0.3052
# Beta Model Training - Epoch [10/200], Loss: 0.2913
# Beta Model Training - Epoch [11/200], Loss: 0.2802
# Beta Model Training - Epoch [12/200], Loss: 0.2616
# Beta Model Training - Epoch [13/200], Loss: 0.2483
# Beta Model Training - Epoch [14/200], Loss: 0.2306
# Beta Model Training - Epoch [15/200], Loss: 0.2213
# Beta Model Training - Epoch [16/200], Loss: 0.2067
# Beta Model Training - Epoch [17/200], Loss: 0.1944
# Beta Model Training - Epoch [18/200], Loss: 0.1826
# Beta Model Training - Epoch [19/200], Loss: 0.1775
# Beta Model Training - Epoch [20/200], Loss: 0.1658
# Beta Model Training - Epoch [21/200], Loss: 0.1624
# Beta Model Training - Epoch [22/200], Loss: 0.1532
# Beta Model Training - Epoch [23/200], Loss: 0.1494
# Beta Model Training - Epoch [24/200], Loss: 0.1450
# Beta Model Training - Epoch [25/200], Loss: 0.1431
# Beta Model Training - Epoch [26/200], Loss: 0.1402
# Beta Model Training - Epoch [27/200], Loss: 0.1354
# Beta Model Training - Epoch [28/200], Loss: 0.1359
# Beta Model Training - Epoch [29/200], Loss: 0.1343
# Beta Model Training - Epoch [30/200], Loss: 0.1368
# Beta Model Training - Epoch [31/200], Loss: 0.1320
# Beta Model Training - Epoch [32/200], Loss: 0.1310
# Beta Model Training - Epoch [33/200], Loss: 0.1252
# Beta Model Training - Epoch [34/200], Loss: 0.1207
# Beta Model Training - Epoch [35/200], Loss: 0.1223
# Beta Model Training - Epoch [36/200], Loss: 0.1229
# Beta Model Training - Epoch [37/200], Loss: 0.1205
# Beta Model Training - Epoch [38/200], Loss: 0.1159
# Beta Model Training - Epoch [39/200], Loss: 0.1165
# Beta Model Training - Epoch [40/200], Loss: 0.1249
# Beta Model Training - Epoch [41/200], Loss: 0.1301
# Beta Model Training - Epoch [42/200], Loss: 0.1324
# Beta Model Training - Epoch [43/200], Loss: 0.1277
# Beta Model Training - Epoch [44/200], Loss: 0.1212
# Beta Model Training - Epoch [45/200], Loss: 0.1147
# Beta Model Training - Epoch [46/200], Loss: 0.1058
# Beta Model Training - Epoch [47/200], Loss: 0.1018
# Beta Model Training - Epoch [48/200], Loss: 0.0992
# Beta Model Training - Epoch [49/200], Loss: 0.0945
# Beta Model Training - Epoch [50/200], Loss: 0.0933
# Beta Model Training - Epoch [51/200], Loss: 0.0897
# Beta Model Training - Epoch [52/200], Loss: 0.0892
# Beta Model Training - Epoch [53/200], Loss: 0.0886
# Beta Model Training - Epoch [54/200], Loss: 0.0874
# Beta Model Training - Epoch [55/200], Loss: 0.0860
# Beta Model Training - Epoch [56/200], Loss: 0.0850
# Beta Model Training - Epoch [57/200], Loss: 0.0853
# Beta Model Training - Epoch [58/200], Loss: 0.0846
# Beta Model Training - Epoch [59/200], Loss: 0.0830
# Beta Model Training - Epoch [60/200], Loss: 0.0812
# Beta Model Training - Epoch [61/200], Loss: 0.0803
# Beta Model Training - Epoch [62/200], Loss: 0.0801
# Beta Model Training - Epoch [63/200], Loss: 0.0816
# Beta Model Training - Epoch [64/200], Loss: 0.0852
# Beta Model Training - Epoch [65/200], Loss: 0.0825
# Beta Model Training - Epoch [66/200], Loss: 0.0829
# Beta Model Training - Epoch [67/200], Loss: 0.0808
# Beta Model Training - Epoch [68/200], Loss: 0.0823
# Beta Model Training - Epoch [69/200], Loss: 0.0828
# Beta Model Training - Epoch [70/200], Loss: 0.0782
# Beta Model Training - Epoch [71/200], Loss: 0.0758
# Beta Model Training - Epoch [72/200], Loss: 0.0744
# Beta Model Training - Epoch [73/200], Loss: 0.0730
# Beta Model Training - Epoch [74/200], Loss: 0.0749
# Beta Model Training - Epoch [75/200], Loss: 0.0729
# Beta Model Training - Epoch [76/200], Loss: 0.0738
# Beta Model Training - Epoch [77/200], Loss: 0.0736
# Beta Model Training - Epoch [78/200], Loss: 0.0722
# Beta Model Training - Epoch [79/200], Loss: 0.0703
# Beta Model Training - Epoch [80/200], Loss: 0.0716
# Beta Model Training - Epoch [81/200], Loss: 0.0701
# Beta Model Training - Epoch [82/200], Loss: 0.0730
# Beta Model Training - Epoch [83/200], Loss: 0.0738
# Beta Model Training - Epoch [84/200], Loss: 0.0721
# Beta Model Training - Epoch [85/200], Loss: 0.0707
# Beta Model Training - Epoch [86/200], Loss: 0.0680
# Beta Model Training - Epoch [87/200], Loss: 0.0691
# Beta Model Training - Epoch [88/200], Loss: 0.0665
# Beta Model Training - Epoch [89/200], Loss: 0.0659
# Beta Model Training - Epoch [90/200], Loss: 0.0665
# Beta Model Training - Epoch [91/200], Loss: 0.0649
# Beta Model Training - Epoch [92/200], Loss: 0.0645
# Beta Model Training - Epoch [93/200], Loss: 0.0655
# Beta Model Training - Epoch [94/200], Loss: 0.0677
# Beta Model Training - Epoch [95/200], Loss: 0.0666
# Beta Model Training - Epoch [96/200], Loss: 0.0662
# Beta Model Training - Epoch [97/200], Loss: 0.0661
# Beta Model Training - Epoch [98/200], Loss: 0.0655
# Beta Model Training - Epoch [99/200], Loss: 0.0691
# Beta Model Training - Epoch [100/200], Loss: 0.0665
# Beta Model Training - Epoch [101/200], Loss: 0.0659
# Beta Model Training - Epoch [102/200], Loss: 0.0635
# Beta Model Training - Epoch [103/200], Loss: 0.0634
# Beta Model Training - Epoch [104/200], Loss: 0.0679
# Beta Model Training - Epoch [105/200], Loss: 0.0714
# Beta Model Training - Epoch [106/200], Loss: 0.0673
# Beta Model Training - Epoch [107/200], Loss: 0.0674
# Beta Model Training - Epoch [108/200], Loss: 0.0651
# Beta Model Training - Epoch [109/200], Loss: 0.0645
# Beta Model Training - Epoch [110/200], Loss: 0.0630
# Beta Model Training - Epoch [111/200], Loss: 0.0602
# Beta Model Training - Epoch [112/200], Loss: 0.0606
# Beta Model Training - Epoch [113/200], Loss: 0.0595
# Beta Model Training - Epoch [114/200], Loss: 0.0585
# Beta Model Training - Epoch [115/200], Loss: 0.0575
# Beta Model Training - Epoch [116/200], Loss: 0.0561
# Beta Model Training - Epoch [117/200], Loss: 0.0568
# Beta Model Training - Epoch [118/200], Loss: 0.0561
# Beta Model Training - Epoch [119/200], Loss: 0.0553
# Beta Model Training - Epoch [120/200], Loss: 0.0566
# Beta Model Training - Epoch [121/200], Loss: 0.0559
# Beta Model Training - Epoch [122/200], Loss: 0.0547
# Beta Model Training - Epoch [123/200], Loss: 0.0563
# Beta Model Training - Epoch [124/200], Loss: 0.0570
# Beta Model Training - Epoch [125/200], Loss: 0.0551
# Beta Model Training - Epoch [126/200], Loss: 0.0581
# Beta Model Training - Epoch [127/200], Loss: 0.0674
# Beta Model Training - Epoch [128/200], Loss: 0.0622
# Beta Model Training - Epoch [129/200], Loss: 0.0604
# Beta Model Training - Epoch [130/200], Loss: 0.0571
# Beta Model Training - Epoch [131/200], Loss: 0.0555
# Beta Model Training - Epoch [132/200], Loss: 0.0552
# Beta Model Training - Epoch [133/200], Loss: 0.0569
# Beta Model Training - Epoch [134/200], Loss: 0.0595
# Beta Model Training - Epoch [135/200], Loss: 0.0643
# Beta Model Training - Epoch [136/200], Loss: 0.0606
# Beta Model Training - Epoch [137/200], Loss: 0.0577
# Beta Model Training - Epoch [138/200], Loss: 0.0557
# Beta Model Training - Epoch [139/200], Loss: 0.0539
# Beta Model Training - Epoch [140/200], Loss: 0.0545
# Beta Model Training - Epoch [141/200], Loss: 0.0556
# Beta Model Training - Epoch [142/200], Loss: 0.0554
# Beta Model Training - Epoch [143/200], Loss: 0.0533
# Beta Model Training - Epoch [144/200], Loss: 0.0531
# Beta Model Training - Epoch [145/200], Loss: 0.0525
# Beta Model Training - Epoch [146/200], Loss: 0.0586
# Beta Model Training - Epoch [147/200], Loss: 0.0581
# Beta Model Training - Epoch [148/200], Loss: 0.0565
# Beta Model Training - Epoch [149/200], Loss: 0.0586
# Beta Model Training - Epoch [150/200], Loss: 0.0576
# Beta Model Training - Epoch [151/200], Loss: 0.0602
# Beta Model Training - Epoch [152/200], Loss: 0.0657
# Beta Model Training - Epoch [153/200], Loss: 0.0653
# Beta Model Training - Epoch [154/200], Loss: 0.0588
# Beta Model Training - Epoch [155/200], Loss: 0.0550
# Beta Model Training - Epoch [156/200], Loss: 0.0542
# Beta Model Training - Epoch [157/200], Loss: 0.0546
# Beta Model Training - Epoch [158/200], Loss: 0.0576
# Beta Model Training - Epoch [159/200], Loss: 0.0532
# Beta Model Training - Epoch [160/200], Loss: 0.0540
# Beta Model Training - Epoch [161/200], Loss: 0.0502
# Beta Model Training - Epoch [162/200], Loss: 0.0506
# Beta Model Training - Epoch [163/200], Loss: 0.0493
# Beta Model Training - Epoch [164/200], Loss: 0.0494
# Beta Model Training - Epoch [165/200], Loss: 0.0519
# Beta Model Training - Epoch [166/200], Loss: 0.0510
# Beta Model Training - Epoch [167/200], Loss: 0.0507
# Beta Model Training - Epoch [168/200], Loss: 0.0479
# Beta Model Training - Epoch [169/200], Loss: 0.0469
# Beta Model Training - Epoch [170/200], Loss: 0.0457
# Beta Model Training - Epoch [171/200], Loss: 0.0453
# Beta Model Training - Epoch [172/200], Loss: 0.0450
# Beta Model Training - Epoch [173/200], Loss: 0.0440
# Beta Model Training - Epoch [174/200], Loss: 0.0443
# Beta Model Training - Epoch [175/200], Loss: 0.0459
# Beta Model Training - Epoch [176/200], Loss: 0.0457
# Beta Model Training - Epoch [177/200], Loss: 0.0447
# Beta Model Training - Epoch [178/200], Loss: 0.0453
# Beta Model Training - Epoch [179/200], Loss: 0.0450
# Beta Model Training - Epoch [180/200], Loss: 0.0439
# Beta Model Training - Epoch [181/200], Loss: 0.0439
# Beta Model Training - Epoch [182/200], Loss: 0.0431
# Beta Model Training - Epoch [183/200], Loss: 0.0450
# Beta Model Training - Epoch [184/200], Loss: 0.0441
# Beta Model Training - Epoch [185/200], Loss: 0.0436
# Beta Model Training - Epoch [186/200], Loss: 0.0439
# Beta Model Training - Epoch [187/200], Loss: 0.0437
# Beta Model Training - Epoch [188/200], Loss: 0.0431
# Beta Model Training - Epoch [189/200], Loss: 0.0421
# Beta Model Training - Epoch [190/200], Loss: 0.0422
# Beta Model Training - Epoch [191/200], Loss: 0.0427
# Beta Model Training - Epoch [192/200], Loss: 0.0427
# Beta Model Training - Epoch [193/200], Loss: 0.0457
# Beta Model Training - Epoch [194/200], Loss: 0.0473
# Beta Model Training - Epoch [195/200], Loss: 0.0497
# Beta Model Training - Epoch [196/200], Loss: 0.0509
# Beta Model Training - Epoch [197/200], Loss: 0.0552
# Beta Model Training - Epoch [198/200], Loss: 0.0693
# Beta Model Training - Epoch [199/200], Loss: 0.0934
# Beta Model Training - Epoch [200/200], Loss: 0.0748
#
# === Building dataset/model for Beta 3 ===
# Beta Model Training - Epoch [1/200], Loss: 1.1225
# Beta Model Training - Epoch [2/200], Loss: 0.7420
# Beta Model Training - Epoch [3/200], Loss: 0.5098
# Beta Model Training - Epoch [4/200], Loss: 0.4368
# Beta Model Training - Epoch [5/200], Loss: 0.4002
# Beta Model Training - Epoch [6/200], Loss: 0.3689
# Beta Model Training - Epoch [7/200], Loss: 0.3435
# Beta Model Training - Epoch [8/200], Loss: 0.3286
# Beta Model Training - Epoch [9/200], Loss: 0.3172
# Beta Model Training - Epoch [10/200], Loss: 0.3004
# Beta Model Training - Epoch [11/200], Loss: 0.2889
# Beta Model Training - Epoch [12/200], Loss: 0.2752
# Beta Model Training - Epoch [13/200], Loss: 0.2669
# Beta Model Training - Epoch [14/200], Loss: 0.2585
# Beta Model Training - Epoch [15/200], Loss: 0.2480
# Beta Model Training - Epoch [16/200], Loss: 0.2408
# Beta Model Training - Epoch [17/200], Loss: 0.2335
# Beta Model Training - Epoch [18/200], Loss: 0.2273
# Beta Model Training - Epoch [19/200], Loss: 0.2197
# Beta Model Training - Epoch [20/200], Loss: 0.2135
# Beta Model Training - Epoch [21/200], Loss: 0.2065
# Beta Model Training - Epoch [22/200], Loss: 0.1970
# Beta Model Training - Epoch [23/200], Loss: 0.1933
# Beta Model Training - Epoch [24/200], Loss: 0.1870
# Beta Model Training - Epoch [25/200], Loss: 0.1880
# Beta Model Training - Epoch [26/200], Loss: 0.1807
# Beta Model Training - Epoch [27/200], Loss: 0.1805
# Beta Model Training - Epoch [28/200], Loss: 0.1790
# Beta Model Training - Epoch [29/200], Loss: 0.1685
# Beta Model Training - Epoch [30/200], Loss: 0.1577
# Beta Model Training - Epoch [31/200], Loss: 0.1566
# Beta Model Training - Epoch [32/200], Loss: 0.1510
# Beta Model Training - Epoch [33/200], Loss: 0.1481
# Beta Model Training - Epoch [34/200], Loss: 0.1477
# Beta Model Training - Epoch [35/200], Loss: 0.1512
# Beta Model Training - Epoch [36/200], Loss: 0.1599
# Beta Model Training - Epoch [37/200], Loss: 0.1514
# Beta Model Training - Epoch [38/200], Loss: 0.1447
# Beta Model Training - Epoch [39/200], Loss: 0.1380
# Beta Model Training - Epoch [40/200], Loss: 0.1333
# Beta Model Training - Epoch [41/200], Loss: 0.1315
# Beta Model Training - Epoch [42/200], Loss: 0.1318
# Beta Model Training - Epoch [43/200], Loss: 0.1389
# Beta Model Training - Epoch [44/200], Loss: 0.1295
# Beta Model Training - Epoch [45/200], Loss: 0.1286
# Beta Model Training - Epoch [46/200], Loss: 0.1262
# Beta Model Training - Epoch [47/200], Loss: 0.1255
# Beta Model Training - Epoch [48/200], Loss: 0.1208
# Beta Model Training - Epoch [49/200], Loss: 0.1222
# Beta Model Training - Epoch [50/200], Loss: 0.1200
# Beta Model Training - Epoch [51/200], Loss: 0.1174
# Beta Model Training - Epoch [52/200], Loss: 0.1153
# Beta Model Training - Epoch [53/200], Loss: 0.1109
# Beta Model Training - Epoch [54/200], Loss: 0.1119
# Beta Model Training - Epoch [55/200], Loss: 0.1071
# Beta Model Training - Epoch [56/200], Loss: 0.1058
# Beta Model Training - Epoch [57/200], Loss: 0.1062
# Beta Model Training - Epoch [58/200], Loss: 0.1062
# Beta Model Training - Epoch [59/200], Loss: 0.1047
# Beta Model Training - Epoch [60/200], Loss: 0.1027
# Beta Model Training - Epoch [61/200], Loss: 0.1000
# Beta Model Training - Epoch [62/200], Loss: 0.0978
# Beta Model Training - Epoch [63/200], Loss: 0.0977
# Beta Model Training - Epoch [64/200], Loss: 0.0962
# Beta Model Training - Epoch [65/200], Loss: 0.0961
# Beta Model Training - Epoch [66/200], Loss: 0.0929
# Beta Model Training - Epoch [67/200], Loss: 0.0943
# Beta Model Training - Epoch [68/200], Loss: 0.0920
# Beta Model Training - Epoch [69/200], Loss: 0.0918
# Beta Model Training - Epoch [70/200], Loss: 0.0912
# Beta Model Training - Epoch [71/200], Loss: 0.0884
# Beta Model Training - Epoch [72/200], Loss: 0.0872
# Beta Model Training - Epoch [73/200], Loss: 0.0899
# Beta Model Training - Epoch [74/200], Loss: 0.0874
# Beta Model Training - Epoch [75/200], Loss: 0.0898
# Beta Model Training - Epoch [76/200], Loss: 0.0888
# Beta Model Training - Epoch [77/200], Loss: 0.0862
# Beta Model Training - Epoch [78/200], Loss: 0.0851
# Beta Model Training - Epoch [79/200], Loss: 0.0854
# Beta Model Training - Epoch [80/200], Loss: 0.0942
# Beta Model Training - Epoch [81/200], Loss: 0.0932
# Beta Model Training - Epoch [82/200], Loss: 0.0944
# Beta Model Training - Epoch [83/200], Loss: 0.0961
# Beta Model Training - Epoch [84/200], Loss: 0.0946
# Beta Model Training - Epoch [85/200], Loss: 0.0959
# Beta Model Training - Epoch [86/200], Loss: 0.0965
# Beta Model Training - Epoch [87/200], Loss: 0.0916
# Beta Model Training - Epoch [88/200], Loss: 0.0893
# Beta Model Training - Epoch [89/200], Loss: 0.0855
# Beta Model Training - Epoch [90/200], Loss: 0.0806
# Beta Model Training - Epoch [91/200], Loss: 0.0788
# Beta Model Training - Epoch [92/200], Loss: 0.0770
# Beta Model Training - Epoch [93/200], Loss: 0.0776
# Beta Model Training - Epoch [94/200], Loss: 0.0753
# Beta Model Training - Epoch [95/200], Loss: 0.0747
# Beta Model Training - Epoch [96/200], Loss: 0.0732
# Beta Model Training - Epoch [97/200], Loss: 0.0734
# Beta Model Training - Epoch [98/200], Loss: 0.0726
# Beta Model Training - Epoch [99/200], Loss: 0.0717
# Beta Model Training - Epoch [100/200], Loss: 0.0723
# Beta Model Training - Epoch [101/200], Loss: 0.0710
# Beta Model Training - Epoch [102/200], Loss: 0.0720
# Beta Model Training - Epoch [103/200], Loss: 0.0706
# Beta Model Training - Epoch [104/200], Loss: 0.0714
# Beta Model Training - Epoch [105/200], Loss: 0.0699
# Beta Model Training - Epoch [106/200], Loss: 0.0703
# Beta Model Training - Epoch [107/200], Loss: 0.0693
# Beta Model Training - Epoch [108/200], Loss: 0.0691
# Beta Model Training - Epoch [109/200], Loss: 0.0692
# Beta Model Training - Epoch [110/200], Loss: 0.0683
# Beta Model Training - Epoch [111/200], Loss: 0.0689
# Beta Model Training - Epoch [112/200], Loss: 0.0689
# Beta Model Training - Epoch [113/200], Loss: 0.0670
# Beta Model Training - Epoch [114/200], Loss: 0.0687
# Beta Model Training - Epoch [115/200], Loss: 0.0674
# Beta Model Training - Epoch [116/200], Loss: 0.0676
# Beta Model Training - Epoch [117/200], Loss: 0.0671
# Beta Model Training - Epoch [118/200], Loss: 0.0671
# Beta Model Training - Epoch [119/200], Loss: 0.0660
# Beta Model Training - Epoch [120/200], Loss: 0.0663
# Beta Model Training - Epoch [121/200], Loss: 0.0686
# Beta Model Training - Epoch [122/200], Loss: 0.0679
# Beta Model Training - Epoch [123/200], Loss: 0.0666
# Beta Model Training - Epoch [124/200], Loss: 0.0678
# Beta Model Training - Epoch [125/200], Loss: 0.0683
# Beta Model Training - Epoch [126/200], Loss: 0.0652
# Beta Model Training - Epoch [127/200], Loss: 0.0682
# Beta Model Training - Epoch [128/200], Loss: 0.0648
# Beta Model Training - Epoch [129/200], Loss: 0.0649
# Beta Model Training - Epoch [130/200], Loss: 0.0656
# Beta Model Training - Epoch [131/200], Loss: 0.0668
# Beta Model Training - Epoch [132/200], Loss: 0.0661
# Beta Model Training - Epoch [133/200], Loss: 0.0675
# Beta Model Training - Epoch [134/200], Loss: 0.0653
# Beta Model Training - Epoch [135/200], Loss: 0.0636
# Beta Model Training - Epoch [136/200], Loss: 0.0640
# Beta Model Training - Epoch [137/200], Loss: 0.0632
# Beta Model Training - Epoch [138/200], Loss: 0.0652
# Beta Model Training - Epoch [139/200], Loss: 0.0677
# Beta Model Training - Epoch [140/200], Loss: 0.0657
# Beta Model Training - Epoch [141/200], Loss: 0.0648
# Beta Model Training - Epoch [142/200], Loss: 0.0651
# Beta Model Training - Epoch [143/200], Loss: 0.0651
# Beta Model Training - Epoch [144/200], Loss: 0.0639
# Beta Model Training - Epoch [145/200], Loss: 0.0628
# Beta Model Training - Epoch [146/200], Loss: 0.0631
# Beta Model Training - Epoch [147/200], Loss: 0.0623
# Beta Model Training - Epoch [148/200], Loss: 0.0647
# Beta Model Training - Epoch [149/200], Loss: 0.0622
# Beta Model Training - Epoch [150/200], Loss: 0.0624
# Beta Model Training - Epoch [151/200], Loss: 0.0628
# Beta Model Training - Epoch [152/200], Loss: 0.0663
# Beta Model Training - Epoch [153/200], Loss: 0.0640
# Beta Model Training - Epoch [154/200], Loss: 0.0639
# Beta Model Training - Epoch [155/200], Loss: 0.0635
# Beta Model Training - Epoch [156/200], Loss: 0.0648
# Beta Model Training - Epoch [157/200], Loss: 0.0671
# Beta Model Training - Epoch [158/200], Loss: 0.0637
# Beta Model Training - Epoch [159/200], Loss: 0.0642
# Beta Model Training - Epoch [160/200], Loss: 0.0672
# Beta Model Training - Epoch [161/200], Loss: 0.0709
# Beta Model Training - Epoch [162/200], Loss: 0.0726
# Beta Model Training - Epoch [163/200], Loss: 0.0812
# Beta Model Training - Epoch [164/200], Loss: 0.0859
# Beta Model Training - Epoch [165/200], Loss: 0.0690
# Beta Model Training - Epoch [166/200], Loss: 0.0650
# Beta Model Training - Epoch [167/200], Loss: 0.0657
# Beta Model Training - Epoch [168/200], Loss: 0.0629
# Beta Model Training - Epoch [169/200], Loss: 0.0613
# Beta Model Training - Epoch [170/200], Loss: 0.0598
# Beta Model Training - Epoch [171/200], Loss: 0.0585
# Beta Model Training - Epoch [172/200], Loss: 0.0584
# Beta Model Training - Epoch [173/200], Loss: 0.0566
# Beta Model Training - Epoch [174/200], Loss: 0.0564
# Beta Model Training - Epoch [175/200], Loss: 0.0563
# Beta Model Training - Epoch [176/200], Loss: 0.0560
# Beta Model Training - Epoch [177/200], Loss: 0.0575
# Beta Model Training - Epoch [178/200], Loss: 0.0582
# Beta Model Training - Epoch [179/200], Loss: 0.0613
# Beta Model Training - Epoch [180/200], Loss: 0.0641
# Beta Model Training - Epoch [181/200], Loss: 0.0600
# Beta Model Training - Epoch [182/200], Loss: 0.0569
# Beta Model Training - Epoch [183/200], Loss: 0.0570
# Beta Model Training - Epoch [184/200], Loss: 0.0570
# Beta Model Training - Epoch [185/200], Loss: 0.0601
# Beta Model Training - Epoch [186/200], Loss: 0.0587
# Beta Model Training - Epoch [187/200], Loss: 0.0584
# Beta Model Training - Epoch [188/200], Loss: 0.0585
# Beta Model Training - Epoch [189/200], Loss: 0.0619
# Beta Model Training - Epoch [190/200], Loss: 0.0607
# Beta Model Training - Epoch [191/200], Loss: 0.0598
# Beta Model Training - Epoch [192/200], Loss: 0.0566
# Beta Model Training - Epoch [193/200], Loss: 0.0576
# Beta Model Training - Epoch [194/200], Loss: 0.0574
# Beta Model Training - Epoch [195/200], Loss: 0.0578
# Beta Model Training - Epoch [196/200], Loss: 0.0551
# Beta Model Training - Epoch [197/200], Loss: 0.0552
# Beta Model Training - Epoch [198/200], Loss: 0.0575
# Beta Model Training - Epoch [199/200], Loss: 0.0592
# Beta Model Training - Epoch [200/200], Loss: 0.0596
#
# === Building dataset/model for Beta 4 ===
# Beta Model Training - Epoch [1/200], Loss: 0.7322
# Beta Model Training - Epoch [2/200], Loss: 0.5623
# Beta Model Training - Epoch [3/200], Loss: 0.4073
# Beta Model Training - Epoch [4/200], Loss: 0.3252
# Beta Model Training - Epoch [5/200], Loss: 0.2869
# Beta Model Training - Epoch [6/200], Loss: 0.2591
# Beta Model Training - Epoch [7/200], Loss: 0.2349
# Beta Model Training - Epoch [8/200], Loss: 0.2089
# Beta Model Training - Epoch [9/200], Loss: 0.1822
# Beta Model Training - Epoch [10/200], Loss: 0.1577
# Beta Model Training - Epoch [11/200], Loss: 0.1376
# Beta Model Training - Epoch [12/200], Loss: 0.1272
# Beta Model Training - Epoch [13/200], Loss: 0.1230
# Beta Model Training - Epoch [14/200], Loss: 0.1168
# Beta Model Training - Epoch [15/200], Loss: 0.1058
# Beta Model Training - Epoch [16/200], Loss: 0.1015
# Beta Model Training - Epoch [17/200], Loss: 0.0950
# Beta Model Training - Epoch [18/200], Loss: 0.0902
# Beta Model Training - Epoch [19/200], Loss: 0.0858
# Beta Model Training - Epoch [20/200], Loss: 0.0835
# Beta Model Training - Epoch [21/200], Loss: 0.0804
# Beta Model Training - Epoch [22/200], Loss: 0.0783
# Beta Model Training - Epoch [23/200], Loss: 0.0758
# Beta Model Training - Epoch [24/200], Loss: 0.0735
# Beta Model Training - Epoch [25/200], Loss: 0.0703
# Beta Model Training - Epoch [26/200], Loss: 0.0721
# Beta Model Training - Epoch [27/200], Loss: 0.0739
# Beta Model Training - Epoch [28/200], Loss: 0.0708
# Beta Model Training - Epoch [29/200], Loss: 0.0695
# Beta Model Training - Epoch [30/200], Loss: 0.0699
# Beta Model Training - Epoch [31/200], Loss: 0.0710
# Beta Model Training - Epoch [32/200], Loss: 0.0623
# Beta Model Training - Epoch [33/200], Loss: 0.0603
# Beta Model Training - Epoch [34/200], Loss: 0.0589
# Beta Model Training - Epoch [35/200], Loss: 0.0574
# Beta Model Training - Epoch [36/200], Loss: 0.0548
# Beta Model Training - Epoch [37/200], Loss: 0.0537
# Beta Model Training - Epoch [38/200], Loss: 0.0533
# Beta Model Training - Epoch [39/200], Loss: 0.0528
# Beta Model Training - Epoch [40/200], Loss: 0.0522
# Beta Model Training - Epoch [41/200], Loss: 0.0517
# Beta Model Training - Epoch [42/200], Loss: 0.0510
# Beta Model Training - Epoch [43/200], Loss: 0.0485
# Beta Model Training - Epoch [44/200], Loss: 0.0476
# Beta Model Training - Epoch [45/200], Loss: 0.0472
# Beta Model Training - Epoch [46/200], Loss: 0.0464
# Beta Model Training - Epoch [47/200], Loss: 0.0466
# Beta Model Training - Epoch [48/200], Loss: 0.0468
# Beta Model Training - Epoch [49/200], Loss: 0.0465
# Beta Model Training - Epoch [50/200], Loss: 0.0464
# Beta Model Training - Epoch [51/200], Loss: 0.0460
# Beta Model Training - Epoch [52/200], Loss: 0.0457
# Beta Model Training - Epoch [53/200], Loss: 0.0440
# Beta Model Training - Epoch [54/200], Loss: 0.0434
# Beta Model Training - Epoch [55/200], Loss: 0.0426
# Beta Model Training - Epoch [56/200], Loss: 0.0419
# Beta Model Training - Epoch [57/200], Loss: 0.0407
# Beta Model Training - Epoch [58/200], Loss: 0.0404
# Beta Model Training - Epoch [59/200], Loss: 0.0400
# Beta Model Training - Epoch [60/200], Loss: 0.0389
# Beta Model Training - Epoch [61/200], Loss: 0.0381
# Beta Model Training - Epoch [62/200], Loss: 0.0382
# Beta Model Training - Epoch [63/200], Loss: 0.0369
# Beta Model Training - Epoch [64/200], Loss: 0.0397
# Beta Model Training - Epoch [65/200], Loss: 0.0385
# Beta Model Training - Epoch [66/200], Loss: 0.0381
# Beta Model Training - Epoch [67/200], Loss: 0.0354
# Beta Model Training - Epoch [68/200], Loss: 0.0349
# Beta Model Training - Epoch [69/200], Loss: 0.0366
# Beta Model Training - Epoch [70/200], Loss: 0.0390
# Beta Model Training - Epoch [71/200], Loss: 0.0404
# Beta Model Training - Epoch [72/200], Loss: 0.0446
# Beta Model Training - Epoch [73/200], Loss: 0.0427
# Beta Model Training - Epoch [74/200], Loss: 0.0405
# Beta Model Training - Epoch [75/200], Loss: 0.0365
# Beta Model Training - Epoch [76/200], Loss: 0.0337
# Beta Model Training - Epoch [77/200], Loss: 0.0321
# Beta Model Training - Epoch [78/200], Loss: 0.0313
# Beta Model Training - Epoch [79/200], Loss: 0.0309
# Beta Model Training - Epoch [80/200], Loss: 0.0302
# Beta Model Training - Epoch [81/200], Loss: 0.0297
# Beta Model Training - Epoch [82/200], Loss: 0.0295
# Beta Model Training - Epoch [83/200], Loss: 0.0295
# Beta Model Training - Epoch [84/200], Loss: 0.0292
# Beta Model Training - Epoch [85/200], Loss: 0.0289
# Beta Model Training - Epoch [86/200], Loss: 0.0288
# Beta Model Training - Epoch [87/200], Loss: 0.0286
# Beta Model Training - Epoch [88/200], Loss: 0.0283
# Beta Model Training - Epoch [89/200], Loss: 0.0274
# Beta Model Training - Epoch [90/200], Loss: 0.0271
# Beta Model Training - Epoch [91/200], Loss: 0.0277
# Beta Model Training - Epoch [92/200], Loss: 0.0272
# Beta Model Training - Epoch [93/200], Loss: 0.0274
# Beta Model Training - Epoch [94/200], Loss: 0.0271
# Beta Model Training - Epoch [95/200], Loss: 0.0301
# Beta Model Training - Epoch [96/200], Loss: 0.0325
# Beta Model Training - Epoch [97/200], Loss: 0.0321
# Beta Model Training - Epoch [98/200], Loss: 0.0301
# Beta Model Training - Epoch [99/200], Loss: 0.0322
# Beta Model Training - Epoch [100/200], Loss: 0.0338
# Beta Model Training - Epoch [101/200], Loss: 0.0362
# Beta Model Training - Epoch [102/200], Loss: 0.0364
# Beta Model Training - Epoch [103/200], Loss: 0.0316
# Beta Model Training - Epoch [104/200], Loss: 0.0319
# Beta Model Training - Epoch [105/200], Loss: 0.0313
# Beta Model Training - Epoch [106/200], Loss: 0.0279
# Beta Model Training - Epoch [107/200], Loss: 0.0273
# Beta Model Training - Epoch [108/200], Loss: 0.0255
# Beta Model Training - Epoch [109/200], Loss: 0.0250
# Beta Model Training - Epoch [110/200], Loss: 0.0253
# Beta Model Training - Epoch [111/200], Loss: 0.0245
# Beta Model Training - Epoch [112/200], Loss: 0.0251
# Beta Model Training - Epoch [113/200], Loss: 0.0247
# Beta Model Training - Epoch [114/200], Loss: 0.0251
# Beta Model Training - Epoch [115/200], Loss: 0.0265
# Beta Model Training - Epoch [116/200], Loss: 0.0286
# Beta Model Training - Epoch [117/200], Loss: 0.0260
# Beta Model Training - Epoch [118/200], Loss: 0.0257
# Beta Model Training - Epoch [119/200], Loss: 0.0244
# Beta Model Training - Epoch [120/200], Loss: 0.0241
# Beta Model Training - Epoch [121/200], Loss: 0.0234
# Beta Model Training - Epoch [122/200], Loss: 0.0229
# Beta Model Training - Epoch [123/200], Loss: 0.0231
# Beta Model Training - Epoch [124/200], Loss: 0.0231
# Beta Model Training - Epoch [125/200], Loss: 0.0225
# Beta Model Training - Epoch [126/200], Loss: 0.0220
# Beta Model Training - Epoch [127/200], Loss: 0.0221
# Beta Model Training - Epoch [128/200], Loss: 0.0218
# Beta Model Training - Epoch [129/200], Loss: 0.0219
# Beta Model Training - Epoch [130/200], Loss: 0.0215
# Beta Model Training - Epoch [131/200], Loss: 0.0217
# Beta Model Training - Epoch [132/200], Loss: 0.0208
# Beta Model Training - Epoch [133/200], Loss: 0.0210
# Beta Model Training - Epoch [134/200], Loss: 0.0207
# Beta Model Training - Epoch [135/200], Loss: 0.0207
# Beta Model Training - Epoch [136/200], Loss: 0.0204
# Beta Model Training - Epoch [137/200], Loss: 0.0202
# Beta Model Training - Epoch [138/200], Loss: 0.0202
# Beta Model Training - Epoch [139/200], Loss: 0.0202
# Beta Model Training - Epoch [140/200], Loss: 0.0204
# Beta Model Training - Epoch [141/200], Loss: 0.0202
# Beta Model Training - Epoch [142/200], Loss: 0.0202
# Beta Model Training - Epoch [143/200], Loss: 0.0202
# Beta Model Training - Epoch [144/200], Loss: 0.0196
# Beta Model Training - Epoch [145/200], Loss: 0.0198
# Beta Model Training - Epoch [146/200], Loss: 0.0197
# Beta Model Training - Epoch [147/200], Loss: 0.0204
# Beta Model Training - Epoch [148/200], Loss: 0.0206
# Beta Model Training - Epoch [149/200], Loss: 0.0207
# Beta Model Training - Epoch [150/200], Loss: 0.0211
# Beta Model Training - Epoch [151/200], Loss: 0.0216
# Beta Model Training - Epoch [152/200], Loss: 0.0223
# Beta Model Training - Epoch [153/200], Loss: 0.0237
# Beta Model Training - Epoch [154/200], Loss: 0.0224
# Beta Model Training - Epoch [155/200], Loss: 0.0220
# Beta Model Training - Epoch [156/200], Loss: 0.0207
# Beta Model Training - Epoch [157/200], Loss: 0.0207
# Beta Model Training - Epoch [158/200], Loss: 0.0205
# Beta Model Training - Epoch [159/200], Loss: 0.0209
# Beta Model Training - Epoch [160/200], Loss: 0.0209
# Beta Model Training - Epoch [161/200], Loss: 0.0214
# Beta Model Training - Epoch [162/200], Loss: 0.0205
# Beta Model Training - Epoch [163/200], Loss: 0.0195
# Beta Model Training - Epoch [164/200], Loss: 0.0189
# Beta Model Training - Epoch [165/200], Loss: 0.0189
# Beta Model Training - Epoch [166/200], Loss: 0.0187
# Beta Model Training - Epoch [167/200], Loss: 0.0186
# Beta Model Training - Epoch [168/200], Loss: 0.0187
# Beta Model Training - Epoch [169/200], Loss: 0.0183
# Beta Model Training - Epoch [170/200], Loss: 0.0181
# Beta Model Training - Epoch [171/200], Loss: 0.0180
# Beta Model Training - Epoch [172/200], Loss: 0.0180
# Beta Model Training - Epoch [173/200], Loss: 0.0178
# Beta Model Training - Epoch [174/200], Loss: 0.0178
# Beta Model Training - Epoch [175/200], Loss: 0.0184
# Beta Model Training - Epoch [176/200], Loss: 0.0188
# Beta Model Training - Epoch [177/200], Loss: 0.0184
# Beta Model Training - Epoch [178/200], Loss: 0.0184
# Beta Model Training - Epoch [179/200], Loss: 0.0188
# Beta Model Training - Epoch [180/200], Loss: 0.0185
# Beta Model Training - Epoch [181/200], Loss: 0.0188
# Beta Model Training - Epoch [182/200], Loss: 0.0180
# Beta Model Training - Epoch [183/200], Loss: 0.0182
# Beta Model Training - Epoch [184/200], Loss: 0.0186
# Beta Model Training - Epoch [185/200], Loss: 0.0186
# Beta Model Training - Epoch [186/200], Loss: 0.0195
# Beta Model Training - Epoch [187/200], Loss: 0.0247
# Beta Model Training - Epoch [188/200], Loss: 0.0237
# Beta Model Training - Epoch [189/200], Loss: 0.0207
# Beta Model Training - Epoch [190/200], Loss: 0.0192
# Beta Model Training - Epoch [191/200], Loss: 0.0194
# Beta Model Training - Epoch [192/200], Loss: 0.0199
# Beta Model Training - Epoch [193/200], Loss: 0.0204
# Beta Model Training - Epoch [194/200], Loss: 0.0208
# Beta Model Training - Epoch [195/200], Loss: 0.0223
# Beta Model Training - Epoch [196/200], Loss: 0.0231
# Beta Model Training - Epoch [197/200], Loss: 0.0222
# Beta Model Training - Epoch [198/200], Loss: 0.0216
# Beta Model Training - Epoch [199/200], Loss: 0.0217
# Beta Model Training - Epoch [200/200], Loss: 0.0209

# %%
# save importances results
save_dir = os.path.join(analysis_type, 'Masking Results')
os.makedirs(save_dir, exist_ok=True)

save_subdir_chan = os.path.join(save_dir, 'Channel Masking')
os.makedirs(save_subdir_chan, exist_ok=True)

np.save(os.path.join(save_subdir_chan, 'imp_zero.npy'), all_imp_zero)
np.save(os.path.join(save_subdir_chan, 'imp_drop.npy'), all_imp_drop)

# %%
# Visualize importances of channel masking zero method
import matplotlib.pyplot as plt

values = all_imp_zero.mean(axis=1)  # mean across subjects
plt.figure(figsize=(16,13))
plt.imshow(values, aspect='auto', origin='lower', cmap='Reds')
plt.colorbar(label='Mean importance')
plt.xticks(ticks=np.arange(nChan), labels=np.arange(1, nChan+1))
plt.xlabel('Channel')
plt.ylabel('Beta')
plt.title(analysis_type + '_Channel Importance_zero')
plt.tight_layout()
plt.savefig(os.path.join(save_subdir_chan, '_Channel Importance_zero.png'))
#plt.show()
plt.close()

for iBeta in range(nBeta):
    values = all_imp_zero[iBeta]
    plt.figure(figsize=(16,13))
    plt.imshow(values, aspect='auto', origin='lower', cmap='Reds')
    plt.colorbar(label='Importance')
    plt.xticks(ticks=np.arange(nChan), labels=np.arange(1, nChan+1))
    plt.xlabel('Channel')
    plt.ylabel('Subject')
    plt.title(f'Beta {iBeta}_{analysis_type}_Channel Importance_zero')
    plt.tight_layout()
    plt.savefig(os.path.join(save_subdir_chan, f'Beta_{iBeta}_Channel_Importance_zero.png'))
    #plt.show()
    plt.close()

# %%
# Visualize importances of channel masking dropping method
import matplotlib.pyplot as plt

values = all_imp_drop.mean(axis=1)  # mean across subjects
plt.figure(figsize=(16,13))
plt.imshow(values, aspect='auto', origin='lower', cmap='Reds')
plt.colorbar(label='Mean importance')
plt.xticks(ticks=np.arange(nChan), labels=np.arange(1, nChan+1))
plt.xlabel('Channel')
plt.ylabel('Beta')
plt.title(analysis_type+'_Channel Importance_drop')
plt.tight_layout()
plt.savefig(os.path.join(save_subdir_chan, '_Channel Importance_drop.png'))
#plt.show()
plt.close()

for iBeta in range(nBeta):
    values = all_imp_drop[iBeta]
    plt.figure(figsize=(16,13))
    plt.imshow(values, aspect='auto', origin='lower', cmap='Reds')
    plt.colorbar(label='Importance')
    plt.xticks(ticks=np.arange(nChan), labels=np.arange(1, nChan+1))
    plt.xlabel('Channel')
    plt.ylabel('Subject')
    plt.title(f'Beta {iBeta}_{analysis_type}_Channel Importance_drop')
    plt.tight_layout()
    plt.savefig(os.path.join(save_subdir_chan, f'Beta_{iBeta}_Channel_Importance_drop.png'))
    #plt.show()
    plt.close()
