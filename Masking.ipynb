# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset, ConcatDataset
from torch_geometric.loader import DataLoader as GeometricDataLoader
from torch_geometric.data import Data
from torch_geometric.utils import dense_to_sparse, subgraph, k_hop_subgraph
import torch_geometric.nn as pyg_nn
from scipy.io import loadmat, savemat
import os
import matplotlib.pyplot as plt

# %%
# Load saved beta data from mat file
analysis_type = 'N400'
curr_dir = os.getcwd()
datain_dir = os.path.join(os.getcwd(), 'datain')
datain_mat = loadmat(os.path.join(datain_dir, analysis_type + '_original_betas.mat'))
binatry_matrix_mat = loadmat(os.path.join(datain_dir, 'adjacency_matrix.mat'))
datain = datain_mat['data']
binatry_matrix = binatry_matrix_mat['adjacency_matrix']

datain = np.array(datain)          # shape: [nBeta, nTime, nChan, nSubject] (adjust as needed)
binatry_matrix = np.array(binatry_matrix)

# Parse shapes
nBeta     = datain.shape[0]
nTime     = datain.shape[1]
nChan     = datain.shape[2]
nSubject  = datain.shape[3]

# %%
# ===========================================
# 2) Set device & convert adjacency
# ===========================================
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
edge_index, _ = dense_to_sparse(torch.tensor(binatry_matrix, dtype=torch.float32))
print(device)

# ===========================================
# 3) Dataset builder
# ===========================================
def build_concat_dataset_for_beta(datain, beta_idx):
    """
    Build a ConcatDataset across all subjects for one beta index.
    `datain` is [nBeta, nTime, nChan, nSubject].
    Returns: ConcatDataset of length nSubject.
    """
    subject_datasets = []
    for s in range(nSubject):
        # Extract slice for one subject and one beta
        # shape: [nTime, nChan]
        single_beta_data = datain[beta_idx, :, :, s]

        # If each node is a channel and its feature dimension is time,
        # we might want single_beta_data to be [nChan, nTime].
        # If so, transpose here:
        single_beta_data = single_beta_data.T  # shape: [nChan, nTime]

        # For an autoencoder, features=labels
        x_tensor = torch.tensor(single_beta_data, dtype=torch.float32)
        x_tensor = x_tensor.unsqueeze(0)

        subject_datasets.append(TensorDataset(x_tensor, x_tensor))

    return ConcatDataset(subject_datasets)
# Out:
# cuda

# %%
# ===========================================
# 4) PyG Graph Dataset
# ===========================================
class EEGGraphDataset(torch.utils.data.Dataset):
    """
    Wraps a standard dataset so that each item is a PyG Data object:
      x -> node features (channels)
      edge_index -> adjacency
    """
    def __init__(self, eeg_data, edge_index):
        self.eeg_data = eeg_data
        self.edge_index = edge_index

    def __len__(self):
        return len(self.eeg_data)

    def __getitem__(self, idx):
        # item: (x, x) because it's autoencoder
        sample = self.eeg_data[idx]
        x = sample[0]  # shape: [nChan, nTime] (if you used transpose above)
        # Convert x -> float32, build PyG Data
        graph_data = Data(x=torch.tensor(x, dtype=torch.float32),
                          edge_index=self.edge_index)
        return graph_data

# %%
# ===========================================
# 5) Define GraphAutoencoder
# ===========================================
class GraphAutoencoder(nn.Module):
    def __init__(self, num_features, embedding_dim=64):
        """
        num_features = dimension of each node's feature vector.
                       If each channel is a node, and you pass
                       [nChan, nTime], then num_features = nTime.
        """
        super(GraphAutoencoder, self).__init__()
        # Example with two ARMAConv layers
        self.encoder_gcn1 = pyg_nn.ARMAConv(num_features, 128, 
                                            num_stacks=2, 
                                            num_layers=3,
                                            shared_weights=True)
        self.encoder_gcn2 = pyg_nn.ARMAConv(128, embedding_dim, 
                                            num_stacks=2, 
                                            num_layers=3,
                                            shared_weights=True)
        self.decoder_fc1 = nn.Linear(embedding_dim, 128)
        self.decoder_fc2 = nn.Linear(128, num_features)

    def forward(self, x, edge_index):
        x = torch.relu(self.encoder_gcn1(x, edge_index))
        latent = torch.relu(self.encoder_gcn2(x, edge_index))
        x = torch.relu(self.decoder_fc1(latent))
        reconstructed = self.decoder_fc2(x)
        return reconstructed

# %%
# ===========================================
# 6) Training and evaluation
# ===========================================
def train_model_all(model, train_loader, device, num_epochs):
    model.to(device)
    optimizer = optim.Adam(model.parameters(), lr=1e-3)
    criterion = nn.SmoothL1Loss()

    for epoch in range(num_epochs):
        model.train()
        epoch_loss = 0.0
        for batch_data in train_loader:
            batch_data = batch_data.to(device)
            optimizer.zero_grad()

            # Forward
            reconstructed = model(batch_data.x, batch_data.edge_index)
            loss = criterion(reconstructed, batch_data.x)

            # Backprop
            loss.backward()
            optimizer.step()
            epoch_loss += loss.item()

        epoch_loss /= len(train_loader)
        print(f"Beta Model Training - Epoch [{epoch+1}/{num_epochs}], Loss: {epoch_loss:.4f}")
    return model

def evaluation_model(model, data_sample, edge_index, device):
    """
    data_sample: shape [nChan, nTime], or [nTime, nChan],
                 whichever you used in training.
    Returns: (original_np, reconstructed_np, error_np)
    """
    model.eval()
    with torch.no_grad():
        x = torch.tensor(data_sample, dtype=torch.float32, device=device)
        eidx = edge_index.to(device)
        reconstructed = model(x, eidx)
    orig = x.cpu().numpy()
    recon = reconstructed.cpu().numpy()
    error = orig - recon
    return orig, recon, error

# %%
# Channel Masking

# Define channel masking function with 'zero' and 'mean' methods
def channel_masking(x_n, ch_idx, mode='mean'):
    x_masked = x_n.copy()
    if mode == 'zero':
        x_masked[ch_idx, :] = 0.0
    # Mean of all other channels
    elif mode == 'mean':
        channel_mean = x_n.mean(axis=0)
        x_masked[ch_idx, :] = channel_mean
    return x_masked

# Apply channel masking and compute importance
def apply_channel_masking(model, sample_n, edge_index, device, mode='mean'):
    model.eval()
    with torch.no_grad():
        x = torch.tensor(sample_n, dtype=torch.float32, device=device)
        recon = model(x, edge_index.to(device))
        base_lose = nn.SmoothL1Loss()(recon, x).item()
        
        nChan = sample_n.shape[0]
        imp = np.zeros(nChan)
        
        # Iterate over channels to compute importance
        # The higher the loss increase, the more important the channel
        for c in range(nChan):
            x_masked = channel_masking(sample_n, c, mode=mode)
            x_masked = torch.tensor(x_masked, dtype=torch.float32, device=device)
            recon_masked = model(x_masked, edge_index.to(device))
            masked_loss = nn.SmoothL1Loss()(recon_masked, x_masked).item()
            imp[c] = abs(masked_loss - base_lose)
            
    return imp

# %%
# Channel dropping

# Define channel dropping method
def channel_dropping(model, sample_n, edge_index, device):
    model.eval()
    with torch.no_grad():
        x = torch.tensor(sample_n, dtype=torch.float32, device=device)
        recon = model(x, edge_index.to(device))
        base_loss = nn.SmoothL1Loss()(recon, x).item()

        nChan = sample_n.shape[0]
        imp = np.zeros(nChan)
        all_channels = torch.arange(nChan, device=device)
        e_idx = edge_index.to(device)
        
        for c in range(nChan):
            mask = torch.ones(nChan, dtype=torch.bool, device=device)
            mask[c] = False
            masked_channels = all_channels[mask]
            # Create subgraph with masked channels, dropping the channel c from the graph
            masked_edge_index = subgraph(masked_channels, e_idx, relabel_nodes=True)[0]
            # Drop the channel c from the data x
            masked_x = x[masked_channels, :]
            recon_masked = model(masked_x, masked_edge_index)
            masked_loss = nn.SmoothL1Loss()(recon_masked, masked_x).item()
            imp[c] = abs(masked_loss - base_loss)
            
    return imp

# %%
# Channel region hard masking

# Compute k-hop neighborhood channels for each channel
def compute_neighborhood_channels(edge_index, k=1):
    neighborhood_channels = []
    for c in range(edge_index.max().item() + 1):
        channels, _, _, _ = k_hop_subgraph(c, k, edge_index)
        neighborhood_channels.append(channels.cpu().numpy())
    return neighborhood_channels

# Define region hard masking function with 'zero' and 'mean' methods
def region_hard_masking(x_n, neig_list, mode='local_mean'):
    x_masked = x_n.copy()

    # Get the rest of the channels except the neighborhood list
    nChan = x_n.shape[0]
    mask_neig = np.zeros(nChan, dtype=bool)
    mask_neig[neig_list] = True
    mask_rest = ~mask_neig
    
    if mode == 'zero':
        x_masked[mask_neig, :] = 0.0
    # The mean of the rest of the channels
    elif mode == 'global_mean':
        if mask_rest.any():
            rest_mean = x_n[mask_rest, :].mean(axis=0)
        # If no rest channels, use overall mean
        else:
            rest_mean = x_n.mean(axis=0)
        x_masked[mask_neig, :] = rest_mean
    elif mode == 'local_mean':
        if mask_rest.any():
            local_mean = x_n[mask_neig, :].mean(axis=0)
        else:
            local_mean = x_n.mean(axis=0)
        x_masked[mask_neig, :] = local_mean
    return x_masked

# Apply region hard masking and compute importance
def apply_region_hard_masking(model, sample_n, edge_index, device, mode='mean', k=1):
    model.eval()
    with torch.no_grad():
        neighborhood_channels = compute_neighborhood_channels(edge_index, k)
        x = torch.tensor(sample_n, dtype=torch.float32, device=device)
        recon = model(x, edge_index.to(device))
        base_loss = nn.SmoothL1Loss()(recon, x).item()

        nChan = sample_n.shape[0]
        imp = np.zeros(nChan)
        
        for c in range(nChan):
            neig_list = neighborhood_channels[c]
            x_masked = region_hard_masking(sample_n, neig_list, mode=mode)
            x_masked = torch.tensor(x_masked, dtype=torch.float32, device=device)
            recon_masked = model(x_masked, edge_index.to(device))
            masked_loss = nn.SmoothL1Loss()(recon_masked, x_masked).item()
            imp[c] = abs(masked_loss - base_loss)
    return imp

# %%
neighborhood_channels = compute_neighborhood_channels(edge_index, k=1)
for i in range(len(neighborhood_channels)):
    nbrs = [int(x) + 1 for x in neighborhood_channels[i]]
    print(f"Channel {i+1}: Neighbors {nbrs}")
# Out:
# Channel 1: Neighbors [1, 2, 3, 16, 17]
# Channel 2: Neighbors [1, 2, 3, 4, 17, 21]
# Channel 3: Neighbors [1, 2, 3, 4, 6]
# Channel 4: Neighbors [2, 3, 4, 5, 6, 17, 21, 22]
# Channel 5: Neighbors [4, 5, 6, 7, 8, 15, 21, 22]
# Channel 6: Neighbors [3, 4, 5, 6, 7, 8, 9]
# Channel 7: Neighbors [5, 6, 7, 8, 10, 11, 14, 15]
# Channel 8: Neighbors [5, 6, 7, 8, 9, 10, 11]
# Channel 9: Neighbors [6, 8, 9, 10, 12]
# Channel 10: Neighbors [7, 8, 9, 10, 11, 12]
# Channel 11: Neighbors [7, 8, 10, 11, 12, 13, 14, 15, 29]
# Channel 12: Neighbors [9, 10, 11, 12, 13]
# Channel 13: Neighbors [11, 12, 13, 14, 29, 30]
# Channel 14: Neighbors [7, 11, 13, 14, 15, 25, 29]
# Channel 15: Neighbors [5, 7, 11, 14, 15, 22, 23, 25, 29]
# Channel 16: Neighbors [1, 16, 17, 18, 19]
# Channel 17: Neighbors [1, 2, 4, 16, 17, 18, 20, 21]
# Channel 18: Neighbors [16, 17, 18, 19, 20, 21]
# Channel 19: Neighbors [16, 18, 19, 20, 24]
# Channel 20: Neighbors [17, 18, 19, 20, 21, 22, 23, 24]
# Channel 21: Neighbors [2, 4, 5, 17, 18, 20, 21, 22, 23]
# Channel 22: Neighbors [4, 5, 15, 20, 21, 22, 23]
# Channel 23: Neighbors [15, 20, 21, 22, 23, 24, 25, 26]
# Channel 24: Neighbors [19, 20, 23, 24, 25, 26, 27]
# Channel 25: Neighbors [14, 15, 23, 24, 25, 26, 28, 29]
# Channel 26: Neighbors [23, 24, 25, 26, 27, 28, 29]
# Channel 27: Neighbors [24, 26, 27, 28, 30]
# Channel 28: Neighbors [25, 26, 27, 28, 29, 30]
# Channel 29: Neighbors [11, 13, 14, 15, 25, 26, 28, 29, 30]
# Channel 30: Neighbors [13, 27, 28, 29, 30]

# %%
num_features = nTime   # if each channel is a node, and feature vector = [nTime]
num_epochs   = 200     # number of training - set as needed
batch_size   = 4;      # dataset/batch to update hyperparameters

models = []

imp_chan_zero_list = []
imp_chan_drop_list = []
imp_chan_mean_list = []
imp_region_localmean_list = []
imp_region_globalmean_list = []

for iBeta in range(nBeta):
    print(f"\n=== Building dataset/model for Beta {iBeta} ===")
    # Build dataset & loader
    full_dataset_i  = build_concat_dataset_for_beta(datain, iBeta)
    graph_dataset_i = EEGGraphDataset(full_dataset_i, edge_index)
    full_loader_i   = GeometricDataLoader(graph_dataset_i, batch_size=batch_size, shuffle=True)

    # Init model & train
    model_i = GraphAutoencoder(num_features=num_features, embedding_dim=32)
    model_i = train_model_all(model_i, full_loader_i, device, num_epochs=num_epochs)
    models.append(model_i)

    imp_chan_zero_per_subject = []
    imp_chan_drop_per_subject = []
    imp_chan_mean_per_subject = []
    imp_region_localmean_per_subject = []
    imp_region_globalmean_per_subject = []
    for s in range(len(full_dataset_i)):
        x_s = full_dataset_i[s][0].numpy()  # [nChan, nTime]
        imp_chan_zero = apply_channel_masking(model_i, x_s, edge_index, device, mode='zero')
        imp_chan_mean = apply_channel_masking(model_i, x_s, edge_index, device, mode='mean')
        imp_chan_drop = channel_dropping(model_i, x_s, edge_index, device)
        imp_region_localmean = apply_region_hard_masking(model_i, x_s, edge_index, device, mode='local_mean', k=1)
        imp_region_globalmean = apply_region_hard_masking(model_i, x_s, edge_index, device, mode='global_mean', k=1)
        imp_chan_zero_per_subject.append(imp_chan_zero)
        imp_chan_drop_per_subject.append(imp_chan_drop)
        imp_chan_mean_per_subject.append(imp_chan_mean)
        imp_region_localmean_per_subject.append(imp_region_localmean)
        imp_region_globalmean_per_subject.append(imp_region_globalmean)

    imp_chan_zero_list.append(np.array(imp_chan_zero_per_subject))
    imp_chan_drop_list.append(np.array(imp_chan_drop_per_subject))
    imp_chan_mean_list.append(np.array(imp_chan_mean_per_subject))
    imp_region_localmean_list.append(np.array(imp_region_localmean_per_subject))
    imp_region_globalmean_list.append(np.array(imp_region_globalmean_per_subject))

all_imp_chan_zero = np.array(imp_chan_zero_list)
all_imp_chan_drop = np.array(imp_chan_drop_list)
all_imp_chan_mean = np.array(imp_chan_mean_list)
all_imp_region_localmean = np.array(imp_region_localmean_list)
all_imp_region_globalmean = np.array(imp_region_globalmean_list)
# Out:
# === Building dataset/model for Beta 0 ===
# Beta Model Training - Epoch [1/200], Loss: 0.7542
# Beta Model Training - Epoch [2/200], Loss: 0.7090
# C:\Users\86136\AppData\Local\Temp\ipykernel_34204\1382389434.py:22: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   graph_data = Data(x=torch.tensor(x, dtype=torch.float32),
# Beta Model Training - Epoch [3/200], Loss: 0.6153
# Beta Model Training - Epoch [4/200], Loss: 0.5571
# Beta Model Training - Epoch [5/200], Loss: 0.5199
# Beta Model Training - Epoch [6/200], Loss: 0.4889
# Beta Model Training - Epoch [7/200], Loss: 0.4607
# Beta Model Training - Epoch [8/200], Loss: 0.4332
# Beta Model Training - Epoch [9/200], Loss: 0.4073
# Beta Model Training - Epoch [10/200], Loss: 0.3866
# Beta Model Training - Epoch [11/200], Loss: 0.3654
# Beta Model Training - Epoch [12/200], Loss: 0.3496
# Beta Model Training - Epoch [13/200], Loss: 0.3403
# Beta Model Training - Epoch [14/200], Loss: 0.3262
# Beta Model Training - Epoch [15/200], Loss: 0.3170
# Beta Model Training - Epoch [16/200], Loss: 0.3079
# Beta Model Training - Epoch [17/200], Loss: 0.3009
# Beta Model Training - Epoch [18/200], Loss: 0.2929
# Beta Model Training - Epoch [19/200], Loss: 0.2870
# Beta Model Training - Epoch [20/200], Loss: 0.2822
# Beta Model Training - Epoch [21/200], Loss: 0.2759
# Beta Model Training - Epoch [22/200], Loss: 0.2734
# Beta Model Training - Epoch [23/200], Loss: 0.2660
# Beta Model Training - Epoch [24/200], Loss: 0.2589
# Beta Model Training - Epoch [25/200], Loss: 0.2540
# Beta Model Training - Epoch [26/200], Loss: 0.2501
# Beta Model Training - Epoch [27/200], Loss: 0.2466
# Beta Model Training - Epoch [28/200], Loss: 0.2432
# Beta Model Training - Epoch [29/200], Loss: 0.2408
# Beta Model Training - Epoch [30/200], Loss: 0.2384
# Beta Model Training - Epoch [31/200], Loss: 0.2347
# Beta Model Training - Epoch [32/200], Loss: 0.2293
# Beta Model Training - Epoch [33/200], Loss: 0.2264
# Beta Model Training - Epoch [34/200], Loss: 0.2234
# Beta Model Training - Epoch [35/200], Loss: 0.2227
# Beta Model Training - Epoch [36/200], Loss: 0.2207
# Beta Model Training - Epoch [37/200], Loss: 0.2207
# Beta Model Training - Epoch [38/200], Loss: 0.2172
# Beta Model Training - Epoch [39/200], Loss: 0.2194
# Beta Model Training - Epoch [40/200], Loss: 0.2165
# Beta Model Training - Epoch [41/200], Loss: 0.2187
# Beta Model Training - Epoch [42/200], Loss: 0.2131
# Beta Model Training - Epoch [43/200], Loss: 0.2079
# Beta Model Training - Epoch [44/200], Loss: 0.2066
# Beta Model Training - Epoch [45/200], Loss: 0.2026
# Beta Model Training - Epoch [46/200], Loss: 0.2013
# Beta Model Training - Epoch [47/200], Loss: 0.2000
# Beta Model Training - Epoch [48/200], Loss: 0.1988
# Beta Model Training - Epoch [49/200], Loss: 0.1986
# Beta Model Training - Epoch [50/200], Loss: 0.2005
# Beta Model Training - Epoch [51/200], Loss: 0.2017
# Beta Model Training - Epoch [52/200], Loss: 0.2031
# Beta Model Training - Epoch [53/200], Loss: 0.1953
# Beta Model Training - Epoch [54/200], Loss: 0.1981
# Beta Model Training - Epoch [55/200], Loss: 0.2000
# Beta Model Training - Epoch [56/200], Loss: 0.1962
# Beta Model Training - Epoch [57/200], Loss: 0.1935
# Beta Model Training - Epoch [58/200], Loss: 0.1906
# Beta Model Training - Epoch [59/200], Loss: 0.1889
# Beta Model Training - Epoch [60/200], Loss: 0.1877
# Beta Model Training - Epoch [61/200], Loss: 0.1860
# Beta Model Training - Epoch [62/200], Loss: 0.1851
# Beta Model Training - Epoch [63/200], Loss: 0.1843
# Beta Model Training - Epoch [64/200], Loss: 0.1851
# Beta Model Training - Epoch [65/200], Loss: 0.1924
# Beta Model Training - Epoch [66/200], Loss: 0.1896
# Beta Model Training - Epoch [67/200], Loss: 0.1873
# Beta Model Training - Epoch [68/200], Loss: 0.1869
# Beta Model Training - Epoch [69/200], Loss: 0.1895
# Beta Model Training - Epoch [70/200], Loss: 0.1846
# Beta Model Training - Epoch [71/200], Loss: 0.1835
# Beta Model Training - Epoch [72/200], Loss: 0.1808
# Beta Model Training - Epoch [73/200], Loss: 0.1797
# Beta Model Training - Epoch [74/200], Loss: 0.1805
# Beta Model Training - Epoch [75/200], Loss: 0.1777
# Beta Model Training - Epoch [76/200], Loss: 0.1767
# Beta Model Training - Epoch [77/200], Loss: 0.1761
# Beta Model Training - Epoch [78/200], Loss: 0.1758
# Beta Model Training - Epoch [79/200], Loss: 0.1756
# Beta Model Training - Epoch [80/200], Loss: 0.1758
# Beta Model Training - Epoch [81/200], Loss: 0.1758
# Beta Model Training - Epoch [82/200], Loss: 0.1748
# Beta Model Training - Epoch [83/200], Loss: 0.1734
# Beta Model Training - Epoch [84/200], Loss: 0.1735
# Beta Model Training - Epoch [85/200], Loss: 0.1748
# Beta Model Training - Epoch [86/200], Loss: 0.1731
# Beta Model Training - Epoch [87/200], Loss: 0.1722
# Beta Model Training - Epoch [88/200], Loss: 0.1711
# Beta Model Training - Epoch [89/200], Loss: 0.1703
# Beta Model Training - Epoch [90/200], Loss: 0.1699
# Beta Model Training - Epoch [91/200], Loss: 0.1694
# Beta Model Training - Epoch [92/200], Loss: 0.1700
# Beta Model Training - Epoch [93/200], Loss: 0.1699
# Beta Model Training - Epoch [94/200], Loss: 0.1695
# Beta Model Training - Epoch [95/200], Loss: 0.1690
# Beta Model Training - Epoch [96/200], Loss: 0.1700
# Beta Model Training - Epoch [97/200], Loss: 0.1692
# Beta Model Training - Epoch [98/200], Loss: 0.1682
# Beta Model Training - Epoch [99/200], Loss: 0.1680
# Beta Model Training - Epoch [100/200], Loss: 0.1677
# Beta Model Training - Epoch [101/200], Loss: 0.1675
# Beta Model Training - Epoch [102/200], Loss: 0.1652
# Beta Model Training - Epoch [103/200], Loss: 0.1663
# Beta Model Training - Epoch [104/200], Loss: 0.1672
# Beta Model Training - Epoch [105/200], Loss: 0.1666
# Beta Model Training - Epoch [106/200], Loss: 0.1657
# Beta Model Training - Epoch [107/200], Loss: 0.1666
# Beta Model Training - Epoch [108/200], Loss: 0.1656
# Beta Model Training - Epoch [109/200], Loss: 0.1667
# Beta Model Training - Epoch [110/200], Loss: 0.1681
# Beta Model Training - Epoch [111/200], Loss: 0.1728
# Beta Model Training - Epoch [112/200], Loss: 0.1687
# Beta Model Training - Epoch [113/200], Loss: 0.1671
# Beta Model Training - Epoch [114/200], Loss: 0.1669
# Beta Model Training - Epoch [115/200], Loss: 0.1647
# Beta Model Training - Epoch [116/200], Loss: 0.1639
# Beta Model Training - Epoch [117/200], Loss: 0.1650
# Beta Model Training - Epoch [118/200], Loss: 0.1637
# Beta Model Training - Epoch [119/200], Loss: 0.1638
# Beta Model Training - Epoch [120/200], Loss: 0.1646
# Beta Model Training - Epoch [121/200], Loss: 0.1636
# Beta Model Training - Epoch [122/200], Loss: 0.1646
# Beta Model Training - Epoch [123/200], Loss: 0.1635
# Beta Model Training - Epoch [124/200], Loss: 0.1621
# Beta Model Training - Epoch [125/200], Loss: 0.1624
# Beta Model Training - Epoch [126/200], Loss: 0.1612
# Beta Model Training - Epoch [127/200], Loss: 0.1624
# Beta Model Training - Epoch [128/200], Loss: 0.1622
# Beta Model Training - Epoch [129/200], Loss: 0.1613
# Beta Model Training - Epoch [130/200], Loss: 0.1615
# Beta Model Training - Epoch [131/200], Loss: 0.1626
# Beta Model Training - Epoch [132/200], Loss: 0.1660
# Beta Model Training - Epoch [133/200], Loss: 0.1649
# Beta Model Training - Epoch [134/200], Loss: 0.1672
# Beta Model Training - Epoch [135/200], Loss: 0.1701
# Beta Model Training - Epoch [136/200], Loss: 0.1670
# Beta Model Training - Epoch [137/200], Loss: 0.1659
# Beta Model Training - Epoch [138/200], Loss: 0.1635
# Beta Model Training - Epoch [139/200], Loss: 0.1622
# Beta Model Training - Epoch [140/200], Loss: 0.1619
# Beta Model Training - Epoch [141/200], Loss: 0.1612
# Beta Model Training - Epoch [142/200], Loss: 0.1617
# Beta Model Training - Epoch [143/200], Loss: 0.1604
# Beta Model Training - Epoch [144/200], Loss: 0.1601
# Beta Model Training - Epoch [145/200], Loss: 0.1599
# Beta Model Training - Epoch [146/200], Loss: 0.1599
# Beta Model Training - Epoch [147/200], Loss: 0.1599
# Beta Model Training - Epoch [148/200], Loss: 0.1599
# Beta Model Training - Epoch [149/200], Loss: 0.1592
# Beta Model Training - Epoch [150/200], Loss: 0.1585
# Beta Model Training - Epoch [151/200], Loss: 0.1590
# Beta Model Training - Epoch [152/200], Loss: 0.1584
# Beta Model Training - Epoch [153/200], Loss: 0.1587
# Beta Model Training - Epoch [154/200], Loss: 0.1591
# Beta Model Training - Epoch [155/200], Loss: 0.1590
# Beta Model Training - Epoch [156/200], Loss: 0.1590
# Beta Model Training - Epoch [157/200], Loss: 0.1581
# Beta Model Training - Epoch [158/200], Loss: 0.1576
# Beta Model Training - Epoch [159/200], Loss: 0.1591
# Beta Model Training - Epoch [160/200], Loss: 0.1572
# Beta Model Training - Epoch [161/200], Loss: 0.1567
# Beta Model Training - Epoch [162/200], Loss: 0.1574
# Beta Model Training - Epoch [163/200], Loss: 0.1566
# Beta Model Training - Epoch [164/200], Loss: 0.1562
# Beta Model Training - Epoch [165/200], Loss: 0.1571
# Beta Model Training - Epoch [166/200], Loss: 0.1580
# Beta Model Training - Epoch [167/200], Loss: 0.1579
# Beta Model Training - Epoch [168/200], Loss: 0.1563
# Beta Model Training - Epoch [169/200], Loss: 0.1570
# Beta Model Training - Epoch [170/200], Loss: 0.1588
# Beta Model Training - Epoch [171/200], Loss: 0.1565
# Beta Model Training - Epoch [172/200], Loss: 0.1561
# Beta Model Training - Epoch [173/200], Loss: 0.1567
# Beta Model Training - Epoch [174/200], Loss: 0.1560
# Beta Model Training - Epoch [175/200], Loss: 0.1574
# Beta Model Training - Epoch [176/200], Loss: 0.1563
# Beta Model Training - Epoch [177/200], Loss: 0.1569
# Beta Model Training - Epoch [178/200], Loss: 0.1581
# Beta Model Training - Epoch [179/200], Loss: 0.1601
# Beta Model Training - Epoch [180/200], Loss: 0.1631
# Beta Model Training - Epoch [181/200], Loss: 0.1601
# Beta Model Training - Epoch [182/200], Loss: 0.1582
# Beta Model Training - Epoch [183/200], Loss: 0.1578
# Beta Model Training - Epoch [184/200], Loss: 0.1562
# Beta Model Training - Epoch [185/200], Loss: 0.1560
# Beta Model Training - Epoch [186/200], Loss: 0.1543
# Beta Model Training - Epoch [187/200], Loss: 0.1550
# Beta Model Training - Epoch [188/200], Loss: 0.1554
# Beta Model Training - Epoch [189/200], Loss: 0.1544
# Beta Model Training - Epoch [190/200], Loss: 0.1532
# Beta Model Training - Epoch [191/200], Loss: 0.1536
# Beta Model Training - Epoch [192/200], Loss: 0.1539
# Beta Model Training - Epoch [193/200], Loss: 0.1545
# Beta Model Training - Epoch [194/200], Loss: 0.1560
# Beta Model Training - Epoch [195/200], Loss: 0.1567
# Beta Model Training - Epoch [196/200], Loss: 0.1575
# Beta Model Training - Epoch [197/200], Loss: 0.1563
# Beta Model Training - Epoch [198/200], Loss: 0.1556
# Beta Model Training - Epoch [199/200], Loss: 0.1548
# Beta Model Training - Epoch [200/200], Loss: 0.1541
#
# === Building dataset/model for Beta 1 ===
# Beta Model Training - Epoch [1/200], Loss: 0.8022
# Beta Model Training - Epoch [2/200], Loss: 0.7281
# Beta Model Training - Epoch [3/200], Loss: 0.6549
# Beta Model Training - Epoch [4/200], Loss: 0.6037
# Beta Model Training - Epoch [5/200], Loss: 0.5514
# Beta Model Training - Epoch [6/200], Loss: 0.5095
# Beta Model Training - Epoch [7/200], Loss: 0.4803
# Beta Model Training - Epoch [8/200], Loss: 0.4569
# Beta Model Training - Epoch [9/200], Loss: 0.4367
# Beta Model Training - Epoch [10/200], Loss: 0.4188
# Beta Model Training - Epoch [11/200], Loss: 0.4010
# Beta Model Training - Epoch [12/200], Loss: 0.3859
# Beta Model Training - Epoch [13/200], Loss: 0.3722
# Beta Model Training - Epoch [14/200], Loss: 0.3635
# Beta Model Training - Epoch [15/200], Loss: 0.3483
# Beta Model Training - Epoch [16/200], Loss: 0.3335
# Beta Model Training - Epoch [17/200], Loss: 0.3202
# Beta Model Training - Epoch [18/200], Loss: 0.3123
# Beta Model Training - Epoch [19/200], Loss: 0.3026
# Beta Model Training - Epoch [20/200], Loss: 0.2960
# Beta Model Training - Epoch [21/200], Loss: 0.2892
# Beta Model Training - Epoch [22/200], Loss: 0.2965
# Beta Model Training - Epoch [23/200], Loss: 0.2852
# Beta Model Training - Epoch [24/200], Loss: 0.2764
# Beta Model Training - Epoch [25/200], Loss: 0.2775
# Beta Model Training - Epoch [26/200], Loss: 0.2640
# Beta Model Training - Epoch [27/200], Loss: 0.2593
# Beta Model Training - Epoch [28/200], Loss: 0.2516
# Beta Model Training - Epoch [29/200], Loss: 0.2497
# Beta Model Training - Epoch [30/200], Loss: 0.2451
# Beta Model Training - Epoch [31/200], Loss: 0.2424
# Beta Model Training - Epoch [32/200], Loss: 0.2390
# Beta Model Training - Epoch [33/200], Loss: 0.2363
# Beta Model Training - Epoch [34/200], Loss: 0.2316
# Beta Model Training - Epoch [35/200], Loss: 0.2289
# Beta Model Training - Epoch [36/200], Loss: 0.2289
# Beta Model Training - Epoch [37/200], Loss: 0.2275
# Beta Model Training - Epoch [38/200], Loss: 0.2258
# Beta Model Training - Epoch [39/200], Loss: 0.2227
# Beta Model Training - Epoch [40/200], Loss: 0.2200
# Beta Model Training - Epoch [41/200], Loss: 0.2171
# Beta Model Training - Epoch [42/200], Loss: 0.2134
# Beta Model Training - Epoch [43/200], Loss: 0.2153
# Beta Model Training - Epoch [44/200], Loss: 0.2109
# Beta Model Training - Epoch [45/200], Loss: 0.2114
# Beta Model Training - Epoch [46/200], Loss: 0.2089
# Beta Model Training - Epoch [47/200], Loss: 0.2071
# Beta Model Training - Epoch [48/200], Loss: 0.2055
# Beta Model Training - Epoch [49/200], Loss: 0.2028
# Beta Model Training - Epoch [50/200], Loss: 0.2021
# Beta Model Training - Epoch [51/200], Loss: 0.2020
# Beta Model Training - Epoch [52/200], Loss: 0.2128
# Beta Model Training - Epoch [53/200], Loss: 0.2108
# Beta Model Training - Epoch [54/200], Loss: 0.2171
# Beta Model Training - Epoch [55/200], Loss: 0.2031
# Beta Model Training - Epoch [56/200], Loss: 0.2017
# Beta Model Training - Epoch [57/200], Loss: 0.1995
# Beta Model Training - Epoch [58/200], Loss: 0.2019
# Beta Model Training - Epoch [59/200], Loss: 0.1997
# Beta Model Training - Epoch [60/200], Loss: 0.1981
# Beta Model Training - Epoch [61/200], Loss: 0.1976
# Beta Model Training - Epoch [62/200], Loss: 0.1906
# Beta Model Training - Epoch [63/200], Loss: 0.1975
# Beta Model Training - Epoch [64/200], Loss: 0.1984
# Beta Model Training - Epoch [65/200], Loss: 0.1883
# Beta Model Training - Epoch [66/200], Loss: 0.1885
# Beta Model Training - Epoch [67/200], Loss: 0.1861
# Beta Model Training - Epoch [68/200], Loss: 0.1837
# Beta Model Training - Epoch [69/200], Loss: 0.1836
# Beta Model Training - Epoch [70/200], Loss: 0.1854
# Beta Model Training - Epoch [71/200], Loss: 0.1857
# Beta Model Training - Epoch [72/200], Loss: 0.1832
# Beta Model Training - Epoch [73/200], Loss: 0.1810
# Beta Model Training - Epoch [74/200], Loss: 0.1800
# Beta Model Training - Epoch [75/200], Loss: 0.1794
# Beta Model Training - Epoch [76/200], Loss: 0.1779
# Beta Model Training - Epoch [77/200], Loss: 0.1773
# Beta Model Training - Epoch [78/200], Loss: 0.1767
# Beta Model Training - Epoch [79/200], Loss: 0.1783
# Beta Model Training - Epoch [80/200], Loss: 0.1813
# Beta Model Training - Epoch [81/200], Loss: 0.1803
# Beta Model Training - Epoch [82/200], Loss: 0.1771
# Beta Model Training - Epoch [83/200], Loss: 0.1755
# Beta Model Training - Epoch [84/200], Loss: 0.1786
# Beta Model Training - Epoch [85/200], Loss: 0.1809
# Beta Model Training - Epoch [86/200], Loss: 0.1837
# Beta Model Training - Epoch [87/200], Loss: 0.1840
# Beta Model Training - Epoch [88/200], Loss: 0.1839
# Beta Model Training - Epoch [89/200], Loss: 0.1834
# Beta Model Training - Epoch [90/200], Loss: 0.1802
# Beta Model Training - Epoch [91/200], Loss: 0.1796
# Beta Model Training - Epoch [92/200], Loss: 0.1806
# Beta Model Training - Epoch [93/200], Loss: 0.1739
# Beta Model Training - Epoch [94/200], Loss: 0.1704
# Beta Model Training - Epoch [95/200], Loss: 0.1706
# Beta Model Training - Epoch [96/200], Loss: 0.1709
# Beta Model Training - Epoch [97/200], Loss: 0.1730
# Beta Model Training - Epoch [98/200], Loss: 0.1715
# Beta Model Training - Epoch [99/200], Loss: 0.1710
# Beta Model Training - Epoch [100/200], Loss: 0.1710
# Beta Model Training - Epoch [101/200], Loss: 0.1703
# Beta Model Training - Epoch [102/200], Loss: 0.1691
# Beta Model Training - Epoch [103/200], Loss: 0.1717
# Beta Model Training - Epoch [104/200], Loss: 0.1704
# Beta Model Training - Epoch [105/200], Loss: 0.1705
# Beta Model Training - Epoch [106/200], Loss: 0.1685
# Beta Model Training - Epoch [107/200], Loss: 0.1685
# Beta Model Training - Epoch [108/200], Loss: 0.1679
# Beta Model Training - Epoch [109/200], Loss: 0.1676
# Beta Model Training - Epoch [110/200], Loss: 0.1667
# Beta Model Training - Epoch [111/200], Loss: 0.1633
# Beta Model Training - Epoch [112/200], Loss: 0.1635
# Beta Model Training - Epoch [113/200], Loss: 0.1627
# Beta Model Training - Epoch [114/200], Loss: 0.1618
# Beta Model Training - Epoch [115/200], Loss: 0.1617
# Beta Model Training - Epoch [116/200], Loss: 0.1666
# Beta Model Training - Epoch [117/200], Loss: 0.1681
# Beta Model Training - Epoch [118/200], Loss: 0.1645
# Beta Model Training - Epoch [119/200], Loss: 0.1628
# Beta Model Training - Epoch [120/200], Loss: 0.1659
# Beta Model Training - Epoch [121/200], Loss: 0.1640
# Beta Model Training - Epoch [122/200], Loss: 0.1616
# Beta Model Training - Epoch [123/200], Loss: 0.1600
# Beta Model Training - Epoch [124/200], Loss: 0.1632
# Beta Model Training - Epoch [125/200], Loss: 0.1639
# Beta Model Training - Epoch [126/200], Loss: 0.1640
# Beta Model Training - Epoch [127/200], Loss: 0.1640
# Beta Model Training - Epoch [128/200], Loss: 0.1603
# Beta Model Training - Epoch [129/200], Loss: 0.1586
# Beta Model Training - Epoch [130/200], Loss: 0.1601
# Beta Model Training - Epoch [131/200], Loss: 0.1606
# Beta Model Training - Epoch [132/200], Loss: 0.1610
# Beta Model Training - Epoch [133/200], Loss: 0.1631
# Beta Model Training - Epoch [134/200], Loss: 0.1581
# Beta Model Training - Epoch [135/200], Loss: 0.1560
# Beta Model Training - Epoch [136/200], Loss: 0.1549
# Beta Model Training - Epoch [137/200], Loss: 0.1547
# Beta Model Training - Epoch [138/200], Loss: 0.1551
# Beta Model Training - Epoch [139/200], Loss: 0.1569
# Beta Model Training - Epoch [140/200], Loss: 0.1560
# Beta Model Training - Epoch [141/200], Loss: 0.1562
# Beta Model Training - Epoch [142/200], Loss: 0.1550
# Beta Model Training - Epoch [143/200], Loss: 0.1565
# Beta Model Training - Epoch [144/200], Loss: 0.1554
# Beta Model Training - Epoch [145/200], Loss: 0.1572
# Beta Model Training - Epoch [146/200], Loss: 0.1611
# Beta Model Training - Epoch [147/200], Loss: 0.1587
# Beta Model Training - Epoch [148/200], Loss: 0.1555
# Beta Model Training - Epoch [149/200], Loss: 0.1629
# Beta Model Training - Epoch [150/200], Loss: 0.1555
# Beta Model Training - Epoch [151/200], Loss: 0.1586
# Beta Model Training - Epoch [152/200], Loss: 0.1546
# Beta Model Training - Epoch [153/200], Loss: 0.1551
# Beta Model Training - Epoch [154/200], Loss: 0.1551
# Beta Model Training - Epoch [155/200], Loss: 0.1553
# Beta Model Training - Epoch [156/200], Loss: 0.1583
# Beta Model Training - Epoch [157/200], Loss: 0.1561
# Beta Model Training - Epoch [158/200], Loss: 0.1595
# Beta Model Training - Epoch [159/200], Loss: 0.1587
# Beta Model Training - Epoch [160/200], Loss: 0.1628
# Beta Model Training - Epoch [161/200], Loss: 0.1656
# Beta Model Training - Epoch [162/200], Loss: 0.1603
# Beta Model Training - Epoch [163/200], Loss: 0.1542
# Beta Model Training - Epoch [164/200], Loss: 0.1676
# Beta Model Training - Epoch [165/200], Loss: 0.1784
# Beta Model Training - Epoch [166/200], Loss: 0.1723
# Beta Model Training - Epoch [167/200], Loss: 0.1576
# Beta Model Training - Epoch [168/200], Loss: 0.1555
# Beta Model Training - Epoch [169/200], Loss: 0.1543
# Beta Model Training - Epoch [170/200], Loss: 0.1542
# Beta Model Training - Epoch [171/200], Loss: 0.1563
# Beta Model Training - Epoch [172/200], Loss: 0.1557
# Beta Model Training - Epoch [173/200], Loss: 0.1524
# Beta Model Training - Epoch [174/200], Loss: 0.1492
# Beta Model Training - Epoch [175/200], Loss: 0.1513
# Beta Model Training - Epoch [176/200], Loss: 0.1519
# Beta Model Training - Epoch [177/200], Loss: 0.1488
# Beta Model Training - Epoch [178/200], Loss: 0.1489
# Beta Model Training - Epoch [179/200], Loss: 0.1511
# Beta Model Training - Epoch [180/200], Loss: 0.1500
# Beta Model Training - Epoch [181/200], Loss: 0.1491
# Beta Model Training - Epoch [182/200], Loss: 0.1510
# Beta Model Training - Epoch [183/200], Loss: 0.1481
# Beta Model Training - Epoch [184/200], Loss: 0.1518
# Beta Model Training - Epoch [185/200], Loss: 0.1497
# Beta Model Training - Epoch [186/200], Loss: 0.1478
# Beta Model Training - Epoch [187/200], Loss: 0.1513
# Beta Model Training - Epoch [188/200], Loss: 0.1528
# Beta Model Training - Epoch [189/200], Loss: 0.1558
# Beta Model Training - Epoch [190/200], Loss: 0.1541
# Beta Model Training - Epoch [191/200], Loss: 0.1530
# Beta Model Training - Epoch [192/200], Loss: 0.1518
# Beta Model Training - Epoch [193/200], Loss: 0.1487
# Beta Model Training - Epoch [194/200], Loss: 0.1495
# Beta Model Training - Epoch [195/200], Loss: 0.1479
# Beta Model Training - Epoch [196/200], Loss: 0.1466
# Beta Model Training - Epoch [197/200], Loss: 0.1462
# Beta Model Training - Epoch [198/200], Loss: 0.1484
# Beta Model Training - Epoch [199/200], Loss: 0.1533
# Beta Model Training - Epoch [200/200], Loss: 0.1467
#
# === Building dataset/model for Beta 2 ===
# Beta Model Training - Epoch [1/200], Loss: 0.8125
# Beta Model Training - Epoch [2/200], Loss: 0.7608
# Beta Model Training - Epoch [3/200], Loss: 0.6615
# Beta Model Training - Epoch [4/200], Loss: 0.5893
# Beta Model Training - Epoch [5/200], Loss: 0.5446
# Beta Model Training - Epoch [6/200], Loss: 0.5101
# Beta Model Training - Epoch [7/200], Loss: 0.4790
# Beta Model Training - Epoch [8/200], Loss: 0.4508
# Beta Model Training - Epoch [9/200], Loss: 0.4240
# Beta Model Training - Epoch [10/200], Loss: 0.4004
# Beta Model Training - Epoch [11/200], Loss: 0.3847
# Beta Model Training - Epoch [12/200], Loss: 0.3668
# Beta Model Training - Epoch [13/200], Loss: 0.3548
# Beta Model Training - Epoch [14/200], Loss: 0.3424
# Beta Model Training - Epoch [15/200], Loss: 0.3352
# Beta Model Training - Epoch [16/200], Loss: 0.3235
# Beta Model Training - Epoch [17/200], Loss: 0.3120
# Beta Model Training - Epoch [18/200], Loss: 0.3017
# Beta Model Training - Epoch [19/200], Loss: 0.2927
# Beta Model Training - Epoch [20/200], Loss: 0.2842
# Beta Model Training - Epoch [21/200], Loss: 0.2818
# Beta Model Training - Epoch [22/200], Loss: 0.2756
# Beta Model Training - Epoch [23/200], Loss: 0.2664
# Beta Model Training - Epoch [24/200], Loss: 0.2599
# Beta Model Training - Epoch [25/200], Loss: 0.2539
# Beta Model Training - Epoch [26/200], Loss: 0.2528
# Beta Model Training - Epoch [27/200], Loss: 0.2528
# Beta Model Training - Epoch [28/200], Loss: 0.2474
# Beta Model Training - Epoch [29/200], Loss: 0.2428
# Beta Model Training - Epoch [30/200], Loss: 0.2411
# Beta Model Training - Epoch [31/200], Loss: 0.2357
# Beta Model Training - Epoch [32/200], Loss: 0.2331
# Beta Model Training - Epoch [33/200], Loss: 0.2312
# Beta Model Training - Epoch [34/200], Loss: 0.2298
# Beta Model Training - Epoch [35/200], Loss: 0.2263
# Beta Model Training - Epoch [36/200], Loss: 0.2254
# Beta Model Training - Epoch [37/200], Loss: 0.2238
# Beta Model Training - Epoch [38/200], Loss: 0.2212
# Beta Model Training - Epoch [39/200], Loss: 0.2204
# Beta Model Training - Epoch [40/200], Loss: 0.2213
# Beta Model Training - Epoch [41/200], Loss: 0.2192
# Beta Model Training - Epoch [42/200], Loss: 0.2179
# Beta Model Training - Epoch [43/200], Loss: 0.2161
# Beta Model Training - Epoch [44/200], Loss: 0.2152
# Beta Model Training - Epoch [45/200], Loss: 0.2139
# Beta Model Training - Epoch [46/200], Loss: 0.2149
# Beta Model Training - Epoch [47/200], Loss: 0.2141
# Beta Model Training - Epoch [48/200], Loss: 0.2124
# Beta Model Training - Epoch [49/200], Loss: 0.2106
# Beta Model Training - Epoch [50/200], Loss: 0.2098
# Beta Model Training - Epoch [51/200], Loss: 0.2100
# Beta Model Training - Epoch [52/200], Loss: 0.2094
# Beta Model Training - Epoch [53/200], Loss: 0.2137
# Beta Model Training - Epoch [54/200], Loss: 0.2189
# Beta Model Training - Epoch [55/200], Loss: 0.2191
# Beta Model Training - Epoch [56/200], Loss: 0.2119
# Beta Model Training - Epoch [57/200], Loss: 0.2042
# Beta Model Training - Epoch [58/200], Loss: 0.2014
# Beta Model Training - Epoch [59/200], Loss: 0.2020
# Beta Model Training - Epoch [60/200], Loss: 0.1983
# Beta Model Training - Epoch [61/200], Loss: 0.1963
# Beta Model Training - Epoch [62/200], Loss: 0.1964
# Beta Model Training - Epoch [63/200], Loss: 0.1945
# Beta Model Training - Epoch [64/200], Loss: 0.1935
# Beta Model Training - Epoch [65/200], Loss: 0.1923
# Beta Model Training - Epoch [66/200], Loss: 0.1920
# Beta Model Training - Epoch [67/200], Loss: 0.1910
# Beta Model Training - Epoch [68/200], Loss: 0.1906
# Beta Model Training - Epoch [69/200], Loss: 0.1910
# Beta Model Training - Epoch [70/200], Loss: 0.1888
# Beta Model Training - Epoch [71/200], Loss: 0.1887
# Beta Model Training - Epoch [72/200], Loss: 0.1891
# Beta Model Training - Epoch [73/200], Loss: 0.1901
# Beta Model Training - Epoch [74/200], Loss: 0.1885
# Beta Model Training - Epoch [75/200], Loss: 0.1870
# Beta Model Training - Epoch [76/200], Loss: 0.1876
# Beta Model Training - Epoch [77/200], Loss: 0.1873
# Beta Model Training - Epoch [78/200], Loss: 0.1853
# Beta Model Training - Epoch [79/200], Loss: 0.1861
# Beta Model Training - Epoch [80/200], Loss: 0.1845
# Beta Model Training - Epoch [81/200], Loss: 0.1846
# Beta Model Training - Epoch [82/200], Loss: 0.1849
# Beta Model Training - Epoch [83/200], Loss: 0.1844
# Beta Model Training - Epoch [84/200], Loss: 0.1816
# Beta Model Training - Epoch [85/200], Loss: 0.1825
# Beta Model Training - Epoch [86/200], Loss: 0.1823
# Beta Model Training - Epoch [87/200], Loss: 0.1820
# Beta Model Training - Epoch [88/200], Loss: 0.1825
# Beta Model Training - Epoch [89/200], Loss: 0.1813
# Beta Model Training - Epoch [90/200], Loss: 0.1837
# Beta Model Training - Epoch [91/200], Loss: 0.1816
# Beta Model Training - Epoch [92/200], Loss: 0.1813
# Beta Model Training - Epoch [93/200], Loss: 0.1806
# Beta Model Training - Epoch [94/200], Loss: 0.1803
# Beta Model Training - Epoch [95/200], Loss: 0.1783
# Beta Model Training - Epoch [96/200], Loss: 0.1832
# Beta Model Training - Epoch [97/200], Loss: 0.1795
# Beta Model Training - Epoch [98/200], Loss: 0.1794
# Beta Model Training - Epoch [99/200], Loss: 0.1770
# Beta Model Training - Epoch [100/200], Loss: 0.1769
# Beta Model Training - Epoch [101/200], Loss: 0.1766
# Beta Model Training - Epoch [102/200], Loss: 0.1789
# Beta Model Training - Epoch [103/200], Loss: 0.1791
# Beta Model Training - Epoch [104/200], Loss: 0.1769
# Beta Model Training - Epoch [105/200], Loss: 0.1746
# Beta Model Training - Epoch [106/200], Loss: 0.1747
# Beta Model Training - Epoch [107/200], Loss: 0.1747
# Beta Model Training - Epoch [108/200], Loss: 0.1750
# Beta Model Training - Epoch [109/200], Loss: 0.1747
# Beta Model Training - Epoch [110/200], Loss: 0.1733
# Beta Model Training - Epoch [111/200], Loss: 0.1732
# Beta Model Training - Epoch [112/200], Loss: 0.1747
# Beta Model Training - Epoch [113/200], Loss: 0.1746
# Beta Model Training - Epoch [114/200], Loss: 0.1747
# Beta Model Training - Epoch [115/200], Loss: 0.1730
# Beta Model Training - Epoch [116/200], Loss: 0.1735
# Beta Model Training - Epoch [117/200], Loss: 0.1739
# Beta Model Training - Epoch [118/200], Loss: 0.1736
# Beta Model Training - Epoch [119/200], Loss: 0.1752
# Beta Model Training - Epoch [120/200], Loss: 0.1747
# Beta Model Training - Epoch [121/200], Loss: 0.1764
# Beta Model Training - Epoch [122/200], Loss: 0.1777
# Beta Model Training - Epoch [123/200], Loss: 0.1815
# Beta Model Training - Epoch [124/200], Loss: 0.1753
# Beta Model Training - Epoch [125/200], Loss: 0.1742
# Beta Model Training - Epoch [126/200], Loss: 0.1726
# Beta Model Training - Epoch [127/200], Loss: 0.1730
# Beta Model Training - Epoch [128/200], Loss: 0.1731
# Beta Model Training - Epoch [129/200], Loss: 0.1717
# Beta Model Training - Epoch [130/200], Loss: 0.1705
# Beta Model Training - Epoch [131/200], Loss: 0.1704
# Beta Model Training - Epoch [132/200], Loss: 0.1722
# Beta Model Training - Epoch [133/200], Loss: 0.1731
# Beta Model Training - Epoch [134/200], Loss: 0.1717
# Beta Model Training - Epoch [135/200], Loss: 0.1723
# Beta Model Training - Epoch [136/200], Loss: 0.1724
# Beta Model Training - Epoch [137/200], Loss: 0.1733
# Beta Model Training - Epoch [138/200], Loss: 0.1715
# Beta Model Training - Epoch [139/200], Loss: 0.1709
# Beta Model Training - Epoch [140/200], Loss: 0.1702
# Beta Model Training - Epoch [141/200], Loss: 0.1708
# Beta Model Training - Epoch [142/200], Loss: 0.1713
# Beta Model Training - Epoch [143/200], Loss: 0.1746
# Beta Model Training - Epoch [144/200], Loss: 0.1717
# Beta Model Training - Epoch [145/200], Loss: 0.1716
# Beta Model Training - Epoch [146/200], Loss: 0.1725
# Beta Model Training - Epoch [147/200], Loss: 0.1700
# Beta Model Training - Epoch [148/200], Loss: 0.1682
# Beta Model Training - Epoch [149/200], Loss: 0.1680
# Beta Model Training - Epoch [150/200], Loss: 0.1688
# Beta Model Training - Epoch [151/200], Loss: 0.1686
# Beta Model Training - Epoch [152/200], Loss: 0.1680
# Beta Model Training - Epoch [153/200], Loss: 0.1674
# Beta Model Training - Epoch [154/200], Loss: 0.1687
# Beta Model Training - Epoch [155/200], Loss: 0.1681
# Beta Model Training - Epoch [156/200], Loss: 0.1671
# Beta Model Training - Epoch [157/200], Loss: 0.1691
# Beta Model Training - Epoch [158/200], Loss: 0.1686
# Beta Model Training - Epoch [159/200], Loss: 0.1684
# Beta Model Training - Epoch [160/200], Loss: 0.1670
# Beta Model Training - Epoch [161/200], Loss: 0.1662
# Beta Model Training - Epoch [162/200], Loss: 0.1666
# Beta Model Training - Epoch [163/200], Loss: 0.1666
# Beta Model Training - Epoch [164/200], Loss: 0.1661
# Beta Model Training - Epoch [165/200], Loss: 0.1661
# Beta Model Training - Epoch [166/200], Loss: 0.1660
# Beta Model Training - Epoch [167/200], Loss: 0.1655
# Beta Model Training - Epoch [168/200], Loss: 0.1653
# Beta Model Training - Epoch [169/200], Loss: 0.1661
# Beta Model Training - Epoch [170/200], Loss: 0.1654
# Beta Model Training - Epoch [171/200], Loss: 0.1652
# Beta Model Training - Epoch [172/200], Loss: 0.1647
# Beta Model Training - Epoch [173/200], Loss: 0.1660
# Beta Model Training - Epoch [174/200], Loss: 0.1654
# Beta Model Training - Epoch [175/200], Loss: 0.1656
# Beta Model Training - Epoch [176/200], Loss: 0.1649
# Beta Model Training - Epoch [177/200], Loss: 0.1651
# Beta Model Training - Epoch [178/200], Loss: 0.1647
# Beta Model Training - Epoch [179/200], Loss: 0.1647
# Beta Model Training - Epoch [180/200], Loss: 0.1643
# Beta Model Training - Epoch [181/200], Loss: 0.1635
# Beta Model Training - Epoch [182/200], Loss: 0.1637
# Beta Model Training - Epoch [183/200], Loss: 0.1633
# Beta Model Training - Epoch [184/200], Loss: 0.1632
# Beta Model Training - Epoch [185/200], Loss: 0.1642
# Beta Model Training - Epoch [186/200], Loss: 0.1640
# Beta Model Training - Epoch [187/200], Loss: 0.1658
# Beta Model Training - Epoch [188/200], Loss: 0.1658
# Beta Model Training - Epoch [189/200], Loss: 0.1653
# Beta Model Training - Epoch [190/200], Loss: 0.1643
# Beta Model Training - Epoch [191/200], Loss: 0.1662
# Beta Model Training - Epoch [192/200], Loss: 0.1673
# Beta Model Training - Epoch [193/200], Loss: 0.1651
# Beta Model Training - Epoch [194/200], Loss: 0.1651
# Beta Model Training - Epoch [195/200], Loss: 0.1643
# Beta Model Training - Epoch [196/200], Loss: 0.1659
# Beta Model Training - Epoch [197/200], Loss: 0.1675
# Beta Model Training - Epoch [198/200], Loss: 0.1662
# Beta Model Training - Epoch [199/200], Loss: 0.1653
# Beta Model Training - Epoch [200/200], Loss: 0.1648
#
# === Building dataset/model for Beta 3 ===
# Beta Model Training - Epoch [1/200], Loss: 0.8296
# Beta Model Training - Epoch [2/200], Loss: 0.7729
# Beta Model Training - Epoch [3/200], Loss: 0.6696
# Beta Model Training - Epoch [4/200], Loss: 0.6069
# Beta Model Training - Epoch [5/200], Loss: 0.5666
# Beta Model Training - Epoch [6/200], Loss: 0.5344
# Beta Model Training - Epoch [7/200], Loss: 0.5074
# Beta Model Training - Epoch [8/200], Loss: 0.4841
# Beta Model Training - Epoch [9/200], Loss: 0.4565
# Beta Model Training - Epoch [10/200], Loss: 0.4369
# Beta Model Training - Epoch [11/200], Loss: 0.4175
# Beta Model Training - Epoch [12/200], Loss: 0.3976
# Beta Model Training - Epoch [13/200], Loss: 0.3873
# Beta Model Training - Epoch [14/200], Loss: 0.3700
# Beta Model Training - Epoch [15/200], Loss: 0.3606
# Beta Model Training - Epoch [16/200], Loss: 0.3470
# Beta Model Training - Epoch [17/200], Loss: 0.3368
# Beta Model Training - Epoch [18/200], Loss: 0.3313
# Beta Model Training - Epoch [19/200], Loss: 0.3217
# Beta Model Training - Epoch [20/200], Loss: 0.3127
# Beta Model Training - Epoch [21/200], Loss: 0.3044
# Beta Model Training - Epoch [22/200], Loss: 0.3005
# Beta Model Training - Epoch [23/200], Loss: 0.3007
# Beta Model Training - Epoch [24/200], Loss: 0.2966
# Beta Model Training - Epoch [25/200], Loss: 0.2851
# Beta Model Training - Epoch [26/200], Loss: 0.2786
# Beta Model Training - Epoch [27/200], Loss: 0.2789
# Beta Model Training - Epoch [28/200], Loss: 0.2777
# Beta Model Training - Epoch [29/200], Loss: 0.2718
# Beta Model Training - Epoch [30/200], Loss: 0.2652
# Beta Model Training - Epoch [31/200], Loss: 0.2621
# Beta Model Training - Epoch [32/200], Loss: 0.2599
# Beta Model Training - Epoch [33/200], Loss: 0.2609
# Beta Model Training - Epoch [34/200], Loss: 0.2591
# Beta Model Training - Epoch [35/200], Loss: 0.2568
# Beta Model Training - Epoch [36/200], Loss: 0.2500
# Beta Model Training - Epoch [37/200], Loss: 0.2452
# Beta Model Training - Epoch [38/200], Loss: 0.2409
# Beta Model Training - Epoch [39/200], Loss: 0.2401
# Beta Model Training - Epoch [40/200], Loss: 0.2354
# Beta Model Training - Epoch [41/200], Loss: 0.2327
# Beta Model Training - Epoch [42/200], Loss: 0.2296
# Beta Model Training - Epoch [43/200], Loss: 0.2251
# Beta Model Training - Epoch [44/200], Loss: 0.2279
# Beta Model Training - Epoch [45/200], Loss: 0.2262
# Beta Model Training - Epoch [46/200], Loss: 0.2232
# Beta Model Training - Epoch [47/200], Loss: 0.2213
# Beta Model Training - Epoch [48/200], Loss: 0.2188
# Beta Model Training - Epoch [49/200], Loss: 0.2178
# Beta Model Training - Epoch [50/200], Loss: 0.2165
# Beta Model Training - Epoch [51/200], Loss: 0.2171
# Beta Model Training - Epoch [52/200], Loss: 0.2167
# Beta Model Training - Epoch [53/200], Loss: 0.2122
# Beta Model Training - Epoch [54/200], Loss: 0.2075
# Beta Model Training - Epoch [55/200], Loss: 0.2085
# Beta Model Training - Epoch [56/200], Loss: 0.2125
# Beta Model Training - Epoch [57/200], Loss: 0.2128
# Beta Model Training - Epoch [58/200], Loss: 0.2113
# Beta Model Training - Epoch [59/200], Loss: 0.2065
# Beta Model Training - Epoch [60/200], Loss: 0.2044
# Beta Model Training - Epoch [61/200], Loss: 0.2014
# Beta Model Training - Epoch [62/200], Loss: 0.2015
# Beta Model Training - Epoch [63/200], Loss: 0.1971
# Beta Model Training - Epoch [64/200], Loss: 0.1943
# Beta Model Training - Epoch [65/200], Loss: 0.1950
# Beta Model Training - Epoch [66/200], Loss: 0.1944
# Beta Model Training - Epoch [67/200], Loss: 0.1924
# Beta Model Training - Epoch [68/200], Loss: 0.1971
# Beta Model Training - Epoch [69/200], Loss: 0.2087
# Beta Model Training - Epoch [70/200], Loss: 0.1968
# Beta Model Training - Epoch [71/200], Loss: 0.1959
# Beta Model Training - Epoch [72/200], Loss: 0.1939
# Beta Model Training - Epoch [73/200], Loss: 0.1924
# Beta Model Training - Epoch [74/200], Loss: 0.1902
# Beta Model Training - Epoch [75/200], Loss: 0.1901
# Beta Model Training - Epoch [76/200], Loss: 0.1874
# Beta Model Training - Epoch [77/200], Loss: 0.1852
# Beta Model Training - Epoch [78/200], Loss: 0.1843
# Beta Model Training - Epoch [79/200], Loss: 0.1846
# Beta Model Training - Epoch [80/200], Loss: 0.1834
# Beta Model Training - Epoch [81/200], Loss: 0.1805
# Beta Model Training - Epoch [82/200], Loss: 0.1809
# Beta Model Training - Epoch [83/200], Loss: 0.1794
# Beta Model Training - Epoch [84/200], Loss: 0.1780
# Beta Model Training - Epoch [85/200], Loss: 0.1790
# Beta Model Training - Epoch [86/200], Loss: 0.1791
# Beta Model Training - Epoch [87/200], Loss: 0.1797
# Beta Model Training - Epoch [88/200], Loss: 0.1774
# Beta Model Training - Epoch [89/200], Loss: 0.1784
# Beta Model Training - Epoch [90/200], Loss: 0.1760
# Beta Model Training - Epoch [91/200], Loss: 0.1760
# Beta Model Training - Epoch [92/200], Loss: 0.1746
# Beta Model Training - Epoch [93/200], Loss: 0.1773
# Beta Model Training - Epoch [94/200], Loss: 0.1746
# Beta Model Training - Epoch [95/200], Loss: 0.1749
# Beta Model Training - Epoch [96/200], Loss: 0.1731
# Beta Model Training - Epoch [97/200], Loss: 0.1717
# Beta Model Training - Epoch [98/200], Loss: 0.1702
# Beta Model Training - Epoch [99/200], Loss: 0.1714
# Beta Model Training - Epoch [100/200], Loss: 0.1712
# Beta Model Training - Epoch [101/200], Loss: 0.1707
# Beta Model Training - Epoch [102/200], Loss: 0.1726
# Beta Model Training - Epoch [103/200], Loss: 0.1754
# Beta Model Training - Epoch [104/200], Loss: 0.1719
# Beta Model Training - Epoch [105/200], Loss: 0.1694
# Beta Model Training - Epoch [106/200], Loss: 0.1695
# Beta Model Training - Epoch [107/200], Loss: 0.1694
# Beta Model Training - Epoch [108/200], Loss: 0.1676
# Beta Model Training - Epoch [109/200], Loss: 0.1665
# Beta Model Training - Epoch [110/200], Loss: 0.1658
# Beta Model Training - Epoch [111/200], Loss: 0.1687
# Beta Model Training - Epoch [112/200], Loss: 0.1683
# Beta Model Training - Epoch [113/200], Loss: 0.1672
# Beta Model Training - Epoch [114/200], Loss: 0.1670
# Beta Model Training - Epoch [115/200], Loss: 0.1663
# Beta Model Training - Epoch [116/200], Loss: 0.1665
# Beta Model Training - Epoch [117/200], Loss: 0.1682
# Beta Model Training - Epoch [118/200], Loss: 0.1663
# Beta Model Training - Epoch [119/200], Loss: 0.1672
# Beta Model Training - Epoch [120/200], Loss: 0.1652
# Beta Model Training - Epoch [121/200], Loss: 0.1620
# Beta Model Training - Epoch [122/200], Loss: 0.1629
# Beta Model Training - Epoch [123/200], Loss: 0.1632
# Beta Model Training - Epoch [124/200], Loss: 0.1653
# Beta Model Training - Epoch [125/200], Loss: 0.1692
# Beta Model Training - Epoch [126/200], Loss: 0.1664
# Beta Model Training - Epoch [127/200], Loss: 0.1660
# Beta Model Training - Epoch [128/200], Loss: 0.1640
# Beta Model Training - Epoch [129/200], Loss: 0.1627
# Beta Model Training - Epoch [130/200], Loss: 0.1613
# Beta Model Training - Epoch [131/200], Loss: 0.1615
# Beta Model Training - Epoch [132/200], Loss: 0.1616
# Beta Model Training - Epoch [133/200], Loss: 0.1624
# Beta Model Training - Epoch [134/200], Loss: 0.1661
# Beta Model Training - Epoch [135/200], Loss: 0.1653
# Beta Model Training - Epoch [136/200], Loss: 0.1608
# Beta Model Training - Epoch [137/200], Loss: 0.1606
# Beta Model Training - Epoch [138/200], Loss: 0.1627
# Beta Model Training - Epoch [139/200], Loss: 0.1623
# Beta Model Training - Epoch [140/200], Loss: 0.1625
# Beta Model Training - Epoch [141/200], Loss: 0.1628
# Beta Model Training - Epoch [142/200], Loss: 0.1581
# Beta Model Training - Epoch [143/200], Loss: 0.1595
# Beta Model Training - Epoch [144/200], Loss: 0.1589
# Beta Model Training - Epoch [145/200], Loss: 0.1606
# Beta Model Training - Epoch [146/200], Loss: 0.1592
# Beta Model Training - Epoch [147/200], Loss: 0.1590
# Beta Model Training - Epoch [148/200], Loss: 0.1588
# Beta Model Training - Epoch [149/200], Loss: 0.1572
# Beta Model Training - Epoch [150/200], Loss: 0.1583
# Beta Model Training - Epoch [151/200], Loss: 0.1607
# Beta Model Training - Epoch [152/200], Loss: 0.1595
# Beta Model Training - Epoch [153/200], Loss: 0.1589
# Beta Model Training - Epoch [154/200], Loss: 0.1579
# Beta Model Training - Epoch [155/200], Loss: 0.1570
# Beta Model Training - Epoch [156/200], Loss: 0.1553
# Beta Model Training - Epoch [157/200], Loss: 0.1539
# Beta Model Training - Epoch [158/200], Loss: 0.1566
# Beta Model Training - Epoch [159/200], Loss: 0.1611
# Beta Model Training - Epoch [160/200], Loss: 0.1609
# Beta Model Training - Epoch [161/200], Loss: 0.1605
# Beta Model Training - Epoch [162/200], Loss: 0.1583
# Beta Model Training - Epoch [163/200], Loss: 0.1567
# Beta Model Training - Epoch [164/200], Loss: 0.1595
# Beta Model Training - Epoch [165/200], Loss: 0.1587
# Beta Model Training - Epoch [166/200], Loss: 0.1549
# Beta Model Training - Epoch [167/200], Loss: 0.1553
# Beta Model Training - Epoch [168/200], Loss: 0.1540
# Beta Model Training - Epoch [169/200], Loss: 0.1539
# Beta Model Training - Epoch [170/200], Loss: 0.1530
# Beta Model Training - Epoch [171/200], Loss: 0.1569
# Beta Model Training - Epoch [172/200], Loss: 0.1582
# Beta Model Training - Epoch [173/200], Loss: 0.1608
# Beta Model Training - Epoch [174/200], Loss: 0.1580
# Beta Model Training - Epoch [175/200], Loss: 0.1560
# Beta Model Training - Epoch [176/200], Loss: 0.1573
# Beta Model Training - Epoch [177/200], Loss: 0.1521
# Beta Model Training - Epoch [178/200], Loss: 0.1526
# Beta Model Training - Epoch [179/200], Loss: 0.1526
# Beta Model Training - Epoch [180/200], Loss: 0.1546
# Beta Model Training - Epoch [181/200], Loss: 0.1539
# Beta Model Training - Epoch [182/200], Loss: 0.1571
# Beta Model Training - Epoch [183/200], Loss: 0.1534
# Beta Model Training - Epoch [184/200], Loss: 0.1547
# Beta Model Training - Epoch [185/200], Loss: 0.1548
# Beta Model Training - Epoch [186/200], Loss: 0.1565
# Beta Model Training - Epoch [187/200], Loss: 0.1526
# Beta Model Training - Epoch [188/200], Loss: 0.1524
# Beta Model Training - Epoch [189/200], Loss: 0.1501
# Beta Model Training - Epoch [190/200], Loss: 0.1503
# Beta Model Training - Epoch [191/200], Loss: 0.1489
# Beta Model Training - Epoch [192/200], Loss: 0.1489
# Beta Model Training - Epoch [193/200], Loss: 0.1491
# Beta Model Training - Epoch [194/200], Loss: 0.1492
# Beta Model Training - Epoch [195/200], Loss: 0.1494
# Beta Model Training - Epoch [196/200], Loss: 0.1526
# Beta Model Training - Epoch [197/200], Loss: 0.1559
# Beta Model Training - Epoch [198/200], Loss: 0.1589
# Beta Model Training - Epoch [199/200], Loss: 0.1622
# Beta Model Training - Epoch [200/200], Loss: 0.1534
#
# === Building dataset/model for Beta 4 ===
# Beta Model Training - Epoch [1/200], Loss: 0.8660
# Beta Model Training - Epoch [2/200], Loss: 0.7919
# Beta Model Training - Epoch [3/200], Loss: 0.6763
# Beta Model Training - Epoch [4/200], Loss: 0.6010
# Beta Model Training - Epoch [5/200], Loss: 0.5601
# Beta Model Training - Epoch [6/200], Loss: 0.5208
# Beta Model Training - Epoch [7/200], Loss: 0.4844
# Beta Model Training - Epoch [8/200], Loss: 0.4565
# Beta Model Training - Epoch [9/200], Loss: 0.4378
# Beta Model Training - Epoch [10/200], Loss: 0.4178
# Beta Model Training - Epoch [11/200], Loss: 0.4011
# Beta Model Training - Epoch [12/200], Loss: 0.3850
# Beta Model Training - Epoch [13/200], Loss: 0.3683
# Beta Model Training - Epoch [14/200], Loss: 0.3548
# Beta Model Training - Epoch [15/200], Loss: 0.3436
# Beta Model Training - Epoch [16/200], Loss: 0.3326
# Beta Model Training - Epoch [17/200], Loss: 0.3239
# Beta Model Training - Epoch [18/200], Loss: 0.3164
# Beta Model Training - Epoch [19/200], Loss: 0.3114
# Beta Model Training - Epoch [20/200], Loss: 0.3034
# Beta Model Training - Epoch [21/200], Loss: 0.2938
# Beta Model Training - Epoch [22/200], Loss: 0.2884
# Beta Model Training - Epoch [23/200], Loss: 0.2803
# Beta Model Training - Epoch [24/200], Loss: 0.2736
# Beta Model Training - Epoch [25/200], Loss: 0.2686
# Beta Model Training - Epoch [26/200], Loss: 0.2676
# Beta Model Training - Epoch [27/200], Loss: 0.2585
# Beta Model Training - Epoch [28/200], Loss: 0.2529
# Beta Model Training - Epoch [29/200], Loss: 0.2483
# Beta Model Training - Epoch [30/200], Loss: 0.2441
# Beta Model Training - Epoch [31/200], Loss: 0.2401
# Beta Model Training - Epoch [32/200], Loss: 0.2377
# Beta Model Training - Epoch [33/200], Loss: 0.2371
# Beta Model Training - Epoch [34/200], Loss: 0.2376
# Beta Model Training - Epoch [35/200], Loss: 0.2430
# Beta Model Training - Epoch [36/200], Loss: 0.2361
# Beta Model Training - Epoch [37/200], Loss: 0.2333
# Beta Model Training - Epoch [38/200], Loss: 0.2331
# Beta Model Training - Epoch [39/200], Loss: 0.2270
# Beta Model Training - Epoch [40/200], Loss: 0.2216
# Beta Model Training - Epoch [41/200], Loss: 0.2222
# Beta Model Training - Epoch [42/200], Loss: 0.2170
# Beta Model Training - Epoch [43/200], Loss: 0.2137
# Beta Model Training - Epoch [44/200], Loss: 0.2193
# Beta Model Training - Epoch [45/200], Loss: 0.2265
# Beta Model Training - Epoch [46/200], Loss: 0.2321
# Beta Model Training - Epoch [47/200], Loss: 0.2204
# Beta Model Training - Epoch [48/200], Loss: 0.2131
# Beta Model Training - Epoch [49/200], Loss: 0.2156
# Beta Model Training - Epoch [50/200], Loss: 0.2134
# Beta Model Training - Epoch [51/200], Loss: 0.2107
# Beta Model Training - Epoch [52/200], Loss: 0.2061
# Beta Model Training - Epoch [53/200], Loss: 0.2022
# Beta Model Training - Epoch [54/200], Loss: 0.1990
# Beta Model Training - Epoch [55/200], Loss: 0.1984
# Beta Model Training - Epoch [56/200], Loss: 0.1974
# Beta Model Training - Epoch [57/200], Loss: 0.1965
# Beta Model Training - Epoch [58/200], Loss: 0.1913
# Beta Model Training - Epoch [59/200], Loss: 0.1901
# Beta Model Training - Epoch [60/200], Loss: 0.1898
# Beta Model Training - Epoch [61/200], Loss: 0.1892
# Beta Model Training - Epoch [62/200], Loss: 0.1880
# Beta Model Training - Epoch [63/200], Loss: 0.1873
# Beta Model Training - Epoch [64/200], Loss: 0.1861
# Beta Model Training - Epoch [65/200], Loss: 0.1862
# Beta Model Training - Epoch [66/200], Loss: 0.1869
# Beta Model Training - Epoch [67/200], Loss: 0.1877
# Beta Model Training - Epoch [68/200], Loss: 0.1860
# Beta Model Training - Epoch [69/200], Loss: 0.1836
# Beta Model Training - Epoch [70/200], Loss: 0.1828
# Beta Model Training - Epoch [71/200], Loss: 0.1818
# Beta Model Training - Epoch [72/200], Loss: 0.1820
# Beta Model Training - Epoch [73/200], Loss: 0.1823
# Beta Model Training - Epoch [74/200], Loss: 0.1787
# Beta Model Training - Epoch [75/200], Loss: 0.1789
# Beta Model Training - Epoch [76/200], Loss: 0.1785
# Beta Model Training - Epoch [77/200], Loss: 0.1830
# Beta Model Training - Epoch [78/200], Loss: 0.1870
# Beta Model Training - Epoch [79/200], Loss: 0.1859
# Beta Model Training - Epoch [80/200], Loss: 0.1827
# Beta Model Training - Epoch [81/200], Loss: 0.1773
# Beta Model Training - Epoch [82/200], Loss: 0.1765
# Beta Model Training - Epoch [83/200], Loss: 0.1749
# Beta Model Training - Epoch [84/200], Loss: 0.1751
# Beta Model Training - Epoch [85/200], Loss: 0.1757
# Beta Model Training - Epoch [86/200], Loss: 0.1752
# Beta Model Training - Epoch [87/200], Loss: 0.1768
# Beta Model Training - Epoch [88/200], Loss: 0.1750
# Beta Model Training - Epoch [89/200], Loss: 0.1794
# Beta Model Training - Epoch [90/200], Loss: 0.1926
# Beta Model Training - Epoch [91/200], Loss: 0.1824
# Beta Model Training - Epoch [92/200], Loss: 0.1777
# Beta Model Training - Epoch [93/200], Loss: 0.1774
# Beta Model Training - Epoch [94/200], Loss: 0.1789
# Beta Model Training - Epoch [95/200], Loss: 0.1838
# Beta Model Training - Epoch [96/200], Loss: 0.1845
# Beta Model Training - Epoch [97/200], Loss: 0.1797
# Beta Model Training - Epoch [98/200], Loss: 0.1725
# Beta Model Training - Epoch [99/200], Loss: 0.1747
# Beta Model Training - Epoch [100/200], Loss: 0.1710
# Beta Model Training - Epoch [101/200], Loss: 0.1709
# Beta Model Training - Epoch [102/200], Loss: 0.1687
# Beta Model Training - Epoch [103/200], Loss: 0.1664
# Beta Model Training - Epoch [104/200], Loss: 0.1682
# Beta Model Training - Epoch [105/200], Loss: 0.1671
# Beta Model Training - Epoch [106/200], Loss: 0.1674
# Beta Model Training - Epoch [107/200], Loss: 0.1643
# Beta Model Training - Epoch [108/200], Loss: 0.1660
# Beta Model Training - Epoch [109/200], Loss: 0.1649
# Beta Model Training - Epoch [110/200], Loss: 0.1651
# Beta Model Training - Epoch [111/200], Loss: 0.1663
# Beta Model Training - Epoch [112/200], Loss: 0.1673
# Beta Model Training - Epoch [113/200], Loss: 0.1704
# Beta Model Training - Epoch [114/200], Loss: 0.1687
# Beta Model Training - Epoch [115/200], Loss: 0.1712
# Beta Model Training - Epoch [116/200], Loss: 0.1671
# Beta Model Training - Epoch [117/200], Loss: 0.1680
# Beta Model Training - Epoch [118/200], Loss: 0.1652
# Beta Model Training - Epoch [119/200], Loss: 0.1619
# Beta Model Training - Epoch [120/200], Loss: 0.1609
# Beta Model Training - Epoch [121/200], Loss: 0.1601
# Beta Model Training - Epoch [122/200], Loss: 0.1595
# Beta Model Training - Epoch [123/200], Loss: 0.1591
# ...
# Beta Model Training - Epoch [92/200], Loss: 0.1508
# Beta Model Training - Epoch [93/200], Loss: 0.1516
# Beta Model Training - Epoch [94/200], Loss: 0.1504
# Beta Model Training - Epoch [95/200], Loss: 0.1517
# Beta Model Training - Epoch [96/200], Loss: 0.1512
# Beta Model Training - Epoch [97/200], Loss: 0.1508
# Beta Model Training - Epoch [98/200], Loss: 0.1541
# Beta Model Training - Epoch [99/200], Loss: 0.1549
# Beta Model Training - Epoch [100/200], Loss: 0.1555
# Beta Model Training - Epoch [101/200], Loss: 0.1554
# Beta Model Training - Epoch [102/200], Loss: 0.1511
# Beta Model Training - Epoch [103/200], Loss: 0.1517
# Beta Model Training - Epoch [104/200], Loss: 0.1500
# Beta Model Training - Epoch [105/200], Loss: 0.1498
# Beta Model Training - Epoch [106/200], Loss: 0.1516
# Beta Model Training - Epoch [107/200], Loss: 0.1507
# Beta Model Training - Epoch [108/200], Loss: 0.1558
# Beta Model Training - Epoch [109/200], Loss: 0.1503
# Beta Model Training - Epoch [110/200], Loss: 0.1472
# Beta Model Training - Epoch [111/200], Loss: 0.1467
# Beta Model Training - Epoch [112/200], Loss: 0.1454
# Beta Model Training - Epoch [113/200], Loss: 0.1447
# Beta Model Training - Epoch [114/200], Loss: 0.1455
# Beta Model Training - Epoch [115/200], Loss: 0.1470
# Beta Model Training - Epoch [116/200], Loss: 0.1449
# Beta Model Training - Epoch [117/200], Loss: 0.1426
# Beta Model Training - Epoch [118/200], Loss: 0.1425
# Beta Model Training - Epoch [119/200], Loss: 0.1436
# Beta Model Training - Epoch [120/200], Loss: 0.1440
# Beta Model Training - Epoch [121/200], Loss: 0.1434
# Beta Model Training - Epoch [122/200], Loss: 0.1453
# Beta Model Training - Epoch [123/200], Loss: 0.1440
# Beta Model Training - Epoch [124/200], Loss: 0.1450
# Beta Model Training - Epoch [125/200], Loss: 0.1423
# Beta Model Training - Epoch [126/200], Loss: 0.1433
# Beta Model Training - Epoch [127/200], Loss: 0.1417
# Beta Model Training - Epoch [128/200], Loss: 0.1419
# Beta Model Training - Epoch [129/200], Loss: 0.1411
# Beta Model Training - Epoch [130/200], Loss: 0.1409
# Beta Model Training - Epoch [131/200], Loss: 0.1425
# Beta Model Training - Epoch [132/200], Loss: 0.1419
# Beta Model Training - Epoch [133/200], Loss: 0.1434
# Beta Model Training - Epoch [134/200], Loss: 0.1429
# Beta Model Training - Epoch [135/200], Loss: 0.1462
# Beta Model Training - Epoch [136/200], Loss: 0.1483
# Beta Model Training - Epoch [137/200], Loss: 0.1464
# Beta Model Training - Epoch [138/200], Loss: 0.1436
# Beta Model Training - Epoch [139/200], Loss: 0.1418
# Beta Model Training - Epoch [140/200], Loss: 0.1410
# Beta Model Training - Epoch [141/200], Loss: 0.1419
# Beta Model Training - Epoch [142/200], Loss: 0.1413
# Beta Model Training - Epoch [143/200], Loss: 0.1410
# Beta Model Training - Epoch [144/200], Loss: 0.1438
# Beta Model Training - Epoch [145/200], Loss: 0.1413
# Beta Model Training - Epoch [146/200], Loss: 0.1415
# Beta Model Training - Epoch [147/200], Loss: 0.1394
# Beta Model Training - Epoch [148/200], Loss: 0.1410
# Beta Model Training - Epoch [149/200], Loss: 0.1405
# Beta Model Training - Epoch [150/200], Loss: 0.1395
# Beta Model Training - Epoch [151/200], Loss: 0.1387
# Beta Model Training - Epoch [152/200], Loss: 0.1398
# Beta Model Training - Epoch [153/200], Loss: 0.1390
# Beta Model Training - Epoch [154/200], Loss: 0.1402
# Beta Model Training - Epoch [155/200], Loss: 0.1390
# Beta Model Training - Epoch [156/200], Loss: 0.1390
# Beta Model Training - Epoch [157/200], Loss: 0.1376
# Beta Model Training - Epoch [158/200], Loss: 0.1385
# Beta Model Training - Epoch [159/200], Loss: 0.1374
# Beta Model Training - Epoch [160/200], Loss: 0.1398
# Beta Model Training - Epoch [161/200], Loss: 0.1391
# Beta Model Training - Epoch [162/200], Loss: 0.1395
# Beta Model Training - Epoch [163/200], Loss: 0.1371
# Beta Model Training - Epoch [164/200], Loss: 0.1362
# Beta Model Training - Epoch [165/200], Loss: 0.1371
# Beta Model Training - Epoch [166/200], Loss: 0.1379
# Beta Model Training - Epoch [167/200], Loss: 0.1369
# Beta Model Training - Epoch [168/200], Loss: 0.1357
# Beta Model Training - Epoch [169/200], Loss: 0.1402
# Beta Model Training - Epoch [170/200], Loss: 0.1416
# Beta Model Training - Epoch [171/200], Loss: 0.1378
# Beta Model Training - Epoch [172/200], Loss: 0.1380
# Beta Model Training - Epoch [173/200], Loss: 0.1386
# Beta Model Training - Epoch [174/200], Loss: 0.1376
# Beta Model Training - Epoch [175/200], Loss: 0.1360
# Beta Model Training - Epoch [176/200], Loss: 0.1361
# Beta Model Training - Epoch [177/200], Loss: 0.1367
# Beta Model Training - Epoch [178/200], Loss: 0.1363
# Beta Model Training - Epoch [179/200], Loss: 0.1372
# Beta Model Training - Epoch [180/200], Loss: 0.1365
# Beta Model Training - Epoch [181/200], Loss: 0.1376
# Beta Model Training - Epoch [182/200], Loss: 0.1373
# Beta Model Training - Epoch [183/200], Loss: 0.1345
# Beta Model Training - Epoch [184/200], Loss: 0.1343
# Beta Model Training - Epoch [185/200], Loss: 0.1349
# Beta Model Training - Epoch [186/200], Loss: 0.1352
# Beta Model Training - Epoch [187/200], Loss: 0.1358
# Beta Model Training - Epoch [188/200], Loss: 0.1366
# Beta Model Training - Epoch [189/200], Loss: 0.1347
# Beta Model Training - Epoch [190/200], Loss: 0.1348
# Beta Model Training - Epoch [191/200], Loss: 0.1361
# Beta Model Training - Epoch [192/200], Loss: 0.1333
# Beta Model Training - Epoch [193/200], Loss: 0.1345
# Beta Model Training - Epoch [194/200], Loss: 0.1349
# Beta Model Training - Epoch [195/200], Loss: 0.1348
# Beta Model Training - Epoch [196/200], Loss: 0.1335
# Beta Model Training - Epoch [197/200], Loss: 0.1358
# Beta Model Training - Epoch [198/200], Loss: 0.1347
# Beta Model Training - Epoch [199/200], Loss: 0.1385
# Beta Model Training - Epoch [200/200], Loss: 0.1398
#
# === Building dataset/model for Beta 8 ===
# Beta Model Training - Epoch [1/200], Loss: 0.7518
# Beta Model Training - Epoch [2/200], Loss: 0.6475
# Beta Model Training - Epoch [3/200], Loss: 0.5314
# Beta Model Training - Epoch [4/200], Loss: 0.4513
# Beta Model Training - Epoch [5/200], Loss: 0.3990
# Beta Model Training - Epoch [6/200], Loss: 0.3533
# Beta Model Training - Epoch [7/200], Loss: 0.3143
# Beta Model Training - Epoch [8/200], Loss: 0.2811
# Beta Model Training - Epoch [9/200], Loss: 0.2578
# Beta Model Training - Epoch [10/200], Loss: 0.2403
# Beta Model Training - Epoch [11/200], Loss: 0.2272
# Beta Model Training - Epoch [12/200], Loss: 0.2135
# Beta Model Training - Epoch [13/200], Loss: 0.2024
# Beta Model Training - Epoch [14/200], Loss: 0.1879
# Beta Model Training - Epoch [15/200], Loss: 0.1883
# Beta Model Training - Epoch [16/200], Loss: 0.1755
# Beta Model Training - Epoch [17/200], Loss: 0.1719
# Beta Model Training - Epoch [18/200], Loss: 0.1685
# Beta Model Training - Epoch [19/200], Loss: 0.1649
# Beta Model Training - Epoch [20/200], Loss: 0.1557
# Beta Model Training - Epoch [21/200], Loss: 0.1512
# Beta Model Training - Epoch [22/200], Loss: 0.1511
# Beta Model Training - Epoch [23/200], Loss: 0.1522
# Beta Model Training - Epoch [24/200], Loss: 0.1400
# Beta Model Training - Epoch [25/200], Loss: 0.1340
# Beta Model Training - Epoch [26/200], Loss: 0.1346
# Beta Model Training - Epoch [27/200], Loss: 0.1265
# Beta Model Training - Epoch [28/200], Loss: 0.1259
# Beta Model Training - Epoch [29/200], Loss: 0.1264
# Beta Model Training - Epoch [30/200], Loss: 0.1225
# Beta Model Training - Epoch [31/200], Loss: 0.1234
# Beta Model Training - Epoch [32/200], Loss: 0.1210
# Beta Model Training - Epoch [33/200], Loss: 0.1129
# Beta Model Training - Epoch [34/200], Loss: 0.1140
# Beta Model Training - Epoch [35/200], Loss: 0.1133
# Beta Model Training - Epoch [36/200], Loss: 0.1108
# Beta Model Training - Epoch [37/200], Loss: 0.1078
# Beta Model Training - Epoch [38/200], Loss: 0.1087
# Beta Model Training - Epoch [39/200], Loss: 0.1092
# Beta Model Training - Epoch [40/200], Loss: 0.0965
# Beta Model Training - Epoch [41/200], Loss: 0.0955
# Beta Model Training - Epoch [42/200], Loss: 0.0918
# Beta Model Training - Epoch [43/200], Loss: 0.0878
# Beta Model Training - Epoch [44/200], Loss: 0.0949
# Beta Model Training - Epoch [45/200], Loss: 0.0884
# Beta Model Training - Epoch [46/200], Loss: 0.0864
# Beta Model Training - Epoch [47/200], Loss: 0.0966
# Beta Model Training - Epoch [48/200], Loss: 0.0923
# Beta Model Training - Epoch [49/200], Loss: 0.0893
# Beta Model Training - Epoch [50/200], Loss: 0.0934
# Beta Model Training - Epoch [51/200], Loss: 0.0907
# Beta Model Training - Epoch [52/200], Loss: 0.0900
# Beta Model Training - Epoch [53/200], Loss: 0.0859
# Beta Model Training - Epoch [54/200], Loss: 0.0846
# Beta Model Training - Epoch [55/200], Loss: 0.0879
# Beta Model Training - Epoch [56/200], Loss: 0.0854
# Beta Model Training - Epoch [57/200], Loss: 0.0810
# Beta Model Training - Epoch [58/200], Loss: 0.0820
# Beta Model Training - Epoch [59/200], Loss: 0.0823
# Beta Model Training - Epoch [60/200], Loss: 0.0798
# Beta Model Training - Epoch [61/200], Loss: 0.0806
# Beta Model Training - Epoch [62/200], Loss: 0.0774
# Beta Model Training - Epoch [63/200], Loss: 0.0816
# Beta Model Training - Epoch [64/200], Loss: 0.0762
# Beta Model Training - Epoch [65/200], Loss: 0.0753
# Beta Model Training - Epoch [66/200], Loss: 0.0700
# Beta Model Training - Epoch [67/200], Loss: 0.0714
# Beta Model Training - Epoch [68/200], Loss: 0.0706
# Beta Model Training - Epoch [69/200], Loss: 0.0720
# Beta Model Training - Epoch [70/200], Loss: 0.0755
# Beta Model Training - Epoch [71/200], Loss: 0.0754
# Beta Model Training - Epoch [72/200], Loss: 0.0755
# Beta Model Training - Epoch [73/200], Loss: 0.0751
# Beta Model Training - Epoch [74/200], Loss: 0.0720
# Beta Model Training - Epoch [75/200], Loss: 0.0685
# Beta Model Training - Epoch [76/200], Loss: 0.0689
# Beta Model Training - Epoch [77/200], Loss: 0.0711
# Beta Model Training - Epoch [78/200], Loss: 0.0693
# Beta Model Training - Epoch [79/200], Loss: 0.0692
# Beta Model Training - Epoch [80/200], Loss: 0.0699
# Beta Model Training - Epoch [81/200], Loss: 0.0706
# Beta Model Training - Epoch [82/200], Loss: 0.0651
# Beta Model Training - Epoch [83/200], Loss: 0.0641
# Beta Model Training - Epoch [84/200], Loss: 0.0625
# Beta Model Training - Epoch [85/200], Loss: 0.0648
# Beta Model Training - Epoch [86/200], Loss: 0.0656
# Beta Model Training - Epoch [87/200], Loss: 0.0717
# Beta Model Training - Epoch [88/200], Loss: 0.0706
# Beta Model Training - Epoch [89/200], Loss: 0.0651
# Beta Model Training - Epoch [90/200], Loss: 0.0634
# Beta Model Training - Epoch [91/200], Loss: 0.0690
# Beta Model Training - Epoch [92/200], Loss: 0.0760
# Beta Model Training - Epoch [93/200], Loss: 0.0718
# Beta Model Training - Epoch [94/200], Loss: 0.0653
# Beta Model Training - Epoch [95/200], Loss: 0.0653
# Beta Model Training - Epoch [96/200], Loss: 0.0613
# Beta Model Training - Epoch [97/200], Loss: 0.0611
# Beta Model Training - Epoch [98/200], Loss: 0.0658
# Beta Model Training - Epoch [99/200], Loss: 0.0657
# Beta Model Training - Epoch [100/200], Loss: 0.0607
# Beta Model Training - Epoch [101/200], Loss: 0.0575
# Beta Model Training - Epoch [102/200], Loss: 0.0592
# Beta Model Training - Epoch [103/200], Loss: 0.0586
# Beta Model Training - Epoch [104/200], Loss: 0.0611
# Beta Model Training - Epoch [105/200], Loss: 0.0605
# Beta Model Training - Epoch [106/200], Loss: 0.0589
# Beta Model Training - Epoch [107/200], Loss: 0.0640
# Beta Model Training - Epoch [108/200], Loss: 0.0639
# Beta Model Training - Epoch [109/200], Loss: 0.0632
# Beta Model Training - Epoch [110/200], Loss: 0.0655
# Beta Model Training - Epoch [111/200], Loss: 0.0646
# Beta Model Training - Epoch [112/200], Loss: 0.0749
# Beta Model Training - Epoch [113/200], Loss: 0.0727
# Beta Model Training - Epoch [114/200], Loss: 0.0644
# Beta Model Training - Epoch [115/200], Loss: 0.0628
# Beta Model Training - Epoch [116/200], Loss: 0.0593
# Beta Model Training - Epoch [117/200], Loss: 0.0634
# Beta Model Training - Epoch [118/200], Loss: 0.0692
# Beta Model Training - Epoch [119/200], Loss: 0.0588
# Beta Model Training - Epoch [120/200], Loss: 0.0575
# Beta Model Training - Epoch [121/200], Loss: 0.0554
# Beta Model Training - Epoch [122/200], Loss: 0.0554
# Beta Model Training - Epoch [123/200], Loss: 0.0574
# Beta Model Training - Epoch [124/200], Loss: 0.0558
# Beta Model Training - Epoch [125/200], Loss: 0.0560
# Beta Model Training - Epoch [126/200], Loss: 0.0549
# Beta Model Training - Epoch [127/200], Loss: 0.0551
# Beta Model Training - Epoch [128/200], Loss: 0.0561
# Beta Model Training - Epoch [129/200], Loss: 0.0559
# Beta Model Training - Epoch [130/200], Loss: 0.0537
# Beta Model Training - Epoch [131/200], Loss: 0.0612
# Beta Model Training - Epoch [132/200], Loss: 0.0582
# Beta Model Training - Epoch [133/200], Loss: 0.0632
# Beta Model Training - Epoch [134/200], Loss: 0.0562
# Beta Model Training - Epoch [135/200], Loss: 0.0521
# Beta Model Training - Epoch [136/200], Loss: 0.0519
# Beta Model Training - Epoch [137/200], Loss: 0.0505
# Beta Model Training - Epoch [138/200], Loss: 0.0521
# Beta Model Training - Epoch [139/200], Loss: 0.0512
# Beta Model Training - Epoch [140/200], Loss: 0.0562
# Beta Model Training - Epoch [141/200], Loss: 0.0587
# Beta Model Training - Epoch [142/200], Loss: 0.0584
# Beta Model Training - Epoch [143/200], Loss: 0.0523
# Beta Model Training - Epoch [144/200], Loss: 0.0543
# Beta Model Training - Epoch [145/200], Loss: 0.0541
# Beta Model Training - Epoch [146/200], Loss: 0.0590
# Beta Model Training - Epoch [147/200], Loss: 0.0575
# Beta Model Training - Epoch [148/200], Loss: 0.0589
# Beta Model Training - Epoch [149/200], Loss: 0.0573
# Beta Model Training - Epoch [150/200], Loss: 0.0622
# Beta Model Training - Epoch [151/200], Loss: 0.0548
# Beta Model Training - Epoch [152/200], Loss: 0.0559
# Beta Model Training - Epoch [153/200], Loss: 0.0600
# Beta Model Training - Epoch [154/200], Loss: 0.0632
# Beta Model Training - Epoch [155/200], Loss: 0.0715
# Beta Model Training - Epoch [156/200], Loss: 0.0650
# Beta Model Training - Epoch [157/200], Loss: 0.0626
# Beta Model Training - Epoch [158/200], Loss: 0.0617
# Beta Model Training - Epoch [159/200], Loss: 0.0584
# Beta Model Training - Epoch [160/200], Loss: 0.0538
# Beta Model Training - Epoch [161/200], Loss: 0.0512
# Beta Model Training - Epoch [162/200], Loss: 0.0527
# Beta Model Training - Epoch [163/200], Loss: 0.0483
# Beta Model Training - Epoch [164/200], Loss: 0.0490
# Beta Model Training - Epoch [165/200], Loss: 0.0474
# Beta Model Training - Epoch [166/200], Loss: 0.0470
# Beta Model Training - Epoch [167/200], Loss: 0.0473
# Beta Model Training - Epoch [168/200], Loss: 0.0462
# Beta Model Training - Epoch [169/200], Loss: 0.0447
# Beta Model Training - Epoch [170/200], Loss: 0.0449
# Beta Model Training - Epoch [171/200], Loss: 0.0460
# Beta Model Training - Epoch [172/200], Loss: 0.0501
# Beta Model Training - Epoch [173/200], Loss: 0.0520
# Beta Model Training - Epoch [174/200], Loss: 0.0495
# Beta Model Training - Epoch [175/200], Loss: 0.0486
# Beta Model Training - Epoch [176/200], Loss: 0.0450
# Beta Model Training - Epoch [177/200], Loss: 0.0470
# Beta Model Training - Epoch [178/200], Loss: 0.0454
# Beta Model Training - Epoch [179/200], Loss: 0.0468
# Beta Model Training - Epoch [180/200], Loss: 0.0460
# Beta Model Training - Epoch [181/200], Loss: 0.0469
# Beta Model Training - Epoch [182/200], Loss: 0.0463
# Beta Model Training - Epoch [183/200], Loss: 0.0476
# Beta Model Training - Epoch [184/200], Loss: 0.0473
# Beta Model Training - Epoch [185/200], Loss: 0.0482
# Beta Model Training - Epoch [186/200], Loss: 0.0440
# Beta Model Training - Epoch [187/200], Loss: 0.0447
# Beta Model Training - Epoch [188/200], Loss: 0.0436
# Beta Model Training - Epoch [189/200], Loss: 0.0440
# Beta Model Training - Epoch [190/200], Loss: 0.0432
# Beta Model Training - Epoch [191/200], Loss: 0.0430
# Beta Model Training - Epoch [192/200], Loss: 0.0422
# Beta Model Training - Epoch [193/200], Loss: 0.0439
# Beta Model Training - Epoch [194/200], Loss: 0.0449
# Beta Model Training - Epoch [195/200], Loss: 0.0505
# Beta Model Training - Epoch [196/200], Loss: 0.0507
# Beta Model Training - Epoch [197/200], Loss: 0.0509
# Beta Model Training - Epoch [198/200], Loss: 0.0549
# Beta Model Training - Epoch [199/200], Loss: 0.0555
# Beta Model Training - Epoch [200/200], Loss: 0.0449

# %%
# save importances results
save_dir = os.path.join(curr_dir, analysis_type, 'Masking')
os.makedirs(save_dir, exist_ok=True)

save_subdir_chan = os.path.join(save_dir, 'Channel Masking')
os.makedirs(save_subdir_chan, exist_ok=True)

save_subdir_region = os.path.join(save_dir, 'Region Masking')
os.makedirs(save_subdir_region, exist_ok=True)

save_subdir_subject = os.path.join(save_dir, 'Subject Masking')
os.makedirs(save_subdir_subject, exist_ok=True)

imp_chan_zero_data = {'all_imp_chan_zero': all_imp_chan_zero}
imp_chan_drop_data = {'all_imp_chan_drop': all_imp_chan_drop}
imp_chan_mean_data = {'all_imp_chan_mean': all_imp_chan_mean}
imp_region_localmean_data = {'all_imp_region_localmean': all_imp_region_localmean}
imp_region_globalmean_data = {'all_imp_region_globalmean': all_imp_region_globalmean}

savemat(os.path.join(save_subdir_chan, 'imp_chan_zero.mat'), imp_chan_zero_data)
savemat(os.path.join(save_subdir_chan, 'imp_chan_drop.mat'), imp_chan_drop_data)
savemat(os.path.join(save_subdir_chan, 'imp_chan_mean.mat'), imp_chan_mean_data)
savemat(os.path.join(save_subdir_region, 'imp_region_localmean.mat'), imp_region_localmean_data)
savemat(os.path.join(save_subdir_region, 'imp_region_globalmean.mat'), imp_region_globalmean_data)

# %%
# Visualize importances of channel masking zero method

global_max = all_imp_chan_zero.max()
global_min = all_imp_chan_zero.min()

values = all_imp_chan_zero.mean(axis=1)  # mean across subjects
plt.figure(figsize=(16,13))
plt.imshow(values, aspect='auto', origin='lower', cmap='Reds', vmin=global_min, vmax=global_max)
plt.colorbar(label='Mean importance')
plt.xticks(ticks=np.arange(nChan), labels=np.arange(1, nChan+1))
plt.xlabel('Channel')
plt.ylabel('Beta')
plt.title(analysis_type + '_Channel Importance_zero')
plt.tight_layout()
plt.savefig(os.path.join(save_subdir_chan, analysis_type + '_Channel Importance_zero.png'))
#plt.show()
plt.close()

for iBeta in range(nBeta):
    values = all_imp_chan_zero[iBeta]
    plt.figure(figsize=(16,13))
    plt.imshow(values, aspect='auto', origin='lower', cmap='Reds', vmin=global_min, vmax=global_max)
    plt.colorbar(label='Importance')
    plt.xticks(ticks=np.arange(nChan), labels=np.arange(1, nChan+1))
    plt.xlabel('Channel')
    plt.ylabel('Subject')
    plt.title(f'Beta {iBeta}_{analysis_type}_Channel Importance_zero')
    plt.tight_layout()
    plt.savefig(os.path.join(save_subdir_chan, analysis_type + f'_Beta_{iBeta}_Channel_Importance_zero.png'))
    #plt.show()
    plt.close()

# %%
# Visualize importances of channel masking mean method

global_max = all_imp_chan_mean.max()
global_min = all_imp_chan_mean.min()

values = all_imp_chan_mean.mean(axis=1)  # mean across subjects
plt.figure(figsize=(16,13))
plt.imshow(values, aspect='auto', origin='lower', cmap='Reds', vmin=global_min, vmax=global_max)
plt.colorbar(label='Mean importance')
plt.xticks(ticks=np.arange(nChan), labels=np.arange(1, nChan+1))
plt.xlabel('Channel')
plt.ylabel('Beta')
plt.title(analysis_type + '_Channel Importance_mean')
plt.tight_layout()
plt.savefig(os.path.join(save_subdir_chan, analysis_type + '_Channel Importance_mean.png'))
#plt.show()
plt.close()

for iBeta in range(nBeta):
    values = all_imp_chan_mean[iBeta]
    plt.figure(figsize=(16,13))
    plt.imshow(values, aspect='auto', origin='lower', cmap='Reds', vmin=global_min, vmax=global_max)
    plt.colorbar(label='Importance')
    plt.xticks(ticks=np.arange(nChan), labels=np.arange(1, nChan+1))
    plt.xlabel('Channel')
    plt.ylabel('Subject')
    plt.title(f'Beta {iBeta}_{analysis_type}_Channel Importance_mean')
    plt.tight_layout()
    plt.savefig(os.path.join(save_subdir_chan, analysis_type + f'_Beta_{iBeta}_Channel_Importance_mean.png'))
    #plt.show()
    plt.close()

# %%
# Visualize importances of channel masking dropping method

global_max = all_imp_chan_drop.max()
global_min = all_imp_chan_drop.min()

values = all_imp_chan_drop.mean(axis=1)  # mean across subjects
plt.figure(figsize=(16,13))
plt.imshow(values, aspect='auto', origin='lower', cmap='Reds', vmin=global_min, vmax=global_max)
plt.colorbar(label='Mean importance')
plt.xticks(ticks=np.arange(nChan), labels=np.arange(1, nChan+1))
plt.xlabel('Channel')
plt.ylabel('Beta')
plt.title(analysis_type+'_Channel Importance_drop')
plt.tight_layout()
plt.savefig(os.path.join(save_subdir_chan, analysis_type + '_Channel Importance_drop.png'))
#plt.show()
plt.close()

for iBeta in range(nBeta):
    values = all_imp_chan_drop[iBeta]
    plt.figure(figsize=(16,13))
    plt.imshow(values, aspect='auto', origin='lower', cmap='Reds', vmin=global_min, vmax=global_max)
    plt.colorbar(label='Importance')
    plt.xticks(ticks=np.arange(nChan), labels=np.arange(1, nChan+1))
    plt.xlabel('Channel')
    plt.ylabel('Subject')
    plt.title(f'Beta {iBeta}_{analysis_type}_Channel Importance_drop')
    plt.tight_layout()
    plt.savefig(os.path.join(save_subdir_chan, analysis_type + f'_Beta_{iBeta}_Channel_Importance_drop.png'))
    #plt.show()
    plt.close()

# %%
# Visualize importances of region hard masking

global_max_local = all_imp_region_localmean.max()
global_min_local = all_imp_region_localmean.min()
global_max_global = all_imp_region_globalmean.max()
global_min_global = all_imp_region_globalmean.min()

values = all_imp_region_localmean.mean(axis=1)
plt.figure(figsize=(16,13))
plt.imshow(values, aspect='auto', origin='lower', cmap='Reds', vmin=global_min_local, vmax=global_max_local)
plt.colorbar(label='Mean importance')
plt.xticks(ticks=np.arange(nChan), labels=np.arange(1, nChan+1))
plt.xlabel('Channel')
plt.ylabel('Beta')
plt.title(analysis_type+'_Region Importance_localmean')
plt.tight_layout()
plt.savefig(os.path.join(save_subdir_region, analysis_type + '_Region Importance_localmean.png'))
#plt.show()
plt.close()

values = all_imp_region_globalmean.mean(axis=1)
plt.figure(figsize=(16,13))
plt.imshow(values, aspect='auto', origin='lower', cmap='Reds', vmin=global_min_global, vmax=global_max_global)
plt.colorbar(label='Mean importance')
plt.xticks(ticks=np.arange(nChan), labels=np.arange(1, nChan+1))
plt.xlabel('Channel')
plt.ylabel('Beta')
plt.title(analysis_type+'_Region Importance_globalmean')
plt.tight_layout()
plt.savefig(os.path.join(save_subdir_region, analysis_type + '_Region Importance_globalmean.png'))
#plt.show()
plt.close()

for iBeta in range(nBeta):
    values = all_imp_region_localmean[iBeta]
    plt.figure(figsize=(16,13))
    plt.imshow(values, aspect='auto', origin='lower', cmap='Reds', vmin=global_min_local, vmax=global_max_local)
    plt.colorbar(label='Importance')
    plt.xticks(ticks=np.arange(nChan), labels=np.arange(1, nChan+1))
    plt.xlabel('Channel')
    plt.ylabel('Subject')
    plt.title(f'Beta {iBeta}_{analysis_type}_Region Importance_localmean')
    plt.tight_layout()
    plt.savefig(os.path.join(save_subdir_region, analysis_type + f'_Beta_{iBeta}_Region_Importance_localmean.png'))
    #plt.show()
    plt.close()
    
    values = all_imp_region_globalmean[iBeta]
    plt.figure(figsize=(16,13))
    plt.imshow(values, aspect='auto', origin='lower', cmap='Reds', vmin=global_min_global, vmax=global_max_global)
    plt.colorbar(label='Importance')
    plt.xticks(ticks=np.arange(nChan), labels=np.arange(1, nChan+1))
    plt.xlabel('Channel')
    plt.ylabel('Subject')
    plt.title(f'Beta {iBeta}_{analysis_type}_Region Importance_globalmean')
    plt.tight_layout()
    plt.savefig(os.path.join(save_subdir_region, analysis_type + f'_Beta_{iBeta}_Region_Importance_globalmean.png'))
    #plt.show()
    plt.close()
