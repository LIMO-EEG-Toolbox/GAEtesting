# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset, ConcatDataset
from torch_geometric.loader import DataLoader as GeometricDataLoader
from torch_geometric.data import Data
from torch_geometric.utils import dense_to_sparse, subgraph, k_hop_subgraph
import torch_geometric.nn as pyg_nn
from scipy.io import loadmat, savemat
import os
import matplotlib.pyplot as plt

# %%
# Load saved beta data from mat file
analysis_type = 'N170'
curr_dir = os.getcwd()
datain_mat = loadmat(os.path.join(curr_dir, analysis_type + '_data.mat'))
binatry_matrix_mat = loadmat(os.path.join(curr_dir, 'adjacency_matrix.mat'))
datain = datain_mat['data']
binatry_matrix = binatry_matrix_mat['adjacency_matrix']

datain = np.array(datain)          # shape: [nBeta, nTime, nChan, nSubject] (adjust as needed)
binatry_matrix = np.array(binatry_matrix)

# Parse shapes
nBeta     = datain.shape[0]
nTime     = datain.shape[1]
nChan     = datain.shape[2]
nSubject  = datain.shape[3]

# %%
# ===========================================
# 2) Set device & convert adjacency
# ===========================================
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
edge_index, _ = dense_to_sparse(torch.tensor(binatry_matrix, dtype=torch.float32))
print(device)

# ===========================================
# 3) Dataset builder
# ===========================================
def build_concat_dataset_for_beta(datain, beta_idx):
    """
    Build a ConcatDataset across all subjects for one beta index.
    `datain` is [nBeta, nTime, nChan, nSubject].
    Returns: ConcatDataset of length nSubject.
    """
    subject_datasets = []
    for s in range(nSubject):
        # Extract slice for one subject and one beta
        # shape: [nTime, nChan]
        single_beta_data = datain[beta_idx, :, :, s]

        # If each node is a channel and its feature dimension is time,
        # we might want single_beta_data to be [nChan, nTime].
        # If so, transpose here:
        single_beta_data = single_beta_data.T  # shape: [nChan, nTime]

        # For an autoencoder, features=labels
        x_tensor = torch.tensor(single_beta_data, dtype=torch.float32)
        x_tensor = x_tensor.unsqueeze(0)

        subject_datasets.append(TensorDataset(x_tensor, x_tensor))

    return ConcatDataset(subject_datasets)
# Out:
# cuda

# %%
# ===========================================
# 4) PyG Graph Dataset
# ===========================================
class EEGGraphDataset(torch.utils.data.Dataset):
    """
    Wraps a standard dataset so that each item is a PyG Data object:
      x -> node features (channels)
      edge_index -> adjacency
    """
    def __init__(self, eeg_data, edge_index):
        self.eeg_data = eeg_data
        self.edge_index = edge_index

    def __len__(self):
        return len(self.eeg_data)

    def __getitem__(self, idx):
        # item: (x, x) because it's autoencoder
        sample = self.eeg_data[idx]
        x = sample[0]  # shape: [nChan, nTime] (if you used transpose above)
        # Convert x -> float32, build PyG Data
        graph_data = Data(x=torch.tensor(x, dtype=torch.float32),
                          edge_index=self.edge_index)
        return graph_data

# %%
# ===========================================
# 5) Define GraphAutoencoder
# ===========================================
class GraphAutoencoder(nn.Module):
    def __init__(self, num_features, embedding_dim=64):
        """
        num_features = dimension of each node's feature vector.
                       If each channel is a node, and you pass
                       [nChan, nTime], then num_features = nTime.
        """
        super(GraphAutoencoder, self).__init__()
        # Example with two ARMAConv layers
        self.encoder_gcn1 = pyg_nn.ARMAConv(num_features, 128, 
                                            num_stacks=2, 
                                            num_layers=3,
                                            shared_weights=True)
        self.encoder_gcn2 = pyg_nn.ARMAConv(128, embedding_dim, 
                                            num_stacks=2, 
                                            num_layers=3,
                                            shared_weights=True)
        self.decoder_fc1 = nn.Linear(embedding_dim, 128)
        self.decoder_fc2 = nn.Linear(128, num_features)

    def forward(self, x, edge_index):
        x = torch.relu(self.encoder_gcn1(x, edge_index))
        latent = torch.relu(self.encoder_gcn2(x, edge_index))
        x = torch.relu(self.decoder_fc1(latent))
        reconstructed = self.decoder_fc2(x)
        return reconstructed

# %%
# ===========================================
# 6) Training and evaluation
# ===========================================
def train_model_all(model, train_loader, device, num_epochs):
    model.to(device)
    optimizer = optim.Adam(model.parameters(), lr=1e-3)
    criterion = nn.SmoothL1Loss()

    for epoch in range(num_epochs):
        model.train()
        epoch_loss = 0.0
        for batch_data in train_loader:
            batch_data = batch_data.to(device)
            optimizer.zero_grad()

            # Forward
            reconstructed = model(batch_data.x, batch_data.edge_index)
            loss = criterion(reconstructed, batch_data.x)

            # Backprop
            loss.backward()
            optimizer.step()
            epoch_loss += loss.item()

        epoch_loss /= len(train_loader)
        print(f"Beta Model Training - Epoch [{epoch+1}/{num_epochs}], Loss: {epoch_loss:.4f}")
    return model

def evaluation_model(model, data_sample, edge_index, device):
    """
    data_sample: shape [nChan, nTime], or [nTime, nChan],
                 whichever you used in training.
    Returns: (original_np, reconstructed_np, error_np)
    """
    model.eval()
    with torch.no_grad():
        x = torch.tensor(data_sample, dtype=torch.float32, device=device)
        eidx = edge_index.to(device)
        reconstructed = model(x, eidx)
    orig = x.cpu().numpy()
    recon = reconstructed.cpu().numpy()
    error = orig - recon
    return orig, recon, error

# %%
# Channel Masking

# Define channel masking function with 'zero' and 'mean' methods
def channel_masking(x_n, ch_idx, mode='mean'):
    x_masked = x_n.copy()
    if mode == 'zero':
        x_masked[ch_idx, :] = 0.0
    # Mean of all other channels
    elif mode == 'mean':
        channel_mean = x_n.mean(axis=0)
        x_masked[ch_idx, :] = channel_mean
    return x_masked

# Apply channel masking and compute importance
def apply_channel_masking(model, sample_n, edge_index, device, mode='mean'):
    model.eval()
    with torch.no_grad():
        x = torch.tensor(sample_n, dtype=torch.float32, device=device)
        recon = model(x, edge_index.to(device))
        base_lose = nn.SmoothL1Loss()(recon, x).item()
        
        nChan = sample_n.shape[0]
        imp = np.zeros(nChan)
        
        # Iterate over channels to compute importance
        # The higher the loss increase, the more important the channel
        for c in range(nChan):
            x_masked = channel_masking(sample_n, c, mode=mode)
            x_masked = torch.tensor(x_masked, dtype=torch.float32, device=device)
            recon_masked = model(x_masked, edge_index.to(device))
            masked_loss = nn.SmoothL1Loss()(recon_masked, x_masked).item()
            imp[c] = abs(masked_loss - base_lose)
            
    return imp

# %%
# Channel dropping

# Define channel dropping method
def channel_dropping(model, sample_n, edge_index, device):
    model.eval()
    with torch.no_grad():
        x = torch.tensor(sample_n, dtype=torch.float32, device=device)
        recon = model(x, edge_index.to(device))
        base_loss = nn.SmoothL1Loss()(recon, x).item()

        nChan = sample_n.shape[0]
        imp = np.zeros(nChan)
        all_channels = torch.arange(nChan, device=device)
        e_idx = edge_index.to(device)
        
        for c in range(nChan):
            mask = torch.ones(nChan, dtype=torch.bool, device=device)
            mask[c] = False
            masked_channels = all_channels[mask]
            # Create subgraph with masked channels, dropping the channel c from the graph
            masked_edge_index = subgraph(masked_channels, e_idx, relabel_nodes=True)[0]
            # Drop the channel c from the data x
            masked_x = x[masked_channels, :]
            recon_masked = model(masked_x, masked_edge_index)
            masked_loss = nn.SmoothL1Loss()(recon_masked, masked_x).item()
            imp[c] = abs(masked_loss - base_loss)
            
    return imp

# %%
# Channel region hard masking

# Compute k-hop neighborhood channels for each channel
def compute_neighborhood_channels(edge_index, k=1):
    neighborhood_channels = []
    for c in range(edge_index.max().item() + 1):
        channels, _, _, _ = k_hop_subgraph(c, k, edge_index)
        neighborhood_channels.append(channels.cpu().numpy())
    return neighborhood_channels

# Define region hard masking function with 'zero' and 'mean' methods
def region_hard_masking(x_n, neig_list, mode='local_mean'):
    x_masked = x_n.copy()

    # Get the rest of the channels except the neighborhood list
    nChan = x_n.shape[0]
    mask_neig = np.zeros(nChan, dtype=bool)
    mask_neig[neig_list] = True
    mask_rest = ~mask_neig
    
    if mode == 'zero':
        x_masked[mask_neig, :] = 0.0
    # The mean of the rest of the channels
    elif mode == 'global_mean':
        if mask_rest.any():
            rest_mean = x_n[mask_rest, :].mean(axis=0)
        # If no rest channels, use overall mean
        else:
            rest_mean = x_n.mean(axis=0)
        x_masked[mask_neig, :] = rest_mean
    elif mode == 'local_mean':
        if mask_rest.any():
            local_mean = x_n[mask_neig, :].mean(axis=0)
        else:
            local_mean = x_n.mean(axis=0)
        x_masked[mask_neig, :] = local_mean
    return x_masked

# Apply region hard masking and compute importance
def apply_region_hard_masking(model, sample_n, edge_index, device, mode='mean', k=1):
    model.eval()
    with torch.no_grad():
        neighborhood_channels = compute_neighborhood_channels(edge_index, k)
        x = torch.tensor(sample_n, dtype=torch.float32, device=device)
        recon = model(x, edge_index.to(device))
        base_loss = nn.SmoothL1Loss()(recon, x).item()

        nChan = sample_n.shape[0]
        imp = np.zeros(nChan)
        
        for c in range(nChan):
            neig_list = neighborhood_channels[c]
            x_masked = region_hard_masking(sample_n, neig_list, mode=mode)
            x_masked = torch.tensor(x_masked, dtype=torch.float32, device=device)
            recon_masked = model(x_masked, edge_index.to(device))
            masked_loss = nn.SmoothL1Loss()(recon_masked, x_masked).item()
            imp[c] = abs(masked_loss - base_loss)
    return imp

# %%
neighborhood_channels = compute_neighborhood_channels(edge_index, k=1)
for i in range(len(neighborhood_channels)):
    nbrs = [int(x) + 1 for x in neighborhood_channels[i]]
    print(f"Channel {i+1}: Neighbors {nbrs}")
# Out:
# Channel 1: Neighbors [1, 2, 3, 16, 17]
# Channel 2: Neighbors [1, 2, 3, 4, 17, 21]
# Channel 3: Neighbors [1, 2, 3, 4, 6]
# Channel 4: Neighbors [2, 3, 4, 5, 6, 17, 21, 22]
# Channel 5: Neighbors [4, 5, 6, 7, 8, 15, 21, 22]
# Channel 6: Neighbors [3, 4, 5, 6, 7, 8, 9]
# Channel 7: Neighbors [5, 6, 7, 8, 10, 11, 14, 15]
# Channel 8: Neighbors [5, 6, 7, 8, 9, 10, 11]
# Channel 9: Neighbors [6, 8, 9, 10, 12]
# Channel 10: Neighbors [7, 8, 9, 10, 11, 12]
# Channel 11: Neighbors [7, 8, 10, 11, 12, 13, 14, 15, 29]
# Channel 12: Neighbors [9, 10, 11, 12, 13]
# Channel 13: Neighbors [11, 12, 13, 14, 29, 30]
# Channel 14: Neighbors [7, 11, 13, 14, 15, 25, 29]
# Channel 15: Neighbors [5, 7, 11, 14, 15, 22, 23, 25, 29]
# Channel 16: Neighbors [1, 16, 17, 18, 19]
# Channel 17: Neighbors [1, 2, 4, 16, 17, 18, 20, 21]
# Channel 18: Neighbors [16, 17, 18, 19, 20, 21]
# Channel 19: Neighbors [16, 18, 19, 20, 24]
# Channel 20: Neighbors [17, 18, 19, 20, 21, 22, 23, 24]
# Channel 21: Neighbors [2, 4, 5, 17, 18, 20, 21, 22, 23]
# Channel 22: Neighbors [4, 5, 15, 20, 21, 22, 23]
# Channel 23: Neighbors [15, 20, 21, 22, 23, 24, 25, 26]
# Channel 24: Neighbors [19, 20, 23, 24, 25, 26, 27]
# Channel 25: Neighbors [14, 15, 23, 24, 25, 26, 28, 29]
# Channel 26: Neighbors [23, 24, 25, 26, 27, 28, 29]
# Channel 27: Neighbors [24, 26, 27, 28, 30]
# Channel 28: Neighbors [25, 26, 27, 28, 29, 30]
# Channel 29: Neighbors [11, 13, 14, 15, 25, 26, 28, 29, 30]
# Channel 30: Neighbors [13, 27, 28, 29, 30]

# %%
# Subject masking  -- need to change
def apply_subject_masking(model, full_dataset_i, edge_index, device, mode='zero'):
    model.eval()
    with torch.no_grad():
        nSubjects = len(full_dataset_i)
        imp = np.zeros(nSubjects)
        
        x_list = []
        for s in range(nSubjects):
            x_list.append(full_dataset_i[s][0].numpy())
        # Shape: [nSubject, nChan, nTime]
        x_all = np.stack(x_list, axis=0)
        x_sum = x_all.sum(axis=0)
        
        for s in range(nSubjects):
            x_s =  x_list[s]
            x_s = torch.tensor(x_s, dtype=torch.float32, device=device)
            recon = model(x_s, edge_index.to(device))
            base_loss = nn.SmoothL1Loss()(recon, x_s).item()
            
            if mode == 'zero':
                x_masked = x_s.cpu().numpy()
                x_masked[:, :] = 0.0
            x_masked = torch.tensor(x_masked, dtype=torch.float32, device=device)
            recon_masked = model(x_masked, edge_index.to(device))
            mask_loss = nn.SmoothL1Loss()(recon_masked, x_masked).item()
            imp[s] = abs(mask_loss - base_loss)
    return imp

# %%
# Time period masking

# %%
num_features = nTime   # if each channel is a node, and feature vector = [nTime]
num_epochs   = 200     # number of training - set as needed
batch_size   = 4;      # dataset/batch to update hyperparameters

models = []

imp_chan_zero_list = []
imp_chan_drop_list = []
imp_chan_mean_list = []
imp_region_localmean_list = []
imp_region_globalmean_list = []
imp_subject_zero_list = []
for iBeta in range(nBeta):
    print(f"\n=== Building dataset/model for Beta {iBeta} ===")
    # Build dataset & loader
    full_dataset_i  = build_concat_dataset_for_beta(datain, iBeta)
    graph_dataset_i = EEGGraphDataset(full_dataset_i, edge_index)
    full_loader_i   = GeometricDataLoader(graph_dataset_i, batch_size=batch_size, shuffle=True)

    # Init model & train
    model_i = GraphAutoencoder(num_features=num_features, embedding_dim=32)
    model_i = train_model_all(model_i, full_loader_i, device, num_epochs=num_epochs)
    models.append(model_i)
    
    imp_subject_zero = apply_subject_masking(model_i, full_dataset_i, edge_index, device, mode='zero')
    imp_subject_zero_list.append(np.array(imp_subject_zero))


    imp_chan_zero_per_subject = []
    imp_chan_drop_per_subject = []
    imp_chan_mean_per_subject = []
    imp_region_localmean_per_subject = []
    imp_region_globalmean_per_subject = []
    for s in range(len(full_dataset_i)):
        x_s = full_dataset_i[s][0].numpy()  # [nChan, nTime]
        imp_chan_zero = apply_channel_masking(model_i, x_s, edge_index, device, mode='zero')
        imp_chan_mean = apply_channel_masking(model_i, x_s, edge_index, device, mode='mean')
        imp_chan_drop = channel_dropping(model_i, x_s, edge_index, device)
        imp_region_localmean = apply_region_hard_masking(model_i, x_s, edge_index, device, mode='local_mean', k=1)
        imp_region_globalmean = apply_region_hard_masking(model_i, x_s, edge_index, device, mode='global_mean', k=1)
        imp_chan_zero_per_subject.append(imp_chan_zero)
        imp_chan_drop_per_subject.append(imp_chan_drop)
        imp_chan_mean_per_subject.append(imp_chan_mean)
        imp_region_localmean_per_subject.append(imp_region_localmean)
        imp_region_globalmean_per_subject.append(imp_region_globalmean)

    imp_chan_zero_list.append(np.array(imp_chan_zero_per_subject))
    imp_chan_drop_list.append(np.array(imp_chan_drop_per_subject))
    imp_chan_mean_list.append(np.array(imp_chan_mean_per_subject))
    imp_region_localmean_list.append(np.array(imp_region_localmean_per_subject))
    imp_region_globalmean_list.append(np.array(imp_region_globalmean_per_subject))

all_imp_chan_zero = np.array(imp_chan_zero_list)
all_imp_chan_drop = np.array(imp_chan_drop_list)
all_imp_chan_mean = np.array(imp_chan_mean_list)
all_imp_region_localmean = np.array(imp_region_localmean_list)
all_imp_region_globalmean = np.array(imp_region_globalmean_list)
all_imp_subject_zero = np.array(imp_subject_zero_list)
# Out:
# === Building dataset/model for Beta 0 ===
# Beta Model Training - Epoch [1/200], Loss: 0.7659
# Beta Model Training - Epoch [2/200], Loss: 0.5875
# C:\Users\86136\AppData\Local\Temp\ipykernel_20832\1382389434.py:22: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   graph_data = Data(x=torch.tensor(x, dtype=torch.float32),
# Beta Model Training - Epoch [3/200], Loss: 0.4381
# Beta Model Training - Epoch [4/200], Loss: 0.3742
# Beta Model Training - Epoch [5/200], Loss: 0.3354
# Beta Model Training - Epoch [6/200], Loss: 0.3123
# Beta Model Training - Epoch [7/200], Loss: 0.2962
# Beta Model Training - Epoch [8/200], Loss: 0.2818
# Beta Model Training - Epoch [9/200], Loss: 0.2615
# Beta Model Training - Epoch [10/200], Loss: 0.2448
# Beta Model Training - Epoch [11/200], Loss: 0.2377
# Beta Model Training - Epoch [12/200], Loss: 0.2273
# Beta Model Training - Epoch [13/200], Loss: 0.2119
# Beta Model Training - Epoch [14/200], Loss: 0.1982
# Beta Model Training - Epoch [15/200], Loss: 0.1883
# Beta Model Training - Epoch [16/200], Loss: 0.1789
# Beta Model Training - Epoch [17/200], Loss: 0.1725
# Beta Model Training - Epoch [18/200], Loss: 0.1659
# Beta Model Training - Epoch [19/200], Loss: 0.1629
# Beta Model Training - Epoch [20/200], Loss: 0.1603
# Beta Model Training - Epoch [21/200], Loss: 0.1555
# Beta Model Training - Epoch [22/200], Loss: 0.1503
# Beta Model Training - Epoch [23/200], Loss: 0.1468
# Beta Model Training - Epoch [24/200], Loss: 0.1455
# Beta Model Training - Epoch [25/200], Loss: 0.1401
# Beta Model Training - Epoch [26/200], Loss: 0.1333
# Beta Model Training - Epoch [27/200], Loss: 0.1317
# Beta Model Training - Epoch [28/200], Loss: 0.1280
# Beta Model Training - Epoch [29/200], Loss: 0.1243
# Beta Model Training - Epoch [30/200], Loss: 0.1198
# Beta Model Training - Epoch [31/200], Loss: 0.1193
# Beta Model Training - Epoch [32/200], Loss: 0.1177
# Beta Model Training - Epoch [33/200], Loss: 0.1193
# Beta Model Training - Epoch [34/200], Loss: 0.1317
# Beta Model Training - Epoch [35/200], Loss: 0.1189
# Beta Model Training - Epoch [36/200], Loss: 0.1139
# Beta Model Training - Epoch [37/200], Loss: 0.1130
# Beta Model Training - Epoch [38/200], Loss: 0.1083
# Beta Model Training - Epoch [39/200], Loss: 0.1062
# Beta Model Training - Epoch [40/200], Loss: 0.1013
# Beta Model Training - Epoch [41/200], Loss: 0.0991
# Beta Model Training - Epoch [42/200], Loss: 0.0978
# Beta Model Training - Epoch [43/200], Loss: 0.0945
# Beta Model Training - Epoch [44/200], Loss: 0.0927
# Beta Model Training - Epoch [45/200], Loss: 0.0917
# Beta Model Training - Epoch [46/200], Loss: 0.0904
# Beta Model Training - Epoch [47/200], Loss: 0.0893
# Beta Model Training - Epoch [48/200], Loss: 0.0876
# Beta Model Training - Epoch [49/200], Loss: 0.0869
# Beta Model Training - Epoch [50/200], Loss: 0.0877
# Beta Model Training - Epoch [51/200], Loss: 0.0855
# Beta Model Training - Epoch [52/200], Loss: 0.0852
# Beta Model Training - Epoch [53/200], Loss: 0.0854
# Beta Model Training - Epoch [54/200], Loss: 0.0832
# Beta Model Training - Epoch [55/200], Loss: 0.0827
# Beta Model Training - Epoch [56/200], Loss: 0.0810
# Beta Model Training - Epoch [57/200], Loss: 0.0788
# Beta Model Training - Epoch [58/200], Loss: 0.0775
# Beta Model Training - Epoch [59/200], Loss: 0.0801
# Beta Model Training - Epoch [60/200], Loss: 0.0801
# Beta Model Training - Epoch [61/200], Loss: 0.0793
# Beta Model Training - Epoch [62/200], Loss: 0.0790
# Beta Model Training - Epoch [63/200], Loss: 0.0760
# Beta Model Training - Epoch [64/200], Loss: 0.0762
# Beta Model Training - Epoch [65/200], Loss: 0.0758
# Beta Model Training - Epoch [66/200], Loss: 0.0772
# Beta Model Training - Epoch [67/200], Loss: 0.0744
# Beta Model Training - Epoch [68/200], Loss: 0.0734
# Beta Model Training - Epoch [69/200], Loss: 0.0713
# Beta Model Training - Epoch [70/200], Loss: 0.0712
# Beta Model Training - Epoch [71/200], Loss: 0.0708
# Beta Model Training - Epoch [72/200], Loss: 0.0704
# Beta Model Training - Epoch [73/200], Loss: 0.0705
# Beta Model Training - Epoch [74/200], Loss: 0.0698
# Beta Model Training - Epoch [75/200], Loss: 0.0705
# Beta Model Training - Epoch [76/200], Loss: 0.0698
# Beta Model Training - Epoch [77/200], Loss: 0.0716
# Beta Model Training - Epoch [78/200], Loss: 0.0685
# Beta Model Training - Epoch [79/200], Loss: 0.0682
# Beta Model Training - Epoch [80/200], Loss: 0.0695
# Beta Model Training - Epoch [81/200], Loss: 0.0674
# Beta Model Training - Epoch [82/200], Loss: 0.0670
# Beta Model Training - Epoch [83/200], Loss: 0.0670
# Beta Model Training - Epoch [84/200], Loss: 0.0706
# Beta Model Training - Epoch [85/200], Loss: 0.0769
# Beta Model Training - Epoch [86/200], Loss: 0.0737
# Beta Model Training - Epoch [87/200], Loss: 0.0753
# Beta Model Training - Epoch [88/200], Loss: 0.0725
# Beta Model Training - Epoch [89/200], Loss: 0.0720
# Beta Model Training - Epoch [90/200], Loss: 0.0707
# Beta Model Training - Epoch [91/200], Loss: 0.0687
# Beta Model Training - Epoch [92/200], Loss: 0.0672
# Beta Model Training - Epoch [93/200], Loss: 0.0651
# Beta Model Training - Epoch [94/200], Loss: 0.0640
# Beta Model Training - Epoch [95/200], Loss: 0.0638
# Beta Model Training - Epoch [96/200], Loss: 0.0634
# Beta Model Training - Epoch [97/200], Loss: 0.0634
# Beta Model Training - Epoch [98/200], Loss: 0.0650
# Beta Model Training - Epoch [99/200], Loss: 0.0663
# Beta Model Training - Epoch [100/200], Loss: 0.0690
# Beta Model Training - Epoch [101/200], Loss: 0.0648
# Beta Model Training - Epoch [102/200], Loss: 0.0631
# Beta Model Training - Epoch [103/200], Loss: 0.0610
# Beta Model Training - Epoch [104/200], Loss: 0.0613
# Beta Model Training - Epoch [105/200], Loss: 0.0618
# Beta Model Training - Epoch [106/200], Loss: 0.0640
# Beta Model Training - Epoch [107/200], Loss: 0.0613
# Beta Model Training - Epoch [108/200], Loss: 0.0611
# Beta Model Training - Epoch [109/200], Loss: 0.0602
# Beta Model Training - Epoch [110/200], Loss: 0.0618
# Beta Model Training - Epoch [111/200], Loss: 0.0614
# Beta Model Training - Epoch [112/200], Loss: 0.0669
# Beta Model Training - Epoch [113/200], Loss: 0.0657
# Beta Model Training - Epoch [114/200], Loss: 0.0638
# Beta Model Training - Epoch [115/200], Loss: 0.0615
# Beta Model Training - Epoch [116/200], Loss: 0.0598
# Beta Model Training - Epoch [117/200], Loss: 0.0600
# Beta Model Training - Epoch [118/200], Loss: 0.0590
# Beta Model Training - Epoch [119/200], Loss: 0.0584
# Beta Model Training - Epoch [120/200], Loss: 0.0582
# Beta Model Training - Epoch [121/200], Loss: 0.0575
# Beta Model Training - Epoch [122/200], Loss: 0.0571
# Beta Model Training - Epoch [123/200], Loss: 0.0570
# Beta Model Training - Epoch [124/200], Loss: 0.0571
# Beta Model Training - Epoch [125/200], Loss: 0.0568
# Beta Model Training - Epoch [126/200], Loss: 0.0563
# Beta Model Training - Epoch [127/200], Loss: 0.0566
# Beta Model Training - Epoch [128/200], Loss: 0.0559
# Beta Model Training - Epoch [129/200], Loss: 0.0558
# Beta Model Training - Epoch [130/200], Loss: 0.0560
# Beta Model Training - Epoch [131/200], Loss: 0.0555
# Beta Model Training - Epoch [132/200], Loss: 0.0551
# Beta Model Training - Epoch [133/200], Loss: 0.0571
# Beta Model Training - Epoch [134/200], Loss: 0.0566
# Beta Model Training - Epoch [135/200], Loss: 0.0551
# Beta Model Training - Epoch [136/200], Loss: 0.0550
# Beta Model Training - Epoch [137/200], Loss: 0.0549
# Beta Model Training - Epoch [138/200], Loss: 0.0551
# Beta Model Training - Epoch [139/200], Loss: 0.0541
# Beta Model Training - Epoch [140/200], Loss: 0.0542
# Beta Model Training - Epoch [141/200], Loss: 0.0545
# Beta Model Training - Epoch [142/200], Loss: 0.0550
# Beta Model Training - Epoch [143/200], Loss: 0.0539
# Beta Model Training - Epoch [144/200], Loss: 0.0538
# Beta Model Training - Epoch [145/200], Loss: 0.0539
# Beta Model Training - Epoch [146/200], Loss: 0.0539
# Beta Model Training - Epoch [147/200], Loss: 0.0537
# Beta Model Training - Epoch [148/200], Loss: 0.0528
# Beta Model Training - Epoch [149/200], Loss: 0.0528
# Beta Model Training - Epoch [150/200], Loss: 0.0528
# Beta Model Training - Epoch [151/200], Loss: 0.0527
# Beta Model Training - Epoch [152/200], Loss: 0.0521
# Beta Model Training - Epoch [153/200], Loss: 0.0540
# Beta Model Training - Epoch [154/200], Loss: 0.0523
# Beta Model Training - Epoch [155/200], Loss: 0.0526
# Beta Model Training - Epoch [156/200], Loss: 0.0528
# Beta Model Training - Epoch [157/200], Loss: 0.0524
# Beta Model Training - Epoch [158/200], Loss: 0.0523
# Beta Model Training - Epoch [159/200], Loss: 0.0523
# Beta Model Training - Epoch [160/200], Loss: 0.0520
# Beta Model Training - Epoch [161/200], Loss: 0.0519
# Beta Model Training - Epoch [162/200], Loss: 0.0517
# Beta Model Training - Epoch [163/200], Loss: 0.0523
# Beta Model Training - Epoch [164/200], Loss: 0.0519
# Beta Model Training - Epoch [165/200], Loss: 0.0520
# Beta Model Training - Epoch [166/200], Loss: 0.0526
# Beta Model Training - Epoch [167/200], Loss: 0.0525
# Beta Model Training - Epoch [168/200], Loss: 0.0530
# Beta Model Training - Epoch [169/200], Loss: 0.0546
# Beta Model Training - Epoch [170/200], Loss: 0.0553
# Beta Model Training - Epoch [171/200], Loss: 0.0552
# Beta Model Training - Epoch [172/200], Loss: 0.0581
# Beta Model Training - Epoch [173/200], Loss: 0.0595
# Beta Model Training - Epoch [174/200], Loss: 0.0647
# Beta Model Training - Epoch [175/200], Loss: 0.0616
# Beta Model Training - Epoch [176/200], Loss: 0.0556
# Beta Model Training - Epoch [177/200], Loss: 0.0557
# Beta Model Training - Epoch [178/200], Loss: 0.0532
# Beta Model Training - Epoch [179/200], Loss: 0.0527
# Beta Model Training - Epoch [180/200], Loss: 0.0531
# Beta Model Training - Epoch [181/200], Loss: 0.0514
# Beta Model Training - Epoch [182/200], Loss: 0.0521
# Beta Model Training - Epoch [183/200], Loss: 0.0528
# Beta Model Training - Epoch [184/200], Loss: 0.0523
# Beta Model Training - Epoch [185/200], Loss: 0.0506
# Beta Model Training - Epoch [186/200], Loss: 0.0505
# Beta Model Training - Epoch [187/200], Loss: 0.0500
# Beta Model Training - Epoch [188/200], Loss: 0.0501
# Beta Model Training - Epoch [189/200], Loss: 0.0492
# Beta Model Training - Epoch [190/200], Loss: 0.0485
# Beta Model Training - Epoch [191/200], Loss: 0.0487
# Beta Model Training - Epoch [192/200], Loss: 0.0502
# Beta Model Training - Epoch [193/200], Loss: 0.0502
# Beta Model Training - Epoch [194/200], Loss: 0.0499
# Beta Model Training - Epoch [195/200], Loss: 0.0511
# Beta Model Training - Epoch [196/200], Loss: 0.0518
# Beta Model Training - Epoch [197/200], Loss: 0.0520
# Beta Model Training - Epoch [198/200], Loss: 0.0521
# Beta Model Training - Epoch [199/200], Loss: 0.0519
# Beta Model Training - Epoch [200/200], Loss: 0.0506
#
# === Building dataset/model for Beta 1 ===
# Beta Model Training - Epoch [1/200], Loss: 0.7447
# Beta Model Training - Epoch [2/200], Loss: 0.6318
# Beta Model Training - Epoch [3/200], Loss: 0.4910
# Beta Model Training - Epoch [4/200], Loss: 0.4116
# Beta Model Training - Epoch [5/200], Loss: 0.3719
# Beta Model Training - Epoch [6/200], Loss: 0.3490
# Beta Model Training - Epoch [7/200], Loss: 0.3231
# Beta Model Training - Epoch [8/200], Loss: 0.2998
# Beta Model Training - Epoch [9/200], Loss: 0.2771
# Beta Model Training - Epoch [10/200], Loss: 0.2617
# Beta Model Training - Epoch [11/200], Loss: 0.2425
# Beta Model Training - Epoch [12/200], Loss: 0.2318
# Beta Model Training - Epoch [13/200], Loss: 0.2214
# Beta Model Training - Epoch [14/200], Loss: 0.2111
# Beta Model Training - Epoch [15/200], Loss: 0.2005
# Beta Model Training - Epoch [16/200], Loss: 0.1938
# Beta Model Training - Epoch [17/200], Loss: 0.1837
# Beta Model Training - Epoch [18/200], Loss: 0.1766
# Beta Model Training - Epoch [19/200], Loss: 0.1720
# Beta Model Training - Epoch [20/200], Loss: 0.1672
# Beta Model Training - Epoch [21/200], Loss: 0.1611
# Beta Model Training - Epoch [22/200], Loss: 0.1582
# Beta Model Training - Epoch [23/200], Loss: 0.1523
# Beta Model Training - Epoch [24/200], Loss: 0.1484
# Beta Model Training - Epoch [25/200], Loss: 0.1436
# Beta Model Training - Epoch [26/200], Loss: 0.1413
# Beta Model Training - Epoch [27/200], Loss: 0.1372
# Beta Model Training - Epoch [28/200], Loss: 0.1330
# Beta Model Training - Epoch [29/200], Loss: 0.1300
# Beta Model Training - Epoch [30/200], Loss: 0.1269
# Beta Model Training - Epoch [31/200], Loss: 0.1221
# Beta Model Training - Epoch [32/200], Loss: 0.1243
# Beta Model Training - Epoch [33/200], Loss: 0.1167
# Beta Model Training - Epoch [34/200], Loss: 0.1140
# Beta Model Training - Epoch [35/200], Loss: 0.1088
# Beta Model Training - Epoch [36/200], Loss: 0.1075
# Beta Model Training - Epoch [37/200], Loss: 0.1053
# Beta Model Training - Epoch [38/200], Loss: 0.1047
# Beta Model Training - Epoch [39/200], Loss: 0.1021
# Beta Model Training - Epoch [40/200], Loss: 0.1011
# Beta Model Training - Epoch [41/200], Loss: 0.0993
# Beta Model Training - Epoch [42/200], Loss: 0.0961
# Beta Model Training - Epoch [43/200], Loss: 0.0946
# Beta Model Training - Epoch [44/200], Loss: 0.0925
# Beta Model Training - Epoch [45/200], Loss: 0.0924
# Beta Model Training - Epoch [46/200], Loss: 0.0898
# Beta Model Training - Epoch [47/200], Loss: 0.0881
# Beta Model Training - Epoch [48/200], Loss: 0.0880
# Beta Model Training - Epoch [49/200], Loss: 0.0895
# Beta Model Training - Epoch [50/200], Loss: 0.0868
# Beta Model Training - Epoch [51/200], Loss: 0.0880
# Beta Model Training - Epoch [52/200], Loss: 0.0848
# Beta Model Training - Epoch [53/200], Loss: 0.0843
# Beta Model Training - Epoch [54/200], Loss: 0.0817
# Beta Model Training - Epoch [55/200], Loss: 0.0819
# Beta Model Training - Epoch [56/200], Loss: 0.0801
# Beta Model Training - Epoch [57/200], Loss: 0.0813
# Beta Model Training - Epoch [58/200], Loss: 0.0785
# Beta Model Training - Epoch [59/200], Loss: 0.0777
# Beta Model Training - Epoch [60/200], Loss: 0.0771
# Beta Model Training - Epoch [61/200], Loss: 0.0777
# Beta Model Training - Epoch [62/200], Loss: 0.0791
# Beta Model Training - Epoch [63/200], Loss: 0.0794
# Beta Model Training - Epoch [64/200], Loss: 0.0794
# Beta Model Training - Epoch [65/200], Loss: 0.0764
# Beta Model Training - Epoch [66/200], Loss: 0.0762
# Beta Model Training - Epoch [67/200], Loss: 0.0760
# Beta Model Training - Epoch [68/200], Loss: 0.0749
# Beta Model Training - Epoch [69/200], Loss: 0.0734
# Beta Model Training - Epoch [70/200], Loss: 0.0724
# Beta Model Training - Epoch [71/200], Loss: 0.0744
# Beta Model Training - Epoch [72/200], Loss: 0.0757
# Beta Model Training - Epoch [73/200], Loss: 0.0756
# Beta Model Training - Epoch [74/200], Loss: 0.0741
# Beta Model Training - Epoch [75/200], Loss: 0.0740
# Beta Model Training - Epoch [76/200], Loss: 0.0722
# Beta Model Training - Epoch [77/200], Loss: 0.0706
# Beta Model Training - Epoch [78/200], Loss: 0.0697
# Beta Model Training - Epoch [79/200], Loss: 0.0685
# Beta Model Training - Epoch [80/200], Loss: 0.0674
# Beta Model Training - Epoch [81/200], Loss: 0.0670
# Beta Model Training - Epoch [82/200], Loss: 0.0668
# Beta Model Training - Epoch [83/200], Loss: 0.0694
# Beta Model Training - Epoch [84/200], Loss: 0.0704
# Beta Model Training - Epoch [85/200], Loss: 0.0684
# Beta Model Training - Epoch [86/200], Loss: 0.0668
# Beta Model Training - Epoch [87/200], Loss: 0.0690
# Beta Model Training - Epoch [88/200], Loss: 0.0677
# Beta Model Training - Epoch [89/200], Loss: 0.0661
# Beta Model Training - Epoch [90/200], Loss: 0.0661
# Beta Model Training - Epoch [91/200], Loss: 0.0690
# Beta Model Training - Epoch [92/200], Loss: 0.0672
# Beta Model Training - Epoch [93/200], Loss: 0.0646
# Beta Model Training - Epoch [94/200], Loss: 0.0671
# Beta Model Training - Epoch [95/200], Loss: 0.0685
# Beta Model Training - Epoch [96/200], Loss: 0.0695
# Beta Model Training - Epoch [97/200], Loss: 0.0678
# Beta Model Training - Epoch [98/200], Loss: 0.0648
# Beta Model Training - Epoch [99/200], Loss: 0.0641
# Beta Model Training - Epoch [100/200], Loss: 0.0659
# Beta Model Training - Epoch [101/200], Loss: 0.0663
# Beta Model Training - Epoch [102/200], Loss: 0.0648
# Beta Model Training - Epoch [103/200], Loss: 0.0652
# Beta Model Training - Epoch [104/200], Loss: 0.0630
# Beta Model Training - Epoch [105/200], Loss: 0.0626
# Beta Model Training - Epoch [106/200], Loss: 0.0615
# Beta Model Training - Epoch [107/200], Loss: 0.0624
# Beta Model Training - Epoch [108/200], Loss: 0.0604
# Beta Model Training - Epoch [109/200], Loss: 0.0597
# Beta Model Training - Epoch [110/200], Loss: 0.0599
# Beta Model Training - Epoch [111/200], Loss: 0.0594
# Beta Model Training - Epoch [112/200], Loss: 0.0592
# Beta Model Training - Epoch [113/200], Loss: 0.0592
# Beta Model Training - Epoch [114/200], Loss: 0.0579
# Beta Model Training - Epoch [115/200], Loss: 0.0584
# Beta Model Training - Epoch [116/200], Loss: 0.0574
# Beta Model Training - Epoch [117/200], Loss: 0.0569
# Beta Model Training - Epoch [118/200], Loss: 0.0576
# Beta Model Training - Epoch [119/200], Loss: 0.0575
# Beta Model Training - Epoch [120/200], Loss: 0.0571
# Beta Model Training - Epoch [121/200], Loss: 0.0572
# Beta Model Training - Epoch [122/200], Loss: 0.0568
# Beta Model Training - Epoch [123/200], Loss: 0.0569
# Beta Model Training - Epoch [124/200], Loss: 0.0576
# Beta Model Training - Epoch [125/200], Loss: 0.0574
# Beta Model Training - Epoch [126/200], Loss: 0.0569
# Beta Model Training - Epoch [127/200], Loss: 0.0569
# Beta Model Training - Epoch [128/200], Loss: 0.0568
# Beta Model Training - Epoch [129/200], Loss: 0.0564
# Beta Model Training - Epoch [130/200], Loss: 0.0578
# Beta Model Training - Epoch [131/200], Loss: 0.0610
# Beta Model Training - Epoch [132/200], Loss: 0.0623
# Beta Model Training - Epoch [133/200], Loss: 0.0603
# Beta Model Training - Epoch [134/200], Loss: 0.0605
# Beta Model Training - Epoch [135/200], Loss: 0.0610
# Beta Model Training - Epoch [136/200], Loss: 0.0609
# Beta Model Training - Epoch [137/200], Loss: 0.0593
# Beta Model Training - Epoch [138/200], Loss: 0.0584
# Beta Model Training - Epoch [139/200], Loss: 0.0565
# Beta Model Training - Epoch [140/200], Loss: 0.0560
# Beta Model Training - Epoch [141/200], Loss: 0.0565
# Beta Model Training - Epoch [142/200], Loss: 0.0566
# Beta Model Training - Epoch [143/200], Loss: 0.0574
# Beta Model Training - Epoch [144/200], Loss: 0.0565
# Beta Model Training - Epoch [145/200], Loss: 0.0559
# Beta Model Training - Epoch [146/200], Loss: 0.0554
# Beta Model Training - Epoch [147/200], Loss: 0.0544
# Beta Model Training - Epoch [148/200], Loss: 0.0539
# Beta Model Training - Epoch [149/200], Loss: 0.0532
# Beta Model Training - Epoch [150/200], Loss: 0.0545
# Beta Model Training - Epoch [151/200], Loss: 0.0535
# Beta Model Training - Epoch [152/200], Loss: 0.0529
# Beta Model Training - Epoch [153/200], Loss: 0.0525
# Beta Model Training - Epoch [154/200], Loss: 0.0528
# Beta Model Training - Epoch [155/200], Loss: 0.0527
# Beta Model Training - Epoch [156/200], Loss: 0.0512
# Beta Model Training - Epoch [157/200], Loss: 0.0528
# Beta Model Training - Epoch [158/200], Loss: 0.0518
# Beta Model Training - Epoch [159/200], Loss: 0.0509
# Beta Model Training - Epoch [160/200], Loss: 0.0527
# Beta Model Training - Epoch [161/200], Loss: 0.0518
# Beta Model Training - Epoch [162/200], Loss: 0.0563
# Beta Model Training - Epoch [163/200], Loss: 0.0599
# Beta Model Training - Epoch [164/200], Loss: 0.0575
# Beta Model Training - Epoch [165/200], Loss: 0.0545
# Beta Model Training - Epoch [166/200], Loss: 0.0567
# Beta Model Training - Epoch [167/200], Loss: 0.0545
# Beta Model Training - Epoch [168/200], Loss: 0.0529
# Beta Model Training - Epoch [169/200], Loss: 0.0526
# Beta Model Training - Epoch [170/200], Loss: 0.0512
# Beta Model Training - Epoch [171/200], Loss: 0.0508
# Beta Model Training - Epoch [172/200], Loss: 0.0512
# Beta Model Training - Epoch [173/200], Loss: 0.0504
# Beta Model Training - Epoch [174/200], Loss: 0.0496
# Beta Model Training - Epoch [175/200], Loss: 0.0492
# Beta Model Training - Epoch [176/200], Loss: 0.0493
# Beta Model Training - Epoch [177/200], Loss: 0.0488
# Beta Model Training - Epoch [178/200], Loss: 0.0487
# Beta Model Training - Epoch [179/200], Loss: 0.0496
# Beta Model Training - Epoch [180/200], Loss: 0.0502
# Beta Model Training - Epoch [181/200], Loss: 0.0503
# Beta Model Training - Epoch [182/200], Loss: 0.0509
# Beta Model Training - Epoch [183/200], Loss: 0.0504
# Beta Model Training - Epoch [184/200], Loss: 0.0511
# Beta Model Training - Epoch [185/200], Loss: 0.0501
# Beta Model Training - Epoch [186/200], Loss: 0.0518
# Beta Model Training - Epoch [187/200], Loss: 0.0504
# Beta Model Training - Epoch [188/200], Loss: 0.0509
# Beta Model Training - Epoch [189/200], Loss: 0.0501
# Beta Model Training - Epoch [190/200], Loss: 0.0506
# Beta Model Training - Epoch [191/200], Loss: 0.0515
# Beta Model Training - Epoch [192/200], Loss: 0.0514
# Beta Model Training - Epoch [193/200], Loss: 0.0493
# Beta Model Training - Epoch [194/200], Loss: 0.0483
# Beta Model Training - Epoch [195/200], Loss: 0.0487
# Beta Model Training - Epoch [196/200], Loss: 0.0492
# Beta Model Training - Epoch [197/200], Loss: 0.0488
# Beta Model Training - Epoch [198/200], Loss: 0.0484
# Beta Model Training - Epoch [199/200], Loss: 0.0480
# Beta Model Training - Epoch [200/200], Loss: 0.0491
#
# === Building dataset/model for Beta 2 ===
# Beta Model Training - Epoch [1/200], Loss: 1.6672
# Beta Model Training - Epoch [2/200], Loss: 1.1024
# Beta Model Training - Epoch [3/200], Loss: 0.7035
# Beta Model Training - Epoch [4/200], Loss: 0.4975
# Beta Model Training - Epoch [5/200], Loss: 0.3871
# Beta Model Training - Epoch [6/200], Loss: 0.3424
# Beta Model Training - Epoch [7/200], Loss: 0.3130
# Beta Model Training - Epoch [8/200], Loss: 0.2932
# Beta Model Training - Epoch [9/200], Loss: 0.2764
# Beta Model Training - Epoch [10/200], Loss: 0.2605
# Beta Model Training - Epoch [11/200], Loss: 0.2487
# Beta Model Training - Epoch [12/200], Loss: 0.2439
# Beta Model Training - Epoch [13/200], Loss: 0.2407
# Beta Model Training - Epoch [14/200], Loss: 0.2319
# Beta Model Training - Epoch [15/200], Loss: 0.2220
# Beta Model Training - Epoch [16/200], Loss: 0.2148
# Beta Model Training - Epoch [17/200], Loss: 0.2101
# Beta Model Training - Epoch [18/200], Loss: 0.1997
# Beta Model Training - Epoch [19/200], Loss: 0.1950
# Beta Model Training - Epoch [20/200], Loss: 0.1879
# Beta Model Training - Epoch [21/200], Loss: 0.1856
# Beta Model Training - Epoch [22/200], Loss: 0.1824
# Beta Model Training - Epoch [23/200], Loss: 0.1718
# Beta Model Training - Epoch [24/200], Loss: 0.1652
# Beta Model Training - Epoch [25/200], Loss: 0.1614
# Beta Model Training - Epoch [26/200], Loss: 0.1539
# Beta Model Training - Epoch [27/200], Loss: 0.1466
# Beta Model Training - Epoch [28/200], Loss: 0.1463
# Beta Model Training - Epoch [29/200], Loss: 0.1396
# Beta Model Training - Epoch [30/200], Loss: 0.1363
# Beta Model Training - Epoch [31/200], Loss: 0.1329
# Beta Model Training - Epoch [32/200], Loss: 0.1304
# Beta Model Training - Epoch [33/200], Loss: 0.1224
# Beta Model Training - Epoch [34/200], Loss: 0.1181
# Beta Model Training - Epoch [35/200], Loss: 0.1141
# Beta Model Training - Epoch [36/200], Loss: 0.1134
# Beta Model Training - Epoch [37/200], Loss: 0.1126
# Beta Model Training - Epoch [38/200], Loss: 0.1108
# Beta Model Training - Epoch [39/200], Loss: 0.1104
# Beta Model Training - Epoch [40/200], Loss: 0.1069
# Beta Model Training - Epoch [41/200], Loss: 0.1065
# Beta Model Training - Epoch [42/200], Loss: 0.1039
# Beta Model Training - Epoch [43/200], Loss: 0.1003
# Beta Model Training - Epoch [44/200], Loss: 0.1003
# Beta Model Training - Epoch [45/200], Loss: 0.0967
# Beta Model Training - Epoch [46/200], Loss: 0.1076
# Beta Model Training - Epoch [47/200], Loss: 0.0984
# Beta Model Training - Epoch [48/200], Loss: 0.0956
# Beta Model Training - Epoch [49/200], Loss: 0.0923
# Beta Model Training - Epoch [50/200], Loss: 0.0959
# Beta Model Training - Epoch [51/200], Loss: 0.0895
# Beta Model Training - Epoch [52/200], Loss: 0.0906
# Beta Model Training - Epoch [53/200], Loss: 0.0955
# Beta Model Training - Epoch [54/200], Loss: 0.0888
# Beta Model Training - Epoch [55/200], Loss: 0.0871
# Beta Model Training - Epoch [56/200], Loss: 0.0832
# Beta Model Training - Epoch [57/200], Loss: 0.0840
# Beta Model Training - Epoch [58/200], Loss: 0.0816
# Beta Model Training - Epoch [59/200], Loss: 0.0823
# Beta Model Training - Epoch [60/200], Loss: 0.0814
# Beta Model Training - Epoch [61/200], Loss: 0.0817
# Beta Model Training - Epoch [62/200], Loss: 0.0800
# Beta Model Training - Epoch [63/200], Loss: 0.0792
# Beta Model Training - Epoch [64/200], Loss: 0.0768
# Beta Model Training - Epoch [65/200], Loss: 0.0786
# Beta Model Training - Epoch [66/200], Loss: 0.0821
# Beta Model Training - Epoch [67/200], Loss: 0.0909
# Beta Model Training - Epoch [68/200], Loss: 0.0820
# Beta Model Training - Epoch [69/200], Loss: 0.0791
# Beta Model Training - Epoch [70/200], Loss: 0.0772
# Beta Model Training - Epoch [71/200], Loss: 0.0736
# Beta Model Training - Epoch [72/200], Loss: 0.0703
# Beta Model Training - Epoch [73/200], Loss: 0.0691
# Beta Model Training - Epoch [74/200], Loss: 0.0688
# Beta Model Training - Epoch [75/200], Loss: 0.0669
# Beta Model Training - Epoch [76/200], Loss: 0.0668
# Beta Model Training - Epoch [77/200], Loss: 0.0658
# Beta Model Training - Epoch [78/200], Loss: 0.0659
# Beta Model Training - Epoch [79/200], Loss: 0.0665
# Beta Model Training - Epoch [80/200], Loss: 0.0669
# Beta Model Training - Epoch [81/200], Loss: 0.0671
# Beta Model Training - Epoch [82/200], Loss: 0.0648
# Beta Model Training - Epoch [83/200], Loss: 0.0634
# Beta Model Training - Epoch [84/200], Loss: 0.0624
# Beta Model Training - Epoch [85/200], Loss: 0.0625
# Beta Model Training - Epoch [86/200], Loss: 0.0611
# Beta Model Training - Epoch [87/200], Loss: 0.0616
# Beta Model Training - Epoch [88/200], Loss: 0.0605
# Beta Model Training - Epoch [89/200], Loss: 0.0601
# Beta Model Training - Epoch [90/200], Loss: 0.0579
# Beta Model Training - Epoch [91/200], Loss: 0.0570
# Beta Model Training - Epoch [92/200], Loss: 0.0565
# Beta Model Training - Epoch [93/200], Loss: 0.0577
# Beta Model Training - Epoch [94/200], Loss: 0.0590
# Beta Model Training - Epoch [95/200], Loss: 0.0568
# Beta Model Training - Epoch [96/200], Loss: 0.0566
# Beta Model Training - Epoch [97/200], Loss: 0.0563
# Beta Model Training - Epoch [98/200], Loss: 0.0585
# Beta Model Training - Epoch [99/200], Loss: 0.0597
# Beta Model Training - Epoch [100/200], Loss: 0.0600
# Beta Model Training - Epoch [101/200], Loss: 0.0614
# Beta Model Training - Epoch [102/200], Loss: 0.0608
# Beta Model Training - Epoch [103/200], Loss: 0.0583
# Beta Model Training - Epoch [104/200], Loss: 0.0577
# Beta Model Training - Epoch [105/200], Loss: 0.0627
# Beta Model Training - Epoch [106/200], Loss: 0.0639
# Beta Model Training - Epoch [107/200], Loss: 0.0630
# Beta Model Training - Epoch [108/200], Loss: 0.0606
# Beta Model Training - Epoch [109/200], Loss: 0.0616
# Beta Model Training - Epoch [110/200], Loss: 0.0609
# Beta Model Training - Epoch [111/200], Loss: 0.0634
# Beta Model Training - Epoch [112/200], Loss: 0.0636
# Beta Model Training - Epoch [113/200], Loss: 0.0601
# Beta Model Training - Epoch [114/200], Loss: 0.0629
# Beta Model Training - Epoch [115/200], Loss: 0.0584
# Beta Model Training - Epoch [116/200], Loss: 0.0561
# Beta Model Training - Epoch [117/200], Loss: 0.0530
# Beta Model Training - Epoch [118/200], Loss: 0.0522
# Beta Model Training - Epoch [119/200], Loss: 0.0506
# Beta Model Training - Epoch [120/200], Loss: 0.0498
# Beta Model Training - Epoch [121/200], Loss: 0.0487
# Beta Model Training - Epoch [122/200], Loss: 0.0484
# Beta Model Training - Epoch [123/200], Loss: 0.0487
# Beta Model Training - Epoch [124/200], Loss: 0.0472
# Beta Model Training - Epoch [125/200], Loss: 0.0470
# Beta Model Training - Epoch [126/200], Loss: 0.0474
# Beta Model Training - Epoch [127/200], Loss: 0.0465
# Beta Model Training - Epoch [128/200], Loss: 0.0465
# Beta Model Training - Epoch [129/200], Loss: 0.0460
# Beta Model Training - Epoch [130/200], Loss: 0.0460
# Beta Model Training - Epoch [131/200], Loss: 0.0461
# Beta Model Training - Epoch [132/200], Loss: 0.0468
# Beta Model Training - Epoch [133/200], Loss: 0.0461
# Beta Model Training - Epoch [134/200], Loss: 0.0469
# Beta Model Training - Epoch [135/200], Loss: 0.0477
# Beta Model Training - Epoch [136/200], Loss: 0.0475
# Beta Model Training - Epoch [137/200], Loss: 0.0482
# Beta Model Training - Epoch [138/200], Loss: 0.0485
# Beta Model Training - Epoch [139/200], Loss: 0.0474
# Beta Model Training - Epoch [140/200], Loss: 0.0476
# Beta Model Training - Epoch [141/200], Loss: 0.0462
# Beta Model Training - Epoch [142/200], Loss: 0.0448
# Beta Model Training - Epoch [143/200], Loss: 0.0457
# Beta Model Training - Epoch [144/200], Loss: 0.0448
# Beta Model Training - Epoch [145/200], Loss: 0.0450
# Beta Model Training - Epoch [146/200], Loss: 0.0475
# Beta Model Training - Epoch [147/200], Loss: 0.0523
# Beta Model Training - Epoch [148/200], Loss: 0.0490
# Beta Model Training - Epoch [149/200], Loss: 0.0497
# Beta Model Training - Epoch [150/200], Loss: 0.0485
# Beta Model Training - Epoch [151/200], Loss: 0.0495
# Beta Model Training - Epoch [152/200], Loss: 0.0556
# Beta Model Training - Epoch [153/200], Loss: 0.0554
# Beta Model Training - Epoch [154/200], Loss: 0.0579
# Beta Model Training - Epoch [155/200], Loss: 0.0521
# Beta Model Training - Epoch [156/200], Loss: 0.0479
# Beta Model Training - Epoch [157/200], Loss: 0.0455
# Beta Model Training - Epoch [158/200], Loss: 0.0452
# Beta Model Training - Epoch [159/200], Loss: 0.0448
# Beta Model Training - Epoch [160/200], Loss: 0.0456
# Beta Model Training - Epoch [161/200], Loss: 0.0459
# Beta Model Training - Epoch [162/200], Loss: 0.0447
# Beta Model Training - Epoch [163/200], Loss: 0.0431
# Beta Model Training - Epoch [164/200], Loss: 0.0430
# Beta Model Training - Epoch [165/200], Loss: 0.0418
# Beta Model Training - Epoch [166/200], Loss: 0.0422
# Beta Model Training - Epoch [167/200], Loss: 0.0421
# Beta Model Training - Epoch [168/200], Loss: 0.0421
# Beta Model Training - Epoch [169/200], Loss: 0.0443
# Beta Model Training - Epoch [170/200], Loss: 0.0435
# Beta Model Training - Epoch [171/200], Loss: 0.0423
# Beta Model Training - Epoch [172/200], Loss: 0.0441
# Beta Model Training - Epoch [173/200], Loss: 0.0473
# Beta Model Training - Epoch [174/200], Loss: 0.0454
# Beta Model Training - Epoch [175/200], Loss: 0.0447
# Beta Model Training - Epoch [176/200], Loss: 0.0498
# Beta Model Training - Epoch [177/200], Loss: 0.0507
# Beta Model Training - Epoch [178/200], Loss: 0.0515
# Beta Model Training - Epoch [179/200], Loss: 0.0566
# Beta Model Training - Epoch [180/200], Loss: 0.0598
# Beta Model Training - Epoch [181/200], Loss: 0.0561
# Beta Model Training - Epoch [182/200], Loss: 0.0499
# Beta Model Training - Epoch [183/200], Loss: 0.0445
# Beta Model Training - Epoch [184/200], Loss: 0.0468
# Beta Model Training - Epoch [185/200], Loss: 0.0607
# Beta Model Training - Epoch [186/200], Loss: 0.0484
# Beta Model Training - Epoch [187/200], Loss: 0.0470
# Beta Model Training - Epoch [188/200], Loss: 0.0441
# Beta Model Training - Epoch [189/200], Loss: 0.0437
# Beta Model Training - Epoch [190/200], Loss: 0.0412
# Beta Model Training - Epoch [191/200], Loss: 0.0411
# Beta Model Training - Epoch [192/200], Loss: 0.0404
# Beta Model Training - Epoch [193/200], Loss: 0.0424
# Beta Model Training - Epoch [194/200], Loss: 0.0397
# Beta Model Training - Epoch [195/200], Loss: 0.0388
# Beta Model Training - Epoch [196/200], Loss: 0.0394
# Beta Model Training - Epoch [197/200], Loss: 0.0381
# Beta Model Training - Epoch [198/200], Loss: 0.0380
# Beta Model Training - Epoch [199/200], Loss: 0.0372
# Beta Model Training - Epoch [200/200], Loss: 0.0371
#
# === Building dataset/model for Beta 3 ===
# Beta Model Training - Epoch [1/200], Loss: 1.0967
# Beta Model Training - Epoch [2/200], Loss: 0.6978
# Beta Model Training - Epoch [3/200], Loss: 0.4881
# Beta Model Training - Epoch [4/200], Loss: 0.4307
# Beta Model Training - Epoch [5/200], Loss: 0.3880
# Beta Model Training - Epoch [6/200], Loss: 0.3640
# Beta Model Training - Epoch [7/200], Loss: 0.3464
# Beta Model Training - Epoch [8/200], Loss: 0.3351
# Beta Model Training - Epoch [9/200], Loss: 0.3230
# Beta Model Training - Epoch [10/200], Loss: 0.3152
# Beta Model Training - Epoch [11/200], Loss: 0.3069
# Beta Model Training - Epoch [12/200], Loss: 0.2938
# Beta Model Training - Epoch [13/200], Loss: 0.2812
# Beta Model Training - Epoch [14/200], Loss: 0.2719
# Beta Model Training - Epoch [15/200], Loss: 0.2643
# Beta Model Training - Epoch [16/200], Loss: 0.2493
# Beta Model Training - Epoch [17/200], Loss: 0.2384
# Beta Model Training - Epoch [18/200], Loss: 0.2354
# Beta Model Training - Epoch [19/200], Loss: 0.2269
# Beta Model Training - Epoch [20/200], Loss: 0.2192
# Beta Model Training - Epoch [21/200], Loss: 0.2069
# Beta Model Training - Epoch [22/200], Loss: 0.1968
# Beta Model Training - Epoch [23/200], Loss: 0.1939
# Beta Model Training - Epoch [24/200], Loss: 0.1912
# Beta Model Training - Epoch [25/200], Loss: 0.1880
# Beta Model Training - Epoch [26/200], Loss: 0.1822
# Beta Model Training - Epoch [27/200], Loss: 0.1737
# Beta Model Training - Epoch [28/200], Loss: 0.1708
# Beta Model Training - Epoch [29/200], Loss: 0.1674
# Beta Model Training - Epoch [30/200], Loss: 0.1681
# Beta Model Training - Epoch [31/200], Loss: 0.1619
# Beta Model Training - Epoch [32/200], Loss: 0.1569
# Beta Model Training - Epoch [33/200], Loss: 0.1564
# Beta Model Training - Epoch [34/200], Loss: 0.1534
# Beta Model Training - Epoch [35/200], Loss: 0.1525
# Beta Model Training - Epoch [36/200], Loss: 0.1498
# Beta Model Training - Epoch [37/200], Loss: 0.1435
# Beta Model Training - Epoch [38/200], Loss: 0.1421
# Beta Model Training - Epoch [39/200], Loss: 0.1376
# Beta Model Training - Epoch [40/200], Loss: 0.1388
# Beta Model Training - Epoch [41/200], Loss: 0.1368
# Beta Model Training - Epoch [42/200], Loss: 0.1326
# Beta Model Training - Epoch [43/200], Loss: 0.1331
# Beta Model Training - Epoch [44/200], Loss: 0.1273
# Beta Model Training - Epoch [45/200], Loss: 0.1257
# Beta Model Training - Epoch [46/200], Loss: 0.1234
# Beta Model Training - Epoch [47/200], Loss: 0.1245
# Beta Model Training - Epoch [48/200], Loss: 0.1190
# Beta Model Training - Epoch [49/200], Loss: 0.1190
# Beta Model Training - Epoch [50/200], Loss: 0.1183
# Beta Model Training - Epoch [51/200], Loss: 0.1141
# Beta Model Training - Epoch [52/200], Loss: 0.1152
# Beta Model Training - Epoch [53/200], Loss: 0.1111
# Beta Model Training - Epoch [54/200], Loss: 0.1109
# Beta Model Training - Epoch [55/200], Loss: 0.1075
# Beta Model Training - Epoch [56/200], Loss: 0.1063
# Beta Model Training - Epoch [57/200], Loss: 0.1078
# Beta Model Training - Epoch [58/200], Loss: 0.1065
# Beta Model Training - Epoch [59/200], Loss: 0.1042
# Beta Model Training - Epoch [60/200], Loss: 0.1029
# Beta Model Training - Epoch [61/200], Loss: 0.1031
# Beta Model Training - Epoch [62/200], Loss: 0.1007
# Beta Model Training - Epoch [63/200], Loss: 0.0986
# Beta Model Training - Epoch [64/200], Loss: 0.0978
# Beta Model Training - Epoch [65/200], Loss: 0.0989
# Beta Model Training - Epoch [66/200], Loss: 0.1016
# Beta Model Training - Epoch [67/200], Loss: 0.1049
# Beta Model Training - Epoch [68/200], Loss: 0.1051
# Beta Model Training - Epoch [69/200], Loss: 0.1009
# Beta Model Training - Epoch [70/200], Loss: 0.0959
# Beta Model Training - Epoch [71/200], Loss: 0.0946
# Beta Model Training - Epoch [72/200], Loss: 0.0947
# Beta Model Training - Epoch [73/200], Loss: 0.0916
# Beta Model Training - Epoch [74/200], Loss: 0.0891
# Beta Model Training - Epoch [75/200], Loss: 0.0905
# Beta Model Training - Epoch [76/200], Loss: 0.0885
# Beta Model Training - Epoch [77/200], Loss: 0.0884
# Beta Model Training - Epoch [78/200], Loss: 0.0861
# Beta Model Training - Epoch [79/200], Loss: 0.0860
# Beta Model Training - Epoch [80/200], Loss: 0.0852
# Beta Model Training - Epoch [81/200], Loss: 0.0844
# Beta Model Training - Epoch [82/200], Loss: 0.0852
# Beta Model Training - Epoch [83/200], Loss: 0.0846
# Beta Model Training - Epoch [84/200], Loss: 0.0835
# Beta Model Training - Epoch [85/200], Loss: 0.0840
# Beta Model Training - Epoch [86/200], Loss: 0.0941
# Beta Model Training - Epoch [87/200], Loss: 0.1037
# Beta Model Training - Epoch [88/200], Loss: 0.0917
# Beta Model Training - Epoch [89/200], Loss: 0.0898
# Beta Model Training - Epoch [90/200], Loss: 0.0882
# Beta Model Training - Epoch [91/200], Loss: 0.0875
# Beta Model Training - Epoch [92/200], Loss: 0.0853
# Beta Model Training - Epoch [93/200], Loss: 0.0825
# Beta Model Training - Epoch [94/200], Loss: 0.0808
# Beta Model Training - Epoch [95/200], Loss: 0.0796
# Beta Model Training - Epoch [96/200], Loss: 0.0810
# Beta Model Training - Epoch [97/200], Loss: 0.0805
# Beta Model Training - Epoch [98/200], Loss: 0.0809
# Beta Model Training - Epoch [99/200], Loss: 0.0784
# Beta Model Training - Epoch [100/200], Loss: 0.0802
# Beta Model Training - Epoch [101/200], Loss: 0.0795
# Beta Model Training - Epoch [102/200], Loss: 0.0811
# Beta Model Training - Epoch [103/200], Loss: 0.0788
# Beta Model Training - Epoch [104/200], Loss: 0.0783
# Beta Model Training - Epoch [105/200], Loss: 0.0808
# Beta Model Training - Epoch [106/200], Loss: 0.0791
# Beta Model Training - Epoch [107/200], Loss: 0.0972
# Beta Model Training - Epoch [108/200], Loss: 0.0955
# Beta Model Training - Epoch [109/200], Loss: 0.0888
# Beta Model Training - Epoch [110/200], Loss: 0.0830
# Beta Model Training - Epoch [111/200], Loss: 0.0808
# Beta Model Training - Epoch [112/200], Loss: 0.0755
# Beta Model Training - Epoch [113/200], Loss: 0.0739
# Beta Model Training - Epoch [114/200], Loss: 0.0726
# Beta Model Training - Epoch [115/200], Loss: 0.0704
# Beta Model Training - Epoch [116/200], Loss: 0.0708
# Beta Model Training - Epoch [117/200], Loss: 0.0715
# Beta Model Training - Epoch [118/200], Loss: 0.0708
# Beta Model Training - Epoch [119/200], Loss: 0.0716
# Beta Model Training - Epoch [120/200], Loss: 0.0705
# Beta Model Training - Epoch [121/200], Loss: 0.0695
# Beta Model Training - Epoch [122/200], Loss: 0.0683
# Beta Model Training - Epoch [123/200], Loss: 0.0694
# Beta Model Training - Epoch [124/200], Loss: 0.0684
# Beta Model Training - Epoch [125/200], Loss: 0.0681
# Beta Model Training - Epoch [126/200], Loss: 0.0669
# Beta Model Training - Epoch [127/200], Loss: 0.0669
# Beta Model Training - Epoch [128/200], Loss: 0.0665
# Beta Model Training - Epoch [129/200], Loss: 0.0662
# Beta Model Training - Epoch [130/200], Loss: 0.0658
# Beta Model Training - Epoch [131/200], Loss: 0.0663
# Beta Model Training - Epoch [132/200], Loss: 0.0662
# Beta Model Training - Epoch [133/200], Loss: 0.0652
# Beta Model Training - Epoch [134/200], Loss: 0.0687
# Beta Model Training - Epoch [135/200], Loss: 0.0726
# Beta Model Training - Epoch [136/200], Loss: 0.0734
# Beta Model Training - Epoch [137/200], Loss: 0.0732
# Beta Model Training - Epoch [138/200], Loss: 0.0701
# Beta Model Training - Epoch [139/200], Loss: 0.0722
# Beta Model Training - Epoch [140/200], Loss: 0.0721
# Beta Model Training - Epoch [141/200], Loss: 0.0694
# Beta Model Training - Epoch [142/200], Loss: 0.0697
# Beta Model Training - Epoch [143/200], Loss: 0.0668
# Beta Model Training - Epoch [144/200], Loss: 0.0657
# Beta Model Training - Epoch [145/200], Loss: 0.0654
# Beta Model Training - Epoch [146/200], Loss: 0.0654
# Beta Model Training - Epoch [147/200], Loss: 0.0655
# Beta Model Training - Epoch [148/200], Loss: 0.0644
# Beta Model Training - Epoch [149/200], Loss: 0.0625
# Beta Model Training - Epoch [150/200], Loss: 0.0638
# Beta Model Training - Epoch [151/200], Loss: 0.0637
# Beta Model Training - Epoch [152/200], Loss: 0.0625
# Beta Model Training - Epoch [153/200], Loss: 0.0623
# Beta Model Training - Epoch [154/200], Loss: 0.0634
# Beta Model Training - Epoch [155/200], Loss: 0.0619
# Beta Model Training - Epoch [156/200], Loss: 0.0615
# Beta Model Training - Epoch [157/200], Loss: 0.0619
# Beta Model Training - Epoch [158/200], Loss: 0.0613
# Beta Model Training - Epoch [159/200], Loss: 0.0616
# Beta Model Training - Epoch [160/200], Loss: 0.0610
# Beta Model Training - Epoch [161/200], Loss: 0.0612
# Beta Model Training - Epoch [162/200], Loss: 0.0603
# Beta Model Training - Epoch [163/200], Loss: 0.0599
# Beta Model Training - Epoch [164/200], Loss: 0.0595
# Beta Model Training - Epoch [165/200], Loss: 0.0603
# Beta Model Training - Epoch [166/200], Loss: 0.0615
# Beta Model Training - Epoch [167/200], Loss: 0.0614
# Beta Model Training - Epoch [168/200], Loss: 0.0600
# Beta Model Training - Epoch [169/200], Loss: 0.0596
# Beta Model Training - Epoch [170/200], Loss: 0.0593
# Beta Model Training - Epoch [171/200], Loss: 0.0596
# Beta Model Training - Epoch [172/200], Loss: 0.0601
# Beta Model Training - Epoch [173/200], Loss: 0.0594
# Beta Model Training - Epoch [174/200], Loss: 0.0626
# Beta Model Training - Epoch [175/200], Loss: 0.0736
# Beta Model Training - Epoch [176/200], Loss: 0.0676
# Beta Model Training - Epoch [177/200], Loss: 0.0636
# Beta Model Training - Epoch [178/200], Loss: 0.0625
# Beta Model Training - Epoch [179/200], Loss: 0.0638
# Beta Model Training - Epoch [180/200], Loss: 0.0628
# Beta Model Training - Epoch [181/200], Loss: 0.0621
# Beta Model Training - Epoch [182/200], Loss: 0.0608
# Beta Model Training - Epoch [183/200], Loss: 0.0598
# Beta Model Training - Epoch [184/200], Loss: 0.0587
# Beta Model Training - Epoch [185/200], Loss: 0.0579
# Beta Model Training - Epoch [186/200], Loss: 0.0581
# Beta Model Training - Epoch [187/200], Loss: 0.0572
# Beta Model Training - Epoch [188/200], Loss: 0.0577
# Beta Model Training - Epoch [189/200], Loss: 0.0571
# Beta Model Training - Epoch [190/200], Loss: 0.0578
# Beta Model Training - Epoch [191/200], Loss: 0.0566
# Beta Model Training - Epoch [192/200], Loss: 0.0573
# Beta Model Training - Epoch [193/200], Loss: 0.0571
# Beta Model Training - Epoch [194/200], Loss: 0.0581
# Beta Model Training - Epoch [195/200], Loss: 0.0570
# Beta Model Training - Epoch [196/200], Loss: 0.0568
# Beta Model Training - Epoch [197/200], Loss: 0.0565
# Beta Model Training - Epoch [198/200], Loss: 0.0558
# Beta Model Training - Epoch [199/200], Loss: 0.0572
# Beta Model Training - Epoch [200/200], Loss: 0.0581
#
# === Building dataset/model for Beta 4 ===
# Beta Model Training - Epoch [1/200], Loss: 0.7148
# Beta Model Training - Epoch [2/200], Loss: 0.5333
# Beta Model Training - Epoch [3/200], Loss: 0.4076
# Beta Model Training - Epoch [4/200], Loss: 0.3372
# Beta Model Training - Epoch [5/200], Loss: 0.2920
# Beta Model Training - Epoch [6/200], Loss: 0.2624
# Beta Model Training - Epoch [7/200], Loss: 0.2348
# Beta Model Training - Epoch [8/200], Loss: 0.2118
# Beta Model Training - Epoch [9/200], Loss: 0.1912
# Beta Model Training - Epoch [10/200], Loss: 0.1735
# Beta Model Training - Epoch [11/200], Loss: 0.1571
# Beta Model Training - Epoch [12/200], Loss: 0.1453
# Beta Model Training - Epoch [13/200], Loss: 0.1338
# Beta Model Training - Epoch [14/200], Loss: 0.1228
# Beta Model Training - Epoch [15/200], Loss: 0.1124
# Beta Model Training - Epoch [16/200], Loss: 0.1039
# Beta Model Training - Epoch [17/200], Loss: 0.0992
# Beta Model Training - Epoch [18/200], Loss: 0.0951
# Beta Model Training - Epoch [19/200], Loss: 0.0890
# Beta Model Training - Epoch [20/200], Loss: 0.0834
# Beta Model Training - Epoch [21/200], Loss: 0.0837
# Beta Model Training - Epoch [22/200], Loss: 0.0840
# Beta Model Training - Epoch [23/200], Loss: 0.0829
# Beta Model Training - Epoch [24/200], Loss: 0.0777
# Beta Model Training - Epoch [25/200], Loss: 0.0742
# Beta Model Training - Epoch [26/200], Loss: 0.0740
# Beta Model Training - Epoch [27/200], Loss: 0.0735
# Beta Model Training - Epoch [28/200], Loss: 0.0689
# Beta Model Training - Epoch [29/200], Loss: 0.0673
# Beta Model Training - Epoch [30/200], Loss: 0.0661
# Beta Model Training - Epoch [31/200], Loss: 0.0624
# Beta Model Training - Epoch [32/200], Loss: 0.0607
# Beta Model Training - Epoch [33/200], Loss: 0.0591
# Beta Model Training - Epoch [34/200], Loss: 0.0578
# Beta Model Training - Epoch [35/200], Loss: 0.0561
# Beta Model Training - Epoch [36/200], Loss: 0.0555
# Beta Model Training - Epoch [37/200], Loss: 0.0567
# Beta Model Training - Epoch [38/200], Loss: 0.0560
# Beta Model Training - Epoch [39/200], Loss: 0.0544
# Beta Model Training - Epoch [40/200], Loss: 0.0532
# Beta Model Training - Epoch [41/200], Loss: 0.0520
# Beta Model Training - Epoch [42/200], Loss: 0.0512
# Beta Model Training - Epoch [43/200], Loss: 0.0508
# Beta Model Training - Epoch [44/200], Loss: 0.0496
# Beta Model Training - Epoch [45/200], Loss: 0.0484
# Beta Model Training - Epoch [46/200], Loss: 0.0491
# Beta Model Training - Epoch [47/200], Loss: 0.0477
# Beta Model Training - Epoch [48/200], Loss: 0.0477
# Beta Model Training - Epoch [49/200], Loss: 0.0463
# Beta Model Training - Epoch [50/200], Loss: 0.0460
# Beta Model Training - Epoch [51/200], Loss: 0.0446
# Beta Model Training - Epoch [52/200], Loss: 0.0430
# Beta Model Training - Epoch [53/200], Loss: 0.0423
# Beta Model Training - Epoch [54/200], Loss: 0.0418
# Beta Model Training - Epoch [55/200], Loss: 0.0411
# Beta Model Training - Epoch [56/200], Loss: 0.0413
# Beta Model Training - Epoch [57/200], Loss: 0.0436
# Beta Model Training - Epoch [58/200], Loss: 0.0437
# Beta Model Training - Epoch [59/200], Loss: 0.0431
# Beta Model Training - Epoch [60/200], Loss: 0.0423
# Beta Model Training - Epoch [61/200], Loss: 0.0489
# Beta Model Training - Epoch [62/200], Loss: 0.0464
# Beta Model Training - Epoch [63/200], Loss: 0.0428
# Beta Model Training - Epoch [64/200], Loss: 0.0420
# Beta Model Training - Epoch [65/200], Loss: 0.0397
# Beta Model Training - Epoch [66/200], Loss: 0.0389
# Beta Model Training - Epoch [67/200], Loss: 0.0396
# Beta Model Training - Epoch [68/200], Loss: 0.0433
# Beta Model Training - Epoch [69/200], Loss: 0.0387
# Beta Model Training - Epoch [70/200], Loss: 0.0374
# Beta Model Training - Epoch [71/200], Loss: 0.0361
# Beta Model Training - Epoch [72/200], Loss: 0.0345
# Beta Model Training - Epoch [73/200], Loss: 0.0335
# Beta Model Training - Epoch [74/200], Loss: 0.0323
# Beta Model Training - Epoch [75/200], Loss: 0.0320
# Beta Model Training - Epoch [76/200], Loss: 0.0314
# Beta Model Training - Epoch [77/200], Loss: 0.0317
# Beta Model Training - Epoch [78/200], Loss: 0.0312
# Beta Model Training - Epoch [79/200], Loss: 0.0299
# Beta Model Training - Epoch [80/200], Loss: 0.0298
# Beta Model Training - Epoch [81/200], Loss: 0.0295
# Beta Model Training - Epoch [82/200], Loss: 0.0297
# Beta Model Training - Epoch [83/200], Loss: 0.0301
# Beta Model Training - Epoch [84/200], Loss: 0.0292
# Beta Model Training - Epoch [85/200], Loss: 0.0291
# Beta Model Training - Epoch [86/200], Loss: 0.0287
# Beta Model Training - Epoch [87/200], Loss: 0.0283
# Beta Model Training - Epoch [88/200], Loss: 0.0291
# Beta Model Training - Epoch [89/200], Loss: 0.0285
# Beta Model Training - Epoch [90/200], Loss: 0.0279
# Beta Model Training - Epoch [91/200], Loss: 0.0278
# Beta Model Training - Epoch [92/200], Loss: 0.0281
# Beta Model Training - Epoch [93/200], Loss: 0.0302
# Beta Model Training - Epoch [94/200], Loss: 0.0288
# Beta Model Training - Epoch [95/200], Loss: 0.0275
# Beta Model Training - Epoch [96/200], Loss: 0.0279
# Beta Model Training - Epoch [97/200], Loss: 0.0279
# Beta Model Training - Epoch [98/200], Loss: 0.0285
# Beta Model Training - Epoch [99/200], Loss: 0.0279
# Beta Model Training - Epoch [100/200], Loss: 0.0287
# Beta Model Training - Epoch [101/200], Loss: 0.0298
# Beta Model Training - Epoch [102/200], Loss: 0.0284
# Beta Model Training - Epoch [103/200], Loss: 0.0277
# Beta Model Training - Epoch [104/200], Loss: 0.0277
# Beta Model Training - Epoch [105/200], Loss: 0.0261
# Beta Model Training - Epoch [106/200], Loss: 0.0254
# Beta Model Training - Epoch [107/200], Loss: 0.0259
# Beta Model Training - Epoch [108/200], Loss: 0.0251
# Beta Model Training - Epoch [109/200], Loss: 0.0249
# Beta Model Training - Epoch [110/200], Loss: 0.0248
# Beta Model Training - Epoch [111/200], Loss: 0.0256
# Beta Model Training - Epoch [112/200], Loss: 0.0257
# Beta Model Training - Epoch [113/200], Loss: 0.0254
# Beta Model Training - Epoch [114/200], Loss: 0.0263
# Beta Model Training - Epoch [115/200], Loss: 0.0248
# Beta Model Training - Epoch [116/200], Loss: 0.0242
# Beta Model Training - Epoch [117/200], Loss: 0.0237
# Beta Model Training - Epoch [118/200], Loss: 0.0231
# Beta Model Training - Epoch [119/200], Loss: 0.0232
# Beta Model Training - Epoch [120/200], Loss: 0.0240
# Beta Model Training - Epoch [121/200], Loss: 0.0235
# Beta Model Training - Epoch [122/200], Loss: 0.0234
# Beta Model Training - Epoch [123/200], Loss: 0.0236
# Beta Model Training - Epoch [124/200], Loss: 0.0237
# Beta Model Training - Epoch [125/200], Loss: 0.0232
# Beta Model Training - Epoch [126/200], Loss: 0.0226
# Beta Model Training - Epoch [127/200], Loss: 0.0226
# Beta Model Training - Epoch [128/200], Loss: 0.0225
# Beta Model Training - Epoch [129/200], Loss: 0.0234
# Beta Model Training - Epoch [130/200], Loss: 0.0246
# Beta Model Training - Epoch [131/200], Loss: 0.0245
# Beta Model Training - Epoch [132/200], Loss: 0.0251
# Beta Model Training - Epoch [133/200], Loss: 0.0248
# Beta Model Training - Epoch [134/200], Loss: 0.0239
# Beta Model Training - Epoch [135/200], Loss: 0.0237
# Beta Model Training - Epoch [136/200], Loss: 0.0245
# Beta Model Training - Epoch [137/200], Loss: 0.0300
# Beta Model Training - Epoch [138/200], Loss: 0.0291
# Beta Model Training - Epoch [139/200], Loss: 0.0261
# Beta Model Training - Epoch [140/200], Loss: 0.0235
# Beta Model Training - Epoch [141/200], Loss: 0.0235
# Beta Model Training - Epoch [142/200], Loss: 0.0229
# Beta Model Training - Epoch [143/200], Loss: 0.0214
# Beta Model Training - Epoch [144/200], Loss: 0.0215
# Beta Model Training - Epoch [145/200], Loss: 0.0223
# Beta Model Training - Epoch [146/200], Loss: 0.0243
# Beta Model Training - Epoch [147/200], Loss: 0.0260
# Beta Model Training - Epoch [148/200], Loss: 0.0317
# Beta Model Training - Epoch [149/200], Loss: 0.0270
# Beta Model Training - Epoch [150/200], Loss: 0.0252
# Beta Model Training - Epoch [151/200], Loss: 0.0233
# Beta Model Training - Epoch [152/200], Loss: 0.0223
# Beta Model Training - Epoch [153/200], Loss: 0.0231
# Beta Model Training - Epoch [154/200], Loss: 0.0220
# Beta Model Training - Epoch [155/200], Loss: 0.0212
# Beta Model Training - Epoch [156/200], Loss: 0.0204
# Beta Model Training - Epoch [157/200], Loss: 0.0204
# Beta Model Training - Epoch [158/200], Loss: 0.0206
# Beta Model Training - Epoch [159/200], Loss: 0.0204
# Beta Model Training - Epoch [160/200], Loss: 0.0203
# Beta Model Training - Epoch [161/200], Loss: 0.0198
# Beta Model Training - Epoch [162/200], Loss: 0.0193
# Beta Model Training - Epoch [163/200], Loss: 0.0193
# Beta Model Training - Epoch [164/200], Loss: 0.0192
# Beta Model Training - Epoch [165/200], Loss: 0.0188
# Beta Model Training - Epoch [166/200], Loss: 0.0192
# Beta Model Training - Epoch [167/200], Loss: 0.0193
# Beta Model Training - Epoch [168/200], Loss: 0.0199
# Beta Model Training - Epoch [169/200], Loss: 0.0215
# Beta Model Training - Epoch [170/200], Loss: 0.0237
# Beta Model Training - Epoch [171/200], Loss: 0.0220
# Beta Model Training - Epoch [172/200], Loss: 0.0222
# Beta Model Training - Epoch [173/200], Loss: 0.0212
# Beta Model Training - Epoch [174/200], Loss: 0.0224
# Beta Model Training - Epoch [175/200], Loss: 0.0214
# Beta Model Training - Epoch [176/200], Loss: 0.0212
# Beta Model Training - Epoch [177/200], Loss: 0.0203
# Beta Model Training - Epoch [178/200], Loss: 0.0196
# Beta Model Training - Epoch [179/200], Loss: 0.0193
# Beta Model Training - Epoch [180/200], Loss: 0.0201
# Beta Model Training - Epoch [181/200], Loss: 0.0189
# Beta Model Training - Epoch [182/200], Loss: 0.0188
# Beta Model Training - Epoch [183/200], Loss: 0.0187
# Beta Model Training - Epoch [184/200], Loss: 0.0204
# Beta Model Training - Epoch [185/200], Loss: 0.0190
# Beta Model Training - Epoch [186/200], Loss: 0.0180
# Beta Model Training - Epoch [187/200], Loss: 0.0173
# Beta Model Training - Epoch [188/200], Loss: 0.0172
# Beta Model Training - Epoch [189/200], Loss: 0.0172
# Beta Model Training - Epoch [190/200], Loss: 0.0170
# Beta Model Training - Epoch [191/200], Loss: 0.0175
# Beta Model Training - Epoch [192/200], Loss: 0.0175
# Beta Model Training - Epoch [193/200], Loss: 0.0173
# Beta Model Training - Epoch [194/200], Loss: 0.0171
# Beta Model Training - Epoch [195/200], Loss: 0.0172
# Beta Model Training - Epoch [196/200], Loss: 0.0171
# Beta Model Training - Epoch [197/200], Loss: 0.0170
# Beta Model Training - Epoch [198/200], Loss: 0.0172
# Beta Model Training - Epoch [199/200], Loss: 0.0167
# Beta Model Training - Epoch [200/200], Loss: 0.0169

# %%
# save importances results
save_dir = os.path.join(curr_dir, analysis_type, 'Masking')
os.makedirs(save_dir, exist_ok=True)

save_subdir_chan = os.path.join(save_dir, 'Channel Masking')
os.makedirs(save_subdir_chan, exist_ok=True)

save_subdir_region = os.path.join(save_dir, 'Region Masking')
os.makedirs(save_subdir_region, exist_ok=True)

save_subdir_subject = os.path.join(save_dir, 'Subject Masking')
os.makedirs(save_subdir_subject, exist_ok=True)

imp_chan_zero_data = {'all_imp_chan_zero': all_imp_chan_zero}
imp_chan_drop_data = {'all_imp_chan_drop': all_imp_chan_drop}
imp_chan_mean_data = {'all_imp_chan_mean': all_imp_chan_mean}
imp_region_localmean_data = {'all_imp_region_localmean': all_imp_region_localmean}
imp_region_globalmean_data = {'all_imp_region_globalmean': all_imp_region_globalmean}
imp_subject_zero_data = {'all_imp_subject_zero': all_imp_subject_zero}

savemat(os.path.join(save_subdir_chan, 'imp_chan_zero.mat'), imp_chan_zero_data)
savemat(os.path.join(save_subdir_chan, 'imp_chan_drop.mat'), imp_chan_drop_data)
savemat(os.path.join(save_subdir_chan, 'imp_chan_mean.mat'), imp_chan_mean_data)
savemat(os.path.join(save_subdir_region, 'imp_region_localmean.mat'), imp_region_localmean_data)
savemat(os.path.join(save_subdir_region, 'imp_region_globalmean.mat'), imp_region_globalmean_data)
savemat(os.path.join(save_subdir_subject, 'imp_subject_zero.mat'), imp_subject_zero_data)

# %%
# Visualize importances of channel masking zero method

values = all_imp_chan_zero.mean(axis=1)  # mean across subjects
plt.figure(figsize=(16,13))
plt.imshow(values, aspect='auto', origin='lower', cmap='Reds')
plt.colorbar(label='Mean importance')
plt.xticks(ticks=np.arange(nChan), labels=np.arange(1, nChan+1))
plt.xlabel('Channel')
plt.ylabel('Beta')
plt.title(analysis_type + '_Channel Importance_zero')
plt.tight_layout()
plt.savefig(os.path.join(save_subdir_chan, analysis_type + '_Channel Importance_zero.png'))
#plt.show()
plt.close()

for iBeta in range(nBeta):
    values = all_imp_chan_zero[iBeta]
    plt.figure(figsize=(16,13))
    plt.imshow(values, aspect='auto', origin='lower', cmap='Reds')
    plt.colorbar(label='Importance')
    plt.xticks(ticks=np.arange(nChan), labels=np.arange(1, nChan+1))
    plt.xlabel('Channel')
    plt.ylabel('Subject')
    plt.title(f'Beta {iBeta}_{analysis_type}_Channel Importance_zero')
    plt.tight_layout()
    plt.savefig(os.path.join(save_subdir_chan, analysis_type + f'_Beta_{iBeta}_Channel_Importance_zero.png'))
    #plt.show()
    plt.close()

# %%
# Visualize importances of channel masking mean method

values = all_imp_chan_mean.mean(axis=1)  # mean across subjects
plt.figure(figsize=(16,13))
plt.imshow(values, aspect='auto', origin='lower', cmap='Reds')
plt.colorbar(label='Mean importance')
plt.xticks(ticks=np.arange(nChan), labels=np.arange(1, nChan+1))
plt.xlabel('Channel')
plt.ylabel('Beta')
plt.title(analysis_type + '_Channel Importance_mean')
plt.tight_layout()
plt.savefig(os.path.join(save_subdir_chan, analysis_type + '_Channel Importance_mean.png'))
#plt.show()
plt.close()

for iBeta in range(nBeta):
    values = all_imp_chan_mean[iBeta]
    plt.figure(figsize=(16,13))
    plt.imshow(values, aspect='auto', origin='lower', cmap='Reds')
    plt.colorbar(label='Importance')
    plt.xticks(ticks=np.arange(nChan), labels=np.arange(1, nChan+1))
    plt.xlabel('Channel')
    plt.ylabel('Subject')
    plt.title(f'Beta {iBeta}_{analysis_type}_Channel Importance_mean')
    plt.tight_layout()
    plt.savefig(os.path.join(save_subdir_chan, analysis_type + f'_Beta_{iBeta}_Channel_Importance_mean.png'))
    #plt.show()
    plt.close()

# %%
# Visualize importances of channel masking dropping method

values = all_imp_chan_drop.mean(axis=1)  # mean across subjects
plt.figure(figsize=(16,13))
plt.imshow(values, aspect='auto', origin='lower', cmap='Reds')
plt.colorbar(label='Mean importance')
plt.xticks(ticks=np.arange(nChan), labels=np.arange(1, nChan+1))
plt.xlabel('Channel')
plt.ylabel('Beta')
plt.title(analysis_type+'_Channel Importance_drop')
plt.tight_layout()
plt.savefig(os.path.join(save_subdir_chan, analysis_type + '_Channel Importance_drop.png'))
#plt.show()
plt.close()

for iBeta in range(nBeta):
    values = all_imp_chan_drop[iBeta]
    plt.figure(figsize=(16,13))
    plt.imshow(values, aspect='auto', origin='lower', cmap='Reds')
    plt.colorbar(label='Importance')
    plt.xticks(ticks=np.arange(nChan), labels=np.arange(1, nChan+1))
    plt.xlabel('Channel')
    plt.ylabel('Subject')
    plt.title(f'Beta {iBeta}_{analysis_type}_Channel Importance_drop')
    plt.tight_layout()
    plt.savefig(os.path.join(save_subdir_chan, analysis_type + f'_Beta_{iBeta}_Channel_Importance_drop.png'))
    #plt.show()
    plt.close()

# %%
# Visualize importances of region hard masking

values = all_imp_region_localmean.mean(axis=1)
plt.figure(figsize=(16,13))
plt.imshow(values, aspect='auto', origin='lower', cmap='Reds')
plt.colorbar(label='Mean importance')
plt.xticks(ticks=np.arange(nChan), labels=np.arange(1, nChan+1))
plt.xlabel('Channel')
plt.ylabel('Beta')
plt.title(analysis_type+'_Region Importance_localmean')
plt.tight_layout()
plt.savefig(os.path.join(save_subdir_region, analysis_type + '_Region Importance_localmean.png'))
#plt.show()
plt.close()

values = all_imp_region_globalmean.mean(axis=1)
plt.figure(figsize=(16,13))
plt.imshow(values, aspect='auto', origin='lower', cmap='Reds')
plt.colorbar(label='Mean importance')
plt.xticks(ticks=np.arange(nChan), labels=np.arange(1, nChan+1))
plt.xlabel('Channel')
plt.ylabel('Beta')
plt.title(analysis_type+'_Region Importance_globalmean')
plt.tight_layout()
plt.savefig(os.path.join(save_subdir_region, analysis_type + '_Region Importance_globalmean.png'))
#plt.show()
plt.close()

for iBeta in range(nBeta):
    values = all_imp_region_localmean[iBeta]
    plt.figure(figsize=(16,13))
    plt.imshow(values, aspect='auto', origin='lower', cmap='Reds')
    plt.colorbar(label='Importance')
    plt.xticks(ticks=np.arange(nChan), labels=np.arange(1, nChan+1))
    plt.xlabel('Channel')
    plt.ylabel('Subject')
    plt.title(f'Beta {iBeta}_{analysis_type}_Region Importance_localmean')
    plt.tight_layout()
    plt.savefig(os.path.join(save_subdir_region, analysis_type + f'_Beta_{iBeta}_Region_Importance_localmean.png'))
    #plt.show()
    plt.close()
    
    values = all_imp_region_globalmean[iBeta]
    plt.figure(figsize=(16,13))
    plt.imshow(values, aspect='auto', origin='lower', cmap='Reds')
    plt.colorbar(label='Importance')
    plt.xticks(ticks=np.arange(nChan), labels=np.arange(1, nChan+1))
    plt.xlabel('Channel')
    plt.ylabel('Subject')
    plt.title(f'Beta {iBeta}_{analysis_type}_Region Importance_globalmean')
    plt.tight_layout()
    plt.savefig(os.path.join(save_subdir_region, analysis_type + f'_Beta_{iBeta}_Region_Importance_globalmean.png'))
    #plt.show()
    plt.close()

# %%
# Visualize importances of subject masking

plt.figure(figsize=(16,13))
plt.imshow(all_imp_subject_zero, aspect='auto', origin='lower', cmap='Reds')
plt.colorbar(label='Importance')
plt.xticks(ticks=np.arange(nSubject), labels=np.arange(1, nSubject+1))
plt.xlabel('Subject')
plt.ylabel('Beta')
plt.title(analysis_type+'_Subject Importance_zero')
plt.tight_layout()
plt.savefig(os.path.join(save_subdir_subject, analysis_type + '_Subject Importance_zero.png'))
#plt.show()
plt.close()

for iBeta in range(nBeta):
    values = all_imp_subject_zero[iBeta]
    plt.figure(figsize=(16,13))
    plt.bar(np.arange(nSubject)+1, values)
    plt.xticks(ticks=np.arange(nSubject)+1, labels=np.arange(1, nSubject+1))
    plt.xlabel('Subject')
    plt.ylabel('Importance')
    plt.title(f'Beta {iBeta}_{analysis_type}_Subject Importance_zero')
    plt.tight_layout()
    plt.savefig(os.path.join(save_subdir_subject, analysis_type + f'_Beta_{iBeta}_Subject_Importance_zero.png'))
    #plt.show()
    plt.close()
