# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset, ConcatDataset
from torch_geometric.loader import DataLoader as GeometricDataLoader
from torch_geometric.data import Data
from torch_geometric.utils import dense_to_sparse, k_hop_subgraph
import torch_geometric.nn as pyg_nn
from scipy.io import loadmat, savemat
import os
import matplotlib.pyplot as plt

# %%
# Load saved beta data from mat file
analysis_type = 'N400'
curr_dir = os.getcwd()
datain_dir = os.path.join(os.getcwd(), 'datain')
datain_mat = loadmat(os.path.join(datain_dir, analysis_type + '_original_betas.mat'))
binatry_matrix_mat = loadmat(os.path.join(datain_dir, 'adjacency_matrix.mat'))
datain = datain_mat['data']
binatry_matrix = binatry_matrix_mat['adjacency_matrix']

datain = np.array(datain)          # shape: [nBeta, nTime, nChan, nSubject] (adjust as needed)
binatry_matrix = np.array(binatry_matrix)

# Parse shapes
nBeta     = datain.shape[0]
nTime     = datain.shape[1]
nChan     = datain.shape[2]
nSubject  = datain.shape[3]

# %%
# ===========================================
# 2) Set device & convert adjacency
# ===========================================
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
edge_index, _ = dense_to_sparse(torch.tensor(binatry_matrix, dtype=torch.float32))
print(device)

# ===========================================
# 3) Dataset builder
# ===========================================
def build_concat_dataset_for_beta(datain, beta_idx):
    """
    Build a ConcatDataset across all subjects for one beta index.
    `datain` is [nBeta, nTime, nChan, nSubject].
    Returns: ConcatDataset of length nSubject.
    """
    subject_datasets = []
    for s in range(nSubject):
        # Extract slice for one subject and one beta
        # shape: [nTime, nChan]
        single_beta_data = datain[beta_idx, :, :, s]

        # If each node is a channel and its feature dimension is time,
        # we might want single_beta_data to be [nChan, nTime].
        # If so, transpose here:
        single_beta_data = single_beta_data.T  # shape: [nChan, nTime]

        # For an autoencoder, features=labels
        x_tensor = torch.tensor(single_beta_data, dtype=torch.float32)
        x_tensor = x_tensor.unsqueeze(0)

        subject_datasets.append(TensorDataset(x_tensor, x_tensor))

    return ConcatDataset(subject_datasets)
# Out:
# cuda

# %%
# ===========================================
# 4) PyG Graph Dataset
# ===========================================
class EEGGraphDataset(torch.utils.data.Dataset):
    """
    Wraps a standard dataset so that each item is a PyG Data object:
      x -> node features (channels)
      edge_index -> adjacency
    """
    def __init__(self, eeg_data, edge_index):
        self.eeg_data = eeg_data
        self.edge_index = edge_index

    def __len__(self):
        return len(self.eeg_data)

    def __getitem__(self, idx):
        # item: (x, x) because it's autoencoder
        sample = self.eeg_data[idx]
        x = sample[0]  # shape: [nChan, nTime] (if you used transpose above)
        # Convert x -> float32, build PyG Data
        graph_data = Data(x=torch.tensor(x, dtype=torch.float32),
                          edge_index=self.edge_index)
        return graph_data

# %%
# ===========================================
# 5) Define GraphAutoencoder
# ===========================================
class GraphAutoencoder(nn.Module):
    def __init__(self, num_features, embedding_dim=64):
        """
        num_features = dimension of each node's feature vector.
                       If each channel is a node, and you pass
                       [nChan, nTime], then num_features = nTime.
        """
        super(GraphAutoencoder, self).__init__()
        # Example with two ARMAConv layers
        self.encoder_gcn1 = pyg_nn.ARMAConv(num_features, 128, 
                                            num_stacks=2, 
                                            num_layers=3,
                                            shared_weights=True)
        self.encoder_gcn2 = pyg_nn.ARMAConv(128, embedding_dim, 
                                            num_stacks=2, 
                                            num_layers=3,
                                            shared_weights=True)
        self.decoder_fc1 = nn.Linear(embedding_dim, 128)
        self.decoder_fc2 = nn.Linear(128, num_features)

    def forward(self, x, edge_index):
        x = torch.relu(self.encoder_gcn1(x, edge_index))
        latent = torch.relu(self.encoder_gcn2(x, edge_index))
        x = torch.relu(self.decoder_fc1(latent))
        reconstructed = self.decoder_fc2(x)
        return reconstructed

# %%
# ===========================================
# 6) Training and evaluation
# ===========================================
def train_model_all(model, train_loader, device, num_epochs):
    model.to(device)
    optimizer = optim.Adam(model.parameters(), lr=1e-3)
    criterion = nn.SmoothL1Loss()

    for epoch in range(num_epochs):
        model.train()
        epoch_loss = 0.0
        for batch_data in train_loader:
            batch_data = batch_data.to(device)
            optimizer.zero_grad()

            # Forward
            reconstructed = model(batch_data.x, batch_data.edge_index)
            loss = criterion(reconstructed, batch_data.x)

            # Backprop
            loss.backward()
            optimizer.step()
            epoch_loss += loss.item()

        epoch_loss /= len(train_loader)
        print(f"Beta Model Training - Epoch [{epoch+1}/{num_epochs}], Loss: {epoch_loss:.4f}")
    return model

def evaluation_model(model, data_sample, edge_index, device):
    """
    data_sample: shape [nChan, nTime], or [nTime, nChan],
                 whichever you used in training.
    Returns: (original_np, reconstructed_np, error_np)
    """
    model.eval()
    with torch.no_grad():
        x = torch.tensor(data_sample, dtype=torch.float32, device=device)
        eidx = edge_index.to(device)
        reconstructed = model(x, eidx)
    orig = x.cpu().numpy()
    recon = reconstructed.cpu().numpy()
    error = orig - recon
    return orig, recon, error

# %%
# Channel Masking

# Define channel masking function with 'zero' and 'mean' methods
def channel_masking(x_n, ch_idx, mode='mean'):
    x_masked = x_n.copy()
    if mode == 'zero':
        x_masked[ch_idx, :] = 0.0
    # Mean of all other channels
    elif mode == 'mean':
        channel_mean = x_n.mean(axis=0)
        x_masked[ch_idx, :] = channel_mean
    return x_masked

# Apply channel masking and compute importance
def apply_channel_masking(model, sample_n, edge_index, device, mode='mean'):
    model.eval()
    with torch.no_grad():
        x = torch.tensor(sample_n, dtype=torch.float32, device=device)
        recon = model(x, edge_index.to(device))
        base_lose = nn.SmoothL1Loss()(recon, x).item()
        
        nChan = sample_n.shape[0]
        imp = np.zeros(nChan)
        
        # Iterate over channels to compute importance
        # The higher the loss increase, the more important the channel
        for c in range(nChan):
            x_masked = channel_masking(sample_n, c, mode=mode)
            x_masked = torch.tensor(x_masked, dtype=torch.float32, device=device)
            recon_masked = model(x_masked, edge_index.to(device))
            masked_loss = nn.SmoothL1Loss()(recon_masked, x_masked).item()
            imp[c] = abs(masked_loss - base_lose)
            
    return imp

# %%
# Channel region hard masking

# Compute k-hop neighborhood channels for each channel
def compute_neighborhood_channels(edge_index, k=1):
    neighborhood_channels = []
    for c in range(edge_index.max().item() + 1):
        channels, _, _, _ = k_hop_subgraph(c, k, edge_index)
        neighborhood_channels.append(channels.cpu().numpy())
    return neighborhood_channels

# Define region hard masking function with 'zero' and 'mean' methods
def region_hard_masking(x_n, neig_list, mode='local_mean'):
    x_masked = x_n.copy()

    # Get the rest of the channels except the neighborhood list
    nChan = x_n.shape[0]
    mask_neig = np.zeros(nChan, dtype=bool)
    mask_neig[neig_list] = True
    mask_rest = ~mask_neig
    
    if mode == 'zero':
        x_masked[mask_neig, :] = 0.0
    # The mean of the rest of the channels
    elif mode == 'global_mean':
        if mask_rest.any():
            rest_mean = x_n[mask_rest, :].mean(axis=0)
        # If no rest channels, use overall mean
        else:
            rest_mean = x_n.mean(axis=0)
        x_masked[mask_neig, :] = rest_mean
    elif mode == 'local_mean':
        if mask_rest.any():
            local_mean = x_n[mask_neig, :].mean(axis=0)
        else:
            local_mean = x_n.mean(axis=0)
        x_masked[mask_neig, :] = local_mean
    return x_masked

# Apply region hard masking and compute importance
def apply_region_hard_masking(model, sample_n, edge_index, device, mode='mean', k=1):
    model.eval()
    with torch.no_grad():
        neighborhood_channels = compute_neighborhood_channels(edge_index, k)
        x = torch.tensor(sample_n, dtype=torch.float32, device=device)
        recon = model(x, edge_index.to(device))
        base_loss = nn.SmoothL1Loss()(recon, x).item()

        nChan = sample_n.shape[0]
        imp = np.zeros(nChan)
        
        for c in range(nChan):
            neig_list = neighborhood_channels[c]
            x_masked = region_hard_masking(sample_n, neig_list, mode=mode)
            x_masked = torch.tensor(x_masked, dtype=torch.float32, device=device)
            recon_masked = model(x_masked, edge_index.to(device))
            masked_loss = nn.SmoothL1Loss()(recon_masked, x_masked).item()
            imp[c] = abs(masked_loss - base_loss)
    return imp

# %%
num_features = nTime   # if each channel is a node, and feature vector = [nTime]
num_epochs   = 200     # number of training - set as needed
batch_size   = 4;      # dataset/batch to update hyperparameters

models = []

imp_chan_zero_list = []
imp_chan_mean_list = []
imp_region_localmean_list = []
imp_region_globalmean_list = []

for iBeta in range(nBeta):
    print(f"\n=== Building dataset/model for Beta {iBeta} ===")
    # Build dataset & loader
    full_dataset_i  = build_concat_dataset_for_beta(datain, iBeta)
    graph_dataset_i = EEGGraphDataset(full_dataset_i, edge_index)
    full_loader_i   = GeometricDataLoader(graph_dataset_i, batch_size=batch_size, shuffle=True)

    # Init model & train
    model_i = GraphAutoencoder(num_features=num_features, embedding_dim=32)
    model_i = train_model_all(model_i, full_loader_i, device, num_epochs=num_epochs)
    models.append(model_i)

    imp_chan_zero_per_subject = []
    imp_chan_mean_per_subject = []
    imp_region_localmean_per_subject = []
    imp_region_globalmean_per_subject = []
    for s in range(len(full_dataset_i)):
        x_s = full_dataset_i[s][0].numpy()  # [nChan, nTime]
        imp_chan_zero = apply_channel_masking(model_i, x_s, edge_index, device, mode='zero')
        imp_chan_mean = apply_channel_masking(model_i, x_s, edge_index, device, mode='mean')
        imp_region_localmean = apply_region_hard_masking(model_i, x_s, edge_index, device, mode='local_mean', k=1)
        imp_region_globalmean = apply_region_hard_masking(model_i, x_s, edge_index, device, mode='global_mean', k=1)
        imp_chan_zero_per_subject.append(imp_chan_zero)
        imp_chan_mean_per_subject.append(imp_chan_mean)
        imp_region_localmean_per_subject.append(imp_region_localmean)
        imp_region_globalmean_per_subject.append(imp_region_globalmean)

    imp_chan_zero_list.append(np.array(imp_chan_zero_per_subject))
    imp_chan_mean_list.append(np.array(imp_chan_mean_per_subject))
    imp_region_localmean_list.append(np.array(imp_region_localmean_per_subject))
    imp_region_globalmean_list.append(np.array(imp_region_globalmean_per_subject))

all_imp_chan_zero = np.array(imp_chan_zero_list)
all_imp_chan_mean = np.array(imp_chan_mean_list)
all_imp_region_localmean = np.array(imp_region_localmean_list)
all_imp_region_globalmean = np.array(imp_region_globalmean_list)
# Out:
# === Building dataset/model for Beta 0 ===
# Beta Model Training - Epoch [1/200], Loss: 0.0939
# Beta Model Training - Epoch [2/200], Loss: 0.0795
# C:\Users\86136\AppData\Local\Temp\ipykernel_21052\1382389434.py:22: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   graph_data = Data(x=torch.tensor(x, dtype=torch.float32),
# Beta Model Training - Epoch [3/200], Loss: 0.0652
# Beta Model Training - Epoch [4/200], Loss: 0.0560
# Beta Model Training - Epoch [5/200], Loss: 0.0498
# Beta Model Training - Epoch [6/200], Loss: 0.0449
# Beta Model Training - Epoch [7/200], Loss: 0.0413
# Beta Model Training - Epoch [8/200], Loss: 0.0383
# Beta Model Training - Epoch [9/200], Loss: 0.0358
# Beta Model Training - Epoch [10/200], Loss: 0.0335
# Beta Model Training - Epoch [11/200], Loss: 0.0312
# Beta Model Training - Epoch [12/200], Loss: 0.0293
# Beta Model Training - Epoch [13/200], Loss: 0.0277
# Beta Model Training - Epoch [14/200], Loss: 0.0262
# Beta Model Training - Epoch [15/200], Loss: 0.0251
# Beta Model Training - Epoch [16/200], Loss: 0.0240
# Beta Model Training - Epoch [17/200], Loss: 0.0232
# Beta Model Training - Epoch [18/200], Loss: 0.0227
# Beta Model Training - Epoch [19/200], Loss: 0.0218
# Beta Model Training - Epoch [20/200], Loss: 0.0212
# Beta Model Training - Epoch [21/200], Loss: 0.0208
# Beta Model Training - Epoch [22/200], Loss: 0.0202
# Beta Model Training - Epoch [23/200], Loss: 0.0198
# Beta Model Training - Epoch [24/200], Loss: 0.0193
# Beta Model Training - Epoch [25/200], Loss: 0.0186
# Beta Model Training - Epoch [26/200], Loss: 0.0184
# Beta Model Training - Epoch [27/200], Loss: 0.0185
# Beta Model Training - Epoch [28/200], Loss: 0.0181
# Beta Model Training - Epoch [29/200], Loss: 0.0176
# Beta Model Training - Epoch [30/200], Loss: 0.0176
# Beta Model Training - Epoch [31/200], Loss: 0.0171
# Beta Model Training - Epoch [32/200], Loss: 0.0166
# Beta Model Training - Epoch [33/200], Loss: 0.0162
# Beta Model Training - Epoch [34/200], Loss: 0.0159
# Beta Model Training - Epoch [35/200], Loss: 0.0158
# Beta Model Training - Epoch [36/200], Loss: 0.0155
# Beta Model Training - Epoch [37/200], Loss: 0.0152
# Beta Model Training - Epoch [38/200], Loss: 0.0150
# Beta Model Training - Epoch [39/200], Loss: 0.0147
# Beta Model Training - Epoch [40/200], Loss: 0.0147
# Beta Model Training - Epoch [41/200], Loss: 0.0145
# Beta Model Training - Epoch [42/200], Loss: 0.0145
# Beta Model Training - Epoch [43/200], Loss: 0.0142
# Beta Model Training - Epoch [44/200], Loss: 0.0140
# Beta Model Training - Epoch [45/200], Loss: 0.0140
# Beta Model Training - Epoch [46/200], Loss: 0.0141
# Beta Model Training - Epoch [47/200], Loss: 0.0138
# Beta Model Training - Epoch [48/200], Loss: 0.0136
# Beta Model Training - Epoch [49/200], Loss: 0.0134
# Beta Model Training - Epoch [50/200], Loss: 0.0133
# Beta Model Training - Epoch [51/200], Loss: 0.0131
# Beta Model Training - Epoch [52/200], Loss: 0.0130
# Beta Model Training - Epoch [53/200], Loss: 0.0129
# Beta Model Training - Epoch [54/200], Loss: 0.0128
# Beta Model Training - Epoch [55/200], Loss: 0.0126
# Beta Model Training - Epoch [56/200], Loss: 0.0126
# Beta Model Training - Epoch [57/200], Loss: 0.0126
# Beta Model Training - Epoch [58/200], Loss: 0.0124
# Beta Model Training - Epoch [59/200], Loss: 0.0123
# Beta Model Training - Epoch [60/200], Loss: 0.0122
# Beta Model Training - Epoch [61/200], Loss: 0.0122
# Beta Model Training - Epoch [62/200], Loss: 0.0122
# Beta Model Training - Epoch [63/200], Loss: 0.0121
# Beta Model Training - Epoch [64/200], Loss: 0.0120
# Beta Model Training - Epoch [65/200], Loss: 0.0121
# Beta Model Training - Epoch [66/200], Loss: 0.0120
# Beta Model Training - Epoch [67/200], Loss: 0.0119
# Beta Model Training - Epoch [68/200], Loss: 0.0120
# Beta Model Training - Epoch [69/200], Loss: 0.0120
# Beta Model Training - Epoch [70/200], Loss: 0.0126
# Beta Model Training - Epoch [71/200], Loss: 0.0120
# Beta Model Training - Epoch [72/200], Loss: 0.0117
# Beta Model Training - Epoch [73/200], Loss: 0.0118
# Beta Model Training - Epoch [74/200], Loss: 0.0117
# Beta Model Training - Epoch [75/200], Loss: 0.0115
# Beta Model Training - Epoch [76/200], Loss: 0.0115
# Beta Model Training - Epoch [77/200], Loss: 0.0113
# Beta Model Training - Epoch [78/200], Loss: 0.0113
# Beta Model Training - Epoch [79/200], Loss: 0.0113
# Beta Model Training - Epoch [80/200], Loss: 0.0112
# Beta Model Training - Epoch [81/200], Loss: 0.0111
# Beta Model Training - Epoch [82/200], Loss: 0.0110
# Beta Model Training - Epoch [83/200], Loss: 0.0109
# Beta Model Training - Epoch [84/200], Loss: 0.0109
# Beta Model Training - Epoch [85/200], Loss: 0.0109
# Beta Model Training - Epoch [86/200], Loss: 0.0110
# Beta Model Training - Epoch [87/200], Loss: 0.0108
# Beta Model Training - Epoch [88/200], Loss: 0.0109
# Beta Model Training - Epoch [89/200], Loss: 0.0109
# Beta Model Training - Epoch [90/200], Loss: 0.0109
# Beta Model Training - Epoch [91/200], Loss: 0.0108
# Beta Model Training - Epoch [92/200], Loss: 0.0109
# Beta Model Training - Epoch [93/200], Loss: 0.0111
# Beta Model Training - Epoch [94/200], Loss: 0.0109
# Beta Model Training - Epoch [95/200], Loss: 0.0119
# Beta Model Training - Epoch [96/200], Loss: 0.0118
# Beta Model Training - Epoch [97/200], Loss: 0.0112
# Beta Model Training - Epoch [98/200], Loss: 0.0108
# Beta Model Training - Epoch [99/200], Loss: 0.0106
# Beta Model Training - Epoch [100/200], Loss: 0.0106
# Beta Model Training - Epoch [101/200], Loss: 0.0105
# Beta Model Training - Epoch [102/200], Loss: 0.0105
# Beta Model Training - Epoch [103/200], Loss: 0.0105
# Beta Model Training - Epoch [104/200], Loss: 0.0107
# Beta Model Training - Epoch [105/200], Loss: 0.0108
# Beta Model Training - Epoch [106/200], Loss: 0.0106
# Beta Model Training - Epoch [107/200], Loss: 0.0105
# Beta Model Training - Epoch [108/200], Loss: 0.0104
# Beta Model Training - Epoch [109/200], Loss: 0.0103
# Beta Model Training - Epoch [110/200], Loss: 0.0102
# Beta Model Training - Epoch [111/200], Loss: 0.0101
# Beta Model Training - Epoch [112/200], Loss: 0.0101
# Beta Model Training - Epoch [113/200], Loss: 0.0101
# Beta Model Training - Epoch [114/200], Loss: 0.0101
# Beta Model Training - Epoch [115/200], Loss: 0.0100
# Beta Model Training - Epoch [116/200], Loss: 0.0100
# Beta Model Training - Epoch [117/200], Loss: 0.0100
# Beta Model Training - Epoch [118/200], Loss: 0.0099
# Beta Model Training - Epoch [119/200], Loss: 0.0101
# Beta Model Training - Epoch [120/200], Loss: 0.0100
# Beta Model Training - Epoch [121/200], Loss: 0.0101
# Beta Model Training - Epoch [122/200], Loss: 0.0104
# Beta Model Training - Epoch [123/200], Loss: 0.0104
# Beta Model Training - Epoch [124/200], Loss: 0.0104
# Beta Model Training - Epoch [125/200], Loss: 0.0099
# Beta Model Training - Epoch [126/200], Loss: 0.0099
# Beta Model Training - Epoch [127/200], Loss: 0.0099
# Beta Model Training - Epoch [128/200], Loss: 0.0099
# Beta Model Training - Epoch [129/200], Loss: 0.0099
# Beta Model Training - Epoch [130/200], Loss: 0.0098
# Beta Model Training - Epoch [131/200], Loss: 0.0098
# Beta Model Training - Epoch [132/200], Loss: 0.0098
# Beta Model Training - Epoch [133/200], Loss: 0.0098
# Beta Model Training - Epoch [134/200], Loss: 0.0098
# Beta Model Training - Epoch [135/200], Loss: 0.0097
# Beta Model Training - Epoch [136/200], Loss: 0.0097
# Beta Model Training - Epoch [137/200], Loss: 0.0097
# Beta Model Training - Epoch [138/200], Loss: 0.0097
# Beta Model Training - Epoch [139/200], Loss: 0.0097
# Beta Model Training - Epoch [140/200], Loss: 0.0097
# Beta Model Training - Epoch [141/200], Loss: 0.0097
# Beta Model Training - Epoch [142/200], Loss: 0.0097
# Beta Model Training - Epoch [143/200], Loss: 0.0097
# Beta Model Training - Epoch [144/200], Loss: 0.0098
# Beta Model Training - Epoch [145/200], Loss: 0.0099
# Beta Model Training - Epoch [146/200], Loss: 0.0099
# Beta Model Training - Epoch [147/200], Loss: 0.0098
# Beta Model Training - Epoch [148/200], Loss: 0.0097
# Beta Model Training - Epoch [149/200], Loss: 0.0098
# Beta Model Training - Epoch [150/200], Loss: 0.0097
# Beta Model Training - Epoch [151/200], Loss: 0.0097
# Beta Model Training - Epoch [152/200], Loss: 0.0096
# Beta Model Training - Epoch [153/200], Loss: 0.0097
# Beta Model Training - Epoch [154/200], Loss: 0.0097
# Beta Model Training - Epoch [155/200], Loss: 0.0096
# Beta Model Training - Epoch [156/200], Loss: 0.0097
# Beta Model Training - Epoch [157/200], Loss: 0.0096
# Beta Model Training - Epoch [158/200], Loss: 0.0097
# Beta Model Training - Epoch [159/200], Loss: 0.0096
# Beta Model Training - Epoch [160/200], Loss: 0.0096
# Beta Model Training - Epoch [161/200], Loss: 0.0096
# Beta Model Training - Epoch [162/200], Loss: 0.0095
# Beta Model Training - Epoch [163/200], Loss: 0.0095
# Beta Model Training - Epoch [164/200], Loss: 0.0095
# Beta Model Training - Epoch [165/200], Loss: 0.0095
# Beta Model Training - Epoch [166/200], Loss: 0.0095
# Beta Model Training - Epoch [167/200], Loss: 0.0095
# Beta Model Training - Epoch [168/200], Loss: 0.0095
# Beta Model Training - Epoch [169/200], Loss: 0.0096
# Beta Model Training - Epoch [170/200], Loss: 0.0095
# Beta Model Training - Epoch [171/200], Loss: 0.0095
# Beta Model Training - Epoch [172/200], Loss: 0.0095
# Beta Model Training - Epoch [173/200], Loss: 0.0095
# Beta Model Training - Epoch [174/200], Loss: 0.0095
# Beta Model Training - Epoch [175/200], Loss: 0.0094
# Beta Model Training - Epoch [176/200], Loss: 0.0095
# Beta Model Training - Epoch [177/200], Loss: 0.0095
# Beta Model Training - Epoch [178/200], Loss: 0.0096
# Beta Model Training - Epoch [179/200], Loss: 0.0095
# Beta Model Training - Epoch [180/200], Loss: 0.0095
# Beta Model Training - Epoch [181/200], Loss: 0.0095
# Beta Model Training - Epoch [182/200], Loss: 0.0095
# Beta Model Training - Epoch [183/200], Loss: 0.0094
# Beta Model Training - Epoch [184/200], Loss: 0.0094
# Beta Model Training - Epoch [185/200], Loss: 0.0094
# Beta Model Training - Epoch [186/200], Loss: 0.0094
# Beta Model Training - Epoch [187/200], Loss: 0.0094
# Beta Model Training - Epoch [188/200], Loss: 0.0093
# Beta Model Training - Epoch [189/200], Loss: 0.0093
# Beta Model Training - Epoch [190/200], Loss: 0.0093
# Beta Model Training - Epoch [191/200], Loss: 0.0094
# Beta Model Training - Epoch [192/200], Loss: 0.0094
# Beta Model Training - Epoch [193/200], Loss: 0.0094
# Beta Model Training - Epoch [194/200], Loss: 0.0094
# Beta Model Training - Epoch [195/200], Loss: 0.0094
# Beta Model Training - Epoch [196/200], Loss: 0.0094
# Beta Model Training - Epoch [197/200], Loss: 0.0094
# Beta Model Training - Epoch [198/200], Loss: 0.0093
# Beta Model Training - Epoch [199/200], Loss: 0.0093
# Beta Model Training - Epoch [200/200], Loss: 0.0093
#
# === Building dataset/model for Beta 1 ===
# Beta Model Training - Epoch [1/200], Loss: 0.0659
# Beta Model Training - Epoch [2/200], Loss: 0.0511
# Beta Model Training - Epoch [3/200], Loss: 0.0407
# Beta Model Training - Epoch [4/200], Loss: 0.0350
# Beta Model Training - Epoch [5/200], Loss: 0.0313
# Beta Model Training - Epoch [6/200], Loss: 0.0284
# Beta Model Training - Epoch [7/200], Loss: 0.0255
# Beta Model Training - Epoch [8/200], Loss: 0.0231
# Beta Model Training - Epoch [9/200], Loss: 0.0213
# Beta Model Training - Epoch [10/200], Loss: 0.0197
# Beta Model Training - Epoch [11/200], Loss: 0.0186
# Beta Model Training - Epoch [12/200], Loss: 0.0177
# Beta Model Training - Epoch [13/200], Loss: 0.0169
# Beta Model Training - Epoch [14/200], Loss: 0.0162
# Beta Model Training - Epoch [15/200], Loss: 0.0153
# Beta Model Training - Epoch [16/200], Loss: 0.0147
# Beta Model Training - Epoch [17/200], Loss: 0.0142
# Beta Model Training - Epoch [18/200], Loss: 0.0135
# Beta Model Training - Epoch [19/200], Loss: 0.0131
# Beta Model Training - Epoch [20/200], Loss: 0.0126
# Beta Model Training - Epoch [21/200], Loss: 0.0122
# Beta Model Training - Epoch [22/200], Loss: 0.0119
# Beta Model Training - Epoch [23/200], Loss: 0.0116
# Beta Model Training - Epoch [24/200], Loss: 0.0113
# Beta Model Training - Epoch [25/200], Loss: 0.0111
# Beta Model Training - Epoch [26/200], Loss: 0.0108
# Beta Model Training - Epoch [27/200], Loss: 0.0104
# Beta Model Training - Epoch [28/200], Loss: 0.0103
# Beta Model Training - Epoch [29/200], Loss: 0.0102
# Beta Model Training - Epoch [30/200], Loss: 0.0101
# Beta Model Training - Epoch [31/200], Loss: 0.0102
# Beta Model Training - Epoch [32/200], Loss: 0.0100
# Beta Model Training - Epoch [33/200], Loss: 0.0100
# Beta Model Training - Epoch [34/200], Loss: 0.0097
# Beta Model Training - Epoch [35/200], Loss: 0.0094
# Beta Model Training - Epoch [36/200], Loss: 0.0092
# Beta Model Training - Epoch [37/200], Loss: 0.0090
# Beta Model Training - Epoch [38/200], Loss: 0.0089
# Beta Model Training - Epoch [39/200], Loss: 0.0088
# Beta Model Training - Epoch [40/200], Loss: 0.0087
# Beta Model Training - Epoch [41/200], Loss: 0.0086
# Beta Model Training - Epoch [42/200], Loss: 0.0085
# Beta Model Training - Epoch [43/200], Loss: 0.0085
# Beta Model Training - Epoch [44/200], Loss: 0.0083
# Beta Model Training - Epoch [45/200], Loss: 0.0081
# Beta Model Training - Epoch [46/200], Loss: 0.0080
# Beta Model Training - Epoch [47/200], Loss: 0.0079
# Beta Model Training - Epoch [48/200], Loss: 0.0079
# Beta Model Training - Epoch [49/200], Loss: 0.0078
# Beta Model Training - Epoch [50/200], Loss: 0.0079
# Beta Model Training - Epoch [51/200], Loss: 0.0079
# Beta Model Training - Epoch [52/200], Loss: 0.0078
# Beta Model Training - Epoch [53/200], Loss: 0.0076
# Beta Model Training - Epoch [54/200], Loss: 0.0077
# Beta Model Training - Epoch [55/200], Loss: 0.0076
# Beta Model Training - Epoch [56/200], Loss: 0.0075
# Beta Model Training - Epoch [57/200], Loss: 0.0073
# Beta Model Training - Epoch [58/200], Loss: 0.0072
# Beta Model Training - Epoch [59/200], Loss: 0.0071
# Beta Model Training - Epoch [60/200], Loss: 0.0070
# Beta Model Training - Epoch [61/200], Loss: 0.0070
# Beta Model Training - Epoch [62/200], Loss: 0.0069
# Beta Model Training - Epoch [63/200], Loss: 0.0069
# Beta Model Training - Epoch [64/200], Loss: 0.0068
# Beta Model Training - Epoch [65/200], Loss: 0.0068
# Beta Model Training - Epoch [66/200], Loss: 0.0067
# Beta Model Training - Epoch [67/200], Loss: 0.0067
# Beta Model Training - Epoch [68/200], Loss: 0.0066
# Beta Model Training - Epoch [69/200], Loss: 0.0067
# Beta Model Training - Epoch [70/200], Loss: 0.0066
# Beta Model Training - Epoch [71/200], Loss: 0.0066
# Beta Model Training - Epoch [72/200], Loss: 0.0067
# Beta Model Training - Epoch [73/200], Loss: 0.0065
# Beta Model Training - Epoch [74/200], Loss: 0.0066
# Beta Model Training - Epoch [75/200], Loss: 0.0064
# Beta Model Training - Epoch [76/200], Loss: 0.0064
# Beta Model Training - Epoch [77/200], Loss: 0.0064
# Beta Model Training - Epoch [78/200], Loss: 0.0064
# Beta Model Training - Epoch [79/200], Loss: 0.0064
# Beta Model Training - Epoch [80/200], Loss: 0.0063
# Beta Model Training - Epoch [81/200], Loss: 0.0062
# Beta Model Training - Epoch [82/200], Loss: 0.0062
# Beta Model Training - Epoch [83/200], Loss: 0.0061
# Beta Model Training - Epoch [84/200], Loss: 0.0061
# Beta Model Training - Epoch [85/200], Loss: 0.0061
# Beta Model Training - Epoch [86/200], Loss: 0.0061
# Beta Model Training - Epoch [87/200], Loss: 0.0061
# Beta Model Training - Epoch [88/200], Loss: 0.0061
# Beta Model Training - Epoch [89/200], Loss: 0.0061
# Beta Model Training - Epoch [90/200], Loss: 0.0062
# Beta Model Training - Epoch [91/200], Loss: 0.0061
# Beta Model Training - Epoch [92/200], Loss: 0.0060
# Beta Model Training - Epoch [93/200], Loss: 0.0060
# Beta Model Training - Epoch [94/200], Loss: 0.0060
# Beta Model Training - Epoch [95/200], Loss: 0.0060
# Beta Model Training - Epoch [96/200], Loss: 0.0059
# Beta Model Training - Epoch [97/200], Loss: 0.0060
# Beta Model Training - Epoch [98/200], Loss: 0.0061
# Beta Model Training - Epoch [99/200], Loss: 0.0062
# Beta Model Training - Epoch [100/200], Loss: 0.0061
# Beta Model Training - Epoch [101/200], Loss: 0.0060
# Beta Model Training - Epoch [102/200], Loss: 0.0059
# Beta Model Training - Epoch [103/200], Loss: 0.0059
# Beta Model Training - Epoch [104/200], Loss: 0.0059
# Beta Model Training - Epoch [105/200], Loss: 0.0058
# Beta Model Training - Epoch [106/200], Loss: 0.0061
# Beta Model Training - Epoch [107/200], Loss: 0.0060
# Beta Model Training - Epoch [108/200], Loss: 0.0061
# Beta Model Training - Epoch [109/200], Loss: 0.0063
# Beta Model Training - Epoch [110/200], Loss: 0.0061
# Beta Model Training - Epoch [111/200], Loss: 0.0058
# Beta Model Training - Epoch [112/200], Loss: 0.0057
# Beta Model Training - Epoch [113/200], Loss: 0.0057
# Beta Model Training - Epoch [114/200], Loss: 0.0057
# Beta Model Training - Epoch [115/200], Loss: 0.0056
# Beta Model Training - Epoch [116/200], Loss: 0.0056
# Beta Model Training - Epoch [117/200], Loss: 0.0056
# Beta Model Training - Epoch [118/200], Loss: 0.0056
# Beta Model Training - Epoch [119/200], Loss: 0.0056
# Beta Model Training - Epoch [120/200], Loss: 0.0055
# Beta Model Training - Epoch [121/200], Loss: 0.0055
# Beta Model Training - Epoch [122/200], Loss: 0.0055
# Beta Model Training - Epoch [123/200], Loss: 0.0055
# Beta Model Training - Epoch [124/200], Loss: 0.0054
# Beta Model Training - Epoch [125/200], Loss: 0.0054
# Beta Model Training - Epoch [126/200], Loss: 0.0054
# Beta Model Training - Epoch [127/200], Loss: 0.0054
# Beta Model Training - Epoch [128/200], Loss: 0.0054
# Beta Model Training - Epoch [129/200], Loss: 0.0054
# Beta Model Training - Epoch [130/200], Loss: 0.0054
# Beta Model Training - Epoch [131/200], Loss: 0.0054
# Beta Model Training - Epoch [132/200], Loss: 0.0054
# Beta Model Training - Epoch [133/200], Loss: 0.0054
# Beta Model Training - Epoch [134/200], Loss: 0.0054
# Beta Model Training - Epoch [135/200], Loss: 0.0054
# Beta Model Training - Epoch [136/200], Loss: 0.0054
# Beta Model Training - Epoch [137/200], Loss: 0.0056
# Beta Model Training - Epoch [138/200], Loss: 0.0056
# Beta Model Training - Epoch [139/200], Loss: 0.0055
# Beta Model Training - Epoch [140/200], Loss: 0.0054
# Beta Model Training - Epoch [141/200], Loss: 0.0054
# Beta Model Training - Epoch [142/200], Loss: 0.0053
# Beta Model Training - Epoch [143/200], Loss: 0.0053
# Beta Model Training - Epoch [144/200], Loss: 0.0053
# Beta Model Training - Epoch [145/200], Loss: 0.0052
# Beta Model Training - Epoch [146/200], Loss: 0.0052
# Beta Model Training - Epoch [147/200], Loss: 0.0052
# Beta Model Training - Epoch [148/200], Loss: 0.0052
# Beta Model Training - Epoch [149/200], Loss: 0.0052
# Beta Model Training - Epoch [150/200], Loss: 0.0052
# Beta Model Training - Epoch [151/200], Loss: 0.0052
# Beta Model Training - Epoch [152/200], Loss: 0.0052
# Beta Model Training - Epoch [153/200], Loss: 0.0052
# Beta Model Training - Epoch [154/200], Loss: 0.0052
# Beta Model Training - Epoch [155/200], Loss: 0.0051
# Beta Model Training - Epoch [156/200], Loss: 0.0051
# Beta Model Training - Epoch [157/200], Loss: 0.0051
# Beta Model Training - Epoch [158/200], Loss: 0.0051
# Beta Model Training - Epoch [159/200], Loss: 0.0051
# Beta Model Training - Epoch [160/200], Loss: 0.0051
# Beta Model Training - Epoch [161/200], Loss: 0.0051
# Beta Model Training - Epoch [162/200], Loss: 0.0051
# Beta Model Training - Epoch [163/200], Loss: 0.0051
# Beta Model Training - Epoch [164/200], Loss: 0.0051
# Beta Model Training - Epoch [165/200], Loss: 0.0051
# Beta Model Training - Epoch [166/200], Loss: 0.0051
# Beta Model Training - Epoch [167/200], Loss: 0.0051
# Beta Model Training - Epoch [168/200], Loss: 0.0051
# Beta Model Training - Epoch [169/200], Loss: 0.0050
# Beta Model Training - Epoch [170/200], Loss: 0.0051
# Beta Model Training - Epoch [171/200], Loss: 0.0051
# Beta Model Training - Epoch [172/200], Loss: 0.0050
# Beta Model Training - Epoch [173/200], Loss: 0.0051
# Beta Model Training - Epoch [174/200], Loss: 0.0051
# Beta Model Training - Epoch [175/200], Loss: 0.0052
# Beta Model Training - Epoch [176/200], Loss: 0.0051
# Beta Model Training - Epoch [177/200], Loss: 0.0051
# Beta Model Training - Epoch [178/200], Loss: 0.0052
# Beta Model Training - Epoch [179/200], Loss: 0.0051
# Beta Model Training - Epoch [180/200], Loss: 0.0051
# Beta Model Training - Epoch [181/200], Loss: 0.0051
# Beta Model Training - Epoch [182/200], Loss: 0.0052
# Beta Model Training - Epoch [183/200], Loss: 0.0051
# Beta Model Training - Epoch [184/200], Loss: 0.0051
# Beta Model Training - Epoch [185/200], Loss: 0.0050
# Beta Model Training - Epoch [186/200], Loss: 0.0051
# Beta Model Training - Epoch [187/200], Loss: 0.0050
# Beta Model Training - Epoch [188/200], Loss: 0.0051
# Beta Model Training - Epoch [189/200], Loss: 0.0051
# Beta Model Training - Epoch [190/200], Loss: 0.0051
# Beta Model Training - Epoch [191/200], Loss: 0.0053
# Beta Model Training - Epoch [192/200], Loss: 0.0055
# Beta Model Training - Epoch [193/200], Loss: 0.0055
# Beta Model Training - Epoch [194/200], Loss: 0.0052
# Beta Model Training - Epoch [195/200], Loss: 0.0052
# Beta Model Training - Epoch [196/200], Loss: 0.0053
# Beta Model Training - Epoch [197/200], Loss: 0.0052
# Beta Model Training - Epoch [198/200], Loss: 0.0051
# Beta Model Training - Epoch [199/200], Loss: 0.0050
# Beta Model Training - Epoch [200/200], Loss: 0.0050
#
# === Building dataset/model for Beta 2 ===
# Beta Model Training - Epoch [1/200], Loss: 0.0719
# Beta Model Training - Epoch [2/200], Loss: 0.0536
# Beta Model Training - Epoch [3/200], Loss: 0.0406
# Beta Model Training - Epoch [4/200], Loss: 0.0345
# Beta Model Training - Epoch [5/200], Loss: 0.0296
# Beta Model Training - Epoch [6/200], Loss: 0.0262
# Beta Model Training - Epoch [7/200], Loss: 0.0242
# Beta Model Training - Epoch [8/200], Loss: 0.0227
# Beta Model Training - Epoch [9/200], Loss: 0.0213
# Beta Model Training - Epoch [10/200], Loss: 0.0199
# Beta Model Training - Epoch [11/200], Loss: 0.0181
# Beta Model Training - Epoch [12/200], Loss: 0.0167
# Beta Model Training - Epoch [13/200], Loss: 0.0159
# Beta Model Training - Epoch [14/200], Loss: 0.0152
# Beta Model Training - Epoch [15/200], Loss: 0.0145
# Beta Model Training - Epoch [16/200], Loss: 0.0137
# Beta Model Training - Epoch [17/200], Loss: 0.0128
# Beta Model Training - Epoch [18/200], Loss: 0.0123
# Beta Model Training - Epoch [19/200], Loss: 0.0115
# Beta Model Training - Epoch [20/200], Loss: 0.0111
# Beta Model Training - Epoch [21/200], Loss: 0.0108
# Beta Model Training - Epoch [22/200], Loss: 0.0104
# Beta Model Training - Epoch [23/200], Loss: 0.0101
# Beta Model Training - Epoch [24/200], Loss: 0.0098
# Beta Model Training - Epoch [25/200], Loss: 0.0096
# Beta Model Training - Epoch [26/200], Loss: 0.0093
# Beta Model Training - Epoch [27/200], Loss: 0.0091
# Beta Model Training - Epoch [28/200], Loss: 0.0091
# Beta Model Training - Epoch [29/200], Loss: 0.0088
# Beta Model Training - Epoch [30/200], Loss: 0.0087
# Beta Model Training - Epoch [31/200], Loss: 0.0085
# Beta Model Training - Epoch [32/200], Loss: 0.0084
# Beta Model Training - Epoch [33/200], Loss: 0.0083
# Beta Model Training - Epoch [34/200], Loss: 0.0082
# Beta Model Training - Epoch [35/200], Loss: 0.0078
# Beta Model Training - Epoch [36/200], Loss: 0.0076
# Beta Model Training - Epoch [37/200], Loss: 0.0075
# Beta Model Training - Epoch [38/200], Loss: 0.0074
# Beta Model Training - Epoch [39/200], Loss: 0.0074
# Beta Model Training - Epoch [40/200], Loss: 0.0072
# Beta Model Training - Epoch [41/200], Loss: 0.0071
# Beta Model Training - Epoch [42/200], Loss: 0.0069
# Beta Model Training - Epoch [43/200], Loss: 0.0068
# Beta Model Training - Epoch [44/200], Loss: 0.0067
# Beta Model Training - Epoch [45/200], Loss: 0.0066
# Beta Model Training - Epoch [46/200], Loss: 0.0065
# Beta Model Training - Epoch [47/200], Loss: 0.0064
# Beta Model Training - Epoch [48/200], Loss: 0.0064
# Beta Model Training - Epoch [49/200], Loss: 0.0063
# Beta Model Training - Epoch [50/200], Loss: 0.0062
# Beta Model Training - Epoch [51/200], Loss: 0.0062
# Beta Model Training - Epoch [52/200], Loss: 0.0061
# Beta Model Training - Epoch [53/200], Loss: 0.0061
# Beta Model Training - Epoch [54/200], Loss: 0.0061
# Beta Model Training - Epoch [55/200], Loss: 0.0061
# Beta Model Training - Epoch [56/200], Loss: 0.0060
# Beta Model Training - Epoch [57/200], Loss: 0.0059
# Beta Model Training - Epoch [58/200], Loss: 0.0059
# Beta Model Training - Epoch [59/200], Loss: 0.0058
# Beta Model Training - Epoch [60/200], Loss: 0.0058
# Beta Model Training - Epoch [61/200], Loss: 0.0057
# Beta Model Training - Epoch [62/200], Loss: 0.0059
# Beta Model Training - Epoch [63/200], Loss: 0.0059
# Beta Model Training - Epoch [64/200], Loss: 0.0058
# Beta Model Training - Epoch [65/200], Loss: 0.0058
# Beta Model Training - Epoch [66/200], Loss: 0.0057
# Beta Model Training - Epoch [67/200], Loss: 0.0056
# Beta Model Training - Epoch [68/200], Loss: 0.0056
# Beta Model Training - Epoch [69/200], Loss: 0.0055
# Beta Model Training - Epoch [70/200], Loss: 0.0059
# Beta Model Training - Epoch [71/200], Loss: 0.0063
# Beta Model Training - Epoch [72/200], Loss: 0.0060
# Beta Model Training - Epoch [73/200], Loss: 0.0061
# Beta Model Training - Epoch [74/200], Loss: 0.0057
# Beta Model Training - Epoch [75/200], Loss: 0.0054
# Beta Model Training - Epoch [76/200], Loss: 0.0052
# Beta Model Training - Epoch [77/200], Loss: 0.0051
# Beta Model Training - Epoch [78/200], Loss: 0.0052
# Beta Model Training - Epoch [79/200], Loss: 0.0052
# Beta Model Training - Epoch [80/200], Loss: 0.0051
# Beta Model Training - Epoch [81/200], Loss: 0.0050
# Beta Model Training - Epoch [82/200], Loss: 0.0050
# Beta Model Training - Epoch [83/200], Loss: 0.0049
# Beta Model Training - Epoch [84/200], Loss: 0.0050
# Beta Model Training - Epoch [85/200], Loss: 0.0051
# Beta Model Training - Epoch [86/200], Loss: 0.0049
# Beta Model Training - Epoch [87/200], Loss: 0.0049
# Beta Model Training - Epoch [88/200], Loss: 0.0050
# Beta Model Training - Epoch [89/200], Loss: 0.0048
# Beta Model Training - Epoch [90/200], Loss: 0.0048
# Beta Model Training - Epoch [91/200], Loss: 0.0047
# Beta Model Training - Epoch [92/200], Loss: 0.0046
# Beta Model Training - Epoch [93/200], Loss: 0.0045
# Beta Model Training - Epoch [94/200], Loss: 0.0045
# Beta Model Training - Epoch [95/200], Loss: 0.0045
# Beta Model Training - Epoch [96/200], Loss: 0.0044
# Beta Model Training - Epoch [97/200], Loss: 0.0044
# Beta Model Training - Epoch [98/200], Loss: 0.0044
# Beta Model Training - Epoch [99/200], Loss: 0.0044
# Beta Model Training - Epoch [100/200], Loss: 0.0043
# Beta Model Training - Epoch [101/200], Loss: 0.0043
# Beta Model Training - Epoch [102/200], Loss: 0.0043
# Beta Model Training - Epoch [103/200], Loss: 0.0042
# Beta Model Training - Epoch [104/200], Loss: 0.0042
# Beta Model Training - Epoch [105/200], Loss: 0.0042
# Beta Model Training - Epoch [106/200], Loss: 0.0042
# Beta Model Training - Epoch [107/200], Loss: 0.0042
# Beta Model Training - Epoch [108/200], Loss: 0.0042
# Beta Model Training - Epoch [109/200], Loss: 0.0042
# Beta Model Training - Epoch [110/200], Loss: 0.0042
# Beta Model Training - Epoch [111/200], Loss: 0.0041
# Beta Model Training - Epoch [112/200], Loss: 0.0041
# Beta Model Training - Epoch [113/200], Loss: 0.0041
# Beta Model Training - Epoch [114/200], Loss: 0.0041
# Beta Model Training - Epoch [115/200], Loss: 0.0041
# Beta Model Training - Epoch [116/200], Loss: 0.0041
# Beta Model Training - Epoch [117/200], Loss: 0.0041
# Beta Model Training - Epoch [118/200], Loss: 0.0041
# Beta Model Training - Epoch [119/200], Loss: 0.0041
# Beta Model Training - Epoch [120/200], Loss: 0.0041
# Beta Model Training - Epoch [121/200], Loss: 0.0040
# Beta Model Training - Epoch [122/200], Loss: 0.0040
# Beta Model Training - Epoch [123/200], Loss: 0.0040
# Beta Model Training - Epoch [124/200], Loss: 0.0040
# Beta Model Training - Epoch [125/200], Loss: 0.0039
# Beta Model Training - Epoch [126/200], Loss: 0.0039
# Beta Model Training - Epoch [127/200], Loss: 0.0039
# Beta Model Training - Epoch [128/200], Loss: 0.0039
# Beta Model Training - Epoch [129/200], Loss: 0.0039
# Beta Model Training - Epoch [130/200], Loss: 0.0039
# Beta Model Training - Epoch [131/200], Loss: 0.0039
# Beta Model Training - Epoch [132/200], Loss: 0.0040
# Beta Model Training - Epoch [133/200], Loss: 0.0040
# Beta Model Training - Epoch [134/200], Loss: 0.0041
# Beta Model Training - Epoch [135/200], Loss: 0.0040
# Beta Model Training - Epoch [136/200], Loss: 0.0040
# Beta Model Training - Epoch [137/200], Loss: 0.0039
# Beta Model Training - Epoch [138/200], Loss: 0.0039
# Beta Model Training - Epoch [139/200], Loss: 0.0038
# Beta Model Training - Epoch [140/200], Loss: 0.0039
# Beta Model Training - Epoch [141/200], Loss: 0.0039
# Beta Model Training - Epoch [142/200], Loss: 0.0038
# Beta Model Training - Epoch [143/200], Loss: 0.0038
# Beta Model Training - Epoch [144/200], Loss: 0.0038
# Beta Model Training - Epoch [145/200], Loss: 0.0038
# Beta Model Training - Epoch [146/200], Loss: 0.0039
# Beta Model Training - Epoch [147/200], Loss: 0.0039
# Beta Model Training - Epoch [148/200], Loss: 0.0038
# Beta Model Training - Epoch [149/200], Loss: 0.0038
# Beta Model Training - Epoch [150/200], Loss: 0.0037
# Beta Model Training - Epoch [151/200], Loss: 0.0037
# Beta Model Training - Epoch [152/200], Loss: 0.0037
# Beta Model Training - Epoch [153/200], Loss: 0.0037
# Beta Model Training - Epoch [154/200], Loss: 0.0036
# Beta Model Training - Epoch [155/200], Loss: 0.0036
# Beta Model Training - Epoch [156/200], Loss: 0.0036
# Beta Model Training - Epoch [157/200], Loss: 0.0037
# Beta Model Training - Epoch [158/200], Loss: 0.0037
# Beta Model Training - Epoch [159/200], Loss: 0.0036
# Beta Model Training - Epoch [160/200], Loss: 0.0036
# Beta Model Training - Epoch [161/200], Loss: 0.0036
# Beta Model Training - Epoch [162/200], Loss: 0.0036
# Beta Model Training - Epoch [163/200], Loss: 0.0036
# Beta Model Training - Epoch [164/200], Loss: 0.0035
# Beta Model Training - Epoch [165/200], Loss: 0.0036
# Beta Model Training - Epoch [166/200], Loss: 0.0036
# Beta Model Training - Epoch [167/200], Loss: 0.0036
# Beta Model Training - Epoch [168/200], Loss: 0.0036
# Beta Model Training - Epoch [169/200], Loss: 0.0037
# Beta Model Training - Epoch [170/200], Loss: 0.0037
# Beta Model Training - Epoch [171/200], Loss: 0.0037
# Beta Model Training - Epoch [172/200], Loss: 0.0036
# Beta Model Training - Epoch [173/200], Loss: 0.0037
# Beta Model Training - Epoch [174/200], Loss: 0.0037
# Beta Model Training - Epoch [175/200], Loss: 0.0036
# Beta Model Training - Epoch [176/200], Loss: 0.0036
# Beta Model Training - Epoch [177/200], Loss: 0.0035
# Beta Model Training - Epoch [178/200], Loss: 0.0036
# Beta Model Training - Epoch [179/200], Loss: 0.0036
# Beta Model Training - Epoch [180/200], Loss: 0.0035
# Beta Model Training - Epoch [181/200], Loss: 0.0035
# Beta Model Training - Epoch [182/200], Loss: 0.0037
# Beta Model Training - Epoch [183/200], Loss: 0.0043
# Beta Model Training - Epoch [184/200], Loss: 0.0041
# Beta Model Training - Epoch [185/200], Loss: 0.0039
# Beta Model Training - Epoch [186/200], Loss: 0.0043
# Beta Model Training - Epoch [187/200], Loss: 0.0042
# Beta Model Training - Epoch [188/200], Loss: 0.0042
# Beta Model Training - Epoch [189/200], Loss: 0.0039
# Beta Model Training - Epoch [190/200], Loss: 0.0037
# Beta Model Training - Epoch [191/200], Loss: 0.0036
# Beta Model Training - Epoch [192/200], Loss: 0.0035
# Beta Model Training - Epoch [193/200], Loss: 0.0035
# Beta Model Training - Epoch [194/200], Loss: 0.0035
# Beta Model Training - Epoch [195/200], Loss: 0.0035
# Beta Model Training - Epoch [196/200], Loss: 0.0035
# Beta Model Training - Epoch [197/200], Loss: 0.0034
# Beta Model Training - Epoch [198/200], Loss: 0.0034
# Beta Model Training - Epoch [199/200], Loss: 0.0034
# Beta Model Training - Epoch [200/200], Loss: 0.0034

# %%
# save importances results
save_dir = os.path.join(curr_dir, analysis_type, 'Masking')
os.makedirs(save_dir, exist_ok=True)

save_subdir_chan = os.path.join(save_dir, 'Channel Masking')
os.makedirs(save_subdir_chan, exist_ok=True)

save_subdir_region = os.path.join(save_dir, 'Region Masking')
os.makedirs(save_subdir_region, exist_ok=True)

imp_chan_zero_data = {'all_imp_chan_zero': all_imp_chan_zero}
imp_chan_mean_data = {'all_imp_chan_mean': all_imp_chan_mean}
imp_region_localmean_data = {'all_imp_region_localmean': all_imp_region_localmean}
imp_region_globalmean_data = {'all_imp_region_globalmean': all_imp_region_globalmean}

savemat(os.path.join(save_subdir_chan, 'imp_chan_zero.mat'), imp_chan_zero_data)
savemat(os.path.join(save_subdir_chan, 'imp_chan_mean.mat'), imp_chan_mean_data)
savemat(os.path.join(save_subdir_region, 'imp_region_localmean.mat'), imp_region_localmean_data)
savemat(os.path.join(save_subdir_region, 'imp_region_globalmean.mat'), imp_region_globalmean_data)

# %%
save_dir = os.path.join(curr_dir, analysis_type, 'Masking')
save_subdir_chan = os.path.join(save_dir, 'Channel Masking')
save_subdir_region = os.path.join(save_dir, 'Region Masking')

all_imp_chan_zero = loadmat(os.path.join(save_subdir_chan, 'imp_chan_zero.mat'))['all_imp_chan_zero']
all_imp_chan_mean = loadmat(os.path.join(save_subdir_chan, 'imp_chan_mean.mat'))['all_imp_chan_mean']
all_imp_region_localmean = loadmat(os.path.join(save_subdir_region, 'imp_region_localmean.mat'))['all_imp_region_localmean']
all_imp_region_globalmean = loadmat(os.path.join(save_subdir_region, 'imp_region_globalmean.mat'))['all_imp_region_globalmean']
print(save_dir)
# Out:
# e:\MThesis\GAEtesting\N400\Masking

# %%
# Visualize the importance across Betas
def visualize_importance_across_betas(data, savepath, lablename='Channel Index'):
    norm_all_imp_node = np.zeros_like(data, dtype=float)

    for iBeta in range(nBeta):
        value = data[iBeta]
        max_abs = np.max(np.abs(value))
        if max_abs > 0:
            norm_all_imp_node[iBeta] = value / max_abs
        else:
            norm_all_imp_node[iBeta] = value
    
    agg_imp = norm_all_imp_node.mean(axis=0)
    nChan = len(agg_imp)
    x = np.arange(nChan)
    fig, ax = plt.subplots(figsize=(10, 6))
    bars = ax.bar(x, agg_imp)
    # Set axis labels & ticks
    ax.set_xticks(np.arange(nChan))
    ax.set_xticklabels(np.arange(1, nChan + 1), fontsize=14)
    ax.tick_params(axis='x', labelsize=12, rotation=0)
    ax.tick_params(axis='y', labelsize=12)
    ax.set_xlabel(lablename, fontsize=16)
    ax.set_ylabel('Aggregated Importance', fontsize=16)
    plt.title(f'{analysis_type} Aggregated Importance across Betas', fontsize=18, pad=10)
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.grid(axis='y', linestyle='--', alpha=0.4)
    fig.tight_layout()
    
    fig.savefig(savepath, dpi=300)
    plt.close(fig)

# %%
# Visualize importances of channel masking

def visualize_channel_importance(data, analysis_type, save_path, method, target='channel'):
    print("shape of input data:", data.shape)

    global_max = np.percentile(data, 97)
    global_min = np.min(data)
    # [nBeta, nChan], mean across subjects
    values = data.mean(axis=1) 
    
    visualize_importance_across_betas(values,
        os.path.join(save_path, f'{analysis_type}_Aggregated_Importance_{target.capitalize()}_{method.capitalize()}.png'),
        lablename='Channel Index')

    fig, ax = plt.subplots(figsize=(10, 6))

    im = ax.imshow(
        values,
        aspect='auto',
        origin='lower',
        cmap='Reds',
        vmin=global_min,
        vmax=global_max
    )

    # Set axis labels, font sizes, and title
    ax.set_xlabel(target.capitalize(), fontsize=16)
    ax.set_ylabel('Beta Index', fontsize=16)
    ax.set_title(f'{analysis_type} – {target.capitalize()}-{method.capitalize()}',
                fontsize=18, pad=10)

    # Customize tick labels
    ax.set_xticks(np.arange(nChan))
    ax.set_xticklabels(np.arange(1, nChan + 1), fontsize=10)
    ax.set_yticks(np.arange(nBeta))
    ax.set_yticklabels(np.arange(1, nBeta + 1), fontsize=12)

    # Remove top and right spines
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)

    # Add colorbar
    cbar = fig.colorbar(im, ax=ax, pad=0.02)
    cbar.set_label('Importance', fontsize=14)
    cbar.ax.tick_params(labelsize=12)

    fig.tight_layout()
    fig.savefig(
        os.path.join(save_path, f'{analysis_type}_{target.capitalize()}_Importance_{method.capitalize()}.png'),
        dpi=300
    )
    plt.close(fig)


    for iBeta in range(nBeta):
        # Mean across subjects
        values = data[iBeta].mean(axis=0)

        fig, ax = plt.subplots(figsize=(10, 6))

        x = np.arange(nChan)
        ax.bar(x, values)

        # Set axis labels, font sizes, and title
        ax.set_xticks(x)
        ax.set_xticklabels(np.arange(1, nChan + 1))
        ax.tick_params(axis='x', labelsize=10)
        ax.tick_params(axis='y', labelsize=10)

        ax.set_xlabel(f'Channel index', fontsize=18)
        ax.set_ylabel('Importance', fontsize=18)
        ax.set_ylim(global_min, global_max)
        ax.set_title(
            f'{analysis_type} Beta {iBeta+1} {target.capitalize()}-{method.capitalize()}',
            fontsize=14,
            pad=12
        )

        # Remove top and right spines
        ax.spines['top'].set_visible(False)
        ax.spines['right'].set_visible(False)
        # Add grid lines for y-axis
        ax.grid(axis='y', linestyle='--', alpha=0.4)

        # Save figure
        fig.tight_layout()
        fig.savefig(os.path.join(save_path, f'{analysis_type}_Beta_{iBeta+1}_{target.capitalize()}_Importance_{method.capitalize()}.png'), dpi=300)
        plt.close(fig)

# %%
visualize_channel_importance(all_imp_chan_zero, analysis_type, save_subdir_chan, method='zero', target='channel')
visualize_channel_importance(all_imp_chan_mean, analysis_type, save_subdir_chan, method='mean', target='channel')
visualize_channel_importance(all_imp_region_localmean, analysis_type, save_subdir_region, method='local_mean', target='region')
visualize_channel_importance(all_imp_region_globalmean, analysis_type, save_subdir_region, method='global_mean', target='region')
# Out:
# shape of input data: (9, 40, 30)
# shape of input data: (9, 40, 30)
# shape of input data: (9, 40, 30)
# shape of input data: (9, 40, 30)

# %%
test = compute_neighborhood_channels(edge_index, k=1)
for i in range(len(test)):
    nbrs = [int(x) + 1 for x in test[i]]
    degree = len(nbrs) - 1  # exclude self
    print(f"Channel {i+1}: Neighbors {nbrs}, Degree {degree}")
# Out:
# Channel 1: Neighbors [1, 2, 3, 16, 17], Degree 4
# Channel 2: Neighbors [1, 2, 3, 4, 17, 21], Degree 5
# Channel 3: Neighbors [1, 2, 3, 4, 6], Degree 4
# Channel 4: Neighbors [2, 3, 4, 5, 6, 17, 21, 22], Degree 7
# Channel 5: Neighbors [4, 5, 6, 7, 8, 15, 21, 22], Degree 7
# Channel 6: Neighbors [3, 4, 5, 6, 7, 8, 9], Degree 6
# Channel 7: Neighbors [5, 6, 7, 8, 10, 11, 14, 15], Degree 7
# Channel 8: Neighbors [5, 6, 7, 8, 9, 10, 11], Degree 6
# Channel 9: Neighbors [6, 8, 9, 10, 12], Degree 4
# Channel 10: Neighbors [7, 8, 9, 10, 11, 12], Degree 5
# Channel 11: Neighbors [7, 8, 10, 11, 12, 13, 14, 15, 29], Degree 8
# Channel 12: Neighbors [9, 10, 11, 12, 13], Degree 4
# Channel 13: Neighbors [11, 12, 13, 14, 29, 30], Degree 5
# Channel 14: Neighbors [7, 11, 13, 14, 15, 25, 29], Degree 6
# Channel 15: Neighbors [5, 7, 11, 14, 15, 22, 23, 25, 29], Degree 8
# Channel 16: Neighbors [1, 16, 17, 18, 19], Degree 4
# Channel 17: Neighbors [1, 2, 4, 16, 17, 18, 20, 21], Degree 7
# Channel 18: Neighbors [16, 17, 18, 19, 20, 21], Degree 5
# Channel 19: Neighbors [16, 18, 19, 20, 24], Degree 4
# Channel 20: Neighbors [17, 18, 19, 20, 21, 22, 23, 24], Degree 7
# Channel 21: Neighbors [2, 4, 5, 17, 18, 20, 21, 22, 23], Degree 8
# Channel 22: Neighbors [4, 5, 15, 20, 21, 22, 23], Degree 6
# Channel 23: Neighbors [15, 20, 21, 22, 23, 24, 25, 26], Degree 7
# Channel 24: Neighbors [19, 20, 23, 24, 25, 26, 27], Degree 6
# Channel 25: Neighbors [14, 15, 23, 24, 25, 26, 28, 29], Degree 7
# Channel 26: Neighbors [23, 24, 25, 26, 27, 28, 29], Degree 6
# Channel 27: Neighbors [24, 26, 27, 28, 30], Degree 4
# Channel 28: Neighbors [25, 26, 27, 28, 29, 30], Degree 5
# Channel 29: Neighbors [11, 13, 14, 15, 25, 26, 28, 29, 30], Degree 8
# Channel 30: Neighbors [13, 27, 28, 29, 30], Degree 4
