# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset, ConcatDataset
from torch_geometric.loader import DataLoader as GeometricDataLoader
from torch_geometric.data import Data
from torch_geometric.utils import dense_to_sparse, subgraph, k_hop_subgraph
import torch_geometric.nn as pyg_nn
from scipy.io import loadmat, savemat
import os
import matplotlib.pyplot as plt

# %%
# Load saved beta data from mat file
analysis_type = 'N170'
curr_dir = os.getcwd()
datain_mat = loadmat(os.path.join(curr_dir, analysis_type + '_data.mat'))
binatry_matrix_mat = loadmat(os.path.join(curr_dir, 'adjacency_matrix.mat'))
datain = datain_mat['data']
binatry_matrix = binatry_matrix_mat['adjacency_matrix']

datain = np.array(datain)          # shape: [nBeta, nTime, nChan, nSubject] (adjust as needed)
binatry_matrix = np.array(binatry_matrix)

# Parse shapes
nBeta     = datain.shape[0]
nTime     = datain.shape[1]
nChan     = datain.shape[2]
nSubject  = datain.shape[3]

# %%
# ===========================================
# 2) Set device & convert adjacency
# ===========================================
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
edge_index, _ = dense_to_sparse(torch.tensor(binatry_matrix, dtype=torch.float32))
print(device)

# ===========================================
# 3) Dataset builder
# ===========================================
def build_concat_dataset_for_beta(datain, beta_idx):
    """
    Build a ConcatDataset across all subjects for one beta index.
    `datain` is [nBeta, nTime, nChan, nSubject].
    Returns: ConcatDataset of length nSubject.
    """
    subject_datasets = []
    for s in range(nSubject):
        # Extract slice for one subject and one beta
        # shape: [nTime, nChan]
        single_beta_data = datain[beta_idx, :, :, s]

        # If each node is a channel and its feature dimension is time,
        # we might want single_beta_data to be [nChan, nTime].
        # If so, transpose here:
        single_beta_data = single_beta_data.T  # shape: [nChan, nTime]

        # For an autoencoder, features=labels
        x_tensor = torch.tensor(single_beta_data, dtype=torch.float32)
        x_tensor = x_tensor.unsqueeze(0)

        subject_datasets.append(TensorDataset(x_tensor, x_tensor))

    return ConcatDataset(subject_datasets)
# Out:
# cuda

# %%
# ===========================================
# 4) PyG Graph Dataset
# ===========================================
class EEGGraphDataset(torch.utils.data.Dataset):
    """
    Wraps a standard dataset so that each item is a PyG Data object:
      x -> node features (channels)
      edge_index -> adjacency
    """
    def __init__(self, eeg_data, edge_index):
        self.eeg_data = eeg_data
        self.edge_index = edge_index

    def __len__(self):
        return len(self.eeg_data)

    def __getitem__(self, idx):
        # item: (x, x) because it's autoencoder
        sample = self.eeg_data[idx]
        x = sample[0]  # shape: [nChan, nTime] (if you used transpose above)
        # Convert x -> float32, build PyG Data
        graph_data = Data(x=torch.tensor(x, dtype=torch.float32),
                          edge_index=self.edge_index)
        return graph_data

# %%
# ===========================================
# 5) Define GraphAutoencoder
# ===========================================
class GraphAutoencoder(nn.Module):
    def __init__(self, num_features, embedding_dim=64):
        """
        num_features = dimension of each node's feature vector.
                       If each channel is a node, and you pass
                       [nChan, nTime], then num_features = nTime.
        """
        super(GraphAutoencoder, self).__init__()
        # Example with two ARMAConv layers
        self.encoder_gcn1 = pyg_nn.ARMAConv(num_features, 128, 
                                            num_stacks=2, 
                                            num_layers=3,
                                            shared_weights=True)
        self.encoder_gcn2 = pyg_nn.ARMAConv(128, embedding_dim, 
                                            num_stacks=2, 
                                            num_layers=3,
                                            shared_weights=True)
        self.decoder_fc1 = nn.Linear(embedding_dim, 128)
        self.decoder_fc2 = nn.Linear(128, num_features)

    def forward(self, x, edge_index):
        x = torch.relu(self.encoder_gcn1(x, edge_index))
        latent = torch.relu(self.encoder_gcn2(x, edge_index))
        x = torch.relu(self.decoder_fc1(latent))
        reconstructed = self.decoder_fc2(x)
        return reconstructed

# %%
# ===========================================
# 6) Training and evaluation
# ===========================================
def train_model_all(model, train_loader, device, num_epochs):
    model.to(device)
    optimizer = optim.Adam(model.parameters(), lr=1e-3)
    criterion = nn.SmoothL1Loss()

    for epoch in range(num_epochs):
        model.train()
        epoch_loss = 0.0
        for batch_data in train_loader:
            batch_data = batch_data.to(device)
            optimizer.zero_grad()

            # Forward
            reconstructed = model(batch_data.x, batch_data.edge_index)
            loss = criterion(reconstructed, batch_data.x)

            # Backprop
            loss.backward()
            optimizer.step()
            epoch_loss += loss.item()

        epoch_loss /= len(train_loader)
        print(f"Beta Model Training - Epoch [{epoch+1}/{num_epochs}], Loss: {epoch_loss:.4f}")
    return model

def evaluation_model(model, data_sample, edge_index, device):
    """
    data_sample: shape [nChan, nTime], or [nTime, nChan],
                 whichever you used in training.
    Returns: (original_np, reconstructed_np, error_np)
    """
    model.eval()
    with torch.no_grad():
        x = torch.tensor(data_sample, dtype=torch.float32, device=device)
        eidx = edge_index.to(device)
        reconstructed = model(x, eidx)
    orig = x.cpu().numpy()
    recon = reconstructed.cpu().numpy()
    error = orig - recon
    return orig, recon, error

# %%
# Channel Masking

# Define channel masking function with 'zero' and 'mean' methods
def channel_masking(x_n, ch_idx, mode='mean'):
    x_masked = x_n.copy()
    if mode == 'zero':
        x_masked[ch_idx, :] = 0.0
    # Mean of all other channels
    elif mode == 'mean':
        channel_mean = x_n.mean(axis=0)
        x_masked[ch_idx, :] = channel_mean
    return x_masked

# Apply channel masking and compute importance
def apply_channel_masking(model, sample_n, edge_index, device, mode='mean'):
    model.eval()
    with torch.no_grad():
        x = torch.tensor(sample_n, dtype=torch.float32, device=device)
        recon = model(x, edge_index.to(device))
        base_lose = nn.SmoothL1Loss()(recon, x).item()
        
        nChan = sample_n.shape[0]
        imp = np.zeros(nChan)
        
        # Iterate over channels to compute importance
        # The higher the loss increase, the more important the channel
        for c in range(nChan):
            x_masked = channel_masking(sample_n, c, mode=mode)
            x_masked = torch.tensor(x_masked, dtype=torch.float32, device=device)
            recon_masked = model(x_masked, edge_index.to(device))
            masked_loss = nn.SmoothL1Loss()(recon_masked, x_masked).item()
            imp[c] = abs(masked_loss - base_lose)
            
    return imp

# %%
# Channel dropping

# Define channel dropping method
def channel_dropping(model, sample_n, edge_index, device):
    model.eval()
    with torch.no_grad():
        x = torch.tensor(sample_n, dtype=torch.float32, device=device)
        recon = model(x, edge_index.to(device))
        base_loss = nn.SmoothL1Loss()(recon, x).item()

        nChan = sample_n.shape[0]
        imp = np.zeros(nChan)
        all_channels = torch.arange(nChan, device=device)
        e_idx = edge_index.to(device)
        
        for c in range(nChan):
            mask = torch.ones(nChan, dtype=torch.bool, device=device)
            mask[c] = False
            masked_channels = all_channels[mask]
            # Create subgraph with masked channels, dropping the channel c from the graph
            masked_edge_index = subgraph(masked_channels, e_idx, relabel_nodes=True)[0]
            # Drop the channel c from the data x
            masked_x = x[masked_channels, :]
            recon_masked = model(masked_x, masked_edge_index)
            masked_loss = nn.SmoothL1Loss()(recon_masked, masked_x).item()
            imp[c] = abs(masked_loss - base_loss)
            
    return imp

# %%
# Channel region hard masking

# Compute k-hop neighborhood channels for each channel
def compute_neighborhood_channels(edge_index, k=1):
    neighborhood_channels = []
    for c in range(edge_index.max().item() + 1):
        channels, _, _, _ = k_hop_subgraph(c, k, edge_index)
        neighborhood_channels.append(channels.cpu().numpy())
    return neighborhood_channels

# Define region hard masking function with 'zero' and 'mean' methods
def region_hard_masking(x_n, neig_list, mode='mean'):
    x_masked = x_n.copy()

    # Get the rest of the channels except the neighborhood list
    nChan = x_n.shape[0]
    mask_neig = np.zeros(nChan, dtype=bool)
    mask_neig[neig_list] = True
    mask_rest = ~mask_neig
    
    if mode == 'zero':
        x_masked[mask_neig, :] = 0.0
    # The mean of the rest of the channels
    elif mode == 'mean':
        if mask_rest.any():
            rest_mean = x_n[mask_rest, :].mean(axis=0)
        # If no rest channels, use overall mean
        else:
            rest_mean = x_n.mean(axis=0)
        x_masked[mask_neig, :] = rest_mean
    return x_masked

# Apply region hard masking and compute importance
def apply_region_hard_masking(model, sample_n, edge_index, device, mode='mean', k=1):
    model.eval()
    with torch.no_grad():
        neighborhood_channels = compute_neighborhood_channels(edge_index, k)
        x = torch.tensor(sample_n, dtype=torch.float32, device=device)
        recon = model(x, edge_index.to(device))
        base_loss = nn.SmoothL1Loss()(recon, x).item()

        nChan = sample_n.shape[0]
        imp = np.zeros(nChan)
        
        for c in range(nChan):
            neig_list = neighborhood_channels[c]
            x_masked = region_hard_masking(sample_n, neig_list, mode=mode)
            x_masked = torch.tensor(x_masked, dtype=torch.float32, device=device)
            recon_masked = model(x_masked, edge_index.to(device))
            masked_loss = nn.SmoothL1Loss()(recon_masked, x_masked).item()
            imp[c] = abs(masked_loss - base_loss)
    return imp

# %%
# Subject masking
def apply_subject_masking(model, full_dataset_i, edge_index, device, mode='mean'):
    model.eval()
    nSubjects = len(full_dataset_i)
    imp = np.zeros(nSubjects)
    
    x_list = []
    for s in range(nSubjects):
        x_list.append(full_dataset_i[s][0].numpy())
    # Shape: [nSubject, nChan, nTime]
    x_all = np.stack(x_list, axis=0)
    x_sum = x_all.sum(axis=0)
    
    for s in range(nSubjects):
        x_s =  x_list[s]
        x_s = torch.tensor(x_s, dtype=torch.float32, device=device)
        recon = model(x_s, edge_index.to(device))
        base_loss = nn.SmoothL1Loss()(recon, x_s).item()
        
        if mode == 'zero':
            x_masked = x_s.cpu().numpy()
            x_masked[:, :] = 0.0
        elif mode == 'mean':
            mean_other = (x_sum - x_list[s]) / (nSubjects - 1)
            x_masked = mean_other
        x_masked = torch.tensor(x_masked, dtype=torch.float32, device=device)
        recon_masked = model(x_masked, edge_index.to(device))
        mask_loss = nn.SmoothL1Loss()(recon_masked, x_masked).item()
        imp[s] = abs(mask_loss - base_loss)
    return imp

# %%
num_features = nTime   # if each channel is a node, and feature vector = [nTime]
num_epochs   = 200     # number of training - set as needed
batch_size   = 4;      # dataset/batch to update hyperparameters

models = []

imp_chan_zero_list = []
imp_chan_drop_list = []
imp_chan_mean_list = []
imp_region_mean_list = []
imp_subject_mean_list = []
for iBeta in range(nBeta):
    print(f"\n=== Building dataset/model for Beta {iBeta} ===")
    # Build dataset & loader
    full_dataset_i  = build_concat_dataset_for_beta(datain, iBeta)
    graph_dataset_i = EEGGraphDataset(full_dataset_i, edge_index)
    full_loader_i   = GeometricDataLoader(graph_dataset_i, batch_size=batch_size, shuffle=True)

    # Init model & train
    model_i = GraphAutoencoder(num_features=num_features, embedding_dim=32)
    model_i = train_model_all(model_i, full_loader_i, device, num_epochs=num_epochs)
    models.append(model_i)
    
    imp_subject_mean = apply_subject_masking(model_i, full_dataset_i, edge_index, device, mode='mean')
    imp_subject_mean_list.append(np.array(imp_subject_mean))

    imp_chan_zero_per_subject = []
    imp_chan_drop_per_subject = []
    imp_chan_mean_per_subject = []
    imp_region_mean_per_subject = []
    for s in range(len(full_dataset_i)):
        x_s = full_dataset_i[s][0].numpy()  # [nChan, nTime]
        imp_chan_zero = apply_channel_masking(model_i, x_s, edge_index, device, mode='zero')
        imp_chan_mean = apply_channel_masking(model_i, x_s, edge_index, device, mode='mean')
        imp_chan_drop = channel_dropping(model_i, x_s, edge_index, device)
        imp_region_mean = apply_region_hard_masking(model_i, x_s, edge_index, device, mode='mean', k=1)
        imp_chan_zero_per_subject.append(imp_chan_zero)
        imp_chan_drop_per_subject.append(imp_chan_drop)
        imp_chan_mean_per_subject.append(imp_chan_mean)
        imp_region_mean_per_subject.append(imp_region_mean)

    imp_chan_zero_list.append(np.array(imp_chan_zero_per_subject))
    imp_chan_drop_list.append(np.array(imp_chan_drop_per_subject))
    imp_chan_mean_list.append(np.array(imp_chan_mean_per_subject))
    imp_region_mean_list.append(np.array(imp_region_mean_per_subject))

all_imp_chan_zero = np.array(imp_chan_zero_list)
all_imp_chan_drop = np.array(imp_chan_drop_list)
all_imp_chan_mean = np.array(imp_chan_mean_list)
all_imp_region_mean = np.array(imp_region_mean_list)
all_imp_subject_mean = np.array(imp_subject_mean_list)
# Out:
# === Building dataset/model for Beta 0 ===
# Beta Model Training - Epoch [1/200], Loss: 0.7608
# Beta Model Training - Epoch [2/200], Loss: 0.5626
# C:\Users\86136\AppData\Local\Temp\ipykernel_34192\1382389434.py:22: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   graph_data = Data(x=torch.tensor(x, dtype=torch.float32),
# Beta Model Training - Epoch [3/200], Loss: 0.4204
# Beta Model Training - Epoch [4/200], Loss: 0.3673
# Beta Model Training - Epoch [5/200], Loss: 0.3407
# Beta Model Training - Epoch [6/200], Loss: 0.3208
# Beta Model Training - Epoch [7/200], Loss: 0.3054
# Beta Model Training - Epoch [8/200], Loss: 0.2844
# Beta Model Training - Epoch [9/200], Loss: 0.2616
# Beta Model Training - Epoch [10/200], Loss: 0.2408
# Beta Model Training - Epoch [11/200], Loss: 0.2237
# Beta Model Training - Epoch [12/200], Loss: 0.2086
# Beta Model Training - Epoch [13/200], Loss: 0.1988
# Beta Model Training - Epoch [14/200], Loss: 0.1890
# Beta Model Training - Epoch [15/200], Loss: 0.1785
# Beta Model Training - Epoch [16/200], Loss: 0.1701
# Beta Model Training - Epoch [17/200], Loss: 0.1667
# Beta Model Training - Epoch [18/200], Loss: 0.1589
# Beta Model Training - Epoch [19/200], Loss: 0.1571
# Beta Model Training - Epoch [20/200], Loss: 0.1554
# Beta Model Training - Epoch [21/200], Loss: 0.1473
# Beta Model Training - Epoch [22/200], Loss: 0.1444
# Beta Model Training - Epoch [23/200], Loss: 0.1429
# Beta Model Training - Epoch [24/200], Loss: 0.1419
# Beta Model Training - Epoch [25/200], Loss: 0.1396
# Beta Model Training - Epoch [26/200], Loss: 0.1353
# Beta Model Training - Epoch [27/200], Loss: 0.1284
# Beta Model Training - Epoch [28/200], Loss: 0.1241
# Beta Model Training - Epoch [29/200], Loss: 0.1225
# Beta Model Training - Epoch [30/200], Loss: 0.1172
# Beta Model Training - Epoch [31/200], Loss: 0.1127
# Beta Model Training - Epoch [32/200], Loss: 0.1100
# Beta Model Training - Epoch [33/200], Loss: 0.1085
# Beta Model Training - Epoch [34/200], Loss: 0.1053
# Beta Model Training - Epoch [35/200], Loss: 0.1031
# Beta Model Training - Epoch [36/200], Loss: 0.1011
# Beta Model Training - Epoch [37/200], Loss: 0.0998
# Beta Model Training - Epoch [38/200], Loss: 0.0985
# Beta Model Training - Epoch [39/200], Loss: 0.0943
# Beta Model Training - Epoch [40/200], Loss: 0.0944
# Beta Model Training - Epoch [41/200], Loss: 0.0929
# Beta Model Training - Epoch [42/200], Loss: 0.0942
# Beta Model Training - Epoch [43/200], Loss: 0.0917
# Beta Model Training - Epoch [44/200], Loss: 0.0958
# Beta Model Training - Epoch [45/200], Loss: 0.1034
# Beta Model Training - Epoch [46/200], Loss: 0.0974
# Beta Model Training - Epoch [47/200], Loss: 0.0925
# Beta Model Training - Epoch [48/200], Loss: 0.0881
# Beta Model Training - Epoch [49/200], Loss: 0.0878
# Beta Model Training - Epoch [50/200], Loss: 0.0846
# Beta Model Training - Epoch [51/200], Loss: 0.0834
# Beta Model Training - Epoch [52/200], Loss: 0.0824
# Beta Model Training - Epoch [53/200], Loss: 0.0811
# Beta Model Training - Epoch [54/200], Loss: 0.0784
# Beta Model Training - Epoch [55/200], Loss: 0.0776
# Beta Model Training - Epoch [56/200], Loss: 0.0778
# Beta Model Training - Epoch [57/200], Loss: 0.0772
# Beta Model Training - Epoch [58/200], Loss: 0.0755
# Beta Model Training - Epoch [59/200], Loss: 0.0753
# Beta Model Training - Epoch [60/200], Loss: 0.0745
# Beta Model Training - Epoch [61/200], Loss: 0.0745
# Beta Model Training - Epoch [62/200], Loss: 0.0741
# Beta Model Training - Epoch [63/200], Loss: 0.0747
# Beta Model Training - Epoch [64/200], Loss: 0.0734
# Beta Model Training - Epoch [65/200], Loss: 0.0736
# Beta Model Training - Epoch [66/200], Loss: 0.0748
# Beta Model Training - Epoch [67/200], Loss: 0.0739
# Beta Model Training - Epoch [68/200], Loss: 0.0718
# Beta Model Training - Epoch [69/200], Loss: 0.0742
# Beta Model Training - Epoch [70/200], Loss: 0.0740
# Beta Model Training - Epoch [71/200], Loss: 0.0724
# Beta Model Training - Epoch [72/200], Loss: 0.0711
# Beta Model Training - Epoch [73/200], Loss: 0.0705
# Beta Model Training - Epoch [74/200], Loss: 0.0697
# Beta Model Training - Epoch [75/200], Loss: 0.0675
# Beta Model Training - Epoch [76/200], Loss: 0.0676
# Beta Model Training - Epoch [77/200], Loss: 0.0671
# Beta Model Training - Epoch [78/200], Loss: 0.0669
# Beta Model Training - Epoch [79/200], Loss: 0.0685
# Beta Model Training - Epoch [80/200], Loss: 0.0696
# Beta Model Training - Epoch [81/200], Loss: 0.0713
# Beta Model Training - Epoch [82/200], Loss: 0.0724
# Beta Model Training - Epoch [83/200], Loss: 0.0721
# Beta Model Training - Epoch [84/200], Loss: 0.0721
# Beta Model Training - Epoch [85/200], Loss: 0.0688
# Beta Model Training - Epoch [86/200], Loss: 0.0684
# Beta Model Training - Epoch [87/200], Loss: 0.0668
# Beta Model Training - Epoch [88/200], Loss: 0.0692
# Beta Model Training - Epoch [89/200], Loss: 0.0734
# Beta Model Training - Epoch [90/200], Loss: 0.0720
# Beta Model Training - Epoch [91/200], Loss: 0.0706
# Beta Model Training - Epoch [92/200], Loss: 0.0675
# Beta Model Training - Epoch [93/200], Loss: 0.0694
# Beta Model Training - Epoch [94/200], Loss: 0.0660
# Beta Model Training - Epoch [95/200], Loss: 0.0643
# Beta Model Training - Epoch [96/200], Loss: 0.0631
# Beta Model Training - Epoch [97/200], Loss: 0.0635
# Beta Model Training - Epoch [98/200], Loss: 0.0623
# Beta Model Training - Epoch [99/200], Loss: 0.0631
# Beta Model Training - Epoch [100/200], Loss: 0.0647
# Beta Model Training - Epoch [101/200], Loss: 0.0623
# Beta Model Training - Epoch [102/200], Loss: 0.0604
# Beta Model Training - Epoch [103/200], Loss: 0.0614
# Beta Model Training - Epoch [104/200], Loss: 0.0613
# Beta Model Training - Epoch [105/200], Loss: 0.0603
# Beta Model Training - Epoch [106/200], Loss: 0.0600
# Beta Model Training - Epoch [107/200], Loss: 0.0595
# Beta Model Training - Epoch [108/200], Loss: 0.0586
# Beta Model Training - Epoch [109/200], Loss: 0.0592
# Beta Model Training - Epoch [110/200], Loss: 0.0594
# Beta Model Training - Epoch [111/200], Loss: 0.0588
# Beta Model Training - Epoch [112/200], Loss: 0.0582
# Beta Model Training - Epoch [113/200], Loss: 0.0585
# Beta Model Training - Epoch [114/200], Loss: 0.0591
# Beta Model Training - Epoch [115/200], Loss: 0.0583
# Beta Model Training - Epoch [116/200], Loss: 0.0588
# Beta Model Training - Epoch [117/200], Loss: 0.0570
# Beta Model Training - Epoch [118/200], Loss: 0.0579
# Beta Model Training - Epoch [119/200], Loss: 0.0579
# Beta Model Training - Epoch [120/200], Loss: 0.0565
# Beta Model Training - Epoch [121/200], Loss: 0.0573
# Beta Model Training - Epoch [122/200], Loss: 0.0557
# Beta Model Training - Epoch [123/200], Loss: 0.0556
# Beta Model Training - Epoch [124/200], Loss: 0.0554
# Beta Model Training - Epoch [125/200], Loss: 0.0553
# Beta Model Training - Epoch [126/200], Loss: 0.0551
# Beta Model Training - Epoch [127/200], Loss: 0.0552
# Beta Model Training - Epoch [128/200], Loss: 0.0568
# Beta Model Training - Epoch [129/200], Loss: 0.0553
# Beta Model Training - Epoch [130/200], Loss: 0.0547
# Beta Model Training - Epoch [131/200], Loss: 0.0549
# Beta Model Training - Epoch [132/200], Loss: 0.0554
# Beta Model Training - Epoch [133/200], Loss: 0.0554
# Beta Model Training - Epoch [134/200], Loss: 0.0557
# Beta Model Training - Epoch [135/200], Loss: 0.0573
# Beta Model Training - Epoch [136/200], Loss: 0.0554
# Beta Model Training - Epoch [137/200], Loss: 0.0566
# Beta Model Training - Epoch [138/200], Loss: 0.0554
# Beta Model Training - Epoch [139/200], Loss: 0.0546
# Beta Model Training - Epoch [140/200], Loss: 0.0542
# Beta Model Training - Epoch [141/200], Loss: 0.0535
# Beta Model Training - Epoch [142/200], Loss: 0.0531
# Beta Model Training - Epoch [143/200], Loss: 0.0540
# Beta Model Training - Epoch [144/200], Loss: 0.0528
# Beta Model Training - Epoch [145/200], Loss: 0.0526
# Beta Model Training - Epoch [146/200], Loss: 0.0536
# Beta Model Training - Epoch [147/200], Loss: 0.0522
# Beta Model Training - Epoch [148/200], Loss: 0.0523
# Beta Model Training - Epoch [149/200], Loss: 0.0527
# Beta Model Training - Epoch [150/200], Loss: 0.0531
# Beta Model Training - Epoch [151/200], Loss: 0.0525
# Beta Model Training - Epoch [152/200], Loss: 0.0522
# Beta Model Training - Epoch [153/200], Loss: 0.0526
# Beta Model Training - Epoch [154/200], Loss: 0.0523
# Beta Model Training - Epoch [155/200], Loss: 0.0531
# Beta Model Training - Epoch [156/200], Loss: 0.0522
# Beta Model Training - Epoch [157/200], Loss: 0.0523
# Beta Model Training - Epoch [158/200], Loss: 0.0521
# Beta Model Training - Epoch [159/200], Loss: 0.0536
# Beta Model Training - Epoch [160/200], Loss: 0.0519
# Beta Model Training - Epoch [161/200], Loss: 0.0526
# Beta Model Training - Epoch [162/200], Loss: 0.0523
# Beta Model Training - Epoch [163/200], Loss: 0.0550
# Beta Model Training - Epoch [164/200], Loss: 0.0539
# Beta Model Training - Epoch [165/200], Loss: 0.0551
# Beta Model Training - Epoch [166/200], Loss: 0.0666
# Beta Model Training - Epoch [167/200], Loss: 0.0709
# Beta Model Training - Epoch [168/200], Loss: 0.0647
# Beta Model Training - Epoch [169/200], Loss: 0.0625
# Beta Model Training - Epoch [170/200], Loss: 0.0601
# Beta Model Training - Epoch [171/200], Loss: 0.0568
# Beta Model Training - Epoch [172/200], Loss: 0.0547
# Beta Model Training - Epoch [173/200], Loss: 0.0556
# Beta Model Training - Epoch [174/200], Loss: 0.0584
# Beta Model Training - Epoch [175/200], Loss: 0.0548
# Beta Model Training - Epoch [176/200], Loss: 0.0522
# Beta Model Training - Epoch [177/200], Loss: 0.0552
# Beta Model Training - Epoch [178/200], Loss: 0.0561
# Beta Model Training - Epoch [179/200], Loss: 0.0545
# Beta Model Training - Epoch [180/200], Loss: 0.0547
# Beta Model Training - Epoch [181/200], Loss: 0.0539
# Beta Model Training - Epoch [182/200], Loss: 0.0525
# Beta Model Training - Epoch [183/200], Loss: 0.0497
# Beta Model Training - Epoch [184/200], Loss: 0.0493
# Beta Model Training - Epoch [185/200], Loss: 0.0499
# Beta Model Training - Epoch [186/200], Loss: 0.0486
# Beta Model Training - Epoch [187/200], Loss: 0.0484
# Beta Model Training - Epoch [188/200], Loss: 0.0488
# Beta Model Training - Epoch [189/200], Loss: 0.0487
# Beta Model Training - Epoch [190/200], Loss: 0.0478
# Beta Model Training - Epoch [191/200], Loss: 0.0477
# Beta Model Training - Epoch [192/200], Loss: 0.0479
# Beta Model Training - Epoch [193/200], Loss: 0.0477
# Beta Model Training - Epoch [194/200], Loss: 0.0490
# Beta Model Training - Epoch [195/200], Loss: 0.0486
# Beta Model Training - Epoch [196/200], Loss: 0.0496
# Beta Model Training - Epoch [197/200], Loss: 0.0499
# Beta Model Training - Epoch [198/200], Loss: 0.0504
# Beta Model Training - Epoch [199/200], Loss: 0.0508
# Beta Model Training - Epoch [200/200], Loss: 0.0492
#
# === Building dataset/model for Beta 1 ===
# Beta Model Training - Epoch [1/200], Loss: 0.7504
# Beta Model Training - Epoch [2/200], Loss: 0.6376
# Beta Model Training - Epoch [3/200], Loss: 0.5146
# Beta Model Training - Epoch [4/200], Loss: 0.4365
# Beta Model Training - Epoch [5/200], Loss: 0.3838
# Beta Model Training - Epoch [6/200], Loss: 0.3511
# Beta Model Training - Epoch [7/200], Loss: 0.3267
# Beta Model Training - Epoch [8/200], Loss: 0.3070
# Beta Model Training - Epoch [9/200], Loss: 0.2823
# Beta Model Training - Epoch [10/200], Loss: 0.2653
# Beta Model Training - Epoch [11/200], Loss: 0.2450
# Beta Model Training - Epoch [12/200], Loss: 0.2289
# Beta Model Training - Epoch [13/200], Loss: 0.2161
# Beta Model Training - Epoch [14/200], Loss: 0.2076
# Beta Model Training - Epoch [15/200], Loss: 0.1956
# Beta Model Training - Epoch [16/200], Loss: 0.1884
# Beta Model Training - Epoch [17/200], Loss: 0.1817
# Beta Model Training - Epoch [18/200], Loss: 0.1763
# Beta Model Training - Epoch [19/200], Loss: 0.1699
# Beta Model Training - Epoch [20/200], Loss: 0.1657
# Beta Model Training - Epoch [21/200], Loss: 0.1622
# Beta Model Training - Epoch [22/200], Loss: 0.1588
# Beta Model Training - Epoch [23/200], Loss: 0.1526
# Beta Model Training - Epoch [24/200], Loss: 0.1473
# Beta Model Training - Epoch [25/200], Loss: 0.1452
# Beta Model Training - Epoch [26/200], Loss: 0.1405
# Beta Model Training - Epoch [27/200], Loss: 0.1357
# Beta Model Training - Epoch [28/200], Loss: 0.1307
# Beta Model Training - Epoch [29/200], Loss: 0.1273
# Beta Model Training - Epoch [30/200], Loss: 0.1235
# Beta Model Training - Epoch [31/200], Loss: 0.1217
# Beta Model Training - Epoch [32/200], Loss: 0.1176
# Beta Model Training - Epoch [33/200], Loss: 0.1146
# Beta Model Training - Epoch [34/200], Loss: 0.1120
# Beta Model Training - Epoch [35/200], Loss: 0.1099
# Beta Model Training - Epoch [36/200], Loss: 0.1101
# Beta Model Training - Epoch [37/200], Loss: 0.1112
# Beta Model Training - Epoch [38/200], Loss: 0.1058
# Beta Model Training - Epoch [39/200], Loss: 0.1045
# Beta Model Training - Epoch [40/200], Loss: 0.1049
# Beta Model Training - Epoch [41/200], Loss: 0.1090
# Beta Model Training - Epoch [42/200], Loss: 0.1049
# Beta Model Training - Epoch [43/200], Loss: 0.1069
# Beta Model Training - Epoch [44/200], Loss: 0.1097
# Beta Model Training - Epoch [45/200], Loss: 0.1032
# Beta Model Training - Epoch [46/200], Loss: 0.0952
# Beta Model Training - Epoch [47/200], Loss: 0.0935
# Beta Model Training - Epoch [48/200], Loss: 0.0931
# Beta Model Training - Epoch [49/200], Loss: 0.0918
# Beta Model Training - Epoch [50/200], Loss: 0.0894
# Beta Model Training - Epoch [51/200], Loss: 0.0883
# Beta Model Training - Epoch [52/200], Loss: 0.0871
# Beta Model Training - Epoch [53/200], Loss: 0.0858
# Beta Model Training - Epoch [54/200], Loss: 0.0848
# Beta Model Training - Epoch [55/200], Loss: 0.0875
# Beta Model Training - Epoch [56/200], Loss: 0.0893
# Beta Model Training - Epoch [57/200], Loss: 0.0903
# Beta Model Training - Epoch [58/200], Loss: 0.0870
# Beta Model Training - Epoch [59/200], Loss: 0.0827
# Beta Model Training - Epoch [60/200], Loss: 0.0812
# Beta Model Training - Epoch [61/200], Loss: 0.0791
# Beta Model Training - Epoch [62/200], Loss: 0.0782
# Beta Model Training - Epoch [63/200], Loss: 0.0762
# Beta Model Training - Epoch [64/200], Loss: 0.0760
# Beta Model Training - Epoch [65/200], Loss: 0.0752
# Beta Model Training - Epoch [66/200], Loss: 0.0743
# Beta Model Training - Epoch [67/200], Loss: 0.0735
# Beta Model Training - Epoch [68/200], Loss: 0.0741
# Beta Model Training - Epoch [69/200], Loss: 0.0729
# Beta Model Training - Epoch [70/200], Loss: 0.0733
# Beta Model Training - Epoch [71/200], Loss: 0.0711
# Beta Model Training - Epoch [72/200], Loss: 0.0717
# Beta Model Training - Epoch [73/200], Loss: 0.0707
# Beta Model Training - Epoch [74/200], Loss: 0.0697
# Beta Model Training - Epoch [75/200], Loss: 0.0692
# Beta Model Training - Epoch [76/200], Loss: 0.0698
# Beta Model Training - Epoch [77/200], Loss: 0.0693
# Beta Model Training - Epoch [78/200], Loss: 0.0673
# Beta Model Training - Epoch [79/200], Loss: 0.0671
# Beta Model Training - Epoch [80/200], Loss: 0.0671
# Beta Model Training - Epoch [81/200], Loss: 0.0680
# Beta Model Training - Epoch [82/200], Loss: 0.0670
# Beta Model Training - Epoch [83/200], Loss: 0.0678
# Beta Model Training - Epoch [84/200], Loss: 0.0676
# Beta Model Training - Epoch [85/200], Loss: 0.0677
# Beta Model Training - Epoch [86/200], Loss: 0.0671
# Beta Model Training - Epoch [87/200], Loss: 0.0665
# Beta Model Training - Epoch [88/200], Loss: 0.0653
# Beta Model Training - Epoch [89/200], Loss: 0.0651
# Beta Model Training - Epoch [90/200], Loss: 0.0653
# Beta Model Training - Epoch [91/200], Loss: 0.0653
# Beta Model Training - Epoch [92/200], Loss: 0.0651
# Beta Model Training - Epoch [93/200], Loss: 0.0637
# Beta Model Training - Epoch [94/200], Loss: 0.0650
# Beta Model Training - Epoch [95/200], Loss: 0.0645
# Beta Model Training - Epoch [96/200], Loss: 0.0622
# Beta Model Training - Epoch [97/200], Loss: 0.0629
# Beta Model Training - Epoch [98/200], Loss: 0.0638
# Beta Model Training - Epoch [99/200], Loss: 0.0648
# Beta Model Training - Epoch [100/200], Loss: 0.0631
# Beta Model Training - Epoch [101/200], Loss: 0.0626
# Beta Model Training - Epoch [102/200], Loss: 0.0607
# Beta Model Training - Epoch [103/200], Loss: 0.0613
# Beta Model Training - Epoch [104/200], Loss: 0.0606
# Beta Model Training - Epoch [105/200], Loss: 0.0606
# Beta Model Training - Epoch [106/200], Loss: 0.0602
# Beta Model Training - Epoch [107/200], Loss: 0.0605
# Beta Model Training - Epoch [108/200], Loss: 0.0616
# Beta Model Training - Epoch [109/200], Loss: 0.0605
# Beta Model Training - Epoch [110/200], Loss: 0.0611
# Beta Model Training - Epoch [111/200], Loss: 0.0617
# Beta Model Training - Epoch [112/200], Loss: 0.0608
# Beta Model Training - Epoch [113/200], Loss: 0.0609
# Beta Model Training - Epoch [114/200], Loss: 0.0607
# Beta Model Training - Epoch [115/200], Loss: 0.0654
# Beta Model Training - Epoch [116/200], Loss: 0.0621
# Beta Model Training - Epoch [117/200], Loss: 0.0611
# Beta Model Training - Epoch [118/200], Loss: 0.0597
# Beta Model Training - Epoch [119/200], Loss: 0.0596
# Beta Model Training - Epoch [120/200], Loss: 0.0587
# Beta Model Training - Epoch [121/200], Loss: 0.0596
# Beta Model Training - Epoch [122/200], Loss: 0.0631
# Beta Model Training - Epoch [123/200], Loss: 0.0616
# Beta Model Training - Epoch [124/200], Loss: 0.0596
# Beta Model Training - Epoch [125/200], Loss: 0.0592
# Beta Model Training - Epoch [126/200], Loss: 0.0600
# Beta Model Training - Epoch [127/200], Loss: 0.0584
# Beta Model Training - Epoch [128/200], Loss: 0.0602
# Beta Model Training - Epoch [129/200], Loss: 0.0600
# Beta Model Training - Epoch [130/200], Loss: 0.0601
# Beta Model Training - Epoch [131/200], Loss: 0.0617
# Beta Model Training - Epoch [132/200], Loss: 0.0628
# Beta Model Training - Epoch [133/200], Loss: 0.0633
# Beta Model Training - Epoch [134/200], Loss: 0.0689
# Beta Model Training - Epoch [135/200], Loss: 0.0730
# Beta Model Training - Epoch [136/200], Loss: 0.0709
# Beta Model Training - Epoch [137/200], Loss: 0.0659
# Beta Model Training - Epoch [138/200], Loss: 0.0651
# Beta Model Training - Epoch [139/200], Loss: 0.0651
# Beta Model Training - Epoch [140/200], Loss: 0.0616
# Beta Model Training - Epoch [141/200], Loss: 0.0595
# Beta Model Training - Epoch [142/200], Loss: 0.0578
# Beta Model Training - Epoch [143/200], Loss: 0.0571
# Beta Model Training - Epoch [144/200], Loss: 0.0558
# Beta Model Training - Epoch [145/200], Loss: 0.0546
# Beta Model Training - Epoch [146/200], Loss: 0.0549
# Beta Model Training - Epoch [147/200], Loss: 0.0554
# Beta Model Training - Epoch [148/200], Loss: 0.0546
# Beta Model Training - Epoch [149/200], Loss: 0.0542
# Beta Model Training - Epoch [150/200], Loss: 0.0543
# Beta Model Training - Epoch [151/200], Loss: 0.0536
# Beta Model Training - Epoch [152/200], Loss: 0.0536
# Beta Model Training - Epoch [153/200], Loss: 0.0533
# Beta Model Training - Epoch [154/200], Loss: 0.0534
# Beta Model Training - Epoch [155/200], Loss: 0.0529
# Beta Model Training - Epoch [156/200], Loss: 0.0533
# Beta Model Training - Epoch [157/200], Loss: 0.0531
# Beta Model Training - Epoch [158/200], Loss: 0.0539
# Beta Model Training - Epoch [159/200], Loss: 0.0534
# Beta Model Training - Epoch [160/200], Loss: 0.0548
# Beta Model Training - Epoch [161/200], Loss: 0.0539
# Beta Model Training - Epoch [162/200], Loss: 0.0535
# Beta Model Training - Epoch [163/200], Loss: 0.0541
# Beta Model Training - Epoch [164/200], Loss: 0.0538
# Beta Model Training - Epoch [165/200], Loss: 0.0536
# Beta Model Training - Epoch [166/200], Loss: 0.0544
# Beta Model Training - Epoch [167/200], Loss: 0.0533
# Beta Model Training - Epoch [168/200], Loss: 0.0533
# Beta Model Training - Epoch [169/200], Loss: 0.0529
# Beta Model Training - Epoch [170/200], Loss: 0.0528
# Beta Model Training - Epoch [171/200], Loss: 0.0528
# Beta Model Training - Epoch [172/200], Loss: 0.0522
# Beta Model Training - Epoch [173/200], Loss: 0.0524
# Beta Model Training - Epoch [174/200], Loss: 0.0527
# Beta Model Training - Epoch [175/200], Loss: 0.0527
# Beta Model Training - Epoch [176/200], Loss: 0.0523
# Beta Model Training - Epoch [177/200], Loss: 0.0530
# Beta Model Training - Epoch [178/200], Loss: 0.0528
# Beta Model Training - Epoch [179/200], Loss: 0.0533
# Beta Model Training - Epoch [180/200], Loss: 0.0530
# Beta Model Training - Epoch [181/200], Loss: 0.0526
# Beta Model Training - Epoch [182/200], Loss: 0.0522
# Beta Model Training - Epoch [183/200], Loss: 0.0518
# Beta Model Training - Epoch [184/200], Loss: 0.0522
# Beta Model Training - Epoch [185/200], Loss: 0.0528
# Beta Model Training - Epoch [186/200], Loss: 0.0530
# Beta Model Training - Epoch [187/200], Loss: 0.0534
# Beta Model Training - Epoch [188/200], Loss: 0.0541
# Beta Model Training - Epoch [189/200], Loss: 0.0527
# Beta Model Training - Epoch [190/200], Loss: 0.0536
# Beta Model Training - Epoch [191/200], Loss: 0.0525
# Beta Model Training - Epoch [192/200], Loss: 0.0538
# Beta Model Training - Epoch [193/200], Loss: 0.0512
# Beta Model Training - Epoch [194/200], Loss: 0.0527
# Beta Model Training - Epoch [195/200], Loss: 0.0515
# Beta Model Training - Epoch [196/200], Loss: 0.0509
# Beta Model Training - Epoch [197/200], Loss: 0.0507
# Beta Model Training - Epoch [198/200], Loss: 0.0513
# Beta Model Training - Epoch [199/200], Loss: 0.0515
# Beta Model Training - Epoch [200/200], Loss: 0.0513
#
# === Building dataset/model for Beta 2 ===
# Beta Model Training - Epoch [1/200], Loss: 1.6963
# Beta Model Training - Epoch [2/200], Loss: 1.0086
# Beta Model Training - Epoch [3/200], Loss: 0.6394
# Beta Model Training - Epoch [4/200], Loss: 0.5277
# Beta Model Training - Epoch [5/200], Loss: 0.4164
# Beta Model Training - Epoch [6/200], Loss: 0.3574
# Beta Model Training - Epoch [7/200], Loss: 0.3286
# Beta Model Training - Epoch [8/200], Loss: 0.3096
# Beta Model Training - Epoch [9/200], Loss: 0.2971
# Beta Model Training - Epoch [10/200], Loss: 0.2919
# Beta Model Training - Epoch [11/200], Loss: 0.2797
# Beta Model Training - Epoch [12/200], Loss: 0.2667
# Beta Model Training - Epoch [13/200], Loss: 0.2518
# Beta Model Training - Epoch [14/200], Loss: 0.2470
# Beta Model Training - Epoch [15/200], Loss: 0.2333
# Beta Model Training - Epoch [16/200], Loss: 0.2274
# Beta Model Training - Epoch [17/200], Loss: 0.2178
# Beta Model Training - Epoch [18/200], Loss: 0.2066
# Beta Model Training - Epoch [19/200], Loss: 0.1999
# Beta Model Training - Epoch [20/200], Loss: 0.1908
# Beta Model Training - Epoch [21/200], Loss: 0.1817
# Beta Model Training - Epoch [22/200], Loss: 0.1807
# Beta Model Training - Epoch [23/200], Loss: 0.1762
# Beta Model Training - Epoch [24/200], Loss: 0.1746
# Beta Model Training - Epoch [25/200], Loss: 0.1686
# Beta Model Training - Epoch [26/200], Loss: 0.1511
# Beta Model Training - Epoch [27/200], Loss: 0.1462
# Beta Model Training - Epoch [28/200], Loss: 0.1397
# Beta Model Training - Epoch [29/200], Loss: 0.1341
# Beta Model Training - Epoch [30/200], Loss: 0.1312
# Beta Model Training - Epoch [31/200], Loss: 0.1268
# Beta Model Training - Epoch [32/200], Loss: 0.1297
# Beta Model Training - Epoch [33/200], Loss: 0.1266
# Beta Model Training - Epoch [34/200], Loss: 0.1245
# Beta Model Training - Epoch [35/200], Loss: 0.1254
# Beta Model Training - Epoch [36/200], Loss: 0.1309
# Beta Model Training - Epoch [37/200], Loss: 0.1419
# Beta Model Training - Epoch [38/200], Loss: 0.1326
# Beta Model Training - Epoch [39/200], Loss: 0.1197
# Beta Model Training - Epoch [40/200], Loss: 0.1133
# Beta Model Training - Epoch [41/200], Loss: 0.1112
# Beta Model Training - Epoch [42/200], Loss: 0.1080
# Beta Model Training - Epoch [43/200], Loss: 0.1031
# Beta Model Training - Epoch [44/200], Loss: 0.1005
# Beta Model Training - Epoch [45/200], Loss: 0.0974
# Beta Model Training - Epoch [46/200], Loss: 0.0962
# Beta Model Training - Epoch [47/200], Loss: 0.0939
# Beta Model Training - Epoch [48/200], Loss: 0.0924
# Beta Model Training - Epoch [49/200], Loss: 0.0929
# Beta Model Training - Epoch [50/200], Loss: 0.0906
# Beta Model Training - Epoch [51/200], Loss: 0.0888
# Beta Model Training - Epoch [52/200], Loss: 0.0865
# Beta Model Training - Epoch [53/200], Loss: 0.0885
# Beta Model Training - Epoch [54/200], Loss: 0.0855
# Beta Model Training - Epoch [55/200], Loss: 0.0849
# Beta Model Training - Epoch [56/200], Loss: 0.0828
# Beta Model Training - Epoch [57/200], Loss: 0.0834
# Beta Model Training - Epoch [58/200], Loss: 0.0825
# Beta Model Training - Epoch [59/200], Loss: 0.0812
# Beta Model Training - Epoch [60/200], Loss: 0.0817
# Beta Model Training - Epoch [61/200], Loss: 0.0806
# Beta Model Training - Epoch [62/200], Loss: 0.0808
# Beta Model Training - Epoch [63/200], Loss: 0.0788
# Beta Model Training - Epoch [64/200], Loss: 0.0803
# Beta Model Training - Epoch [65/200], Loss: 0.0811
# Beta Model Training - Epoch [66/200], Loss: 0.0787
# Beta Model Training - Epoch [67/200], Loss: 0.0780
# Beta Model Training - Epoch [68/200], Loss: 0.0772
# Beta Model Training - Epoch [69/200], Loss: 0.0757
# Beta Model Training - Epoch [70/200], Loss: 0.0745
# Beta Model Training - Epoch [71/200], Loss: 0.0749
# Beta Model Training - Epoch [72/200], Loss: 0.0793
# Beta Model Training - Epoch [73/200], Loss: 0.0825
# Beta Model Training - Epoch [74/200], Loss: 0.0770
# Beta Model Training - Epoch [75/200], Loss: 0.0764
# Beta Model Training - Epoch [76/200], Loss: 0.0751
# Beta Model Training - Epoch [77/200], Loss: 0.0749
# Beta Model Training - Epoch [78/200], Loss: 0.0709
# Beta Model Training - Epoch [79/200], Loss: 0.0707
# Beta Model Training - Epoch [80/200], Loss: 0.0695
# Beta Model Training - Epoch [81/200], Loss: 0.0693
# Beta Model Training - Epoch [82/200], Loss: 0.0676
# Beta Model Training - Epoch [83/200], Loss: 0.0663
# Beta Model Training - Epoch [84/200], Loss: 0.0664
# Beta Model Training - Epoch [85/200], Loss: 0.0660
# Beta Model Training - Epoch [86/200], Loss: 0.0660
# Beta Model Training - Epoch [87/200], Loss: 0.0667
# Beta Model Training - Epoch [88/200], Loss: 0.0673
# Beta Model Training - Epoch [89/200], Loss: 0.0662
# Beta Model Training - Epoch [90/200], Loss: 0.0639
# Beta Model Training - Epoch [91/200], Loss: 0.0630
# Beta Model Training - Epoch [92/200], Loss: 0.0649
# Beta Model Training - Epoch [93/200], Loss: 0.0642
# Beta Model Training - Epoch [94/200], Loss: 0.0677
# Beta Model Training - Epoch [95/200], Loss: 0.0657
# Beta Model Training - Epoch [96/200], Loss: 0.0680
# Beta Model Training - Epoch [97/200], Loss: 0.0647
# Beta Model Training - Epoch [98/200], Loss: 0.0659
# Beta Model Training - Epoch [99/200], Loss: 0.0657
# Beta Model Training - Epoch [100/200], Loss: 0.0641
# Beta Model Training - Epoch [101/200], Loss: 0.0634
# Beta Model Training - Epoch [102/200], Loss: 0.0622
# Beta Model Training - Epoch [103/200], Loss: 0.0610
# Beta Model Training - Epoch [104/200], Loss: 0.0616
# Beta Model Training - Epoch [105/200], Loss: 0.0594
# Beta Model Training - Epoch [106/200], Loss: 0.0595
# Beta Model Training - Epoch [107/200], Loss: 0.0586
# Beta Model Training - Epoch [108/200], Loss: 0.0587
# Beta Model Training - Epoch [109/200], Loss: 0.0601
# Beta Model Training - Epoch [110/200], Loss: 0.0610
# Beta Model Training - Epoch [111/200], Loss: 0.0689
# Beta Model Training - Epoch [112/200], Loss: 0.0662
# Beta Model Training - Epoch [113/200], Loss: 0.0660
# Beta Model Training - Epoch [114/200], Loss: 0.0623
# Beta Model Training - Epoch [115/200], Loss: 0.0608
# Beta Model Training - Epoch [116/200], Loss: 0.0602
# Beta Model Training - Epoch [117/200], Loss: 0.0603
# Beta Model Training - Epoch [118/200], Loss: 0.0584
# Beta Model Training - Epoch [119/200], Loss: 0.0596
# Beta Model Training - Epoch [120/200], Loss: 0.0598
# Beta Model Training - Epoch [121/200], Loss: 0.0593
# Beta Model Training - Epoch [122/200], Loss: 0.0593
# Beta Model Training - Epoch [123/200], Loss: 0.0617
# Beta Model Training - Epoch [124/200], Loss: 0.0570
# Beta Model Training - Epoch [125/200], Loss: 0.0567
# Beta Model Training - Epoch [126/200], Loss: 0.0540
# Beta Model Training - Epoch [127/200], Loss: 0.0531
# Beta Model Training - Epoch [128/200], Loss: 0.0540
# Beta Model Training - Epoch [129/200], Loss: 0.0529
# Beta Model Training - Epoch [130/200], Loss: 0.0522
# Beta Model Training - Epoch [131/200], Loss: 0.0514
# Beta Model Training - Epoch [132/200], Loss: 0.0512
# Beta Model Training - Epoch [133/200], Loss: 0.0519
# Beta Model Training - Epoch [134/200], Loss: 0.0531
# Beta Model Training - Epoch [135/200], Loss: 0.0581
# Beta Model Training - Epoch [136/200], Loss: 0.0626
# Beta Model Training - Epoch [137/200], Loss: 0.0672
# Beta Model Training - Epoch [138/200], Loss: 0.0637
# Beta Model Training - Epoch [139/200], Loss: 0.0577
# Beta Model Training - Epoch [140/200], Loss: 0.0571
# Beta Model Training - Epoch [141/200], Loss: 0.0598
# Beta Model Training - Epoch [142/200], Loss: 0.0534
# Beta Model Training - Epoch [143/200], Loss: 0.0546
# Beta Model Training - Epoch [144/200], Loss: 0.0534
# Beta Model Training - Epoch [145/200], Loss: 0.0527
# Beta Model Training - Epoch [146/200], Loss: 0.0525
# Beta Model Training - Epoch [147/200], Loss: 0.0498
# Beta Model Training - Epoch [148/200], Loss: 0.0532
# Beta Model Training - Epoch [149/200], Loss: 0.0548
# Beta Model Training - Epoch [150/200], Loss: 0.0514
# Beta Model Training - Epoch [151/200], Loss: 0.0505
# Beta Model Training - Epoch [152/200], Loss: 0.0519
# Beta Model Training - Epoch [153/200], Loss: 0.0550
# Beta Model Training - Epoch [154/200], Loss: 0.0545
# Beta Model Training - Epoch [155/200], Loss: 0.0509
# Beta Model Training - Epoch [156/200], Loss: 0.0520
# Beta Model Training - Epoch [157/200], Loss: 0.0578
# Beta Model Training - Epoch [158/200], Loss: 0.0599
# Beta Model Training - Epoch [159/200], Loss: 0.0554
# Beta Model Training - Epoch [160/200], Loss: 0.0552
# Beta Model Training - Epoch [161/200], Loss: 0.0498
# Beta Model Training - Epoch [162/200], Loss: 0.0506
# Beta Model Training - Epoch [163/200], Loss: 0.0503
# Beta Model Training - Epoch [164/200], Loss: 0.0498
# Beta Model Training - Epoch [165/200], Loss: 0.0485
# Beta Model Training - Epoch [166/200], Loss: 0.0529
# Beta Model Training - Epoch [167/200], Loss: 0.0482
# Beta Model Training - Epoch [168/200], Loss: 0.0468
# Beta Model Training - Epoch [169/200], Loss: 0.0498
# Beta Model Training - Epoch [170/200], Loss: 0.0456
# Beta Model Training - Epoch [171/200], Loss: 0.0447
# Beta Model Training - Epoch [172/200], Loss: 0.0443
# Beta Model Training - Epoch [173/200], Loss: 0.0434
# Beta Model Training - Epoch [174/200], Loss: 0.0419
# Beta Model Training - Epoch [175/200], Loss: 0.0424
# Beta Model Training - Epoch [176/200], Loss: 0.0417
# Beta Model Training - Epoch [177/200], Loss: 0.0418
# Beta Model Training - Epoch [178/200], Loss: 0.0410
# Beta Model Training - Epoch [179/200], Loss: 0.0420
# Beta Model Training - Epoch [180/200], Loss: 0.0404
# Beta Model Training - Epoch [181/200], Loss: 0.0406
# Beta Model Training - Epoch [182/200], Loss: 0.0411
# Beta Model Training - Epoch [183/200], Loss: 0.0408
# Beta Model Training - Epoch [184/200], Loss: 0.0409
# Beta Model Training - Epoch [185/200], Loss: 0.0427
# Beta Model Training - Epoch [186/200], Loss: 0.0421
# Beta Model Training - Epoch [187/200], Loss: 0.0409
# Beta Model Training - Epoch [188/200], Loss: 0.0419
# Beta Model Training - Epoch [189/200], Loss: 0.0430
# Beta Model Training - Epoch [190/200], Loss: 0.0419
# Beta Model Training - Epoch [191/200], Loss: 0.0412
# Beta Model Training - Epoch [192/200], Loss: 0.0412
# Beta Model Training - Epoch [193/200], Loss: 0.0403
# Beta Model Training - Epoch [194/200], Loss: 0.0393
# Beta Model Training - Epoch [195/200], Loss: 0.0419
# Beta Model Training - Epoch [196/200], Loss: 0.0414
# Beta Model Training - Epoch [197/200], Loss: 0.0429
# Beta Model Training - Epoch [198/200], Loss: 0.0456
# Beta Model Training - Epoch [199/200], Loss: 0.0432
# Beta Model Training - Epoch [200/200], Loss: 0.0425
#
# === Building dataset/model for Beta 3 ===
# Beta Model Training - Epoch [1/200], Loss: 1.1123
# Beta Model Training - Epoch [2/200], Loss: 0.7165
# Beta Model Training - Epoch [3/200], Loss: 0.4981
# Beta Model Training - Epoch [4/200], Loss: 0.4412
# Beta Model Training - Epoch [5/200], Loss: 0.4085
# Beta Model Training - Epoch [6/200], Loss: 0.3792
# Beta Model Training - Epoch [7/200], Loss: 0.3476
# Beta Model Training - Epoch [8/200], Loss: 0.3341
# Beta Model Training - Epoch [9/200], Loss: 0.3210
# Beta Model Training - Epoch [10/200], Loss: 0.3096
# Beta Model Training - Epoch [11/200], Loss: 0.3010
# Beta Model Training - Epoch [12/200], Loss: 0.2897
# Beta Model Training - Epoch [13/200], Loss: 0.2774
# Beta Model Training - Epoch [14/200], Loss: 0.2656
# Beta Model Training - Epoch [15/200], Loss: 0.2527
# Beta Model Training - Epoch [16/200], Loss: 0.2406
# Beta Model Training - Epoch [17/200], Loss: 0.2300
# Beta Model Training - Epoch [18/200], Loss: 0.2173
# Beta Model Training - Epoch [19/200], Loss: 0.2138
# Beta Model Training - Epoch [20/200], Loss: 0.2087
# Beta Model Training - Epoch [21/200], Loss: 0.1991
# Beta Model Training - Epoch [22/200], Loss: 0.1959
# Beta Model Training - Epoch [23/200], Loss: 0.1950
# Beta Model Training - Epoch [24/200], Loss: 0.1897
# Beta Model Training - Epoch [25/200], Loss: 0.1828
# Beta Model Training - Epoch [26/200], Loss: 0.1770
# Beta Model Training - Epoch [27/200], Loss: 0.1697
# Beta Model Training - Epoch [28/200], Loss: 0.1670
# Beta Model Training - Epoch [29/200], Loss: 0.1625
# Beta Model Training - Epoch [30/200], Loss: 0.1589
# Beta Model Training - Epoch [31/200], Loss: 0.1530
# Beta Model Training - Epoch [32/200], Loss: 0.1515
# Beta Model Training - Epoch [33/200], Loss: 0.1513
# Beta Model Training - Epoch [34/200], Loss: 0.1493
# Beta Model Training - Epoch [35/200], Loss: 0.1429
# Beta Model Training - Epoch [36/200], Loss: 0.1413
# Beta Model Training - Epoch [37/200], Loss: 0.1380
# Beta Model Training - Epoch [38/200], Loss: 0.1379
# Beta Model Training - Epoch [39/200], Loss: 0.1408
# Beta Model Training - Epoch [40/200], Loss: 0.1382
# Beta Model Training - Epoch [41/200], Loss: 0.1387
# Beta Model Training - Epoch [42/200], Loss: 0.1492
# Beta Model Training - Epoch [43/200], Loss: 0.1384
# Beta Model Training - Epoch [44/200], Loss: 0.1369
# Beta Model Training - Epoch [45/200], Loss: 0.1324
# Beta Model Training - Epoch [46/200], Loss: 0.1420
# Beta Model Training - Epoch [47/200], Loss: 0.1389
# Beta Model Training - Epoch [48/200], Loss: 0.1319
# Beta Model Training - Epoch [49/200], Loss: 0.1245
# Beta Model Training - Epoch [50/200], Loss: 0.1204
# Beta Model Training - Epoch [51/200], Loss: 0.1188
# Beta Model Training - Epoch [52/200], Loss: 0.1160
# Beta Model Training - Epoch [53/200], Loss: 0.1106
# Beta Model Training - Epoch [54/200], Loss: 0.1086
# Beta Model Training - Epoch [55/200], Loss: 0.1065
# Beta Model Training - Epoch [56/200], Loss: 0.1084
# Beta Model Training - Epoch [57/200], Loss: 0.1069
# Beta Model Training - Epoch [58/200], Loss: 0.1031
# Beta Model Training - Epoch [59/200], Loss: 0.1024
# Beta Model Training - Epoch [60/200], Loss: 0.1041
# Beta Model Training - Epoch [61/200], Loss: 0.1023
# Beta Model Training - Epoch [62/200], Loss: 0.1048
# Beta Model Training - Epoch [63/200], Loss: 0.1023
# Beta Model Training - Epoch [64/200], Loss: 0.0977
# Beta Model Training - Epoch [65/200], Loss: 0.0961
# Beta Model Training - Epoch [66/200], Loss: 0.0980
# Beta Model Training - Epoch [67/200], Loss: 0.0947
# Beta Model Training - Epoch [68/200], Loss: 0.0932
# Beta Model Training - Epoch [69/200], Loss: 0.0951
# Beta Model Training - Epoch [70/200], Loss: 0.0945
# Beta Model Training - Epoch [71/200], Loss: 0.0963
# Beta Model Training - Epoch [72/200], Loss: 0.0950
# Beta Model Training - Epoch [73/200], Loss: 0.0928
# Beta Model Training - Epoch [74/200], Loss: 0.0902
# Beta Model Training - Epoch [75/200], Loss: 0.0905
# Beta Model Training - Epoch [76/200], Loss: 0.0920
# Beta Model Training - Epoch [77/200], Loss: 0.0915
# Beta Model Training - Epoch [78/200], Loss: 0.0922
# Beta Model Training - Epoch [79/200], Loss: 0.0931
# Beta Model Training - Epoch [80/200], Loss: 0.0921
# Beta Model Training - Epoch [81/200], Loss: 0.0901
# Beta Model Training - Epoch [82/200], Loss: 0.0872
# Beta Model Training - Epoch [83/200], Loss: 0.0899
# Beta Model Training - Epoch [84/200], Loss: 0.0924
# Beta Model Training - Epoch [85/200], Loss: 0.0914
# Beta Model Training - Epoch [86/200], Loss: 0.0925
# Beta Model Training - Epoch [87/200], Loss: 0.0881
# Beta Model Training - Epoch [88/200], Loss: 0.0862
# Beta Model Training - Epoch [89/200], Loss: 0.0833
# Beta Model Training - Epoch [90/200], Loss: 0.0824
# Beta Model Training - Epoch [91/200], Loss: 0.0803
# Beta Model Training - Epoch [92/200], Loss: 0.0802
# Beta Model Training - Epoch [93/200], Loss: 0.0805
# Beta Model Training - Epoch [94/200], Loss: 0.0789
# Beta Model Training - Epoch [95/200], Loss: 0.0799
# Beta Model Training - Epoch [96/200], Loss: 0.0784
# Beta Model Training - Epoch [97/200], Loss: 0.0786
# Beta Model Training - Epoch [98/200], Loss: 0.0809
# Beta Model Training - Epoch [99/200], Loss: 0.0827
# Beta Model Training - Epoch [100/200], Loss: 0.0838
# Beta Model Training - Epoch [101/200], Loss: 0.0927
# Beta Model Training - Epoch [102/200], Loss: 0.0879
# Beta Model Training - Epoch [103/200], Loss: 0.0847
# Beta Model Training - Epoch [104/200], Loss: 0.0892
# Beta Model Training - Epoch [105/200], Loss: 0.0871
# Beta Model Training - Epoch [106/200], Loss: 0.0833
# Beta Model Training - Epoch [107/200], Loss: 0.0843
# Beta Model Training - Epoch [108/200], Loss: 0.0815
# Beta Model Training - Epoch [109/200], Loss: 0.0785
# Beta Model Training - Epoch [110/200], Loss: 0.0824
# Beta Model Training - Epoch [111/200], Loss: 0.0791
# Beta Model Training - Epoch [112/200], Loss: 0.0789
# Beta Model Training - Epoch [113/200], Loss: 0.0785
# Beta Model Training - Epoch [114/200], Loss: 0.0803
# Beta Model Training - Epoch [115/200], Loss: 0.0828
# Beta Model Training - Epoch [116/200], Loss: 0.0851
# Beta Model Training - Epoch [117/200], Loss: 0.0816
# Beta Model Training - Epoch [118/200], Loss: 0.0769
# Beta Model Training - Epoch [119/200], Loss: 0.0751
# Beta Model Training - Epoch [120/200], Loss: 0.0746
# Beta Model Training - Epoch [121/200], Loss: 0.0721
# Beta Model Training - Epoch [122/200], Loss: 0.0715
# Beta Model Training - Epoch [123/200], Loss: 0.0728
# Beta Model Training - Epoch [124/200], Loss: 0.0718
# Beta Model Training - Epoch [125/200], Loss: 0.0708
# Beta Model Training - Epoch [126/200], Loss: 0.0706
# Beta Model Training - Epoch [127/200], Loss: 0.0703
# Beta Model Training - Epoch [128/200], Loss: 0.0705
# Beta Model Training - Epoch [129/200], Loss: 0.0704
# Beta Model Training - Epoch [130/200], Loss: 0.0699
# Beta Model Training - Epoch [131/200], Loss: 0.0696
# Beta Model Training - Epoch [132/200], Loss: 0.0702
# Beta Model Training - Epoch [133/200], Loss: 0.0707
# Beta Model Training - Epoch [134/200], Loss: 0.0706
# Beta Model Training - Epoch [135/200], Loss: 0.0726
# Beta Model Training - Epoch [136/200], Loss: 0.0723
# Beta Model Training - Epoch [137/200], Loss: 0.0703
# Beta Model Training - Epoch [138/200], Loss: 0.0709
# Beta Model Training - Epoch [139/200], Loss: 0.0709
# Beta Model Training - Epoch [140/200], Loss: 0.0688
# Beta Model Training - Epoch [141/200], Loss: 0.0688
# Beta Model Training - Epoch [142/200], Loss: 0.0680
# Beta Model Training - Epoch [143/200], Loss: 0.0680
# Beta Model Training - Epoch [144/200], Loss: 0.0680
# Beta Model Training - Epoch [145/200], Loss: 0.0708
# Beta Model Training - Epoch [146/200], Loss: 0.0745
# Beta Model Training - Epoch [147/200], Loss: 0.0745
# Beta Model Training - Epoch [148/200], Loss: 0.0789
# Beta Model Training - Epoch [149/200], Loss: 0.0849
# Beta Model Training - Epoch [150/200], Loss: 0.0791
# Beta Model Training - Epoch [151/200], Loss: 0.0750
# Beta Model Training - Epoch [152/200], Loss: 0.0735
# Beta Model Training - Epoch [153/200], Loss: 0.0722
# Beta Model Training - Epoch [154/200], Loss: 0.0723
# Beta Model Training - Epoch [155/200], Loss: 0.0718
# Beta Model Training - Epoch [156/200], Loss: 0.0782
# Beta Model Training - Epoch [157/200], Loss: 0.0761
# Beta Model Training - Epoch [158/200], Loss: 0.0754
# Beta Model Training - Epoch [159/200], Loss: 0.0702
# Beta Model Training - Epoch [160/200], Loss: 0.0709
# Beta Model Training - Epoch [161/200], Loss: 0.0730
# Beta Model Training - Epoch [162/200], Loss: 0.0726
# Beta Model Training - Epoch [163/200], Loss: 0.0716
# Beta Model Training - Epoch [164/200], Loss: 0.0683
# Beta Model Training - Epoch [165/200], Loss: 0.0662
# Beta Model Training - Epoch [166/200], Loss: 0.0650
# Beta Model Training - Epoch [167/200], Loss: 0.0650
# Beta Model Training - Epoch [168/200], Loss: 0.0666
# Beta Model Training - Epoch [169/200], Loss: 0.0674
# Beta Model Training - Epoch [170/200], Loss: 0.0649
# Beta Model Training - Epoch [171/200], Loss: 0.0647
# Beta Model Training - Epoch [172/200], Loss: 0.0651
# Beta Model Training - Epoch [173/200], Loss: 0.0642
# Beta Model Training - Epoch [174/200], Loss: 0.0635
# Beta Model Training - Epoch [175/200], Loss: 0.0638
# Beta Model Training - Epoch [176/200], Loss: 0.0621
# Beta Model Training - Epoch [177/200], Loss: 0.0623
# Beta Model Training - Epoch [178/200], Loss: 0.0617
# Beta Model Training - Epoch [179/200], Loss: 0.0614
# Beta Model Training - Epoch [180/200], Loss: 0.0615
# Beta Model Training - Epoch [181/200], Loss: 0.0635
# Beta Model Training - Epoch [182/200], Loss: 0.0616
# Beta Model Training - Epoch [183/200], Loss: 0.0616
# Beta Model Training - Epoch [184/200], Loss: 0.0617
# Beta Model Training - Epoch [185/200], Loss: 0.0615
# Beta Model Training - Epoch [186/200], Loss: 0.0610
# Beta Model Training - Epoch [187/200], Loss: 0.0602
# Beta Model Training - Epoch [188/200], Loss: 0.0607
# Beta Model Training - Epoch [189/200], Loss: 0.0596
# Beta Model Training - Epoch [190/200], Loss: 0.0603
# Beta Model Training - Epoch [191/200], Loss: 0.0600
# Beta Model Training - Epoch [192/200], Loss: 0.0589
# Beta Model Training - Epoch [193/200], Loss: 0.0596
# Beta Model Training - Epoch [194/200], Loss: 0.0597
# Beta Model Training - Epoch [195/200], Loss: 0.0589
# Beta Model Training - Epoch [196/200], Loss: 0.0592
# Beta Model Training - Epoch [197/200], Loss: 0.0587
# Beta Model Training - Epoch [198/200], Loss: 0.0591
# Beta Model Training - Epoch [199/200], Loss: 0.0592
# Beta Model Training - Epoch [200/200], Loss: 0.0584
#
# === Building dataset/model for Beta 4 ===
# Beta Model Training - Epoch [1/200], Loss: 0.7284
# Beta Model Training - Epoch [2/200], Loss: 0.5658
# Beta Model Training - Epoch [3/200], Loss: 0.3903
# Beta Model Training - Epoch [4/200], Loss: 0.3086
# Beta Model Training - Epoch [5/200], Loss: 0.2600
# Beta Model Training - Epoch [6/200], Loss: 0.2295
# Beta Model Training - Epoch [7/200], Loss: 0.2020
# Beta Model Training - Epoch [8/200], Loss: 0.1793
# Beta Model Training - Epoch [9/200], Loss: 0.1638
# Beta Model Training - Epoch [10/200], Loss: 0.1475
# Beta Model Training - Epoch [11/200], Loss: 0.1351
# Beta Model Training - Epoch [12/200], Loss: 0.1264
# Beta Model Training - Epoch [13/200], Loss: 0.1222
# Beta Model Training - Epoch [14/200], Loss: 0.1103
# Beta Model Training - Epoch [15/200], Loss: 0.1029
# Beta Model Training - Epoch [16/200], Loss: 0.0960
# Beta Model Training - Epoch [17/200], Loss: 0.0919
# Beta Model Training - Epoch [18/200], Loss: 0.0867
# Beta Model Training - Epoch [19/200], Loss: 0.0839
# Beta Model Training - Epoch [20/200], Loss: 0.0814
# Beta Model Training - Epoch [21/200], Loss: 0.0805
# Beta Model Training - Epoch [22/200], Loss: 0.0781
# Beta Model Training - Epoch [23/200], Loss: 0.0764
# Beta Model Training - Epoch [24/200], Loss: 0.0748
# Beta Model Training - Epoch [25/200], Loss: 0.0741
# Beta Model Training - Epoch [26/200], Loss: 0.0748
# Beta Model Training - Epoch [27/200], Loss: 0.0736
# Beta Model Training - Epoch [28/200], Loss: 0.0696
# Beta Model Training - Epoch [29/200], Loss: 0.0688
# Beta Model Training - Epoch [30/200], Loss: 0.0677
# Beta Model Training - Epoch [31/200], Loss: 0.0645
# Beta Model Training - Epoch [32/200], Loss: 0.0633
# Beta Model Training - Epoch [33/200], Loss: 0.0604
# Beta Model Training - Epoch [34/200], Loss: 0.0584
# Beta Model Training - Epoch [35/200], Loss: 0.0583
# Beta Model Training - Epoch [36/200], Loss: 0.0563
# Beta Model Training - Epoch [37/200], Loss: 0.0575
# Beta Model Training - Epoch [38/200], Loss: 0.0551
# Beta Model Training - Epoch [39/200], Loss: 0.0567
# Beta Model Training - Epoch [40/200], Loss: 0.0539
# Beta Model Training - Epoch [41/200], Loss: 0.0521
# Beta Model Training - Epoch [42/200], Loss: 0.0517
# Beta Model Training - Epoch [43/200], Loss: 0.0500
# Beta Model Training - Epoch [44/200], Loss: 0.0496
# Beta Model Training - Epoch [45/200], Loss: 0.0491
# Beta Model Training - Epoch [46/200], Loss: 0.0514
# Beta Model Training - Epoch [47/200], Loss: 0.0476
# Beta Model Training - Epoch [48/200], Loss: 0.0454
# Beta Model Training - Epoch [49/200], Loss: 0.0455
# Beta Model Training - Epoch [50/200], Loss: 0.0432
# Beta Model Training - Epoch [51/200], Loss: 0.0430
# Beta Model Training - Epoch [52/200], Loss: 0.0432
# Beta Model Training - Epoch [53/200], Loss: 0.0422
# Beta Model Training - Epoch [54/200], Loss: 0.0421
# Beta Model Training - Epoch [55/200], Loss: 0.0406
# Beta Model Training - Epoch [56/200], Loss: 0.0391
# Beta Model Training - Epoch [57/200], Loss: 0.0388
# Beta Model Training - Epoch [58/200], Loss: 0.0387
# Beta Model Training - Epoch [59/200], Loss: 0.0374
# Beta Model Training - Epoch [60/200], Loss: 0.0378
# Beta Model Training - Epoch [61/200], Loss: 0.0378
# Beta Model Training - Epoch [62/200], Loss: 0.0372
# Beta Model Training - Epoch [63/200], Loss: 0.0362
# Beta Model Training - Epoch [64/200], Loss: 0.0357
# Beta Model Training - Epoch [65/200], Loss: 0.0357
# Beta Model Training - Epoch [66/200], Loss: 0.0349
# Beta Model Training - Epoch [67/200], Loss: 0.0343
# Beta Model Training - Epoch [68/200], Loss: 0.0337
# Beta Model Training - Epoch [69/200], Loss: 0.0340
# Beta Model Training - Epoch [70/200], Loss: 0.0341
# Beta Model Training - Epoch [71/200], Loss: 0.0347
# Beta Model Training - Epoch [72/200], Loss: 0.0330
# Beta Model Training - Epoch [73/200], Loss: 0.0328
# Beta Model Training - Epoch [74/200], Loss: 0.0322
# Beta Model Training - Epoch [75/200], Loss: 0.0327
# Beta Model Training - Epoch [76/200], Loss: 0.0336
# Beta Model Training - Epoch [77/200], Loss: 0.0360
# Beta Model Training - Epoch [78/200], Loss: 0.0320
# Beta Model Training - Epoch [79/200], Loss: 0.0322
# Beta Model Training - Epoch [80/200], Loss: 0.0344
# Beta Model Training - Epoch [81/200], Loss: 0.0332
# Beta Model Training - Epoch [82/200], Loss: 0.0335
# Beta Model Training - Epoch [83/200], Loss: 0.0367
# Beta Model Training - Epoch [84/200], Loss: 0.0336
# Beta Model Training - Epoch [85/200], Loss: 0.0298
# Beta Model Training - Epoch [86/200], Loss: 0.0289
# Beta Model Training - Epoch [87/200], Loss: 0.0286
# Beta Model Training - Epoch [88/200], Loss: 0.0285
# Beta Model Training - Epoch [89/200], Loss: 0.0281
# Beta Model Training - Epoch [90/200], Loss: 0.0274
# Beta Model Training - Epoch [91/200], Loss: 0.0270
# Beta Model Training - Epoch [92/200], Loss: 0.0269
# Beta Model Training - Epoch [93/200], Loss: 0.0266
# Beta Model Training - Epoch [94/200], Loss: 0.0263
# Beta Model Training - Epoch [95/200], Loss: 0.0265
# Beta Model Training - Epoch [96/200], Loss: 0.0288
# Beta Model Training - Epoch [97/200], Loss: 0.0296
# Beta Model Training - Epoch [98/200], Loss: 0.0291
# Beta Model Training - Epoch [99/200], Loss: 0.0279
# Beta Model Training - Epoch [100/200], Loss: 0.0282
# Beta Model Training - Epoch [101/200], Loss: 0.0332
# Beta Model Training - Epoch [102/200], Loss: 0.0300
# Beta Model Training - Epoch [103/200], Loss: 0.0276
# Beta Model Training - Epoch [104/200], Loss: 0.0272
# Beta Model Training - Epoch [105/200], Loss: 0.0276
# Beta Model Training - Epoch [106/200], Loss: 0.0263
# Beta Model Training - Epoch [107/200], Loss: 0.0263
# Beta Model Training - Epoch [108/200], Loss: 0.0260
# Beta Model Training - Epoch [109/200], Loss: 0.0259
# Beta Model Training - Epoch [110/200], Loss: 0.0249
# Beta Model Training - Epoch [111/200], Loss: 0.0251
# Beta Model Training - Epoch [112/200], Loss: 0.0241
# Beta Model Training - Epoch [113/200], Loss: 0.0238
# Beta Model Training - Epoch [114/200], Loss: 0.0238
# Beta Model Training - Epoch [115/200], Loss: 0.0238
# Beta Model Training - Epoch [116/200], Loss: 0.0242
# Beta Model Training - Epoch [117/200], Loss: 0.0260
# Beta Model Training - Epoch [118/200], Loss: 0.0275
# Beta Model Training - Epoch [119/200], Loss: 0.0309
# Beta Model Training - Epoch [120/200], Loss: 0.0340
# Beta Model Training - Epoch [121/200], Loss: 0.0394
# Beta Model Training - Epoch [122/200], Loss: 0.0338
# Beta Model Training - Epoch [123/200], Loss: 0.0292
# Beta Model Training - Epoch [124/200], Loss: 0.0268
# Beta Model Training - Epoch [125/200], Loss: 0.0247
# Beta Model Training - Epoch [126/200], Loss: 0.0244
# Beta Model Training - Epoch [127/200], Loss: 0.0248
# Beta Model Training - Epoch [128/200], Loss: 0.0232
# Beta Model Training - Epoch [129/200], Loss: 0.0229
# Beta Model Training - Epoch [130/200], Loss: 0.0231
# Beta Model Training - Epoch [131/200], Loss: 0.0224
# Beta Model Training - Epoch [132/200], Loss: 0.0218
# Beta Model Training - Epoch [133/200], Loss: 0.0221
# Beta Model Training - Epoch [134/200], Loss: 0.0216
# Beta Model Training - Epoch [135/200], Loss: 0.0214
# Beta Model Training - Epoch [136/200], Loss: 0.0211
# Beta Model Training - Epoch [137/200], Loss: 0.0209
# Beta Model Training - Epoch [138/200], Loss: 0.0210
# Beta Model Training - Epoch [139/200], Loss: 0.0207
# Beta Model Training - Epoch [140/200], Loss: 0.0209
# Beta Model Training - Epoch [141/200], Loss: 0.0207
# Beta Model Training - Epoch [142/200], Loss: 0.0206
# Beta Model Training - Epoch [143/200], Loss: 0.0208
# Beta Model Training - Epoch [144/200], Loss: 0.0217
# Beta Model Training - Epoch [145/200], Loss: 0.0209
# Beta Model Training - Epoch [146/200], Loss: 0.0204
# Beta Model Training - Epoch [147/200], Loss: 0.0201
# Beta Model Training - Epoch [148/200], Loss: 0.0201
# Beta Model Training - Epoch [149/200], Loss: 0.0204
# Beta Model Training - Epoch [150/200], Loss: 0.0205
# Beta Model Training - Epoch [151/200], Loss: 0.0205
# Beta Model Training - Epoch [152/200], Loss: 0.0201
# Beta Model Training - Epoch [153/200], Loss: 0.0202
# Beta Model Training - Epoch [154/200], Loss: 0.0202
# Beta Model Training - Epoch [155/200], Loss: 0.0204
# Beta Model Training - Epoch [156/200], Loss: 0.0203
# Beta Model Training - Epoch [157/200], Loss: 0.0197
# Beta Model Training - Epoch [158/200], Loss: 0.0202
# Beta Model Training - Epoch [159/200], Loss: 0.0201
# Beta Model Training - Epoch [160/200], Loss: 0.0197
# Beta Model Training - Epoch [161/200], Loss: 0.0193
# Beta Model Training - Epoch [162/200], Loss: 0.0193
# Beta Model Training - Epoch [163/200], Loss: 0.0191
# Beta Model Training - Epoch [164/200], Loss: 0.0188
# Beta Model Training - Epoch [165/200], Loss: 0.0192
# Beta Model Training - Epoch [166/200], Loss: 0.0197
# Beta Model Training - Epoch [167/200], Loss: 0.0202
# Beta Model Training - Epoch [168/200], Loss: 0.0206
# Beta Model Training - Epoch [169/200], Loss: 0.0197
# Beta Model Training - Epoch [170/200], Loss: 0.0195
# Beta Model Training - Epoch [171/200], Loss: 0.0194
# Beta Model Training - Epoch [172/200], Loss: 0.0189
# Beta Model Training - Epoch [173/200], Loss: 0.0191
# Beta Model Training - Epoch [174/200], Loss: 0.0190
# Beta Model Training - Epoch [175/200], Loss: 0.0185
# Beta Model Training - Epoch [176/200], Loss: 0.0189
# Beta Model Training - Epoch [177/200], Loss: 0.0185
# Beta Model Training - Epoch [178/200], Loss: 0.0180
# Beta Model Training - Epoch [179/200], Loss: 0.0184
# Beta Model Training - Epoch [180/200], Loss: 0.0206
# Beta Model Training - Epoch [181/200], Loss: 0.0211
# Beta Model Training - Epoch [182/200], Loss: 0.0205
# Beta Model Training - Epoch [183/200], Loss: 0.0205
# Beta Model Training - Epoch [184/200], Loss: 0.0204
# Beta Model Training - Epoch [185/200], Loss: 0.0231
# Beta Model Training - Epoch [186/200], Loss: 0.0236
# Beta Model Training - Epoch [187/200], Loss: 0.0207
# Beta Model Training - Epoch [188/200], Loss: 0.0229
# Beta Model Training - Epoch [189/200], Loss: 0.0207
# Beta Model Training - Epoch [190/200], Loss: 0.0206
# Beta Model Training - Epoch [191/200], Loss: 0.0196
# Beta Model Training - Epoch [192/200], Loss: 0.0198
# Beta Model Training - Epoch [193/200], Loss: 0.0187
# Beta Model Training - Epoch [194/200], Loss: 0.0184
# Beta Model Training - Epoch [195/200], Loss: 0.0190
# Beta Model Training - Epoch [196/200], Loss: 0.0189
# Beta Model Training - Epoch [197/200], Loss: 0.0184
# Beta Model Training - Epoch [198/200], Loss: 0.0198
# Beta Model Training - Epoch [199/200], Loss: 0.0202
# Beta Model Training - Epoch [200/200], Loss: 0.0200

# %%
# save importances results
save_dir = os.path.join(curr_dir, analysis_type, 'Masking')
os.makedirs(save_dir, exist_ok=True)

save_subdir_chan = os.path.join(save_dir, 'Channel Masking')
os.makedirs(save_subdir_chan, exist_ok=True)

save_subdir_region = os.path.join(save_dir, 'Region Masking')
os.makedirs(save_subdir_region, exist_ok=True)

save_subdir_subject = os.path.join(save_dir, 'Subject Masking')
os.makedirs(save_subdir_subject, exist_ok=True)

imp_chan_zero_data = {'all_imp_chan_zero': all_imp_chan_zero}
imp_chan_drop_data = {'all_imp_chan_drop': all_imp_chan_drop}
imp_chan_mean_data = {'all_imp_chan_mean': all_imp_chan_mean}
imp_region_mean_data = {'all_imp_region_mean': all_imp_region_mean}
imp_subject_mean_data = {'all_imp_subject_mean': all_imp_subject_mean}

savemat(os.path.join(save_subdir_chan, 'imp_chan_zero.mat'), imp_chan_zero_data)
savemat(os.path.join(save_subdir_chan, 'imp_chan_drop.mat'), imp_chan_drop_data)
savemat(os.path.join(save_subdir_chan, 'imp_chan_mean.mat'), imp_chan_mean_data)
savemat(os.path.join(save_subdir_region, 'imp_region_mean.mat'), imp_region_mean_data)
savemat(os.path.join(save_subdir_subject, 'imp_subject_mean.mat'), imp_subject_mean_data)

# %%
# Visualize importances of channel masking zero method

values = all_imp_chan_zero.mean(axis=1)  # mean across subjects
plt.figure(figsize=(16,13))
plt.imshow(values, aspect='auto', origin='lower', cmap='Reds')
plt.colorbar(label='Mean importance')
plt.xticks(ticks=np.arange(nChan), labels=np.arange(1, nChan+1))
plt.xlabel('Channel')
plt.ylabel('Beta')
plt.title(analysis_type + '_Channel Importance_zero')
plt.tight_layout()
plt.savefig(os.path.join(save_subdir_chan, analysis_type + '_Channel Importance_zero.png'))
#plt.show()
plt.close()

for iBeta in range(nBeta):
    values = all_imp_chan_zero[iBeta]
    plt.figure(figsize=(16,13))
    plt.imshow(values, aspect='auto', origin='lower', cmap='Reds')
    plt.colorbar(label='Importance')
    plt.xticks(ticks=np.arange(nChan), labels=np.arange(1, nChan+1))
    plt.xlabel('Channel')
    plt.ylabel('Subject')
    plt.title(f'Beta {iBeta}_{analysis_type}_Channel Importance_zero')
    plt.tight_layout()
    plt.savefig(os.path.join(save_subdir_chan, analysis_type + f'_Beta_{iBeta}_Channel_Importance_zero.png'))
    #plt.show()
    plt.close()

# %%
# Visualize importances of channel masking mean method

values = all_imp_chan_mean.mean(axis=1)  # mean across subjects
plt.figure(figsize=(16,13))
plt.imshow(values, aspect='auto', origin='lower', cmap='Reds')
plt.colorbar(label='Mean importance')
plt.xticks(ticks=np.arange(nChan), labels=np.arange(1, nChan+1))
plt.xlabel('Channel')
plt.ylabel('Beta')
plt.title(analysis_type + '_Channel Importance_mean')
plt.tight_layout()
plt.savefig(os.path.join(save_subdir_chan, analysis_type + '_Channel Importance_mean.png'))
#plt.show()
plt.close()

for iBeta in range(nBeta):
    values = all_imp_chan_mean[iBeta]
    plt.figure(figsize=(16,13))
    plt.imshow(values, aspect='auto', origin='lower', cmap='Reds')
    plt.colorbar(label='Importance')
    plt.xticks(ticks=np.arange(nChan), labels=np.arange(1, nChan+1))
    plt.xlabel('Channel')
    plt.ylabel('Subject')
    plt.title(f'Beta {iBeta}_{analysis_type}_Channel Importance_mean')
    plt.tight_layout()
    plt.savefig(os.path.join(save_subdir_chan, analysis_type + f'_Beta_{iBeta}_Channel_Importance_mean.png'))
    #plt.show()
    plt.close()

# %%
# Visualize importances of channel masking dropping method

values = all_imp_chan_drop.mean(axis=1)  # mean across subjects
plt.figure(figsize=(16,13))
plt.imshow(values, aspect='auto', origin='lower', cmap='Reds')
plt.colorbar(label='Mean importance')
plt.xticks(ticks=np.arange(nChan), labels=np.arange(1, nChan+1))
plt.xlabel('Channel')
plt.ylabel('Beta')
plt.title(analysis_type+'_Channel Importance_drop')
plt.tight_layout()
plt.savefig(os.path.join(save_subdir_chan, analysis_type + '_Channel Importance_drop.png'))
#plt.show()
plt.close()

for iBeta in range(nBeta):
    values = all_imp_chan_drop[iBeta]
    plt.figure(figsize=(16,13))
    plt.imshow(values, aspect='auto', origin='lower', cmap='Reds')
    plt.colorbar(label='Importance')
    plt.xticks(ticks=np.arange(nChan), labels=np.arange(1, nChan+1))
    plt.xlabel('Channel')
    plt.ylabel('Subject')
    plt.title(f'Beta {iBeta}_{analysis_type}_Channel Importance_drop')
    plt.tight_layout()
    plt.savefig(os.path.join(save_subdir_chan, analysis_type + f'_Beta_{iBeta}_Channel_Importance_drop.png'))
    #plt.show()
    plt.close()

# %%
# Visualize importances of region hard masking

values = all_imp_region_mean.mean(axis=1)
plt.figure(figsize=(16,13))
plt.imshow(values, aspect='auto', origin='lower', cmap='Reds')
plt.colorbar(label='Mean importance')
plt.xticks(ticks=np.arange(nChan), labels=np.arange(1, nChan+1))
plt.xlabel('Channel')
plt.ylabel('Beta')
plt.title(analysis_type+'_Region Importance_mean')
plt.tight_layout()
plt.savefig(os.path.join(save_subdir_region, analysis_type + '_Region Importance_mean.png'))
#plt.show()
plt.close()

for iBeta in range(nBeta):
    values = all_imp_region_mean[iBeta]
    plt.figure(figsize=(16,13))
    plt.imshow(values, aspect='auto', origin='lower', cmap='Reds')
    plt.colorbar(label='Importance')
    plt.xticks(ticks=np.arange(nChan), labels=np.arange(1, nChan+1))
    plt.xlabel('Channel')
    plt.ylabel('Subject')
    plt.title(f'Beta {iBeta}_{analysis_type}_Region Importance_mean')
    plt.tight_layout()
    plt.savefig(os.path.join(save_subdir_region, analysis_type + f'_Beta_{iBeta}_Region_Importance_mean.png'))
    #plt.show()
    plt.close()

# %%
# Visualize importances of subject masking

plt.figure(figsize=(16,13))
plt.imshow(all_imp_subject_mean, aspect='auto', origin='lower', cmap='Reds')
plt.colorbar(label='Importance')
plt.xticks(ticks=np.arange(nSubject), labels=np.arange(1, nSubject+1))
plt.xlabel('Subject')
plt.ylabel('Beta')
plt.title(analysis_type+'_Subject Importance_mean')
plt.tight_layout()
plt.savefig(os.path.join(save_subdir_subject, analysis_type + '_Subject Importance_mean.png'))
#plt.show()
plt.close()

for iBeta in range(nBeta):
    values = all_imp_subject_mean[iBeta]
    plt.figure(figsize=(16,13))
    plt.imshow(values.reshape(1, -1), aspect='auto', origin='lower', cmap='Reds')
    plt.colorbar(label='Importance')
    plt.xticks(ticks=np.arange(nSubject), labels=np.arange(1, nSubject+1))
    plt.xlabel('Subject')
    plt.title(f'Beta {iBeta}_{analysis_type}_Subject Importance_mean')
    plt.tight_layout()
    plt.savefig(os.path.join(save_subdir_subject, analysis_type + f'_Beta_{iBeta}_Subject_Importance_mean.png'))
    #plt.show()
    plt.close()
