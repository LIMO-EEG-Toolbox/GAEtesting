# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset, ConcatDataset
from torch_geometric.loader import DataLoader as GeometricDataLoader
from torch_geometric.data import Data
from torch_geometric.utils import dense_to_sparse
import torch_geometric.nn as pyg_nn
import os
import matplotlib.pyplot as plt
from scipy.io import loadmat, savemat

# %%
# Load saved beta data from mat files
analysis_type = 'MMN'
curr_dir = os.getcwd()
datain_dir = os.path.join(os.getcwd(), 'datain')
datain_mat = loadmat(os.path.join(datain_dir, analysis_type + '_original_betas.mat'))
binatry_matrix_mat = loadmat(os.path.join(datain_dir, 'adjacency_matrix.mat'))
datain = datain_mat['data']
binatry_matrix = binatry_matrix_mat['adjacency_matrix']

datain = np.array(datain)          # shape: [nBeta, nTime, nChan, nSubject] (adjust as needed)
binatry_matrix = np.array(binatry_matrix)

# Parse shapes
nBeta     = datain.shape[0]
nTime     = datain.shape[1]
nChan     = datain.shape[2]
nSubject  = datain.shape[3]

# %%
# ===========================================
# 2) Set device & convert adjacency
# ===========================================
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
edge_index, _ = dense_to_sparse(torch.tensor(binatry_matrix, dtype=torch.float32))
print(device)

# ===========================================
# 3) Dataset builder
# ===========================================
def build_concat_dataset_for_beta(datain, beta_idx):
    """
    Build a ConcatDataset across all subjects for one beta index.
    `datain` is [nBeta, nTime, nChan, nSubject].
    Returns: ConcatDataset of length nSubject.
    """
    subject_datasets = []
    for s in range(nSubject):
        # Extract slice for one subject and one beta
        # shape: [nTime, nChan]
        single_beta_data = datain[beta_idx, :, :, s]

        # If each node is a channel and its feature dimension is time,
        # we might want single_beta_data to be [nChan, nTime].
        # If so, transpose here:
        single_beta_data = single_beta_data.T  # shape: [nChan, nTime]

        # For an autoencoder, features=labels
        x_tensor = torch.tensor(single_beta_data, dtype=torch.float32)
        x_tensor = x_tensor.unsqueeze(0)

        subject_datasets.append(TensorDataset(x_tensor, x_tensor))

    return ConcatDataset(subject_datasets)
# Out:
# cuda

# %%
# ===========================================
# 4) PyG Graph Dataset
# ===========================================
class EEGGraphDataset(torch.utils.data.Dataset):
    """
    Wraps a standard dataset so that each item is a PyG Data object:
      x -> node features (channels)
      edge_index -> adjacency
    """
    def __init__(self, eeg_data, edge_index):
        self.eeg_data = eeg_data
        self.edge_index = edge_index

    def __len__(self):
        return len(self.eeg_data)

    def __getitem__(self, idx):
        # item: (x, x) because it's autoencoder
        sample = self.eeg_data[idx]
        x = sample[0]  # shape: [nChan, nTime] (if you used transpose above)
        # Convert x -> float32, build PyG Data
        graph_data = Data(x=torch.tensor(x, dtype=torch.float32),
                          edge_index=self.edge_index)
        return graph_data

# %%
# ===========================================
# 5) Define GraphAutoencoder
# ===========================================
class GraphAutoencoder(nn.Module):
    def __init__(self, num_features, embedding_dim=64):
        """
        num_features = dimension of each node's feature vector.
                       If each channel is a node, and you pass
                       [nChan, nTime], then num_features = nTime.
        """
        super(GraphAutoencoder, self).__init__()
        # Example with two ARMAConv layers
        self.encoder_gcn1 = pyg_nn.ARMAConv(num_features, 128, 
                                            num_stacks=2, 
                                            num_layers=3,
                                            shared_weights=True)
        self.encoder_gcn2 = pyg_nn.ARMAConv(128, embedding_dim, 
                                            num_stacks=2, 
                                            num_layers=3,
                                            shared_weights=True)
        self.decoder_fc1 = nn.Linear(embedding_dim, 128)
        self.decoder_fc2 = nn.Linear(128, num_features)

    # def forward(self, x, edge_index):
    #     x = torch.relu(self.encoder_gcn1(x, edge_index))
    #     latent = torch.relu(self.encoder_gcn2(x, edge_index))
    #     x = torch.relu(self.decoder_fc1(latent))
    #     reconstructed = self.decoder_fc2(x)
    #     return reconstructed
    
    def encode(self, x, edge_index):
        x = torch.relu(self.encoder_gcn1(x, edge_index))
        latent = torch.relu(self.encoder_gcn2(x, edge_index))
        return latent
    
    def decode(self, latent):
        x = torch.relu(self.decoder_fc1(latent))
        reconstructed = self.decoder_fc2(x)
        return reconstructed
    
    def forward(self, x, edge_index):
        latent = self.encode(x, edge_index)
        reconstructed = self.decode(latent)
        return reconstructed, latent

# %%
# ===========================================
# 6) Training and evaluation
# ===========================================
def train_model_all(model, train_loader, device, num_epochs):
    model.to(device)
    optimizer = optim.Adam(model.parameters(), lr=1e-3)
    criterion = nn.SmoothL1Loss()

    for epoch in range(num_epochs):
        model.train()
        epoch_loss = 0.0
        for batch_data in train_loader:
            batch_data = batch_data.to(device)
            optimizer.zero_grad()

            # Forward
            reconstructed, _ = model(batch_data.x, batch_data.edge_index)
            loss = criterion(reconstructed, batch_data.x)

            # Backprop
            loss.backward()
            optimizer.step()
            epoch_loss += loss.item()

        epoch_loss /= len(train_loader)
        print(f"Beta Model Training - Epoch [{epoch+1}/{num_epochs}], Loss: {epoch_loss:.4f}")
    return model

def evaluation_model(model, data_sample, edge_index, device):
    """
    data_sample: shape [nChan, nTime], or [nTime, nChan],
                 whichever you used in training.
    Returns: (original_np, reconstructed_np, error_np)
    """
    model.eval()
    with torch.no_grad():
        x = torch.tensor(data_sample, dtype=torch.float32, device=device)
        eidx = edge_index.to(device)
        reconstructed, _ = model(x, eidx)
    orig = x.cpu().numpy()
    recon = reconstructed.cpu().numpy()
    error = orig - recon
    return orig, recon, error

# %%
# LinearProbing part

# Define a simple linear layer probe without activation function as
class LinearProbe(nn.Module):
    def __init__(self, embedding_dim, num_features):
        super().__init__()
        self.probe = nn.Linear(embedding_dim, num_features, bias=True)

    def forward(self, x):
        return self.probe(x)


# Train linear probe using frozen GAE latent representations
def train_linear_probe(model, train_loader, device, embedding_dim, num_features, num_epochs):
    # Freeze GAE model parameters
    model.eval()
    for param in model.parameters():
        param.requires_grad = False
        
    linear_probe = LinearProbe(embedding_dim, num_features).to(device)
    optimizer = optim.Adam(linear_probe.parameters(), lr=1e-3)
    criterion = nn.SmoothL1Loss()
    
    for epoch in range(num_epochs):
        linear_probe.train()
        epoch_loss = 0.0
        for batch_data in train_loader:
            batch_data = batch_data.to(device)
            optimizer.zero_grad()
            
            # Get latent representations from frozen GAE
            with torch.no_grad():
                latent = model.encode(batch_data.x, batch_data.edge_index)
            
            lin_reconstructed = linear_probe(latent)
            loss = criterion(lin_reconstructed, batch_data.x)

            loss.backward()
            optimizer.step()
            epoch_loss += loss.item()

        epoch_loss /= len(train_loader)
        print(f"Linear Probe Training - Epoch [{epoch+1}/{num_epochs}], Loss: {epoch_loss:.4f}")

    return linear_probe

def evaluation_linear_probe(model, linear_probe, data_sample, edge_index, device):
    model.eval()
    linear_probe.eval()
    with torch.no_grad():
        x = torch.tensor(data_sample, dtype=torch.float32, device=device)
        eidx = edge_index.to(device)
        latent_repr = model.encode(x, eidx)
        lin_reconstructed = linear_probe(latent_repr)
    orig = x.cpu().numpy()
    recon = lin_reconstructed.cpu().numpy()
    error = orig - recon
    return orig, recon, error

# %%
# ===========================================
# 7) Main pipeline
#    1) For each beta, build dataset/loader.
#    2) Initialize & train a separate model.
#    3) Reconstruct each subject's data for that beta.
#    4) Store reconstruction in a final array.
# ===========================================

num_features = nTime   # if each channel is a node, and feature vector = [nTime]
num_epochs   = 200     # number of training - set as needed
batch_size   = 4;      # dataset/batch to update hyperparameters

models = []
ori_reconstructed_list = []  # will hold arrays of shape [nSubject, nChan, nTime] for each beta
linPro_reconstructed_list = []
ori_error_list = []
linPro_error_list = []

for iBeta in range(nBeta):
    print(f"\n=== Building dataset/model for Beta {iBeta} ===")
    # Build dataset & loader
    full_dataset_i  = build_concat_dataset_for_beta(datain, iBeta)
    graph_dataset_i = EEGGraphDataset(full_dataset_i, edge_index)
    full_loader_i   = GeometricDataLoader(graph_dataset_i, batch_size=batch_size, shuffle=True)

    # Init model & train
    model_i = GraphAutoencoder(num_features=num_features, embedding_dim=32)
    model_i = train_model_all(model_i, full_loader_i, device, num_epochs=num_epochs)
    models.append(model_i)

    # Train linear probe
    linPro_model = train_linear_probe(model_i, full_loader_i, device, embedding_dim=32, num_features=num_features, num_epochs=num_epochs)

    # Error evaluation original GAE vs Linear Probing for all subjects
    ori_error_per_subject = []
    linPro_error_per_subject = []
    
    ori_recon_per_subject = []
    linPro_recon_per_subject = []
    
    for s in range(len(full_dataset_i)):
        data_s = full_dataset_i[s][0].numpy()  # [nChan, nTime]
        _, recon_o, error_o = evaluation_model(model_i, data_s, edge_index, device)
        _, recon_l, error_l = evaluation_linear_probe(model_i, linPro_model, data_s, edge_index, device)
        
        ori_error_per_subject.append(error_o)
        linPro_error_per_subject.append(error_l)
        
        ori_recon_per_subject.append(recon_o)  # shape [nChan, nTime]
        linPro_recon_per_subject.append(recon_l)
        

    ori_error_list.append(np.array(ori_error_per_subject))
    linPro_error_list.append(np.array(linPro_error_per_subject))

    ori_reconstructed_list.append(np.array(ori_recon_per_subject))
    linPro_reconstructed_list.append(np.array(linPro_recon_per_subject))

ori_reconstructed_all = np.array(ori_reconstructed_list)  # [nBeta, nSubject, nChan, nTime]
linPro_reconstructed_all = np.array(linPro_reconstructed_list)
ori_error_all = np.array(ori_error_list)  # [nBeta, nSubject, nChan, nTime]
linPro_error_all = np.array(linPro_error_list)
# Out:
# === Building dataset/model for Beta 0 ===
# Beta Model Training - Epoch [1/200], Loss: 0.0943
# Beta Model Training - Epoch [2/200], Loss: 0.0789
# C:\Users\86136\AppData\Local\Temp\ipykernel_33340\1382389434.py:22: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   graph_data = Data(x=torch.tensor(x, dtype=torch.float32),
# Beta Model Training - Epoch [3/200], Loss: 0.0629
# Beta Model Training - Epoch [4/200], Loss: 0.0553
# Beta Model Training - Epoch [5/200], Loss: 0.0499
# Beta Model Training - Epoch [6/200], Loss: 0.0451
# Beta Model Training - Epoch [7/200], Loss: 0.0410
# Beta Model Training - Epoch [8/200], Loss: 0.0379
# Beta Model Training - Epoch [9/200], Loss: 0.0352
# Beta Model Training - Epoch [10/200], Loss: 0.0326
# Beta Model Training - Epoch [11/200], Loss: 0.0307
# Beta Model Training - Epoch [12/200], Loss: 0.0291
# Beta Model Training - Epoch [13/200], Loss: 0.0277
# Beta Model Training - Epoch [14/200], Loss: 0.0267
# Beta Model Training - Epoch [15/200], Loss: 0.0258
# Beta Model Training - Epoch [16/200], Loss: 0.0249
# Beta Model Training - Epoch [17/200], Loss: 0.0240
# Beta Model Training - Epoch [18/200], Loss: 0.0231
# Beta Model Training - Epoch [19/200], Loss: 0.0222
# Beta Model Training - Epoch [20/200], Loss: 0.0215
# Beta Model Training - Epoch [21/200], Loss: 0.0209
# Beta Model Training - Epoch [22/200], Loss: 0.0203
# Beta Model Training - Epoch [23/200], Loss: 0.0198
# Beta Model Training - Epoch [24/200], Loss: 0.0194
# Beta Model Training - Epoch [25/200], Loss: 0.0192
# Beta Model Training - Epoch [26/200], Loss: 0.0189
# Beta Model Training - Epoch [27/200], Loss: 0.0186
# Beta Model Training - Epoch [28/200], Loss: 0.0181
# Beta Model Training - Epoch [29/200], Loss: 0.0175
# Beta Model Training - Epoch [30/200], Loss: 0.0172
# Beta Model Training - Epoch [31/200], Loss: 0.0168
# Beta Model Training - Epoch [32/200], Loss: 0.0165
# Beta Model Training - Epoch [33/200], Loss: 0.0162
# Beta Model Training - Epoch [34/200], Loss: 0.0159
# Beta Model Training - Epoch [35/200], Loss: 0.0157
# Beta Model Training - Epoch [36/200], Loss: 0.0155
# Beta Model Training - Epoch [37/200], Loss: 0.0154
# Beta Model Training - Epoch [38/200], Loss: 0.0151
# Beta Model Training - Epoch [39/200], Loss: 0.0151
# Beta Model Training - Epoch [40/200], Loss: 0.0150
# Beta Model Training - Epoch [41/200], Loss: 0.0152
# Beta Model Training - Epoch [42/200], Loss: 0.0149
# Beta Model Training - Epoch [43/200], Loss: 0.0147
# Beta Model Training - Epoch [44/200], Loss: 0.0145
# Beta Model Training - Epoch [45/200], Loss: 0.0144
# Beta Model Training - Epoch [46/200], Loss: 0.0142
# Beta Model Training - Epoch [47/200], Loss: 0.0141
# Beta Model Training - Epoch [48/200], Loss: 0.0138
# Beta Model Training - Epoch [49/200], Loss: 0.0137
# Beta Model Training - Epoch [50/200], Loss: 0.0135
# Beta Model Training - Epoch [51/200], Loss: 0.0135
# Beta Model Training - Epoch [52/200], Loss: 0.0132
# Beta Model Training - Epoch [53/200], Loss: 0.0131
# Beta Model Training - Epoch [54/200], Loss: 0.0129
# Beta Model Training - Epoch [55/200], Loss: 0.0129
# Beta Model Training - Epoch [56/200], Loss: 0.0128
# Beta Model Training - Epoch [57/200], Loss: 0.0128
# Beta Model Training - Epoch [58/200], Loss: 0.0127
# Beta Model Training - Epoch [59/200], Loss: 0.0126
# Beta Model Training - Epoch [60/200], Loss: 0.0124
# Beta Model Training - Epoch [61/200], Loss: 0.0123
# Beta Model Training - Epoch [62/200], Loss: 0.0123
# Beta Model Training - Epoch [63/200], Loss: 0.0122
# Beta Model Training - Epoch [64/200], Loss: 0.0121
# Beta Model Training - Epoch [65/200], Loss: 0.0121
# Beta Model Training - Epoch [66/200], Loss: 0.0121
# Beta Model Training - Epoch [67/200], Loss: 0.0121
# Beta Model Training - Epoch [68/200], Loss: 0.0121
# Beta Model Training - Epoch [69/200], Loss: 0.0120
# Beta Model Training - Epoch [70/200], Loss: 0.0118
# Beta Model Training - Epoch [71/200], Loss: 0.0118
# Beta Model Training - Epoch [72/200], Loss: 0.0118
# Beta Model Training - Epoch [73/200], Loss: 0.0118
# Beta Model Training - Epoch [74/200], Loss: 0.0117
# Beta Model Training - Epoch [75/200], Loss: 0.0116
# Beta Model Training - Epoch [76/200], Loss: 0.0115
# Beta Model Training - Epoch [77/200], Loss: 0.0116
# Beta Model Training - Epoch [78/200], Loss: 0.0115
# Beta Model Training - Epoch [79/200], Loss: 0.0114
# Beta Model Training - Epoch [80/200], Loss: 0.0114
# Beta Model Training - Epoch [81/200], Loss: 0.0113
# Beta Model Training - Epoch [82/200], Loss: 0.0113
# Beta Model Training - Epoch [83/200], Loss: 0.0113
# Beta Model Training - Epoch [84/200], Loss: 0.0112
# Beta Model Training - Epoch [85/200], Loss: 0.0111
# Beta Model Training - Epoch [86/200], Loss: 0.0113
# Beta Model Training - Epoch [87/200], Loss: 0.0115
# Beta Model Training - Epoch [88/200], Loss: 0.0115
# Beta Model Training - Epoch [89/200], Loss: 0.0112
# Beta Model Training - Epoch [90/200], Loss: 0.0117
# Beta Model Training - Epoch [91/200], Loss: 0.0113
# Beta Model Training - Epoch [92/200], Loss: 0.0111
# Beta Model Training - Epoch [93/200], Loss: 0.0111
# Beta Model Training - Epoch [94/200], Loss: 0.0109
# Beta Model Training - Epoch [95/200], Loss: 0.0109
# Beta Model Training - Epoch [96/200], Loss: 0.0109
# Beta Model Training - Epoch [97/200], Loss: 0.0107
# Beta Model Training - Epoch [98/200], Loss: 0.0107
# Beta Model Training - Epoch [99/200], Loss: 0.0106
# Beta Model Training - Epoch [100/200], Loss: 0.0106
# Beta Model Training - Epoch [101/200], Loss: 0.0106
# Beta Model Training - Epoch [102/200], Loss: 0.0106
# Beta Model Training - Epoch [103/200], Loss: 0.0104
# Beta Model Training - Epoch [104/200], Loss: 0.0105
# Beta Model Training - Epoch [105/200], Loss: 0.0104
# Beta Model Training - Epoch [106/200], Loss: 0.0103
# Beta Model Training - Epoch [107/200], Loss: 0.0103
# Beta Model Training - Epoch [108/200], Loss: 0.0103
# Beta Model Training - Epoch [109/200], Loss: 0.0102
# Beta Model Training - Epoch [110/200], Loss: 0.0102
# Beta Model Training - Epoch [111/200], Loss: 0.0102
# Beta Model Training - Epoch [112/200], Loss: 0.0102
# Beta Model Training - Epoch [113/200], Loss: 0.0102
# Beta Model Training - Epoch [114/200], Loss: 0.0101
# Beta Model Training - Epoch [115/200], Loss: 0.0101
# Beta Model Training - Epoch [116/200], Loss: 0.0101
# Beta Model Training - Epoch [117/200], Loss: 0.0100
# Beta Model Training - Epoch [118/200], Loss: 0.0100
# Beta Model Training - Epoch [119/200], Loss: 0.0101
# Beta Model Training - Epoch [120/200], Loss: 0.0100
# Beta Model Training - Epoch [121/200], Loss: 0.0100
# Beta Model Training - Epoch [122/200], Loss: 0.0100
# Beta Model Training - Epoch [123/200], Loss: 0.0100
# Beta Model Training - Epoch [124/200], Loss: 0.0101
# Beta Model Training - Epoch [125/200], Loss: 0.0102
# Beta Model Training - Epoch [126/200], Loss: 0.0101
# Beta Model Training - Epoch [127/200], Loss: 0.0100
# Beta Model Training - Epoch [128/200], Loss: 0.0100
# Beta Model Training - Epoch [129/200], Loss: 0.0100
# Beta Model Training - Epoch [130/200], Loss: 0.0099
# Beta Model Training - Epoch [131/200], Loss: 0.0099
# Beta Model Training - Epoch [132/200], Loss: 0.0099
# Beta Model Training - Epoch [133/200], Loss: 0.0099
# Beta Model Training - Epoch [134/200], Loss: 0.0098
# Beta Model Training - Epoch [135/200], Loss: 0.0098
# Beta Model Training - Epoch [136/200], Loss: 0.0097
# Beta Model Training - Epoch [137/200], Loss: 0.0097
# Beta Model Training - Epoch [138/200], Loss: 0.0097
# Beta Model Training - Epoch [139/200], Loss: 0.0097
# Beta Model Training - Epoch [140/200], Loss: 0.0096
# Beta Model Training - Epoch [141/200], Loss: 0.0096
# Beta Model Training - Epoch [142/200], Loss: 0.0097
# Beta Model Training - Epoch [143/200], Loss: 0.0098
# Beta Model Training - Epoch [144/200], Loss: 0.0096
# Beta Model Training - Epoch [145/200], Loss: 0.0097
# Beta Model Training - Epoch [146/200], Loss: 0.0096
# Beta Model Training - Epoch [147/200], Loss: 0.0098
# Beta Model Training - Epoch [148/200], Loss: 0.0097
# Beta Model Training - Epoch [149/200], Loss: 0.0096
# Beta Model Training - Epoch [150/200], Loss: 0.0097
# Beta Model Training - Epoch [151/200], Loss: 0.0098
# Beta Model Training - Epoch [152/200], Loss: 0.0096
# Beta Model Training - Epoch [153/200], Loss: 0.0096
# Beta Model Training - Epoch [154/200], Loss: 0.0096
# Beta Model Training - Epoch [155/200], Loss: 0.0099
# Beta Model Training - Epoch [156/200], Loss: 0.0098
# Beta Model Training - Epoch [157/200], Loss: 0.0099
# Beta Model Training - Epoch [158/200], Loss: 0.0100
# Beta Model Training - Epoch [159/200], Loss: 0.0099
# Beta Model Training - Epoch [160/200], Loss: 0.0100
# Beta Model Training - Epoch [161/200], Loss: 0.0100
# Beta Model Training - Epoch [162/200], Loss: 0.0098
# Beta Model Training - Epoch [163/200], Loss: 0.0098
# Beta Model Training - Epoch [164/200], Loss: 0.0096
# Beta Model Training - Epoch [165/200], Loss: 0.0096
# Beta Model Training - Epoch [166/200], Loss: 0.0095
# Beta Model Training - Epoch [167/200], Loss: 0.0095
# Beta Model Training - Epoch [168/200], Loss: 0.0094
# Beta Model Training - Epoch [169/200], Loss: 0.0093
# Beta Model Training - Epoch [170/200], Loss: 0.0093
# Beta Model Training - Epoch [171/200], Loss: 0.0093
# Beta Model Training - Epoch [172/200], Loss: 0.0092
# Beta Model Training - Epoch [173/200], Loss: 0.0092
# Beta Model Training - Epoch [174/200], Loss: 0.0092
# Beta Model Training - Epoch [175/200], Loss: 0.0092
# Beta Model Training - Epoch [176/200], Loss: 0.0092
# Beta Model Training - Epoch [177/200], Loss: 0.0092
# Beta Model Training - Epoch [178/200], Loss: 0.0091
# Beta Model Training - Epoch [179/200], Loss: 0.0091
# Beta Model Training - Epoch [180/200], Loss: 0.0092
# Beta Model Training - Epoch [181/200], Loss: 0.0091
# Beta Model Training - Epoch [182/200], Loss: 0.0092
# Beta Model Training - Epoch [183/200], Loss: 0.0091
# Beta Model Training - Epoch [184/200], Loss: 0.0091
# Beta Model Training - Epoch [185/200], Loss: 0.0091
# Beta Model Training - Epoch [186/200], Loss: 0.0091
# Beta Model Training - Epoch [187/200], Loss: 0.0091
# Beta Model Training - Epoch [188/200], Loss: 0.0091
# Beta Model Training - Epoch [189/200], Loss: 0.0091
# Beta Model Training - Epoch [190/200], Loss: 0.0091
# Beta Model Training - Epoch [191/200], Loss: 0.0091
# Beta Model Training - Epoch [192/200], Loss: 0.0091
# Beta Model Training - Epoch [193/200], Loss: 0.0091
# Beta Model Training - Epoch [194/200], Loss: 0.0091
# Beta Model Training - Epoch [195/200], Loss: 0.0091
# Beta Model Training - Epoch [196/200], Loss: 0.0091
# Beta Model Training - Epoch [197/200], Loss: 0.0090
# Beta Model Training - Epoch [198/200], Loss: 0.0090
# Beta Model Training - Epoch [199/200], Loss: 0.0090
# Beta Model Training - Epoch [200/200], Loss: 0.0090
# Linear Probe Training - Epoch [1/200], Loss: 0.5454
# Linear Probe Training - Epoch [2/200], Loss: 0.3180
# Linear Probe Training - Epoch [3/200], Loss: 0.2124
# Linear Probe Training - Epoch [4/200], Loss: 0.1715
# Linear Probe Training - Epoch [5/200], Loss: 0.1572
# Linear Probe Training - Epoch [6/200], Loss: 0.1485
# Linear Probe Training - Epoch [7/200], Loss: 0.1416
# Linear Probe Training - Epoch [8/200], Loss: 0.1353
# Linear Probe Training - Epoch [9/200], Loss: 0.1294
# Linear Probe Training - Epoch [10/200], Loss: 0.1240
# Linear Probe Training - Epoch [11/200], Loss: 0.1189
# Linear Probe Training - Epoch [12/200], Loss: 0.1139
# Linear Probe Training - Epoch [13/200], Loss: 0.1092
# Linear Probe Training - Epoch [14/200], Loss: 0.1049
# Linear Probe Training - Epoch [15/200], Loss: 0.1006
# Linear Probe Training - Epoch [16/200], Loss: 0.0967
# Linear Probe Training - Epoch [17/200], Loss: 0.0929
# Linear Probe Training - Epoch [18/200], Loss: 0.0892
# Linear Probe Training - Epoch [19/200], Loss: 0.0859
# Linear Probe Training - Epoch [20/200], Loss: 0.0826
# Linear Probe Training - Epoch [21/200], Loss: 0.0795
# Linear Probe Training - Epoch [22/200], Loss: 0.0767
# Linear Probe Training - Epoch [23/200], Loss: 0.0740
# Linear Probe Training - Epoch [24/200], Loss: 0.0713
# Linear Probe Training - Epoch [25/200], Loss: 0.0688
# Linear Probe Training - Epoch [26/200], Loss: 0.0664
# Linear Probe Training - Epoch [27/200], Loss: 0.0642
# Linear Probe Training - Epoch [28/200], Loss: 0.0620
# Linear Probe Training - Epoch [29/200], Loss: 0.0600
# Linear Probe Training - Epoch [30/200], Loss: 0.0581
# Linear Probe Training - Epoch [31/200], Loss: 0.0561
# Linear Probe Training - Epoch [32/200], Loss: 0.0544
# Linear Probe Training - Epoch [33/200], Loss: 0.0527
# Linear Probe Training - Epoch [34/200], Loss: 0.0511
# Linear Probe Training - Epoch [35/200], Loss: 0.0495
# Linear Probe Training - Epoch [36/200], Loss: 0.0481
# Linear Probe Training - Epoch [37/200], Loss: 0.0467
# Linear Probe Training - Epoch [38/200], Loss: 0.0454
# Linear Probe Training - Epoch [39/200], Loss: 0.0440
# Linear Probe Training - Epoch [40/200], Loss: 0.0428
# Linear Probe Training - Epoch [41/200], Loss: 0.0417
# Linear Probe Training - Epoch [42/200], Loss: 0.0405
# Linear Probe Training - Epoch [43/200], Loss: 0.0395
# Linear Probe Training - Epoch [44/200], Loss: 0.0384
# Linear Probe Training - Epoch [45/200], Loss: 0.0375
# Linear Probe Training - Epoch [46/200], Loss: 0.0365
# Linear Probe Training - Epoch [47/200], Loss: 0.0356
# Linear Probe Training - Epoch [48/200], Loss: 0.0347
# Linear Probe Training - Epoch [49/200], Loss: 0.0339
# Linear Probe Training - Epoch [50/200], Loss: 0.0331
# Linear Probe Training - Epoch [51/200], Loss: 0.0323
# Linear Probe Training - Epoch [52/200], Loss: 0.0316
# Linear Probe Training - Epoch [53/200], Loss: 0.0308
# Linear Probe Training - Epoch [54/200], Loss: 0.0302
# Linear Probe Training - Epoch [55/200], Loss: 0.0295
# Linear Probe Training - Epoch [56/200], Loss: 0.0289
# Linear Probe Training - Epoch [57/200], Loss: 0.0282
# Linear Probe Training - Epoch [58/200], Loss: 0.0277
# Linear Probe Training - Epoch [59/200], Loss: 0.0271
# Linear Probe Training - Epoch [60/200], Loss: 0.0266
# Linear Probe Training - Epoch [61/200], Loss: 0.0260
# Linear Probe Training - Epoch [62/200], Loss: 0.0255
# Linear Probe Training - Epoch [63/200], Loss: 0.0250
# Linear Probe Training - Epoch [64/200], Loss: 0.0246
# Linear Probe Training - Epoch [65/200], Loss: 0.0241
# Linear Probe Training - Epoch [66/200], Loss: 0.0237
# Linear Probe Training - Epoch [67/200], Loss: 0.0232
# Linear Probe Training - Epoch [68/200], Loss: 0.0229
# Linear Probe Training - Epoch [69/200], Loss: 0.0225
# Linear Probe Training - Epoch [70/200], Loss: 0.0221
# Linear Probe Training - Epoch [71/200], Loss: 0.0217
# Linear Probe Training - Epoch [72/200], Loss: 0.0213
# Linear Probe Training - Epoch [73/200], Loss: 0.0210
# Linear Probe Training - Epoch [74/200], Loss: 0.0207
# Linear Probe Training - Epoch [75/200], Loss: 0.0204
# Linear Probe Training - Epoch [76/200], Loss: 0.0200
# Linear Probe Training - Epoch [77/200], Loss: 0.0197
# Linear Probe Training - Epoch [78/200], Loss: 0.0194
# Linear Probe Training - Epoch [79/200], Loss: 0.0192
# Linear Probe Training - Epoch [80/200], Loss: 0.0189
# Linear Probe Training - Epoch [81/200], Loss: 0.0186
# Linear Probe Training - Epoch [82/200], Loss: 0.0184
# Linear Probe Training - Epoch [83/200], Loss: 0.0181
# Linear Probe Training - Epoch [84/200], Loss: 0.0179
# Linear Probe Training - Epoch [85/200], Loss: 0.0177
# Linear Probe Training - Epoch [86/200], Loss: 0.0174
# Linear Probe Training - Epoch [87/200], Loss: 0.0172
# Linear Probe Training - Epoch [88/200], Loss: 0.0170
# Linear Probe Training - Epoch [89/200], Loss: 0.0168
# Linear Probe Training - Epoch [90/200], Loss: 0.0166
# Linear Probe Training - Epoch [91/200], Loss: 0.0164
# Linear Probe Training - Epoch [92/200], Loss: 0.0162
# Linear Probe Training - Epoch [93/200], Loss: 0.0161
# Linear Probe Training - Epoch [94/200], Loss: 0.0159
# Linear Probe Training - Epoch [95/200], Loss: 0.0157
# Linear Probe Training - Epoch [96/200], Loss: 0.0156
# Linear Probe Training - Epoch [97/200], Loss: 0.0154
# Linear Probe Training - Epoch [98/200], Loss: 0.0152
# Linear Probe Training - Epoch [99/200], Loss: 0.0151
# Linear Probe Training - Epoch [100/200], Loss: 0.0150
# Linear Probe Training - Epoch [101/200], Loss: 0.0148
# Linear Probe Training - Epoch [102/200], Loss: 0.0147
# Linear Probe Training - Epoch [103/200], Loss: 0.0145
# Linear Probe Training - Epoch [104/200], Loss: 0.0144
# Linear Probe Training - Epoch [105/200], Loss: 0.0143
# Linear Probe Training - Epoch [106/200], Loss: 0.0142
# Linear Probe Training - Epoch [107/200], Loss: 0.0140
# Linear Probe Training - Epoch [108/200], Loss: 0.0139
# Linear Probe Training - Epoch [109/200], Loss: 0.0138
# Linear Probe Training - Epoch [110/200], Loss: 0.0137
# Linear Probe Training - Epoch [111/200], Loss: 0.0136
# Linear Probe Training - Epoch [112/200], Loss: 0.0135
# Linear Probe Training - Epoch [113/200], Loss: 0.0134
# Linear Probe Training - Epoch [114/200], Loss: 0.0133
# Linear Probe Training - Epoch [115/200], Loss: 0.0132
# Linear Probe Training - Epoch [116/200], Loss: 0.0131
# Linear Probe Training - Epoch [117/200], Loss: 0.0131
# Linear Probe Training - Epoch [118/200], Loss: 0.0130
# Linear Probe Training - Epoch [119/200], Loss: 0.0129
# Linear Probe Training - Epoch [120/200], Loss: 0.0128
# Linear Probe Training - Epoch [121/200], Loss: 0.0127
# Linear Probe Training - Epoch [122/200], Loss: 0.0127
# Linear Probe Training - Epoch [123/200], Loss: 0.0126
# Linear Probe Training - Epoch [124/200], Loss: 0.0125
# Linear Probe Training - Epoch [125/200], Loss: 0.0124
# Linear Probe Training - Epoch [126/200], Loss: 0.0124
# Linear Probe Training - Epoch [127/200], Loss: 0.0123
# Linear Probe Training - Epoch [128/200], Loss: 0.0122
# Linear Probe Training - Epoch [129/200], Loss: 0.0122
# Linear Probe Training - Epoch [130/200], Loss: 0.0121
# Linear Probe Training - Epoch [131/200], Loss: 0.0121
# Linear Probe Training - Epoch [132/200], Loss: 0.0120
# Linear Probe Training - Epoch [133/200], Loss: 0.0120
# Linear Probe Training - Epoch [134/200], Loss: 0.0119
# Linear Probe Training - Epoch [135/200], Loss: 0.0119
# Linear Probe Training - Epoch [136/200], Loss: 0.0118
# Linear Probe Training - Epoch [137/200], Loss: 0.0118
# Linear Probe Training - Epoch [138/200], Loss: 0.0117
# Linear Probe Training - Epoch [139/200], Loss: 0.0117
# Linear Probe Training - Epoch [140/200], Loss: 0.0116
# Linear Probe Training - Epoch [141/200], Loss: 0.0116
# Linear Probe Training - Epoch [142/200], Loss: 0.0115
# Linear Probe Training - Epoch [143/200], Loss: 0.0115
# Linear Probe Training - Epoch [144/200], Loss: 0.0115
# Linear Probe Training - Epoch [145/200], Loss: 0.0114
# Linear Probe Training - Epoch [146/200], Loss: 0.0114
# Linear Probe Training - Epoch [147/200], Loss: 0.0113
# Linear Probe Training - Epoch [148/200], Loss: 0.0113
# Linear Probe Training - Epoch [149/200], Loss: 0.0113
# Linear Probe Training - Epoch [150/200], Loss: 0.0112
# Linear Probe Training - Epoch [151/200], Loss: 0.0112
# Linear Probe Training - Epoch [152/200], Loss: 0.0112
# Linear Probe Training - Epoch [153/200], Loss: 0.0112
# Linear Probe Training - Epoch [154/200], Loss: 0.0111
# Linear Probe Training - Epoch [155/200], Loss: 0.0111
# Linear Probe Training - Epoch [156/200], Loss: 0.0110
# Linear Probe Training - Epoch [157/200], Loss: 0.0110
# Linear Probe Training - Epoch [158/200], Loss: 0.0110
# Linear Probe Training - Epoch [159/200], Loss: 0.0110
# Linear Probe Training - Epoch [160/200], Loss: 0.0110
# Linear Probe Training - Epoch [161/200], Loss: 0.0109
# Linear Probe Training - Epoch [162/200], Loss: 0.0109
# Linear Probe Training - Epoch [163/200], Loss: 0.0109
# Linear Probe Training - Epoch [164/200], Loss: 0.0109
# Linear Probe Training - Epoch [165/200], Loss: 0.0108
# Linear Probe Training - Epoch [166/200], Loss: 0.0108
# Linear Probe Training - Epoch [167/200], Loss: 0.0108
# Linear Probe Training - Epoch [168/200], Loss: 0.0108
# Linear Probe Training - Epoch [169/200], Loss: 0.0107
# Linear Probe Training - Epoch [170/200], Loss: 0.0107
# Linear Probe Training - Epoch [171/200], Loss: 0.0107
# Linear Probe Training - Epoch [172/200], Loss: 0.0107
# Linear Probe Training - Epoch [173/200], Loss: 0.0107
# Linear Probe Training - Epoch [174/200], Loss: 0.0107
# Linear Probe Training - Epoch [175/200], Loss: 0.0106
# Linear Probe Training - Epoch [176/200], Loss: 0.0106
# Linear Probe Training - Epoch [177/200], Loss: 0.0106
# Linear Probe Training - Epoch [178/200], Loss: 0.0106
# Linear Probe Training - Epoch [179/200], Loss: 0.0106
# Linear Probe Training - Epoch [180/200], Loss: 0.0106
# Linear Probe Training - Epoch [181/200], Loss: 0.0105
# Linear Probe Training - Epoch [182/200], Loss: 0.0105
# Linear Probe Training - Epoch [183/200], Loss: 0.0105
# Linear Probe Training - Epoch [184/200], Loss: 0.0105
# Linear Probe Training - Epoch [185/200], Loss: 0.0105
# Linear Probe Training - Epoch [186/200], Loss: 0.0105
# Linear Probe Training - Epoch [187/200], Loss: 0.0105
# Linear Probe Training - Epoch [188/200], Loss: 0.0105
# Linear Probe Training - Epoch [189/200], Loss: 0.0105
# Linear Probe Training - Epoch [190/200], Loss: 0.0104
# Linear Probe Training - Epoch [191/200], Loss: 0.0104
# Linear Probe Training - Epoch [192/200], Loss: 0.0104
# Linear Probe Training - Epoch [193/200], Loss: 0.0104
# Linear Probe Training - Epoch [194/200], Loss: 0.0104
# Linear Probe Training - Epoch [195/200], Loss: 0.0104
# Linear Probe Training - Epoch [196/200], Loss: 0.0104
# Linear Probe Training - Epoch [197/200], Loss: 0.0104
# Linear Probe Training - Epoch [198/200], Loss: 0.0104
# Linear Probe Training - Epoch [199/200], Loss: 0.0104
# Linear Probe Training - Epoch [200/200], Loss: 0.0103
#
# === Building dataset/model for Beta 1 ===
# Beta Model Training - Epoch [1/200], Loss: 0.0659
# Beta Model Training - Epoch [2/200], Loss: 0.0528
# Beta Model Training - Epoch [3/200], Loss: 0.0406
# Beta Model Training - Epoch [4/200], Loss: 0.0338
# Beta Model Training - Epoch [5/200], Loss: 0.0309
# Beta Model Training - Epoch [6/200], Loss: 0.0284
# Beta Model Training - Epoch [7/200], Loss: 0.0257
# Beta Model Training - Epoch [8/200], Loss: 0.0234
# Beta Model Training - Epoch [9/200], Loss: 0.0216
# Beta Model Training - Epoch [10/200], Loss: 0.0204
# Beta Model Training - Epoch [11/200], Loss: 0.0196
# Beta Model Training - Epoch [12/200], Loss: 0.0185
# Beta Model Training - Epoch [13/200], Loss: 0.0175
# Beta Model Training - Epoch [14/200], Loss: 0.0166
# Beta Model Training - Epoch [15/200], Loss: 0.0158
# Beta Model Training - Epoch [16/200], Loss: 0.0149
# Beta Model Training - Epoch [17/200], Loss: 0.0140
# Beta Model Training - Epoch [18/200], Loss: 0.0134
# Beta Model Training - Epoch [19/200], Loss: 0.0128
# Beta Model Training - Epoch [20/200], Loss: 0.0126
# Beta Model Training - Epoch [21/200], Loss: 0.0121
# Beta Model Training - Epoch [22/200], Loss: 0.0117
# Beta Model Training - Epoch [23/200], Loss: 0.0114
# Beta Model Training - Epoch [24/200], Loss: 0.0111
# Beta Model Training - Epoch [25/200], Loss: 0.0109
# Beta Model Training - Epoch [26/200], Loss: 0.0106
# Beta Model Training - Epoch [27/200], Loss: 0.0103
# Beta Model Training - Epoch [28/200], Loss: 0.0101
# Beta Model Training - Epoch [29/200], Loss: 0.0100
# Beta Model Training - Epoch [30/200], Loss: 0.0098
# Beta Model Training - Epoch [31/200], Loss: 0.0097
# Beta Model Training - Epoch [32/200], Loss: 0.0097
# Beta Model Training - Epoch [33/200], Loss: 0.0097
# Beta Model Training - Epoch [34/200], Loss: 0.0096
# Beta Model Training - Epoch [35/200], Loss: 0.0093
# Beta Model Training - Epoch [36/200], Loss: 0.0091
# Beta Model Training - Epoch [37/200], Loss: 0.0090
# Beta Model Training - Epoch [38/200], Loss: 0.0091
# Beta Model Training - Epoch [39/200], Loss: 0.0090
# Beta Model Training - Epoch [40/200], Loss: 0.0087
# Beta Model Training - Epoch [41/200], Loss: 0.0085
# Beta Model Training - Epoch [42/200], Loss: 0.0085
# Beta Model Training - Epoch [43/200], Loss: 0.0084
# Beta Model Training - Epoch [44/200], Loss: 0.0083
# Beta Model Training - Epoch [45/200], Loss: 0.0081
# Beta Model Training - Epoch [46/200], Loss: 0.0081
# Beta Model Training - Epoch [47/200], Loss: 0.0080
# Beta Model Training - Epoch [48/200], Loss: 0.0080
# Beta Model Training - Epoch [49/200], Loss: 0.0079
# Beta Model Training - Epoch [50/200], Loss: 0.0079
# Beta Model Training - Epoch [51/200], Loss: 0.0079
# Beta Model Training - Epoch [52/200], Loss: 0.0077
# Beta Model Training - Epoch [53/200], Loss: 0.0076
# Beta Model Training - Epoch [54/200], Loss: 0.0075
# Beta Model Training - Epoch [55/200], Loss: 0.0074
# Beta Model Training - Epoch [56/200], Loss: 0.0073
# Beta Model Training - Epoch [57/200], Loss: 0.0072
# Beta Model Training - Epoch [58/200], Loss: 0.0072
# Beta Model Training - Epoch [59/200], Loss: 0.0071
# Beta Model Training - Epoch [60/200], Loss: 0.0071
# Beta Model Training - Epoch [61/200], Loss: 0.0071
# Beta Model Training - Epoch [62/200], Loss: 0.0070
# Beta Model Training - Epoch [63/200], Loss: 0.0069
# Beta Model Training - Epoch [64/200], Loss: 0.0069
# Beta Model Training - Epoch [65/200], Loss: 0.0069
# Beta Model Training - Epoch [66/200], Loss: 0.0068
# Beta Model Training - Epoch [67/200], Loss: 0.0068
# Beta Model Training - Epoch [68/200], Loss: 0.0068
# Beta Model Training - Epoch [69/200], Loss: 0.0067
# Beta Model Training - Epoch [70/200], Loss: 0.0066
# Beta Model Training - Epoch [71/200], Loss: 0.0067
# Beta Model Training - Epoch [72/200], Loss: 0.0066
# Beta Model Training - Epoch [73/200], Loss: 0.0067
# Beta Model Training - Epoch [74/200], Loss: 0.0066
# Beta Model Training - Epoch [75/200], Loss: 0.0066
# Beta Model Training - Epoch [76/200], Loss: 0.0065
# Beta Model Training - Epoch [77/200], Loss: 0.0064
# Beta Model Training - Epoch [78/200], Loss: 0.0064
# Beta Model Training - Epoch [79/200], Loss: 0.0064
# Beta Model Training - Epoch [80/200], Loss: 0.0064
# Beta Model Training - Epoch [81/200], Loss: 0.0063
# Beta Model Training - Epoch [82/200], Loss: 0.0063
# Beta Model Training - Epoch [83/200], Loss: 0.0063
# Beta Model Training - Epoch [84/200], Loss: 0.0063
# Beta Model Training - Epoch [85/200], Loss: 0.0062
# Beta Model Training - Epoch [86/200], Loss: 0.0063
# Beta Model Training - Epoch [87/200], Loss: 0.0063
# Beta Model Training - Epoch [88/200], Loss: 0.0065
# Beta Model Training - Epoch [89/200], Loss: 0.0064
# Beta Model Training - Epoch [90/200], Loss: 0.0063
# Beta Model Training - Epoch [91/200], Loss: 0.0065
# Beta Model Training - Epoch [92/200], Loss: 0.0067
# Beta Model Training - Epoch [93/200], Loss: 0.0064
# Beta Model Training - Epoch [94/200], Loss: 0.0063
# Beta Model Training - Epoch [95/200], Loss: 0.0061
# Beta Model Training - Epoch [96/200], Loss: 0.0061
# Beta Model Training - Epoch [97/200], Loss: 0.0060
# Beta Model Training - Epoch [98/200], Loss: 0.0060
# Beta Model Training - Epoch [99/200], Loss: 0.0060
# Beta Model Training - Epoch [100/200], Loss: 0.0060
# Beta Model Training - Epoch [101/200], Loss: 0.0059
# Beta Model Training - Epoch [102/200], Loss: 0.0059
# Beta Model Training - Epoch [103/200], Loss: 0.0059
# Beta Model Training - Epoch [104/200], Loss: 0.0059
# Beta Model Training - Epoch [105/200], Loss: 0.0058
# Beta Model Training - Epoch [106/200], Loss: 0.0058
# Beta Model Training - Epoch [107/200], Loss: 0.0058
# Beta Model Training - Epoch [108/200], Loss: 0.0058
# Beta Model Training - Epoch [109/200], Loss: 0.0058
# Beta Model Training - Epoch [110/200], Loss: 0.0058
# Beta Model Training - Epoch [111/200], Loss: 0.0059
# Beta Model Training - Epoch [112/200], Loss: 0.0062
# Beta Model Training - Epoch [113/200], Loss: 0.0059
# Beta Model Training - Epoch [114/200], Loss: 0.0058
# Beta Model Training - Epoch [115/200], Loss: 0.0058
# Beta Model Training - Epoch [116/200], Loss: 0.0060
# Beta Model Training - Epoch [117/200], Loss: 0.0059
# Beta Model Training - Epoch [118/200], Loss: 0.0058
# Beta Model Training - Epoch [119/200], Loss: 0.0057
# Beta Model Training - Epoch [120/200], Loss: 0.0057
# Beta Model Training - Epoch [121/200], Loss: 0.0057
# Beta Model Training - Epoch [122/200], Loss: 0.0057
# Beta Model Training - Epoch [123/200], Loss: 0.0056
# Beta Model Training - Epoch [124/200], Loss: 0.0056
# Beta Model Training - Epoch [125/200], Loss: 0.0057
# Beta Model Training - Epoch [126/200], Loss: 0.0056
# Beta Model Training - Epoch [127/200], Loss: 0.0056
# Beta Model Training - Epoch [128/200], Loss: 0.0056
# Beta Model Training - Epoch [129/200], Loss: 0.0056
# Beta Model Training - Epoch [130/200], Loss: 0.0056
# Beta Model Training - Epoch [131/200], Loss: 0.0055
# Beta Model Training - Epoch [132/200], Loss: 0.0055
# Beta Model Training - Epoch [133/200], Loss: 0.0055
# Beta Model Training - Epoch [134/200], Loss: 0.0055
# Beta Model Training - Epoch [135/200], Loss: 0.0055
# Beta Model Training - Epoch [136/200], Loss: 0.0055
# Beta Model Training - Epoch [137/200], Loss: 0.0055
# Beta Model Training - Epoch [138/200], Loss: 0.0055
# Beta Model Training - Epoch [139/200], Loss: 0.0055
# Beta Model Training - Epoch [140/200], Loss: 0.0055
# Beta Model Training - Epoch [141/200], Loss: 0.0054
# Beta Model Training - Epoch [142/200], Loss: 0.0054
# Beta Model Training - Epoch [143/200], Loss: 0.0054
# Beta Model Training - Epoch [144/200], Loss: 0.0054
# Beta Model Training - Epoch [145/200], Loss: 0.0054
# Beta Model Training - Epoch [146/200], Loss: 0.0054
# Beta Model Training - Epoch [147/200], Loss: 0.0054
# Beta Model Training - Epoch [148/200], Loss: 0.0055
# Beta Model Training - Epoch [149/200], Loss: 0.0055
# Beta Model Training - Epoch [150/200], Loss: 0.0057
# Beta Model Training - Epoch [151/200], Loss: 0.0056
# Beta Model Training - Epoch [152/200], Loss: 0.0059
# Beta Model Training - Epoch [153/200], Loss: 0.0065
# Beta Model Training - Epoch [154/200], Loss: 0.0062
# Beta Model Training - Epoch [155/200], Loss: 0.0064
# Beta Model Training - Epoch [156/200], Loss: 0.0059
# Beta Model Training - Epoch [157/200], Loss: 0.0056
# Beta Model Training - Epoch [158/200], Loss: 0.0056
# Beta Model Training - Epoch [159/200], Loss: 0.0057
# Beta Model Training - Epoch [160/200], Loss: 0.0056
# Beta Model Training - Epoch [161/200], Loss: 0.0056
# Beta Model Training - Epoch [162/200], Loss: 0.0054
# Beta Model Training - Epoch [163/200], Loss: 0.0054
# Beta Model Training - Epoch [164/200], Loss: 0.0053
# Beta Model Training - Epoch [165/200], Loss: 0.0053
# Beta Model Training - Epoch [166/200], Loss: 0.0053
# Beta Model Training - Epoch [167/200], Loss: 0.0053
# Beta Model Training - Epoch [168/200], Loss: 0.0053
# Beta Model Training - Epoch [169/200], Loss: 0.0053
# Beta Model Training - Epoch [170/200], Loss: 0.0052
# Beta Model Training - Epoch [171/200], Loss: 0.0053
# Beta Model Training - Epoch [172/200], Loss: 0.0053
# Beta Model Training - Epoch [173/200], Loss: 0.0053
# Beta Model Training - Epoch [174/200], Loss: 0.0052
# Beta Model Training - Epoch [175/200], Loss: 0.0052
# Beta Model Training - Epoch [176/200], Loss: 0.0052
# Beta Model Training - Epoch [177/200], Loss: 0.0052
# Beta Model Training - Epoch [178/200], Loss: 0.0052
# Beta Model Training - Epoch [179/200], Loss: 0.0052
# Beta Model Training - Epoch [180/200], Loss: 0.0052
# Beta Model Training - Epoch [181/200], Loss: 0.0052
# Beta Model Training - Epoch [182/200], Loss: 0.0052
# Beta Model Training - Epoch [183/200], Loss: 0.0052
# Beta Model Training - Epoch [184/200], Loss: 0.0052
# Beta Model Training - Epoch [185/200], Loss: 0.0052
# Beta Model Training - Epoch [186/200], Loss: 0.0053
# Beta Model Training - Epoch [187/200], Loss: 0.0053
# Beta Model Training - Epoch [188/200], Loss: 0.0052
# Beta Model Training - Epoch [189/200], Loss: 0.0052
# Beta Model Training - Epoch [190/200], Loss: 0.0053
# Beta Model Training - Epoch [191/200], Loss: 0.0053
# Beta Model Training - Epoch [192/200], Loss: 0.0053
# Beta Model Training - Epoch [193/200], Loss: 0.0052
# Beta Model Training - Epoch [194/200], Loss: 0.0053
# Beta Model Training - Epoch [195/200], Loss: 0.0052
# Beta Model Training - Epoch [196/200], Loss: 0.0052
# Beta Model Training - Epoch [197/200], Loss: 0.0052
# Beta Model Training - Epoch [198/200], Loss: 0.0052
# Beta Model Training - Epoch [199/200], Loss: 0.0052
# Beta Model Training - Epoch [200/200], Loss: 0.0052
# Linear Probe Training - Epoch [1/200], Loss: 0.3224
# Linear Probe Training - Epoch [2/200], Loss: 0.1939
# Linear Probe Training - Epoch [3/200], Loss: 0.1383
# Linear Probe Training - Epoch [4/200], Loss: 0.1137
# Linear Probe Training - Epoch [5/200], Loss: 0.1008
# Linear Probe Training - Epoch [6/200], Loss: 0.0918
# Linear Probe Training - Epoch [7/200], Loss: 0.0848
# Linear Probe Training - Epoch [8/200], Loss: 0.0793
# Linear Probe Training - Epoch [9/200], Loss: 0.0747
# Linear Probe Training - Epoch [10/200], Loss: 0.0707
# Linear Probe Training - Epoch [11/200], Loss: 0.0673
# Linear Probe Training - Epoch [12/200], Loss: 0.0639
# Linear Probe Training - Epoch [13/200], Loss: 0.0610
# Linear Probe Training - Epoch [14/200], Loss: 0.0582
# Linear Probe Training - Epoch [15/200], Loss: 0.0557
# Linear Probe Training - Epoch [16/200], Loss: 0.0534
# Linear Probe Training - Epoch [17/200], Loss: 0.0512
# Linear Probe Training - Epoch [18/200], Loss: 0.0492
# Linear Probe Training - Epoch [19/200], Loss: 0.0473
# Linear Probe Training - Epoch [20/200], Loss: 0.0455
# Linear Probe Training - Epoch [21/200], Loss: 0.0438
# Linear Probe Training - Epoch [22/200], Loss: 0.0423
# Linear Probe Training - Epoch [23/200], Loss: 0.0408
# Linear Probe Training - Epoch [24/200], Loss: 0.0395
# Linear Probe Training - Epoch [25/200], Loss: 0.0381
# Linear Probe Training - Epoch [26/200], Loss: 0.0368
# Linear Probe Training - Epoch [27/200], Loss: 0.0357
# Linear Probe Training - Epoch [28/200], Loss: 0.0345
# Linear Probe Training - Epoch [29/200], Loss: 0.0334
# Linear Probe Training - Epoch [30/200], Loss: 0.0324
# Linear Probe Training - Epoch [31/200], Loss: 0.0314
# Linear Probe Training - Epoch [32/200], Loss: 0.0305
# Linear Probe Training - Epoch [33/200], Loss: 0.0297
# Linear Probe Training - Epoch [34/200], Loss: 0.0288
# Linear Probe Training - Epoch [35/200], Loss: 0.0279
# Linear Probe Training - Epoch [36/200], Loss: 0.0272
# Linear Probe Training - Epoch [37/200], Loss: 0.0264
# Linear Probe Training - Epoch [38/200], Loss: 0.0257
# Linear Probe Training - Epoch [39/200], Loss: 0.0250
# Linear Probe Training - Epoch [40/200], Loss: 0.0243
# Linear Probe Training - Epoch [41/200], Loss: 0.0237
# Linear Probe Training - Epoch [42/200], Loss: 0.0231
# Linear Probe Training - Epoch [43/200], Loss: 0.0225
# Linear Probe Training - Epoch [44/200], Loss: 0.0219
# Linear Probe Training - Epoch [45/200], Loss: 0.0214
# Linear Probe Training - Epoch [46/200], Loss: 0.0209
# Linear Probe Training - Epoch [47/200], Loss: 0.0204
# Linear Probe Training - Epoch [48/200], Loss: 0.0199
# Linear Probe Training - Epoch [49/200], Loss: 0.0194
# Linear Probe Training - Epoch [50/200], Loss: 0.0190
# Linear Probe Training - Epoch [51/200], Loss: 0.0185
# Linear Probe Training - Epoch [52/200], Loss: 0.0181
# Linear Probe Training - Epoch [53/200], Loss: 0.0177
# Linear Probe Training - Epoch [54/200], Loss: 0.0173
# Linear Probe Training - Epoch [55/200], Loss: 0.0169
# Linear Probe Training - Epoch [56/200], Loss: 0.0166
# Linear Probe Training - Epoch [57/200], Loss: 0.0163
# Linear Probe Training - Epoch [58/200], Loss: 0.0159
# Linear Probe Training - Epoch [59/200], Loss: 0.0156
# Linear Probe Training - Epoch [60/200], Loss: 0.0153
# Linear Probe Training - Epoch [61/200], Loss: 0.0150
# Linear Probe Training - Epoch [62/200], Loss: 0.0147
# Linear Probe Training - Epoch [63/200], Loss: 0.0144
# Linear Probe Training - Epoch [64/200], Loss: 0.0141
# Linear Probe Training - Epoch [65/200], Loss: 0.0139
# Linear Probe Training - Epoch [66/200], Loss: 0.0136
# Linear Probe Training - Epoch [67/200], Loss: 0.0134
# Linear Probe Training - Epoch [68/200], Loss: 0.0131
# Linear Probe Training - Epoch [69/200], Loss: 0.0129
# Linear Probe Training - Epoch [70/200], Loss: 0.0127
# Linear Probe Training - Epoch [71/200], Loss: 0.0125
# Linear Probe Training - Epoch [72/200], Loss: 0.0123
# Linear Probe Training - Epoch [73/200], Loss: 0.0121
# Linear Probe Training - Epoch [74/200], Loss: 0.0119
# Linear Probe Training - Epoch [75/200], Loss: 0.0117
# Linear Probe Training - Epoch [76/200], Loss: 0.0115
# Linear Probe Training - Epoch [77/200], Loss: 0.0113
# Linear Probe Training - Epoch [78/200], Loss: 0.0111
# Linear Probe Training - Epoch [79/200], Loss: 0.0110
# Linear Probe Training - Epoch [80/200], Loss: 0.0108
# Linear Probe Training - Epoch [81/200], Loss: 0.0107
# Linear Probe Training - Epoch [82/200], Loss: 0.0105
# Linear Probe Training - Epoch [83/200], Loss: 0.0104
# Linear Probe Training - Epoch [84/200], Loss: 0.0102
# Linear Probe Training - Epoch [85/200], Loss: 0.0101
# Linear Probe Training - Epoch [86/200], Loss: 0.0100
# Linear Probe Training - Epoch [87/200], Loss: 0.0098
# Linear Probe Training - Epoch [88/200], Loss: 0.0097
# Linear Probe Training - Epoch [89/200], Loss: 0.0096
# Linear Probe Training - Epoch [90/200], Loss: 0.0095
# Linear Probe Training - Epoch [91/200], Loss: 0.0094
# Linear Probe Training - Epoch [92/200], Loss: 0.0093
# Linear Probe Training - Epoch [93/200], Loss: 0.0091
# Linear Probe Training - Epoch [94/200], Loss: 0.0090
# Linear Probe Training - Epoch [95/200], Loss: 0.0090
# Linear Probe Training - Epoch [96/200], Loss: 0.0088
# Linear Probe Training - Epoch [97/200], Loss: 0.0087
# Linear Probe Training - Epoch [98/200], Loss: 0.0087
# Linear Probe Training - Epoch [99/200], Loss: 0.0086
# Linear Probe Training - Epoch [100/200], Loss: 0.0085
# Linear Probe Training - Epoch [101/200], Loss: 0.0084
# Linear Probe Training - Epoch [102/200], Loss: 0.0083
# Linear Probe Training - Epoch [103/200], Loss: 0.0083
# Linear Probe Training - Epoch [104/200], Loss: 0.0082
# Linear Probe Training - Epoch [105/200], Loss: 0.0081
# Linear Probe Training - Epoch [106/200], Loss: 0.0080
# Linear Probe Training - Epoch [107/200], Loss: 0.0080
# Linear Probe Training - Epoch [108/200], Loss: 0.0079
# Linear Probe Training - Epoch [109/200], Loss: 0.0078
# Linear Probe Training - Epoch [110/200], Loss: 0.0078
# Linear Probe Training - Epoch [111/200], Loss: 0.0077
# Linear Probe Training - Epoch [112/200], Loss: 0.0076
# Linear Probe Training - Epoch [113/200], Loss: 0.0076
# Linear Probe Training - Epoch [114/200], Loss: 0.0075
# Linear Probe Training - Epoch [115/200], Loss: 0.0075
# Linear Probe Training - Epoch [116/200], Loss: 0.0074
# Linear Probe Training - Epoch [117/200], Loss: 0.0074
# Linear Probe Training - Epoch [118/200], Loss: 0.0073
# Linear Probe Training - Epoch [119/200], Loss: 0.0073
# Linear Probe Training - Epoch [120/200], Loss: 0.0072
# Linear Probe Training - Epoch [121/200], Loss: 0.0072
# Linear Probe Training - Epoch [122/200], Loss: 0.0071
# Linear Probe Training - Epoch [123/200], Loss: 0.0071
# Linear Probe Training - Epoch [124/200], Loss: 0.0070
# Linear Probe Training - Epoch [125/200], Loss: 0.0070
# Linear Probe Training - Epoch [126/200], Loss: 0.0070
# Linear Probe Training - Epoch [127/200], Loss: 0.0069
# Linear Probe Training - Epoch [128/200], Loss: 0.0069
# Linear Probe Training - Epoch [129/200], Loss: 0.0068
# Linear Probe Training - Epoch [130/200], Loss: 0.0068
# Linear Probe Training - Epoch [131/200], Loss: 0.0068
# Linear Probe Training - Epoch [132/200], Loss: 0.0067
# Linear Probe Training - Epoch [133/200], Loss: 0.0067
# Linear Probe Training - Epoch [134/200], Loss: 0.0067
# Linear Probe Training - Epoch [135/200], Loss: 0.0066
# Linear Probe Training - Epoch [136/200], Loss: 0.0066
# Linear Probe Training - Epoch [137/200], Loss: 0.0066
# Linear Probe Training - Epoch [138/200], Loss: 0.0065
# Linear Probe Training - Epoch [139/200], Loss: 0.0065
# Linear Probe Training - Epoch [140/200], Loss: 0.0065
# Linear Probe Training - Epoch [141/200], Loss: 0.0064
# Linear Probe Training - Epoch [142/200], Loss: 0.0064
# Linear Probe Training - Epoch [143/200], Loss: 0.0064
# Linear Probe Training - Epoch [144/200], Loss: 0.0064
# Linear Probe Training - Epoch [145/200], Loss: 0.0064
# Linear Probe Training - Epoch [146/200], Loss: 0.0063
# Linear Probe Training - Epoch [147/200], Loss: 0.0063
# Linear Probe Training - Epoch [148/200], Loss: 0.0063
# Linear Probe Training - Epoch [149/200], Loss: 0.0063
# Linear Probe Training - Epoch [150/200], Loss: 0.0062
# Linear Probe Training - Epoch [151/200], Loss: 0.0062
# Linear Probe Training - Epoch [152/200], Loss: 0.0062
# Linear Probe Training - Epoch [153/200], Loss: 0.0062
# Linear Probe Training - Epoch [154/200], Loss: 0.0062
# Linear Probe Training - Epoch [155/200], Loss: 0.0061
# Linear Probe Training - Epoch [156/200], Loss: 0.0061
# Linear Probe Training - Epoch [157/200], Loss: 0.0061
# Linear Probe Training - Epoch [158/200], Loss: 0.0061
# Linear Probe Training - Epoch [159/200], Loss: 0.0061
# Linear Probe Training - Epoch [160/200], Loss: 0.0061
# Linear Probe Training - Epoch [161/200], Loss: 0.0060
# Linear Probe Training - Epoch [162/200], Loss: 0.0060
# Linear Probe Training - Epoch [163/200], Loss: 0.0060
# Linear Probe Training - Epoch [164/200], Loss: 0.0060
# Linear Probe Training - Epoch [165/200], Loss: 0.0060
# Linear Probe Training - Epoch [166/200], Loss: 0.0060
# Linear Probe Training - Epoch [167/200], Loss: 0.0059
# Linear Probe Training - Epoch [168/200], Loss: 0.0059
# Linear Probe Training - Epoch [169/200], Loss: 0.0059
# Linear Probe Training - Epoch [170/200], Loss: 0.0059
# Linear Probe Training - Epoch [171/200], Loss: 0.0059
# Linear Probe Training - Epoch [172/200], Loss: 0.0059
# Linear Probe Training - Epoch [173/200], Loss: 0.0059
# Linear Probe Training - Epoch [174/200], Loss: 0.0059
# Linear Probe Training - Epoch [175/200], Loss: 0.0058
# Linear Probe Training - Epoch [176/200], Loss: 0.0058
# Linear Probe Training - Epoch [177/200], Loss: 0.0058
# Linear Probe Training - Epoch [178/200], Loss: 0.0058
# Linear Probe Training - Epoch [179/200], Loss: 0.0058
# Linear Probe Training - Epoch [180/200], Loss: 0.0058
# Linear Probe Training - Epoch [181/200], Loss: 0.0058
# Linear Probe Training - Epoch [182/200], Loss: 0.0058
# Linear Probe Training - Epoch [183/200], Loss: 0.0058
# Linear Probe Training - Epoch [184/200], Loss: 0.0058
# Linear Probe Training - Epoch [185/200], Loss: 0.0058
# Linear Probe Training - Epoch [186/200], Loss: 0.0057
# Linear Probe Training - Epoch [187/200], Loss: 0.0057
# Linear Probe Training - Epoch [188/200], Loss: 0.0057
# Linear Probe Training - Epoch [189/200], Loss: 0.0057
# Linear Probe Training - Epoch [190/200], Loss: 0.0057
# Linear Probe Training - Epoch [191/200], Loss: 0.0057
# Linear Probe Training - Epoch [192/200], Loss: 0.0057
# Linear Probe Training - Epoch [193/200], Loss: 0.0057
# Linear Probe Training - Epoch [194/200], Loss: 0.0057
# Linear Probe Training - Epoch [195/200], Loss: 0.0057
# Linear Probe Training - Epoch [196/200], Loss: 0.0057
# Linear Probe Training - Epoch [197/200], Loss: 0.0057
# Linear Probe Training - Epoch [198/200], Loss: 0.0057
# Linear Probe Training - Epoch [199/200], Loss: 0.0057
# Linear Probe Training - Epoch [200/200], Loss: 0.0057
#
# === Building dataset/model for Beta 2 ===
# Beta Model Training - Epoch [1/200], Loss: 0.0710
# Beta Model Training - Epoch [2/200], Loss: 0.0538
# Beta Model Training - Epoch [3/200], Loss: 0.0408
# Beta Model Training - Epoch [4/200], Loss: 0.0343
# Beta Model Training - Epoch [5/200], Loss: 0.0300
# Beta Model Training - Epoch [6/200], Loss: 0.0270
# Beta Model Training - Epoch [7/200], Loss: 0.0252
# Beta Model Training - Epoch [8/200], Loss: 0.0232
# Beta Model Training - Epoch [9/200], Loss: 0.0214
# Beta Model Training - Epoch [10/200], Loss: 0.0196
# Beta Model Training - Epoch [11/200], Loss: 0.0184
# Beta Model Training - Epoch [12/200], Loss: 0.0179
# Beta Model Training - Epoch [13/200], Loss: 0.0165
# Beta Model Training - Epoch [14/200], Loss: 0.0155
# Beta Model Training - Epoch [15/200], Loss: 0.0146
# Beta Model Training - Epoch [16/200], Loss: 0.0140
# Beta Model Training - Epoch [17/200], Loss: 0.0133
# Beta Model Training - Epoch [18/200], Loss: 0.0131
# Beta Model Training - Epoch [19/200], Loss: 0.0123
# Beta Model Training - Epoch [20/200], Loss: 0.0119
# Beta Model Training - Epoch [21/200], Loss: 0.0114
# Beta Model Training - Epoch [22/200], Loss: 0.0110
# Beta Model Training - Epoch [23/200], Loss: 0.0106
# Beta Model Training - Epoch [24/200], Loss: 0.0103
# Beta Model Training - Epoch [25/200], Loss: 0.0100
# Beta Model Training - Epoch [26/200], Loss: 0.0098
# Beta Model Training - Epoch [27/200], Loss: 0.0096
# Beta Model Training - Epoch [28/200], Loss: 0.0094
# Beta Model Training - Epoch [29/200], Loss: 0.0093
# Beta Model Training - Epoch [30/200], Loss: 0.0090
# Beta Model Training - Epoch [31/200], Loss: 0.0087
# Beta Model Training - Epoch [32/200], Loss: 0.0086
# Beta Model Training - Epoch [33/200], Loss: 0.0086
# Beta Model Training - Epoch [34/200], Loss: 0.0085
# Beta Model Training - Epoch [35/200], Loss: 0.0083
# Beta Model Training - Epoch [36/200], Loss: 0.0081
# Beta Model Training - Epoch [37/200], Loss: 0.0081
# Beta Model Training - Epoch [38/200], Loss: 0.0080
# Beta Model Training - Epoch [39/200], Loss: 0.0079
# Beta Model Training - Epoch [40/200], Loss: 0.0077
# Beta Model Training - Epoch [41/200], Loss: 0.0075
# Beta Model Training - Epoch [42/200], Loss: 0.0074
# Beta Model Training - Epoch [43/200], Loss: 0.0073
# Beta Model Training - Epoch [44/200], Loss: 0.0073
# Beta Model Training - Epoch [45/200], Loss: 0.0073
# Beta Model Training - Epoch [46/200], Loss: 0.0072
# Beta Model Training - Epoch [47/200], Loss: 0.0071
# Beta Model Training - Epoch [48/200], Loss: 0.0072
# Beta Model Training - Epoch [49/200], Loss: 0.0071
# Beta Model Training - Epoch [50/200], Loss: 0.0069
# Beta Model Training - Epoch [51/200], Loss: 0.0068
# Beta Model Training - Epoch [52/200], Loss: 0.0069
# Beta Model Training - Epoch [53/200], Loss: 0.0072
# Beta Model Training - Epoch [54/200], Loss: 0.0075
# Beta Model Training - Epoch [55/200], Loss: 0.0074
# Beta Model Training - Epoch [56/200], Loss: 0.0071
# Beta Model Training - Epoch [57/200], Loss: 0.0069
# Beta Model Training - Epoch [58/200], Loss: 0.0067
# Beta Model Training - Epoch [59/200], Loss: 0.0068
# Beta Model Training - Epoch [60/200], Loss: 0.0068
# Beta Model Training - Epoch [61/200], Loss: 0.0066
# Beta Model Training - Epoch [62/200], Loss: 0.0064
# Beta Model Training - Epoch [63/200], Loss: 0.0062
# Beta Model Training - Epoch [64/200], Loss: 0.0060
# Beta Model Training - Epoch [65/200], Loss: 0.0060
# Beta Model Training - Epoch [66/200], Loss: 0.0059
# Beta Model Training - Epoch [67/200], Loss: 0.0058
# Beta Model Training - Epoch [68/200], Loss: 0.0058
# Beta Model Training - Epoch [69/200], Loss: 0.0058
# Beta Model Training - Epoch [70/200], Loss: 0.0057
# Beta Model Training - Epoch [71/200], Loss: 0.0057
# Beta Model Training - Epoch [72/200], Loss: 0.0057
# Beta Model Training - Epoch [73/200], Loss: 0.0056
# Beta Model Training - Epoch [74/200], Loss: 0.0057
# Beta Model Training - Epoch [75/200], Loss: 0.0059
# Beta Model Training - Epoch [76/200], Loss: 0.0059
# Beta Model Training - Epoch [77/200], Loss: 0.0058
# Beta Model Training - Epoch [78/200], Loss: 0.0056
# Beta Model Training - Epoch [79/200], Loss: 0.0055
# Beta Model Training - Epoch [80/200], Loss: 0.0055
# Beta Model Training - Epoch [81/200], Loss: 0.0054
# Beta Model Training - Epoch [82/200], Loss: 0.0053
# Beta Model Training - Epoch [83/200], Loss: 0.0053
# Beta Model Training - Epoch [84/200], Loss: 0.0053
# Beta Model Training - Epoch [85/200], Loss: 0.0053
# Beta Model Training - Epoch [86/200], Loss: 0.0052
# Beta Model Training - Epoch [87/200], Loss: 0.0052
# Beta Model Training - Epoch [88/200], Loss: 0.0052
# Beta Model Training - Epoch [89/200], Loss: 0.0054
# Beta Model Training - Epoch [90/200], Loss: 0.0053
# Beta Model Training - Epoch [91/200], Loss: 0.0053
# Beta Model Training - Epoch [92/200], Loss: 0.0052
# Beta Model Training - Epoch [93/200], Loss: 0.0052
# Beta Model Training - Epoch [94/200], Loss: 0.0052
# Beta Model Training - Epoch [95/200], Loss: 0.0051
# Beta Model Training - Epoch [96/200], Loss: 0.0051
# Beta Model Training - Epoch [97/200], Loss: 0.0051
# Beta Model Training - Epoch [98/200], Loss: 0.0049
# Beta Model Training - Epoch [99/200], Loss: 0.0049
# Beta Model Training - Epoch [100/200], Loss: 0.0048
# Beta Model Training - Epoch [101/200], Loss: 0.0048
# Beta Model Training - Epoch [102/200], Loss: 0.0048
# Beta Model Training - Epoch [103/200], Loss: 0.0048
# Beta Model Training - Epoch [104/200], Loss: 0.0048
# Beta Model Training - Epoch [105/200], Loss: 0.0048
# Beta Model Training - Epoch [106/200], Loss: 0.0048
# Beta Model Training - Epoch [107/200], Loss: 0.0048
# Beta Model Training - Epoch [108/200], Loss: 0.0048
# Beta Model Training - Epoch [109/200], Loss: 0.0050
# Beta Model Training - Epoch [110/200], Loss: 0.0049
# Beta Model Training - Epoch [111/200], Loss: 0.0051
# Beta Model Training - Epoch [112/200], Loss: 0.0051
# Beta Model Training - Epoch [113/200], Loss: 0.0051
# Beta Model Training - Epoch [114/200], Loss: 0.0048
# Beta Model Training - Epoch [115/200], Loss: 0.0049
# Beta Model Training - Epoch [116/200], Loss: 0.0047
# Beta Model Training - Epoch [117/200], Loss: 0.0047
# Beta Model Training - Epoch [118/200], Loss: 0.0047
# Beta Model Training - Epoch [119/200], Loss: 0.0047
# Beta Model Training - Epoch [120/200], Loss: 0.0046
# Beta Model Training - Epoch [121/200], Loss: 0.0046
# Beta Model Training - Epoch [122/200], Loss: 0.0045
# Beta Model Training - Epoch [123/200], Loss: 0.0044
# Beta Model Training - Epoch [124/200], Loss: 0.0044
# Beta Model Training - Epoch [125/200], Loss: 0.0043
# Beta Model Training - Epoch [126/200], Loss: 0.0044
# Beta Model Training - Epoch [127/200], Loss: 0.0044
# Beta Model Training - Epoch [128/200], Loss: 0.0044
# Beta Model Training - Epoch [129/200], Loss: 0.0043
# Beta Model Training - Epoch [130/200], Loss: 0.0043
# Beta Model Training - Epoch [131/200], Loss: 0.0043
# Beta Model Training - Epoch [132/200], Loss: 0.0042
# Beta Model Training - Epoch [133/200], Loss: 0.0042
# Beta Model Training - Epoch [134/200], Loss: 0.0042
# Beta Model Training - Epoch [135/200], Loss: 0.0042
# Beta Model Training - Epoch [136/200], Loss: 0.0043
# Beta Model Training - Epoch [137/200], Loss: 0.0044
# Beta Model Training - Epoch [138/200], Loss: 0.0044
# Beta Model Training - Epoch [139/200], Loss: 0.0045
# Beta Model Training - Epoch [140/200], Loss: 0.0044
# Beta Model Training - Epoch [141/200], Loss: 0.0045
# Beta Model Training - Epoch [142/200], Loss: 0.0047
# Beta Model Training - Epoch [143/200], Loss: 0.0044
# Beta Model Training - Epoch [144/200], Loss: 0.0043
# Beta Model Training - Epoch [145/200], Loss: 0.0043
# Beta Model Training - Epoch [146/200], Loss: 0.0041
# Beta Model Training - Epoch [147/200], Loss: 0.0041
# Beta Model Training - Epoch [148/200], Loss: 0.0041
# Beta Model Training - Epoch [149/200], Loss: 0.0041
# Beta Model Training - Epoch [150/200], Loss: 0.0041
# Beta Model Training - Epoch [151/200], Loss: 0.0040
# Beta Model Training - Epoch [152/200], Loss: 0.0040
# Beta Model Training - Epoch [153/200], Loss: 0.0040
# Beta Model Training - Epoch [154/200], Loss: 0.0040
# Beta Model Training - Epoch [155/200], Loss: 0.0040
# Beta Model Training - Epoch [156/200], Loss: 0.0040
# Beta Model Training - Epoch [157/200], Loss: 0.0040
# Beta Model Training - Epoch [158/200], Loss: 0.0040
# Beta Model Training - Epoch [159/200], Loss: 0.0040
# Beta Model Training - Epoch [160/200], Loss: 0.0040
# Beta Model Training - Epoch [161/200], Loss: 0.0040
# Beta Model Training - Epoch [162/200], Loss: 0.0040
# Beta Model Training - Epoch [163/200], Loss: 0.0039
# Beta Model Training - Epoch [164/200], Loss: 0.0039
# Beta Model Training - Epoch [165/200], Loss: 0.0039
# Beta Model Training - Epoch [166/200], Loss: 0.0039
# Beta Model Training - Epoch [167/200], Loss: 0.0038
# Beta Model Training - Epoch [168/200], Loss: 0.0039
# Beta Model Training - Epoch [169/200], Loss: 0.0038
# Beta Model Training - Epoch [170/200], Loss: 0.0038
# Beta Model Training - Epoch [171/200], Loss: 0.0038
# Beta Model Training - Epoch [172/200], Loss: 0.0038
# Beta Model Training - Epoch [173/200], Loss: 0.0039
# Beta Model Training - Epoch [174/200], Loss: 0.0039
# Beta Model Training - Epoch [175/200], Loss: 0.0039
# Beta Model Training - Epoch [176/200], Loss: 0.0039
# Beta Model Training - Epoch [177/200], Loss: 0.0038
# Beta Model Training - Epoch [178/200], Loss: 0.0038
# Beta Model Training - Epoch [179/200], Loss: 0.0038
# Beta Model Training - Epoch [180/200], Loss: 0.0038
# Beta Model Training - Epoch [181/200], Loss: 0.0038
# Beta Model Training - Epoch [182/200], Loss: 0.0038
# Beta Model Training - Epoch [183/200], Loss: 0.0038
# Beta Model Training - Epoch [184/200], Loss: 0.0038
# Beta Model Training - Epoch [185/200], Loss: 0.0039
# Beta Model Training - Epoch [186/200], Loss: 0.0040
# Beta Model Training - Epoch [187/200], Loss: 0.0039
# Beta Model Training - Epoch [188/200], Loss: 0.0038
# Beta Model Training - Epoch [189/200], Loss: 0.0038
# Beta Model Training - Epoch [190/200], Loss: 0.0038
# Beta Model Training - Epoch [191/200], Loss: 0.0038
# Beta Model Training - Epoch [192/200], Loss: 0.0039
# Beta Model Training - Epoch [193/200], Loss: 0.0038
# Beta Model Training - Epoch [194/200], Loss: 0.0039
# Beta Model Training - Epoch [195/200], Loss: 0.0039
# Beta Model Training - Epoch [196/200], Loss: 0.0038
# Beta Model Training - Epoch [197/200], Loss: 0.0038
# Beta Model Training - Epoch [198/200], Loss: 0.0038
# Beta Model Training - Epoch [199/200], Loss: 0.0038
# Beta Model Training - Epoch [200/200], Loss: 0.0038
# Linear Probe Training - Epoch [1/200], Loss: 0.3165
# Linear Probe Training - Epoch [2/200], Loss: 0.2080
# Linear Probe Training - Epoch [3/200], Loss: 0.1515
# Linear Probe Training - Epoch [4/200], Loss: 0.1211
# Linear Probe Training - Epoch [5/200], Loss: 0.1038
# Linear Probe Training - Epoch [6/200], Loss: 0.0924
# Linear Probe Training - Epoch [7/200], Loss: 0.0848
# Linear Probe Training - Epoch [8/200], Loss: 0.0790
# Linear Probe Training - Epoch [9/200], Loss: 0.0734
# Linear Probe Training - Epoch [10/200], Loss: 0.0685
# Linear Probe Training - Epoch [11/200], Loss: 0.0643
# Linear Probe Training - Epoch [12/200], Loss: 0.0603
# Linear Probe Training - Epoch [13/200], Loss: 0.0568
# Linear Probe Training - Epoch [14/200], Loss: 0.0535
# Linear Probe Training - Epoch [15/200], Loss: 0.0505
# Linear Probe Training - Epoch [16/200], Loss: 0.0478
# Linear Probe Training - Epoch [17/200], Loss: 0.0455
# Linear Probe Training - Epoch [18/200], Loss: 0.0432
# Linear Probe Training - Epoch [19/200], Loss: 0.0411
# Linear Probe Training - Epoch [20/200], Loss: 0.0392
# Linear Probe Training - Epoch [21/200], Loss: 0.0374
# Linear Probe Training - Epoch [22/200], Loss: 0.0359
# Linear Probe Training - Epoch [23/200], Loss: 0.0343
# Linear Probe Training - Epoch [24/200], Loss: 0.0329
# Linear Probe Training - Epoch [25/200], Loss: 0.0318
# Linear Probe Training - Epoch [26/200], Loss: 0.0305
# Linear Probe Training - Epoch [27/200], Loss: 0.0294
# Linear Probe Training - Epoch [28/200], Loss: 0.0283
# Linear Probe Training - Epoch [29/200], Loss: 0.0273
# Linear Probe Training - Epoch [30/200], Loss: 0.0264
# Linear Probe Training - Epoch [31/200], Loss: 0.0255
# Linear Probe Training - Epoch [32/200], Loss: 0.0247
# Linear Probe Training - Epoch [33/200], Loss: 0.0239
# Linear Probe Training - Epoch [34/200], Loss: 0.0231
# Linear Probe Training - Epoch [35/200], Loss: 0.0224
# Linear Probe Training - Epoch [36/200], Loss: 0.0218
# Linear Probe Training - Epoch [37/200], Loss: 0.0211
# Linear Probe Training - Epoch [38/200], Loss: 0.0205
# Linear Probe Training - Epoch [39/200], Loss: 0.0199
# Linear Probe Training - Epoch [40/200], Loss: 0.0193
# Linear Probe Training - Epoch [41/200], Loss: 0.0188
# Linear Probe Training - Epoch [42/200], Loss: 0.0183
# Linear Probe Training - Epoch [43/200], Loss: 0.0178
# Linear Probe Training - Epoch [44/200], Loss: 0.0174
# Linear Probe Training - Epoch [45/200], Loss: 0.0169
# Linear Probe Training - Epoch [46/200], Loss: 0.0165
# Linear Probe Training - Epoch [47/200], Loss: 0.0161
# Linear Probe Training - Epoch [48/200], Loss: 0.0157
# Linear Probe Training - Epoch [49/200], Loss: 0.0153
# Linear Probe Training - Epoch [50/200], Loss: 0.0150
# Linear Probe Training - Epoch [51/200], Loss: 0.0146
# Linear Probe Training - Epoch [52/200], Loss: 0.0143
# Linear Probe Training - Epoch [53/200], Loss: 0.0140
# Linear Probe Training - Epoch [54/200], Loss: 0.0136
# Linear Probe Training - Epoch [55/200], Loss: 0.0134
# Linear Probe Training - Epoch [56/200], Loss: 0.0131
# Linear Probe Training - Epoch [57/200], Loss: 0.0128
# Linear Probe Training - Epoch [58/200], Loss: 0.0125
# Linear Probe Training - Epoch [59/200], Loss: 0.0123
# Linear Probe Training - Epoch [60/200], Loss: 0.0120
# Linear Probe Training - Epoch [61/200], Loss: 0.0118
# Linear Probe Training - Epoch [62/200], Loss: 0.0115
# Linear Probe Training - Epoch [63/200], Loss: 0.0113
# Linear Probe Training - Epoch [64/200], Loss: 0.0111
# Linear Probe Training - Epoch [65/200], Loss: 0.0109
# Linear Probe Training - Epoch [66/200], Loss: 0.0107
# Linear Probe Training - Epoch [67/200], Loss: 0.0105
# Linear Probe Training - Epoch [68/200], Loss: 0.0103
# Linear Probe Training - Epoch [69/200], Loss: 0.0101
# Linear Probe Training - Epoch [70/200], Loss: 0.0099
# Linear Probe Training - Epoch [71/200], Loss: 0.0098
# Linear Probe Training - Epoch [72/200], Loss: 0.0096
# Linear Probe Training - Epoch [73/200], Loss: 0.0094
# Linear Probe Training - Epoch [74/200], Loss: 0.0093
# Linear Probe Training - Epoch [75/200], Loss: 0.0091
# Linear Probe Training - Epoch [76/200], Loss: 0.0090
# Linear Probe Training - Epoch [77/200], Loss: 0.0089
# Linear Probe Training - Epoch [78/200], Loss: 0.0087
# Linear Probe Training - Epoch [79/200], Loss: 0.0086
# Linear Probe Training - Epoch [80/200], Loss: 0.0085
# Linear Probe Training - Epoch [81/200], Loss: 0.0083
# Linear Probe Training - Epoch [82/200], Loss: 0.0082
# Linear Probe Training - Epoch [83/200], Loss: 0.0081
# Linear Probe Training - Epoch [84/200], Loss: 0.0080
# Linear Probe Training - Epoch [85/200], Loss: 0.0079
# Linear Probe Training - Epoch [86/200], Loss: 0.0078
# Linear Probe Training - Epoch [87/200], Loss: 0.0077
# Linear Probe Training - Epoch [88/200], Loss: 0.0076
# Linear Probe Training - Epoch [89/200], Loss: 0.0075
# Linear Probe Training - Epoch [90/200], Loss: 0.0074
# Linear Probe Training - Epoch [91/200], Loss: 0.0073
# Linear Probe Training - Epoch [92/200], Loss: 0.0072
# Linear Probe Training - Epoch [93/200], Loss: 0.0071
# Linear Probe Training - Epoch [94/200], Loss: 0.0070
# Linear Probe Training - Epoch [95/200], Loss: 0.0069
# Linear Probe Training - Epoch [96/200], Loss: 0.0069
# Linear Probe Training - Epoch [97/200], Loss: 0.0068
# Linear Probe Training - Epoch [98/200], Loss: 0.0067
# Linear Probe Training - Epoch [99/200], Loss: 0.0066
# Linear Probe Training - Epoch [100/200], Loss: 0.0066
# Linear Probe Training - Epoch [101/200], Loss: 0.0065
# Linear Probe Training - Epoch [102/200], Loss: 0.0064
# Linear Probe Training - Epoch [103/200], Loss: 0.0064
# Linear Probe Training - Epoch [104/200], Loss: 0.0063
# Linear Probe Training - Epoch [105/200], Loss: 0.0062
# Linear Probe Training - Epoch [106/200], Loss: 0.0062
# Linear Probe Training - Epoch [107/200], Loss: 0.0061
# Linear Probe Training - Epoch [108/200], Loss: 0.0061
# Linear Probe Training - Epoch [109/200], Loss: 0.0060
# Linear Probe Training - Epoch [110/200], Loss: 0.0060
# Linear Probe Training - Epoch [111/200], Loss: 0.0059
# Linear Probe Training - Epoch [112/200], Loss: 0.0059
# Linear Probe Training - Epoch [113/200], Loss: 0.0058
# Linear Probe Training - Epoch [114/200], Loss: 0.0058
# Linear Probe Training - Epoch [115/200], Loss: 0.0057
# Linear Probe Training - Epoch [116/200], Loss: 0.0057
# Linear Probe Training - Epoch [117/200], Loss: 0.0056
# Linear Probe Training - Epoch [118/200], Loss: 0.0056
# Linear Probe Training - Epoch [119/200], Loss: 0.0055
# Linear Probe Training - Epoch [120/200], Loss: 0.0055
# Linear Probe Training - Epoch [121/200], Loss: 0.0055
# Linear Probe Training - Epoch [122/200], Loss: 0.0054
# Linear Probe Training - Epoch [123/200], Loss: 0.0054
# Linear Probe Training - Epoch [124/200], Loss: 0.0053
# Linear Probe Training - Epoch [125/200], Loss: 0.0053
# Linear Probe Training - Epoch [126/200], Loss: 0.0053
# Linear Probe Training - Epoch [127/200], Loss: 0.0052
# Linear Probe Training - Epoch [128/200], Loss: 0.0052
# Linear Probe Training - Epoch [129/200], Loss: 0.0052
# Linear Probe Training - Epoch [130/200], Loss: 0.0051
# Linear Probe Training - Epoch [131/200], Loss: 0.0051
# Linear Probe Training - Epoch [132/200], Loss: 0.0051
# Linear Probe Training - Epoch [133/200], Loss: 0.0051
# Linear Probe Training - Epoch [134/200], Loss: 0.0050
# Linear Probe Training - Epoch [135/200], Loss: 0.0050
# Linear Probe Training - Epoch [136/200], Loss: 0.0050
# Linear Probe Training - Epoch [137/200], Loss: 0.0050
# Linear Probe Training - Epoch [138/200], Loss: 0.0049
# Linear Probe Training - Epoch [139/200], Loss: 0.0049
# Linear Probe Training - Epoch [140/200], Loss: 0.0049
# Linear Probe Training - Epoch [141/200], Loss: 0.0048
# Linear Probe Training - Epoch [142/200], Loss: 0.0048
# Linear Probe Training - Epoch [143/200], Loss: 0.0048
# Linear Probe Training - Epoch [144/200], Loss: 0.0048
# Linear Probe Training - Epoch [145/200], Loss: 0.0048
# Linear Probe Training - Epoch [146/200], Loss: 0.0047
# Linear Probe Training - Epoch [147/200], Loss: 0.0047
# Linear Probe Training - Epoch [148/200], Loss: 0.0047
# Linear Probe Training - Epoch [149/200], Loss: 0.0047
# Linear Probe Training - Epoch [150/200], Loss: 0.0047
# Linear Probe Training - Epoch [151/200], Loss: 0.0046
# Linear Probe Training - Epoch [152/200], Loss: 0.0046
# Linear Probe Training - Epoch [153/200], Loss: 0.0046
# Linear Probe Training - Epoch [154/200], Loss: 0.0046
# Linear Probe Training - Epoch [155/200], Loss: 0.0046
# Linear Probe Training - Epoch [156/200], Loss: 0.0046
# Linear Probe Training - Epoch [157/200], Loss: 0.0045
# Linear Probe Training - Epoch [158/200], Loss: 0.0045
# Linear Probe Training - Epoch [159/200], Loss: 0.0045
# Linear Probe Training - Epoch [160/200], Loss: 0.0045
# Linear Probe Training - Epoch [161/200], Loss: 0.0045
# Linear Probe Training - Epoch [162/200], Loss: 0.0045
# Linear Probe Training - Epoch [163/200], Loss: 0.0045
# Linear Probe Training - Epoch [164/200], Loss: 0.0044
# Linear Probe Training - Epoch [165/200], Loss: 0.0044
# Linear Probe Training - Epoch [166/200], Loss: 0.0044
# Linear Probe Training - Epoch [167/200], Loss: 0.0044
# Linear Probe Training - Epoch [168/200], Loss: 0.0044
# Linear Probe Training - Epoch [169/200], Loss: 0.0044
# Linear Probe Training - Epoch [170/200], Loss: 0.0044
# Linear Probe Training - Epoch [171/200], Loss: 0.0044
# Linear Probe Training - Epoch [172/200], Loss: 0.0043
# Linear Probe Training - Epoch [173/200], Loss: 0.0043
# Linear Probe Training - Epoch [174/200], Loss: 0.0043
# Linear Probe Training - Epoch [175/200], Loss: 0.0043
# Linear Probe Training - Epoch [176/200], Loss: 0.0043
# Linear Probe Training - Epoch [177/200], Loss: 0.0043
# Linear Probe Training - Epoch [178/200], Loss: 0.0043
# Linear Probe Training - Epoch [179/200], Loss: 0.0043
# Linear Probe Training - Epoch [180/200], Loss: 0.0043
# Linear Probe Training - Epoch [181/200], Loss: 0.0043
# Linear Probe Training - Epoch [182/200], Loss: 0.0042
# Linear Probe Training - Epoch [183/200], Loss: 0.0042
# Linear Probe Training - Epoch [184/200], Loss: 0.0042
# Linear Probe Training - Epoch [185/200], Loss: 0.0042
# Linear Probe Training - Epoch [186/200], Loss: 0.0042
# Linear Probe Training - Epoch [187/200], Loss: 0.0042
# Linear Probe Training - Epoch [188/200], Loss: 0.0042
# Linear Probe Training - Epoch [189/200], Loss: 0.0042
# Linear Probe Training - Epoch [190/200], Loss: 0.0042
# Linear Probe Training - Epoch [191/200], Loss: 0.0042
# Linear Probe Training - Epoch [192/200], Loss: 0.0042
# Linear Probe Training - Epoch [193/200], Loss: 0.0042
# Linear Probe Training - Epoch [194/200], Loss: 0.0042
# Linear Probe Training - Epoch [195/200], Loss: 0.0041
# Linear Probe Training - Epoch [196/200], Loss: 0.0041
# Linear Probe Training - Epoch [197/200], Loss: 0.0041
# Linear Probe Training - Epoch [198/200], Loss: 0.0041
# Linear Probe Training - Epoch [199/200], Loss: 0.0041
# Linear Probe Training - Epoch [200/200], Loss: 0.0041

# %%
save_dir = os.path.join(curr_dir,analysis_type, 'Linear Probing')
print(f"Saving results to {save_dir}...")
os.makedirs(save_dir, exist_ok=True)

savemat(os.path.join(save_dir, 'ori_error_all.mat'), {'ori_error_all': ori_error_all})
savemat(os.path.join(save_dir, 'linPro_error_all.mat'), {'linPro_error_all': linPro_error_all})
# Out:
# Saving results to e:\MThesis\GAEtesting\MMN\Linear Probing...

# %%
save_dir = os.path.join(curr_dir,analysis_type, 'Linear Probing')
ori_error_all = loadmat(os.path.join(save_dir, 'ori_error_all.mat'))['ori_error_all']
linPro_error_all = loadmat(os.path.join(save_dir, 'linPro_error_all.mat'))['linPro_error_all']
print("shapes:", ori_error_all.shape)
# Out:
# shapes: (3, 40, 30, 201)

# %%
global_max = 0.15
global_min = 0.05

# Print MAE of original GAE and Linear Probing and plot reconstruction result comparison of origainal GAE and Linear Probing
for iBeta in range(nBeta):
    err_o = ori_error_all[iBeta]  # [nSubject, nChan, nTime]
    err_l = linPro_error_all[iBeta]
    mean_err_o = np.mean(np.abs(err_o))
    mean_err_l = np.mean(np.abs(err_l))
    print(f"Beta {iBeta+1} Mean Absolute Error:")
    print(f"Original GAE: {mean_err_o:.4f}")
    print(f"Linear Probing: {mean_err_l:.4f}")
    
    time_mae_o = np.abs(err_o).mean(axis=(0, 1))
    time_mae_l = np.abs(err_l).mean(axis=(0, 1))
    
    plt.figure(figsize=(16,13))
    plt.plot(time_mae_o, label='Original GAE', linewidth=2)
    plt.plot(time_mae_l, label='Linear Probing', linewidth=2)
    plt.xlabel('Time')
    plt.ylabel('MAE')
    plt.yticks(np.arange(global_min, global_max, step=0.01))
    plt.ylim(global_min, global_max)
    plt.title(f'{analysis_type} Beta {iBeta+1} MAE over Time')
    plt.legend(fontsize=40, loc='upper left')
    plt.tight_layout()
    plt.savefig(os.path.join(save_dir, f'{analysis_type}_Beta_{iBeta+1}.png'))
    plt.close()
    
    print(f"Saved plot for Beta {iBeta+1}.\n")
# Out:
# Beta 1 Mean Absolute Error:
# Original GAE: 0.1006
# Linear Probing: 0.1059
# Saved plot for Beta 1.
#
# Beta 2 Mean Absolute Error:
# Original GAE: 0.0760
# Linear Probing: 0.0788
# Saved plot for Beta 2.
#
# Beta 3 Mean Absolute Error:
# Original GAE: 0.0662
# Linear Probing: 0.0674
# Saved plot for Beta 3.
