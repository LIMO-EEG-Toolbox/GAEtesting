# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset, ConcatDataset
from torch_geometric.loader import DataLoader as GeometricDataLoader
from torch_geometric.data import Data
from torch_geometric.utils import dense_to_sparse
import torch_geometric.nn as pyg_nn
import os
import matplotlib.pyplot as plt

from scipy.io import loadmat, savemat

# %%
# Test - load saved beta data from mat file
analysis_type = 'N170'
datain_mat = loadmat(analysis_type + '_data.mat')
binatry_matrix_mat = loadmat('adjacency_matrix.mat')
datain = datain_mat['data']
binatry_matrix = binatry_matrix_mat['adjacency_matrix']

datain = np.array(datain)          # shape: [nBeta, nTime, nChan, nSubject] (adjust as needed)
binatry_matrix = np.array(binatry_matrix)

# Parse shapes
nBeta     = datain.shape[0]
nTime     = datain.shape[1]
nChan     = datain.shape[2]
nSubject  = datain.shape[3]

# %%
# ===========================================
# 2) Set device & convert adjacency
# ===========================================
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
edge_index, _ = dense_to_sparse(torch.tensor(binatry_matrix, dtype=torch.float32))
print(device)

# ===========================================
# 3) Dataset builder
# ===========================================
def build_concat_dataset_for_beta(datain, beta_idx):
    """
    Build a ConcatDataset across all subjects for one beta index.
    `datain` is [nBeta, nTime, nChan, nSubject].
    Returns: ConcatDataset of length nSubject.
    """
    subject_datasets = []
    for s in range(nSubject):
        # Extract slice for one subject and one beta
        # shape: [nTime, nChan]
        single_beta_data = datain[beta_idx, :, :, s]

        # If each node is a channel and its feature dimension is time,
        # we might want single_beta_data to be [nChan, nTime].
        # If so, transpose here:
        single_beta_data = single_beta_data.T  # shape: [nChan, nTime]

        # For an autoencoder, features=labels
        x_tensor = torch.tensor(single_beta_data, dtype=torch.float32)
        x_tensor = x_tensor.unsqueeze(0)

        subject_datasets.append(TensorDataset(x_tensor, x_tensor))

    return ConcatDataset(subject_datasets)
# Out:
# cuda

# %%
# ===========================================
# 4) PyG Graph Dataset
# ===========================================
class EEGGraphDataset(torch.utils.data.Dataset):
    """
    Wraps a standard dataset so that each item is a PyG Data object:
      x -> node features (channels)
      edge_index -> adjacency
    """
    def __init__(self, eeg_data, edge_index):
        self.eeg_data = eeg_data
        self.edge_index = edge_index

    def __len__(self):
        return len(self.eeg_data)

    def __getitem__(self, idx):
        # item: (x, x) because it's autoencoder
        sample = self.eeg_data[idx]
        x = sample[0]  # shape: [nChan, nTime] (if you used transpose above)
        # Convert x -> float32, build PyG Data
        graph_data = Data(x=torch.tensor(x, dtype=torch.float32),
                          edge_index=self.edge_index)
        return graph_data

# %%
# ===========================================
# 5) Define GraphAutoencoder
# ===========================================
class GraphAutoencoder(nn.Module):
    def __init__(self, num_features, embedding_dim=64):
        """
        num_features = dimension of each node's feature vector.
                       If each channel is a node, and you pass
                       [nChan, nTime], then num_features = nTime.
        """
        super(GraphAutoencoder, self).__init__()
        # Example with two ARMAConv layers
        self.encoder_gcn1 = pyg_nn.ARMAConv(num_features, 128, 
                                            num_stacks=2, 
                                            num_layers=3,
                                            shared_weights=True)
        self.encoder_gcn2 = pyg_nn.ARMAConv(128, embedding_dim, 
                                            num_stacks=2, 
                                            num_layers=3,
                                            shared_weights=True)
        self.decoder_fc1 = nn.Linear(embedding_dim, 128)
        self.decoder_fc2 = nn.Linear(128, num_features)

    # def forward(self, x, edge_index):
    #     x = torch.relu(self.encoder_gcn1(x, edge_index))
    #     latent = torch.relu(self.encoder_gcn2(x, edge_index))
    #     x = torch.relu(self.decoder_fc1(latent))
    #     reconstructed = self.decoder_fc2(x)
    #     return reconstructed
    
    def encode(self, x, edge_index):
        x = torch.relu(self.encoder_gcn1(x, edge_index))
        latent = torch.relu(self.encoder_gcn2(x, edge_index))
        return latent
    
    def decode(self, latent):
        x = torch.relu(self.decoder_fc1(latent))
        reconstructed = self.decoder_fc2(x)
        return reconstructed
    
    def forward(self, x, edge_index):
        latent = self.encode(x, edge_index)
        reconstructed = self.decode(latent)
        return reconstructed, latent

# %%
# ===========================================
# 6) Training and evaluation
# ===========================================
def train_model_all(model, train_loader, device, num_epochs):
    model.to(device)
    optimizer = optim.Adam(model.parameters(), lr=1e-3)
    criterion = nn.SmoothL1Loss()

    for epoch in range(num_epochs):
        model.train()
        epoch_loss = 0.0
        for batch_data in train_loader:
            batch_data = batch_data.to(device)
            optimizer.zero_grad()

            # Forward
            reconstructed, _ = model(batch_data.x, batch_data.edge_index)
            loss = criterion(reconstructed, batch_data.x)

            # Backprop
            loss.backward()
            optimizer.step()
            epoch_loss += loss.item()

        epoch_loss /= len(train_loader)
        print(f"Beta Model Training - Epoch [{epoch+1}/{num_epochs}], Loss: {epoch_loss:.4f}")
    return model

def evaluation_model(model, data_sample, edge_index, device):
    """
    data_sample: shape [nChan, nTime], or [nTime, nChan],
                 whichever you used in training.
    Returns: (original_np, reconstructed_np, error_np)
    """
    model.eval()
    with torch.no_grad():
        x = torch.tensor(data_sample, dtype=torch.float32, device=device)
        eidx = edge_index.to(device)
        reconstructed, _ = model(x, eidx)
    orig = x.cpu().numpy()
    recon = reconstructed.cpu().numpy()
    error = orig - recon
    return orig, recon, error

# %%
# LinearProbing part
class LinearProbe(nn.Module):
    def __init__(self, embedding_dim, num_features):
        super().__init__()
        self.probe = nn.Linear(embedding_dim, num_features, bias=True)

    def forward(self, x):
        return self.probe(x)

def train_linear_probe(model, train_loader, device, embedding_dim, num_features, num_epochs):
    model.eval()
    for param in model.parameters():
        param.requires_grad = False
        
    linear_probe = LinearProbe(embedding_dim, num_features).to(device)
    optimizer = optim.Adam(linear_probe.parameters(), lr=1e-3)
    criterion = nn.SmoothL1Loss()
    
    for epoch in range(num_epochs):
        linear_probe.train()
        epoch_loss = 0.0
        for batch_data in train_loader:
            batch_data = batch_data.to(device)
            optimizer.zero_grad()
            
            with torch.no_grad():
                latent = model.encode(batch_data.x, batch_data.edge_index)
            
            lin_reconstructed = linear_probe(latent)
            loss = criterion(lin_reconstructed, batch_data.x)

            loss.backward()
            optimizer.step()
            epoch_loss += loss.item()

        epoch_loss /= len(train_loader)
        print(f"Linear Probe Training - Epoch [{epoch+1}/{num_epochs}], Loss: {epoch_loss:.4f}")

    return linear_probe

def evaluation_linear_probe(model, linear_probe, data_sample, edge_index, device):
    model.eval()
    linear_probe.eval()
    with torch.no_grad():
        x = torch.tensor(data_sample, dtype=torch.float32, device=device)
        eidx = edge_index.to(device)
        latent = model.encode(x, eidx)
        lin_reconstructed = linear_probe(latent)
    orig = x.cpu().numpy()
    recon = lin_reconstructed.cpu().numpy()
    error = orig - recon
    return orig, recon, error

# %%
# ===========================================
# 7) Main pipeline
#    1) For each beta, build dataset/loader.
#    2) Initialize & train a separate model.
#    3) Reconstruct each subject's data for that beta.
#    4) Store reconstruction in a final array.
# ===========================================

num_features = nTime   # if each channel is a node, and feature vector = [nTime]
num_epochs   = 200     # number of training - set as needed
batch_size   = 4;      # dataset/batch to update hyperparameters

models = []
ori_reconstructed_list = []  # will hold arrays of shape [nSubject, nChan, nTime] for each beta
linPro_reconstructed_list = []
ori_error_list = []
linPro_error_list = []

for iBeta in range(nBeta):
    print(f"\n=== Building dataset/model for Beta {iBeta} ===")
    # Build dataset & loader
    full_dataset_i  = build_concat_dataset_for_beta(datain, iBeta)
    graph_dataset_i = EEGGraphDataset(full_dataset_i, edge_index)
    full_loader_i   = GeometricDataLoader(graph_dataset_i, batch_size=batch_size, shuffle=True)

    # Init model & train
    model_i = GraphAutoencoder(num_features=num_features, embedding_dim=32)
    model_i = train_model_all(model_i, full_loader_i, device, num_epochs=num_epochs)
    models.append(model_i)

    linPro_model = train_linear_probe(model_i, full_loader_i, device, embedding_dim=32, num_features=num_features, num_epochs=num_epochs)

    # Error evaluation original GAE vs Linear Probing for all subjects
    ori_error_per_subject = []
    linPro_error_per_subject = []
    
    ori_recon_per_subject = []
    linPro_recon_per_subject = []
    
    for s in range(len(full_dataset_i)):
        data_s = full_dataset_i[s][0].numpy()  # [nChan, nTime]
        _, recon_o, error_o = evaluation_model(model_i, data_s, edge_index, device)
        _, recon_l, error_l = evaluation_linear_probe(model_i, linPro_model, data_s, edge_index, device)
        
        ori_error_per_subject.append(error_o)
        linPro_error_per_subject.append(error_l)
        
        ori_recon_per_subject.append(recon_o)  # shape [nChan, nTime]
        linPro_recon_per_subject.append(recon_l)
        

    ori_error_list.append(np.array(ori_error_per_subject))
    linPro_error_list.append(np.array(linPro_error_per_subject))

    ori_reconstructed_list.append(np.array(ori_recon_per_subject))
    linPro_reconstructed_list.append(np.array(linPro_recon_per_subject))

ori_reconstructed_all = np.array(ori_reconstructed_list)  # [nBeta, nSubject, nChan, nTime]
linPro_reconstructed_all = np.array(linPro_reconstructed_list)
ori_error_all = np.array(ori_error_list)  # [nBeta, nSubject, nChan, nTime]
linPro_error_all = np.array(linPro_error_list)
# Out:
# === Building dataset/model for Beta 0 ===
# C:\Users\86136\AppData\Local\Temp\ipykernel_15156\1382389434.py:22: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   graph_data = Data(x=torch.tensor(x, dtype=torch.float32),
# Beta Model Training - Epoch [1/200], Loss: 0.7425
# Beta Model Training - Epoch [2/200], Loss: 0.5269
# Beta Model Training - Epoch [3/200], Loss: 0.4187
# Beta Model Training - Epoch [4/200], Loss: 0.3685
# Beta Model Training - Epoch [5/200], Loss: 0.3375
# Beta Model Training - Epoch [6/200], Loss: 0.3174
# Beta Model Training - Epoch [7/200], Loss: 0.3022
# Beta Model Training - Epoch [8/200], Loss: 0.2866
# Beta Model Training - Epoch [9/200], Loss: 0.2655
# Beta Model Training - Epoch [10/200], Loss: 0.2491
# Beta Model Training - Epoch [11/200], Loss: 0.2335
# Beta Model Training - Epoch [12/200], Loss: 0.2221
# Beta Model Training - Epoch [13/200], Loss: 0.2136
# Beta Model Training - Epoch [14/200], Loss: 0.2012
# Beta Model Training - Epoch [15/200], Loss: 0.1938
# Beta Model Training - Epoch [16/200], Loss: 0.1889
# Beta Model Training - Epoch [17/200], Loss: 0.1763
# Beta Model Training - Epoch [18/200], Loss: 0.1711
# Beta Model Training - Epoch [19/200], Loss: 0.1614
# Beta Model Training - Epoch [20/200], Loss: 0.1561
# Beta Model Training - Epoch [21/200], Loss: 0.1532
# Beta Model Training - Epoch [22/200], Loss: 0.1573
# Beta Model Training - Epoch [23/200], Loss: 0.1530
# Beta Model Training - Epoch [24/200], Loss: 0.1483
# Beta Model Training - Epoch [25/200], Loss: 0.1396
# Beta Model Training - Epoch [26/200], Loss: 0.1321
# Beta Model Training - Epoch [27/200], Loss: 0.1295
# Beta Model Training - Epoch [28/200], Loss: 0.1279
# Beta Model Training - Epoch [29/200], Loss: 0.1258
# Beta Model Training - Epoch [30/200], Loss: 0.1246
# Beta Model Training - Epoch [31/200], Loss: 0.1165
# Beta Model Training - Epoch [32/200], Loss: 0.1182
# Beta Model Training - Epoch [33/200], Loss: 0.1188
# Beta Model Training - Epoch [34/200], Loss: 0.1135
# Beta Model Training - Epoch [35/200], Loss: 0.1099
# Beta Model Training - Epoch [36/200], Loss: 0.1081
# Beta Model Training - Epoch [37/200], Loss: 0.1053
# Beta Model Training - Epoch [38/200], Loss: 0.1030
# Beta Model Training - Epoch [39/200], Loss: 0.1015
# Beta Model Training - Epoch [40/200], Loss: 0.1007
# Beta Model Training - Epoch [41/200], Loss: 0.1031
# Beta Model Training - Epoch [42/200], Loss: 0.1011
# Beta Model Training - Epoch [43/200], Loss: 0.0980
# Beta Model Training - Epoch [44/200], Loss: 0.0941
# Beta Model Training - Epoch [45/200], Loss: 0.0927
# Beta Model Training - Epoch [46/200], Loss: 0.0900
# Beta Model Training - Epoch [47/200], Loss: 0.0904
# Beta Model Training - Epoch [48/200], Loss: 0.0890
# Beta Model Training - Epoch [49/200], Loss: 0.0895
# Beta Model Training - Epoch [50/200], Loss: 0.0881
# Beta Model Training - Epoch [51/200], Loss: 0.0872
# Beta Model Training - Epoch [52/200], Loss: 0.0874
# Beta Model Training - Epoch [53/200], Loss: 0.0850
# Beta Model Training - Epoch [54/200], Loss: 0.0849
# Beta Model Training - Epoch [55/200], Loss: 0.0845
# Beta Model Training - Epoch [56/200], Loss: 0.0837
# Beta Model Training - Epoch [57/200], Loss: 0.0818
# Beta Model Training - Epoch [58/200], Loss: 0.0806
# Beta Model Training - Epoch [59/200], Loss: 0.0802
# Beta Model Training - Epoch [60/200], Loss: 0.0790
# Beta Model Training - Epoch [61/200], Loss: 0.0793
# Beta Model Training - Epoch [62/200], Loss: 0.0793
# Beta Model Training - Epoch [63/200], Loss: 0.0803
# Beta Model Training - Epoch [64/200], Loss: 0.0874
# Beta Model Training - Epoch [65/200], Loss: 0.0894
# Beta Model Training - Epoch [66/200], Loss: 0.0876
# Beta Model Training - Epoch [67/200], Loss: 0.0845
# Beta Model Training - Epoch [68/200], Loss: 0.0820
# Beta Model Training - Epoch [69/200], Loss: 0.0773
# Beta Model Training - Epoch [70/200], Loss: 0.0774
# Beta Model Training - Epoch [71/200], Loss: 0.0751
# Beta Model Training - Epoch [72/200], Loss: 0.0761
# Beta Model Training - Epoch [73/200], Loss: 0.0731
# Beta Model Training - Epoch [74/200], Loss: 0.0723
# Beta Model Training - Epoch [75/200], Loss: 0.0730
# Beta Model Training - Epoch [76/200], Loss: 0.0709
# Beta Model Training - Epoch [77/200], Loss: 0.0717
# Beta Model Training - Epoch [78/200], Loss: 0.0707
# Beta Model Training - Epoch [79/200], Loss: 0.0706
# Beta Model Training - Epoch [80/200], Loss: 0.0696
# Beta Model Training - Epoch [81/200], Loss: 0.0707
# Beta Model Training - Epoch [82/200], Loss: 0.0695
# Beta Model Training - Epoch [83/200], Loss: 0.0699
# Beta Model Training - Epoch [84/200], Loss: 0.0695
# Beta Model Training - Epoch [85/200], Loss: 0.0688
# Beta Model Training - Epoch [86/200], Loss: 0.0690
# Beta Model Training - Epoch [87/200], Loss: 0.0693
# Beta Model Training - Epoch [88/200], Loss: 0.0680
# Beta Model Training - Epoch [89/200], Loss: 0.0682
# Beta Model Training - Epoch [90/200], Loss: 0.0678
# Beta Model Training - Epoch [91/200], Loss: 0.0674
# Beta Model Training - Epoch [92/200], Loss: 0.0676
# Beta Model Training - Epoch [93/200], Loss: 0.0654
# Beta Model Training - Epoch [94/200], Loss: 0.0650
# Beta Model Training - Epoch [95/200], Loss: 0.0650
# Beta Model Training - Epoch [96/200], Loss: 0.0654
# Beta Model Training - Epoch [97/200], Loss: 0.0654
# Beta Model Training - Epoch [98/200], Loss: 0.0673
# Beta Model Training - Epoch [99/200], Loss: 0.0641
# Beta Model Training - Epoch [100/200], Loss: 0.0636
# Beta Model Training - Epoch [101/200], Loss: 0.0637
# Beta Model Training - Epoch [102/200], Loss: 0.0626
# Beta Model Training - Epoch [103/200], Loss: 0.0631
# Beta Model Training - Epoch [104/200], Loss: 0.0630
# Beta Model Training - Epoch [105/200], Loss: 0.0625
# Beta Model Training - Epoch [106/200], Loss: 0.0621
# Beta Model Training - Epoch [107/200], Loss: 0.0628
# Beta Model Training - Epoch [108/200], Loss: 0.0615
# Beta Model Training - Epoch [109/200], Loss: 0.0621
# Beta Model Training - Epoch [110/200], Loss: 0.0648
# Beta Model Training - Epoch [111/200], Loss: 0.0643
# Beta Model Training - Epoch [112/200], Loss: 0.0624
# Beta Model Training - Epoch [113/200], Loss: 0.0616
# Beta Model Training - Epoch [114/200], Loss: 0.0614
# Beta Model Training - Epoch [115/200], Loss: 0.0610
# Beta Model Training - Epoch [116/200], Loss: 0.0592
# Beta Model Training - Epoch [117/200], Loss: 0.0616
# Beta Model Training - Epoch [118/200], Loss: 0.0596
# Beta Model Training - Epoch [119/200], Loss: 0.0619
# Beta Model Training - Epoch [120/200], Loss: 0.0603
# Beta Model Training - Epoch [121/200], Loss: 0.0616
# Beta Model Training - Epoch [122/200], Loss: 0.0602
# Beta Model Training - Epoch [123/200], Loss: 0.0591
# Beta Model Training - Epoch [124/200], Loss: 0.0608
# Beta Model Training - Epoch [125/200], Loss: 0.0655
# Beta Model Training - Epoch [126/200], Loss: 0.0658
# Beta Model Training - Epoch [127/200], Loss: 0.0631
# Beta Model Training - Epoch [128/200], Loss: 0.0607
# Beta Model Training - Epoch [129/200], Loss: 0.0629
# Beta Model Training - Epoch [130/200], Loss: 0.0668
# Beta Model Training - Epoch [131/200], Loss: 0.0634
# Beta Model Training - Epoch [132/200], Loss: 0.0604
# Beta Model Training - Epoch [133/200], Loss: 0.0604
# Beta Model Training - Epoch [134/200], Loss: 0.0594
# Beta Model Training - Epoch [135/200], Loss: 0.0599
# Beta Model Training - Epoch [136/200], Loss: 0.0599
# Beta Model Training - Epoch [137/200], Loss: 0.0599
# Beta Model Training - Epoch [138/200], Loss: 0.0636
# Beta Model Training - Epoch [139/200], Loss: 0.0624
# Beta Model Training - Epoch [140/200], Loss: 0.0619
# Beta Model Training - Epoch [141/200], Loss: 0.0624
# Beta Model Training - Epoch [142/200], Loss: 0.0605
# Beta Model Training - Epoch [143/200], Loss: 0.0606
# Beta Model Training - Epoch [144/200], Loss: 0.0594
# Beta Model Training - Epoch [145/200], Loss: 0.0578
# Beta Model Training - Epoch [146/200], Loss: 0.0569
# Beta Model Training - Epoch [147/200], Loss: 0.0561
# Beta Model Training - Epoch [148/200], Loss: 0.0557
# Beta Model Training - Epoch [149/200], Loss: 0.0551
# Beta Model Training - Epoch [150/200], Loss: 0.0570
# Beta Model Training - Epoch [151/200], Loss: 0.0558
# Beta Model Training - Epoch [152/200], Loss: 0.0554
# Beta Model Training - Epoch [153/200], Loss: 0.0545
# Beta Model Training - Epoch [154/200], Loss: 0.0558
# Beta Model Training - Epoch [155/200], Loss: 0.0538
# Beta Model Training - Epoch [156/200], Loss: 0.0538
# Beta Model Training - Epoch [157/200], Loss: 0.0536
# Beta Model Training - Epoch [158/200], Loss: 0.0541
# Beta Model Training - Epoch [159/200], Loss: 0.0532
# Beta Model Training - Epoch [160/200], Loss: 0.0534
# Beta Model Training - Epoch [161/200], Loss: 0.0532
# Beta Model Training - Epoch [162/200], Loss: 0.0534
# Beta Model Training - Epoch [163/200], Loss: 0.0529
# Beta Model Training - Epoch [164/200], Loss: 0.0536
# Beta Model Training - Epoch [165/200], Loss: 0.0535
# Beta Model Training - Epoch [166/200], Loss: 0.0533
# Beta Model Training - Epoch [167/200], Loss: 0.0529
# Beta Model Training - Epoch [168/200], Loss: 0.0538
# Beta Model Training - Epoch [169/200], Loss: 0.0535
# Beta Model Training - Epoch [170/200], Loss: 0.0539
# Beta Model Training - Epoch [171/200], Loss: 0.0538
# Beta Model Training - Epoch [172/200], Loss: 0.0531
# Beta Model Training - Epoch [173/200], Loss: 0.0542
# Beta Model Training - Epoch [174/200], Loss: 0.0548
# Beta Model Training - Epoch [175/200], Loss: 0.0543
# Beta Model Training - Epoch [176/200], Loss: 0.0540
# Beta Model Training - Epoch [177/200], Loss: 0.0535
# Beta Model Training - Epoch [178/200], Loss: 0.0545
# Beta Model Training - Epoch [179/200], Loss: 0.0556
# Beta Model Training - Epoch [180/200], Loss: 0.0545
# Beta Model Training - Epoch [181/200], Loss: 0.0544
# Beta Model Training - Epoch [182/200], Loss: 0.0537
# Beta Model Training - Epoch [183/200], Loss: 0.0542
# Beta Model Training - Epoch [184/200], Loss: 0.0534
# Beta Model Training - Epoch [185/200], Loss: 0.0534
# Beta Model Training - Epoch [186/200], Loss: 0.0530
# Beta Model Training - Epoch [187/200], Loss: 0.0531
# Beta Model Training - Epoch [188/200], Loss: 0.0527
# Beta Model Training - Epoch [189/200], Loss: 0.0534
# Beta Model Training - Epoch [190/200], Loss: 0.0536
# Beta Model Training - Epoch [191/200], Loss: 0.0547
# Beta Model Training - Epoch [192/200], Loss: 0.0546
# Beta Model Training - Epoch [193/200], Loss: 0.0533
# Beta Model Training - Epoch [194/200], Loss: 0.0536
# Beta Model Training - Epoch [195/200], Loss: 0.0527
# Beta Model Training - Epoch [196/200], Loss: 0.0529
# Beta Model Training - Epoch [197/200], Loss: 0.0527
# Beta Model Training - Epoch [198/200], Loss: 0.0529
# Beta Model Training - Epoch [199/200], Loss: 0.0564
# Beta Model Training - Epoch [200/200], Loss: 0.0618
# Linear Probe Training - Epoch [1/200], Loss: 1.9353
# Linear Probe Training - Epoch [2/200], Loss: 1.4377
# Linear Probe Training - Epoch [3/200], Loss: 1.1598
# Linear Probe Training - Epoch [4/200], Loss: 1.0011
# Linear Probe Training - Epoch [5/200], Loss: 0.9069
# Linear Probe Training - Epoch [6/200], Loss: 0.8283
# Linear Probe Training - Epoch [7/200], Loss: 0.7727
# Linear Probe Training - Epoch [8/200], Loss: 0.7262
# Linear Probe Training - Epoch [9/200], Loss: 0.6786
# Linear Probe Training - Epoch [10/200], Loss: 0.6367
# Linear Probe Training - Epoch [11/200], Loss: 0.5968
# Linear Probe Training - Epoch [12/200], Loss: 0.5626
# Linear Probe Training - Epoch [13/200], Loss: 0.5331
# Linear Probe Training - Epoch [14/200], Loss: 0.5078
# Linear Probe Training - Epoch [15/200], Loss: 0.4785
# Linear Probe Training - Epoch [16/200], Loss: 0.4563
# Linear Probe Training - Epoch [17/200], Loss: 0.4352
# Linear Probe Training - Epoch [18/200], Loss: 0.4116
# Linear Probe Training - Epoch [19/200], Loss: 0.3950
# Linear Probe Training - Epoch [20/200], Loss: 0.3776
# Linear Probe Training - Epoch [21/200], Loss: 0.3582
# Linear Probe Training - Epoch [22/200], Loss: 0.3425
# Linear Probe Training - Epoch [23/200], Loss: 0.3278
# Linear Probe Training - Epoch [24/200], Loss: 0.3129
# Linear Probe Training - Epoch [25/200], Loss: 0.3028
# Linear Probe Training - Epoch [26/200], Loss: 0.2880
# Linear Probe Training - Epoch [27/200], Loss: 0.2776
# Linear Probe Training - Epoch [28/200], Loss: 0.2651
# Linear Probe Training - Epoch [29/200], Loss: 0.2532
# Linear Probe Training - Epoch [30/200], Loss: 0.2474
# Linear Probe Training - Epoch [31/200], Loss: 0.2383
# Linear Probe Training - Epoch [32/200], Loss: 0.2261
# Linear Probe Training - Epoch [33/200], Loss: 0.2195
# Linear Probe Training - Epoch [34/200], Loss: 0.2099
# Linear Probe Training - Epoch [35/200], Loss: 0.2033
# Linear Probe Training - Epoch [36/200], Loss: 0.1961
# Linear Probe Training - Epoch [37/200], Loss: 0.1885
# Linear Probe Training - Epoch [38/200], Loss: 0.1825
# Linear Probe Training - Epoch [39/200], Loss: 0.1771
# Linear Probe Training - Epoch [40/200], Loss: 0.1710
# Linear Probe Training - Epoch [41/200], Loss: 0.1658
# Linear Probe Training - Epoch [42/200], Loss: 0.1593
# Linear Probe Training - Epoch [43/200], Loss: 0.1546
# Linear Probe Training - Epoch [44/200], Loss: 0.1504
# Linear Probe Training - Epoch [45/200], Loss: 0.1484
# Linear Probe Training - Epoch [46/200], Loss: 0.1424
# Linear Probe Training - Epoch [47/200], Loss: 0.1391
# Linear Probe Training - Epoch [48/200], Loss: 0.1358
# Linear Probe Training - Epoch [49/200], Loss: 0.1313
# Linear Probe Training - Epoch [50/200], Loss: 0.1286
# Linear Probe Training - Epoch [51/200], Loss: 0.1240
# Linear Probe Training - Epoch [52/200], Loss: 0.1205
# Linear Probe Training - Epoch [53/200], Loss: 0.1197
# Linear Probe Training - Epoch [54/200], Loss: 0.1151
# Linear Probe Training - Epoch [55/200], Loss: 0.1127
# Linear Probe Training - Epoch [56/200], Loss: 0.1118
# Linear Probe Training - Epoch [57/200], Loss: 0.1077
# Linear Probe Training - Epoch [58/200], Loss: 0.1049
# Linear Probe Training - Epoch [59/200], Loss: 0.1030
# Linear Probe Training - Epoch [60/200], Loss: 0.1003
# Linear Probe Training - Epoch [61/200], Loss: 0.0990
# Linear Probe Training - Epoch [62/200], Loss: 0.0970
# Linear Probe Training - Epoch [63/200], Loss: 0.0957
# Linear Probe Training - Epoch [64/200], Loss: 0.0932
# Linear Probe Training - Epoch [65/200], Loss: 0.0918
# Linear Probe Training - Epoch [66/200], Loss: 0.0897
# Linear Probe Training - Epoch [67/200], Loss: 0.0891
# Linear Probe Training - Epoch [68/200], Loss: 0.0880
# Linear Probe Training - Epoch [69/200], Loss: 0.0859
# Linear Probe Training - Epoch [70/200], Loss: 0.0841
# Linear Probe Training - Epoch [71/200], Loss: 0.0826
# Linear Probe Training - Epoch [72/200], Loss: 0.0819
# Linear Probe Training - Epoch [73/200], Loss: 0.0817
# Linear Probe Training - Epoch [74/200], Loss: 0.0801
# Linear Probe Training - Epoch [75/200], Loss: 0.0792
# Linear Probe Training - Epoch [76/200], Loss: 0.0777
# Linear Probe Training - Epoch [77/200], Loss: 0.0779
# Linear Probe Training - Epoch [78/200], Loss: 0.0761
# Linear Probe Training - Epoch [79/200], Loss: 0.0752
# Linear Probe Training - Epoch [80/200], Loss: 0.0755
# Linear Probe Training - Epoch [81/200], Loss: 0.0739
# Linear Probe Training - Epoch [82/200], Loss: 0.0724
# Linear Probe Training - Epoch [83/200], Loss: 0.0724
# Linear Probe Training - Epoch [84/200], Loss: 0.0710
# Linear Probe Training - Epoch [85/200], Loss: 0.0717
# Linear Probe Training - Epoch [86/200], Loss: 0.0705
# Linear Probe Training - Epoch [87/200], Loss: 0.0695
# Linear Probe Training - Epoch [88/200], Loss: 0.0699
# Linear Probe Training - Epoch [89/200], Loss: 0.0682
# Linear Probe Training - Epoch [90/200], Loss: 0.0676
# Linear Probe Training - Epoch [91/200], Loss: 0.0676
# Linear Probe Training - Epoch [92/200], Loss: 0.0664
# Linear Probe Training - Epoch [93/200], Loss: 0.0668
# Linear Probe Training - Epoch [94/200], Loss: 0.0671
# Linear Probe Training - Epoch [95/200], Loss: 0.0653
# Linear Probe Training - Epoch [96/200], Loss: 0.0650
# Linear Probe Training - Epoch [97/200], Loss: 0.0641
# Linear Probe Training - Epoch [98/200], Loss: 0.0639
# Linear Probe Training - Epoch [99/200], Loss: 0.0636
# Linear Probe Training - Epoch [100/200], Loss: 0.0646
# Linear Probe Training - Epoch [101/200], Loss: 0.0634
# Linear Probe Training - Epoch [102/200], Loss: 0.0626
# Linear Probe Training - Epoch [103/200], Loss: 0.0626
# Linear Probe Training - Epoch [104/200], Loss: 0.0622
# Linear Probe Training - Epoch [105/200], Loss: 0.0616
# Linear Probe Training - Epoch [106/200], Loss: 0.0633
# Linear Probe Training - Epoch [107/200], Loss: 0.0616
# Linear Probe Training - Epoch [108/200], Loss: 0.0610
# Linear Probe Training - Epoch [109/200], Loss: 0.0613
# Linear Probe Training - Epoch [110/200], Loss: 0.0609
# Linear Probe Training - Epoch [111/200], Loss: 0.0604
# Linear Probe Training - Epoch [112/200], Loss: 0.0598
# Linear Probe Training - Epoch [113/200], Loss: 0.0599
# Linear Probe Training - Epoch [114/200], Loss: 0.0609
# Linear Probe Training - Epoch [115/200], Loss: 0.0605
# Linear Probe Training - Epoch [116/200], Loss: 0.0592
# Linear Probe Training - Epoch [117/200], Loss: 0.0593
# Linear Probe Training - Epoch [118/200], Loss: 0.0595
# Linear Probe Training - Epoch [119/200], Loss: 0.0586
# Linear Probe Training - Epoch [120/200], Loss: 0.0599
# Linear Probe Training - Epoch [121/200], Loss: 0.0588
# Linear Probe Training - Epoch [122/200], Loss: 0.0584
# Linear Probe Training - Epoch [123/200], Loss: 0.0580
# Linear Probe Training - Epoch [124/200], Loss: 0.0590
# Linear Probe Training - Epoch [125/200], Loss: 0.0583
# Linear Probe Training - Epoch [126/200], Loss: 0.0579
# Linear Probe Training - Epoch [127/200], Loss: 0.0582
# Linear Probe Training - Epoch [128/200], Loss: 0.0574
# Linear Probe Training - Epoch [129/200], Loss: 0.0581
# Linear Probe Training - Epoch [130/200], Loss: 0.0588
# Linear Probe Training - Epoch [131/200], Loss: 0.0573
# Linear Probe Training - Epoch [132/200], Loss: 0.0571
# Linear Probe Training - Epoch [133/200], Loss: 0.0576
# Linear Probe Training - Epoch [134/200], Loss: 0.0571
# Linear Probe Training - Epoch [135/200], Loss: 0.0564
# Linear Probe Training - Epoch [136/200], Loss: 0.0571
# Linear Probe Training - Epoch [137/200], Loss: 0.0568
# Linear Probe Training - Epoch [138/200], Loss: 0.0576
# Linear Probe Training - Epoch [139/200], Loss: 0.0565
# Linear Probe Training - Epoch [140/200], Loss: 0.0569
# Linear Probe Training - Epoch [141/200], Loss: 0.0566
# Linear Probe Training - Epoch [142/200], Loss: 0.0565
# Linear Probe Training - Epoch [143/200], Loss: 0.0569
# Linear Probe Training - Epoch [144/200], Loss: 0.0570
# Linear Probe Training - Epoch [145/200], Loss: 0.0566
# Linear Probe Training - Epoch [146/200], Loss: 0.0575
# Linear Probe Training - Epoch [147/200], Loss: 0.0561
# Linear Probe Training - Epoch [148/200], Loss: 0.0566
# Linear Probe Training - Epoch [149/200], Loss: 0.0559
# Linear Probe Training - Epoch [150/200], Loss: 0.0562
# Linear Probe Training - Epoch [151/200], Loss: 0.0571
# Linear Probe Training - Epoch [152/200], Loss: 0.0561
# Linear Probe Training - Epoch [153/200], Loss: 0.0560
# Linear Probe Training - Epoch [154/200], Loss: 0.0561
# Linear Probe Training - Epoch [155/200], Loss: 0.0566
# Linear Probe Training - Epoch [156/200], Loss: 0.0557
# Linear Probe Training - Epoch [157/200], Loss: 0.0561
# Linear Probe Training - Epoch [158/200], Loss: 0.0572
# Linear Probe Training - Epoch [159/200], Loss: 0.0564
# Linear Probe Training - Epoch [160/200], Loss: 0.0554
# Linear Probe Training - Epoch [161/200], Loss: 0.0555
# Linear Probe Training - Epoch [162/200], Loss: 0.0559
# Linear Probe Training - Epoch [163/200], Loss: 0.0567
# Linear Probe Training - Epoch [164/200], Loss: 0.0569
# Linear Probe Training - Epoch [165/200], Loss: 0.0556
# Linear Probe Training - Epoch [166/200], Loss: 0.0553
# Linear Probe Training - Epoch [167/200], Loss: 0.0552
# Linear Probe Training - Epoch [168/200], Loss: 0.0552
# Linear Probe Training - Epoch [169/200], Loss: 0.0550
# Linear Probe Training - Epoch [170/200], Loss: 0.0553
# Linear Probe Training - Epoch [171/200], Loss: 0.0557
# Linear Probe Training - Epoch [172/200], Loss: 0.0559
# Linear Probe Training - Epoch [173/200], Loss: 0.0563
# Linear Probe Training - Epoch [174/200], Loss: 0.0557
# Linear Probe Training - Epoch [175/200], Loss: 0.0555
# Linear Probe Training - Epoch [176/200], Loss: 0.0557
# Linear Probe Training - Epoch [177/200], Loss: 0.0558
# Linear Probe Training - Epoch [178/200], Loss: 0.0551
# Linear Probe Training - Epoch [179/200], Loss: 0.0553
# Linear Probe Training - Epoch [180/200], Loss: 0.0551
# Linear Probe Training - Epoch [181/200], Loss: 0.0554
# Linear Probe Training - Epoch [182/200], Loss: 0.0554
# Linear Probe Training - Epoch [183/200], Loss: 0.0549
# Linear Probe Training - Epoch [184/200], Loss: 0.0551
# Linear Probe Training - Epoch [185/200], Loss: 0.0547
# Linear Probe Training - Epoch [186/200], Loss: 0.0551
# Linear Probe Training - Epoch [187/200], Loss: 0.0557
# Linear Probe Training - Epoch [188/200], Loss: 0.0549
# Linear Probe Training - Epoch [189/200], Loss: 0.0551
# Linear Probe Training - Epoch [190/200], Loss: 0.0546
# Linear Probe Training - Epoch [191/200], Loss: 0.0565
# Linear Probe Training - Epoch [192/200], Loss: 0.0547
# Linear Probe Training - Epoch [193/200], Loss: 0.0561
# Linear Probe Training - Epoch [194/200], Loss: 0.0549
# Linear Probe Training - Epoch [195/200], Loss: 0.0562
# Linear Probe Training - Epoch [196/200], Loss: 0.0552
# Linear Probe Training - Epoch [197/200], Loss: 0.0559
# Linear Probe Training - Epoch [198/200], Loss: 0.0553
# Linear Probe Training - Epoch [199/200], Loss: 0.0561
# Linear Probe Training - Epoch [200/200], Loss: 0.0562
#
# === Building dataset/model for Beta 1 ===
# Beta Model Training - Epoch [1/200], Loss: 0.7503
# Beta Model Training - Epoch [2/200], Loss: 0.6417
# Beta Model Training - Epoch [3/200], Loss: 0.5045
# Beta Model Training - Epoch [4/200], Loss: 0.4115
# Beta Model Training - Epoch [5/200], Loss: 0.3717
# Beta Model Training - Epoch [6/200], Loss: 0.3433
# Beta Model Training - Epoch [7/200], Loss: 0.3222
# Beta Model Training - Epoch [8/200], Loss: 0.3053
# Beta Model Training - Epoch [9/200], Loss: 0.2913
# Beta Model Training - Epoch [10/200], Loss: 0.2736
# Beta Model Training - Epoch [11/200], Loss: 0.2547
# Beta Model Training - Epoch [12/200], Loss: 0.2375
# Beta Model Training - Epoch [13/200], Loss: 0.2239
# Beta Model Training - Epoch [14/200], Loss: 0.2114
# Beta Model Training - Epoch [15/200], Loss: 0.1975
# Beta Model Training - Epoch [16/200], Loss: 0.1871
# Beta Model Training - Epoch [17/200], Loss: 0.1830
# Beta Model Training - Epoch [18/200], Loss: 0.1793
# Beta Model Training - Epoch [19/200], Loss: 0.1741
# Beta Model Training - Epoch [20/200], Loss: 0.1652
# Beta Model Training - Epoch [21/200], Loss: 0.1595
# Beta Model Training - Epoch [22/200], Loss: 0.1554
# Beta Model Training - Epoch [23/200], Loss: 0.1498
# Beta Model Training - Epoch [24/200], Loss: 0.1410
# Beta Model Training - Epoch [25/200], Loss: 0.1345
# Beta Model Training - Epoch [26/200], Loss: 0.1293
# Beta Model Training - Epoch [27/200], Loss: 0.1232
# Beta Model Training - Epoch [28/200], Loss: 0.1191
# Beta Model Training - Epoch [29/200], Loss: 0.1163
# Beta Model Training - Epoch [30/200], Loss: 0.1145
# Beta Model Training - Epoch [31/200], Loss: 0.1102
# Beta Model Training - Epoch [32/200], Loss: 0.1093
# Beta Model Training - Epoch [33/200], Loss: 0.1118
# Beta Model Training - Epoch [34/200], Loss: 0.1148
# Beta Model Training - Epoch [35/200], Loss: 0.1129
# Beta Model Training - Epoch [36/200], Loss: 0.1075
# Beta Model Training - Epoch [37/200], Loss: 0.1015
# Beta Model Training - Epoch [38/200], Loss: 0.1021
# Beta Model Training - Epoch [39/200], Loss: 0.0978
# Beta Model Training - Epoch [40/200], Loss: 0.0969
# Beta Model Training - Epoch [41/200], Loss: 0.0943
# Beta Model Training - Epoch [42/200], Loss: 0.0948
# Beta Model Training - Epoch [43/200], Loss: 0.0949
# Beta Model Training - Epoch [44/200], Loss: 0.0964
# Beta Model Training - Epoch [45/200], Loss: 0.0947
# Beta Model Training - Epoch [46/200], Loss: 0.0897
# Beta Model Training - Epoch [47/200], Loss: 0.0896
# Beta Model Training - Epoch [48/200], Loss: 0.0900
# Beta Model Training - Epoch [49/200], Loss: 0.0890
# Beta Model Training - Epoch [50/200], Loss: 0.0921
# Beta Model Training - Epoch [51/200], Loss: 0.0870
# Beta Model Training - Epoch [52/200], Loss: 0.0847
# Beta Model Training - Epoch [53/200], Loss: 0.0847
# Beta Model Training - Epoch [54/200], Loss: 0.0825
# Beta Model Training - Epoch [55/200], Loss: 0.0821
# Beta Model Training - Epoch [56/200], Loss: 0.0789
# Beta Model Training - Epoch [57/200], Loss: 0.0781
# Beta Model Training - Epoch [58/200], Loss: 0.0778
# Beta Model Training - Epoch [59/200], Loss: 0.0762
# Beta Model Training - Epoch [60/200], Loss: 0.0754
# Beta Model Training - Epoch [61/200], Loss: 0.0751
# Beta Model Training - Epoch [62/200], Loss: 0.0743
# Beta Model Training - Epoch [63/200], Loss: 0.0740
# Beta Model Training - Epoch [64/200], Loss: 0.0731
# Beta Model Training - Epoch [65/200], Loss: 0.0735
# Beta Model Training - Epoch [66/200], Loss: 0.0721
# Beta Model Training - Epoch [67/200], Loss: 0.0718
# Beta Model Training - Epoch [68/200], Loss: 0.0721
# Beta Model Training - Epoch [69/200], Loss: 0.0720
# Beta Model Training - Epoch [70/200], Loss: 0.0711
# Beta Model Training - Epoch [71/200], Loss: 0.0716
# Beta Model Training - Epoch [72/200], Loss: 0.0718
# Beta Model Training - Epoch [73/200], Loss: 0.0736
# Beta Model Training - Epoch [74/200], Loss: 0.0723
# Beta Model Training - Epoch [75/200], Loss: 0.0713
# Beta Model Training - Epoch [76/200], Loss: 0.0742
# Beta Model Training - Epoch [77/200], Loss: 0.0710
# Beta Model Training - Epoch [78/200], Loss: 0.0712
# Beta Model Training - Epoch [79/200], Loss: 0.0703
# Beta Model Training - Epoch [80/200], Loss: 0.0697
# Beta Model Training - Epoch [81/200], Loss: 0.0692
# Beta Model Training - Epoch [82/200], Loss: 0.0701
# Beta Model Training - Epoch [83/200], Loss: 0.0675
# Beta Model Training - Epoch [84/200], Loss: 0.0666
# Beta Model Training - Epoch [85/200], Loss: 0.0656
# Beta Model Training - Epoch [86/200], Loss: 0.0670
# Beta Model Training - Epoch [87/200], Loss: 0.0667
# Beta Model Training - Epoch [88/200], Loss: 0.0659
# Beta Model Training - Epoch [89/200], Loss: 0.0671
# Beta Model Training - Epoch [90/200], Loss: 0.0667
# Beta Model Training - Epoch [91/200], Loss: 0.0647
# Beta Model Training - Epoch [92/200], Loss: 0.0652
# Beta Model Training - Epoch [93/200], Loss: 0.0665
# Beta Model Training - Epoch [94/200], Loss: 0.0671
# Beta Model Training - Epoch [95/200], Loss: 0.0642
# Beta Model Training - Epoch [96/200], Loss: 0.0630
# Beta Model Training - Epoch [97/200], Loss: 0.0629
# Beta Model Training - Epoch [98/200], Loss: 0.0626
# Beta Model Training - Epoch [99/200], Loss: 0.0620
# Beta Model Training - Epoch [100/200], Loss: 0.0623
# Beta Model Training - Epoch [101/200], Loss: 0.0618
# Beta Model Training - Epoch [102/200], Loss: 0.0628
# Beta Model Training - Epoch [103/200], Loss: 0.0644
# Beta Model Training - Epoch [104/200], Loss: 0.0621
# Beta Model Training - Epoch [105/200], Loss: 0.0618
# Beta Model Training - Epoch [106/200], Loss: 0.0612
# Beta Model Training - Epoch [107/200], Loss: 0.0610
# Beta Model Training - Epoch [108/200], Loss: 0.0605
# Beta Model Training - Epoch [109/200], Loss: 0.0598
# Beta Model Training - Epoch [110/200], Loss: 0.0586
# Beta Model Training - Epoch [111/200], Loss: 0.0587
# Beta Model Training - Epoch [112/200], Loss: 0.0588
# Beta Model Training - Epoch [113/200], Loss: 0.0599
# Beta Model Training - Epoch [114/200], Loss: 0.0599
# Beta Model Training - Epoch [115/200], Loss: 0.0607
# Beta Model Training - Epoch [116/200], Loss: 0.0587
# Beta Model Training - Epoch [117/200], Loss: 0.0600
# Beta Model Training - Epoch [118/200], Loss: 0.0611
# Beta Model Training - Epoch [119/200], Loss: 0.0592
# Beta Model Training - Epoch [120/200], Loss: 0.0579
# Beta Model Training - Epoch [121/200], Loss: 0.0576
# Beta Model Training - Epoch [122/200], Loss: 0.0585
# Beta Model Training - Epoch [123/200], Loss: 0.0576
# Beta Model Training - Epoch [124/200], Loss: 0.0577
# Beta Model Training - Epoch [125/200], Loss: 0.0566
# Beta Model Training - Epoch [126/200], Loss: 0.0561
# Beta Model Training - Epoch [127/200], Loss: 0.0563
# Beta Model Training - Epoch [128/200], Loss: 0.0569
# Beta Model Training - Epoch [129/200], Loss: 0.0576
# Beta Model Training - Epoch [130/200], Loss: 0.0556
# Beta Model Training - Epoch [131/200], Loss: 0.0566
# Beta Model Training - Epoch [132/200], Loss: 0.0565
# Beta Model Training - Epoch [133/200], Loss: 0.0581
# Beta Model Training - Epoch [134/200], Loss: 0.0562
# Beta Model Training - Epoch [135/200], Loss: 0.0565
# Beta Model Training - Epoch [136/200], Loss: 0.0577
# Beta Model Training - Epoch [137/200], Loss: 0.0581
# Beta Model Training - Epoch [138/200], Loss: 0.0587
# Beta Model Training - Epoch [139/200], Loss: 0.0595
# Beta Model Training - Epoch [140/200], Loss: 0.0593
# Beta Model Training - Epoch [141/200], Loss: 0.0604
# Beta Model Training - Epoch [142/200], Loss: 0.0584
# Beta Model Training - Epoch [143/200], Loss: 0.0575
# Beta Model Training - Epoch [144/200], Loss: 0.0561
# Beta Model Training - Epoch [145/200], Loss: 0.0557
# Beta Model Training - Epoch [146/200], Loss: 0.0545
# Beta Model Training - Epoch [147/200], Loss: 0.0551
# Beta Model Training - Epoch [148/200], Loss: 0.0544
# Beta Model Training - Epoch [149/200], Loss: 0.0538
# Beta Model Training - Epoch [150/200], Loss: 0.0541
# Beta Model Training - Epoch [151/200], Loss: 0.0540
# Beta Model Training - Epoch [152/200], Loss: 0.0548
# Beta Model Training - Epoch [153/200], Loss: 0.0560
# Beta Model Training - Epoch [154/200], Loss: 0.0579
# Beta Model Training - Epoch [155/200], Loss: 0.0549
# Beta Model Training - Epoch [156/200], Loss: 0.0553
# Beta Model Training - Epoch [157/200], Loss: 0.0553
# Beta Model Training - Epoch [158/200], Loss: 0.0588
# Beta Model Training - Epoch [159/200], Loss: 0.0570
# Beta Model Training - Epoch [160/200], Loss: 0.0571
# Beta Model Training - Epoch [161/200], Loss: 0.0569
# Beta Model Training - Epoch [162/200], Loss: 0.0552
# Beta Model Training - Epoch [163/200], Loss: 0.0600
# Beta Model Training - Epoch [164/200], Loss: 0.0626
# Beta Model Training - Epoch [165/200], Loss: 0.0640
# Beta Model Training - Epoch [166/200], Loss: 0.0579
# Beta Model Training - Epoch [167/200], Loss: 0.0557
# Beta Model Training - Epoch [168/200], Loss: 0.0551
# Beta Model Training - Epoch [169/200], Loss: 0.0543
# Beta Model Training - Epoch [170/200], Loss: 0.0525
# Beta Model Training - Epoch [171/200], Loss: 0.0519
# Beta Model Training - Epoch [172/200], Loss: 0.0527
# Beta Model Training - Epoch [173/200], Loss: 0.0522
# Beta Model Training - Epoch [174/200], Loss: 0.0522
# Beta Model Training - Epoch [175/200], Loss: 0.0523
# Beta Model Training - Epoch [176/200], Loss: 0.0525
# Beta Model Training - Epoch [177/200], Loss: 0.0514
# Beta Model Training - Epoch [178/200], Loss: 0.0521
# Beta Model Training - Epoch [179/200], Loss: 0.0517
# Beta Model Training - Epoch [180/200], Loss: 0.0507
# Beta Model Training - Epoch [181/200], Loss: 0.0500
# Beta Model Training - Epoch [182/200], Loss: 0.0497
# Beta Model Training - Epoch [183/200], Loss: 0.0500
# Beta Model Training - Epoch [184/200], Loss: 0.0509
# Beta Model Training - Epoch [185/200], Loss: 0.0495
# Beta Model Training - Epoch [186/200], Loss: 0.0498
# Beta Model Training - Epoch [187/200], Loss: 0.0494
# Beta Model Training - Epoch [188/200], Loss: 0.0492
# Beta Model Training - Epoch [189/200], Loss: 0.0502
# Beta Model Training - Epoch [190/200], Loss: 0.0497
# Beta Model Training - Epoch [191/200], Loss: 0.0491
# Beta Model Training - Epoch [192/200], Loss: 0.0499
# Beta Model Training - Epoch [193/200], Loss: 0.0502
# Beta Model Training - Epoch [194/200], Loss: 0.0496
# Beta Model Training - Epoch [195/200], Loss: 0.0500
# Beta Model Training - Epoch [196/200], Loss: 0.0496
# Beta Model Training - Epoch [197/200], Loss: 0.0496
# Beta Model Training - Epoch [198/200], Loss: 0.0488
# Beta Model Training - Epoch [199/200], Loss: 0.0489
# Beta Model Training - Epoch [200/200], Loss: 0.0487
# Linear Probe Training - Epoch [1/200], Loss: 2.0677
# Linear Probe Training - Epoch [2/200], Loss: 1.4465
# Linear Probe Training - Epoch [3/200], Loss: 1.1432
# Linear Probe Training - Epoch [4/200], Loss: 0.9983
# Linear Probe Training - Epoch [5/200], Loss: 0.9130
# Linear Probe Training - Epoch [6/200], Loss: 0.8480
# Linear Probe Training - Epoch [7/200], Loss: 0.8053
# Linear Probe Training - Epoch [8/200], Loss: 0.7584
# Linear Probe Training - Epoch [9/200], Loss: 0.7149
# Linear Probe Training - Epoch [10/200], Loss: 0.6801
# Linear Probe Training - Epoch [11/200], Loss: 0.6494
# Linear Probe Training - Epoch [12/200], Loss: 0.6067
# Linear Probe Training - Epoch [13/200], Loss: 0.5785
# Linear Probe Training - Epoch [14/200], Loss: 0.5519
# Linear Probe Training - Epoch [15/200], Loss: 0.5264
# Linear Probe Training - Epoch [16/200], Loss: 0.4994
# Linear Probe Training - Epoch [17/200], Loss: 0.4759
# Linear Probe Training - Epoch [18/200], Loss: 0.4558
# Linear Probe Training - Epoch [19/200], Loss: 0.4331
# Linear Probe Training - Epoch [20/200], Loss: 0.4150
# Linear Probe Training - Epoch [21/200], Loss: 0.3942
# Linear Probe Training - Epoch [22/200], Loss: 0.3785
# Linear Probe Training - Epoch [23/200], Loss: 0.3664
# Linear Probe Training - Epoch [24/200], Loss: 0.3529
# Linear Probe Training - Epoch [25/200], Loss: 0.3333
# Linear Probe Training - Epoch [26/200], Loss: 0.3209
# Linear Probe Training - Epoch [27/200], Loss: 0.3099
# Linear Probe Training - Epoch [28/200], Loss: 0.2950
# Linear Probe Training - Epoch [29/200], Loss: 0.2847
# Linear Probe Training - Epoch [30/200], Loss: 0.2746
# Linear Probe Training - Epoch [31/200], Loss: 0.2622
# Linear Probe Training - Epoch [32/200], Loss: 0.2528
# Linear Probe Training - Epoch [33/200], Loss: 0.2422
# Linear Probe Training - Epoch [34/200], Loss: 0.2338
# Linear Probe Training - Epoch [35/200], Loss: 0.2230
# Linear Probe Training - Epoch [36/200], Loss: 0.2155
# Linear Probe Training - Epoch [37/200], Loss: 0.2080
# Linear Probe Training - Epoch [38/200], Loss: 0.2007
# Linear Probe Training - Epoch [39/200], Loss: 0.1924
# Linear Probe Training - Epoch [40/200], Loss: 0.1885
# Linear Probe Training - Epoch [41/200], Loss: 0.1802
# Linear Probe Training - Epoch [42/200], Loss: 0.1729
# Linear Probe Training - Epoch [43/200], Loss: 0.1679
# Linear Probe Training - Epoch [44/200], Loss: 0.1642
# Linear Probe Training - Epoch [45/200], Loss: 0.1559
# Linear Probe Training - Epoch [46/200], Loss: 0.1535
# Linear Probe Training - Epoch [47/200], Loss: 0.1482
# Linear Probe Training - Epoch [48/200], Loss: 0.1456
# Linear Probe Training - Epoch [49/200], Loss: 0.1386
# Linear Probe Training - Epoch [50/200], Loss: 0.1342
# Linear Probe Training - Epoch [51/200], Loss: 0.1299
# Linear Probe Training - Epoch [52/200], Loss: 0.1273
# Linear Probe Training - Epoch [53/200], Loss: 0.1231
# Linear Probe Training - Epoch [54/200], Loss: 0.1214
# Linear Probe Training - Epoch [55/200], Loss: 0.1181
# Linear Probe Training - Epoch [56/200], Loss: 0.1138
# Linear Probe Training - Epoch [57/200], Loss: 0.1113
# Linear Probe Training - Epoch [58/200], Loss: 0.1090
# Linear Probe Training - Epoch [59/200], Loss: 0.1070
# Linear Probe Training - Epoch [60/200], Loss: 0.1045
# Linear Probe Training - Epoch [61/200], Loss: 0.1022
# Linear Probe Training - Epoch [62/200], Loss: 0.0992
# Linear Probe Training - Epoch [63/200], Loss: 0.0982
# Linear Probe Training - Epoch [64/200], Loss: 0.0957
# Linear Probe Training - Epoch [65/200], Loss: 0.0933
# Linear Probe Training - Epoch [66/200], Loss: 0.0911
# Linear Probe Training - Epoch [67/200], Loss: 0.0902
# Linear Probe Training - Epoch [68/200], Loss: 0.0885
# Linear Probe Training - Epoch [69/200], Loss: 0.0865
# Linear Probe Training - Epoch [70/200], Loss: 0.0870
# Linear Probe Training - Epoch [71/200], Loss: 0.0837
# Linear Probe Training - Epoch [72/200], Loss: 0.0835
# Linear Probe Training - Epoch [73/200], Loss: 0.0814
# Linear Probe Training - Epoch [74/200], Loss: 0.0810
# Linear Probe Training - Epoch [75/200], Loss: 0.0792
# Linear Probe Training - Epoch [76/200], Loss: 0.0778
# Linear Probe Training - Epoch [77/200], Loss: 0.0767
# Linear Probe Training - Epoch [78/200], Loss: 0.0772
# Linear Probe Training - Epoch [79/200], Loss: 0.0757
# Linear Probe Training - Epoch [80/200], Loss: 0.0748
# Linear Probe Training - Epoch [81/200], Loss: 0.0727
# Linear Probe Training - Epoch [82/200], Loss: 0.0722
# Linear Probe Training - Epoch [83/200], Loss: 0.0715
# Linear Probe Training - Epoch [84/200], Loss: 0.0702
# Linear Probe Training - Epoch [85/200], Loss: 0.0698
# Linear Probe Training - Epoch [86/200], Loss: 0.0690
# Linear Probe Training - Epoch [87/200], Loss: 0.0689
# Linear Probe Training - Epoch [88/200], Loss: 0.0674
# Linear Probe Training - Epoch [89/200], Loss: 0.0662
# Linear Probe Training - Epoch [90/200], Loss: 0.0666
# Linear Probe Training - Epoch [91/200], Loss: 0.0674
# Linear Probe Training - Epoch [92/200], Loss: 0.0663
# Linear Probe Training - Epoch [93/200], Loss: 0.0650
# Linear Probe Training - Epoch [94/200], Loss: 0.0644
# Linear Probe Training - Epoch [95/200], Loss: 0.0636
# Linear Probe Training - Epoch [96/200], Loss: 0.0634
# Linear Probe Training - Epoch [97/200], Loss: 0.0627
# Linear Probe Training - Epoch [98/200], Loss: 0.0622
# Linear Probe Training - Epoch [99/200], Loss: 0.0617
# Linear Probe Training - Epoch [100/200], Loss: 0.0620
# Linear Probe Training - Epoch [101/200], Loss: 0.0614
# Linear Probe Training - Epoch [102/200], Loss: 0.0603
# Linear Probe Training - Epoch [103/200], Loss: 0.0604
# Linear Probe Training - Epoch [104/200], Loss: 0.0613
# Linear Probe Training - Epoch [105/200], Loss: 0.0604
# Linear Probe Training - Epoch [106/200], Loss: 0.0592
# Linear Probe Training - Epoch [107/200], Loss: 0.0591
# Linear Probe Training - Epoch [108/200], Loss: 0.0588
# Linear Probe Training - Epoch [109/200], Loss: 0.0585
# Linear Probe Training - Epoch [110/200], Loss: 0.0590
# Linear Probe Training - Epoch [111/200], Loss: 0.0576
# Linear Probe Training - Epoch [112/200], Loss: 0.0577
# Linear Probe Training - Epoch [113/200], Loss: 0.0574
# Linear Probe Training - Epoch [114/200], Loss: 0.0574
# Linear Probe Training - Epoch [115/200], Loss: 0.0573
# Linear Probe Training - Epoch [116/200], Loss: 0.0567
# Linear Probe Training - Epoch [117/200], Loss: 0.0564
# Linear Probe Training - Epoch [118/200], Loss: 0.0566
# Linear Probe Training - Epoch [119/200], Loss: 0.0566
# Linear Probe Training - Epoch [120/200], Loss: 0.0567
# Linear Probe Training - Epoch [121/200], Loss: 0.0557
# Linear Probe Training - Epoch [122/200], Loss: 0.0572
# Linear Probe Training - Epoch [123/200], Loss: 0.0565
# Linear Probe Training - Epoch [124/200], Loss: 0.0558
# Linear Probe Training - Epoch [125/200], Loss: 0.0552
# Linear Probe Training - Epoch [126/200], Loss: 0.0551
# Linear Probe Training - Epoch [127/200], Loss: 0.0552
# Linear Probe Training - Epoch [128/200], Loss: 0.0551
# Linear Probe Training - Epoch [129/200], Loss: 0.0545
# Linear Probe Training - Epoch [130/200], Loss: 0.0565
# Linear Probe Training - Epoch [131/200], Loss: 0.0546
# Linear Probe Training - Epoch [132/200], Loss: 0.0542
# Linear Probe Training - Epoch [133/200], Loss: 0.0543
# Linear Probe Training - Epoch [134/200], Loss: 0.0542
# Linear Probe Training - Epoch [135/200], Loss: 0.0552
# Linear Probe Training - Epoch [136/200], Loss: 0.0547
# Linear Probe Training - Epoch [137/200], Loss: 0.0544
# Linear Probe Training - Epoch [138/200], Loss: 0.0533
# Linear Probe Training - Epoch [139/200], Loss: 0.0540
# Linear Probe Training - Epoch [140/200], Loss: 0.0537
# Linear Probe Training - Epoch [141/200], Loss: 0.0535
# Linear Probe Training - Epoch [142/200], Loss: 0.0535
# Linear Probe Training - Epoch [143/200], Loss: 0.0530
# Linear Probe Training - Epoch [144/200], Loss: 0.0530
# Linear Probe Training - Epoch [145/200], Loss: 0.0530
# Linear Probe Training - Epoch [146/200], Loss: 0.0534
# Linear Probe Training - Epoch [147/200], Loss: 0.0529
# Linear Probe Training - Epoch [148/200], Loss: 0.0527
# Linear Probe Training - Epoch [149/200], Loss: 0.0526
# Linear Probe Training - Epoch [150/200], Loss: 0.0527
# Linear Probe Training - Epoch [151/200], Loss: 0.0521
# Linear Probe Training - Epoch [152/200], Loss: 0.0532
# Linear Probe Training - Epoch [153/200], Loss: 0.0535
# Linear Probe Training - Epoch [154/200], Loss: 0.0525
# Linear Probe Training - Epoch [155/200], Loss: 0.0525
# Linear Probe Training - Epoch [156/200], Loss: 0.0523
# Linear Probe Training - Epoch [157/200], Loss: 0.0533
# Linear Probe Training - Epoch [158/200], Loss: 0.0522
# Linear Probe Training - Epoch [159/200], Loss: 0.0521
# Linear Probe Training - Epoch [160/200], Loss: 0.0523
# Linear Probe Training - Epoch [161/200], Loss: 0.0528
# Linear Probe Training - Epoch [162/200], Loss: 0.0521
# Linear Probe Training - Epoch [163/200], Loss: 0.0521
# Linear Probe Training - Epoch [164/200], Loss: 0.0522
# Linear Probe Training - Epoch [165/200], Loss: 0.0522
# Linear Probe Training - Epoch [166/200], Loss: 0.0525
# Linear Probe Training - Epoch [167/200], Loss: 0.0519
# Linear Probe Training - Epoch [168/200], Loss: 0.0517
# Linear Probe Training - Epoch [169/200], Loss: 0.0519
# Linear Probe Training - Epoch [170/200], Loss: 0.0525
# Linear Probe Training - Epoch [171/200], Loss: 0.0522
# Linear Probe Training - Epoch [172/200], Loss: 0.0523
# Linear Probe Training - Epoch [173/200], Loss: 0.0520
# Linear Probe Training - Epoch [174/200], Loss: 0.0520
# Linear Probe Training - Epoch [175/200], Loss: 0.0518
# Linear Probe Training - Epoch [176/200], Loss: 0.0518
# Linear Probe Training - Epoch [177/200], Loss: 0.0523
# Linear Probe Training - Epoch [178/200], Loss: 0.0521
# Linear Probe Training - Epoch [179/200], Loss: 0.0515
# Linear Probe Training - Epoch [180/200], Loss: 0.0525
# Linear Probe Training - Epoch [181/200], Loss: 0.0517
# Linear Probe Training - Epoch [182/200], Loss: 0.0526
# Linear Probe Training - Epoch [183/200], Loss: 0.0519
# Linear Probe Training - Epoch [184/200], Loss: 0.0530
# Linear Probe Training - Epoch [185/200], Loss: 0.0514
# Linear Probe Training - Epoch [186/200], Loss: 0.0526
# Linear Probe Training - Epoch [187/200], Loss: 0.0521
# Linear Probe Training - Epoch [188/200], Loss: 0.0510
# Linear Probe Training - Epoch [189/200], Loss: 0.0519
# Linear Probe Training - Epoch [190/200], Loss: 0.0516
# Linear Probe Training - Epoch [191/200], Loss: 0.0513
# Linear Probe Training - Epoch [192/200], Loss: 0.0520
# Linear Probe Training - Epoch [193/200], Loss: 0.0520
# Linear Probe Training - Epoch [194/200], Loss: 0.0524
# Linear Probe Training - Epoch [195/200], Loss: 0.0517
# Linear Probe Training - Epoch [196/200], Loss: 0.0518
# Linear Probe Training - Epoch [197/200], Loss: 0.0515
# Linear Probe Training - Epoch [198/200], Loss: 0.0516
# Linear Probe Training - Epoch [199/200], Loss: 0.0518
# Linear Probe Training - Epoch [200/200], Loss: 0.0522
#
# === Building dataset/model for Beta 2 ===
# Beta Model Training - Epoch [1/200], Loss: 1.7053
# Beta Model Training - Epoch [2/200], Loss: 0.9694
# Beta Model Training - Epoch [3/200], Loss: 0.6259
# Beta Model Training - Epoch [4/200], Loss: 0.5169
# Beta Model Training - Epoch [5/200], Loss: 0.4246
# Beta Model Training - Epoch [6/200], Loss: 0.3638
# Beta Model Training - Epoch [7/200], Loss: 0.3164
# Beta Model Training - Epoch [8/200], Loss: 0.3048
# Beta Model Training - Epoch [9/200], Loss: 0.2842
# Beta Model Training - Epoch [10/200], Loss: 0.2801
# Beta Model Training - Epoch [11/200], Loss: 0.2564
# Beta Model Training - Epoch [12/200], Loss: 0.2476
# Beta Model Training - Epoch [13/200], Loss: 0.2393
# Beta Model Training - Epoch [14/200], Loss: 0.2372
# Beta Model Training - Epoch [15/200], Loss: 0.2333
# Beta Model Training - Epoch [16/200], Loss: 0.2320
# Beta Model Training - Epoch [17/200], Loss: 0.2199
# Beta Model Training - Epoch [18/200], Loss: 0.2137
# Beta Model Training - Epoch [19/200], Loss: 0.2050
# Beta Model Training - Epoch [20/200], Loss: 0.1957
# Beta Model Training - Epoch [21/200], Loss: 0.1829
# Beta Model Training - Epoch [22/200], Loss: 0.1800
# Beta Model Training - Epoch [23/200], Loss: 0.1667
# Beta Model Training - Epoch [24/200], Loss: 0.1648
# Beta Model Training - Epoch [25/200], Loss: 0.1548
# Beta Model Training - Epoch [26/200], Loss: 0.1507
# Beta Model Training - Epoch [27/200], Loss: 0.1472
# Beta Model Training - Epoch [28/200], Loss: 0.1428
# Beta Model Training - Epoch [29/200], Loss: 0.1380
# Beta Model Training - Epoch [30/200], Loss: 0.1372
# Beta Model Training - Epoch [31/200], Loss: 0.1319
# Beta Model Training - Epoch [32/200], Loss: 0.1287
# Beta Model Training - Epoch [33/200], Loss: 0.1247
# Beta Model Training - Epoch [34/200], Loss: 0.1196
# Beta Model Training - Epoch [35/200], Loss: 0.1170
# Beta Model Training - Epoch [36/200], Loss: 0.1141
# Beta Model Training - Epoch [37/200], Loss: 0.1130
# Beta Model Training - Epoch [38/200], Loss: 0.1096
# Beta Model Training - Epoch [39/200], Loss: 0.1084
# Beta Model Training - Epoch [40/200], Loss: 0.1060
# Beta Model Training - Epoch [41/200], Loss: 0.1087
# Beta Model Training - Epoch [42/200], Loss: 0.1034
# Beta Model Training - Epoch [43/200], Loss: 0.1014
# Beta Model Training - Epoch [44/200], Loss: 0.1012
# Beta Model Training - Epoch [45/200], Loss: 0.1036
# Beta Model Training - Epoch [46/200], Loss: 0.1103
# Beta Model Training - Epoch [47/200], Loss: 0.1152
# Beta Model Training - Epoch [48/200], Loss: 0.1153
# Beta Model Training - Epoch [49/200], Loss: 0.1024
# Beta Model Training - Epoch [50/200], Loss: 0.0966
# Beta Model Training - Epoch [51/200], Loss: 0.0907
# Beta Model Training - Epoch [52/200], Loss: 0.0865
# Beta Model Training - Epoch [53/200], Loss: 0.0848
# Beta Model Training - Epoch [54/200], Loss: 0.0838
# Beta Model Training - Epoch [55/200], Loss: 0.0823
# Beta Model Training - Epoch [56/200], Loss: 0.0821
# Beta Model Training - Epoch [57/200], Loss: 0.0808
# Beta Model Training - Epoch [58/200], Loss: 0.0789
# Beta Model Training - Epoch [59/200], Loss: 0.0776
# Beta Model Training - Epoch [60/200], Loss: 0.0786
# Beta Model Training - Epoch [61/200], Loss: 0.0827
# Beta Model Training - Epoch [62/200], Loss: 0.0833
# Beta Model Training - Epoch [63/200], Loss: 0.0823
# Beta Model Training - Epoch [64/200], Loss: 0.0831
# Beta Model Training - Epoch [65/200], Loss: 0.0828
# Beta Model Training - Epoch [66/200], Loss: 0.0799
# Beta Model Training - Epoch [67/200], Loss: 0.0811
# Beta Model Training - Epoch [68/200], Loss: 0.0786
# Beta Model Training - Epoch [69/200], Loss: 0.0831
# Beta Model Training - Epoch [70/200], Loss: 0.0865
# Beta Model Training - Epoch [71/200], Loss: 0.0919
# Beta Model Training - Epoch [72/200], Loss: 0.0834
# Beta Model Training - Epoch [73/200], Loss: 0.0832
# Beta Model Training - Epoch [74/200], Loss: 0.0763
# Beta Model Training - Epoch [75/200], Loss: 0.0748
# Beta Model Training - Epoch [76/200], Loss: 0.0717
# Beta Model Training - Epoch [77/200], Loss: 0.0708
# Beta Model Training - Epoch [78/200], Loss: 0.0683
# Beta Model Training - Epoch [79/200], Loss: 0.0692
# Beta Model Training - Epoch [80/200], Loss: 0.0703
# Beta Model Training - Epoch [81/200], Loss: 0.0730
# Beta Model Training - Epoch [82/200], Loss: 0.0716
# Beta Model Training - Epoch [83/200], Loss: 0.0712
# Beta Model Training - Epoch [84/200], Loss: 0.0704
# Beta Model Training - Epoch [85/200], Loss: 0.0668
# Beta Model Training - Epoch [86/200], Loss: 0.0671
# Beta Model Training - Epoch [87/200], Loss: 0.0700
# Beta Model Training - Epoch [88/200], Loss: 0.0718
# Beta Model Training - Epoch [89/200], Loss: 0.0695
# Beta Model Training - Epoch [90/200], Loss: 0.0675
# Beta Model Training - Epoch [91/200], Loss: 0.0685
# Beta Model Training - Epoch [92/200], Loss: 0.0678
# Beta Model Training - Epoch [93/200], Loss: 0.0642
# Beta Model Training - Epoch [94/200], Loss: 0.0648
# Beta Model Training - Epoch [95/200], Loss: 0.0656
# Beta Model Training - Epoch [96/200], Loss: 0.0629
# Beta Model Training - Epoch [97/200], Loss: 0.0630
# Beta Model Training - Epoch [98/200], Loss: 0.0618
# Beta Model Training - Epoch [99/200], Loss: 0.0614
# Beta Model Training - Epoch [100/200], Loss: 0.0596
# Beta Model Training - Epoch [101/200], Loss: 0.0595
# Beta Model Training - Epoch [102/200], Loss: 0.0601
# Beta Model Training - Epoch [103/200], Loss: 0.0603
# Beta Model Training - Epoch [104/200], Loss: 0.0606
# Beta Model Training - Epoch [105/200], Loss: 0.0594
# Beta Model Training - Epoch [106/200], Loss: 0.0593
# Beta Model Training - Epoch [107/200], Loss: 0.0629
# Beta Model Training - Epoch [108/200], Loss: 0.0654
# Beta Model Training - Epoch [109/200], Loss: 0.0662
# ...
# Beta Model Training - Epoch [99/200], Loss: 0.0257
# Beta Model Training - Epoch [100/200], Loss: 0.0256
# Beta Model Training - Epoch [101/200], Loss: 0.0259
# Beta Model Training - Epoch [102/200], Loss: 0.0258
# Beta Model Training - Epoch [103/200], Loss: 0.0257
# Beta Model Training - Epoch [104/200], Loss: 0.0263
# Beta Model Training - Epoch [105/200], Loss: 0.0259
# Beta Model Training - Epoch [106/200], Loss: 0.0258
# Beta Model Training - Epoch [107/200], Loss: 0.0260
# Beta Model Training - Epoch [108/200], Loss: 0.0270
# Beta Model Training - Epoch [109/200], Loss: 0.0267
# Beta Model Training - Epoch [110/200], Loss: 0.0276
# Beta Model Training - Epoch [111/200], Loss: 0.0304
# Beta Model Training - Epoch [112/200], Loss: 0.0292
# Beta Model Training - Epoch [113/200], Loss: 0.0273
# Beta Model Training - Epoch [114/200], Loss: 0.0257
# Beta Model Training - Epoch [115/200], Loss: 0.0257
# Beta Model Training - Epoch [116/200], Loss: 0.0245
# Beta Model Training - Epoch [117/200], Loss: 0.0246
# Beta Model Training - Epoch [118/200], Loss: 0.0240
# Beta Model Training - Epoch [119/200], Loss: 0.0242
# Beta Model Training - Epoch [120/200], Loss: 0.0242
# Beta Model Training - Epoch [121/200], Loss: 0.0242
# Beta Model Training - Epoch [122/200], Loss: 0.0236
# Beta Model Training - Epoch [123/200], Loss: 0.0234
# Beta Model Training - Epoch [124/200], Loss: 0.0249
# Beta Model Training - Epoch [125/200], Loss: 0.0233
# Beta Model Training - Epoch [126/200], Loss: 0.0244
# Beta Model Training - Epoch [127/200], Loss: 0.0251
# Beta Model Training - Epoch [128/200], Loss: 0.0228
# Beta Model Training - Epoch [129/200], Loss: 0.0221
# Beta Model Training - Epoch [130/200], Loss: 0.0215
# Beta Model Training - Epoch [131/200], Loss: 0.0211
# Beta Model Training - Epoch [132/200], Loss: 0.0209
# Beta Model Training - Epoch [133/200], Loss: 0.0213
# Beta Model Training - Epoch [134/200], Loss: 0.0215
# Beta Model Training - Epoch [135/200], Loss: 0.0219
# Beta Model Training - Epoch [136/200], Loss: 0.0214
# Beta Model Training - Epoch [137/200], Loss: 0.0213
# Beta Model Training - Epoch [138/200], Loss: 0.0210
# Beta Model Training - Epoch [139/200], Loss: 0.0206
# Beta Model Training - Epoch [140/200], Loss: 0.0205
# Beta Model Training - Epoch [141/200], Loss: 0.0203
# Beta Model Training - Epoch [142/200], Loss: 0.0200
# Beta Model Training - Epoch [143/200], Loss: 0.0200
# Beta Model Training - Epoch [144/200], Loss: 0.0202
# Beta Model Training - Epoch [145/200], Loss: 0.0200
# Beta Model Training - Epoch [146/200], Loss: 0.0196
# Beta Model Training - Epoch [147/200], Loss: 0.0195
# Beta Model Training - Epoch [148/200], Loss: 0.0199
# Beta Model Training - Epoch [149/200], Loss: 0.0201
# Beta Model Training - Epoch [150/200], Loss: 0.0200
# Beta Model Training - Epoch [151/200], Loss: 0.0210
# Beta Model Training - Epoch [152/200], Loss: 0.0203
# Beta Model Training - Epoch [153/200], Loss: 0.0218
# Beta Model Training - Epoch [154/200], Loss: 0.0201
# Beta Model Training - Epoch [155/200], Loss: 0.0198
# Beta Model Training - Epoch [156/200], Loss: 0.0202
# Beta Model Training - Epoch [157/200], Loss: 0.0200
# Beta Model Training - Epoch [158/200], Loss: 0.0215
# Beta Model Training - Epoch [159/200], Loss: 0.0213
# Beta Model Training - Epoch [160/200], Loss: 0.0208
# Beta Model Training - Epoch [161/200], Loss: 0.0205
# Beta Model Training - Epoch [162/200], Loss: 0.0205
# Beta Model Training - Epoch [163/200], Loss: 0.0202
# Beta Model Training - Epoch [164/200], Loss: 0.0203
# Beta Model Training - Epoch [165/200], Loss: 0.0202
# Beta Model Training - Epoch [166/200], Loss: 0.0204
# Beta Model Training - Epoch [167/200], Loss: 0.0212
# Beta Model Training - Epoch [168/200], Loss: 0.0214
# Beta Model Training - Epoch [169/200], Loss: 0.0211
# Beta Model Training - Epoch [170/200], Loss: 0.0211
# Beta Model Training - Epoch [171/200], Loss: 0.0212
# Beta Model Training - Epoch [172/200], Loss: 0.0215
# Beta Model Training - Epoch [173/200], Loss: 0.0234
# Beta Model Training - Epoch [174/200], Loss: 0.0219
# Beta Model Training - Epoch [175/200], Loss: 0.0210
# Beta Model Training - Epoch [176/200], Loss: 0.0207
# Beta Model Training - Epoch [177/200], Loss: 0.0202
# Beta Model Training - Epoch [178/200], Loss: 0.0212
# Beta Model Training - Epoch [179/200], Loss: 0.0216
# Beta Model Training - Epoch [180/200], Loss: 0.0305
# Beta Model Training - Epoch [181/200], Loss: 0.0290
# Beta Model Training - Epoch [182/200], Loss: 0.0292
# Beta Model Training - Epoch [183/200], Loss: 0.0436
# Beta Model Training - Epoch [184/200], Loss: 0.0467
# Beta Model Training - Epoch [185/200], Loss: 0.0534
# Beta Model Training - Epoch [186/200], Loss: 0.0387
# Beta Model Training - Epoch [187/200], Loss: 0.0358
# Beta Model Training - Epoch [188/200], Loss: 0.0348
# Beta Model Training - Epoch [189/200], Loss: 0.0309
# Beta Model Training - Epoch [190/200], Loss: 0.0304
# Beta Model Training - Epoch [191/200], Loss: 0.0242
# Beta Model Training - Epoch [192/200], Loss: 0.0217
# Beta Model Training - Epoch [193/200], Loss: 0.0206
# Beta Model Training - Epoch [194/200], Loss: 0.0196
# Beta Model Training - Epoch [195/200], Loss: 0.0187
# Beta Model Training - Epoch [196/200], Loss: 0.0185
# Beta Model Training - Epoch [197/200], Loss: 0.0181
# Beta Model Training - Epoch [198/200], Loss: 0.0176
# Beta Model Training - Epoch [199/200], Loss: 0.0176
# Beta Model Training - Epoch [200/200], Loss: 0.0172
# Linear Probe Training - Epoch [1/200], Loss: 1.8207
# Linear Probe Training - Epoch [2/200], Loss: 1.3252
# Linear Probe Training - Epoch [3/200], Loss: 1.0591
# Linear Probe Training - Epoch [4/200], Loss: 0.9093
# Linear Probe Training - Epoch [5/200], Loss: 0.8168
# Linear Probe Training - Epoch [6/200], Loss: 0.7354
# Linear Probe Training - Epoch [7/200], Loss: 0.6713
# Linear Probe Training - Epoch [8/200], Loss: 0.6081
# Linear Probe Training - Epoch [9/200], Loss: 0.5549
# Linear Probe Training - Epoch [10/200], Loss: 0.5143
# Linear Probe Training - Epoch [11/200], Loss: 0.4706
# Linear Probe Training - Epoch [12/200], Loss: 0.4407
# Linear Probe Training - Epoch [13/200], Loss: 0.4089
# Linear Probe Training - Epoch [14/200], Loss: 0.3836
# Linear Probe Training - Epoch [15/200], Loss: 0.3602
# Linear Probe Training - Epoch [16/200], Loss: 0.3380
# Linear Probe Training - Epoch [17/200], Loss: 0.3184
# Linear Probe Training - Epoch [18/200], Loss: 0.3023
# Linear Probe Training - Epoch [19/200], Loss: 0.2839
# Linear Probe Training - Epoch [20/200], Loss: 0.2705
# Linear Probe Training - Epoch [21/200], Loss: 0.2559
# Linear Probe Training - Epoch [22/200], Loss: 0.2419
# Linear Probe Training - Epoch [23/200], Loss: 0.2303
# Linear Probe Training - Epoch [24/200], Loss: 0.2210
# Linear Probe Training - Epoch [25/200], Loss: 0.2082
# Linear Probe Training - Epoch [26/200], Loss: 0.1974
# Linear Probe Training - Epoch [27/200], Loss: 0.1886
# Linear Probe Training - Epoch [28/200], Loss: 0.1796
# Linear Probe Training - Epoch [29/200], Loss: 0.1712
# Linear Probe Training - Epoch [30/200], Loss: 0.1634
# Linear Probe Training - Epoch [31/200], Loss: 0.1582
# Linear Probe Training - Epoch [32/200], Loss: 0.1506
# Linear Probe Training - Epoch [33/200], Loss: 0.1439
# Linear Probe Training - Epoch [34/200], Loss: 0.1370
# Linear Probe Training - Epoch [35/200], Loss: 0.1317
# Linear Probe Training - Epoch [36/200], Loss: 0.1257
# Linear Probe Training - Epoch [37/200], Loss: 0.1207
# Linear Probe Training - Epoch [38/200], Loss: 0.1162
# Linear Probe Training - Epoch [39/200], Loss: 0.1118
# Linear Probe Training - Epoch [40/200], Loss: 0.1073
# Linear Probe Training - Epoch [41/200], Loss: 0.1041
# Linear Probe Training - Epoch [42/200], Loss: 0.1005
# Linear Probe Training - Epoch [43/200], Loss: 0.0956
# Linear Probe Training - Epoch [44/200], Loss: 0.0929
# Linear Probe Training - Epoch [45/200], Loss: 0.0887
# Linear Probe Training - Epoch [46/200], Loss: 0.0870
# Linear Probe Training - Epoch [47/200], Loss: 0.0836
# Linear Probe Training - Epoch [48/200], Loss: 0.0807
# Linear Probe Training - Epoch [49/200], Loss: 0.0785
# Linear Probe Training - Epoch [50/200], Loss: 0.0767
# Linear Probe Training - Epoch [51/200], Loss: 0.0734
# Linear Probe Training - Epoch [52/200], Loss: 0.0712
# Linear Probe Training - Epoch [53/200], Loss: 0.0688
# Linear Probe Training - Epoch [54/200], Loss: 0.0668
# Linear Probe Training - Epoch [55/200], Loss: 0.0652
# Linear Probe Training - Epoch [56/200], Loss: 0.0637
# Linear Probe Training - Epoch [57/200], Loss: 0.0613
# Linear Probe Training - Epoch [58/200], Loss: 0.0595
# Linear Probe Training - Epoch [59/200], Loss: 0.0582
# Linear Probe Training - Epoch [60/200], Loss: 0.0566
# Linear Probe Training - Epoch [61/200], Loss: 0.0552
# Linear Probe Training - Epoch [62/200], Loss: 0.0540
# Linear Probe Training - Epoch [63/200], Loss: 0.0527
# Linear Probe Training - Epoch [64/200], Loss: 0.0515
# Linear Probe Training - Epoch [65/200], Loss: 0.0503
# Linear Probe Training - Epoch [66/200], Loss: 0.0488
# Linear Probe Training - Epoch [67/200], Loss: 0.0484
# Linear Probe Training - Epoch [68/200], Loss: 0.0472
# Linear Probe Training - Epoch [69/200], Loss: 0.0461
# Linear Probe Training - Epoch [70/200], Loss: 0.0453
# Linear Probe Training - Epoch [71/200], Loss: 0.0447
# Linear Probe Training - Epoch [72/200], Loss: 0.0438
# Linear Probe Training - Epoch [73/200], Loss: 0.0428
# Linear Probe Training - Epoch [74/200], Loss: 0.0417
# Linear Probe Training - Epoch [75/200], Loss: 0.0407
# Linear Probe Training - Epoch [76/200], Loss: 0.0406
# Linear Probe Training - Epoch [77/200], Loss: 0.0397
# Linear Probe Training - Epoch [78/200], Loss: 0.0388
# Linear Probe Training - Epoch [79/200], Loss: 0.0381
# Linear Probe Training - Epoch [80/200], Loss: 0.0374
# Linear Probe Training - Epoch [81/200], Loss: 0.0377
# Linear Probe Training - Epoch [82/200], Loss: 0.0364
# Linear Probe Training - Epoch [83/200], Loss: 0.0359
# Linear Probe Training - Epoch [84/200], Loss: 0.0353
# Linear Probe Training - Epoch [85/200], Loss: 0.0353
# Linear Probe Training - Epoch [86/200], Loss: 0.0348
# Linear Probe Training - Epoch [87/200], Loss: 0.0340
# Linear Probe Training - Epoch [88/200], Loss: 0.0336
# Linear Probe Training - Epoch [89/200], Loss: 0.0331
# Linear Probe Training - Epoch [90/200], Loss: 0.0326
# Linear Probe Training - Epoch [91/200], Loss: 0.0321
# Linear Probe Training - Epoch [92/200], Loss: 0.0315
# Linear Probe Training - Epoch [93/200], Loss: 0.0314
# Linear Probe Training - Epoch [94/200], Loss: 0.0309
# Linear Probe Training - Epoch [95/200], Loss: 0.0303
# Linear Probe Training - Epoch [96/200], Loss: 0.0304
# Linear Probe Training - Epoch [97/200], Loss: 0.0297
# Linear Probe Training - Epoch [98/200], Loss: 0.0295
# Linear Probe Training - Epoch [99/200], Loss: 0.0291
# Linear Probe Training - Epoch [100/200], Loss: 0.0287
# Linear Probe Training - Epoch [101/200], Loss: 0.0286
# Linear Probe Training - Epoch [102/200], Loss: 0.0284
# Linear Probe Training - Epoch [103/200], Loss: 0.0280
# Linear Probe Training - Epoch [104/200], Loss: 0.0277
# Linear Probe Training - Epoch [105/200], Loss: 0.0274
# Linear Probe Training - Epoch [106/200], Loss: 0.0275
# Linear Probe Training - Epoch [107/200], Loss: 0.0272
# Linear Probe Training - Epoch [108/200], Loss: 0.0266
# Linear Probe Training - Epoch [109/200], Loss: 0.0266
# Linear Probe Training - Epoch [110/200], Loss: 0.0264
# Linear Probe Training - Epoch [111/200], Loss: 0.0263
# Linear Probe Training - Epoch [112/200], Loss: 0.0259
# Linear Probe Training - Epoch [113/200], Loss: 0.0257
# Linear Probe Training - Epoch [114/200], Loss: 0.0259
# Linear Probe Training - Epoch [115/200], Loss: 0.0251
# Linear Probe Training - Epoch [116/200], Loss: 0.0252
# Linear Probe Training - Epoch [117/200], Loss: 0.0250
# Linear Probe Training - Epoch [118/200], Loss: 0.0247
# Linear Probe Training - Epoch [119/200], Loss: 0.0246
# Linear Probe Training - Epoch [120/200], Loss: 0.0248
# Linear Probe Training - Epoch [121/200], Loss: 0.0243
# Linear Probe Training - Epoch [122/200], Loss: 0.0240
# Linear Probe Training - Epoch [123/200], Loss: 0.0239
# Linear Probe Training - Epoch [124/200], Loss: 0.0236
# Linear Probe Training - Epoch [125/200], Loss: 0.0234
# Linear Probe Training - Epoch [126/200], Loss: 0.0233
# Linear Probe Training - Epoch [127/200], Loss: 0.0233
# Linear Probe Training - Epoch [128/200], Loss: 0.0230
# Linear Probe Training - Epoch [129/200], Loss: 0.0231
# Linear Probe Training - Epoch [130/200], Loss: 0.0228
# Linear Probe Training - Epoch [131/200], Loss: 0.0227
# Linear Probe Training - Epoch [132/200], Loss: 0.0226
# Linear Probe Training - Epoch [133/200], Loss: 0.0225
# Linear Probe Training - Epoch [134/200], Loss: 0.0222
# Linear Probe Training - Epoch [135/200], Loss: 0.0221
# Linear Probe Training - Epoch [136/200], Loss: 0.0223
# Linear Probe Training - Epoch [137/200], Loss: 0.0220
# Linear Probe Training - Epoch [138/200], Loss: 0.0219
# Linear Probe Training - Epoch [139/200], Loss: 0.0217
# Linear Probe Training - Epoch [140/200], Loss: 0.0217
# Linear Probe Training - Epoch [141/200], Loss: 0.0216
# Linear Probe Training - Epoch [142/200], Loss: 0.0216
# Linear Probe Training - Epoch [143/200], Loss: 0.0215
# Linear Probe Training - Epoch [144/200], Loss: 0.0215
# Linear Probe Training - Epoch [145/200], Loss: 0.0212
# Linear Probe Training - Epoch [146/200], Loss: 0.0212
# Linear Probe Training - Epoch [147/200], Loss: 0.0208
# Linear Probe Training - Epoch [148/200], Loss: 0.0209
# Linear Probe Training - Epoch [149/200], Loss: 0.0212
# Linear Probe Training - Epoch [150/200], Loss: 0.0207
# Linear Probe Training - Epoch [151/200], Loss: 0.0207
# Linear Probe Training - Epoch [152/200], Loss: 0.0204
# Linear Probe Training - Epoch [153/200], Loss: 0.0207
# Linear Probe Training - Epoch [154/200], Loss: 0.0205
# Linear Probe Training - Epoch [155/200], Loss: 0.0207
# Linear Probe Training - Epoch [156/200], Loss: 0.0205
# Linear Probe Training - Epoch [157/200], Loss: 0.0204
# Linear Probe Training - Epoch [158/200], Loss: 0.0203
# Linear Probe Training - Epoch [159/200], Loss: 0.0202
# Linear Probe Training - Epoch [160/200], Loss: 0.0202
# Linear Probe Training - Epoch [161/200], Loss: 0.0200
# Linear Probe Training - Epoch [162/200], Loss: 0.0199
# Linear Probe Training - Epoch [163/200], Loss: 0.0202
# Linear Probe Training - Epoch [164/200], Loss: 0.0198
# Linear Probe Training - Epoch [165/200], Loss: 0.0198
# Linear Probe Training - Epoch [166/200], Loss: 0.0197
# Linear Probe Training - Epoch [167/200], Loss: 0.0202
# Linear Probe Training - Epoch [168/200], Loss: 0.0196
# Linear Probe Training - Epoch [169/200], Loss: 0.0197
# Linear Probe Training - Epoch [170/200], Loss: 0.0196
# Linear Probe Training - Epoch [171/200], Loss: 0.0195
# Linear Probe Training - Epoch [172/200], Loss: 0.0197
# Linear Probe Training - Epoch [173/200], Loss: 0.0192
# Linear Probe Training - Epoch [174/200], Loss: 0.0194
# Linear Probe Training - Epoch [175/200], Loss: 0.0194
# Linear Probe Training - Epoch [176/200], Loss: 0.0193
# Linear Probe Training - Epoch [177/200], Loss: 0.0194
# Linear Probe Training - Epoch [178/200], Loss: 0.0193
# Linear Probe Training - Epoch [179/200], Loss: 0.0193
# Linear Probe Training - Epoch [180/200], Loss: 0.0193
# Linear Probe Training - Epoch [181/200], Loss: 0.0192
# Linear Probe Training - Epoch [182/200], Loss: 0.0189
# Linear Probe Training - Epoch [183/200], Loss: 0.0189
# Linear Probe Training - Epoch [184/200], Loss: 0.0192
# Linear Probe Training - Epoch [185/200], Loss: 0.0190
# Linear Probe Training - Epoch [186/200], Loss: 0.0189
# Linear Probe Training - Epoch [187/200], Loss: 0.0194
# Linear Probe Training - Epoch [188/200], Loss: 0.0191
# Linear Probe Training - Epoch [189/200], Loss: 0.0186
# Linear Probe Training - Epoch [190/200], Loss: 0.0188
# Linear Probe Training - Epoch [191/200], Loss: 0.0189
# Linear Probe Training - Epoch [192/200], Loss: 0.0189
# Linear Probe Training - Epoch [193/200], Loss: 0.0188
# Linear Probe Training - Epoch [194/200], Loss: 0.0187
# Linear Probe Training - Epoch [195/200], Loss: 0.0188
# Linear Probe Training - Epoch [196/200], Loss: 0.0188
# Linear Probe Training - Epoch [197/200], Loss: 0.0185
# Linear Probe Training - Epoch [198/200], Loss: 0.0185
# Linear Probe Training - Epoch [199/200], Loss: 0.0186
# Linear Probe Training - Epoch [200/200], Loss: 0.0184

# %%
save_dir = os.path.join(analysis_type, 'Linear Probing Results')
os.makedirs(save_dir, exist_ok=True)

# %%
import matplotlib.pyplot as plt

for iBeta in range(nBeta):
    err_o = ori_error_all[iBeta]  # [nSubject, nChan, nTime]
    err_l = linPro_error_all[iBeta]
    mean_err_o = np.mean(np.abs(err_o))
    mean_err_l = np.mean(np.abs(err_l))
    print(f"Beta {iBeta+1} Mean Absolute Error:")
    print(f"Original GAE: {mean_err_o:.6f}")
    print(f"Linear Probing: {mean_err_l:.6f}")
    
    time_mae_o = np.abs(err_o).mean(axis=(0, 1))
    time_mae_l = np.abs(err_l).mean(axis=(0, 1))
    
    plt.figure(figsize=(16,13))
    plt.plot(time_mae_o, label='Original GAE')
    plt.plot(time_mae_l, label='Linear Probing')
    plt.xlabel('Time')
    plt.ylabel('MAE')
    plt.title(f'Beta {iBeta+1} MAE of original GAE and Linear Probing over Time')
    plt.legend()
    plt.tight_layout()
    plt.savefig(os.path.join(save_dir, f'Beta_{iBeta+1}.png'))
    plt.close()
    
    print(f"Saved plot for Beta {iBeta+1}.\n")
# Out:
# Beta 1 Mean Absolute Error:
# Original GAE: 0.243736
# Linear Probing: 0.240976
# Saved plot for Beta 1.
#
# Beta 2 Mean Absolute Error:
# Original GAE: 0.226487
# Linear Probing: 0.231642
# Saved plot for Beta 2.
#
# Beta 3 Mean Absolute Error:
# Original GAE: 0.214203
# Linear Probing: 0.228838
# Saved plot for Beta 3.
#
# Beta 4 Mean Absolute Error:
# Original GAE: 0.244821
# Linear Probing: 0.256750
# Saved plot for Beta 4.
#
# Beta 5 Mean Absolute Error:
# Original GAE: 0.140942
# Linear Probing: 0.141783
# Saved plot for Beta 5.
