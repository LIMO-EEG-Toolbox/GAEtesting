# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset, ConcatDataset
from torch_geometric.loader import DataLoader as GeometricDataLoader
from torch_geometric.data import Data
from torch_geometric.utils import dense_to_sparse
import torch_geometric.nn as pyg_nn
import os
import matplotlib.pyplot as plt
from scipy.io import loadmat, savemat

# %%
# Load saved beta data from mat files
analysis_type = 'N170'
curr_dir = os.getcwd()
datain_mat = loadmat(os.path.join(curr_dir, analysis_type + '_data.mat'))
binatry_matrix_mat = loadmat(os.path.join(curr_dir, 'adjacency_matrix.mat'))
datain = datain_mat['data']
binatry_matrix = binatry_matrix_mat['adjacency_matrix']

datain = np.array(datain)          # shape: [nBeta, nTime, nChan, nSubject] (adjust as needed)
binatry_matrix = np.array(binatry_matrix)

# Parse shapes
nBeta     = datain.shape[0]
nTime     = datain.shape[1]
nChan     = datain.shape[2]
nSubject  = datain.shape[3]

# %%
# ===========================================
# 2) Set device & convert adjacency
# ===========================================
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
edge_index, _ = dense_to_sparse(torch.tensor(binatry_matrix, dtype=torch.float32))
print(device)

# ===========================================
# 3) Dataset builder
# ===========================================
def build_concat_dataset_for_beta(datain, beta_idx):
    """
    Build a ConcatDataset across all subjects for one beta index.
    `datain` is [nBeta, nTime, nChan, nSubject].
    Returns: ConcatDataset of length nSubject.
    """
    subject_datasets = []
    for s in range(nSubject):
        # Extract slice for one subject and one beta
        # shape: [nTime, nChan]
        single_beta_data = datain[beta_idx, :, :, s]

        # If each node is a channel and its feature dimension is time,
        # we might want single_beta_data to be [nChan, nTime].
        # If so, transpose here:
        single_beta_data = single_beta_data.T  # shape: [nChan, nTime]

        # For an autoencoder, features=labels
        x_tensor = torch.tensor(single_beta_data, dtype=torch.float32)
        x_tensor = x_tensor.unsqueeze(0)

        subject_datasets.append(TensorDataset(x_tensor, x_tensor))

    return ConcatDataset(subject_datasets)
# Out:
# cuda

# %%
# ===========================================
# 4) PyG Graph Dataset
# ===========================================
class EEGGraphDataset(torch.utils.data.Dataset):
    """
    Wraps a standard dataset so that each item is a PyG Data object:
      x -> node features (channels)
      edge_index -> adjacency
    """
    def __init__(self, eeg_data, edge_index):
        self.eeg_data = eeg_data
        self.edge_index = edge_index

    def __len__(self):
        return len(self.eeg_data)

    def __getitem__(self, idx):
        # item: (x, x) because it's autoencoder
        sample = self.eeg_data[idx]
        x = sample[0]  # shape: [nChan, nTime] (if you used transpose above)
        # Convert x -> float32, build PyG Data
        graph_data = Data(x=torch.tensor(x, dtype=torch.float32),
                          edge_index=self.edge_index)
        return graph_data

# %%
# ===========================================
# 5) Define GraphAutoencoder
# ===========================================
class GraphAutoencoder(nn.Module):
    def __init__(self, num_features, embedding_dim=64):
        """
        num_features = dimension of each node's feature vector.
                       If each channel is a node, and you pass
                       [nChan, nTime], then num_features = nTime.
        """
        super(GraphAutoencoder, self).__init__()
        # Example with two ARMAConv layers
        self.encoder_gcn1 = pyg_nn.ARMAConv(num_features, 128, 
                                            num_stacks=2, 
                                            num_layers=3,
                                            shared_weights=True)
        self.encoder_gcn2 = pyg_nn.ARMAConv(128, embedding_dim, 
                                            num_stacks=2, 
                                            num_layers=3,
                                            shared_weights=True)
        self.decoder_fc1 = nn.Linear(embedding_dim, 128)
        self.decoder_fc2 = nn.Linear(128, num_features)

    # def forward(self, x, edge_index):
    #     x = torch.relu(self.encoder_gcn1(x, edge_index))
    #     latent = torch.relu(self.encoder_gcn2(x, edge_index))
    #     x = torch.relu(self.decoder_fc1(latent))
    #     reconstructed = self.decoder_fc2(x)
    #     return reconstructed
    
    def encode(self, x, edge_index):
        x = torch.relu(self.encoder_gcn1(x, edge_index))
        latent = torch.relu(self.encoder_gcn2(x, edge_index))
        return latent
    
    def decode(self, latent):
        x = torch.relu(self.decoder_fc1(latent))
        reconstructed = self.decoder_fc2(x)
        return reconstructed
    
    def forward(self, x, edge_index):
        latent = self.encode(x, edge_index)
        reconstructed = self.decode(latent)
        return reconstructed, latent

# %%
# ===========================================
# 6) Training and evaluation
# ===========================================
def train_model_all(model, train_loader, device, num_epochs):
    model.to(device)
    optimizer = optim.Adam(model.parameters(), lr=1e-3)
    criterion = nn.SmoothL1Loss()

    for epoch in range(num_epochs):
        model.train()
        epoch_loss = 0.0
        for batch_data in train_loader:
            batch_data = batch_data.to(device)
            optimizer.zero_grad()

            # Forward
            reconstructed, _ = model(batch_data.x, batch_data.edge_index)
            loss = criterion(reconstructed, batch_data.x)

            # Backprop
            loss.backward()
            optimizer.step()
            epoch_loss += loss.item()

        epoch_loss /= len(train_loader)
        print(f"Beta Model Training - Epoch [{epoch+1}/{num_epochs}], Loss: {epoch_loss:.4f}")
    return model

def evaluation_model(model, data_sample, edge_index, device):
    """
    data_sample: shape [nChan, nTime], or [nTime, nChan],
                 whichever you used in training.
    Returns: (original_np, reconstructed_np, error_np)
    """
    model.eval()
    with torch.no_grad():
        x = torch.tensor(data_sample, dtype=torch.float32, device=device)
        eidx = edge_index.to(device)
        reconstructed, _ = model(x, eidx)
    orig = x.cpu().numpy()
    recon = reconstructed.cpu().numpy()
    error = orig - recon
    return orig, recon, error

# %%
# LinearProbing part

# Define a simple linear layer probe without activation function as
class LinearProbe(nn.Module):
    def __init__(self, embedding_dim, num_features):
        super().__init__()
        self.probe = nn.Linear(embedding_dim, num_features, bias=True)

    def forward(self, x):
        return self.probe(x)


# Train linear probe using frozen GAE latent representations
def train_linear_probe(model, train_loader, device, embedding_dim, num_features, num_epochs):
    # Freeze GAE model parameters
    model.eval()
    for param in model.parameters():
        param.requires_grad = False
        
    linear_probe = LinearProbe(embedding_dim, num_features).to(device)
    optimizer = optim.Adam(linear_probe.parameters(), lr=1e-3)
    criterion = nn.SmoothL1Loss()
    
    for epoch in range(num_epochs):
        linear_probe.train()
        epoch_loss = 0.0
        for batch_data in train_loader:
            batch_data = batch_data.to(device)
            optimizer.zero_grad()
            
            # Get latent representations from frozen GAE
            with torch.no_grad():
                latent = model.encode(batch_data.x, batch_data.edge_index)
            
            lin_reconstructed = linear_probe(latent)
            loss = criterion(lin_reconstructed, batch_data.x)

            loss.backward()
            optimizer.step()
            epoch_loss += loss.item()

        epoch_loss /= len(train_loader)
        print(f"Linear Probe Training - Epoch [{epoch+1}/{num_epochs}], Loss: {epoch_loss:.4f}")

    return linear_probe

def evaluation_linear_probe(model, linear_probe, data_sample, edge_index, device):
    model.eval()
    linear_probe.eval()
    with torch.no_grad():
        x = torch.tensor(data_sample, dtype=torch.float32, device=device)
        eidx = edge_index.to(device)
        latent_repr = model.encode(x, eidx)
        lin_reconstructed = linear_probe(latent_repr)
    orig = x.cpu().numpy()
    recon = lin_reconstructed.cpu().numpy()
    error = orig - recon
    return orig, recon, error

# %%
# ===========================================
# 7) Main pipeline
#    1) For each beta, build dataset/loader.
#    2) Initialize & train a separate model.
#    3) Reconstruct each subject's data for that beta.
#    4) Store reconstruction in a final array.
# ===========================================

num_features = nTime   # if each channel is a node, and feature vector = [nTime]
num_epochs   = 200     # number of training - set as needed
batch_size   = 4;      # dataset/batch to update hyperparameters

models = []
ori_reconstructed_list = []  # will hold arrays of shape [nSubject, nChan, nTime] for each beta
linPro_reconstructed_list = []
ori_error_list = []
linPro_error_list = []

for iBeta in range(nBeta):
    print(f"\n=== Building dataset/model for Beta {iBeta} ===")
    # Build dataset & loader
    full_dataset_i  = build_concat_dataset_for_beta(datain, iBeta)
    graph_dataset_i = EEGGraphDataset(full_dataset_i, edge_index)
    full_loader_i   = GeometricDataLoader(graph_dataset_i, batch_size=batch_size, shuffle=True)

    # Init model & train
    model_i = GraphAutoencoder(num_features=num_features, embedding_dim=32)
    model_i = train_model_all(model_i, full_loader_i, device, num_epochs=num_epochs)
    models.append(model_i)

    # Train linear probe
    linPro_model = train_linear_probe(model_i, full_loader_i, device, embedding_dim=32, num_features=num_features, num_epochs=num_epochs)

    # Error evaluation original GAE vs Linear Probing for all subjects
    ori_error_per_subject = []
    linPro_error_per_subject = []
    
    ori_recon_per_subject = []
    linPro_recon_per_subject = []
    
    for s in range(len(full_dataset_i)):
        data_s = full_dataset_i[s][0].numpy()  # [nChan, nTime]
        _, recon_o, error_o = evaluation_model(model_i, data_s, edge_index, device)
        _, recon_l, error_l = evaluation_linear_probe(model_i, linPro_model, data_s, edge_index, device)
        
        ori_error_per_subject.append(error_o)
        linPro_error_per_subject.append(error_l)
        
        ori_recon_per_subject.append(recon_o)  # shape [nChan, nTime]
        linPro_recon_per_subject.append(recon_l)
        

    ori_error_list.append(np.array(ori_error_per_subject))
    linPro_error_list.append(np.array(linPro_error_per_subject))

    ori_reconstructed_list.append(np.array(ori_recon_per_subject))
    linPro_reconstructed_list.append(np.array(linPro_recon_per_subject))

ori_reconstructed_all = np.array(ori_reconstructed_list)  # [nBeta, nSubject, nChan, nTime]
linPro_reconstructed_all = np.array(linPro_reconstructed_list)
ori_error_all = np.array(ori_error_list)  # [nBeta, nSubject, nChan, nTime]
linPro_error_all = np.array(linPro_error_list)
# Out:
# === Building dataset/model for Beta 0 ===
# C:\Users\86136\AppData\Local\Temp\ipykernel_5704\1382389434.py:22: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   graph_data = Data(x=torch.tensor(x, dtype=torch.float32),
# Beta Model Training - Epoch [1/200], Loss: 0.7576
# Beta Model Training - Epoch [2/200], Loss: 0.5700
# Beta Model Training - Epoch [3/200], Loss: 0.4366
# Beta Model Training - Epoch [4/200], Loss: 0.3865
# Beta Model Training - Epoch [5/200], Loss: 0.3514
# Beta Model Training - Epoch [6/200], Loss: 0.3275
# Beta Model Training - Epoch [7/200], Loss: 0.3075
# Beta Model Training - Epoch [8/200], Loss: 0.2875
# Beta Model Training - Epoch [9/200], Loss: 0.2675
# Beta Model Training - Epoch [10/200], Loss: 0.2474
# Beta Model Training - Epoch [11/200], Loss: 0.2294
# Beta Model Training - Epoch [12/200], Loss: 0.2134
# Beta Model Training - Epoch [13/200], Loss: 0.2028
# Beta Model Training - Epoch [14/200], Loss: 0.1920
# Beta Model Training - Epoch [15/200], Loss: 0.1821
# Beta Model Training - Epoch [16/200], Loss: 0.1721
# Beta Model Training - Epoch [17/200], Loss: 0.1664
# Beta Model Training - Epoch [18/200], Loss: 0.1624
# Beta Model Training - Epoch [19/200], Loss: 0.1555
# Beta Model Training - Epoch [20/200], Loss: 0.1523
# Beta Model Training - Epoch [21/200], Loss: 0.1486
# Beta Model Training - Epoch [22/200], Loss: 0.1457
# Beta Model Training - Epoch [23/200], Loss: 0.1431
# Beta Model Training - Epoch [24/200], Loss: 0.1387
# Beta Model Training - Epoch [25/200], Loss: 0.1336
# Beta Model Training - Epoch [26/200], Loss: 0.1291
# Beta Model Training - Epoch [27/200], Loss: 0.1264
# Beta Model Training - Epoch [28/200], Loss: 0.1230
# Beta Model Training - Epoch [29/200], Loss: 0.1204
# Beta Model Training - Epoch [30/200], Loss: 0.1190
# Beta Model Training - Epoch [31/200], Loss: 0.1159
# Beta Model Training - Epoch [32/200], Loss: 0.1129
# Beta Model Training - Epoch [33/200], Loss: 0.1124
# Beta Model Training - Epoch [34/200], Loss: 0.1155
# Beta Model Training - Epoch [35/200], Loss: 0.1184
# Beta Model Training - Epoch [36/200], Loss: 0.1169
# Beta Model Training - Epoch [37/200], Loss: 0.1086
# Beta Model Training - Epoch [38/200], Loss: 0.1085
# Beta Model Training - Epoch [39/200], Loss: 0.1120
# Beta Model Training - Epoch [40/200], Loss: 0.1037
# Beta Model Training - Epoch [41/200], Loss: 0.1034
# Beta Model Training - Epoch [42/200], Loss: 0.1055
# Beta Model Training - Epoch [43/200], Loss: 0.1016
# Beta Model Training - Epoch [44/200], Loss: 0.1019
# Beta Model Training - Epoch [45/200], Loss: 0.0997
# Beta Model Training - Epoch [46/200], Loss: 0.0978
# Beta Model Training - Epoch [47/200], Loss: 0.0948
# Beta Model Training - Epoch [48/200], Loss: 0.0927
# Beta Model Training - Epoch [49/200], Loss: 0.0889
# Beta Model Training - Epoch [50/200], Loss: 0.0868
# Beta Model Training - Epoch [51/200], Loss: 0.0845
# Beta Model Training - Epoch [52/200], Loss: 0.0826
# Beta Model Training - Epoch [53/200], Loss: 0.0826
# Beta Model Training - Epoch [54/200], Loss: 0.0805
# Beta Model Training - Epoch [55/200], Loss: 0.0795
# Beta Model Training - Epoch [56/200], Loss: 0.0786
# Beta Model Training - Epoch [57/200], Loss: 0.0786
# Beta Model Training - Epoch [58/200], Loss: 0.0771
# Beta Model Training - Epoch [59/200], Loss: 0.0769
# Beta Model Training - Epoch [60/200], Loss: 0.0757
# Beta Model Training - Epoch [61/200], Loss: 0.0748
# Beta Model Training - Epoch [62/200], Loss: 0.0747
# Beta Model Training - Epoch [63/200], Loss: 0.0745
# Beta Model Training - Epoch [64/200], Loss: 0.0737
# Beta Model Training - Epoch [65/200], Loss: 0.0738
# Beta Model Training - Epoch [66/200], Loss: 0.0722
# Beta Model Training - Epoch [67/200], Loss: 0.0718
# Beta Model Training - Epoch [68/200], Loss: 0.0723
# Beta Model Training - Epoch [69/200], Loss: 0.0732
# Beta Model Training - Epoch [70/200], Loss: 0.0715
# Beta Model Training - Epoch [71/200], Loss: 0.0706
# Beta Model Training - Epoch [72/200], Loss: 0.0732
# Beta Model Training - Epoch [73/200], Loss: 0.0717
# Beta Model Training - Epoch [74/200], Loss: 0.0730
# Beta Model Training - Epoch [75/200], Loss: 0.0717
# Beta Model Training - Epoch [76/200], Loss: 0.0708
# Beta Model Training - Epoch [77/200], Loss: 0.0739
# Beta Model Training - Epoch [78/200], Loss: 0.0707
# Beta Model Training - Epoch [79/200], Loss: 0.0688
# Beta Model Training - Epoch [80/200], Loss: 0.0679
# Beta Model Training - Epoch [81/200], Loss: 0.0668
# Beta Model Training - Epoch [82/200], Loss: 0.0673
# Beta Model Training - Epoch [83/200], Loss: 0.0698
# Beta Model Training - Epoch [84/200], Loss: 0.0714
# Beta Model Training - Epoch [85/200], Loss: 0.0663
# Beta Model Training - Epoch [86/200], Loss: 0.0668
# Beta Model Training - Epoch [87/200], Loss: 0.0661
# Beta Model Training - Epoch [88/200], Loss: 0.0648
# Beta Model Training - Epoch [89/200], Loss: 0.0648
# Beta Model Training - Epoch [90/200], Loss: 0.0654
# Beta Model Training - Epoch [91/200], Loss: 0.0665
# Beta Model Training - Epoch [92/200], Loss: 0.0716
# Beta Model Training - Epoch [93/200], Loss: 0.0671
# Beta Model Training - Epoch [94/200], Loss: 0.0656
# Beta Model Training - Epoch [95/200], Loss: 0.0656
# Beta Model Training - Epoch [96/200], Loss: 0.0635
# Beta Model Training - Epoch [97/200], Loss: 0.0630
# Beta Model Training - Epoch [98/200], Loss: 0.0622
# Beta Model Training - Epoch [99/200], Loss: 0.0638
# Beta Model Training - Epoch [100/200], Loss: 0.0614
# Beta Model Training - Epoch [101/200], Loss: 0.0605
# Beta Model Training - Epoch [102/200], Loss: 0.0600
# Beta Model Training - Epoch [103/200], Loss: 0.0607
# Beta Model Training - Epoch [104/200], Loss: 0.0603
# Beta Model Training - Epoch [105/200], Loss: 0.0604
# Beta Model Training - Epoch [106/200], Loss: 0.0597
# Beta Model Training - Epoch [107/200], Loss: 0.0607
# Beta Model Training - Epoch [108/200], Loss: 0.0594
# Beta Model Training - Epoch [109/200], Loss: 0.0593
# Beta Model Training - Epoch [110/200], Loss: 0.0583
# Beta Model Training - Epoch [111/200], Loss: 0.0579
# Beta Model Training - Epoch [112/200], Loss: 0.0572
# Beta Model Training - Epoch [113/200], Loss: 0.0582
# Beta Model Training - Epoch [114/200], Loss: 0.0572
# Beta Model Training - Epoch [115/200], Loss: 0.0573
# Beta Model Training - Epoch [116/200], Loss: 0.0569
# Beta Model Training - Epoch [117/200], Loss: 0.0565
# Beta Model Training - Epoch [118/200], Loss: 0.0565
# Beta Model Training - Epoch [119/200], Loss: 0.0585
# Beta Model Training - Epoch [120/200], Loss: 0.0598
# Beta Model Training - Epoch [121/200], Loss: 0.0586
# Beta Model Training - Epoch [122/200], Loss: 0.0600
# Beta Model Training - Epoch [123/200], Loss: 0.0600
# Beta Model Training - Epoch [124/200], Loss: 0.0582
# Beta Model Training - Epoch [125/200], Loss: 0.0578
# Beta Model Training - Epoch [126/200], Loss: 0.0591
# Beta Model Training - Epoch [127/200], Loss: 0.0572
# Beta Model Training - Epoch [128/200], Loss: 0.0561
# Beta Model Training - Epoch [129/200], Loss: 0.0562
# Beta Model Training - Epoch [130/200], Loss: 0.0551
# Beta Model Training - Epoch [131/200], Loss: 0.0560
# Beta Model Training - Epoch [132/200], Loss: 0.0565
# Beta Model Training - Epoch [133/200], Loss: 0.0564
# Beta Model Training - Epoch [134/200], Loss: 0.0563
# Beta Model Training - Epoch [135/200], Loss: 0.0566
# Beta Model Training - Epoch [136/200], Loss: 0.0549
# Beta Model Training - Epoch [137/200], Loss: 0.0550
# Beta Model Training - Epoch [138/200], Loss: 0.0559
# Beta Model Training - Epoch [139/200], Loss: 0.0590
# Beta Model Training - Epoch [140/200], Loss: 0.0560
# Beta Model Training - Epoch [141/200], Loss: 0.0568
# Beta Model Training - Epoch [142/200], Loss: 0.0542
# Beta Model Training - Epoch [143/200], Loss: 0.0535
# Beta Model Training - Epoch [144/200], Loss: 0.0528
# Beta Model Training - Epoch [145/200], Loss: 0.0522
# Beta Model Training - Epoch [146/200], Loss: 0.0534
# Beta Model Training - Epoch [147/200], Loss: 0.0525
# Beta Model Training - Epoch [148/200], Loss: 0.0523
# Beta Model Training - Epoch [149/200], Loss: 0.0518
# Beta Model Training - Epoch [150/200], Loss: 0.0526
# Beta Model Training - Epoch [151/200], Loss: 0.0524
# Beta Model Training - Epoch [152/200], Loss: 0.0512
# Beta Model Training - Epoch [153/200], Loss: 0.0512
# Beta Model Training - Epoch [154/200], Loss: 0.0511
# Beta Model Training - Epoch [155/200], Loss: 0.0515
# Beta Model Training - Epoch [156/200], Loss: 0.0506
# Beta Model Training - Epoch [157/200], Loss: 0.0508
# Beta Model Training - Epoch [158/200], Loss: 0.0534
# Beta Model Training - Epoch [159/200], Loss: 0.0544
# Beta Model Training - Epoch [160/200], Loss: 0.0511
# Beta Model Training - Epoch [161/200], Loss: 0.0513
# Beta Model Training - Epoch [162/200], Loss: 0.0514
# Beta Model Training - Epoch [163/200], Loss: 0.0519
# Beta Model Training - Epoch [164/200], Loss: 0.0519
# Beta Model Training - Epoch [165/200], Loss: 0.0506
# Beta Model Training - Epoch [166/200], Loss: 0.0504
# Beta Model Training - Epoch [167/200], Loss: 0.0504
# Beta Model Training - Epoch [168/200], Loss: 0.0505
# Beta Model Training - Epoch [169/200], Loss: 0.0506
# Beta Model Training - Epoch [170/200], Loss: 0.0513
# Beta Model Training - Epoch [171/200], Loss: 0.0506
# Beta Model Training - Epoch [172/200], Loss: 0.0506
# Beta Model Training - Epoch [173/200], Loss: 0.0501
# Beta Model Training - Epoch [174/200], Loss: 0.0496
# Beta Model Training - Epoch [175/200], Loss: 0.0502
# Beta Model Training - Epoch [176/200], Loss: 0.0511
# Beta Model Training - Epoch [177/200], Loss: 0.0502
# Beta Model Training - Epoch [178/200], Loss: 0.0557
# Beta Model Training - Epoch [179/200], Loss: 0.0592
# Beta Model Training - Epoch [180/200], Loss: 0.0603
# Beta Model Training - Epoch [181/200], Loss: 0.0577
# Beta Model Training - Epoch [182/200], Loss: 0.0540
# Beta Model Training - Epoch [183/200], Loss: 0.0538
# Beta Model Training - Epoch [184/200], Loss: 0.0531
# Beta Model Training - Epoch [185/200], Loss: 0.0520
# Beta Model Training - Epoch [186/200], Loss: 0.0526
# Beta Model Training - Epoch [187/200], Loss: 0.0536
# Beta Model Training - Epoch [188/200], Loss: 0.0634
# Beta Model Training - Epoch [189/200], Loss: 0.0569
# Beta Model Training - Epoch [190/200], Loss: 0.0537
# Beta Model Training - Epoch [191/200], Loss: 0.0525
# Beta Model Training - Epoch [192/200], Loss: 0.0517
# Beta Model Training - Epoch [193/200], Loss: 0.0502
# Beta Model Training - Epoch [194/200], Loss: 0.0491
# Beta Model Training - Epoch [195/200], Loss: 0.0502
# Beta Model Training - Epoch [196/200], Loss: 0.0485
# Beta Model Training - Epoch [197/200], Loss: 0.0480
# Beta Model Training - Epoch [198/200], Loss: 0.0479
# Beta Model Training - Epoch [199/200], Loss: 0.0481
# Beta Model Training - Epoch [200/200], Loss: 0.0484
# Linear Probe Training - Epoch [1/200], Loss: 1.9857
# Linear Probe Training - Epoch [2/200], Loss: 1.4452
# Linear Probe Training - Epoch [3/200], Loss: 1.1710
# Linear Probe Training - Epoch [4/200], Loss: 1.0249
# Linear Probe Training - Epoch [5/200], Loss: 0.9374
# Linear Probe Training - Epoch [6/200], Loss: 0.8674
# Linear Probe Training - Epoch [7/200], Loss: 0.7963
# Linear Probe Training - Epoch [8/200], Loss: 0.7440
# Linear Probe Training - Epoch [9/200], Loss: 0.6992
# Linear Probe Training - Epoch [10/200], Loss: 0.6640
# Linear Probe Training - Epoch [11/200], Loss: 0.6121
# Linear Probe Training - Epoch [12/200], Loss: 0.5826
# Linear Probe Training - Epoch [13/200], Loss: 0.5414
# Linear Probe Training - Epoch [14/200], Loss: 0.5220
# Linear Probe Training - Epoch [15/200], Loss: 0.4928
# Linear Probe Training - Epoch [16/200], Loss: 0.4649
# Linear Probe Training - Epoch [17/200], Loss: 0.4419
# Linear Probe Training - Epoch [18/200], Loss: 0.4166
# Linear Probe Training - Epoch [19/200], Loss: 0.4002
# Linear Probe Training - Epoch [20/200], Loss: 0.3772
# Linear Probe Training - Epoch [21/200], Loss: 0.3614
# Linear Probe Training - Epoch [22/200], Loss: 0.3444
# Linear Probe Training - Epoch [23/200], Loss: 0.3265
# Linear Probe Training - Epoch [24/200], Loss: 0.3132
# Linear Probe Training - Epoch [25/200], Loss: 0.3022
# Linear Probe Training - Epoch [26/200], Loss: 0.2889
# Linear Probe Training - Epoch [27/200], Loss: 0.2750
# Linear Probe Training - Epoch [28/200], Loss: 0.2644
# Linear Probe Training - Epoch [29/200], Loss: 0.2536
# Linear Probe Training - Epoch [30/200], Loss: 0.2421
# Linear Probe Training - Epoch [31/200], Loss: 0.2324
# Linear Probe Training - Epoch [32/200], Loss: 0.2226
# Linear Probe Training - Epoch [33/200], Loss: 0.2134
# Linear Probe Training - Epoch [34/200], Loss: 0.2059
# Linear Probe Training - Epoch [35/200], Loss: 0.1969
# Linear Probe Training - Epoch [36/200], Loss: 0.1907
# Linear Probe Training - Epoch [37/200], Loss: 0.1816
# Linear Probe Training - Epoch [38/200], Loss: 0.1774
# Linear Probe Training - Epoch [39/200], Loss: 0.1690
# Linear Probe Training - Epoch [40/200], Loss: 0.1636
# Linear Probe Training - Epoch [41/200], Loss: 0.1580
# Linear Probe Training - Epoch [42/200], Loss: 0.1524
# Linear Probe Training - Epoch [43/200], Loss: 0.1493
# Linear Probe Training - Epoch [44/200], Loss: 0.1440
# Linear Probe Training - Epoch [45/200], Loss: 0.1391
# Linear Probe Training - Epoch [46/200], Loss: 0.1343
# Linear Probe Training - Epoch [47/200], Loss: 0.1292
# Linear Probe Training - Epoch [48/200], Loss: 0.1264
# Linear Probe Training - Epoch [49/200], Loss: 0.1248
# Linear Probe Training - Epoch [50/200], Loss: 0.1204
# Linear Probe Training - Epoch [51/200], Loss: 0.1165
# Linear Probe Training - Epoch [52/200], Loss: 0.1124
# Linear Probe Training - Epoch [53/200], Loss: 0.1099
# Linear Probe Training - Epoch [54/200], Loss: 0.1074
# Linear Probe Training - Epoch [55/200], Loss: 0.1041
# Linear Probe Training - Epoch [56/200], Loss: 0.1014
# Linear Probe Training - Epoch [57/200], Loss: 0.0998
# Linear Probe Training - Epoch [58/200], Loss: 0.0966
# Linear Probe Training - Epoch [59/200], Loss: 0.0949
# Linear Probe Training - Epoch [60/200], Loss: 0.0931
# Linear Probe Training - Epoch [61/200], Loss: 0.0911
# Linear Probe Training - Epoch [62/200], Loss: 0.0889
# Linear Probe Training - Epoch [63/200], Loss: 0.0879
# Linear Probe Training - Epoch [64/200], Loss: 0.0866
# Linear Probe Training - Epoch [65/200], Loss: 0.0841
# Linear Probe Training - Epoch [66/200], Loss: 0.0824
# Linear Probe Training - Epoch [67/200], Loss: 0.0815
# Linear Probe Training - Epoch [68/200], Loss: 0.0795
# Linear Probe Training - Epoch [69/200], Loss: 0.0784
# Linear Probe Training - Epoch [70/200], Loss: 0.0779
# Linear Probe Training - Epoch [71/200], Loss: 0.0760
# Linear Probe Training - Epoch [72/200], Loss: 0.0749
# Linear Probe Training - Epoch [73/200], Loss: 0.0743
# Linear Probe Training - Epoch [74/200], Loss: 0.0732
# Linear Probe Training - Epoch [75/200], Loss: 0.0719
# Linear Probe Training - Epoch [76/200], Loss: 0.0706
# Linear Probe Training - Epoch [77/200], Loss: 0.0700
# Linear Probe Training - Epoch [78/200], Loss: 0.0696
# Linear Probe Training - Epoch [79/200], Loss: 0.0694
# Linear Probe Training - Epoch [80/200], Loss: 0.0676
# Linear Probe Training - Epoch [81/200], Loss: 0.0665
# Linear Probe Training - Epoch [82/200], Loss: 0.0666
# Linear Probe Training - Epoch [83/200], Loss: 0.0652
# Linear Probe Training - Epoch [84/200], Loss: 0.0656
# Linear Probe Training - Epoch [85/200], Loss: 0.0639
# Linear Probe Training - Epoch [86/200], Loss: 0.0634
# Linear Probe Training - Epoch [87/200], Loss: 0.0644
# Linear Probe Training - Epoch [88/200], Loss: 0.0622
# Linear Probe Training - Epoch [89/200], Loss: 0.0625
# Linear Probe Training - Epoch [90/200], Loss: 0.0611
# Linear Probe Training - Epoch [91/200], Loss: 0.0610
# Linear Probe Training - Epoch [92/200], Loss: 0.0603
# Linear Probe Training - Epoch [93/200], Loss: 0.0597
# Linear Probe Training - Epoch [94/200], Loss: 0.0602
# Linear Probe Training - Epoch [95/200], Loss: 0.0598
# Linear Probe Training - Epoch [96/200], Loss: 0.0593
# Linear Probe Training - Epoch [97/200], Loss: 0.0599
# Linear Probe Training - Epoch [98/200], Loss: 0.0592
# Linear Probe Training - Epoch [99/200], Loss: 0.0592
# Linear Probe Training - Epoch [100/200], Loss: 0.0577
# Linear Probe Training - Epoch [101/200], Loss: 0.0579
# Linear Probe Training - Epoch [102/200], Loss: 0.0581
# Linear Probe Training - Epoch [103/200], Loss: 0.0566
# Linear Probe Training - Epoch [104/200], Loss: 0.0564
# Linear Probe Training - Epoch [105/200], Loss: 0.0558
# Linear Probe Training - Epoch [106/200], Loss: 0.0560
# Linear Probe Training - Epoch [107/200], Loss: 0.0555
# Linear Probe Training - Epoch [108/200], Loss: 0.0557
# Linear Probe Training - Epoch [109/200], Loss: 0.0550
# Linear Probe Training - Epoch [110/200], Loss: 0.0548
# Linear Probe Training - Epoch [111/200], Loss: 0.0546
# Linear Probe Training - Epoch [112/200], Loss: 0.0550
# Linear Probe Training - Epoch [113/200], Loss: 0.0543
# Linear Probe Training - Epoch [114/200], Loss: 0.0540
# Linear Probe Training - Epoch [115/200], Loss: 0.0540
# Linear Probe Training - Epoch [116/200], Loss: 0.0548
# Linear Probe Training - Epoch [117/200], Loss: 0.0551
# Linear Probe Training - Epoch [118/200], Loss: 0.0541
# Linear Probe Training - Epoch [119/200], Loss: 0.0532
# Linear Probe Training - Epoch [120/200], Loss: 0.0531
# Linear Probe Training - Epoch [121/200], Loss: 0.0542
# Linear Probe Training - Epoch [122/200], Loss: 0.0535
# Linear Probe Training - Epoch [123/200], Loss: 0.0541
# Linear Probe Training - Epoch [124/200], Loss: 0.0530
# Linear Probe Training - Epoch [125/200], Loss: 0.0525
# Linear Probe Training - Epoch [126/200], Loss: 0.0534
# Linear Probe Training - Epoch [127/200], Loss: 0.0525
# Linear Probe Training - Epoch [128/200], Loss: 0.0523
# Linear Probe Training - Epoch [129/200], Loss: 0.0526
# Linear Probe Training - Epoch [130/200], Loss: 0.0532
# Linear Probe Training - Epoch [131/200], Loss: 0.0522
# Linear Probe Training - Epoch [132/200], Loss: 0.0518
# Linear Probe Training - Epoch [133/200], Loss: 0.0519
# Linear Probe Training - Epoch [134/200], Loss: 0.0519
# Linear Probe Training - Epoch [135/200], Loss: 0.0520
# Linear Probe Training - Epoch [136/200], Loss: 0.0526
# Linear Probe Training - Epoch [137/200], Loss: 0.0510
# Linear Probe Training - Epoch [138/200], Loss: 0.0508
# Linear Probe Training - Epoch [139/200], Loss: 0.0511
# Linear Probe Training - Epoch [140/200], Loss: 0.0512
# Linear Probe Training - Epoch [141/200], Loss: 0.0523
# Linear Probe Training - Epoch [142/200], Loss: 0.0510
# Linear Probe Training - Epoch [143/200], Loss: 0.0520
# Linear Probe Training - Epoch [144/200], Loss: 0.0512
# Linear Probe Training - Epoch [145/200], Loss: 0.0518
# Linear Probe Training - Epoch [146/200], Loss: 0.0508
# Linear Probe Training - Epoch [147/200], Loss: 0.0511
# Linear Probe Training - Epoch [148/200], Loss: 0.0509
# Linear Probe Training - Epoch [149/200], Loss: 0.0504
# Linear Probe Training - Epoch [150/200], Loss: 0.0507
# Linear Probe Training - Epoch [151/200], Loss: 0.0510
# Linear Probe Training - Epoch [152/200], Loss: 0.0505
# Linear Probe Training - Epoch [153/200], Loss: 0.0511
# Linear Probe Training - Epoch [154/200], Loss: 0.0512
# Linear Probe Training - Epoch [155/200], Loss: 0.0505
# Linear Probe Training - Epoch [156/200], Loss: 0.0502
# Linear Probe Training - Epoch [157/200], Loss: 0.0503
# Linear Probe Training - Epoch [158/200], Loss: 0.0512
# Linear Probe Training - Epoch [159/200], Loss: 0.0503
# Linear Probe Training - Epoch [160/200], Loss: 0.0501
# Linear Probe Training - Epoch [161/200], Loss: 0.0503
# Linear Probe Training - Epoch [162/200], Loss: 0.0500
# Linear Probe Training - Epoch [163/200], Loss: 0.0502
# Linear Probe Training - Epoch [164/200], Loss: 0.0501
# Linear Probe Training - Epoch [165/200], Loss: 0.0508
# Linear Probe Training - Epoch [166/200], Loss: 0.0502
# Linear Probe Training - Epoch [167/200], Loss: 0.0510
# Linear Probe Training - Epoch [168/200], Loss: 0.0511
# Linear Probe Training - Epoch [169/200], Loss: 0.0501
# Linear Probe Training - Epoch [170/200], Loss: 0.0500
# Linear Probe Training - Epoch [171/200], Loss: 0.0502
# Linear Probe Training - Epoch [172/200], Loss: 0.0509
# Linear Probe Training - Epoch [173/200], Loss: 0.0511
# Linear Probe Training - Epoch [174/200], Loss: 0.0499
# Linear Probe Training - Epoch [175/200], Loss: 0.0499
# Linear Probe Training - Epoch [176/200], Loss: 0.0499
# Linear Probe Training - Epoch [177/200], Loss: 0.0501
# Linear Probe Training - Epoch [178/200], Loss: 0.0501
# Linear Probe Training - Epoch [179/200], Loss: 0.0501
# Linear Probe Training - Epoch [180/200], Loss: 0.0496
# Linear Probe Training - Epoch [181/200], Loss: 0.0500
# Linear Probe Training - Epoch [182/200], Loss: 0.0499
# Linear Probe Training - Epoch [183/200], Loss: 0.0497
# Linear Probe Training - Epoch [184/200], Loss: 0.0500
# Linear Probe Training - Epoch [185/200], Loss: 0.0502
# Linear Probe Training - Epoch [186/200], Loss: 0.0499
# Linear Probe Training - Epoch [187/200], Loss: 0.0495
# Linear Probe Training - Epoch [188/200], Loss: 0.0507
# Linear Probe Training - Epoch [189/200], Loss: 0.0507
# Linear Probe Training - Epoch [190/200], Loss: 0.0501
# Linear Probe Training - Epoch [191/200], Loss: 0.0496
# Linear Probe Training - Epoch [192/200], Loss: 0.0498
# Linear Probe Training - Epoch [193/200], Loss: 0.0494
# Linear Probe Training - Epoch [194/200], Loss: 0.0493
# Linear Probe Training - Epoch [195/200], Loss: 0.0500
# Linear Probe Training - Epoch [196/200], Loss: 0.0504
# Linear Probe Training - Epoch [197/200], Loss: 0.0506
# Linear Probe Training - Epoch [198/200], Loss: 0.0498
# Linear Probe Training - Epoch [199/200], Loss: 0.0497
# Linear Probe Training - Epoch [200/200], Loss: 0.0497
#
# === Building dataset/model for Beta 1 ===
# Beta Model Training - Epoch [1/200], Loss: 0.7554
# Beta Model Training - Epoch [2/200], Loss: 0.6342
# Beta Model Training - Epoch [3/200], Loss: 0.4815
# Beta Model Training - Epoch [4/200], Loss: 0.3994
# Beta Model Training - Epoch [5/200], Loss: 0.3702
# Beta Model Training - Epoch [6/200], Loss: 0.3509
# Beta Model Training - Epoch [7/200], Loss: 0.3270
# Beta Model Training - Epoch [8/200], Loss: 0.3056
# Beta Model Training - Epoch [9/200], Loss: 0.2821
# Beta Model Training - Epoch [10/200], Loss: 0.2631
# Beta Model Training - Epoch [11/200], Loss: 0.2413
# Beta Model Training - Epoch [12/200], Loss: 0.2304
# Beta Model Training - Epoch [13/200], Loss: 0.2155
# Beta Model Training - Epoch [14/200], Loss: 0.2036
# Beta Model Training - Epoch [15/200], Loss: 0.1928
# Beta Model Training - Epoch [16/200], Loss: 0.1832
# Beta Model Training - Epoch [17/200], Loss: 0.1771
# Beta Model Training - Epoch [18/200], Loss: 0.1705
# Beta Model Training - Epoch [19/200], Loss: 0.1639
# Beta Model Training - Epoch [20/200], Loss: 0.1554
# Beta Model Training - Epoch [21/200], Loss: 0.1508
# Beta Model Training - Epoch [22/200], Loss: 0.1464
# Beta Model Training - Epoch [23/200], Loss: 0.1447
# Beta Model Training - Epoch [24/200], Loss: 0.1462
# Beta Model Training - Epoch [25/200], Loss: 0.1452
# Beta Model Training - Epoch [26/200], Loss: 0.1383
# Beta Model Training - Epoch [27/200], Loss: 0.1363
# Beta Model Training - Epoch [28/200], Loss: 0.1322
# Beta Model Training - Epoch [29/200], Loss: 0.1293
# Beta Model Training - Epoch [30/200], Loss: 0.1236
# Beta Model Training - Epoch [31/200], Loss: 0.1221
# Beta Model Training - Epoch [32/200], Loss: 0.1195
# Beta Model Training - Epoch [33/200], Loss: 0.1158
# Beta Model Training - Epoch [34/200], Loss: 0.1126
# Beta Model Training - Epoch [35/200], Loss: 0.1138
# Beta Model Training - Epoch [36/200], Loss: 0.1117
# Beta Model Training - Epoch [37/200], Loss: 0.1115
# Beta Model Training - Epoch [38/200], Loss: 0.1074
# Beta Model Training - Epoch [39/200], Loss: 0.1056
# Beta Model Training - Epoch [40/200], Loss: 0.1034
# Beta Model Training - Epoch [41/200], Loss: 0.1014
# Beta Model Training - Epoch [42/200], Loss: 0.0996
# Beta Model Training - Epoch [43/200], Loss: 0.0979
# Beta Model Training - Epoch [44/200], Loss: 0.0952
# Beta Model Training - Epoch [45/200], Loss: 0.0951
# Beta Model Training - Epoch [46/200], Loss: 0.0934
# Beta Model Training - Epoch [47/200], Loss: 0.0918
# Beta Model Training - Epoch [48/200], Loss: 0.0915
# Beta Model Training - Epoch [49/200], Loss: 0.0904
# Beta Model Training - Epoch [50/200], Loss: 0.0919
# Beta Model Training - Epoch [51/200], Loss: 0.0901
# Beta Model Training - Epoch [52/200], Loss: 0.0893
# Beta Model Training - Epoch [53/200], Loss: 0.0890
# Beta Model Training - Epoch [54/200], Loss: 0.0861
# Beta Model Training - Epoch [55/200], Loss: 0.0865
# Beta Model Training - Epoch [56/200], Loss: 0.0849
# Beta Model Training - Epoch [57/200], Loss: 0.0884
# Beta Model Training - Epoch [58/200], Loss: 0.0923
# Beta Model Training - Epoch [59/200], Loss: 0.0896
# Beta Model Training - Epoch [60/200], Loss: 0.0849
# Beta Model Training - Epoch [61/200], Loss: 0.0843
# Beta Model Training - Epoch [62/200], Loss: 0.0847
# Beta Model Training - Epoch [63/200], Loss: 0.0857
# Beta Model Training - Epoch [64/200], Loss: 0.0863
# Beta Model Training - Epoch [65/200], Loss: 0.0820
# Beta Model Training - Epoch [66/200], Loss: 0.0793
# Beta Model Training - Epoch [67/200], Loss: 0.0772
# Beta Model Training - Epoch [68/200], Loss: 0.0756
# Beta Model Training - Epoch [69/200], Loss: 0.0757
# Beta Model Training - Epoch [70/200], Loss: 0.0747
# Beta Model Training - Epoch [71/200], Loss: 0.0772
# Beta Model Training - Epoch [72/200], Loss: 0.0736
# Beta Model Training - Epoch [73/200], Loss: 0.0732
# Beta Model Training - Epoch [74/200], Loss: 0.0745
# Beta Model Training - Epoch [75/200], Loss: 0.0722
# Beta Model Training - Epoch [76/200], Loss: 0.0725
# Beta Model Training - Epoch [77/200], Loss: 0.0724
# Beta Model Training - Epoch [78/200], Loss: 0.0764
# Beta Model Training - Epoch [79/200], Loss: 0.0752
# Beta Model Training - Epoch [80/200], Loss: 0.0734
# Beta Model Training - Epoch [81/200], Loss: 0.0709
# Beta Model Training - Epoch [82/200], Loss: 0.0703
# Beta Model Training - Epoch [83/200], Loss: 0.0698
# Beta Model Training - Epoch [84/200], Loss: 0.0716
# Beta Model Training - Epoch [85/200], Loss: 0.0693
# Beta Model Training - Epoch [86/200], Loss: 0.0676
# Beta Model Training - Epoch [87/200], Loss: 0.0687
# Beta Model Training - Epoch [88/200], Loss: 0.0695
# Beta Model Training - Epoch [89/200], Loss: 0.0696
# Beta Model Training - Epoch [90/200], Loss: 0.0713
# Beta Model Training - Epoch [91/200], Loss: 0.0680
# Beta Model Training - Epoch [92/200], Loss: 0.0685
# Beta Model Training - Epoch [93/200], Loss: 0.0654
# Beta Model Training - Epoch [94/200], Loss: 0.0666
# Beta Model Training - Epoch [95/200], Loss: 0.0649
# Beta Model Training - Epoch [96/200], Loss: 0.0646
# Beta Model Training - Epoch [97/200], Loss: 0.0635
# Beta Model Training - Epoch [98/200], Loss: 0.0645
# Beta Model Training - Epoch [99/200], Loss: 0.0638
# Beta Model Training - Epoch [100/200], Loss: 0.0634
# Beta Model Training - Epoch [101/200], Loss: 0.0653
# Beta Model Training - Epoch [102/200], Loss: 0.0636
# Beta Model Training - Epoch [103/200], Loss: 0.0624
# Beta Model Training - Epoch [104/200], Loss: 0.0621
# Beta Model Training - Epoch [105/200], Loss: 0.0621
# Beta Model Training - Epoch [106/200], Loss: 0.0633
# Beta Model Training - Epoch [107/200], Loss: 0.0617
# Beta Model Training - Epoch [108/200], Loss: 0.0610
# Beta Model Training - Epoch [109/200], Loss: 0.0608
# Beta Model Training - Epoch [110/200], Loss: 0.0605
# Beta Model Training - Epoch [111/200], Loss: 0.0604
# Beta Model Training - Epoch [112/200], Loss: 0.0605
# Beta Model Training - Epoch [113/200], Loss: 0.0604
# Beta Model Training - Epoch [114/200], Loss: 0.0608
# Beta Model Training - Epoch [115/200], Loss: 0.0613
# Beta Model Training - Epoch [116/200], Loss: 0.0619
# Beta Model Training - Epoch [117/200], Loss: 0.0660
# Beta Model Training - Epoch [118/200], Loss: 0.0658
# Beta Model Training - Epoch [119/200], Loss: 0.0662
# Beta Model Training - Epoch [120/200], Loss: 0.0625
# Beta Model Training - Epoch [121/200], Loss: 0.0621
# Beta Model Training - Epoch [122/200], Loss: 0.0618
# Beta Model Training - Epoch [123/200], Loss: 0.0614
# Beta Model Training - Epoch [124/200], Loss: 0.0611
# Beta Model Training - Epoch [125/200], Loss: 0.0611
# Beta Model Training - Epoch [126/200], Loss: 0.0616
# Beta Model Training - Epoch [127/200], Loss: 0.0624
# Beta Model Training - Epoch [128/200], Loss: 0.0619
# Beta Model Training - Epoch [129/200], Loss: 0.0613
# Beta Model Training - Epoch [130/200], Loss: 0.0612
# Beta Model Training - Epoch [131/200], Loss: 0.0625
# Beta Model Training - Epoch [132/200], Loss: 0.0616
# Beta Model Training - Epoch [133/200], Loss: 0.0623
# Beta Model Training - Epoch [134/200], Loss: 0.0611
# Beta Model Training - Epoch [135/200], Loss: 0.0613
# Beta Model Training - Epoch [136/200], Loss: 0.0599
# Beta Model Training - Epoch [137/200], Loss: 0.0580
# Beta Model Training - Epoch [138/200], Loss: 0.0579
# Beta Model Training - Epoch [139/200], Loss: 0.0592
# Beta Model Training - Epoch [140/200], Loss: 0.0586
# Beta Model Training - Epoch [141/200], Loss: 0.0586
# Beta Model Training - Epoch [142/200], Loss: 0.0593
# Beta Model Training - Epoch [143/200], Loss: 0.0587
# Beta Model Training - Epoch [144/200], Loss: 0.0578
# Beta Model Training - Epoch [145/200], Loss: 0.0577
# Beta Model Training - Epoch [146/200], Loss: 0.0579
# Beta Model Training - Epoch [147/200], Loss: 0.0580
# Beta Model Training - Epoch [148/200], Loss: 0.0569
# Beta Model Training - Epoch [149/200], Loss: 0.0571
# Beta Model Training - Epoch [150/200], Loss: 0.0571
# Beta Model Training - Epoch [151/200], Loss: 0.0564
# Beta Model Training - Epoch [152/200], Loss: 0.0578
# Beta Model Training - Epoch [153/200], Loss: 0.0607
# Beta Model Training - Epoch [154/200], Loss: 0.0605
# Beta Model Training - Epoch [155/200], Loss: 0.0630
# Beta Model Training - Epoch [156/200], Loss: 0.0627
# Beta Model Training - Epoch [157/200], Loss: 0.0613
# Beta Model Training - Epoch [158/200], Loss: 0.0614
# Beta Model Training - Epoch [159/200], Loss: 0.0618
# Beta Model Training - Epoch [160/200], Loss: 0.0582
# Beta Model Training - Epoch [161/200], Loss: 0.0567
# Beta Model Training - Epoch [162/200], Loss: 0.0561
# Beta Model Training - Epoch [163/200], Loss: 0.0579
# Beta Model Training - Epoch [164/200], Loss: 0.0584
# Beta Model Training - Epoch [165/200], Loss: 0.0568
# Beta Model Training - Epoch [166/200], Loss: 0.0560
# Beta Model Training - Epoch [167/200], Loss: 0.0564
# Beta Model Training - Epoch [168/200], Loss: 0.0567
# Beta Model Training - Epoch [169/200], Loss: 0.0557
# Beta Model Training - Epoch [170/200], Loss: 0.0562
# Beta Model Training - Epoch [171/200], Loss: 0.0567
# Beta Model Training - Epoch [172/200], Loss: 0.0572
# Beta Model Training - Epoch [173/200], Loss: 0.0551
# Beta Model Training - Epoch [174/200], Loss: 0.0552
# Beta Model Training - Epoch [175/200], Loss: 0.0548
# Beta Model Training - Epoch [176/200], Loss: 0.0535
# Beta Model Training - Epoch [177/200], Loss: 0.0529
# Beta Model Training - Epoch [178/200], Loss: 0.0527
# Beta Model Training - Epoch [179/200], Loss: 0.0532
# Beta Model Training - Epoch [180/200], Loss: 0.0531
# Beta Model Training - Epoch [181/200], Loss: 0.0533
# Beta Model Training - Epoch [182/200], Loss: 0.0535
# Beta Model Training - Epoch [183/200], Loss: 0.0532
# Beta Model Training - Epoch [184/200], Loss: 0.0525
# Beta Model Training - Epoch [185/200], Loss: 0.0532
# Beta Model Training - Epoch [186/200], Loss: 0.0526
# Beta Model Training - Epoch [187/200], Loss: 0.0521
# Beta Model Training - Epoch [188/200], Loss: 0.0522
# Beta Model Training - Epoch [189/200], Loss: 0.0524
# Beta Model Training - Epoch [190/200], Loss: 0.0525
# Beta Model Training - Epoch [191/200], Loss: 0.0521
# Beta Model Training - Epoch [192/200], Loss: 0.0528
# Beta Model Training - Epoch [193/200], Loss: 0.0538
# Beta Model Training - Epoch [194/200], Loss: 0.0521
# Beta Model Training - Epoch [195/200], Loss: 0.0520
# Beta Model Training - Epoch [196/200], Loss: 0.0521
# Beta Model Training - Epoch [197/200], Loss: 0.0511
# Beta Model Training - Epoch [198/200], Loss: 0.0515
# Beta Model Training - Epoch [199/200], Loss: 0.0513
# Beta Model Training - Epoch [200/200], Loss: 0.0517
# Linear Probe Training - Epoch [1/200], Loss: 2.2235
# Linear Probe Training - Epoch [2/200], Loss: 1.5658
# Linear Probe Training - Epoch [3/200], Loss: 1.2267
# Linear Probe Training - Epoch [4/200], Loss: 1.0767
# Linear Probe Training - Epoch [5/200], Loss: 0.9895
# Linear Probe Training - Epoch [6/200], Loss: 0.9313
# Linear Probe Training - Epoch [7/200], Loss: 0.8802
# Linear Probe Training - Epoch [8/200], Loss: 0.8320
# Linear Probe Training - Epoch [9/200], Loss: 0.7880
# Linear Probe Training - Epoch [10/200], Loss: 0.7446
# Linear Probe Training - Epoch [11/200], Loss: 0.7070
# Linear Probe Training - Epoch [12/200], Loss: 0.6675
# Linear Probe Training - Epoch [13/200], Loss: 0.6319
# Linear Probe Training - Epoch [14/200], Loss: 0.5995
# Linear Probe Training - Epoch [15/200], Loss: 0.5730
# Linear Probe Training - Epoch [16/200], Loss: 0.5397
# Linear Probe Training - Epoch [17/200], Loss: 0.5144
# Linear Probe Training - Epoch [18/200], Loss: 0.4881
# Linear Probe Training - Epoch [19/200], Loss: 0.4631
# Linear Probe Training - Epoch [20/200], Loss: 0.4424
# Linear Probe Training - Epoch [21/200], Loss: 0.4235
# Linear Probe Training - Epoch [22/200], Loss: 0.4020
# Linear Probe Training - Epoch [23/200], Loss: 0.3808
# Linear Probe Training - Epoch [24/200], Loss: 0.3699
# Linear Probe Training - Epoch [25/200], Loss: 0.3522
# Linear Probe Training - Epoch [26/200], Loss: 0.3369
# Linear Probe Training - Epoch [27/200], Loss: 0.3251
# Linear Probe Training - Epoch [28/200], Loss: 0.3114
# Linear Probe Training - Epoch [29/200], Loss: 0.2989
# Linear Probe Training - Epoch [30/200], Loss: 0.2866
# Linear Probe Training - Epoch [31/200], Loss: 0.2769
# Linear Probe Training - Epoch [32/200], Loss: 0.2661
# Linear Probe Training - Epoch [33/200], Loss: 0.2563
# Linear Probe Training - Epoch [34/200], Loss: 0.2462
# Linear Probe Training - Epoch [35/200], Loss: 0.2367
# Linear Probe Training - Epoch [36/200], Loss: 0.2286
# Linear Probe Training - Epoch [37/200], Loss: 0.2206
# Linear Probe Training - Epoch [38/200], Loss: 0.2151
# Linear Probe Training - Epoch [39/200], Loss: 0.2054
# Linear Probe Training - Epoch [40/200], Loss: 0.2010
# Linear Probe Training - Epoch [41/200], Loss: 0.1918
# Linear Probe Training - Epoch [42/200], Loss: 0.1853
# Linear Probe Training - Epoch [43/200], Loss: 0.1806
# Linear Probe Training - Epoch [44/200], Loss: 0.1748
# Linear Probe Training - Epoch [45/200], Loss: 0.1692
# Linear Probe Training - Epoch [46/200], Loss: 0.1653
# Linear Probe Training - Epoch [47/200], Loss: 0.1583
# Linear Probe Training - Epoch [48/200], Loss: 0.1540
# Linear Probe Training - Epoch [49/200], Loss: 0.1506
# Linear Probe Training - Epoch [50/200], Loss: 0.1491
# Linear Probe Training - Epoch [51/200], Loss: 0.1416
# Linear Probe Training - Epoch [52/200], Loss: 0.1376
# Linear Probe Training - Epoch [53/200], Loss: 0.1344
# Linear Probe Training - Epoch [54/200], Loss: 0.1309
# Linear Probe Training - Epoch [55/200], Loss: 0.1282
# Linear Probe Training - Epoch [56/200], Loss: 0.1236
# Linear Probe Training - Epoch [57/200], Loss: 0.1213
# Linear Probe Training - Epoch [58/200], Loss: 0.1179
# Linear Probe Training - Epoch [59/200], Loss: 0.1170
# Linear Probe Training - Epoch [60/200], Loss: 0.1132
# Linear Probe Training - Epoch [61/200], Loss: 0.1124
# Linear Probe Training - Epoch [62/200], Loss: 0.1089
# Linear Probe Training - Epoch [63/200], Loss: 0.1088
# Linear Probe Training - Epoch [64/200], Loss: 0.1036
# Linear Probe Training - Epoch [65/200], Loss: 0.1010
# Linear Probe Training - Epoch [66/200], Loss: 0.1000
# Linear Probe Training - Epoch [67/200], Loss: 0.0988
# Linear Probe Training - Epoch [68/200], Loss: 0.0960
# Linear Probe Training - Epoch [69/200], Loss: 0.0944
# Linear Probe Training - Epoch [70/200], Loss: 0.0932
# Linear Probe Training - Epoch [71/200], Loss: 0.0911
# Linear Probe Training - Epoch [72/200], Loss: 0.0902
# Linear Probe Training - Epoch [73/200], Loss: 0.0882
# Linear Probe Training - Epoch [74/200], Loss: 0.0859
# Linear Probe Training - Epoch [75/200], Loss: 0.0851
# Linear Probe Training - Epoch [76/200], Loss: 0.0838
# Linear Probe Training - Epoch [77/200], Loss: 0.0835
# Linear Probe Training - Epoch [78/200], Loss: 0.0812
# Linear Probe Training - Epoch [79/200], Loss: 0.0811
# Linear Probe Training - Epoch [80/200], Loss: 0.0797
# Linear Probe Training - Epoch [81/200], Loss: 0.0784
# Linear Probe Training - Epoch [82/200], Loss: 0.0794
# Linear Probe Training - Epoch [83/200], Loss: 0.0767
# Linear Probe Training - Epoch [84/200], Loss: 0.0760
# Linear Probe Training - Epoch [85/200], Loss: 0.0745
# Linear Probe Training - Epoch [86/200], Loss: 0.0749
# Linear Probe Training - Epoch [87/200], Loss: 0.0736
# Linear Probe Training - Epoch [88/200], Loss: 0.0743
# Linear Probe Training - Epoch [89/200], Loss: 0.0716
# Linear Probe Training - Epoch [90/200], Loss: 0.0715
# Linear Probe Training - Epoch [91/200], Loss: 0.0720
# Linear Probe Training - Epoch [92/200], Loss: 0.0715
# Linear Probe Training - Epoch [93/200], Loss: 0.0697
# Linear Probe Training - Epoch [94/200], Loss: 0.0684
# Linear Probe Training - Epoch [95/200], Loss: 0.0681
# Linear Probe Training - Epoch [96/200], Loss: 0.0678
# Linear Probe Training - Epoch [97/200], Loss: 0.0674
# Linear Probe Training - Epoch [98/200], Loss: 0.0664
# Linear Probe Training - Epoch [99/200], Loss: 0.0660
# Linear Probe Training - Epoch [100/200], Loss: 0.0656
# Linear Probe Training - Epoch [101/200], Loss: 0.0659
# Linear Probe Training - Epoch [102/200], Loss: 0.0656
# Linear Probe Training - Epoch [103/200], Loss: 0.0649
# Linear Probe Training - Epoch [104/200], Loss: 0.0646
# Linear Probe Training - Epoch [105/200], Loss: 0.0643
# Linear Probe Training - Epoch [106/200], Loss: 0.0630
# Linear Probe Training - Epoch [107/200], Loss: 0.0629
# Linear Probe Training - Epoch [108/200], Loss: 0.0630
# Linear Probe Training - Epoch [109/200], Loss: 0.0631
# Linear Probe Training - Epoch [110/200], Loss: 0.0623
# Linear Probe Training - Epoch [111/200], Loss: 0.0616
# Linear Probe Training - Epoch [112/200], Loss: 0.0625
# Linear Probe Training - Epoch [113/200], Loss: 0.0611
# Linear Probe Training - Epoch [114/200], Loss: 0.0617
# Linear Probe Training - Epoch [115/200], Loss: 0.0607
# Linear Probe Training - Epoch [116/200], Loss: 0.0606
# Linear Probe Training - Epoch [117/200], Loss: 0.0602
# Linear Probe Training - Epoch [118/200], Loss: 0.0597
# Linear Probe Training - Epoch [119/200], Loss: 0.0593
# Linear Probe Training - Epoch [120/200], Loss: 0.0599
# Linear Probe Training - Epoch [121/200], Loss: 0.0588
# Linear Probe Training - Epoch [122/200], Loss: 0.0589
# Linear Probe Training - Epoch [123/200], Loss: 0.0590
# Linear Probe Training - Epoch [124/200], Loss: 0.0584
# Linear Probe Training - Epoch [125/200], Loss: 0.0583
# Linear Probe Training - Epoch [126/200], Loss: 0.0592
# Linear Probe Training - Epoch [127/200], Loss: 0.0577
# Linear Probe Training - Epoch [128/200], Loss: 0.0587
# Linear Probe Training - Epoch [129/200], Loss: 0.0584
# Linear Probe Training - Epoch [130/200], Loss: 0.0595
# Linear Probe Training - Epoch [131/200], Loss: 0.0571
# Linear Probe Training - Epoch [132/200], Loss: 0.0574
# Linear Probe Training - Epoch [133/200], Loss: 0.0588
# Linear Probe Training - Epoch [134/200], Loss: 0.0576
# Linear Probe Training - Epoch [135/200], Loss: 0.0575
# Linear Probe Training - Epoch [136/200], Loss: 0.0576
# Linear Probe Training - Epoch [137/200], Loss: 0.0571
# Linear Probe Training - Epoch [138/200], Loss: 0.0569
# Linear Probe Training - Epoch [139/200], Loss: 0.0569
# Linear Probe Training - Epoch [140/200], Loss: 0.0568
# Linear Probe Training - Epoch [141/200], Loss: 0.0567
# Linear Probe Training - Epoch [142/200], Loss: 0.0569
# Linear Probe Training - Epoch [143/200], Loss: 0.0561
# Linear Probe Training - Epoch [144/200], Loss: 0.0574
# Linear Probe Training - Epoch [145/200], Loss: 0.0565
# Linear Probe Training - Epoch [146/200], Loss: 0.0564
# Linear Probe Training - Epoch [147/200], Loss: 0.0559
# Linear Probe Training - Epoch [148/200], Loss: 0.0564
# Linear Probe Training - Epoch [149/200], Loss: 0.0558
# Linear Probe Training - Epoch [150/200], Loss: 0.0560
# Linear Probe Training - Epoch [151/200], Loss: 0.0560
# Linear Probe Training - Epoch [152/200], Loss: 0.0560
# Linear Probe Training - Epoch [153/200], Loss: 0.0560
# Linear Probe Training - Epoch [154/200], Loss: 0.0569
# Linear Probe Training - Epoch [155/200], Loss: 0.0568
# Linear Probe Training - Epoch [156/200], Loss: 0.0553
# Linear Probe Training - Epoch [157/200], Loss: 0.0557
# Linear Probe Training - Epoch [158/200], Loss: 0.0567
# Linear Probe Training - Epoch [159/200], Loss: 0.0571
# Linear Probe Training - Epoch [160/200], Loss: 0.0557
# Linear Probe Training - Epoch [161/200], Loss: 0.0554
# Linear Probe Training - Epoch [162/200], Loss: 0.0549
# Linear Probe Training - Epoch [163/200], Loss: 0.0550
# Linear Probe Training - Epoch [164/200], Loss: 0.0561
# Linear Probe Training - Epoch [165/200], Loss: 0.0547
# Linear Probe Training - Epoch [166/200], Loss: 0.0547
# Linear Probe Training - Epoch [167/200], Loss: 0.0549
# Linear Probe Training - Epoch [168/200], Loss: 0.0549
# Linear Probe Training - Epoch [169/200], Loss: 0.0550
# Linear Probe Training - Epoch [170/200], Loss: 0.0548
# Linear Probe Training - Epoch [171/200], Loss: 0.0550
# Linear Probe Training - Epoch [172/200], Loss: 0.0556
# Linear Probe Training - Epoch [173/200], Loss: 0.0557
# Linear Probe Training - Epoch [174/200], Loss: 0.0548
# Linear Probe Training - Epoch [175/200], Loss: 0.0552
# Linear Probe Training - Epoch [176/200], Loss: 0.0546
# Linear Probe Training - Epoch [177/200], Loss: 0.0554
# Linear Probe Training - Epoch [178/200], Loss: 0.0545
# Linear Probe Training - Epoch [179/200], Loss: 0.0544
# Linear Probe Training - Epoch [180/200], Loss: 0.0549
# Linear Probe Training - Epoch [181/200], Loss: 0.0546
# Linear Probe Training - Epoch [182/200], Loss: 0.0543
# Linear Probe Training - Epoch [183/200], Loss: 0.0549
# Linear Probe Training - Epoch [184/200], Loss: 0.0556
# Linear Probe Training - Epoch [185/200], Loss: 0.0547
# Linear Probe Training - Epoch [186/200], Loss: 0.0546
# Linear Probe Training - Epoch [187/200], Loss: 0.0553
# Linear Probe Training - Epoch [188/200], Loss: 0.0548
# Linear Probe Training - Epoch [189/200], Loss: 0.0546
# Linear Probe Training - Epoch [190/200], Loss: 0.0551
# Linear Probe Training - Epoch [191/200], Loss: 0.0540
# Linear Probe Training - Epoch [192/200], Loss: 0.0543
# Linear Probe Training - Epoch [193/200], Loss: 0.0545
# Linear Probe Training - Epoch [194/200], Loss: 0.0549
# Linear Probe Training - Epoch [195/200], Loss: 0.0550
# Linear Probe Training - Epoch [196/200], Loss: 0.0543
# Linear Probe Training - Epoch [197/200], Loss: 0.0549
# Linear Probe Training - Epoch [198/200], Loss: 0.0541
# Linear Probe Training - Epoch [199/200], Loss: 0.0542
# Linear Probe Training - Epoch [200/200], Loss: 0.0547
#
# === Building dataset/model for Beta 2 ===
# Beta Model Training - Epoch [1/200], Loss: 1.7183
# Beta Model Training - Epoch [2/200], Loss: 1.0936
# Beta Model Training - Epoch [3/200], Loss: 0.6671
# Beta Model Training - Epoch [4/200], Loss: 0.5067
# Beta Model Training - Epoch [5/200], Loss: 0.4081
# Beta Model Training - Epoch [6/200], Loss: 0.3487
# Beta Model Training - Epoch [7/200], Loss: 0.3256
# Beta Model Training - Epoch [8/200], Loss: 0.3115
# Beta Model Training - Epoch [9/200], Loss: 0.2966
# Beta Model Training - Epoch [10/200], Loss: 0.2894
# Beta Model Training - Epoch [11/200], Loss: 0.2745
# Beta Model Training - Epoch [12/200], Loss: 0.2621
# Beta Model Training - Epoch [13/200], Loss: 0.2481
# Beta Model Training - Epoch [14/200], Loss: 0.2377
# Beta Model Training - Epoch [15/200], Loss: 0.2331
# Beta Model Training - Epoch [16/200], Loss: 0.2221
# Beta Model Training - Epoch [17/200], Loss: 0.2162
# Beta Model Training - Epoch [18/200], Loss: 0.2070
# Beta Model Training - Epoch [19/200], Loss: 0.1997
# Beta Model Training - Epoch [20/200], Loss: 0.1905
# Beta Model Training - Epoch [21/200], Loss: 0.1827
# Beta Model Training - Epoch [22/200], Loss: 0.1745
# Beta Model Training - Epoch [23/200], Loss: 0.1648
# Beta Model Training - Epoch [24/200], Loss: 0.1612
# Beta Model Training - Epoch [25/200], Loss: 0.1579
# Beta Model Training - Epoch [26/200], Loss: 0.1525
# Beta Model Training - Epoch [27/200], Loss: 0.1429
# Beta Model Training - Epoch [28/200], Loss: 0.1393
# Beta Model Training - Epoch [29/200], Loss: 0.1340
# Beta Model Training - Epoch [30/200], Loss: 0.1297
# Beta Model Training - Epoch [31/200], Loss: 0.1271
# Beta Model Training - Epoch [32/200], Loss: 0.1243
# Beta Model Training - Epoch [33/200], Loss: 0.1250
# Beta Model Training - Epoch [34/200], Loss: 0.1216
# Beta Model Training - Epoch [35/200], Loss: 0.1261
# Beta Model Training - Epoch [36/200], Loss: 0.1260
# Beta Model Training - Epoch [37/200], Loss: 0.1234
# Beta Model Training - Epoch [38/200], Loss: 0.1348
# Beta Model Training - Epoch [39/200], Loss: 0.1267
# Beta Model Training - Epoch [40/200], Loss: 0.1158
# Beta Model Training - Epoch [41/200], Loss: 0.1099
# Beta Model Training - Epoch [42/200], Loss: 0.1054
# Beta Model Training - Epoch [43/200], Loss: 0.1043
# Beta Model Training - Epoch [44/200], Loss: 0.1034
# Beta Model Training - Epoch [45/200], Loss: 0.1023
# Beta Model Training - Epoch [46/200], Loss: 0.0995
# Beta Model Training - Epoch [47/200], Loss: 0.0982
# Beta Model Training - Epoch [48/200], Loss: 0.0980
# Beta Model Training - Epoch [49/200], Loss: 0.0963
# Beta Model Training - Epoch [50/200], Loss: 0.0953
# Beta Model Training - Epoch [51/200], Loss: 0.0927
# Beta Model Training - Epoch [52/200], Loss: 0.0979
# Beta Model Training - Epoch [53/200], Loss: 0.1099
# Beta Model Training - Epoch [54/200], Loss: 0.1061
# Beta Model Training - Epoch [55/200], Loss: 0.1008
# Beta Model Training - Epoch [56/200], Loss: 0.0983
# Beta Model Training - Epoch [57/200], Loss: 0.0930
# Beta Model Training - Epoch [58/200], Loss: 0.0913
# Beta Model Training - Epoch [59/200], Loss: 0.0937
# Beta Model Training - Epoch [60/200], Loss: 0.0882
# Beta Model Training - Epoch [61/200], Loss: 0.0852
# Beta Model Training - Epoch [62/200], Loss: 0.0825
# Beta Model Training - Epoch [63/200], Loss: 0.0818
# Beta Model Training - Epoch [64/200], Loss: 0.0833
# Beta Model Training - Epoch [65/200], Loss: 0.0829
# Beta Model Training - Epoch [66/200], Loss: 0.0832
# Beta Model Training - Epoch [67/200], Loss: 0.0834
# Beta Model Training - Epoch [68/200], Loss: 0.0800
# Beta Model Training - Epoch [69/200], Loss: 0.0770
# Beta Model Training - Epoch [70/200], Loss: 0.0750
# Beta Model Training - Epoch [71/200], Loss: 0.0734
# Beta Model Training - Epoch [72/200], Loss: 0.0738
# Beta Model Training - Epoch [73/200], Loss: 0.0724
# Beta Model Training - Epoch [74/200], Loss: 0.0733
# Beta Model Training - Epoch [75/200], Loss: 0.0731
# Beta Model Training - Epoch [76/200], Loss: 0.0731
# Beta Model Training - Epoch [77/200], Loss: 0.0778
# Beta Model Training - Epoch [78/200], Loss: 0.0728
# Beta Model Training - Epoch [79/200], Loss: 0.0752
# Beta Model Training - Epoch [80/200], Loss: 0.0752
# Beta Model Training - Epoch [81/200], Loss: 0.0765
# Beta Model Training - Epoch [82/200], Loss: 0.0752
# Beta Model Training - Epoch [83/200], Loss: 0.0903
# Beta Model Training - Epoch [84/200], Loss: 0.0830
# Beta Model Training - Epoch [85/200], Loss: 0.0741
# Beta Model Training - Epoch [86/200], Loss: 0.0745
# Beta Model Training - Epoch [87/200], Loss: 0.0711
# Beta Model Training - Epoch [88/200], Loss: 0.0684
# Beta Model Training - Epoch [89/200], Loss: 0.0694
# Beta Model Training - Epoch [90/200], Loss: 0.0674
# Beta Model Training - Epoch [91/200], Loss: 0.0670
# Beta Model Training - Epoch [92/200], Loss: 0.0656
# Beta Model Training - Epoch [93/200], Loss: 0.0678
# Beta Model Training - Epoch [94/200], Loss: 0.0646
# Beta Model Training - Epoch [95/200], Loss: 0.0637
# Beta Model Training - Epoch [96/200], Loss: 0.0631
# Beta Model Training - Epoch [97/200], Loss: 0.0625
# Beta Model Training - Epoch [98/200], Loss: 0.0617
# Beta Model Training - Epoch [99/200], Loss: 0.0619
# Beta Model Training - Epoch [100/200], Loss: 0.0613
# Beta Model Training - Epoch [101/200], Loss: 0.0612
# Beta Model Training - Epoch [102/200], Loss: 0.0610
# Beta Model Training - Epoch [103/200], Loss: 0.0596
# Beta Model Training - Epoch [104/200], Loss: 0.0599
# Beta Model Training - Epoch [105/200], Loss: 0.0616
# Beta Model Training - Epoch [106/200], Loss: 0.0642
# Beta Model Training - Epoch [107/200], Loss: 0.0667
# Beta Model Training - Epoch [108/200], Loss: 0.0617
# Beta Model Training - Epoch [109/200], Loss: 0.0626
# ...
# Beta Model Training - Epoch [99/200], Loss: 0.0280
# Beta Model Training - Epoch [100/200], Loss: 0.0274
# Beta Model Training - Epoch [101/200], Loss: 0.0261
# Beta Model Training - Epoch [102/200], Loss: 0.0261
# Beta Model Training - Epoch [103/200], Loss: 0.0264
# Beta Model Training - Epoch [104/200], Loss: 0.0259
# Beta Model Training - Epoch [105/200], Loss: 0.0263
# Beta Model Training - Epoch [106/200], Loss: 0.0252
# Beta Model Training - Epoch [107/200], Loss: 0.0249
# Beta Model Training - Epoch [108/200], Loss: 0.0248
# Beta Model Training - Epoch [109/200], Loss: 0.0241
# Beta Model Training - Epoch [110/200], Loss: 0.0246
# Beta Model Training - Epoch [111/200], Loss: 0.0246
# Beta Model Training - Epoch [112/200], Loss: 0.0242
# Beta Model Training - Epoch [113/200], Loss: 0.0234
# Beta Model Training - Epoch [114/200], Loss: 0.0231
# Beta Model Training - Epoch [115/200], Loss: 0.0232
# Beta Model Training - Epoch [116/200], Loss: 0.0229
# Beta Model Training - Epoch [117/200], Loss: 0.0231
# Beta Model Training - Epoch [118/200], Loss: 0.0232
# Beta Model Training - Epoch [119/200], Loss: 0.0241
# Beta Model Training - Epoch [120/200], Loss: 0.0245
# Beta Model Training - Epoch [121/200], Loss: 0.0232
# Beta Model Training - Epoch [122/200], Loss: 0.0263
# Beta Model Training - Epoch [123/200], Loss: 0.0249
# Beta Model Training - Epoch [124/200], Loss: 0.0270
# Beta Model Training - Epoch [125/200], Loss: 0.0274
# Beta Model Training - Epoch [126/200], Loss: 0.0281
# Beta Model Training - Epoch [127/200], Loss: 0.0277
# Beta Model Training - Epoch [128/200], Loss: 0.0258
# Beta Model Training - Epoch [129/200], Loss: 0.0254
# Beta Model Training - Epoch [130/200], Loss: 0.0246
# Beta Model Training - Epoch [131/200], Loss: 0.0246
# Beta Model Training - Epoch [132/200], Loss: 0.0260
# Beta Model Training - Epoch [133/200], Loss: 0.0265
# Beta Model Training - Epoch [134/200], Loss: 0.0258
# Beta Model Training - Epoch [135/200], Loss: 0.0238
# Beta Model Training - Epoch [136/200], Loss: 0.0233
# Beta Model Training - Epoch [137/200], Loss: 0.0236
# Beta Model Training - Epoch [138/200], Loss: 0.0242
# Beta Model Training - Epoch [139/200], Loss: 0.0257
# Beta Model Training - Epoch [140/200], Loss: 0.0241
# Beta Model Training - Epoch [141/200], Loss: 0.0252
# Beta Model Training - Epoch [142/200], Loss: 0.0265
# Beta Model Training - Epoch [143/200], Loss: 0.0260
# Beta Model Training - Epoch [144/200], Loss: 0.0262
# Beta Model Training - Epoch [145/200], Loss: 0.0230
# Beta Model Training - Epoch [146/200], Loss: 0.0219
# Beta Model Training - Epoch [147/200], Loss: 0.0223
# Beta Model Training - Epoch [148/200], Loss: 0.0236
# Beta Model Training - Epoch [149/200], Loss: 0.0215
# Beta Model Training - Epoch [150/200], Loss: 0.0208
# Beta Model Training - Epoch [151/200], Loss: 0.0202
# Beta Model Training - Epoch [152/200], Loss: 0.0204
# Beta Model Training - Epoch [153/200], Loss: 0.0201
# Beta Model Training - Epoch [154/200], Loss: 0.0196
# Beta Model Training - Epoch [155/200], Loss: 0.0196
# Beta Model Training - Epoch [156/200], Loss: 0.0194
# Beta Model Training - Epoch [157/200], Loss: 0.0192
# Beta Model Training - Epoch [158/200], Loss: 0.0189
# Beta Model Training - Epoch [159/200], Loss: 0.0189
# Beta Model Training - Epoch [160/200], Loss: 0.0187
# Beta Model Training - Epoch [161/200], Loss: 0.0191
# Beta Model Training - Epoch [162/200], Loss: 0.0187
# Beta Model Training - Epoch [163/200], Loss: 0.0189
# Beta Model Training - Epoch [164/200], Loss: 0.0189
# Beta Model Training - Epoch [165/200], Loss: 0.0186
# Beta Model Training - Epoch [166/200], Loss: 0.0184
# Beta Model Training - Epoch [167/200], Loss: 0.0185
# Beta Model Training - Epoch [168/200], Loss: 0.0180
# Beta Model Training - Epoch [169/200], Loss: 0.0179
# Beta Model Training - Epoch [170/200], Loss: 0.0181
# Beta Model Training - Epoch [171/200], Loss: 0.0176
# Beta Model Training - Epoch [172/200], Loss: 0.0178
# Beta Model Training - Epoch [173/200], Loss: 0.0177
# Beta Model Training - Epoch [174/200], Loss: 0.0178
# Beta Model Training - Epoch [175/200], Loss: 0.0178
# Beta Model Training - Epoch [176/200], Loss: 0.0178
# Beta Model Training - Epoch [177/200], Loss: 0.0175
# Beta Model Training - Epoch [178/200], Loss: 0.0172
# Beta Model Training - Epoch [179/200], Loss: 0.0173
# Beta Model Training - Epoch [180/200], Loss: 0.0175
# Beta Model Training - Epoch [181/200], Loss: 0.0180
# Beta Model Training - Epoch [182/200], Loss: 0.0179
# Beta Model Training - Epoch [183/200], Loss: 0.0182
# Beta Model Training - Epoch [184/200], Loss: 0.0176
# Beta Model Training - Epoch [185/200], Loss: 0.0175
# Beta Model Training - Epoch [186/200], Loss: 0.0178
# Beta Model Training - Epoch [187/200], Loss: 0.0180
# Beta Model Training - Epoch [188/200], Loss: 0.0178
# Beta Model Training - Epoch [189/200], Loss: 0.0182
# Beta Model Training - Epoch [190/200], Loss: 0.0176
# Beta Model Training - Epoch [191/200], Loss: 0.0177
# Beta Model Training - Epoch [192/200], Loss: 0.0174
# Beta Model Training - Epoch [193/200], Loss: 0.0171
# Beta Model Training - Epoch [194/200], Loss: 0.0171
# Beta Model Training - Epoch [195/200], Loss: 0.0171
# Beta Model Training - Epoch [196/200], Loss: 0.0172
# Beta Model Training - Epoch [197/200], Loss: 0.0173
# Beta Model Training - Epoch [198/200], Loss: 0.0187
# Beta Model Training - Epoch [199/200], Loss: 0.0184
# Beta Model Training - Epoch [200/200], Loss: 0.0185
# Linear Probe Training - Epoch [1/200], Loss: 1.8741
# Linear Probe Training - Epoch [2/200], Loss: 1.4193
# Linear Probe Training - Epoch [3/200], Loss: 1.1594
# Linear Probe Training - Epoch [4/200], Loss: 0.9872
# Linear Probe Training - Epoch [5/200], Loss: 0.8737
# Linear Probe Training - Epoch [6/200], Loss: 0.7978
# Linear Probe Training - Epoch [7/200], Loss: 0.7258
# Linear Probe Training - Epoch [8/200], Loss: 0.6667
# Linear Probe Training - Epoch [9/200], Loss: 0.6113
# Linear Probe Training - Epoch [10/200], Loss: 0.5619
# Linear Probe Training - Epoch [11/200], Loss: 0.5171
# Linear Probe Training - Epoch [12/200], Loss: 0.4740
# Linear Probe Training - Epoch [13/200], Loss: 0.4471
# Linear Probe Training - Epoch [14/200], Loss: 0.4090
# Linear Probe Training - Epoch [15/200], Loss: 0.3805
# Linear Probe Training - Epoch [16/200], Loss: 0.3557
# Linear Probe Training - Epoch [17/200], Loss: 0.3318
# Linear Probe Training - Epoch [18/200], Loss: 0.3095
# Linear Probe Training - Epoch [19/200], Loss: 0.2893
# Linear Probe Training - Epoch [20/200], Loss: 0.2711
# Linear Probe Training - Epoch [21/200], Loss: 0.2549
# Linear Probe Training - Epoch [22/200], Loss: 0.2424
# Linear Probe Training - Epoch [23/200], Loss: 0.2266
# Linear Probe Training - Epoch [24/200], Loss: 0.2133
# Linear Probe Training - Epoch [25/200], Loss: 0.2045
# Linear Probe Training - Epoch [26/200], Loss: 0.1947
# Linear Probe Training - Epoch [27/200], Loss: 0.1821
# Linear Probe Training - Epoch [28/200], Loss: 0.1750
# Linear Probe Training - Epoch [29/200], Loss: 0.1655
# Linear Probe Training - Epoch [30/200], Loss: 0.1575
# Linear Probe Training - Epoch [31/200], Loss: 0.1507
# Linear Probe Training - Epoch [32/200], Loss: 0.1440
# Linear Probe Training - Epoch [33/200], Loss: 0.1381
# Linear Probe Training - Epoch [34/200], Loss: 0.1314
# Linear Probe Training - Epoch [35/200], Loss: 0.1256
# Linear Probe Training - Epoch [36/200], Loss: 0.1209
# Linear Probe Training - Epoch [37/200], Loss: 0.1161
# Linear Probe Training - Epoch [38/200], Loss: 0.1116
# Linear Probe Training - Epoch [39/200], Loss: 0.1074
# Linear Probe Training - Epoch [40/200], Loss: 0.1023
# Linear Probe Training - Epoch [41/200], Loss: 0.0989
# Linear Probe Training - Epoch [42/200], Loss: 0.0945
# Linear Probe Training - Epoch [43/200], Loss: 0.0917
# Linear Probe Training - Epoch [44/200], Loss: 0.0881
# Linear Probe Training - Epoch [45/200], Loss: 0.0853
# Linear Probe Training - Epoch [46/200], Loss: 0.0825
# Linear Probe Training - Epoch [47/200], Loss: 0.0794
# Linear Probe Training - Epoch [48/200], Loss: 0.0767
# Linear Probe Training - Epoch [49/200], Loss: 0.0750
# Linear Probe Training - Epoch [50/200], Loss: 0.0725
# Linear Probe Training - Epoch [51/200], Loss: 0.0704
# Linear Probe Training - Epoch [52/200], Loss: 0.0685
# Linear Probe Training - Epoch [53/200], Loss: 0.0664
# Linear Probe Training - Epoch [54/200], Loss: 0.0649
# Linear Probe Training - Epoch [55/200], Loss: 0.0626
# Linear Probe Training - Epoch [56/200], Loss: 0.0606
# Linear Probe Training - Epoch [57/200], Loss: 0.0596
# Linear Probe Training - Epoch [58/200], Loss: 0.0574
# Linear Probe Training - Epoch [59/200], Loss: 0.0558
# Linear Probe Training - Epoch [60/200], Loss: 0.0544
# Linear Probe Training - Epoch [61/200], Loss: 0.0531
# Linear Probe Training - Epoch [62/200], Loss: 0.0519
# Linear Probe Training - Epoch [63/200], Loss: 0.0509
# Linear Probe Training - Epoch [64/200], Loss: 0.0495
# Linear Probe Training - Epoch [65/200], Loss: 0.0487
# Linear Probe Training - Epoch [66/200], Loss: 0.0475
# Linear Probe Training - Epoch [67/200], Loss: 0.0464
# Linear Probe Training - Epoch [68/200], Loss: 0.0456
# Linear Probe Training - Epoch [69/200], Loss: 0.0448
# Linear Probe Training - Epoch [70/200], Loss: 0.0437
# Linear Probe Training - Epoch [71/200], Loss: 0.0428
# Linear Probe Training - Epoch [72/200], Loss: 0.0420
# Linear Probe Training - Epoch [73/200], Loss: 0.0416
# Linear Probe Training - Epoch [74/200], Loss: 0.0404
# Linear Probe Training - Epoch [75/200], Loss: 0.0397
# Linear Probe Training - Epoch [76/200], Loss: 0.0389
# Linear Probe Training - Epoch [77/200], Loss: 0.0383
# Linear Probe Training - Epoch [78/200], Loss: 0.0377
# Linear Probe Training - Epoch [79/200], Loss: 0.0370
# Linear Probe Training - Epoch [80/200], Loss: 0.0368
# Linear Probe Training - Epoch [81/200], Loss: 0.0362
# Linear Probe Training - Epoch [82/200], Loss: 0.0358
# Linear Probe Training - Epoch [83/200], Loss: 0.0351
# Linear Probe Training - Epoch [84/200], Loss: 0.0347
# Linear Probe Training - Epoch [85/200], Loss: 0.0344
# Linear Probe Training - Epoch [86/200], Loss: 0.0340
# Linear Probe Training - Epoch [87/200], Loss: 0.0332
# Linear Probe Training - Epoch [88/200], Loss: 0.0327
# Linear Probe Training - Epoch [89/200], Loss: 0.0323
# Linear Probe Training - Epoch [90/200], Loss: 0.0324
# Linear Probe Training - Epoch [91/200], Loss: 0.0316
# Linear Probe Training - Epoch [92/200], Loss: 0.0314
# Linear Probe Training - Epoch [93/200], Loss: 0.0307
# Linear Probe Training - Epoch [94/200], Loss: 0.0307
# Linear Probe Training - Epoch [95/200], Loss: 0.0301
# Linear Probe Training - Epoch [96/200], Loss: 0.0296
# Linear Probe Training - Epoch [97/200], Loss: 0.0295
# Linear Probe Training - Epoch [98/200], Loss: 0.0292
# Linear Probe Training - Epoch [99/200], Loss: 0.0289
# Linear Probe Training - Epoch [100/200], Loss: 0.0290
# Linear Probe Training - Epoch [101/200], Loss: 0.0285
# Linear Probe Training - Epoch [102/200], Loss: 0.0280
# Linear Probe Training - Epoch [103/200], Loss: 0.0281
# Linear Probe Training - Epoch [104/200], Loss: 0.0276
# Linear Probe Training - Epoch [105/200], Loss: 0.0276
# Linear Probe Training - Epoch [106/200], Loss: 0.0272
# Linear Probe Training - Epoch [107/200], Loss: 0.0271
# Linear Probe Training - Epoch [108/200], Loss: 0.0266
# Linear Probe Training - Epoch [109/200], Loss: 0.0270
# Linear Probe Training - Epoch [110/200], Loss: 0.0262
# Linear Probe Training - Epoch [111/200], Loss: 0.0263
# Linear Probe Training - Epoch [112/200], Loss: 0.0259
# Linear Probe Training - Epoch [113/200], Loss: 0.0256
# Linear Probe Training - Epoch [114/200], Loss: 0.0255
# Linear Probe Training - Epoch [115/200], Loss: 0.0258
# Linear Probe Training - Epoch [116/200], Loss: 0.0255
# Linear Probe Training - Epoch [117/200], Loss: 0.0254
# Linear Probe Training - Epoch [118/200], Loss: 0.0250
# Linear Probe Training - Epoch [119/200], Loss: 0.0248
# Linear Probe Training - Epoch [120/200], Loss: 0.0246
# Linear Probe Training - Epoch [121/200], Loss: 0.0245
# Linear Probe Training - Epoch [122/200], Loss: 0.0244
# Linear Probe Training - Epoch [123/200], Loss: 0.0243
# Linear Probe Training - Epoch [124/200], Loss: 0.0241
# Linear Probe Training - Epoch [125/200], Loss: 0.0241
# Linear Probe Training - Epoch [126/200], Loss: 0.0239
# Linear Probe Training - Epoch [127/200], Loss: 0.0234
# Linear Probe Training - Epoch [128/200], Loss: 0.0237
# Linear Probe Training - Epoch [129/200], Loss: 0.0235
# Linear Probe Training - Epoch [130/200], Loss: 0.0233
# Linear Probe Training - Epoch [131/200], Loss: 0.0236
# Linear Probe Training - Epoch [132/200], Loss: 0.0232
# Linear Probe Training - Epoch [133/200], Loss: 0.0232
# Linear Probe Training - Epoch [134/200], Loss: 0.0230
# Linear Probe Training - Epoch [135/200], Loss: 0.0229
# Linear Probe Training - Epoch [136/200], Loss: 0.0227
# Linear Probe Training - Epoch [137/200], Loss: 0.0230
# Linear Probe Training - Epoch [138/200], Loss: 0.0225
# Linear Probe Training - Epoch [139/200], Loss: 0.0227
# Linear Probe Training - Epoch [140/200], Loss: 0.0222
# Linear Probe Training - Epoch [141/200], Loss: 0.0221
# Linear Probe Training - Epoch [142/200], Loss: 0.0223
# Linear Probe Training - Epoch [143/200], Loss: 0.0220
# Linear Probe Training - Epoch [144/200], Loss: 0.0221
# Linear Probe Training - Epoch [145/200], Loss: 0.0222
# Linear Probe Training - Epoch [146/200], Loss: 0.0222
# Linear Probe Training - Epoch [147/200], Loss: 0.0216
# Linear Probe Training - Epoch [148/200], Loss: 0.0220
# Linear Probe Training - Epoch [149/200], Loss: 0.0217
# Linear Probe Training - Epoch [150/200], Loss: 0.0216
# Linear Probe Training - Epoch [151/200], Loss: 0.0216
# Linear Probe Training - Epoch [152/200], Loss: 0.0217
# Linear Probe Training - Epoch [153/200], Loss: 0.0212
# Linear Probe Training - Epoch [154/200], Loss: 0.0212
# Linear Probe Training - Epoch [155/200], Loss: 0.0213
# Linear Probe Training - Epoch [156/200], Loss: 0.0210
# Linear Probe Training - Epoch [157/200], Loss: 0.0211
# Linear Probe Training - Epoch [158/200], Loss: 0.0209
# Linear Probe Training - Epoch [159/200], Loss: 0.0213
# Linear Probe Training - Epoch [160/200], Loss: 0.0209
# Linear Probe Training - Epoch [161/200], Loss: 0.0212
# Linear Probe Training - Epoch [162/200], Loss: 0.0209
# Linear Probe Training - Epoch [163/200], Loss: 0.0206
# Linear Probe Training - Epoch [164/200], Loss: 0.0207
# Linear Probe Training - Epoch [165/200], Loss: 0.0205
# Linear Probe Training - Epoch [166/200], Loss: 0.0204
# Linear Probe Training - Epoch [167/200], Loss: 0.0205
# Linear Probe Training - Epoch [168/200], Loss: 0.0206
# Linear Probe Training - Epoch [169/200], Loss: 0.0203
# Linear Probe Training - Epoch [170/200], Loss: 0.0203
# Linear Probe Training - Epoch [171/200], Loss: 0.0207
# Linear Probe Training - Epoch [172/200], Loss: 0.0205
# Linear Probe Training - Epoch [173/200], Loss: 0.0205
# Linear Probe Training - Epoch [174/200], Loss: 0.0202
# Linear Probe Training - Epoch [175/200], Loss: 0.0202
# Linear Probe Training - Epoch [176/200], Loss: 0.0202
# Linear Probe Training - Epoch [177/200], Loss: 0.0203
# Linear Probe Training - Epoch [178/200], Loss: 0.0202
# Linear Probe Training - Epoch [179/200], Loss: 0.0198
# Linear Probe Training - Epoch [180/200], Loss: 0.0202
# Linear Probe Training - Epoch [181/200], Loss: 0.0199
# Linear Probe Training - Epoch [182/200], Loss: 0.0198
# Linear Probe Training - Epoch [183/200], Loss: 0.0199
# Linear Probe Training - Epoch [184/200], Loss: 0.0200
# Linear Probe Training - Epoch [185/200], Loss: 0.0199
# Linear Probe Training - Epoch [186/200], Loss: 0.0197
# Linear Probe Training - Epoch [187/200], Loss: 0.0196
# Linear Probe Training - Epoch [188/200], Loss: 0.0200
# Linear Probe Training - Epoch [189/200], Loss: 0.0199
# Linear Probe Training - Epoch [190/200], Loss: 0.0196
# Linear Probe Training - Epoch [191/200], Loss: 0.0200
# Linear Probe Training - Epoch [192/200], Loss: 0.0197
# Linear Probe Training - Epoch [193/200], Loss: 0.0197
# Linear Probe Training - Epoch [194/200], Loss: 0.0196
# Linear Probe Training - Epoch [195/200], Loss: 0.0194
# Linear Probe Training - Epoch [196/200], Loss: 0.0194
# Linear Probe Training - Epoch [197/200], Loss: 0.0193
# Linear Probe Training - Epoch [198/200], Loss: 0.0192
# Linear Probe Training - Epoch [199/200], Loss: 0.0196
# Linear Probe Training - Epoch [200/200], Loss: 0.0193

# %%
save_dir = os.path.join(curr_dir,analysis_type, 'Linear Probing')
os.makedirs(save_dir, exist_ok=True)

# %%
import matplotlib.pyplot as plt

# Print MAE of original GAE and Linear Probing and plot reconstruction result comparison of origainal GAE and Linear Probing
for iBeta in range(nBeta):
    err_o = ori_error_all[iBeta]  # [nSubject, nChan, nTime]
    err_l = linPro_error_all[iBeta]
    mean_err_o = np.mean(np.abs(err_o))
    mean_err_l = np.mean(np.abs(err_l))
    print(f"Beta {iBeta+1} Mean Absolute Error:")
    print(f"Original GAE: {mean_err_o:.6f}")
    print(f"Linear Probing: {mean_err_l:.6f}")
    
    time_mae_o = np.abs(err_o).mean(axis=(0, 1))
    time_mae_l = np.abs(err_l).mean(axis=(0, 1))
    
    plt.figure(figsize=(16,13))
    plt.plot(time_mae_o, label='Original GAE')
    plt.plot(time_mae_l, label='Linear Probing')
    plt.xlabel('Time')
    plt.ylabel('MAE')
    plt.title(f'Beta {iBeta+1} MAE of original GAE and Linear Probing over Time')
    plt.legend()
    plt.tight_layout()
    plt.savefig(os.path.join(save_dir, f'Beta_{iBeta+1}.png'))
    plt.close()
    
    print(f"Saved plot for Beta {iBeta+1}.\n")
# Out:
# Beta 1 Mean Absolute Error:
# Original GAE: 0.225791
# Linear Probing: 0.227345
# Saved plot for Beta 1.
#
# Beta 2 Mean Absolute Error:
# Original GAE: 0.241487
# Linear Probing: 0.239247
# Saved plot for Beta 2.
#
# Beta 3 Mean Absolute Error:
# Original GAE: 0.211135
# Linear Probing: 0.230027
# Saved plot for Beta 3.
#
# Beta 4 Mean Absolute Error:
# Original GAE: 0.241518
# Linear Probing: 0.250761
# Saved plot for Beta 4.
#
# Beta 5 Mean Absolute Error:
# Original GAE: 0.144080
# Linear Probing: 0.145242
# Saved plot for Beta 5.
